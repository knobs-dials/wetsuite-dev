# %% [markdown]
# Fetches a large CSV from overheid.nl,
#     takes out some of the more interesting data
#
# One of the fields is a link to a semantic store that mentions some organisational relationships,
#     these are fetched and added.
#
# See the dataset description field below for a little more information.
#
# The combination should take a few minutes overall.
#
#
# CONSIDER: broaden this, to e.g. include the codes for the provincies and waterschappen    https://tardis.overheid.nl/waardelijsten.html

# %%
import pprint, datetime, pprint, json, io, csv

import rdflib # installed package
from rdflib.namespace import RDF, RDFS, SKOS, FOAF, DCTERMS

import wetsuite.datacollect.db
import wetsuite.helpers.etree
import wetsuite.helpers.net
import wetsuite.helpers.strings

# %%
OVERHEID = rdflib.Namespace('http://standaarden.overheid.nl/owms/terms/')


_fetchcache = {} 
def urlfetch(url):
    " Fetch data from URL.  Caches results in memory, to avoid fetching the same thing multiple times within a run of this script "
    if url in _fetchcache:
        #print( 'CACHED', url )
        return _fetchcache[url]
    else:
        print( 'FETCHING', url )
        #data,_,_ = wetsuite.datacollect.db.cached_fetch( url )    # faster during debug, but requires that database to be set up (and wouldn't fetch the newest values)
        data = wetsuite.helpers.net.download( url ) # could also use urllib to make it more independent.
        _fetchcache[url] = data
        return data


def labels_from_n3(url):
    ' fetch n3 from URL, parse, then pick out and return _just_ the label '
    g = rdflib.Graph()
    n3data = urlfetch( url )
    graph = g.parse(data=n3data, format="n3")
    ret = []
    for a,b,c in graph:
        if 'http://www.w3.org/2000/01/rdf-schema#label' in b:
            ret.append( c.value )
    return tuple(ret)

# %%
class GemeenteCSVDialect(csv.Dialect):
    delimiter      = ';'
    doublequote    = True
    quotechar      = '"'
    quoting        = csv.QUOTE_ALL
    lineterminator = '\n'
    header         = True

csv.field_size_limit(1000000)

csv_bytes  = urlfetch( 'https://organisaties.overheid.nl/export/Gemeenten.csv' )
csv_utext  = csv_bytes.decode('utf8') # used to be utf-16, and take ~15s, it seems the changed it somewhere late 2023
csv_parsed = csv.DictReader( io.StringIO(csv_utext) , dialect=GemeenteCSVDialect())  # is a generator, seems to parse as it goes

# %%
gemeentes_overheidnl = [] # list of dicts

for row_dict in list( csv_parsed ): # yields just the data rows, as a {headerkey:value} dict
    print( row_dict )
    selected_dict = {}
    for field_name, value in row_dict.items():
        # - removes fields that are less interesting  or just too sparesely filled
        # - renames some long-named fields, 

        
        ## Currently ignored, but might use
        if wetsuite.helpers.strings.contains_all_of(field_name, ('Adressen', 'type', 'toelichting') ): 
            continue # not really interested, though
            field_name = 'Adressen'
            new_value = []
            for part in value.split(','):
                k, v = part.split(':', 1)
                new_value.append( (k.strip(), v.strip()) )
            value = new_value


        ## Known things to ignore
        elif wetsuite.helpers.strings.contains_any_of( field_name, (  
            'Classificaties','E-mail', 'Internet', 'Telefoon', 'Fax', 'Bezoekadres',  'Postadres',   
            'Contact pagina', 'Sociale Media', "Contactpagina's",
            'Actieve afwijkingen van de Regeling', 'Relatie met ministerie', 'Beleidsterreinen',  
            'Startdatum', 'Einddatum',
            'Type', # should always be Gemeente, in this list at least
            'Subtype',
            'Alternatieve naam', # seems empty
            'Inwoners per km2', # we have both inwoners and km2 separately anyway
            'Beschrijving', 'Informatie Woo-verzoek', 'OIN',  'Loonheffingennummer', 'btw-nummer', 'KVK-nummer',
            'Datum van publiceren begroting', 
            'Wateroppervlakte',
            'Onderdeel van',
            'Datum ter verificatie',
            'Laatste mutatie',
            #'Laatste mutatie'
            'TOOI URI', # TODO: figure out what exactly we can do with the TOOI and OWMS links
        ) ):
            continue


        ## Known things to pass through, as-is or with some tweaking
        elif field_name in ('Afkorting', 'Aantal inwoners', 'Totaal aantal zetels', 'Organisatiecode', 'Officiële naam' ):
            pass #as-is

        elif wetsuite.helpers.strings.contains_all_of(field_name, ('Raad', 'Partij', 'aantal zetels') ):
            field_name = 'Raad'
            new_value = []
            for s in value.split(';'):
                name, count = s.strip().rstrip(')').rsplit(' (',1)
                new_value.append( (name, int(count)) )
            value = new_value

        elif field_name == 'Bevat plaatsen':
            value = list( s.strip()  for s in value.split(',') )

        elif field_name == 'Oppervlakte (km2)':
            field_name = 'Oppervlakte'
            value = (int(value.rsplit(',',1)[0]), 'km2')    # that comma is confusable

        elif field_name == 'Adressen':
            value = list( s.strip() for s in value.split(',') )
            continue

        elif field_name == 'OWMS URI':  # on top of passing that URL though, fetch some details from the (indirectly) referenced RDF
            value = value.replace("'", '%27') # the URL is either given to us decoded, or never encoded in the first place, but either way...
            if 1: # temporarily disabled because there's a bug in the site
                service_area, overlaps, predecessors = set(), set(), set()
                n3_url = '%s.n3'%(value)
                g = rdflib.Graph()
                n3data = urlfetch( n3_url )
                graph = g.parse(data=n3data, format="n3")
                for a,b,c in graph: # note that c is often a  rdflib.term.Literal (hence the .value)  or a rdflib.term.URIRef (which here is coerced to str)
                    if b == OVERHEID.serviceAreaOf:
                        service_area.add( labels_from_n3( c + '.n3' ) )
                    elif b == OVERHEID.hasServiceArea:
                        pass
                    elif b == OVERHEID.CBSCode:
                        selected_dict['CBSCode'] = c.value
                    elif b == SKOS.altLabel:
                        selected_dict['altLabel'] = c.value
                    elif b == SKOS.prefLabel:
                        selected_dict['prefLabel'] = c.value
                    elif b == OVERHEID.overlapsWith:
                        overlaps.add(     labels_from_n3( c + '.n3' ) )
                    elif b == OVERHEID.predecessor: # previously in gemeente...
                        predecessors.add( labels_from_n3( c + '.n3' ) )

                    # CONSIDER: maybe use
                    elif b == RDFS.label:
                        pass
                    elif b == SKOS.prefLabel:
                        pass
                    elif b == OVERHEID.replaces:
                        pass
                    elif b == OVERHEID.successor: 
                        pass
                    elif b == OVERHEID.grondslag:
                        pass

                    # probably not
                    elif b in (RDFS.isDefinedBy, SKOS.note, SKOS.changeNote, FOAF.page, OVERHEID.startDate, OVERHEID.endDate ):
                        pass
                    elif b == RDF.type:
                        pass
                    elif b  in (DCTERMS.publisher, DCTERMS.rights, DCTERMS.isPartOf, DCTERMS.date):
                        pass
                    
                    else:
                        print('UNKNOWN RELATION', b,c)
                
                selected_dict['Service area of'] = sorted(  service_area )
                selected_dict['Overlaps with']   = sorted(  overlaps     )
                selected_dict['Predecessors']    = sorted(  predecessors )

        else:
            print("UNKNOWN field %r (%r)"%(field_name,value))
                
        selected_dict[ field_name ] = value

    #take a few sources of names and put them into one field, in order of most useful
    selected_dict['Namen'] = wetsuite.helpers.strings.ordered_unique(
        list( selected_dict.pop(key, None)   for key in ('Afkorting', 'Officiële naam', 'altLabel', 'prefLabel') ),
        remove_none=True
    )

    gemeentes_overheidnl.append( selected_dict )
# Out:
# {'Officiële naam': 'Gemeente Aa en Hunze', 'Alternatieve naam': '', 'Afkorting': 'Aa en Hunze', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '01-01-1998', 'Einddatum': '', 'Datum ter verificatie': '08-07-2023', 'Laatste mutatie': '08-07-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Spiekersteeg, huisnummer: 1, postcode: 9461 BH, plaats: GIETEN, provincieAfkorting: DR, centroideLatitude: 53.00479338, centroideLongitude: 6.76022075, centroideRdx: 247163.0, centroideRdy: 558415.0;type: Postadres, postbus: 93, postcode: 9460 AB, plaats: GIETEN', 'Telefoonnummers ': '14 0592, label: algemeen', 'Fax': '', 'E-mail adressen': 'gemeente@aaenhunze.nl, label: algemeen', "Internetpagina's": 'http://www.aaenhunze.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '279,27', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Amen, Anderen, Anloo, Annen, Annerveenschekanaal, Balloerveld, Balloo, Deurze, Eext, Eexterveen, Eexterveenschekanaal, Eexterzandvoort, Ekehaar, Eldersloo, Eleveld, Gasselte, Gasselternijveen, Gasselternijveenschemond, Gasteren, Geelbroek, Gieten, Gieterveen, Grolloo, Marwijksoord, Nieuw Annerveen, Nieuwediep, Nijlande, Nooitgedacht, Oud Annerveen, Papenvoort, Rolde, Schipborg, Schoonloo, Spijkerboor DR, Vredenheim', 'Aantal inwoners': '25724', 'Inwoners per km2': '92', 'Totaal aantal zetels': '21', 'Raad (Partij (aantal zetels))': 'Gemeentebelangen Aa en Hunze (9);VVD (3);PvdA (3);GroenLinks (3);D66 (2);CDA (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Aa_en_Hunze', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm1680', 'KVK-nummer': '01140749', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm1680', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Aa_en_Hunze.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/wpldraa.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/sopvgd.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Regiokorps_Politie_Drenthe.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Waterschap_Drents_Overijsselse_Delta.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/alescon.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/ruddr.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/GGD_Drenthe.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Waterschap_Reest_en_Wieden.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Drenthe.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Waterschap_Hunze_en_Aa's.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Veiligheidsregio_Drenthe.n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Aalsmeer', 'Alternatieve naam': '', 'Afkorting': 'Aalsmeer', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '', 'Einddatum': '', 'Datum ter verificatie': '13-07-2023', 'Laatste mutatie': '13-07-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Raadhuisplein, huisnummer: 1, postcode: 1431 EH, plaats: AALSMEER, provincieAfkorting: NH, centroideLatitude: 52.26706291, centroideLongitude: 4.75031522, centroideRdx: 111524.747, centroideRdy: 475639.972;type: Postadres, postbus: 253, postcode: 1430 AG, plaats: AALSMEER;type: Woo-Adres, straat: Raadhuisplein, huisnummer: 1, postbus: 253, postcode: 1431EH, plaats: Aalsmeer, provincieAfkorting: NH, land: Nederland, centroideLatitude: 52.26706291, centroideLongitude: 4.75031516, centroideRdx: 111524.747, centroideRdy: 475639.972', 'Telefoonnummers ': '(0297) 38 75 75, label: algemeen', 'Fax': '', 'E-mail adressen': 'info@aalsmeer.nl, label: algemeen', "Internetpagina's": 'http://www.aalsmeer.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '33,91', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Aalsmeer, Kudelstaart', 'Aantal inwoners': '33063', 'Inwoners per km2': '975', 'Totaal aantal zetels': '23', 'Raad (Partij (aantal zetels))': 'Absoluut Aalsmeer (6);CDA (6);VVD (5);D66 (3);GroenLinks (2);PvdA (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Aalsmeer_(gemeente)', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm0358', 'KVK-nummer': '34362237', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm0358', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Aalsmeer_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/ogz_amstelland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Regiokorps_Politie_Amsterdam-Amstelland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/wsagv.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/amlmlwo.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Commissie_Regionaal_Overleg_Luchthaven_Schiphol.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Hoogheemraadschap_Amstel,_Gooi_en_Vecht.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/GGD_Amsterdam.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Amstelland-_en_Meerlanden_Overleg.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Veiligheidsregio_Amsterdam-Amstelland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/schschsch.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/ggdamsaml.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Hoogheemraadschap_van_Rijnland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/vrvregams.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Stadsregio_Amsterdam.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Noorzeekanaalgebied.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Noord-Holland.n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Aalten', 'Alternatieve naam': '', 'Afkorting': 'Aalten', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '', 'Einddatum': '', 'Datum ter verificatie': '09-07-2023', 'Laatste mutatie': '09-07-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Hofstraat, huisnummer: 8, postcode: 7121 DM, plaats: AALTEN, provincieAfkorting: GD, centroideLatitude: 51.92598703, centroideLongitude: 6.5826625, centroideRdx: 237227.538, centroideRdy: 438177.8;type: Postadres, postbus: 119, postcode: 7120 AC, plaats: AALTEN', 'Telefoonnummers ': '(0543) 49 33 33, label: algemeen', 'Fax': '', 'E-mail adressen': 'gemeente@aalten.nl, label: algemeen', "Internetpagina's": 'http://www.aalten.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '97,04', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Aalten, Bredevoort, De Heurne, Dinxperlo', 'Aantal inwoners': '27244', 'Inwoners per km2': '280', 'Totaal aantal zetels': '21', 'Raad (Partij (aantal zetels))': 'CDA (7);GemeenteBelangen (4);BBB-HMV (4);Progressieve Partij (2);VVD (2);D66 (1);ChristenUnie (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Aalten_(gemeente)', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm0197', 'KVK-nummer': '09215631', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm0197', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Aalten_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Regio_Achterhoek.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Gelderland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Regiokorps_Politie_Noord-_en_Oost-Gelderland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/odach.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/gtgdnog.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/sbonl.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/GGD_Gelre-IJssel.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Veiligheidsregio_Noord-_en_Oost-Gelderland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Dinxperlo_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/reflexis.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Waterschap_Rijn_en_IJssel.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/laborijn.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/ecaenl.n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Achtkarspelen', 'Alternatieve naam': '', 'Afkorting': 'Achtkarspelen', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '', 'Einddatum': '', 'Datum ter verificatie': '25-08-2023', 'Laatste mutatie': '25-08-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Stationsstraat, huisnummer: 18, postcode: 9285 NH, plaats: BUITENPOST, provincieAfkorting: FR, centroideLatitude: 53.25549633, centroideLongitude: 6.14316759, centroideRdx: 205452.39, centroideRdy: 585702.54;type: Postadres, postbus: 2, postcode: 9285 ZV, plaats: BUITENPOST', 'Telefoonnummers ': '14 0511, label: algemeen', 'Fax': '', 'E-mail adressen': 'gemeente@achtkarspelen.nl, label: algemeen', "Internetpagina's": 'http://www.achtkarspelen.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '103,98', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Augustinusga, Boelenslaan, Buitenpost, Drogeham, Gerkesklooster, Harkema, Kootstertille, Stroobos, Surhuisterveen, Surhuizum, Twijzel, Twijzelerheide', 'Aantal inwoners': '28149', 'Inwoners per km2': '270', 'Totaal aantal zetels': '21', 'Raad (Partij (aantal zetels))': 'CDA (6);FNP (4);ChristenUnie (3);GBA (2);PvdA (2);GroenLinks (1);Onafhankelijk (1);Partij voor de Vrijheid (1);Forum voor Democratie (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Achtkarspelen', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm0059', 'KVK-nummer': '01176356', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm0059', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Achtkarspelen.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/swfrysl.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/mbnofy.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/GGD_Fryslan.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/marrekrite.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Regiokorps_Politie_Fryslan.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Servicebureau_De_Friese_Wouden.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Wetterskip_Fryslan.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Sociale_werkvoorziening_Fryslan.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Fryslan.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/wm8ktd.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Veiligheidsregio_Fryslan.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/fumo.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/huseh.n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Alblasserdam', 'Alternatieve naam': '', 'Afkorting': 'Alblasserdam', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '', 'Einddatum': '', 'Datum ter verificatie': '09-07-2023', 'Laatste mutatie': '09-07-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Cortgene, huisnummer: 2, postcode: 2951 ED, plaats: ALBLASSERDAM, provincieAfkorting: ZH, centroideLatitude: 51.86160378, centroideLongitude: 4.65801057, centroideRdx: 104771.0, centroideRdy: 430590.0;type: Postadres, postbus: 2, postcode: 2950 AA, plaats: ALBLASSERDAM', 'Telefoonnummers ': '14 078, label: algemeen', 'Fax': '', 'E-mail adressen': 'bestuurssecretariaat@alblasserdam.nl, label: algemeen', "Internetpagina's": 'http://www.alblasserdam.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '10,0', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Alblasserdam', 'Aantal inwoners': '20356', 'Inwoners per km2': '2035', 'Totaal aantal zetels': '19', 'Raad (Partij (aantal zetels))': 'SGP (5);VVD (3);CDA (3);PvdA (3);D66 (3);ChristenUnie (2)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Alblasserdam_(gemeente)', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm0482', 'KVK-nummer': '51378469', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm0482', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Alblasserdam_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/drechtwerk.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/GGD_Zuid-Holland_Zuid.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Milieudienst_Zuid-Holland_Zuid.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/DGJZHZ.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/vregzhz.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/gevudo.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Waterschap_Rivierenland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Zuid-Holland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/svhw.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/spsoub.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Omgevingsdienst_Zuid-Holland_Zuid.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/drechtsteden.n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Albrandswaard', 'Alternatieve naam': '', 'Afkorting': 'Albrandswaard', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '01-01-1985', 'Einddatum': '', 'Datum ter verificatie': '11-07-2023', 'Laatste mutatie': '11-07-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Stationsstraat, huisnummer: 4, postcode: 3161 KP, plaats: RHOON, provincieAfkorting: ZH, centroideLatitude: 51.86088914, centroideLongitude: 4.39400437, centroideRdx: 86585.03, centroideRdy: 430725.885;type: Postadres, postbus: 1000, postcode: 3160 GA, plaats: RHOON', 'Telefoonnummers ': '(010) 506 11 11, label: algemeen', 'Fax': '', 'E-mail adressen': 'info@albrandswaard.nl, label: algemeen', "Internetpagina's": 'http://www.albrandswaard.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '24,0', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Poortugaal, Rhoon, Rotterdam-Albrandswaard', 'Aantal inwoners': '26357', 'Inwoners per km2': '1098', 'Totaal aantal zetels': '22', 'Raad (Partij (aantal zetels))': 'EVA (6);VVD (5);Stem Lokaal (3);CDA (3);GroenLinks/PvdA (3);NAP (Nieuwe Albrandswaardse Partij) (1);Leefbaar Albrandswaard (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Albrandswaard', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm0613', 'KVK-nummer': '50875825', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm0613', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Albrandswaard.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/DCMR_Milieudienst_Rijnmond.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/jhrijnm.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/metregrdh.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Veiligheidsregio_Rotterdam-Rijnmond.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Regiokorps_Politie_Rotterdam-Rijnmond.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/ggdrorm.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/BAR-organisatie.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/nrsijsm.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Waterschap_Hollandse_Delta.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/koepbstgr.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Stadsregio_Rotterdam.n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Alkmaar', 'Alternatieve naam': '', 'Afkorting': 'Alkmaar', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '', 'Einddatum': '', 'Datum ter verificatie': '08-07-2023', 'Laatste mutatie': '08-07-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Mallegatsplein, huisnummer: 10, postcode: 1815 AG, plaats: ALKMAAR, provincieAfkorting: NH, centroideLatitude: 52.63536462, centroideLongitude: 4.7461302, centroideRdx: 111601.792, centroideRdy: 516621.113;type: Postadres, postbus: 53, postcode: 1800 BC, plaats: ALKMAAR', 'Telefoonnummers ': '14 072, label: algemeen', 'Fax': '', 'E-mail adressen': 'post@alkmaar.nl, label: algemeen', "Internetpagina's": 'http://www.alkmaar.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '31,22', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Alkmaar, De Rijp, Driehuizen, Graft, Grootschermer, Koedijk, Markenbinnen, Noordeinde NH, Oost-Graftdijk, Oterleek, Oudorp NH, Schermerhorn, Starnmeer, Stompetoren, Ursem Gem Schermer, West-Graftdijk, Zuidschermer', 'Aantal inwoners': '111834', 'Inwoners per km2': '3582', 'Totaal aantal zetels': '39', 'Raad (Partij (aantal zetels))': 'GroenLinks (5);OPA (5);D66 (5);VVD (4);BAS (4);CDA (3);Leefbaar Alkmaar (3);PvdA (3);Partij voor de Dieren (2);SeniorenPartij Alkmaar (2);ChristenUnie (1);SP (1);Forum voor Democratie (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Alkmaar_(gemeente)', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm0361', 'KVK-nummer': '62255398', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm0361', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Alkmaar_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Regiokorps_Politie_Noord-Holland-Noord.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/odnhn.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Recreatieschap_Geestmerambacht.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/RUDNHN.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/haltewerk.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/cocen.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Vuilverbrandingsinstallatie_Alkmaar_en_Omstreken.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/ggdholn.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Schermer_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Milieudienst_Regio_Alkmaar.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Graft-De_Rijp_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/rstwwl.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/wvschnknm.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Recreatieschap_Alkmaarder-_en_Uitgeestermeer.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Veiligheidsregio_Noord-Holland-Noord.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Hoogheemraadschap_Hollands_Noorderkwartier.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/rhcalkmaar.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/coopparkserv.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/vregnhn.n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Almelo', 'Alternatieve naam': '', 'Afkorting': 'Almelo', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '01-01-1913', 'Einddatum': '', 'Datum ter verificatie': '03-09-2023', 'Laatste mutatie': '03-09-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Haven Zuidzijde, huisnummer: 30, postcode: 7607 EW, plaats: ALMELO, provincieAfkorting: OV, centroideLatitude: 52.35722017, centroideLongitude: 6.65928678, centroideRdx: 241656.398, centroideRdy: 486241.252;type: Postadres, postbus: 5100, postcode: 7600 GC, plaats: ALMELO', 'Telefoonnummers ': '(0546) 54 11 11, label: algemeen', 'Fax': '', 'E-mail adressen': 'Gemeente@almelo.nl, label: algemeen', "Internetpagina's": 'http://www.almelo.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '69,41', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Aadorp, Almelo, Bornerbroek', 'Aantal inwoners': '73949', 'Inwoners per km2': '1065', 'Totaal aantal zetels': '35', 'Raad (Partij (aantal zetels))': 'Lokaal Almelo Samen (5);VVD (5);CDA (5);D66 (3);PvdA (3);Partij voor de Vrijheid (2);SP (2);Partij Vrij Almelo (2);ChristenUnie (2);Leefbaar Almelo (1);Democraten.Nu (1);GroenLinks (1);Lijst Çete (1);Forum voor Democratie (1);Almelo Centraal (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Almelo', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm0141', 'KVK-nummer': '08214858', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm0141', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Almelo.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/twntbdrf.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Waterschap_Vechtstromen.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/odtwente.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Veiligheidsregio_Twente.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Regio_Twente.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Overijssel.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/rcstw.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/regbedtwe.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/gembelktw.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/rudtw.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/olct.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/soweco.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Regiokorps_Politie_Twente.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Waterschap_Regge_en_Dinkel.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/GGD_Regio_Twente.n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Almere', 'Alternatieve naam': '', 'Afkorting': 'Almere', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '01-01-1984', 'Einddatum': '', 'Datum ter verificatie': '09-07-2023', 'Laatste mutatie': '09-07-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Stadhuisplein, huisnummer: 1, postcode: 1315 HR, plaats: ALMERE, provincieAfkorting: FL, centroideLatitude: 52.37170651, centroideLongitude: 5.22161002, centroideRdx: 143722.718, centroideRdy: 487105.007;type: Postadres, postbus: 200, postcode: 1300 AE, plaats: ALMERE', 'Telefoonnummers ': '14 036, label: algemeen', 'Fax': '', 'E-mail adressen': 'info@almere.nl, label: algemeen', "Internetpagina's": 'http://www.almere.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '248,77', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Almere', 'Aantal inwoners': '222825', 'Inwoners per km2': '895', 'Totaal aantal zetels': '45', 'Raad (Partij (aantal zetels))': 'VVD (6);Partij voor de Vrijheid (5);SP (4);D66 (4);PvdA (4);Leefbaar Almere (3);Partij voor de Dieren (3);GroenLinks (3);CDA (2);ChristenUnie (2);50PLUS (2);Forum voor Democratie (2);BIJ1 (2);Respect Almere (1);Almere Partij / OPA (1);DENK (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Almere_(gemeente)', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm0034', 'KVK-nummer': '32164984', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm0034', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Almere_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Waterschap_Zuiderzeeland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/ggdfld.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/wvstomgrp.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/odflgvs.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/gemgdfld.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/GGD_Flevoland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Veiligheidsregio_Flevoland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Regiokorps_Politie_Flevoland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/OFGV.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/vregfl.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/ombmetrams.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Flevoland.n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Alphen aan den Rijn', 'Alternatieve naam': '', 'Afkorting': 'Alphen aan den Rijn', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '01-01-1918', 'Einddatum': '', 'Datum ter verificatie': '08-07-2023', 'Laatste mutatie': '08-07-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Stadhuisplein, huisnummer: 1, postcode: 2405 SH, plaats: ALPHEN AAN DEN RIJN, provincieAfkorting: ZH, centroideLatitude: 52.12928954, centroideLongitude: 4.65951485, centroideRdx: 105172.925, centroideRdy: 460369.996;type: Postadres, postbus: 13, postcode: 2400 AA, plaats: ALPHEN AAN DEN RIJN', 'Telefoonnummers ': '14 0172, label: algemeen', 'Fax': '', 'E-mail adressen': 'gemeente@alphenaandenrijn.nl, label: algemeen', "Internetpagina's": 'http://www.alphenaandenrijn.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '57,68', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Aarlanderveen, Alphen aan den Rijn, Benthuizen, Boskoop, Hazerswoude-Dorp, Hazerswoude-Rijndijk, Koudekerk aan den Rijn, Zwammerdam', 'Aantal inwoners': '114182', 'Inwoners per km2': '1979', 'Totaal aantal zetels': '39', 'Raad (Partij (aantal zetels))': 'Nieuw Elan (8);GroenLinks (6);CDA (5);VVD (5);D66 (4);ChristenUnie (2);PvdA (2);SP (2);SGP (1);RijnGouwe Lokaal (1);Beter Alphen (1);Lokaal Belang Alphen (1);Forum voor Democratie (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Alphen_aan_den_Rijn_(gemeente)', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm0484', 'KVK-nummer': '27375186', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm0484', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Alphen_aan_den_Rijn_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Boskoop_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Veiligheidsregio_Hollands_Midden.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/promen.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Hoogheemraadschap_De_Stichtse_Rijnlanden.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Milieudienst_West-Holland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/odmh.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/svshslzuid.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/sohlrl.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Regiokorps_Politie_Hollands_Midden.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/ouderijnz.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Rijnstreekberaad.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Rijnwoude.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/SZHR.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/bvorenb.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/rdoghm.n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Alphen-Chaam', 'Alternatieve naam': '', 'Afkorting': 'Alphen-Chaam', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '01-01-1997', 'Einddatum': '', 'Datum ter verificatie': '23-08-2023', 'Laatste mutatie': '23-08-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Willibrordplein, huisnummer: 1, postcode: 5131 AV, plaats: ALPHEN NB, provincieAfkorting: NB, centroideLatitude: 51.48298782, centroideLongitude: 4.95473616, centroideRdx: 124960.0, centroideRdy: 388305.0;type: Postadres, postbus: 3, postcode: 5130 AA, plaats: ALPHEN NB', 'Telefoonnummers ': '013, label: algemeen', 'Fax': '', 'E-mail adressen': 'info@alphen-chaam.nl, label: algemeen', "Internetpagina's": 'http://www.alphen-chaam.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '93,63', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Alphen NB, Bavel Ac, Chaam, Galder, Strijbeek, Ulvenhout Ac', 'Aantal inwoners': '10463', 'Inwoners per km2': '111', 'Totaal aantal zetels': '15', 'Raad (Partij (aantal zetels))': 'GemeenteBelangen SamenwerkingsVerband (GBSV) (4);Gemeenschapsbelangen Alphen (GBA) (4);CDA (3);VVD (2);GSU (1);D66 (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Alphen-Chaam', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm1723', 'KVK-nummer': '50166727', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm1723', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Alphen-Chaam.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/reghvbr.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Veiligheidsregio_Midden-_en_West-Brabant.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/ravbmwn.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/abgorg.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/regwbr.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/svvsvwb.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/omwb.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Noord-Brabant.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/benego.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/GGD_West-Brabant.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/diamant-groep.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Regiokorps_Politie_Midden-_en_West-Brabant.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Waterschap_Brabantse_Delta.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Waterschap_De_Dommel.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/ngsbdz.n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Altena', 'Alternatieve naam': '', 'Afkorting': 'Altena', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '01-01-2019', 'Einddatum': '', 'Datum ter verificatie': '07-09-2023', 'Laatste mutatie': '07-09-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Sportlaan, huisnummer: 170, postcode: 4286 ET, plaats: ALMKERK, provincieAfkorting: NB, centroideLatitude: 51.77085134, centroideLongitude: 4.93960317, centroideRdx: 124105.626, centroideRdy: 420336.532;type: Postadres, postbus: 5, postcode: 4286 ZG, plaats: ALMKERK', 'Telefoonnummers ': '(0183) 51 61 00, label: algemeen', 'Fax': '', 'E-mail adressen': 'info@gemeenteAltena.nl, label: algemeen', "Internetpagina's": 'http://www.gemeenteAltena.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '201,86', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Almkerk, Andel, Babylonienbroek, Drongelen, Dussen, Eethen, Genderen, Giessen, Hank, Meeuwen, Nieuwendijk NB, Rijswijk NB, Sleeuwijk, Uitwijk, Veen, Waardhuizen, Werkendam, Wijk en Aalburg, Woudrichem', 'Aantal inwoners': '57726', 'Inwoners per km2': '285', 'Totaal aantal zetels': '31', 'Raad (Partij (aantal zetels))': 'CDA (8);AltenaLokaal (6);SGP (5);ChristenUnie (4);Progressief Altena (4);VVD (2);Vrije Volkspartij Altena (2)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Altena', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm1959', 'KVK-nummer': '73578886', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': '', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Altena.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/wvsava.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Woudrichem_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/salha.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Aalburg_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/npbiesbosch.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Werkendam_(gemeente).n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Ameland', 'Alternatieve naam': '', 'Afkorting': 'Ameland', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '', 'Einddatum': '', 'Datum ter verificatie': '07-08-2023', 'Laatste mutatie': '07-08-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Jelmeraweg, huisnummer: 1, postcode: 9162 EA, plaats: BALLUM, provincieAfkorting: FR, centroideLatitude: 53.44149463, centroideLongitude: 5.68754272, centroideRdx: 174958.0, centroideRdy: 606180.0;type: Postadres, postbus: 22, postcode: 9160 AA, plaats: HOLLUM', 'Telefoonnummers ': '(0519) 55 55 55, label: algemeen', 'Fax': '', 'E-mail adressen': 'info@ameland.nl, label: algemeen', "Internetpagina's": 'http://www.ameland.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '268,5', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Ballum, Buren FR, Hollum, Nes Ameland', 'Aantal inwoners': '3840', 'Inwoners per km2': '14', 'Totaal aantal zetels': '11', 'Raad (Partij (aantal zetels))': "AmelandEén (4);Algemeen Belang Ameland (2);Fractie Robin Oud (1);CDA (1);PvdA (1);VVD (1);Ameland '82 (1)", 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Ameland', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm0060', 'KVK-nummer': '01180264', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm0060', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Ameland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/svwad.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Milieuadviesdienst_Noord-Friesland.n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# ...
# FETCHING http://standaarden.overheid.nl/owms/terms/Zuidplas.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Moordrecht_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Zevenhuizen-Moerkapelle.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Nieuwerkerk_aan_den_IJssel.n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Zundert', 'Alternatieve naam': '', 'Afkorting': 'Zundert', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '', 'Einddatum': '', 'Datum ter verificatie': '02-09-2023', 'Laatste mutatie': '02-09-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Markt, huisnummer: 1, postcode: 4881 CN, plaats: ZUNDERT, provincieAfkorting: NB, centroideLatitude: 51.47292269, centroideLongitude: 4.66448847, centroideRdx: 104788.0, centroideRdy: 387345.0;type: Postadres, postbus: 10001, postcode: 4880 GA, plaats: ZUNDERT;type: Bezoekadres Woo-contactpersoon, straat: Markt, huisnummer: 1, postbus: 10001, postcode: 4881CN, plaats: Zundert, provincieAfkorting: NB, centroideLatitude: 51.47292269, centroideLongitude: 4.6644884, centroideRdx: 104788.0, centroideRdy: 387345.0;type: Woo-Adres, postbus: 10001, postcode: 4880 GA, plaats: zundert', 'Telefoonnummers ': '(076) 599 56 00, label: algemeen', 'Fax': '', 'E-mail adressen': 'gemeente@zundert.nl, label: algemeen', "Internetpagina's": 'http://www.zundert.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '120,12', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Achtmaal, Klein Zundert, Rijsbergen, Wernhout, Zundert', 'Aantal inwoners': '22518', 'Inwoners per km2': '187', 'Totaal aantal zetels': '19', 'Raad (Partij (aantal zetels))': 'Ondernemend Platteland (5);CDA (4);VVD (3);Dorpsbelangen (2);D66 (2);Lokaal Perspectief (2);Onafhankelijke Partij Zundert (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zundert_(gemeente)', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm0879', 'KVK-nummer': '51853876', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm0879', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Zundert_(gemeente).n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Zutphen', 'Alternatieve naam': '', 'Afkorting': 'Zutphen', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '', 'Einddatum': '', 'Datum ter verificatie': '04-08-2023', 'Laatste mutatie': '04-08-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': "type: Bezoekadres, straat: 's Gravenhof, huisnummer: 2, postcode: 7201 DN, plaats: ZUTPHEN, provincieAfkorting: GD, centroideLatitude: 52.13999395, centroideLongitude: 6.19475319, centroideRdx: 210282.0, centroideRdy: 461619.0;type: Postadres, postbus: 41, postcode: 7200 AA, plaats: ZUTPHEN", 'Telefoonnummers ': '14 0575, label: algemeen', 'Fax': '', 'E-mail adressen': 'info@zutphen.nl, label: algemeen', "Internetpagina's": 'http://www.zutphen.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '42,93', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Warnsveld, Zutphen', 'Aantal inwoners': '48510', 'Inwoners per km2': '1129', 'Totaal aantal zetels': '29', 'Raad (Partij (aantal zetels))': 'GroenLinks (5);PvdA (4);Burgerbelang (4);SP (3);D66 (3);VVD (3);Kies Bewust Lokaal (2);Partij voor de Dieren (2);ChristenUnie (1);Stadspartij (1);CDA (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zutphen_(gemeente)', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm0301', 'KVK-nummer': '50099604', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm0301', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Zutphen_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Warnsveld_(gemeente).n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Zwartewaterland', 'Alternatieve naam': '', 'Afkorting': 'Zwartewaterland', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '01-01-2001', 'Einddatum': '', 'Datum ter verificatie': '07-09-2023', 'Laatste mutatie': '07-09-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Telvorenstraat, huisnummer: 2, postcode: 8061 CB, plaats: HASSELT, provincieAfkorting: OV, centroideLatitude: 52.5920604, centroideLongitude: 6.09585327, centroideRdx: 203019.73, centroideRdy: 511845.677;type: Postadres, postbus: 23, postcode: 8060 AA, plaats: HASSELT', 'Telefoonnummers ': '(038) 385 30 00, label: algemeen', 'Fax': '', 'E-mail adressen': 'info@zwartewaterland.nl, label: algemeen', "Internetpagina's": 'http://www.zwartewaterland.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '87,91', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Genemuiden, Hasselt, Mastenbroek, Zwartsluis', 'Aantal inwoners': '23368', 'Inwoners per km2': '265', 'Totaal aantal zetels': '19', 'Raad (Partij (aantal zetels))': 'SGP (6);ChristenUnie (4);BGZ (4);PvdA (2);CDA (2);VVD (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zwartewaterland', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm1896', 'KVK-nummer': '54552907', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm1896', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Zwartewaterland.n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Hasselt_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Zwartsluis_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Genemuiden_(gemeente).n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Zwijndrecht', 'Alternatieve naam': '', 'Afkorting': 'Zwijndrecht', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '', 'Einddatum': '', 'Datum ter verificatie': '08-07-2023', 'Laatste mutatie': '08-07-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Raadhuisplein, huisnummer: 3, postcode: 3331 BT, plaats: ZWIJNDRECHT, provincieAfkorting: ZH, centroideLatitude: 51.81788323, centroideLongitude: 4.64713918, centroideRdx: 103972.666, centroideRdy: 425733.602;type: Postadres, postbus: 15, postcode: 3330 AA, plaats: ZWIJNDRECHT', 'Telefoonnummers ': '14 078, label: algemeen', 'Fax': '', 'E-mail adressen': 'gemeente@zwijndrecht.nl, label: algemeen', "Internetpagina's": 'http://www.zwijndrecht.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '22,77', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Heerjansdam, Zwijndrecht', 'Aantal inwoners': '45018', 'Inwoners per km2': '1977', 'Totaal aantal zetels': '27', 'Raad (Partij (aantal zetels))': 'Algemeen Belang Zwijndrecht (10);ChristenUnie/SGP (4);VVD (3);CDA (3);Zwijndrechtse Plus Partij (2);PvdA (2);GroenLinks (2);D66 (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zwijndrecht_(gemeente)', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm0642', 'KVK-nummer': '24490491', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm0642', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Zwijndrecht_(gemeente).n3
# FETCHING http://standaarden.overheid.nl/owms/terms/Heerjansdam_(gemeente).n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')
# {'Officiële naam': 'Gemeente Zwolle', 'Alternatieve naam': '', 'Afkorting': 'Zwolle', 'Type': 'Gemeente', 'Subtype': '', 'Startdatum': '', 'Einddatum': '', 'Datum ter verificatie': '04-08-2023', 'Laatste mutatie': '04-08-2023', 'Classificaties': 'CAO, wettelijke-grondslag: https://www.caogemeenten.nl/, opschrift: CAO Gemeenten;Overheidswerkgever, externe-url: https://www.wnra.nl/, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0001947, opschrift: Ambtenarenwet 2017;WNT-instelling, externe-url: https://www.topinkomens.nl/voor-wnt-instellingen/wnt-register, wettelijke-grondslag: http://wetten.overheid.nl/jci1.3:c:BWBR0032249&paragraaf=1&artikel=1.2&lid=1, opschrift: Gemeenten (Artikel 1.2, lid 1c, WNT);Woo, externe-url: https://www.rijksoverheid.nl/onderwerpen/wet-open-overheid-woo, wettelijke-grondslag: https://wetten.overheid.nl/BWBR0045754, opschrift: Wet open overheid', 'Onderdeel van': '', 'Beschrijving/doel': '', 'Adressen (type, toelichting, straat, huisnummer, toevoeging, postbus, postcode, plaats, regio, provincieAfkorting, land, centroideLatitude, centroideLongitude, centroideRdx, centroideRdy)': 'type: Bezoekadres, straat: Lubeckplein, huisnummer: 2, postcode: 8017 JZ, plaats: ZWOLLE, provincieAfkorting: OV, centroideLatitude: 52.50307251, centroideLongitude: 6.0909244, centroideRdx: 202782.06, centroideRdy: 501941.144;type: Postadres, postbus: 10007, postcode: 8000 GA, plaats: ZWOLLE', 'Telefoonnummers ': '14 038, label: algemeen', 'Fax': '', 'E-mail adressen': 'postbus@zwolle.nl, label: algemeen', "Internetpagina's": 'http://www.zwolle.nl, label: algemeen', 'Sociale Media': '', "Contactpagina's": '', 'Beschrijving contactgegevens': '', 'Relatie met ministerie': '', 'Oppervlakte (km2)': '119,28', 'Wateroppervlakte (km2)': '', 'Bevat plaatsen': 'Zwolle', 'Aantal inwoners': '132411', 'Inwoners per km2': '1110', 'Totaal aantal zetels': '39', 'Raad (Partij (aantal zetels))': 'ChristenUnie (7);GroenLinks (7);VVD (5);CDA (4);PvdA (4);D66 (4);Swollwacht (3);SP (2);Partij voor de Dieren (2);Volt (1)', 'Beleidsterreinen': '', 'Datum van publiceren begroting': '', 'Actieve afwijkingen van de Regeling': '', 'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zwolle_(gemeente)', 'TOOI URI': 'https://identifier.overheid.nl/tooi/id/gemeente/gm0193', 'KVK-nummer': '08218173', 'btw-nummer': '', 'Loonheffingennummer': '', 'OIN': '', 'Organisatiecode': 'gm0193', 'Actieve beheerder ROO': 'Ja'}
# FETCHING http://standaarden.overheid.nl/owms/terms/Zwolle_(gemeente).n3
# UNKNOWN field 'Actieve beheerder ROO' ('Ja')

# %%
gemeentes_overheidnl
# Out:
# [{'Oppervlakte': (279, 'km2'),
#   'Bevat plaatsen': ['Amen',
#    'Anderen',
#    'Anloo',
#    'Annen',
#    'Annerveenschekanaal',
#    'Balloerveld',
#    'Balloo',
#    'Deurze',
#    'Eext',
#    'Eexterveen',
#    'Eexterveenschekanaal',
#    'Eexterzandvoort',
#    'Ekehaar',
#    'Eldersloo',
#    'Eleveld',
#    'Gasselte',
#    'Gasselternijveen',
#    'Gasselternijveenschemond',
#    'Gasteren',
#    'Geelbroek',
#    'Gieten',
#    'Gieterveen',
#    'Grolloo',
#    'Marwijksoord',
#    'Nieuw Annerveen',
#    'Nieuwediep',
#    'Nijlande',
#    'Nooitgedacht',
#    'Oud Annerveen',
#    'Papenvoort',
#    'Rolde',
#    'Schipborg',
#    'Schoonloo',
#    'Spijkerboor DR',
#    'Vredenheim'],
#   'Aantal inwoners': '25724',
#   'Totaal aantal zetels': '21',
#   'Raad': [('Gemeentebelangen Aa en Hunze', 9),
#    ('VVD', 3),
#    ('PvdA', 3),
#    ('GroenLinks', 3),
#    ('D66', 2),
#    ('CDA', 1)],
#   'CBSCode': '1680',
#   'Service area of': [('Alescon',),
#    ('GGD Drenthe', '90'),
#    ('RUD Drenthe', 'Regionale Uitvoeringsdienst Drenthe'),
#    ('Regiokorps Politie Drenthe',),
#    ('Samenwerkingsorganisatie Publiek Vervoer Groningen Drenthe',),
#    ('VRD', 'Veiligheidsregio Drenthe'),
#    ('Werkplein Drentsche Aa', 'WPDA')],
#   'Overlaps with': [('Drenthe',),
#    ('Waterschap Drents Overijsselse Delta',),
#    ("Waterschap Hunze en Aa's",),
#    ('Waterschap Reest en Wieden',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Aa_en_Hunze',
#   'Organisatiecode': 'gm1680',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Aa en Hunze', 'Gemeente Aa en Hunze']},
#  {'Oppervlakte': (33, 'km2'),
#   'Bevat plaatsen': ['Aalsmeer', 'Kudelstaart'],
#   'Aantal inwoners': '33063',
#   'Totaal aantal zetels': '23',
#   'Raad': [('Absoluut Aalsmeer', 6),
#    ('CDA', 6),
#    ('VVD', 5),
#    ('D66', 3),
#    ('GroenLinks', 2),
#    ('PvdA', 1)],
#   'CBSCode': '0358',
#   'Service area of': [('Amstelland en Meerlanden Werkorganisatie',),
#    ('Amstelland-en Meerlandenoverleg',),
#    ('CROS', 'Commissie Regionaal Overleg Luchthaven Schiphol'),
#    ('GGD Amsterdam', '340'),
#    ('GGD Amsterdam-Amstelland',
#     'Gemeentelijke gezondheidsdienst Amsterdam-Amstelland'),
#    ('OGZ Amstelland', 'Openbare gezondheidszorg Amstelland'),
#    ('Omgevingsdienst Noordzeekanaalgebied',),
#    ('Regiokorps Politie Amsterdam-Amstelland',),
#    ('Schadeschap Luchthaven Schiphol',),
#    ('Stadsregio Amsterdam',),
#    ('Veiligheidsregio Amsterdam-Amstelland',),
#    ('Vervoerregio Amsterdam',)],
#   'Overlaps with': [('Hoogheemraadschap Amstel, Gooi en Vecht',),
#    ('Hoogheemraadschap van Rijnland',),
#    ('Noord-Holland',),
#    ('Waterschap Amstel, Gooi en Vecht',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Aalsmeer_(gemeente)',
#   'Organisatiecode': 'gm0358',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Aalsmeer', 'Gemeente Aalsmeer']},
#  {'Oppervlakte': (97, 'km2'),
#   'Bevat plaatsen': ['Aalten', 'Bredevoort', 'De Heurne', 'Dinxperlo'],
#   'Aantal inwoners': '27244',
#   'Totaal aantal zetels': '21',
#   'Raad': [('CDA', 7),
#    ('GemeenteBelangen', 4),
#    ('BBB-HMV', 4),
#    ('Progressieve Partij', 2),
#    ('VVD', 2),
#    ('D66', 1),
#    ('ChristenUnie', 1)],
#   'CBSCode': '0197',
#   'Service area of': [('Erfgoedcentrum Achterhoek en Liemers',),
#    ('GGD Gelre-IJssel',),
#    ('Gemeentelijke Gezondheidsdienst Noord- en Oost-Gelderland',
#     'GGD NOG',
#     'GGD Noord- en Oost-Gelderland'),
#    ('Omgevingsdienst Achterhoek',),
#    ('Reflexis', 'Reflexis Openbaar Basisonderwijs'),
#    ('Regio Achterhoek',),
#    ('Regiokorps Politie Noord- en Oost-Gelderland',),
#    ('Stadsbank Oost Nederland',),
#    ('Uitvoeringsorganisatie Laborijn',),
#    ('Veiligheidsregio Noord- en Oost-Gelderland', 'VNOG')],
#   'Overlaps with': [('Gelderland',), ('Waterschap Rijn en IJssel',)],
#   'Predecessors': [('Dinxperlo',)],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Aalten_(gemeente)',
#   'Organisatiecode': 'gm0197',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Aalten', 'Gemeente Aalten']},
#  {'Oppervlakte': (103, 'km2'),
#   'Bevat plaatsen': ['Augustinusga',
#    'Boelenslaan',
#    'Buitenpost',
#    'Drogeham',
#    'Gerkesklooster',
#    'Harkema',
#    'Kootstertille',
#    'Stroobos',
#    'Surhuisterveen',
#    'Surhuizum',
#    'Twijzel',
#    'Twijzelerheide'],
#   'Aantal inwoners': '28149',
#   'Totaal aantal zetels': '21',
#   'Raad': [('CDA', 6),
#    ('FNP', 4),
#    ('ChristenUnie', 3),
#    ('GBA', 2),
#    ('PvdA', 2),
#    ('GroenLinks', 1),
#    ('Onafhankelijk', 1),
#    ('Partij voor de Vrijheid', 1),
#    ('Forum voor Democratie', 1)],
#   'CBSCode': '0059',
#   'Service area of': [('FUMO',
#     'Friese Uitvoeringsdienst Milieu en Omgeving',
#     'Fryske Utfieringstsjinst Miljeu en Omjouwing'),
#    ('GGD Fryslân', '1040'),
#    ('Gemeenschappelijke Regeling SW Fryslân',),
#    ('Mobiliteitsbureau Noordoost Fryslân',),
#    ('Recreatieschap voor het Friese water en land de Marrekrite',
#     'Marrekrite'),
#    ('Regiokorps Politie Fryslân',),
#    ('Servicebureau De Friese Wouden',),
#    ('Sociale werkvoorziening Fryslân',),
#    ('VRF', 'Veiligheidsregio Fryslân'),
#    ('Werkmaatschappij 8KTD', 'WM8KTD'),
#    ('hûs en hiem, welstandsadvisering en monumentenzorg',)],
#   'Overlaps with': [('Fryslân',), ('Wetterskip Fryslân',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Achtkarspelen',
#   'Organisatiecode': 'gm0059',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Achtkarspelen', 'Gemeente Achtkarspelen']},
#  {'Oppervlakte': (10, 'km2'),
#   'Bevat plaatsen': ['Alblasserdam'],
#   'Aantal inwoners': '20356',
#   'Totaal aantal zetels': '19',
#   'Raad': [('SGP', 5),
#    ('VVD', 3),
#    ('CDA', 3),
#    ('PvdA', 3),
#    ('D66', 3),
#    ('ChristenUnie', 2)],
#   'CBSCode': '0482',
#   'Service area of': [('480', 'GGD Zuid-Holland Zuid'),
#    ('Dienst Gezondheid & Jeugd Zuid-Holland Zuid',),
#    ('Drechtwerk', 'Sociale Werkvoorziening Drechtwerk'),
#    ('Gemeenschappelijke Vuilverwerking Dordrecht en Omstreken', 'GEVUDO'),
#    ('Milieudienst Zuid-Holland Zuid',),
#    ('Omgevingsdienst Zuid-Holland Zuid', 'OZHZ'),
#    ('Samenwerkingsverband vastgoedinformatie, heffing en waardebepaling',
#     'SVHW'),
#    ('Sociaal',),
#    ('Sportpark Souburgh',),
#    ('VRZHZ', 'Veiligheidsregio Zuid-Holland Zuid')],
#   'Overlaps with': [('Waterschap Rivierenland',), ('Zuid-Holland',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Alblasserdam_(gemeente)',
#   'Organisatiecode': 'gm0482',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Alblasserdam', 'Gemeente Alblasserdam']},
#  {'Oppervlakte': (24, 'km2'),
#   'Bevat plaatsen': ['Poortugaal', 'Rhoon', 'Rotterdam-Albrandswaard'],
#   'Aantal inwoners': '26357',
#   'Totaal aantal zetels': '22',
#   'Raad': [('EVA', 6),
#    ('VVD', 5),
#    ('Stem Lokaal', 3),
#    ('CDA', 3),
#    ('GroenLinks/PvdA', 3),
#    ('NAP (Nieuwe Albrandswaardse Partij)', 1),
#    ('Leefbaar Albrandswaard', 1)],
#   'CBSCode': '0613',
#   'Service area of': [('BAR-organisatie',),
#    ('DCMR Milieudienst Rijnmond',),
#    ('Gemeentelijke Gezondheidsdienst Rotterdam-Rijnmond',
#     'GGD Rotterdam-Rijnmond',
#     '460'),
#    ('Koepelschap Buitenstedelijk Groen',),
#    ('MRDH', 'Metropoolregio Rotterdam Den Haag'),
#    ('Natuur- en recreatieschap IJsselmonde',),
#    ('Openbaar Lichaam Jeugdhulp Rijnmond', 'Jeugdhulp Rijnmond'),
#    ('Regiokorps Politie Rotterdam-Rijnmond',),
#    ('Samenwerkingsverband vastgoedinformatie, heffing en waardebepaling',
#     'SVHW'),
#    ('Stadsregio Rotterdam',),
#    ('Veiligheidsregio Rotterdam-Rijnmond',)],
#   'Overlaps with': [('Waterschap Hollandse Delta',), ('Zuid-Holland',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Albrandswaard',
#   'Organisatiecode': 'gm0613',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Albrandswaard', 'Gemeente Albrandswaard']},
#  {'Oppervlakte': (31, 'km2'),
#   'Bevat plaatsen': ['Alkmaar',
#    'De Rijp',
#    'Driehuizen',
#    'Graft',
#    'Grootschermer',
#    'Koedijk',
#    'Markenbinnen',
#    'Noordeinde NH',
#    'Oost-Graftdijk',
#    'Oterleek',
#    'Oudorp NH',
#    'Schermerhorn',
#    'Starnmeer',
#    'Stompetoren',
#    'Ursem Gem Schermer',
#    'West-Graftdijk',
#    'Zuidschermer'],
#   'Aantal inwoners': '111834',
#   'Totaal aantal zetels': '39',
#   'Raad': [('GroenLinks', 5),
#    ('OPA', 5),
#    ('D66', 5),
#    ('VVD', 4),
#    ('BAS', 4),
#    ('CDA', 3),
#    ('Leefbaar Alkmaar', 3),
#    ('PvdA', 3),
#    ('Partij voor de Dieren', 2),
#    ('SeniorenPartij Alkmaar', 2),
#    ('ChristenUnie', 1),
#    ('SP', 1),
#    ('Forum voor Democratie', 1)],
#   'CBSCode': '0361',
#   'Service area of': [('Cocensus',),
#    ('Coöperatie ParkeerService U.A.',),
#    ('Gemeentelijke Gezondheidsdienst Hollands Noorden',
#     '1620',
#     'GGD Hollands Noorden',
#     'GGD HN'),
#    ('HALte werk',),
#    ('MRA', 'Milieudienst Regio Alkmaar'),
#    ('OD NHN', 'Omgevingsdienst Noord-Holland Noord'),
#    ('Recreatieschap Alkmaarder- en Uitgeestermeer',),
#    ('Recreatieschap Geestmerambacht',),
#    ('Recreatieschap Twiske-Waterland',),
#    ('Regiokorps Politie Noord-Holland-Noord',),
#    ('Regionaal Historisch Centrum Alkmaar', 'RHC Alkmaar'),
#    ('Regionale Uitvoeringsdienst Noord-Holland Noord', 'RUD NHN'),
#    ('VVI Alkmaar e.o.', 'Vuilverbrandingsinstallatie Alkmaar en Omstreken'),
#    ('Veiligheidsregio Noord-Holland Noord',),
#    ('Veiligheidsregio Noord-Holland-Noord',),
#    ('Zaffier',)],
#   'Overlaps with': [('Hoogheemraadschap Hollands Noorderkwartier',),
#    ('Noord-Holland',)],
#   'Predecessors': [('Graft-De Rijp',), ('Schermer',)],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Alkmaar_(gemeente)',
#   'Organisatiecode': 'gm0361',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Alkmaar', 'Gemeente Alkmaar']},
#  {'Oppervlakte': (69, 'km2'),
#   'Bevat plaatsen': ['Aadorp', 'Almelo', 'Bornerbroek'],
#   'Aantal inwoners': '73949',
#   'Totaal aantal zetels': '35',
#   'Raad': [('Lokaal Almelo Samen', 5),
#    ('VVD', 5),
#    ('CDA', 5),
#    ('D66', 3),
#    ('PvdA', 3),
#    ('Partij voor de Vrijheid', 2),
#    ('SP', 2),
#    ('Partij Vrij Almelo', 2),
#    ('ChristenUnie', 2),
#    ('Leefbaar Almelo', 1),
#    ('Democraten.Nu', 1),
#    ('GroenLinks', 1),
#    ('Lijst Çete', 1),
#    ('Forum voor Democratie', 1),
#    ('Almelo Centraal', 1)],
#   'CBSCode': '0141',
#   'Service area of': [('110', 'GGD Regio Twente'),
#    ('GBTwente',
#     'Gemeenschappelijke Regeling Gemeentelijk Belastingkantoor Twente'),
#    ('ODT', 'Omgevingsdienst Twente'),
#    ('OLCT', 'Openbaar Lichaam Crematoria Twente'),
#    ('RUD Twente',),
#    ('Recreatieschap Twente',),
#    ('Regiokorps Politie Twente',),
#    ('Regionaal Bedrijventerrein Twente',),
#    ('SOWECO', 'Sociaal Werkvoorzieningsschap Centraal Overijssel '),
#    ('SamenTwente',),
#    ('Stadsbank Oost Nederland',),
#    ('Twentebedrijf',),
#    ('Veiligheidsregio Twente',)],
#   'Overlaps with': [('Overijssel',),
#    ('Waterschap Regge en Dinkel',),
#    ('Waterschap Vechtstromen',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Almelo',
#   'Organisatiecode': 'gm0141',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Almelo', 'Gemeente Almelo']},
#  {'Oppervlakte': (248, 'km2'),
#   'Bevat plaatsen': ['Almere'],
#   'Aantal inwoners': '222825',
#   'Totaal aantal zetels': '45',
#   'Raad': [('VVD', 6),
#    ('Partij voor de Vrijheid', 5),
#    ('SP', 4),
#    ('D66', 4),
#    ('PvdA', 4),
#    ('Leefbaar Almere', 3),
#    ('Partij voor de Dieren', 3),
#    ('GroenLinks', 3),
#    ('CDA', 2),
#    ('ChristenUnie', 2),
#    ('50PLUS', 2),
#    ('Forum voor Democratie', 2),
#    ('BIJ1', 2),
#    ('Respect Almere', 1),
#    ('Almere Partij / OPA', 1),
#    ('DENK', 1)],
#   'CBSCode': '0034',
#   'Service area of': [('GGD Fl', 'Gemeentelijke Gezondheidsdienst Flevoland'),
#    ('GGD Flevoland',),
#    ('Gemeenschappelijke Gezondheidsdienst Flevoland 2008', 'GGD Fl', '220'),
#    ('OMA', 'Ombudsman Metropool Amsterdam'),
#    ('Omgevingsdienst Flevoland & Gooi en Vechtstreek', 'OFGV'),
#    ('Omgevingsdienst Flevoland en Gooi en Vechtstreek',),
#    ('Regiokorps Politie Flevoland',),
#    ('Veiligheidsregio Flevoland',),
#    ('Werkvoorzieningsschap Tomingroep',)],
#   'Overlaps with': [('Flevoland',), ('Waterschap Zuiderzeeland',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Almere_(gemeente)',
#   'Organisatiecode': 'gm0034',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Almere', 'Gemeente Almere']},
#  {'Oppervlakte': (57, 'km2'),
#   'Bevat plaatsen': ['Aarlanderveen',
#    'Alphen aan den Rijn',
#    'Benthuizen',
#    'Boskoop',
#    'Hazerswoude-Dorp',
#    'Hazerswoude-Rijndijk',
#    'Koudekerk aan den Rijn',
#    'Zwammerdam'],
#   'Aantal inwoners': '114182',
#   'Totaal aantal zetels': '39',
#   'Raad': [('Nieuw Elan', 8),
#    ('GroenLinks', 6),
#    ('CDA', 5),
#    ('VVD', 5),
#    ('D66', 4),
#    ('ChristenUnie', 2),
#    ('PvdA', 2),
#    ('SP', 2),
#    ('SGP', 1),
#    ('RijnGouwe Lokaal', 1),
#    ('Beter Alphen', 1),
#    ('Lokaal Belang Alphen', 1),
#    ('Forum voor Democratie', 1)],
#   'CBSCode': '0484',
#   'Service area of': [('Bedrijfsvoeringsorganisatie Rijn en Braassem',),
#    ('CROS', 'Commissie Regionaal Overleg Luchthaven Schiphol'),
#    ('Coöperatie ParkeerService U.A.',),
#    ('De Oude Rijnzone',),
#    ('Milieudienst West-Holland',),
#    ('Omgevingsdienst Midden-Holland', 'ODMH'),
#    ('Promen',),
#    ('RDOG HM',
#     'Regionale dienst openbare gezondheidszorg Hollands Midden',
#     '1600',
#     'RDOG Hollands Midden'),
#    ('Regiokorps Politie Hollands Midden',),
#    ('Rijnstreekberaad',),
#    ('Samenwerkingsorgaan Holland Rijnland',),
#    ('Serviceorganisatie Zorg Holland Rijnland',),
#    ('Veiligheidsregio Hollands Midden',),
#    ('het Schap', 'Schadevergoedingsschap HSL-Zuid, A 16 en A 4')],
#   'Overlaps with': [('Hoogheemraadschap De Stichtse Rijnlanden',),
#    ('Hoogheemraadschap van Rijnland',),
#    ('Zuid-Holland',)],
#   'Predecessors': [('Boskoop',), ('Rijnwoude',)],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Alphen_aan_den_Rijn_(gemeente)',
#   'Organisatiecode': 'gm0484',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Alphen aan den Rijn', 'Gemeente Alphen aan den Rijn']},
#  {'Oppervlakte': (93, 'km2'),
#   'Bevat plaatsen': ['Alphen NB',
#    'Bavel Ac',
#    'Chaam',
#    'Galder',
#    'Strijbeek',
#    'Ulvenhout Ac'],
#   'Aantal inwoners': '10463',
#   'Totaal aantal zetels': '15',
#   'Raad': [('GemeenteBelangen SamenwerkingsVerband (GBSV)', 4),
#    ('Gemeenschapsbelangen Alphen (GBA)', 4),
#    ('CDA', 3),
#    ('VVD', 2),
#    ('GSU', 1),
#    ('D66', 1)],
#   'CBSCode': '1723',
#   'Service area of': [('ABG-organisatie',),
#    ('BENEGO',),
#    ('Diamant-groep',),
#    ('GGD West-Brabant', '1510'),
#    ('Gemeenschappelijk orgaan schoolverzuim en VSV regio West-Brabant',),
#    ('Nazorg gesloten stortplaatsen Bavel-Dorst en Zevenbergen',),
#    ('Omgevingsdienst Midden- en West-Brabant',),
#    ('RWB', 'Regio West-Brabant'),
#    ('Regio Hart van Brabant',),
#    ('Regiokorps Politie Midden- en West-Brabant',),
#    ('Regionale Ambulancevoorziening Brabant Midden-West-Noord',
#     'RAV Brabant Midden-West-Noord'),
#    ('Veiligheidsregio Midden- en West-Brabant',)],
#   'Overlaps with': [('Noord-Brabant',),
#    ('Waterschap Brabantse Delta',),
#    ('Waterschap De Dommel',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Alphen-Chaam',
#   'Organisatiecode': 'gm1723',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Alphen-Chaam', 'Gemeente Alphen-Chaam']},
#  {'Oppervlakte': (201, 'km2'),
#   'Bevat plaatsen': ['Almkerk',
#    'Andel',
#    'Babylonienbroek',
#    'Drongelen',
#    'Dussen',
#    'Eethen',
#    'Genderen',
#    'Giessen',
#    'Hank',
#    'Meeuwen',
#    'Nieuwendijk NB',
#    'Rijswijk NB',
#    'Sleeuwijk',
#    'Uitwijk',
#    'Veen',
#    'Waardhuizen',
#    'Werkendam',
#    'Wijk en Aalburg',
#    'Woudrichem'],
#   'Aantal inwoners': '57726',
#   'Totaal aantal zetels': '31',
#   'Raad': [('CDA', 8),
#    ('AltenaLokaal', 6),
#    ('SGP', 5),
#    ('ChristenUnie', 4),
#    ('Progressief Altena', 4),
#    ('VVD', 2),
#    ('Vrije Volkspartij Altena', 2)],
#   'CBSCode': '1959',
#   'Service area of': [('GGD West-Brabant', '1510'),
#    ('Gemeenschappelijk orgaan schoolverzuim en VSV regio West-Brabant',),
#    ('Nazorg gesloten stortplaatsen Bavel-Dorst en Zevenbergen',),
#    ('Omgevingsdienst Midden- en West-Brabant',),
#    ('Parkschap Nationaal Park De Biesbosch',),
#    ('RWB', 'Regio West-Brabant'),
#    ('Regionale Ambulancevoorziening Brabant Midden-West-Noord',
#     'RAV Brabant Midden-West-Noord'),
#    ('Samenwerkingsverband vastgoedinformatie, heffing en waardebepaling',
#     'SVHW'),
#    ('Streekarchief Langstraat Heusden Altena',),
#    ('Veiligheidsregio Midden- en West-Brabant',),
#    ('Werkbedrijf Arbeid Voor Allen', 'WAVA')],
#   'Overlaps with': [('Noord-Brabant',), ('Waterschap Rivierenland',)],
#   'Predecessors': [('Aalburg',), ('Werkendam',), ('Woudrichem',)],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Altena',
#   'Organisatiecode': '',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Altena', 'Gemeente Altena']},
#  {'Oppervlakte': (268, 'km2'),
#   'Bevat plaatsen': ['Ballum', 'Buren FR', 'Hollum', 'Nes Ameland'],
#   'Aantal inwoners': '3840',
#   'Totaal aantal zetels': '11',
#   'Raad': [('AmelandEén', 4),
#    ('Algemeen Belang Ameland', 2),
#    ('Fractie Robin Oud', 1),
#    ('CDA', 1),
#    ('PvdA', 1),
#    ('VVD', 1),
#    ("Ameland '82", 1)],
#   'CBSCode': '0060',
#   'Service area of': [('De Waddeneilanden',),
#    ('FUMO',
#     'Friese Uitvoeringsdienst Milieu en Omgeving',
#     'Fryske Utfieringstsjinst Miljeu en Omjouwing'),
#    ('GGD Fryslân', '1040'),
#    ('Milieuadviesdienst Noord Friesland',),
#    ('Regiokorps Politie Fryslân',),
#    ('VRF', 'Veiligheidsregio Fryslân'),
#    ('hûs en hiem, welstandsadvisering en monumentenzorg',)],
#   'Overlaps with': [('Fryslân',), ('Wetterskip Fryslân',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Ameland',
#   'Organisatiecode': 'gm0060',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Ameland', 'Gemeente Ameland']},
#  {'Oppervlakte': (63, 'km2'),
#   'Bevat plaatsen': ['Amersfoort',
#    'Hoogland',
#    'Hooglanderveen',
#    'Stoutenburg Noord'],
#   'Aantal inwoners': '160759',
#   'Totaal aantal zetels': '39',
#   'Raad': [('GroenLinks', 6),
#    ('D66', 6),
#    ('CDA', 5),
#    ('VVD', 4),
#    ('Amersfoort2014', 4),
#    ('ChristenUnie', 4),
#    ('PvdA', 2),
#    ('SP', 2),
#    ('Partij voor de Dieren', 2),
#    ('Burger Partij Amersfoort', 1),
#    ('Beter Amersfoort', 1),
#    ('DENK', 1),
#    ('Amersfoort voor Vrijheid', 1)],
#   'CBSCode': '0307',
#   'Service area of': [('1250',
#     'Gemeentelijke Gezondheidsdienst Regio Utrecht'),
#    ('AVU', 'Afvalverwijdering Utrecht'),
#    ('Coöperatie ParkeerService U.A.',),
#    ('GGD Midden-Nederland',),
#    ('RUD Utrecht 2.0', 'Regionale uitvoeringsdienst Utrecht 2.0'),
#    ('RWA',
#     'Regionaal Sociaal Werkvoorzieningschap Amersfoort en omgeving RWA'),
#    ('Regiokorps Politie Utrecht',),
#    ('Servicebureau|Gemeenten',),
#    ('Veiligheidsregio Utrecht', 'VRU')],
#   'Overlaps with': [('Utrecht',),
#    ('Waterschap Vallei & Eem',),
#    ('Waterschap Vallei en Veluwe',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Amersfoort_(gemeente)',
#   'Organisatiecode': 'gm0307',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Amersfoort', 'Gemeente Amersfoort']},
#  {'Oppervlakte': (42, 'km2'),
#   'Bevat plaatsen': ['Amstelveen'],
#   'Aantal inwoners': '94418',
#   'Totaal aantal zetels': '37',
#   'Raad': [('VVD', 8),
#    ('D66', 7),
#    ('Burgerbelangen Amstelveen', 5),
#    ('GroenLinks', 4),
#    ('PvdA', 3),
#    ('Goed voor Amstelveen', 2),
#    ('Actief voor Amstelveen', 2),
#    ('SP', 2),
#    ('Belang van Nederland', 1),
#    ('CDA', 1),
#    ('50PLUS', 1),
#    ('ChristenUnie', 1)],
#   'CBSCode': '0362',
#   'Service area of': [('Amstelland en Meerlanden Werkorganisatie',),
#    ('Amstelland-en Meerlandenoverleg',),
#    ('CROS', 'Commissie Regionaal Overleg Luchthaven Schiphol'),
#    ('GGD Amsterdam', '340'),
#    ('GGD Amsterdam-Amstelland',
#     'Gemeentelijke gezondheidsdienst Amsterdam-Amstelland'),
#    ('Groengebied Amstelland',),
#    ('OGZ Amstelland', 'Openbare gezondheidszorg Amstelland'),
#    ('OMA', 'Ombudsman Metropool Amsterdam'),
#    ('Omgevingsdienst Noordzeekanaalgebied',),
#    ('Regiokorps Politie Amsterdam-Amstelland',),
#    ('Schadeschap Luchthaven Schiphol',),
#    ('Stadsregio Amsterdam',),
#    ('Veiligheidsregio Amsterdam-Amstelland',),
#    ('Vervoerregio Amsterdam',)],
#   'Overlaps with': [('Hoogheemraadschap Amstel, Gooi en Vecht',),
#    ('Hoogheemraadschap van Rijnland',),
#    ('Noord-Holland',),
#    ('Waterschap Amstel, Gooi en Vecht',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Amstelveen_(gemeente)',
#   'Organisatiecode': 'gm0362',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Amstelveen', 'Gemeente Amstelveen']},
#  {'Oppervlakte': (219, 'km2'),
#   'Bevat plaatsen': ['Amsterdam', 'Weesp'],
#   'Aantal inwoners': '918117',
#   'Totaal aantal zetels': '46',
#   'Raad': [('PvdA', 9),
#    ('GroenLinks', 8),
#    ('D66', 7),
#    ('VVD', 6),
#    ('Partij voor de Dieren', 3),
#    ('JA21', 2),
#    ('DENK', 2),
#    ('SP', 2),
#    ('Volt', 2),
#    ('BIJ1', 2),
#    ('Forum voor Democratie', 1),
#    ('CDA', 1),
#    ('Lijst Kabamba', 1)],
#   'CBSCode': '0363',
#   'Service area of': [('CROS',
#     'Commissie Regionaal Overleg Luchthaven Schiphol'),
#    ('Centraal Nautisch Beheer Noordzeekanaalgebied',),
#    ('GGD Amsterdam', '340'),
#    ('GGD Amsterdam-Amstelland',
#     'Gemeentelijke gezondheidsdienst Amsterdam-Amstelland'),
#    ('Gemeenschappelijke Rekenkamer Metropool Amsterdam',
#     'Rekenkamer Zaanstad',
#     'RMA',
#     'Rekenkamer Amsterdam'),
#    ('Groengebied Amstelland',),
#    ('Nationaal Dataportaal Wegverkeer',
#     'Nationale Databank Wegverkeersgegevens',
#     'NDW'),
#    ('OMA', 'Ombudsman Metropool Amsterdam'),
#    ('Omgevingsdienst Noordzeekanaalgebied',),
#    ('Recreatieschap Spaarnwoude',),
#    ('Recreatieschap Twiske-Waterland',),
#    ('Regiokorps Politie Amsterdam-Amstelland',),
#    ('Stadsregio Amsterdam',),
#    ('Veiligheidsregio Amsterdam-Amstelland',),
#    ('Vervoerregio Amsterdam',)],
#   'Overlaps with': [('Amsterdam - Bos en Lommer',),
#    ('Amsterdam - Centrum',),
#    ('Amsterdam - De Baarsjes',),
#    ('Amsterdam - Geuzenveld-Slotermeer',),
#    ('Amsterdam - Nieuw-West',),
#    ('Amsterdam - Noord',),
#    ('Amsterdam - Oost',),
#    ('Amsterdam - Oost/Watergraafsmeer',),
#    ('Amsterdam - Osdorp',),
#    ('Amsterdam - Oud Zuid',),
#    ('Amsterdam - Oud-West',),
#    ('Amsterdam - Slotervaart',),
#    ('Amsterdam - West',),
#    ('Amsterdam - Westerpark',),
#    ('Amsterdam - Westpoort',),
#    ('Amsterdam - Zeeburg',),
#    ('Amsterdam - Zuid',),
#    ('Amsterdam - Zuideramstel',),
#    ('Amsterdam - Zuidoost',),
#    ('Hoogheemraadschap Amstel, Gooi en Vecht',),
#    ('Hoogheemraadschap Hollands Noorderkwartier',),
#    ('Hoogheemraadschap van Rijnland',),
#    ('Noord-Holland',),
#    ('Waterschap Amstel, Gooi en Vecht',)],
#   'Predecessors': [('Weesp',)],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Amsterdam',
#   'Organisatiecode': 'gm0363',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Amsterdam', 'Gemeente Amsterdam']},
#  {'Oppervlakte': (341, 'km2'),
#   'Bevat plaatsen': ['Apeldoorn',
#    'Beekbergen',
#    'Beemte Broekland',
#    'Hoenderloo',
#    'Hoog Soeren',
#    'Klarenbeek',
#    'Lieren',
#    'Loenen GLD',
#    'Radio Kootwijk',
#    'Uddel',
#    'Ugchelen',
#    'Wenum Wiesel'],
#   'Aantal inwoners': '167191',
#   'Totaal aantal zetels': '39',
#   'Raad': [('VVD', 6),
#    ('Lokaal Apeldoorn', 6),
#    ('GroenLinks', 4),
#    ('PvdA', 3),
#    ('ChristenUnie', 3),
#    ('D66', 3),
#    ('BVNL Apeldoorn', 3),
#    ('WijApeldoorn', 2),
#    ('SGP', 2),
#    ('SP', 2),
#    ('CDA', 2),
#    ('Partij voor de Dieren', 2),
#    ('50PLUS', 1)],
#   'CBSCode': '0200',
#   'Service area of': [('Euregio Rijn-Waal',),
#    ('GGD Gelre-IJssel',),
#    ('Gemeentelijke Gezondheidsdienst Noord- en Oost-Gelderland',
#     'GGD NOG',
#     'GGD Noord- en Oost-Gelderland'),
#    ('Lucrato',),
#    ('OVIJ', 'Omgevingsdienst Veluwe IJssel'),
#    ('PlusOV', 'Vervoerscentrale Stedendriehoek'),
#    ('Regiokorps Politie Noord- en Oost-Gelderland',),
#    ('Tribuut belastingsamenwerking',),
#    ('Veiligheidsregio Noord- en Oost-Gelderland', 'VNOG'),
#    ('regio Stedendriehoek',)],
#   'Overlaps with': [('Gelderland',),
#    ('Waterschap Vallei en Veluwe',),
#    ('Waterschap Veluwe',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Apeldoorn_(gemeente)',
#   'Organisatiecode': 'gm0200',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Apeldoorn', 'Gemeente Apeldoorn']},
#  {'Oppervlakte': (101, 'km2'),
#   'Bevat plaatsen': ['Arnhem'],
#   'Aantal inwoners': '165770',
#   'Totaal aantal zetels': '39',
#   'Raad': [('GroenLinks', 7),
#    ('D66', 5),
#    ('VVD', 5),
#    ('Arnhem Centraal', 4),
#    ('Partij voor de Dieren', 3),
#    ('PvdA', 3),
#    ('SP', 2),
#    ('DENK', 2),
#    ('CDA', 2),
#    ('Volt', 2),
#    ('Arnhemse Ouderen Partij', 1),
#    ('ChristenUnie', 1),
#    ('Partij voor de Vrijheid', 1),
#    ('Forum voor Democratie', 1)],
#   'CBSCode': '0202',
#   'Service area of': [('DRAN',
#     'Bedrijfsvoeringsorganisatie doelgroepenvervoer regio Arnhem Nijmegen'),
#    ('De Connectie', 'IGUO'),
#    ('Euregio Rijn-Waal',),
#    ('GGD Gelderland Midden',),
#    ('Gelders Archief',),
#    ('Gemeenschappelijk Orgaan Arnhem Nijmegen City Region',),
#    ('Groene Metropoolregio Arnhem-Nijmegen',),
#    ('Modulaire gemeenschappelijke regeling sociaal domein centraal Gelderland',
#     'MGR SDCG'),
#    ('Omgevingsdienst regio Arnhem', 'Omgevingsdienst Regio Arnhem', 'ODRA'),
#    ('Parkorganisatie',),
#    ('Presikhaaf Bedrijven',),
#    ('Recreatieschap Over-Betuwe',),
#    ('Regiokorps Politie Gelderland-Midden',),
#    ('Stadsregio Arnhem Nijmegen', 'Knooppunt Arnhem Nijmegen'),
#    ('Veiligheidsregio Gelderland-Midden',
#     '190',
#     'Veiligheids- en Gezondheidsregio Gelderland-Midden')],
#   'Overlaps with': [('Gelderland',),
#    ('Waterschap Rijn en IJssel',),
#    ('Waterschap Rivierenland',),
#    ('Waterschap Vallei en Veluwe',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Arnhem_(gemeente)',
#   'Organisatiecode': 'gm0202',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Arnhem', 'Gemeente Arnhem']},
#  {'Oppervlakte': (83, 'km2'),
#   'Bevat plaatsen': ['Assen',
#    'Loon',
#    'Rhee',
#    'Ter Aard',
#    'Ubbena',
#    'Zeijerveen',
#    'Zeijerveld'],
#   'Aantal inwoners': '69414',
#   'Totaal aantal zetels': '33',
#   'Raad': [('Stadspartij PLOP', 5),
#    ('ChristenUnie', 5),
#    ('PvdA', 4),
#    ('Assen Centraal', 3),
#    ('VVD', 3),
#    ('GroenLinks', 3),
#    ('D66', 3),
#    ('SP', 2),
#    ('50PLUS', 2),
#    ('CDA', 2),
#    ('Lijst De Rijke', 1)],
#   'CBSCode': '0106',
#   'Service area of': [('Alescon',),
#    ('GGD Drenthe', '90'),
#    ('Gemeentelijke Kredietbank Drenthe', 'GKB'),
#    ('RHC Drents Archief',),
#    ('RUD Drenthe', 'Regionale Uitvoeringsdienst Drenthe'),
#    ('Regiokorps Politie Drenthe',),
#    ('Samenwerkingsorganisatie Publiek Vervoer Groningen Drenthe',),
#    ('VRD', 'Veiligheidsregio Drenthe'),
#    ('Werkplein Drentsche Aa', 'WPDA')],
#   'Overlaps with': [('Drenthe',),
#    ('Waterschap Drents Overijsselse Delta',),
#    ("Waterschap Hunze en Aa's",),
#    ('Waterschap Noorderzijlvest',),
#    ('Waterschap Reest en Wieden',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Assen_(gemeente)',
#   'Organisatiecode': 'gm0106',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Assen', 'Gemeente Assen']},
#  {'Oppervlakte': (71, 'km2'),
#   'Bevat plaatsen': ['Asten', 'Heusden Gem Asten', 'Ommel'],
#   'Aantal inwoners': '17242',
#   'Totaal aantal zetels': '17',
#   'Raad': [('Samen voor Asten', 5),
#    ('CDA', 5),
#    ('Algemeen Belang', 4),
#    ('PGA', 2),
#    ('VVD', 1)],
#   'CBSCode': '0743',
#   'Service area of': [('Atlant Groep',),
#    ('Belastingsamenwerking Oost-Brabant', 'BSOB'),
#    ('Blink',),
#    ('GGD Brabant-Zuidoost', '1630'),
#    ('Metropoolregio Eindhoven', 'MRE'),
#    ('Omgevingsdienst Zuidoost-Brabant',),
#    ('Peelgemeenten',),
#    ('Regiokorps Politie Brabant-Zuid-Oost',),
#    ('Samenwerkingsverband Regio Eindhoven',),
#    ('Veiligheidsregio Brabant-Zuidoost', 'VRBZO'),
#    ('Werkbedrijf Atlant De Peel',)],
#   'Overlaps with': [('Noord-Brabant',), ('Waterschap Aa en Maas',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Asten_(gemeente)',
#   'Organisatiecode': 'gm0743',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Asten', 'Gemeente Asten']},
#  {'Oppervlakte': (76, 'km2'),
#   'Bevat plaatsen': ['Baarle-Nassau', 'Castelre', 'Ulicoten'],
#   'Aantal inwoners': '7071',
#   'Totaal aantal zetels': '13',
#   'Raad': [('CDA', 4), ('BAARLE!', 4), ('VPB', 3), ('Fractie Ulicoten', 2)],
#   'CBSCode': '0744',
#   'Service area of': [('ABG-organisatie',),
#    ('BENEGO',),
#    ('GGD West-Brabant', '1510'),
#    ('Gemeenschappelijk orgaan schoolverzuim en VSV regio West-Brabant',),
#    ('Nazorg gesloten stortplaatsen Bavel-Dorst en Zevenbergen',),
#    ('Omgevingsdienst Midden- en West-Brabant',),
#    ('RWB', 'Regio West-Brabant'),
#    ('Regio Hart van Brabant',),
#    ('Regiokorps Politie Midden- en West-Brabant',),
#    ('Regionale Ambulancevoorziening Brabant Midden-West-Noord',
#     'RAV Brabant Midden-West-Noord'),
#    ('Veiligheidsregio Midden- en West-Brabant',)],
#   'Overlaps with': [('Noord-Brabant',),
#    ('Waterschap Brabantse Delta',),
#    ('Waterschap De Dommel',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Baarle-Nassau_(gemeente)',
#   'Organisatiecode': 'gm0744',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Baarle-Nassau', 'Gemeente Baarle-Nassau']},
#  {'Oppervlakte': (33, 'km2'),
#   'Bevat plaatsen': ['Baarn', 'Lage Vuursche'],
#   'Aantal inwoners': '25008',
#   'Totaal aantal zetels': '19',
#   'Raad': [('VoorBaarn', 5),
#    ('VVD', 4),
#    ('GroenLinks', 3),
#    ('CDA', 2),
#    ('PvdA', 2),
#    ('ChristenUnie', 1),
#    ('D66', 1),
#    ('50PLUS', 1)],
#   'CBSCode': '0308',
#   'Service area of': [('1250',
#     'Gemeentelijke Gezondheidsdienst Regio Utrecht'),
#    ('AVU', 'Afvalverwijdering Utrecht'),
#    ('GGD Midden-Nederland',),
#    ('Gemeenschappelijke regeling samenwerking sociaal domein Baarn, Bunschoten en Soest',
#     'BBS'),
#    ('RID',),
#    ('RMN', 'Reinigingsbedrijf Midden Nederland'),
#    ('RUD Utrecht 2.0', 'Regionale uitvoeringsdienst Utrecht 2.0'),
#    ('RWA',
#     'Regionaal Sociaal Werkvoorzieningschap Amersfoort en omgeving RWA'),
#    ('Regiokorps Politie Utrecht',),
#    ('Servicebureau|Gemeenten',),
#    ('Veiligheidsregio Utrecht', 'VRU')],
#   'Overlaps with': [('Utrecht',),
#    ('Waterschap Vallei & Eem',),
#    ('Waterschap Vallei en Veluwe',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Baarn_(gemeente)',
#   'Organisatiecode': 'gm0308',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Baarn', 'Gemeente Baarn']},
#  {'Oppervlakte': (21, 'km2'),
#   'Bevat plaatsen': ['Barendrecht'],
#   'Aantal inwoners': '48812',
#   'Totaal aantal zetels': '29',
#   'Raad': [('EVB', 20),
#    ('SGP/ChristenUnie', 3),
#    ('CDA', 2),
#    ('D66', 1),
#    ('GroenLinks', 1),
#    ('VVD', 1),
#    ('PvdA', 1)],
#   'CBSCode': '0489',
#   'Service area of': [('BAR-organisatie',),
#    ('DCMR Milieudienst Rijnmond',),
#    ('GR Nieuw Reijerwaard',),
#    ('Gemeentelijke Gezondheidsdienst Rotterdam-Rijnmond',
#     'GGD Rotterdam-Rijnmond',
#     '460'),
#    ('Koepelschap Buitenstedelijk Groen',),
#    ('MRDH', 'Metropoolregio Rotterdam Den Haag'),
#    ('Natuur- en recreatieschap IJsselmonde',),
#    ('Openbaar Lichaam Jeugdhulp Rijnmond', 'Jeugdhulp Rijnmond'),
#    ('ROM Rijnmond',),
#    ('Regiokorps Politie Rotterdam-Rijnmond',),
#    ('Samenwerkingsverband vastgoedinformatie, heffing en waardebepaling',
#     'SVHW'),
#    ('Stadsregio Rotterdam',),
#    ('Veiligheidsregio Rotterdam-Rijnmond',)],
#   'Overlaps with': [('Waterschap Hollandse Delta',), ('Zuid-Holland',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Barendrecht_(gemeente)',
#   'Organisatiecode': 'gm0489',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Barendrecht', 'Gemeente Barendrecht']},
#  {'Oppervlakte': (176, 'km2'),
#   'Bevat plaatsen': ['Achterveld',
#    'Barneveld',
#    'De Glind',
#    'Garderen',
#    'Kootwijk',
#    'Kootwijkerbroek',
#    'Stroe',
#    'Terschuur',
#    'Voorthuizen',
#    'Zwartebroek'],
#   'Aantal inwoners': '61655',
#   'Totaal aantal zetels': '33',
#   'Raad': [('SGP', 10),
#    ('Lokaal Belang', 7),
#    ('ChristenUnie', 5),
#    ('CDA', 4),
#    ("Pro'98", 4),
#    ('VVD', 2),
#    ('Burger Initiatief', 1)],
#   'CBSCode': '0203',
#   'Service area of': [('Bedrijfsvoeringsorganisatie Valleihopper',),
#    ('Coöperatie ParkeerService U.A.',),
#    ('GGD Gelderland Midden',),
#    ('Omgevingsdienst de Vallei',),
#    ('Regio De Vallei',),
#    ('Regio FoodValley',),
#    ('Regiokorps Politie Gelderland-Midden',),
#    ('Veiligheidsregio Gelderland-Midden',
#     '190',
#     'Veiligheids- en Gezondheidsregio Gelderland-Midden')],
#   'Overlaps with': [('Gelderland',),
#    ('Waterschap Vallei & Eem',),
#    ('Waterschap Vallei en Veluwe',),
#    ('Waterschap Veluwe',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Barneveld_(gemeente)',
#   'Organisatiecode': 'gm0203',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Barneveld', 'Gemeente Barneveld']},
#  {'Oppervlakte': (21, 'km2'),
#   'Bevat plaatsen': ['Beek LB', 'Maastricht-Airport', 'Spaubeek'],
#   'Aantal inwoners': '16132',
#   'Totaal aantal zetels': '17',
#   'Raad': [('CDA', 6),
#    ('Burger Belangen Beek - Nieuwe Democraten Beek', 4),
#    ('Progressief Beek', 4),
#    ('Belang van Beek', 2),
#    ('VVD', 1)],
#   'CBSCode': '0888',
#   'Service area of': [('BsGW',
#     'Belastingsamenwerking Gemeenten en Waterschappen'),
#    ('GGD ZL',
#     'GGD Zuid Limburg',
#     '1610',
#     'Geneeskundige Gezondheidsdienst Zuid-Limburg'),
#    ('GGD Zuid Limburg',),
#    ('Gemeenschappelijke Regeling Participatiebedrijf Wsw',),
#    ('Gemeenschappelijke Regeling Vidar Wsw',),
#    ('Gemeenschappelijke Regeling Vixia',),
#    ('Omnibuzz',),
#    ('RUD Zuid-Limburg',),
#    ('Regio Westelijke Mijnstreek',),
#    ('Regiokorps Politie Limburg-Zuid',),
#    ('Veiligheidsregio Zuid-Limburg',)],
#   'Overlaps with': [('Limburg',),
#    ('Waterschap Limburg',),
#    ('Waterschap Roer en Overmaas',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Beek_(gemeente)',
#   'Organisatiecode': 'gm0888',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Beek', 'Gemeente Beek']},
#  {'Oppervlakte': (78, 'km2'),
#   'Bevat plaatsen': ['Amstenrade',
#    'Bingelrade',
#    'Doenrade',
#    'Hulsberg',
#    'Jabeek',
#    'Merkelbeek',
#    'Nuth',
#    'Oirsbeek',
#    'Puth',
#    'Schimmert',
#    'Schinnen',
#    'Schinveld',
#    'Sweikhuizen',
#    'Wijnandsrade'],
#   'Aantal inwoners': '35966',
#   'Totaal aantal zetels': '25',
#   'Raad': [('Beekdaelen Lokaal', 6),
#    ('CDA', 5),
#    ('Vernieuwingsgroep', 5),
#    ('GroenLinks', 3),
#    ('Fractie Rijkx - Kollée', 2),
#    ('VVD', 2),
#    ('D66', 1),
#    ('PvdA', 1)],
#   'CBSCode': '1954',
#   'Service area of': [('BsGW',
#     'Belastingsamenwerking Gemeenten en Waterschappen'),
#    ('GGD ZL',
#     'GGD Zuid Limburg',
#     '1610',
#     'Geneeskundige Gezondheidsdienst Zuid-Limburg'),
#    ('Het Gegevenshuis',),
#    ('Kompas, Gemeentelijk collectief voor werk, inkomen & zorg',
#     'Kompas',
#     'ISD Kompas'),
#    ('Omnibuzz',),
#    ('RUD Zuid-Limburg',),
#    ('Reinigingsdiensten Rd4',),
#    ('Veiligheidsregio Zuid-Limburg',),
#    ('WOZL', 'het Werkvoorzieningschap Oostelijk Zuid Limburg'),
#    ('WSP Parkstad', 'WSP', 'het Werkgeversservicepunt Parkstad')],
#   'Overlaps with': [('Limburg',),
#    ('Waterschap Limburg',),
#    ('Waterschap Roer en Overmaas',)],
#   'Predecessors': [('Nuth',), ('Onderbanken',), ('Schinnen',)],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Beekdaelen',
#   'Organisatiecode': '',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Beekdaelen', 'Gemeente Beekdaelen']},
#  {'Oppervlakte': (29, 'km2'),
#   'Bevat plaatsen': ['Beesel', 'Reuver'],
#   'Aantal inwoners': '13449',
#   'Totaal aantal zetels': '15',
#   'Raad': [('CDA', 5),
#    ('VLP', 4),
#    ('Beeselse Lijst', 3),
#    ('Samen Verder Beesel', 3)],
#   'CBSCode': '0889',
#   'Service area of': [('BsGW',
#     'Belastingsamenwerking Gemeenten en Waterschappen'),
#    ('GGD Limburg-Noord', '600'),
#    ('Modulaire gemeenschappelijke regeling sociaal domein Limburg-Noord',),
#    ('Omnibuzz',),
#    ('Openbaar Lichaam Duits-Nederlands Grenspark Maas-Swalm-Nette',),
#    ('RUD LN',
#     'RUD Limburg-Noord',
#     'Regionale Uitvoeringsdienst Limburg-Noord'),
#    ('RUD Limburg-Noord',),
#    ('Regiokorps Politie Limburg-Noord',),
#    ('Veiligheidsregio Limburg-Noord',),
#    ('Veiligheidsregio en Gemeentelijke Gezondheidsdienst Limburg-Noord',
#     'Veiligheidsregio Limburg-Noord',
#     'VRLN'),
#    ('Werkvoorzieningschap Venlo en omstreken',),
#    ('euregio rijn-maas-noord',)],
#   'Overlaps with': [('Limburg',),
#    ('Waterschap Limburg',),
#    ('Waterschap Peel en Maasvallei',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Beesel_(gemeente)',
#   'Organisatiecode': 'gm0889',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Beesel', 'Gemeente Beesel']},
#  {'Oppervlakte': (93, 'km2'),
#   'Bevat plaatsen': ['Beek-Ubbergen',
#    'Berg en Dal',
#    'Erlecom',
#    'Groesbeek',
#    'Heilig Landstichting',
#    'Kekerdom',
#    'Leuth',
#    'Millingen aan de Rijn',
#    'Ooij',
#    'Persingen',
#    'Ubbergen'],
#   'Aantal inwoners': '35420',
#   'Totaal aantal zetels': '24',
#   'Raad': [('Kernachtig Groesbeek', 7),
#    ('LOKAAL!', 6),
#    ('GroenLinks', 3),
#    ('D66', 3),
#    ('CDA', 2),
#    ('PvdA', 2),
#    ('VVD', 1)],
#   'CBSCode': '1945',
#   'Service area of': [('2010',
#     'GGD Gelderland-Zuid',
#     'Gemeentelijke Gezondheidsdienst Gelderland-Zuid'),
#    ('DRAN',
#     'Bedrijfsvoeringsorganisatie doelgroepenvervoer regio Arnhem Nijmegen'),
#    ('Euregio Rijn-Waal',),
#    ('Gemeenschappelijk Orgaan Arnhem Nijmegen City Region',),
#    ('Groene Metropoolregio Arnhem-Nijmegen',),
#    ('MARN', 'Milieusamenwerking en Afvalverwerking Regio Nijmegen'),
#    ('ODRN', 'Omgevingsdienst Regio Nijmegen'),
#    ('Stadsregio Arnhem Nijmegen', 'Knooppunt Arnhem Nijmegen'),
#    ('VRGZ', 'Veiligheidsregio Gelderland-Zuid'),
#    ('modulaire gemeenschappelijke regeling Rijk van Nijmegen',)],
#   'Overlaps with': [('Gelderland',), ('Waterschap Rivierenland',)],
#   'Predecessors': [('Groesbeek',)],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Berg_en_Dal',
#   'Organisatiecode': 'gm1945',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Berg en Dal', 'Gemeente Berg en Dal']},
#  {'Oppervlakte': (103, 'km2'),
#   'Bevat plaatsen': ['Bergeijk', 'Luyksgestel', 'Riethoven', 'Westerhoven'],
#   'Aantal inwoners': '19092',
#   'Totaal aantal zetels': '17',
#   'Raad': [('CDA', 7), ('LPB', 5), ('GroenLinks-PvdA', 3), ('VVD', 2)],
#   'CBSCode': '1724',
#   'Service area of': [('GGD Brabant-Zuidoost', '1630'),
#    ('Kempisch Bedrijvenpark',),
#    ('Metropoolregio Eindhoven', 'MRE'),
#    ('Omgevingsdienst Zuidoost-Brabant',),
#    ('Participatiebedrijf KempenPlus', 'Het Participatiebedrijf'),
#    ('Regiokorps Politie Brabant-Zuid-Oost',),
#    ('Samenwerking Kempengemeenten',),
#    ('Samenwerkingsverband Regio Eindhoven',),
#    ('Veiligheidsregio Brabant-Zuidoost', 'VRBZO'),
#    ('WVK-groep',)],
#   'Overlaps with': [('Noord-Brabant',), ('Waterschap De Dommel',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Bergeijk_(gemeente)',
#   'Organisatiecode': 'gm1724',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Bergeijk', 'Gemeente Bergeijk']},
#  {'Oppervlakte': (108, 'km2'),
#   'Bevat plaatsen': ['Afferden L',
#    'Bergen L',
#    'Siebengewald',
#    'Well L',
#    'Wellerlooi'],
#   'Aantal inwoners': '13119',
#   'Totaal aantal zetels': '15',
#   'Raad': [('CDA', 4),
#    ('PK', 4),
#    ('KERN', 3),
#    ('Dorpsbelangen Bergen', 3),
#    ('VVD', 1)],
#   'CBSCode': '0893',
#   'Service area of': [('BsGW',
#     'Belastingsamenwerking Gemeenten en Waterschappen'),
#    ('Euregio Rijn-Waal',),
#    ('GGD Limburg-Noord', '600'),
#    ('Modulaire gemeenschappelijke regeling sociaal domein Limburg-Noord',),
#    ('Omnibuzz',),
#    ('RUD LN',
#     'RUD Limburg-Noord',
#     'Regionale Uitvoeringsdienst Limburg-Noord'),
#    ('RUD Limburg-Noord',),
#    ('Regiokorps Politie Limburg-Noord',),
#    ('Veiligheidsregio Limburg-Noord',),
#    ('Veiligheidsregio en Gemeentelijke Gezondheidsdienst Limburg-Noord',
#     'Veiligheidsregio Limburg-Noord',
#     'VRLN'),
#    ('Werkvoorzieningschap Venlo en omstreken',),
#    ('euregio rijn-maas-noord',)],
#   'Overlaps with': [('Limburg',),
#    ('Waterschap Limburg',),
#    ('Waterschap Peel en Maasvallei',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Bergen_(Li)',
#   'Organisatiecode': 'gm0893',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Bergen (L)', 'Gemeente Bergen (L)']},
#  {'Oppervlakte': (119, 'km2'),
#   'Bevat plaatsen': ['Bergen NH',
#    'Bergen aan Zee',
#    'Egmond aan Zee',
#    'Egmond aan den Hoef',
#    'Egmond-Binnen',
#    'Groet',
#    'Schoorl'],
#   'Aantal inwoners': '30138',
#   'Totaal aantal zetels': '21',
#   'Raad': [('ONS DORP', 4),
#    ('KIES Lokaal', 4),
#    ('GroenLinks', 3),
#    ('CDA', 3),
#    ('VVD', 3),
#    ('D66', 2),
#    ('PvdA', 1),
#    ('Fractie Bruin', 1)],
#   'CBSCode': '0373',
#   'Service area of': [('Cocensus',),
#    ('Coöperatie ParkeerService U.A.',),
#    ('Gemeentelijke Gezondheidsdienst Hollands Noorden',
#     '1620',
#     'GGD Hollands Noorden',
#     'GGD HN'),
#    ('MRA', 'Milieudienst Regio Alkmaar'),
#    ('OD NHN', 'Omgevingsdienst Noord-Holland Noord'),
#    ('Recreatieschap Geestmerambacht',),
#    ('Regiokorps Politie Noord-Holland-Noord',),
#    ('Regionaal Historisch Centrum Alkmaar', 'RHC Alkmaar'),
#    ('Regionale Uitvoeringsdienst Noord-Holland Noord', 'RUD NHN'),
#    ('VVI Alkmaar e.o.', 'Vuilverbrandingsinstallatie Alkmaar en Omstreken'),
#    ('Veiligheidsregio Noord-Holland Noord',),
#    ('Veiligheidsregio Noord-Holland-Noord',),
#    ('Werkorganisatie BUCH',),
#    ('Zaffier',)],
#   'Overlaps with': [('Hoogheemraadschap Hollands Noorderkwartier',),
#    ('Noord-Holland',)],
#   'Predecessors': [('Egmond',), ('Schoorl',)],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Bergen_(NH)',
#   'Organisatiecode': 'gm0373',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Bergen NH', 'Gemeente Bergen NH', 'Bergen (NH)']},
#  {'Oppervlakte': (100, 'km2'),
#   'Bevat plaatsen': ['Bergen Op Zoom', 'Halsteren', 'Lepelstraat'],
#   'Aantal inwoners': '68864',
#   'Totaal aantal zetels': '33',
#   'Raad': [('VVD', 5),
#    ('GBWP', 5),
#    ('D66', 3),
#    ('Lokaal Realisme', 3),
#    ('CDA', 2),
#    ('PvdA', 2),
#    ('BSD', 2),
#    ('Groep Akkaya', 2),
#    ('V-BoZ!', 2),
#    ('GroenLinks', 2),
#    ('SP', 1),
#    ('Samen0164', 1),
#    ('50PLUS', 1),
#    ('Belang van Bergen op Zoom', 1),
#    ('Lijst Linssen', 1)],
#   'CBSCode': '0748',
#   'Service area of': [('BENEGO',),
#    ('BWB', 'Belastingsamenwerking West-Brabant'),
#    ('GGD West-Brabant', '1510'),
#    ('Gemeenschappelijk orgaan schoolverzuim en VSV regio West-Brabant',),
#    ('ICT samenwerking West-Brabant-West',),
#    ('Intergemeentelijke Sociale Dienst Brabantse Wal', 'ISD Brabantse Wal'),
#    ('Omgevingsdienst Midden- en West-Brabant',),
#    ('RWB', 'Regio West-Brabant'),
#    ('Regiokorps Politie Midden- en West-Brabant',),
#    ('Regionale Ambulancevoorziening Brabant Midden-West-Noord',
#     'RAV Brabant Midden-West-Noord'),
#    ('Veiligheidsregio Midden- en West-Brabant',),
#    ('Werkvoorzieningsschap West Noord-Brabant', 'WVS-groep'),
#    ('West-Brabants Archief', 'WBA')],
#   'Overlaps with': [('Noord-Brabant',), ('Waterschap Brabantse Delta',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Bergen_op_Zoom_(gemeente)',
#   'Organisatiecode': 'gm0748',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Bergen op Zoom', 'Gemeente Bergen op Zoom']},
#  {'Oppervlakte': (260, 'km2'),
#   'Bevat plaatsen': ['Beltrum',
#    'Borculo',
#    'Eibergen',
#    'Geesteren GLD',
#    'Gelselaar',
#    'Haarlo',
#    'Neede',
#    'Rekken',
#    'Rietmolen',
#    'Ruurlo'],
#   'Aantal inwoners': '44022',
#   'Totaal aantal zetels': '27',
#   'Raad': [('CDA', 6),
#    ('D66', 5),
#    ('VVD', 3),
#    ('PvdA', 3),
#    ('BBB', 3),
#    ('Gemeentebelangen', 2),
#    ('BBBL', 2),
#    ('GroenLinks', 2),
#    ('BP', 1)],
#   'CBSCode': '1859',
#   'Service area of': [('Erfgoedcentrum Achterhoek en Liemers',),
#    ('Fijnder', 'Sociale Dienst Oost Achterhoek'),
#    ('GGD Gelre-IJssel',),
#    ('Gemeentelijke Gezondheidsdienst Noord- en Oost-Gelderland',
#     'GGD NOG',
#     'GGD Noord- en Oost-Gelderland'),
#    ('OLCT', 'Openbaar Lichaam Crematoria Twente'),
#    ('Omgevingsdienst Achterhoek',),
#    ('Openbaar Lichaam Vuilverwering Noord Oost Achterhoek', 'OLVNOA'),
#    ('Regio Achterhoek',),
#    ('Regiokorps Politie Noord- en Oost-Gelderland',),
#    ('Stadsbank Oost Nederland',),
#    ('Veiligheidsregio Noord- en Oost-Gelderland', 'VNOG')],
#   'Overlaps with': [('Gelderland',),
#    ('Waterschap Regge en Dinkel',),
#    ('Waterschap Rijn en IJssel',),
#    ('Waterschap Vechtstromen',)],
#   'Predecessors': [('Borculo',), ('Eibergen',), ('Neede',), ('Ruurlo',)],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Berkelland',
#   'Organisatiecode': 'gm1859',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Berkelland', 'Gemeente Berkelland']},
#  {'Oppervlakte': (90, 'km2'),
#   'Bevat plaatsen': ['Heesch',
#    'Heeswijk-Dinther',
#    'Loosbroek',
#    'Nistelrode',
#    'Vorstenbosch'],
#   'Aantal inwoners': '32263',
#   'Totaal aantal zetels': '23',
#   'Raad': [('CDA', 7),
#    ('Lokaal', 5),
#    ('D66', 3),
#    ('SP', 3),
#    ('VVD', 2),
#    ('Progressief Bernheze', 2),
#    ('50PLUS', 1)],
#   'CBSCode': '1721',
#   'Service area of': [('1530', 'GGD Hart voor Brabant'),
#    ('Belastingsamenwerking Oost-Brabant', 'BSOB'),
#    ('Brabants Historisch Informatie Centrum',),
#    ('Heesch West',),
#    ('ISD Optimisd',),
#    ('ODBN', 'Omgevingsdienst Brabant Noord'),
#    ('RMB', 'Regionaal Milieubedrijf Brabant Noordoost'),
#    ('Regiokorps Politie Brabant-Noord',),
#    ('Regionale Ambulancevoorziening Brabant Midden-West-Noord',
#     'RAV Brabant Midden-West-Noord'),
#    ('Samenwerkingsverband kleinschalig collectief vervoer Brabant-Noordoost',),
#    ('Veiligheidsregio Brabant-Noord', 'VRBN'),
#    ('WVS-NB', 'Werkvoorzieningschap Noordoost-Brabant')],
#   'Overlaps with': [('Noord-Brabant',), ('Waterschap Aa en Maas',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Bernheze',
#   'Organisatiecode': 'gm1721',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Bernheze', 'Gemeente Bernheze']},
#  {'Oppervlakte': (35, 'km2'),
#   'Bevat plaatsen': ['Best'],
#   'Aantal inwoners': '30897',
#   'Totaal aantal zetels': '23',
#   'Raad': [('Jongerenpartij JO', 4),
#    ('VVD', 4),
#    ('D66', 4),
#    ('PvdA/GroenLinks', 3),
#    ('CDA', 3),
#    ('Best Open', 3),
#    ('Gemeentebelangen', 1),
#    ('ChristenUnie', 1)],
#   'CBSCode': '0753',
#   'Service area of': [('GGD Brabant-Zuidoost', '1630'),
#    ('Metropoolregio Eindhoven', 'MRE'),
#    ('Omgevingsdienst Zuidoost-Brabant',),
#    ('Regiokorps Politie Brabant-Zuid-Oost',),
#    ('Samenwerkingsverband Regio Eindhoven',),
#    ('Veiligheidsregio Brabant-Zuidoost', 'VRBZO'),
#    ('WSD', 'Werkvoorzieningsschap De Dommel')],
#   'Overlaps with': [('Noord-Brabant',), ('Waterschap De Dommel',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Best_(gemeente)',
#   'Organisatiecode': 'gm0753',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Best', 'Gemeente Best']},
#  {'Oppervlakte': (47, 'km2'),
#   'Bevat plaatsen': ['Beuningen GLD', 'Ewijk', 'Weurt', 'Winssen'],
#   'Aantal inwoners': '26573',
#   'Totaal aantal zetels': '21',
#   'Raad': [('Beuningen Nu & Morgen', 6),
#    ('VVD', 4),
#    ('D66', 3),
#    ('CDA', 3),
#    ('GroenLinks', 2),
#    ('SP', 2),
#    ('PvdA', 1)],
#   'CBSCode': '0209',
#   'Service area of': [('2010',
#     'GGD Gelderland-Zuid',
#     'Gemeentelijke Gezondheidsdienst Gelderland-Zuid'),
#    ('DRAN',
#     'Bedrijfsvoeringsorganisatie doelgroepenvervoer regio Arnhem Nijmegen'),
#    ('Euregio Rijn-Waal',),
#    ('GGD Regio Nijmegen',),
#    ('Gemeenschappelijk Orgaan Arnhem Nijmegen City Region',),
#    ('Groene Metropoolregio Arnhem-Nijmegen',),
#    ('MARN', 'Milieusamenwerking en Afvalverwerking Regio Nijmegen'),
#    ('ODRN', 'Omgevingsdienst Regio Nijmegen'),
#    ('Regiokorps Politie Gelderland-Zuid',),
#    ('Stadsregio Arnhem Nijmegen', 'Knooppunt Arnhem Nijmegen'),
#    ('VRGZ', 'Veiligheidsregio Gelderland-Zuid'),
#    ('modulaire gemeenschappelijke regeling Rijk van Nijmegen',)],
#   'Overlaps with': [('Gelderland',), ('Waterschap Rivierenland',)],
#   'Predecessors': [],
# ...
#    ('Regio Rivierenland',),
#    ('Regiokorps Politie Gelderland-Zuid',),
#    ('Regionaal Archief Rivierenland', 'RAR'),
#    ('UBR',
#     'UBRivierenland',
#     'Uitvoeringsorganisatie Breedbandnetwerk Rivierenland'),
#    ('VRGZ', 'Veiligheidsregio Gelderland-Zuid'),
#    ('Werkzaak Rivierenland',)],
#   'Overlaps with': [('Gelderland',), ('Waterschap Rivierenland',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zaltbommel_(gemeente)',
#   'Organisatiecode': 'gm0297',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Zaltbommel', 'Gemeente Zaltbommel']},
#  {'Oppervlakte': (44, 'km2'),
#   'Bevat plaatsen': ['Bentveld', 'Zandvoort'],
#   'Aantal inwoners': '17542',
#   'Totaal aantal zetels': '17',
#   'Raad': [('Ouderen Partij Zandvoort', 3),
#    ('CDA', 3),
#    ('Jong Zandvoort', 3),
#    ('Partij voor de Vrijheid', 2),
#    ('VVD', 2),
#    ('D66', 1),
#    ('GroenLinks', 1),
#    ('PvdA', 1),
#    ('ZEE (Zandvoort Echt Een)', 1)],
#   'CBSCode': '0473',
#   'Service area of': [('Coöperatie ParkeerService U.A.',),
#    ('GGD Kennemerland', '300'),
#    ('Gemeenschappelijk Orgaan schoolverzuim en voortijdig schoolverlaten West-Kennemerland',),
#    ('Omgevingsdienst IJmond',),
#    ('Orgaan Bereikbaarheid Zuid-Kennemerland',),
#    ('Participatiebedrijf Zuid-Kennemerland', 'Spaarne Werkt'),
#    ('Regiokorps Politie Kennemerland',),
#    ('Veiligheidsregio Kennemerland',)],
#   'Overlaps with': [('Hoogheemraadschap van Rijnland',), ('Noord-Holland',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zandvoort_(gemeente)',
#   'Organisatiecode': 'gm0473',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Zandvoort', 'Gemeente Zandvoort']},
#  {'Oppervlakte': (268, 'km2'),
#   'Bevat plaatsen': ['Zeewolde'],
#   'Aantal inwoners': '23692',
#   'Totaal aantal zetels': '19',
#   'Raad': [('Leefbaar Zeewolde', 10),
#    ('ChristenUnie', 4),
#    ('VVD', 2),
#    ('Actief Zeewolde', 1),
#    ('D66', 1),
#    ('CDA', 1)],
#   'CBSCode': '0050',
#   'Service area of': [('GGD Fl', 'Gemeentelijke Gezondheidsdienst Flevoland'),
#    ('GGD Flevoland',),
#    ('Gemeenschappelijke Gezondheidsdienst Flevoland 2008', 'GGD Fl', '220'),
#    ('Het Flevolands Archief',),
#    ('Meerinzicht',),
#    ('Omgevingsdienst Flevoland & Gooi en Vechtstreek', 'OFGV'),
#    ('Omgevingsdienst Flevoland en Gooi en Vechtstreek',),
#    ('Regiokorps Politie Flevoland',),
#    ('Veiligheidsregio Flevoland',)],
#   'Overlaps with': [('Flevoland',), ('Waterschap Zuiderzeeland',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zeewolde_(gemeente)',
#   'Organisatiecode': 'gm0050',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Zeewolde', 'Gemeente Zeewolde']},
#  {'Oppervlakte': (48, 'km2'),
#   'Bevat plaatsen': ['Austerlitz',
#    'Bosch en Duin',
#    'Den Dolder',
#    'Huis Ter Heide UT',
#    'Zeist'],
#   'Aantal inwoners': '66629',
#   'Totaal aantal zetels': '33',
#   'Raad': [('GroenLinks', 7),
#    ('VVD', 6),
#    ('D66', 6),
#    ('NieuwDemocratischZeist', 3),
#    ('CDA', 3),
#    ('Seyst.nu', 2),
#    ('ChristenUnie/SGP', 2),
#    ('ZeisterBelang', 1),
#    ('SP', 1),
#    ('PvdA', 1),
#    ('Onafhankelijk', 1)],
#   'CBSCode': '0355',
#   'Service area of': [('1250',
#     'Gemeentelijke Gezondheidsdienst Regio Utrecht'),
#    ('AVU', 'Afvalverwijdering Utrecht'),
#    ('Bestuur Regio Utrecht',),
#    ('BghU', 'Belastingsamenwerking gemeenten en hoogheemraadschap Utrecht'),
#    ('Coöperatie ParkeerService U.A.',),
#    ('GGD Midden-Nederland',),
#    ('Gasdistributie Zeist en Omstreken', 'GZO'),
#    ('Milieudienst Zuidoost-Utrecht',),
#    ('ODRU', 'Omgevingsdienst regio Utrecht'),
#    ('RMN', 'Reinigingsbedrijf Midden Nederland'),
#    ('RSD Kromme Rijn Heuvelrug',),
#    ('Regiokorps Politie Utrecht',),
#    ('Regionale Sociale Dienst Kromme Rijn Heuvelrug',
#     'RDWI',
#     'Regionale Dienst Werk en Inkomen Kromme Rijn Heuvelrug'),
#    ('Veiligheidsregio Utrecht', 'VRU')],
#   'Overlaps with': [('Hoogheemraadschap De Stichtse Rijnlanden',),
#    ('Utrecht',),
#    ('Waterschap Vallei & Eem',),
#    ('Waterschap Vallei en Veluwe',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zeist_(gemeente)',
#   'Organisatiecode': 'gm0355',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Zeist', 'Gemeente Zeist']},
#  {'Oppervlakte': (106, 'km2'),
#   'Bevat plaatsen': ['Aerdt',
#    'Angerlo',
#    'Babberich',
#    'Giesbeek',
#    'Herwen',
#    'Lathum',
#    'Lobith',
#    'Pannerden',
#    'Spijk Gem Zevenaar',
#    'Tolkamer',
#    'Zevenaar'],
#   'Aantal inwoners': '45042',
#   'Totaal aantal zetels': '27',
#   'Raad': [('CDA', 4),
#    ('WijZZ', 4),
#    ('VVD', 4),
#    ('PvdA', 3),
#    ('Lokaal Belang', 3),
#    ('D66', 2),
#    ('Lijst 11', 2),
#    ('GroenLinks', 2),
#    ('SP', 1),
#    ('Sociaal Zevenaar', 1),
#    ('Ons Zevenaar', 1)],
#   'CBSCode': '0299',
#   'Service area of': [('DRAN',
#     'Bedrijfsvoeringsorganisatie doelgroepenvervoer regio Arnhem Nijmegen'),
#    ('Euregio Rijn-Waal',),
#    ('GGD Gelderland Midden',),
#    ('Gemeenschappelijk Orgaan Arnhem Nijmegen City Region',),
#    ('Groene Metropoolregio Arnhem-Nijmegen',),
#    ('Modulaire gemeenschappelijke regeling sociaal domein centraal Gelderland',
#     'MGR SDCG'),
#    ('Omgevingsdienst regio Arnhem', 'Omgevingsdienst Regio Arnhem', 'ODRA'),
#    ('Presikhaaf Bedrijven',),
#    ('Regiokorps Politie Gelderland-Midden',),
#    ('Reinigingsdienst De Liemers', 'RDL'),
#    ('Samenwerking De Liemers', 'SDL'),
#    ('Stadsregio Arnhem Nijmegen', 'Knooppunt Arnhem Nijmegen'),
#    ('Streekarchivariaat de Liemers en Doesburg', 'SALD'),
#    ('Veiligheidsregio Gelderland-Midden',
#     '190',
#     'Veiligheids- en Gezondheidsregio Gelderland-Midden')],
#   'Overlaps with': [('Gelderland',), ('Waterschap Rijn en IJssel',)],
#   'Predecessors': [('Angerlo',), ('Rijnwaarden',)],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zevenaar_(gemeente)',
#   'Organisatiecode': 'gm0299',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Zevenaar', 'Gemeente Zevenaar']},
#  {'Oppervlakte': (37, 'km2'),
#   'Bevat plaatsen': ['Zoetermeer'],
#   'Aantal inwoners': '126998',
#   'Totaal aantal zetels': '39',
#   'Raad': [('Lijst Hilbrand Nawijn', 5),
#    ('VVD', 5),
#    ('GroenLinks', 4),
#    ('Partij Democratie voor Zoetermeer', 4),
#    ('Zó! Zoetermeer', 3),
#    ('D66', 3),
#    ('Zoetermeer Vooruit', 3),
#    ('PvdA', 3),
#    ('ChristenUnie-SGP', 2),
#    ('CDA', 2),
#    ('Partij voor de Vrijheid', 2),
#    ('SP', 2),
#    ('Forum voor Democratie', 1)],
#   'CBSCode': '0637',
#   'Service area of': [('390', 'Gemeentelijke Gezondheidsdienst Haaglanden'),
#    ('Bedrijvenschap Hoefweg',),
#    ('Dienst Sociale Werkvoorziening Rijswijk e.o.', 'DSW'),
#    ('GGD Zuid-Holland West',),
#    ('GR Bleizo',),
#    ('Gemeentelijke Gezondheidsdienst en Veilig Thuis Haaglanden',),
#    ('Inkoopbureau H-10',),
#    ('MRDH', 'Metropoolregio Rotterdam Den Haag'),
#    ('Omgevingsdienst Haaglanden', 'ODH'),
#    ('Regiokorps Politie Haaglanden',),
#    ('Servicebureau Jeugdhulp Haaglanden',),
#    ('Stadsgewest Haaglanden',),
#    ('Veiligheidsregio Haaglanden',),
#    ('het Schap', 'Schadevergoedingsschap HSL-Zuid, A 16 en A 4')],
#   'Overlaps with': [('Hoogheemraadschap van Delfland',),
#    ('Hoogheemraadschap van Rijnland',),
#    ('Hoogheemraadschap van Schieland en de Krimpenerwaard',),
#    ('Zuid-Holland',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zoetermeer_(gemeente)',
#   'Organisatiecode': 'gm0637',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Zoetermeer', 'Gemeente Zoetermeer']},
#  {'Oppervlakte': (21, 'km2'),
#   'Bevat plaatsen': ['Gelderswoude', 'Zoeterwoude'],
#   'Aantal inwoners': '9443',
#   'Totaal aantal zetels': '13',
#   'Raad': [('CDA', 5),
#    ('VVD', 2),
#    ('Senioren Belangen Zoeterwoude', 1),
#    ('progressief Zoeterwoude', 1)],
#   'CBSCode': '0638',
#   'Service area of': [('BSGR', 'Belastingsamenwerking Gouwe-Rijnland'),
#    ('Milieudienst West-Holland',),
#    ('Omgevingsdienst West-Holland', 'ODWH'),
#    ('RDOG HM',
#     'Regionale dienst openbare gezondheidszorg Hollands Midden',
#     '1600',
#     'RDOG Hollands Midden'),
#    ('Regiokorps Politie Hollands Midden',),
#    ('Samenwerkingsorgaan Holland Rijnland',),
#    ('Serviceorganisatie Zorg Holland Rijnland',),
#    ('Servicepunt71',),
#    ('Veiligheidsregio Hollands Midden',),
#    ('het Schap', 'Schadevergoedingsschap HSL-Zuid, A 16 en A 4')],
#   'Overlaps with': [('Hoogheemraadschap van Rijnland',), ('Zuid-Holland',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zoeterwoude_(gemeente)',
#   'Organisatiecode': 'gm0638',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Zoeterwoude', 'Gemeente Zoeterwoude']},
#  {'Oppervlakte': (18, 'km2'),
#   'Bevat plaatsen': ['Moerkapelle',
#    'Moordrecht',
#    'Nieuwerkerk aan den IJssel',
#    'Zevenhuizen ZH'],
#   'Aantal inwoners': '46981',
#   'Totaal aantal zetels': '29',
#   'Raad': [('VVD', 6),
#    ('ChristenUnie/SGP', 6),
#    ('CDA', 4),
#    ('NEZ', 4),
#    ('D66', 4),
#    ('SP', 2),
#    ('PvdA/GroenLinks', 2),
#    ('Groep Pouwels', 1)],
#   'CBSCode': '1892',
#   'Service area of': [('Bedrijvenschap Regio Gouda',),
#    ('Grondbank RZG Zuidplas',),
#    ('IJSSELgemeenten',),
#    ('Intergemeentelijk Samenwerkingsorgaan Midden-Holland', 'ISMH'),
#    ('Milieudienst Midden-Holland',),
#    ('Omgevingsdienst Midden-Holland', 'ODMH'),
#    ('Promen',),
#    ('RDOG HM',
#     'Regionale dienst openbare gezondheidszorg Hollands Midden',
#     '1600',
#     'RDOG Hollands Midden'),
#    ('Recreatieschap Hitland',),
#    ('Recreatieschap Rottemeren',),
#    ('Regio Midden-Holland',),
#    ('Regiokorps Politie Hollands Midden',),
#    ('Streekarchief Midden-Holland',),
#    ('Veiligheidsregio Hollands Midden',)],
#   'Overlaps with': [('Hoogheemraadschap van Schieland en de Krimpenerwaard',),
#    ('Zuid-Holland',)],
#   'Predecessors': [('Moordrecht',),
#    ('Nieuwerkerk aan den IJssel',),
#    ('Zevenhuizen-Moerkapelle',)],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zuidplas',
#   'Organisatiecode': 'gm1892',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Zuidplas', 'Gemeente Zuidplas']},
#  {'Oppervlakte': (120, 'km2'),
#   'Bevat plaatsen': ['Achtmaal',
#    'Klein Zundert',
#    'Rijsbergen',
#    'Wernhout',
#    'Zundert'],
#   'Aantal inwoners': '22518',
#   'Totaal aantal zetels': '19',
#   'Raad': [('Ondernemend Platteland', 5),
#    ('CDA', 4),
#    ('VVD', 3),
#    ('Dorpsbelangen', 2),
#    ('D66', 2),
#    ('Lokaal Perspectief', 2),
#    ('Onafhankelijke Partij Zundert', 1)],
#   'CBSCode': '0879',
#   'Service area of': [('BENEGO',),
#    ('BWB', 'Belastingsamenwerking West-Brabant'),
#    ('GGD West-Brabant', '1510'),
#    ('Gemeenschappelijk orgaan schoolverzuim en VSV regio West-Brabant',),
#    ('Intergemeentelijke Sociale Dienst Werkplein Hart van West-Brabant',
#     'Werkplein Hart van West-Brabant'),
#    ('Nazorg gesloten stortplaatsen Bavel-Dorst en Zevenbergen',),
#    ('Omgevingsdienst Midden- en West-Brabant',),
#    ('RWB', 'Regio West-Brabant'),
#    ('Regiokorps Politie Midden- en West-Brabant',),
#    ('Regionale Ambulancevoorziening Brabant Midden-West-Noord',
#     'RAV Brabant Midden-West-Noord'),
#    ('Veiligheidsregio Midden- en West-Brabant',),
#    ('Werkvoorzieningsschap West Noord-Brabant', 'WVS-groep'),
#    ('West-Brabants Archief', 'WBA')],
#   'Overlaps with': [('Noord-Brabant',), ('Waterschap Brabantse Delta',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zundert_(gemeente)',
#   'Organisatiecode': 'gm0879',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Zundert', 'Gemeente Zundert']},
#  {'Oppervlakte': (42, 'km2'),
#   'Bevat plaatsen': ['Warnsveld', 'Zutphen'],
#   'Aantal inwoners': '48510',
#   'Totaal aantal zetels': '29',
#   'Raad': [('GroenLinks', 5),
#    ('PvdA', 4),
#    ('Burgerbelang', 4),
#    ('SP', 3),
#    ('D66', 3),
#    ('VVD', 3),
#    ('Kies Bewust Lokaal', 2),
#    ('Partij voor de Dieren', 2),
#    ('ChristenUnie', 1),
#    ('Stadspartij', 1),
#    ('CDA', 1)],
#   'CBSCode': '0301',
#   'Service area of': [('Delta',),
#    ('GGD Gelre-IJssel',),
#    ('Gemeentelijke Gezondheidsdienst Noord- en Oost-Gelderland',
#     'GGD NOG',
#     'GGD Noord- en Oost-Gelderland'),
#    ('Het Plein',),
#    ('Omgevingsdienst Achterhoek',),
#    ('PlusOV', 'Vervoerscentrale Stedendriehoek'),
#    ('Regiokorps Politie Noord- en Oost-Gelderland',),
#    ('Tribuut belastingsamenwerking',),
#    ('Veiligheidsregio Noord- en Oost-Gelderland', 'VNOG'),
#    ('regio Stedendriehoek',)],
#   'Overlaps with': [('Gelderland',),
#    ('Waterschap Rijn en IJssel',),
#    ('Waterschap Vallei en Veluwe',),
#    ('Waterschap Veluwe',)],
#   'Predecessors': [('Warnsveld',)],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zutphen_(gemeente)',
#   'Organisatiecode': 'gm0301',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Zutphen', 'Gemeente Zutphen']},
#  {'Oppervlakte': (87, 'km2'),
#   'Bevat plaatsen': ['Genemuiden', 'Hasselt', 'Mastenbroek', 'Zwartsluis'],
#   'Aantal inwoners': '23368',
#   'Totaal aantal zetels': '19',
#   'Raad': [('SGP', 6),
#    ('ChristenUnie', 4),
#    ('BGZ', 4),
#    ('PvdA', 2),
#    ('CDA', 2),
#    ('VVD', 1)],
#   'CBSCode': '1896',
#   'Service area of': [('100', 'GGD IJsselland'),
#    ('Omgevingsdienst IJsselland', 'OD IJsselland'),
#    ('RUD IJsselland',),
#    ('Regiokorps Politie IJsselland',),
#    ('Regionaal Serviceteam Jeugd IJsselland', 'RSJ IJsselland'),
#    ('Uitvoeringsorganisatie Jeugdzorg IJsselland',),
#    ('Veiligheidsregio IJsselland',)],
#   'Overlaps with': [('Overijssel',),
#    ('Waterschap Drents Overijsselse Delta',),
#    ('Waterschap Groot Salland',),
#    ('Waterschap Reest en Wieden',)],
#   'Predecessors': [('Genemuiden',), ('Hasselt',), ('Zwartsluis',)],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zwartewaterland',
#   'Organisatiecode': 'gm1896',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Zwartewaterland', 'Gemeente Zwartewaterland']},
#  {'Oppervlakte': (22, 'km2'),
#   'Bevat plaatsen': ['Heerjansdam', 'Zwijndrecht'],
#   'Aantal inwoners': '45018',
#   'Totaal aantal zetels': '27',
#   'Raad': [('Algemeen Belang Zwijndrecht', 10),
#    ('ChristenUnie/SGP', 4),
#    ('VVD', 3),
#    ('CDA', 3),
#    ('Zwijndrechtse Plus Partij', 2),
#    ('PvdA', 2),
#    ('GroenLinks', 2),
#    ('D66', 1)],
#   'CBSCode': '0642',
#   'Service area of': [('480', 'GGD Zuid-Holland Zuid'),
#    ('Dienst Gezondheid & Jeugd Zuid-Holland Zuid',),
#    ('Drechtwerk', 'Sociale Werkvoorziening Drechtwerk'),
#    ('Gemeenschappelijke Vuilverwerking Dordrecht en Omstreken', 'GEVUDO'),
#    ('Koepelschap Buitenstedelijk Groen',),
#    ('Milieudienst Zuid-Holland Zuid',),
#    ('Natuur- en recreatieschap IJsselmonde',),
#    ('Omgevingsdienst Zuid-Holland Zuid', 'OZHZ'),
#    ('Sociaal',),
#    ('VRZHZ', 'Veiligheidsregio Zuid-Holland Zuid'),
#    ('het Schap', 'Schadevergoedingsschap HSL-Zuid, A 16 en A 4')],
#   'Overlaps with': [('Waterschap Hollandse Delta',), ('Zuid-Holland',)],
#   'Predecessors': [('Heerjansdam',)],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zwijndrecht_(gemeente)',
#   'Organisatiecode': 'gm0642',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Zwijndrecht', 'Gemeente Zwijndrecht']},
#  {'Oppervlakte': (119, 'km2'),
#   'Bevat plaatsen': ['Zwolle'],
#   'Aantal inwoners': '132411',
#   'Totaal aantal zetels': '39',
#   'Raad': [('ChristenUnie', 7),
#    ('GroenLinks', 7),
#    ('VVD', 5),
#    ('CDA', 4),
#    ('PvdA', 4),
#    ('D66', 4),
#    ('Swollwacht', 3),
#    ('SP', 2),
#    ('Partij voor de Dieren', 2),
#    ('Volt', 1)],
#   'CBSCode': '0193',
#   'Service area of': [('100', 'GGD IJsselland'),
#    ('Gemeenschappelijk Belastingkantoor Lococensus - Tricijn', 'GBLT'),
#    ('Historisch Centrum Overijssel',),
#    ('ONS', 'Shared Service Centrum ONS'),
#    ('Omgevingsdienst IJsselland', 'OD IJsselland'),
#    ('RUD IJsselland',),
#    ('Regiokorps Politie IJsselland',),
#    ('Regionaal Serviceteam Jeugd IJsselland', 'RSJ IJsselland'),
#    ('Uitvoeringsorganisatie Jeugdzorg IJsselland',),
#    ('Veiligheidsregio IJsselland',)],
#   'Overlaps with': [('Overijssel',),
#    ('Waterschap Drents Overijsselse Delta',),
#    ('Waterschap Groot Salland',)],
#   'Predecessors': [],
#   'OWMS URI': 'http://standaarden.overheid.nl/owms/terms/Zwolle_(gemeente)',
#   'Organisatiecode': 'gm0193',
#   'Actieve beheerder ROO': 'Ja',
#   'Namen': ['Zwolle', 'Gemeente Zwolle']}]

# %%
pprint.pprint( gemeentes_overheidnl )


## Write that structure to a file
today_str = datetime.date.today().strftime('%Y-%m-%d')
with open('gemeentes.json', 'wb') as f:
    dataset = {
        'description':'''
This is largely the more interesting fields from https://organisaties.overheid.nl/export/Gemeenten.csv
augmented with some of the RDF data like that under https://standaarden.overheid.nl/owms/terms/Leiden_(gemeente)


.data is a list of dicts, one per gemeente (currently 344 of them). Keys in that dict include:

'Namen' - a list of name variants. 
    Usually just the short name, and a longer one with "Gemeente " in front
    Sometimes with alternative names, e.g. ["Den Bosch", "Gemeente 's-Hertogenbosch", "'s-Hertogenbosch"]
    We have used these as "Match one of these" to search for gemeentebeleid per gemeente

Descriptions like 'Aantal inwoners', 'Oppervlakte'

Organisational relations like 
    - 'Bevat plaatsen'
    - 'Overlaps with', mentioning Provinces, Waterschappen
    - 'Service area of' - things like GGD, Police, Social services  (each item is a list because we tend to have a full name and an abbreviation)
    - 'Predecessors' - mentions previous gemeente names

Useful in other APIs / joining with other data
- 'OWMS URI'
- 'CBSCode', 'Organisatiecode'

Politics
- 'Totaal aantal zetels', 'Raad'


This version was fetched from overheid.nl on %s
        '''%today_str,
        'fetched':today_str, 
        'data':gemeentes_overheidnl,
    }

    f.write( json.dumps( dataset ).encode('u8') )




# # some context   https://nl.wikipedia.org/wiki/Lijst_van_voormalige_Nederlandse_gemeenten


# # from wikipedia
# import bs4, requests, urllib.parse 
# import wetsuite.helpers.net
# url = 'https://nl.wikipedia.org/wiki/Lijst_van_Nederlandse_gemeenten'
# soup = bs4.BeautifulSoup( wetsuite.helpers.net.download( url ), features="xml" )
# rows = soup.select("#mw-content-text table.wikitable tbody tr")
# gemeentes_wiki = []
# for row in rows:
#     ths = row.select('th')
#     if len(ths) == 1: # data rows use oe TH for the name, easiest way to filter out the header rows
#         cells = row.select('td, th')
#         if len(cells) in (10,11): # real data row, last column may be missing
#             name_flag, cbscode, province, population, area_km2, _, _,_,_, kaartimg, inkomen = (cells+[None]*4)[:11]
#             name = name_flag.text.strip() # CONSIDER: URL to flag, URL to map image
#             if name in ('Bonaire', 'Sint Eustatius', 'Saba' ):
#                 continue
#             #flaglink = name_flag.find('a')
#             #if flaglink is not None:
#             #    print( urllib.parse.urljoin( url, flaglink.find('img').get('src') ) ) # flag url. These seem to be effectively public domain (see the link)
#             cbscode = cbscode.text.strip()
#             province = province.text.strip()
#             population =   int( float( population.text.replace('.','') ) )
#             area_km2   = float( area_km2.text.replace(',','.') )
#
#             gemeentes_wiki.append( (name, cbscode, province, population) )
#         else:
#             raise ValueError( 'weird row (%d): %r'%(len(cells), row) )
#
#
# pprint.pprint(gemeentes_wiki)

# %% [markdown]
# ##
