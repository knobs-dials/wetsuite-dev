# %% [markdown]
# # Purpose of this notebook
#
# Finding the varied names used to refer to laws can help,
# among other things, resolve the varied references to them, and e.g. see how unambiguous those are.
#
# Even when specific laws and regulations have official names, people will use shortened names, acronyms, and other variations,
# and we would like to know these - also to support finding the many references that use these.
#
# <!-- -->
#
# This code takes the approach of "we don't care to catch every case, if we throw enough data at is we will get clean results via consistent use" approach.
#
# That said, a lot of the (messy) code is specifically there to try to get something out of at least the majority of references,
# which is also messy code because it's playing whack-a-mole with alternate ways of formatting names and/or identifiers.
#
# <!-- -->
#
# This notebook may not be directly useful to you, but might contain some code you might consider taking, and which we might put into our library.
#
# <!-- -->
#
# The below spends time stripping things like "article x lid y" from the text because we care mostly about the main names,
# but actually the non-stripped  text is specifically interesting to e.g. train a classifier on finding these references by text.

# %%
import re, collections, pprint, random, json, urllib.parse

import bs4, requests

import wetsuite.datasets
import wetsuite.helpers.etree
import wetsuite.helpers.localdata
import wetsuite.helpers.meta
import wetsuite.helpers.strings
import wetsuite.helpers.koop_parse
import wetsuite.helpers.spacy
import wetsuite.extras.word_cloud

# %%
_parse_cache = {} # url -> etree object; see cached_parsed for why
# in a separate cell so we can tweak the helpers without clearing this cache

# %%
# some helper functions we will use later

def cached_parse(store, url, disabled=1):
    ''' This isn't necessary, but helps speed in notebooks while working on this:
        when repeatedly running extractions on the same HTML/XML, 
        it helps to keep those parses in memory, rather than interpret them each time.

        This caches the result of fetch-and-parse.
        It does however take considerable RAM when, say, reading _all_ versions within BWB, so `disabled` is a quick hack for this to _just_ parse each time after all
    '''
    if not disabled  and  url in _parse_cache:
        return _parse_cache[url] # return cached
    else: # parse, and store in cacke
        data = store.get( url )
        tree = wetsuite.helpers.etree.fromstring( data )
        tree = wetsuite.helpers.etree.strip_namespace( tree )
        #wetsuite.helpers.etree.indent_inplace( tree )
        if not disabled: # store
            _parse_cache[url] = tree
        return tree
    

# The distinction between the two cleanup functions became vague;  maybe merge
# and there is an argument for using  wetsuite.helpers.patterns.find_nonidentifier_references() to strip the 
#  TODO: consider both
def cleanup_basics(name: str):
    ' tries to turn a more detailed reference like "artikel 3 van de Woo"  into  "Woo"   but nothing more creative than that ' 
    if 'van de ' in name:
        name = name[name.index('van de ')+7:].strip()
    if 'van het ' in name:
        name = name[name.index('van het ')+8:].strip()
    if ', art' in name: # "Woo, artikel" -> Woo
        name = name[:name.index(', art')].strip()

    for re_remove in ('^[Aa]rt(?:[.]|ikel)? [0-9:.]+[a-z]*',   # at start
                        '[Aa]rt(?:[.]|ikel)? [0-9:.]+[a-z]*$',  # at end
                        ):
        if re.search( re_remove, name ) is not None:
            name = re.sub(re_remove, ' ', name).strip(', ')

    for re_remove in ('^lid [0-9:.]+[\u00baa-z]*',   # at start
                        'lid [0-9:.]+[\u00baa-z]*$',  # at end
                        ):
        if re.search( re_remove, name ) is not None:
            name = re.sub(re_remove, ' ', name).strip(', ')

    return name


def cleanup_wet_title(name: str):
    ''' Takes what is probably a full name of a thing, but may in some of the below uses be the entire aanhaal alinea,
        tries to take off anything not the title - quotes, spaces, rest of a sentence.
    '''
    name = name.replace('\u00A0',' ') # replace non-breaking space with a regular one

    # take out matching quotations -- and assume they are being used to demark the entire name  (the rest and the below still executes but is unlikely to match)
    for qleft, qright in (
        ('\u2018', '\u2019'),
        ('\u00ab', '\u00bb'),
        ('\u201c', '\u201d'),
        ('\u201e', '\u201d'),
        ('\u201d', '\u201d'),
    ):
        left_index  = name.find(qleft)
        right_index = name.rfind(qright)
        if left_index != -1 and right_index != -1   and left_index < 10  and  right_index > left_index+5:
            name = name[ left_index+1 : right_index ]

    if name.startswith('"') and name.count('"')>=2: #assume these are outside quotations
        try:
            name = name[ 1: name.index('"', 4) ].strip()
        except:
            print( repr(name) )
            raise

    # aimed at the aanheffing sentence specifically
    for re_cutafter in(
        r'en zal',                              # probaly more often than not the note where it will be publicised
        r'en treedt',                           # probaly more often than not the note when it will be publicised
        r'[;,.] ([zZ]ij |Het |Dit besluit )?(treedt|treden) in werking',
        r'[.] Deze ',
        r'zal worden gepubliceerd', 
        r'en wordt gepubliceerd',
        r'wordt .{0,20}in de Staatscourant',
        r' (en|zij|zei|zal) (wordt|worden) bekend\s?gemaakt',
        r'. De beleidsregels', 
        r' en werkt terug ',
        r'Zij werkt terug ',
        r'De regeling zal met ',
        r' met vermelding van ',
        r' met bijvoeging van ',

        # TODO: extract abbreviations too
        r'(, )?(of )? afgekort (als|tot)',
        r'[\(]afgekort\b',
    ):
        match = re.search( re_cutafter.replace(' ',r'[\s\n]+'), name, re.M )
        if match is not None:
            name = name[:match.start()]

    if name.startswith('de '):  # wet
        name = name[3:].strip()
    if name.startswith('het '): # besluit
        name = name[4:].strip()
    # note: taking off 'nieuwe' at the start is dangerous because that is frequently part of the actual name

    name = name.strip('\u2018\u2019') #quote
    name = re.sub('\s+',' ', name).strip()
    name = name.strip('"\'.;:,\u00ab\u00bb \u2018\u2019\u201c\u201d\u201e')
    return name


def title_is_too_generic( title ):
    """ various documents will refer to shortened names it defined earlier.    Until we perhaps parse and can use that contextual information, we can ignore these. 
        Sometimes used after abovementioned cleanup.
    """
    title_lower = title.strip().lower()
    title_lower = title_lower.replace('genoemde ','').strip()
    if title_lower in ('die wet', 'de wet', 'deze wet', 'regeling', 'wet',  'besluit', 'het besluit', 'wetboek', 'uitvoeringswet', 'subsidieregeling',  'fonds', 'het', 'model', 'mens',  
               ''): # some of these are singular edge cases, shouldn't really be here
        return True
    return False


def name_from_extref_tag(extref_tag, allow_fuzzier=False):
    ''' Thats an etree object, specifically an extref,
        Returns the part of the extref's text that is probably the name of a thing being referenced,
          stripped of some obvious stuff
        ...or None, if we decide it's probably not a useful name, or we're not really sure what's in there.
          with allow_fuzzier we're pretty strict about only matching some known patterns,
          with allow_fuzzier==True we just hope for the best

    '''
    match1 = re.search(' van (?:de|het) (.*)', extref_tag.text)   # I've seen a case where 'van de' is in the reference twice, like 'van de wet, in artikel 7 van de Elektriciteitswet 1998', but meh.
    match2 = re.search('lid, (Wet .*)', extref_tag.text)

    if match1 is not None:
        name = match1.groups()[0].strip()
        if name == 'wet': #  'van de wet' without a name
            return None
    elif match2 is not None:
        name = match2.groups()[0].strip()
    elif extref_tag.text.startswith('Wet ') or extref_tag.text.startswith('Successiewet ') or extref_tag.text.startswith('Besluit ') or extref_tag.text.startswith('Verordening ') or extref_tag.text.startswith('Warenwetbesluit '):
        name = extref_tag.text.strip()
    elif extref_tag.text.rstrip('0123456789 ').endswith('wet'): # assume it's a short name
        name = extref_tag.text.strip()
    elif extref_tag.text.rstrip('0123456789 ').endswith('besluit'): # assume it's a short name
        name = extref_tag.text.strip()
    elif extref_tag.text.rstrip('0123456789 ').endswith('regeling'): # assume it's a short name
        name = extref_tag.text.strip()
    elif re.match( 'W[A-Za-z]+$', extref_tag.text)   and len(extref_tag.text) in (2,3,4)  and  extref_tag.text.lower()!='wet': # assume it's a short initalism, for a law
        name = extref_tag.text.strip('')
    else: # maybe look at what these are
        if allow_fuzzier:
            name = extref_tag.text.strip('') # will still be cleaned below
            name = cleanup_basics( name ) # this is a little awkward of a combination, really
        else:
            #print( 'DUNNO %r'%(wetsuite.helpers.etree.tostring(extref_tag).decode('u8')) )
            return None

    # right now we're interested in the main name, not reference to specific part
    #  ...but we could later try to deal with those as well - there are ~15K cases that the below skipped
    name = cleanup_wet_title(name)
    #name = cleanup_basics(name)
    
    # ignore less-formal references
    if title_is_too_generic(name):
        #print( "SKIP non-useful name (generic 1): %r"%name)
        return None

    if wetsuite.helpers.strings.contains_any_of(name, [', van (deze|die) wet$'], regexp=True ):
        #print( "SKIP non-useful name (generic 2): %r"%name)
        return None
    
    #if wetsuite.helpers.strings.contains_any_of( name.lower(), (
    #    'artikel ','artikelen ', 'art.', 'lid,', 'paragraaf ', 'van die ', ' die wet', 'van de wet', 'van deze wet', 'met vermelding ',
    #    'eerste lid', 'tweede lid', 'boek van ', 'weede lid', 'met de bijbehorende', 'voornoemde wet', 'Bijlage ', 'bijlage bij', 'bijlage ') ):
    #    #print( "SKIP FOR NOW (specific reference): %r"%name) # there
    #    return None
    return name


resolved = wetsuite.helpers.localdata.open_store( 'redirect_urls.db', str, str )
def resolve_deeplink(url):
    ' Given BWB deeplink URLs (mainly the title ones), try to fetch '
    if url in resolved:
        #print("CACHED for %r"%url)
        retval = resolved.get( url ) # which might be None
        if retval == 'None': # special casing, since it's either that or a BWBR. We _could_ store 'could not resolve' and its reason, but there is little point.
            return None
        return retval
    else:
        print("FETCHING %r"%url)
        resp = requests.get(url, allow_redirects=True)
        soup = bs4.BeautifulSoup(resp.content)
        identifier_tags = soup.select("meta[name='dcterms:identifier']")
        if len(identifier_tags)>0:
            bwbid = identifier_tags[0].get('content')
            resolved.put( url, bwbid )
            return bwbid
        else:

            if b'De opgevraagde pagina is niet gevonden' in resp.content:
                #print("DID NOT RESOLVE %r"%resp.history[-1].url)
                resolved.put( url, 'None' )
            elif b'Gebruikt formaat in de URL wordt niet ondersteund':
                #print("DID NOT RESOLVE %r"%resp.history[-1].url)
                resolved.put( url, 'None' )
            else:
                print("DID NOT HANDLE %r"%resp.history[-1].url)
            return None

# %% [markdown]
# # Collect references from BWB

# %% [markdown]
# ## Names from BWB's intitule, citeertitel, and "aangehaald als" text
#
# __Citeertitel__ - is often a fairly succinct name
# : this basically comes from the last paragraph when it says something like "Deze wet wordt aangehaald als: Wet op de rechterlijke organisatie.", though the code belows does not assume those are identical, in part for ease of code because mostly laws have that paragraph, but _everything_ has a citeertitel.
#
# __Intitule__ - is often a more detailed description, and will rarely be the text people use to cite (though sometimes it is the _same_ as citeertitel)

# %%
bwb_latestonly_xml = wetsuite.datasets.load('bwb-mostrecent-xml').data
# there are a few laws that changed name, but due to that choice of data, we focus on the recent version

                                                                     # lists mostly for code below to be simpler, they'll contain 0 or 1 items
bwb_names_citeertitel = collections.defaultdict(list)   # BWB-id -> list of name strings     from something's own metadata, what it calls itself
bwb_names_aanhaling   = collections.defaultdict(list)   # BWB-id -> list of name strings     from something's own data, what it calls itself
bwb_soort             = {}                              # BWB-id -> soort    


for xml_url in bwb_latestonly_xml.keys(): # note: going through ~36K documents will take a minute or two
    tree = cached_parse( bwb_latestonly_xml, xml_url )

    meta = wetsuite.helpers.koop_parse.bwb_toestand_usefuls(tree)
    bwbid = meta['bwb-id']
    bwb_soort[bwbid] = meta['soort']

    ## record the citeertitel 
    # which is just in the metadata
    bwb_names_citeertitel[ bwbid ].append( cleanup_wet_title(meta['citeertitel']) )  


    ## find the self-reference
    # find all alineas that mention 'aangehaald' (if any), find the thing it then mentions
    aanhaling = []
    for al_tag in tree.getiterator(tag='al'):
        tagtext = wetsuite.helpers.etree.all_text_fragments( al_tag, strip='\n', join='' )
        #tagtext = all_text_fragments( tag, strip='\n', join='' )
        #if 'aangehaald' in tagtext:
            #print( tagtext )
        match = re.search(r' (?:aangehaald als|aangehaald onder de titel van):?\s*(.*)', tagtext) # this probably filters out too much
        if match is not None:
            aanhaling.append( match.groups()[0].rstrip('.') )

    if len(aanhaling)==0: 
        #TODO: consider subelements, e.g. the CO<sub>2</sub> example

        # While debugging, it is useful to check that indeed they're without such a reference
        if wetsuite.helpers.strings.contains_any_of( meta['intitule'].lower(), ['regeling ', 'toepassing ', 'aanwijzing ', 'besluit ', 'beschikking ']): # maybe look at soort instead?
            pass
            #print( "SELFAANHAALFAIL (OKAY; seeming non-law) in %r"%xml_url)
        else:
            pass
            #print( "SELFAANHAALFAIL in %r"%xml_url)
        # there was previously also an 'is this french' check
    else:
        text = aanhaling[-1] # pretty sure it's always the last

        cleaner_title = cleanup_wet_title( text )
        if cleaner_title not in bwb_names_aanhaling[ bwbid ]:
            bwb_names_aanhaling[ bwbid ].append( cleaner_title )
        if '(' in cleaner_title: # some titles have parentheses at the end. Probably add them both with and without, because that may or may not be part of the name (TODO: clean more)
            cleaner_title = cleaner_title[:cleaner_title.index('(')].strip()
            if cleaner_title not in bwb_names_aanhaling[ bwbid ]:
                bwb_names_aanhaling[ bwbid ].append( cleaner_title )

# %%
len(bwb_latestonly_xml)
# Out:
# 36906

# %% [markdown]
# ### Quick summary

# %%
# how much did we get?
print("From  %d BWB documents  we got  %d citeertitels  and  %d aanhalingen."%(
    len(bwb_latestonly_xml.data),
    len(bwb_names_citeertitel),
    len(bwb_names_aanhaling),
))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/www/coding/wetsuite/notebooks/miscellany/extras_datacollect_lawnames.ipynb Cell 10 line <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a227363617266626f792e636f6d222c2275736572223a227363617266626f79222c22706f7274223a32313231327d/var/www/coding/wetsuite/notebooks/miscellany/extras_datacollect_lawnames.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # how much did we get?
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a227363617266626f792e636f6d222c2275736572223a227363617266626f79222c22706f7274223a32313231327d/var/www/coding/wetsuite/notebooks/miscellany/extras_datacollect_lawnames.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> print("From  %d BWB documents  we got  %d citeertitels  and  %d aanhalingen."%(
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a227363617266626f792e636f6d222c2275736572223a227363617266626f79222c22706f7274223a32313231327d/var/www/coding/wetsuite/notebooks/miscellany/extras_datacollect_lawnames.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     len(bwb_latestonly_xml.data),
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a227363617266626f792e636f6d222c2275736572223a227363617266626f79222c22706f7274223a32313231327d/var/www/coding/wetsuite/notebooks/miscellany/extras_datacollect_lawnames.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     len(bwb_names_citeertitel),
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a227363617266626f792e636f6d222c2275736572223a227363617266626f79222c22706f7274223a32313231327d/var/www/coding/wetsuite/notebooks/miscellany/extras_datacollect_lawnames.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     len(bwb_names_aanhaling),
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a227363617266626f792e636f6d222c2275736572223a227363617266626f79222c22706f7274223a32313231327d/var/www/coding/wetsuite/notebooks/miscellany/extras_datacollect_lawnames.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> ))
#
# AttributeError: 'LocalKV' object has no attribute 'data'

# %%
# Quick inspection of
#    what kind of things are we apparently not cleaning from the aanhaling? 
# and/or 
#   what kind of differences are there between aanhaling and citeertitel?

for bwbid in bwb_names_aanhaling:
    aanhaling   = bwb_names_aanhaling[bwbid]
    citeertitel = bwb_names_citeertitel[bwbid]
    if set( aanhaling ).symmetric_difference( citeertitel ): 
        print()
        print( bwbid )
        print( aanhaling )
        print( citeertitel )
# Out:
# BWBR0001919
# ['Deegwarenbesluit (Warenwet)', 'Deegwarenbesluit']
# ['Deegwarenbesluit (Warenwet)']
#
# BWBR0002028
# ['Meststoffenwet']
# ['Meststoffenwet 1947']
#
# BWBR0002030
# ['Wet voorzieningen onder den vijand aangetroffen goederen']
# ['Wet van 24 april 1947, houdende voorzieningen onder den vijand aangetroffen goederen']
#
# BWBR0002055
# ['Wet Souvereiniteitsoverdracht Indonesië']
# ['Wet souvereiniteitsoverdracht Indonesië']
#
# BWBR0002099
# ['WET OORLOGSSTRAFRECHT']
# ['Wet oorlogsstrafrecht']
#
# BWBR0002121
# ['Beschikking commissie gewetensbezwaren immunisatie militairen']
# ['Beschikking Commissie Gewetensbezwaren Immunisatie Militairen']
#
# BWBR0002130
# ['Vestigingswet Bedrijven']
# ['Vestigingswet Bedrijven 1954']
#
# BWBR0002226
# ['Successiewet']
# ['Successiewet 1956']
#
# BWBR0002269
# ['Pachtwet 1937']
# ['Pachtwet']
#
# BWBR0002346
# ['Lijst MKR']
# ['Militair keuringsreglement']
#
# BWBR0002365
# ['']
# ['Rijkssubsidieregeling voor het algemeen maatschappelijk werk']
#
# BWBR0002398
# ['Landbouwuitvoerbesluit 1963 (Algemene Voorwaarden)', 'Landbouwuitvoerbesluit 1963']
# ['Landbouwuitvoerbesluit 1963 (Algemene Voorwaarden)']
#
# BWBR0002416
# ['Visserijwet']
# ['Visserijwet 1963']
#
# BWBR0002421
# ['Vrijstellingsregeling klein grensverkeer (niet-landbouwgoederen) 1963', 'Vrijstellingsregeling klein grensverkeer']
# ['Vrijstellingsregeling klein grensverkeer (niet-landbouwgoederen) 1963']
#
# BWBR0002443
# ['Reglement voor de Organisatie ter verbetering van de Binnenvisserij']
# ['Reglement voor de Organisatie ter verbetering van de Binnenvisserij 1964']
#
# BWBR0002444
# ['Reglement voor de Kamer voor de Binnenvisserij']
# ['Reglement voor de Kamer voor de Binnenvisserij 1964']
#
# BWBR0002452
# ['Overgangswet ruimtelijke ordening en volkshuisvesting']
# ['Overgangswet Ruimtelijke Ordening en Volkshuisvesting']
#
# BWBR0002454
# ['']
# ['Bestrijdingsmiddelenregeling']
#
# BWBR0002515
# ['Wet op de dividendbelasting']
# ['Wet op de dividendbelasting 1965']
#
# BWBR0002527
# ['Vrijstellingsregeling militaire zendingen (niet-landbouwgoederen) 1966', 'Vrijstellingsregeling militaire zendingen']
# ['Vrijstellingsregeling militaire zendingen (niet-landbouwgoederen) 1966']
#
# BWBR0002534
# ['Wet op de motorrijtuigenbelasting']
# ['Wet op de motorrijtuigenbelasting 1966']
#
# BWBR0002678
# ['']
# ['Vrijstellingsbesluit landsverdediging Kernenergiewet']
#
# BWBR0002687
# ['Beschikking aanwijzing eerste kantoren Kernenergiewet']
# ['Aanwijzing eerste kantoren Kernenergiewet']
#
# BWBR0002703
# ['Besluit aanwijzing zeegebied en kustwateren']
# ['Besluit aanwijzing zeegebied en kustwateren 1970']
#
# BWBR0002750
# ['Benelux-vrijstellingsbeschikking Landbouwuitvoerwet 1938']
# ['Benelux – vrijstellingsbeschikking Landbouwuitvoerwet 1938']
#
# BWBR0002808
# ["Besluit staatsexamen diploma's handvaardigheid (handenarbeid)", "Besluit staatsexamen diploma's handvaardigheid"]
# ["Besluit staatsexamen diploma's handvaardigheid (handenarbeid)"]
#
# BWBR0002856
# ['Wet op de Accountants-Administratieconsulenten']
# ['Wet op de Accountants-administratieconsulenten']
#
# BWBR0002864
# ['']
# ['Besluit chronisch intermitterende beademing ziekenfondsverzekering']
#
# BWBR0002865
# ['Besluit hulpverlening door trombosediensten ziekenfondsverzekering, wordt met de daarbij behorende toelichting in de Staatscourant geplaatst']
# ['Besluit hulpverlening door trombosediensten ziekenfondsverzekering']
#
# BWBR0002932
# ['Textielartikelenbesluit (Warenwet)', 'Textielartikelenbesluit']
# ['Textielartikelenbesluit (Warenwet)']
#
# BWBR0002946
# ['Uitvoeringsbesluit artikel 1, derde lid, Wet verontreniging oppervlaktewateren']
# ['Uitvoeringsbesluit artikel 1, derde lid, Wet verontreiniging oppervlaktewateren']
#
# BWBR0002955
# ['']
# ['Beschikking wering besmettelijke pluimveeziekten']
#
# BWBR0002976
# ['Wet aansprakelijkheid olietankschepen. Zij treedt voor wat betreft de artikelen 4-7 en 9-29 in werking op een door Ons nader te bepalen tijdstip. De artikelen 1-3 en 8 zijn slechts van toepassing ten aanzien van aansprakelijkheid uit een voorval dat na de dag van inwerkingtreding van deze wet heeft plaats gevonden']
# ['Wet aansprakelijkheid olietankschepen']
#
# BWBR0003006
# ['Zetmeelbesluit (Warenwet)', 'Zetmeelbesluit']
# ['Zetmeelbesluit (Warenwet)']
#
# BWBR0003076
# ['Besluit programma dagverblijven en gezinsvervangende tehuizen voor gehandicapten, zal met de Nota van toelichting in de Nederlandse Staatscourant worden geplaatst']
# ['Besluit programma dagverblijven en gezinsvervangende tehuizen voor gehandicapten']
#
# BWBR0003089
# ['Suiker- en stroopbesluit (Warenwet) 1977', 'Suiker- en stroopbesluit']
# ['Suiker- en stroopbesluit (Warenwet) 1977']
#
# BWBR0003097
# ['besluit toelating rechtspersonen maatschappelijke dienstverlening']
# ['Besluit toelating rechtspersonen maatschappelijke dienstverlening']
#
# BWBR0003128
# ['Landbouwkwaliteitsregeling vrijstellingen, ontheffingen en nadere voorschriften groenten en fruit']
# ['Landbouwkwaliteitsbeschikking vrijstellingen, ontheffingen en nadere voorschriften groenten en fruit']
#
# BWBR0003204
# ['Honingbesluit (Warenwet)', 'Honingbesluit']
# ['Honingbesluit (Warenwet)']
#
# BWBR0003217
# ['']
# ['Regeling in- en doorvoer vlees 1979']
#
# BWBR0003223
# ['Besluit begripsomschrijvingen artikel 1']
# ['Besluit begripsomschrijvingen artikel 1a Algemene Bijstandswet']
#
# BWBR0003232
# ['Besluit toelating tot het vrije verkeer luchtvaartuigen (Internationale Gezondheidsregeling)', 'Besluit toelating tot het vrije verkeer luchtvaartuigen']
# ['Besluit toelating tot het vrije verkeer luchtvaartuigen (Internationale Gezondheidsregeling)']
#
# BWBR0003254
# ['Besluit toezicht Wet ziekenhuisvoorzieningen, wordt met de daarbij behorende toelichting in de Nederlandse Staatscourant geplaatst']
# ['Besluit toezicht Wet ziekenhuisvoorzieningen']
#
# BWBR0003255
# ['Besluit uitzondering toestemmingsprocedures Wet ziekenhuisvoorzieningen, wordt met de daarbij behorende toelichting in de Nederlandse Staatscourant geplaatst']
# ['Besluit uitzondering toestemmingsprocedures Wet ziekenhuisvoorzieningen']
#
# BWBR0003267
# ['Verpakkingen- en gebruiksartikelenbesluit (Warenwet)', 'Verpakkingen- en gebruiksartikelenbesluit']
# ['Verpakkingen- en gebruiksartikelenbesluit (Warenwet)']
#
# BWBR0003268
# ['Kokswarenbesluit (Warenwet)', 'Kokswarenbesluit']
# ['Kokswarenbesluit (Warenwet)']
#
# BWBR0003276
# ['Regeling Verpakkingen- en gebruiksartikelen (Warenwet)', 'Regeling Verpakkingen- en gebruiksartikelen']
# ['Regeling Verpakkingen- en gebruiksartikelen (Warenwet)']
#
# BWBR0003297
# ['']
# ['Regeling samenstelling bestrijdingsmiddelen']
#
# BWBR0003302
# ['']
# ['Regeling tarieven Kamer voor de Binnenvisserij']
#
# BWBR0003310
# ['Hoeveelheidsaanduidingenbesluit (Warenwet)', 'Hoeveelheidsaanduidingenbesluit']
# ['Hoeveelheidsaanduidingenbesluit (Warenwet)']
#
# BWBR0003333
# ['Beschikking bescherming persoonlijke levenssfeer (Registratie artikel 24 Landbouwwet)', 'Beschikking bescherming persoonlijke levenssfeer']
# ['Beschikking bescherming persoonlijke levenssfeer (Registratie artikel 24 Landbouwwet)']
#
# BWBR0003359
# ['Besluit niet-klinische haemodialyse ziekenfondsverzekering, wordt met de daarbij behorende toelichting in de Nederlandse Staatscourant geplaatst']
# ['Besluit niet-klinische haemodialyse ziekenfondsverzekering']
#
# BWBR0003363
# ['besluit Ziekenfondsraad nadere regelen niet-klinische haemodialyse ziekenfondsverzekering 1980']
# ['Besluit Ziekenfondsraad nadere regelen niet-klinische haemodialyse ziekenfondsverzekering 1980']
#
# BWBR0003376
# ['Regeling vracht- en overige vluchten']
# ['Regeling Vracht- en overige Vluchten']
#
# BWBR0003378
# ['Meetbrievenwet']
# ['Meetbrievenwet 1981']
#
# BWBR0003381
# ['Regeling in- en uitvoer landbouwgoederen']
# ['Regeling In- en uitvoer landbouwgoederen']
#
# BWBR0003395
# ['Wet afbreking zwangerschap']
# ['Wet vaststelling Wet afbreking zwangerschap']
#
# BWBR0003403
# ['Leegstandwet, treden de artikelen 1 en 4, hoofdstuk V, paragraaf E van artikel 18 en hoofdstuk VII in werking op een door Ons te bepalen tijdstip']
# ['Leegstandwet']
#
# BWBR0003417
# ['Meetbrievenbesluit']
# ['Meetbrievenbesluit 1981']
#
# BWBR0003431
# ['Beschikking steun boter met bijzonder gebruik of bijzondere bestemming 1981. Zij wordt bekend gemaakt in de Nederlandse Staatscourant']
# ['Beschikking steun boter met bijzonder gebruik of bijzondere bestemming 1981']
#
# BWBR0003437
# ['koffiebeschikking 1981']
# ['Koffiebeschikking 1981']
#
# BWBR0003471
# ['']
# ['Beschikking beëdiging technische en administratieve ambtenaren Korps Rijkspolitie']
#
# BWBR0003597
# ['Vrijstellingsbesluit Aanduidingenbesluit waren voor bijzondere voeding (Warenwet)-suikerwerk en kauwgom', 'Vrijstellingsbesluit Aanduidingenbesluit waren voor bijzondere voeding']
# ['Vrijstellingsbesluit Aanduidingenbesluit waren voor bijzondere voeding (Warenwet)-suikerwerk en kauwgom']
#
# BWBR0003612
# ['Vrijstellingsbesluit Kunstmatige zoetstoffen (Warenwet)', 'Vrijstellingsbesluit Kunstmatige zoetstoffen']
# ['Vrijstellingsbesluit Kunstmatige zoetstoffen (Warenwet)']
#
# BWBR0003644
# ['Regeling bijdragen werkgelegenheid in de bosbouw 1984–1985']
# ['Beschikking bijdragen werkgelegenheid in de bosbouw 1984–1985']
#
# BWBR0003652
# ['Richtlijnen voor het gebruik van CS-traangas']
# ['Richtlijnen voor gebruik CS-traangas']
#
# BWBR0003700
# ['besluit Kernprogramma opleiding diploma Kraamverzorgster 1984']
# ['Besluit Kernprogramma opleiding diploma Kraamverzorgster 1984']
#
# BWBR0003750
# ['regeling plaatsing opgavebussen']
# ['Regeling plaatsing opgavebussen']
#
# BWBR0003751
# ['Besluit beheer gegevens Wet ziekenhuisvoorzieningen, wordt geplaatst in de Nederlandse Staatscourant']
# ['Besluit beheer gegevens Wet ziekenhuisvoorzieningen']
#
# BWBR0003753
# ['Besluit gegevens Wet ziekenhuisvoorzieningen categorie ziekenhuizen, wordt geplaatst in de Nederlandse Staatscourant']
# ['Besluit gegevens Wet ziekenhuisvoorzieningen categorie ziekenhuizen']
#
# BWBR0003760
# ['Vrijstellingsregeling vispasta (Warenwet)', 'Vrijstellingsregeling vispasta']
# ['Vrijstellingsregeling vispasta (Warenwet)']
#
# BWBR0003764
# ['Brandweerwet']
# ['Brandweerwet 1985']
#
# BWBR0003805
# ['Reglement minimummaten en gesloten tijden']
# ['Reglement minimummaten en gesloten tijden 1985']
#
# BWBR0003826
# ['Besluit Rijks bedrijfsgezondheids- en bedrijfsveiligheidsdienst, afgekort Rbb']
# ['Besluit Rijks bedrijfsgezondheids- en bedrijfsveiligheidsdienst']
#
# BWBR0003831
# ['Afvloeiingsregeling rijksscholen W.V.O. 1985']
# ['Afvloeiingsregeling Rijksscholen W.V.O. 1985']
#
# BWBR0003932
# ['Besluit voorwaarden schone en beperkt schone personenauto’s']
# ["Besluit voorwaarden schone en beperkt schone personenauto's"]
#
# BWBR0003938
# ['']
# ['Regeling aanwijzing van uitkeringen waarover ziekenfondspremie voor personen van 65 jaar en ouder aan de bron wordt ingehouden']
#
# BWBR0003940
# ['']
# ['Regeling tijdelijke vrijstelling van de verplichting tot inhouding ziekenfondspremie']
#
# BWBR0003962
# ['schadecompensatieregeling Willemsspoortunnel']
# ['Schadecompensatieregeling Willemsspoortunnel']
#
# BWBR0003997
# ['Regeling bezwarenprocedure functiewaardering BBRA 1984, wordt in de Nederlandse Staatscourant bekendgemaakt']
# ['Regeling bezwarenprocedure functiewaardering BBRA 1984']
#
# BWBR0004056
# ['Reglement rijksscholen v.w.o., h.a.v.o., m.a.v.o., l.b.o. 1986 en vervangt, onverminderd het bepaalde in artikel 57, het Reglement Rijksscholen v.w.o., h.a.v.o., m.a.v.o., l.b.o., vastgesteld bij beschikking van 4 juli 1973, kenmerk AVO-539.447, Stcrt. nr. 158, laastelijk gewijzigd bij beschikking van 7 september 1981, kenmerk VO/AV/RVO-748.346, Stcrt. nr. 185']
# ['Reglement rijksscholen v.w.o., h.a.v.o., m.a.v.o., l.b.o. 1986']
#
# BWBR0004088
# ['regeling actief veredelingsverkeer landbouwgoederen 1986']
# ['Regeling actief veredelingsverkeer landbouwgoederen 1986']
#
# BWBR0004131
# ['Vrijstelling benaming verduurzaamde vruchten (Warenwet)', 'Vrijstelling benaming verduurzaamde vruchten']
# ['Vrijstelling benaming verduurzaamde vruchten (Warenwet)']
#
# BWBR0004138
# ['']
# ['Rechtspositieregeling personeel Stichting voor Huishoudelijke Voorlichting ten Plattelande 1985']
#
# BWBR0004194
# ['Regeling vrijstelling zuigelingenvoeding (EEG)', 'Regeling vrijstelling zuigelingenvoeding']
# ['Regeling vrijstelling zuigelingenvoeding (EEG)']
#
# BWBR0004230
# ["Regeling bevoegdheid (voortgezet) speciaal onderwijs voor buitenlandse diploma's", 'Regeling bevoegdheid']
# ["Regeling bevoegdheid (voortgezet) speciaal onderwijs voor buitenlandse diploma's"]
#
# BWBR0004271
# ['Vrijstellingsregeling Garnalenbesluit (Warenwet) EEG-landen', 'Vrijstellingsregeling Garnalenbesluit']
# ['Vrijstellingsregeling (Warenwet) Garnalenbesluit EEG-landen']
#
# BWBR0004318
# ['']
# ['Wet openbare manifestaties']
#
# BWBR0004326
# ['']
# ['Bijdrageregeling proefprojecten mestverwerking']
#
# BWBR0004352
# ['']
# ['Regeling bewijs van verzekering niet-kentekenplichtige motorrijtuigen']
#
# BWBR0004368
# ['schadecompensatieregeling inzake het verleggen van kabels en leidingen in Rijkswaterstaatswerken']
# ['Schadecompensatieregeling inzake het verleggen van kabels en leidingen in Rijkswaterstaatswerken']
#
# BWBR0004386
# ['']
# ['Regeling loodsverplichtingen bij loodsen op afstand']
#
# BWBR0004396
# ['Regeling monsterneming Melkeiwitten (caseïne en caseïnaten)', 'Regeling monsterneming Melkeiwitten']
# ['Regeling monsterneming Melkeiwitten (caseïne en caseïnaten)']
#
# BWBR0004402
# ['Besluit bijdragen regionale brandweren']
# ['Besluit bijdragen regionale brandweren 1988']
#
# BWBR0004422
# ['Machtigingswet Koninklijke PTT Nederland N.V']
# ['Machtigingswet Koninklijke PTT Nederland NV']
#
# BWBR0004436
# ['definitieve vaststelling aanvaardbare beheerskosten ziekenfondsverzekering en AWBZ 1988']
# ['Definitieve vaststelling aanvaardbare beheerskosten ziekenfondsverzekering en AWBZ 1988']
#
# BWBR0004440
# ['Verordening op de publiciteit']
# ['Verordening op de Publiciteit']
#
# BWBR0004456
# ['']
# ['Regeling vrijstelling machtiging zendinrichtingen niet-ingezetenen']
#
# BWBR0004464
# ['']
# ['Overgangsregeling huurgewenningsbijdrage domeinwoningen']
#
# BWBR0004470
# ['Besluit Rode Kruis']
# ['Besluit Rode Kruis 1988']
#
# BWBR0004514
# ['Vrijstellingsregeling Komijnzaad (Warenwet)', 'Vrijstellingsregeling Komijnzaad']
# ['Vrijstellingsregeling Komijnzaad (Warenwet)']
#
# BWBR0004523
# ['Beschikking erkenning psychiatrische poliklinieken 1989 wordt met de bijbehorende bijlage in de Staatscourant geplaatst']
# ['Beschikking erkenning psychiatrische poliklinieken 1989']
#
# BWBR0004526
# ['Beschikking kortingscompensatie in de sector melk en zuivelprodukten']
# ['Beschikking kortingcompensatie in de sector melk- en zuivelprodukten']
#
# BWBR0004544
# ['Beschikking erkenning instellingen voor psychiatrische deeltijdbehandeling 1989 wordt met de bijbehorende bijlage in de Staatscourant geplaatst']
# ['Erkenning instellingen voor psychiatrische deeltijdbehandeling']
#
# BWBR0004555
# ['beschikking erkenning psychiatrische afdelingen van algemene ziekenhuizen 1989 wordt met de bijhorende bijlage in de Nederlandse Staatscourant geplaatst']
# ['Beschikking erkenning psychiatrische afdelingen van algemene ziekenhuizen 1989']
#
# BWBR0004556
# ['Beschikking erkenning psychiatrische ziekenhuizen 1989 wordt met de bijbehorende bijlage in de Staatscourant geplaatst']
# ['Beschikking erkenning psychiatrische ziekenhuizen 1989']
#
# BWBR0004582
# ['Besluit opneming buitenlandse pleegkinderen']
# ['Besluit opneming buitenlandse kinderen ter adoptie']
#
# BWBR0004610
# ['Vrijstellingsregeling Wei-eiwitconcentraat in melkprodukten (Warenwet)', 'Vrijstellingsregeling Wei-eiwitconcentraat in melkprodukten']
# ['Vrijstellingsregeling Wei-eiwitconcentraat in melkprodukten (Warenwet)']
#
# BWBR0004650
# ['definitieve vaststelling aanvaardbare beheerskosten ziekenfondsverzekering en AWBZ 1989']
# ['Definitieve vaststelling aanvaardbare beheerskosten ziekenfondsverzekering en AWBZ 1989']
#
# BWBR0004730
# ['Wet op de uitoefening van de diergeneeskunde']
# ['Wet op de uitoefening van de diergeneeskunde 1990']
#
# BWBR0004736
# ['']
# ['Beschikking Landbouwtelling 1990']
#
# BWBR0004784
# ['']
# ['Instellingsbesluit Interdepartementale raad voor de handelspolitiek']
#
# BWBR0004825
# ['Reglement verkeersregels en verkeerstekens 1990']
# ['Reglement verkeersregels en verkeerstekens 1990 (RVV 1990)']
#
# BWBR0004826
# ['Besluit administratieve bepalingen inzake het wegverkeer']
# ['Besluit administratieve bepalingen inzake het wegverkeer (BABW)']
#
# BWBR0004851
# ['Besluit integratie welzijnsmiddelen Provinciefonds']
# ['Besluit integratie welzijnsmiddelen provinciefonds']
#
# BWBR0004862
# ['Vrijstellingsregeling sulfiet in schaaldieren (Warenwet)', 'Vrijstellingsregeling sulfiet in schaaldieren']
# ['Vrijstellingsregeling sulfiet in schaaldieren (Warenwet)']
#
# BWBR0004863
# ['Vrijstellingsregeling Margarinebesluit (Warenwet)', 'Vrijstellingsregeling Margarinebesluit']
# ['Vrijstellingsregeling Margarinebesluit (Warenwet)']
#
# BWBR0004870
# ['Vrijstellingsregeling Paraffine in suikerwerk (Warenwet)', 'Vrijstellingsregeling Paraffine in suikerwerk']
# ['Vrijstellingsregeling Paraffine in suikerwerk (Warenwet)']
#
# BWBR0004888
# ['Nederlandse uitvoeringsvoorschriften belastingovereenkomst Nederland Ierland']
# ['Nederlandse uitvoeringsvoorschriften belastingovereenkomst Nederland-Ierland']
#
# BWBR0004920
# ['definitieve vaststelling aanvaardbare beheerskosten ziekenfondsverzekering en AWBZ 1990']
# ['Definitieve vaststelling aanvaardbare beheerskosten ziekenfondsverzekering en AWBZ 1990']
#
# BWBR0004961
# ['Nederlandse uitvoeringsvoorschriften belastingovereenkomst Nederland Frankrijk']
# ['Nederlandse uitvoeringsvoorschriften belastingovereenkomst Nederland-Frankrijk']
#
# BWBR0004976
# ['Besluit informatievoorziening in de rijksdienst 1990 (Besluit IVR 1990)', 'Besluit informatievoorziening in de rijksdienst 1990']
# ['Besluit informatievoorziening in de rijksdienst 1990 (Besluit IVR 1990)']
#
# BWBR0005039
# ['regeling houdende wijziging van de Regeling afgifte vlaggebrieven door aangewezen organisaties']
# ['Regeling houdende wijziging van de Regeling afgifte vlaggebrieven door aangewezen organisaties']
#
# BWBR0005041
# ['']
# ['Regeling examens assurantiebemiddeling 1991']
#
# BWBR0005046
# ['compensatieregeling vakonderwijs basisonderwijs']
# ['Compensatieregeling vakonderwijs basisonderwijs']
#
# BWBR0005048
# ['Invoeringswet Boeken 3, 5 en 6 nieuw B.W. (twaalfde gedeelte)', 'Invoeringswet Boeken 3, 5 en 6 nieuw B.W.']
# ['Invoeringswet Boeken 3, 5 en 6 nieuw B.W. (twaalfde gedeelte)']
#
# BWBR0005054
# ['Regeling dekking kosten Ziekenfondsraad en zijn secretariaat 1991 (AWBZ), wordt in de Nederlandse Staatscourant geplaatst en in afschrift gezonden aan de Ziekenfondsraad te Amstelveen', 'Regeling dekking kosten Ziekenfondsraad en zijn secretariaat 1991']
# ['Regeling dekking kosten Ziekenfondsraad en zijn secretariaat 1991 (AWBZ)']
#
# BWBR0005059
# ['P.C.B.-, P.C.T.-en chlooretheen-besluit milieubeheer']
# ['P.C.B.-, P.C.T.- en chlooretheen-besluit milieubeheer']
#
# BWBR0005072
# ['Regeling eisen farmaceutische preparaten (apotheken)', 'Regeling eisen farmaceutische preparaten']
# ['Regeling eisen farmaceutische preparaten (apotheken)']
#
# BWBR0005084
# ['Regeling dekking kosten Ziekenfondsraad en zijn secretariaat 1990 (AWBZ), wordt in de Nederlandse Staatscourant geplaatst en in afschrift gezonden aan de Ziekenfondsraad te Amstelveen', 'Regeling dekking kosten Ziekenfondsraad en zijn secretariaat 1990']
# ['Regeling dekking kosten Ziekenfondsraad en zijn secretariaat 1990 (AWBZ)']
#
# BWBR0005113
# ['']
# ['Privacyreglement registers secties jeugdzaken en hulpverlening']
#
# BWBR0005155
# ['']
# ['Regeling vrijstelling protocolplicht']
#
# BWBR0005165
# ['Vrijstellingsregeling Conserveermiddelen in vruchtenlimonades (Warenwet)', 'Vrijstellingsregeling Conserveermiddelen in vruchtenlimonades']
# ['Vrijstellingsregeling Conserveermiddelen in vruchtenlimonades (Warenwet)']
#
# BWBR0005175
# ['']
# ['Beschikking landbouwtelling boomkwekerijgewassen en vaste planten 1991']
#
# BWBR0005200
# ['Vrijstellingsregeling Mosterdbesluit (Warenwet)', 'Vrijstellingsregeling Mosterdbesluit']
# ['Vrijstellingsregeling Mosterdbesluit (Warenwet)']
#
# BWBR0005214
# ['Vrijstellingsregeling Voedingswaardenaanduidingenbesluit (Warenwet)', 'Vrijstellingsregeling Voedingswaardenaanduidingenbesluit']
# ['Vrijstellingsregeling Voedingswaardenaanduidingenbesluit (Warenwet)']
#
# BWBR0005223
# ['Vrijstellingsregeling Zuiverheidseisen emulgatoren (Warenwet)', 'Vrijstellingsregeling Zuiverheidseisen emulgatoren']
# ['Vrijstellingsregeling Zuiverheidseisen emulgatoren (Warenwet)']
#
# BWBR0005250
# ['Kiesreglement Dollardzijlvest']
# ['Besluit oprichting waterschap Dollardzijlvest']
#
# BWBR0005271
# ['Definitieve vaststelling aanvaardbare beheerskosten ziekenfondsverzekering en AWBZ 1991']
# ['Definitieve vaststelling aanvaardbare beheerskosten ziekenfondsverzekering en a.w.b.z. 1991']
#
# BWBR0005279
# ['Uniform Aanbestedingsreglement EG 1991’, bij afkorting ‘UAR-EG 1991']
# ['Uniform Aanbestedingsreglement EG 1991']
#
# BWBR0005298
# ['Voorlopige vaststelling aanvaardbare beheerskosten ziekenfondsverzekering en AWBZ 1992 wordt met de bijbehorende bijlage in de Nederlandse Staatscourant geplaatst']
# ['Voorlopige vaststelling aanvaardbare beheerskosten ziekenfondsverzekering en AWBZ 1992']
#
# BWBR0005335
# ['Inschrijvingsbesluit bijzondere ziektekostenverzekering 1992']
# ['Inschrijvingsbesluit Bijzondere Ziektekostenverzekering 1992']
#
# BWBR0005379
# ['besluit reglement BPS-politieregisters rijkspolitie']
# ['Besluit reglement BPS-politieregisters rijkspolitie']
#
# BWBR0005424
# ['']
# ['Algemeen organisatiebesluit Defensie 1992']
#
# BWBR0005430
# ['Wet beëindiging ministers en leden Staten-Generaal']
# ['Wet beëdiging ministers en leden Staten-Generaal']
#
# BWBR0005449
# ['Regeling grenswaarden voor DRINS in afvalwater']
# ['Regeling grenswaarden voor drins in afvalwater']
#
# BWBR0005477
# ['Regeling grenswaarden voor TETRA in afvalwater']
# ['Regeling grenswaarden voor tetra in afvalwater']
#
# BWBR0005489
# ['Warenwetbesluit producten voor bijzondere voeding']
# ['Warenwetbesluit Producten voor bijzondere voeding']
#
# BWBR0005493
# ['Aanwijzing inzake de officiële controle op levensmiddelen (EEG)', 'Aanwijzing inzake de officiële controle op levensmiddelen']
# ['Aanwijzing inzake de officiële controle op levensmiddelen (EEG)']
#
# BWBR0005533
# ['instellingsbeschikking projectgroep evaluatie OVB']
# ['Instellingsbeschikking projectgroep evaluatie OVB']
#
# BWBR0005547
# ['Regeling openbaarheid van bestuur (Defensie)', 'Regeling openbaarheid van bestuur']
# ['Regeling openbaarheid van bestuur (Defensie)']
#
# BWBR0005560
# ['beschikking terugbetaling ingehouden medeverantwoordelijkheidsheffing in verband met het tijdelijk uit produktie nemen van bouwland']
# ['Beschikking terugbetaling ingehouden medeverantwoordelijkheidsheffing in verband met het tijdelijk uit produktie nemen van bouwland']
#
# BWBR0005637
# ['Uitvoervrijstelling (Warenwet)', 'Uitvoervrijstelling']
# ['Uitvoervrijstelling (Warenwet)']
#
# BWBR0005655
# ['Regeling vaststelling mede te financieren bedrag MOOZ voor 1991 en voor 1992, wordt met de daarbij behorende toelichting in de Staatscourant geplaatst']
# ['Regeling vaststelling mede te financieren bedrag MOOZ voor 1991 en voor 1992']
#
# BWBR0005680
# ['bijdrageregeling milieuvriendelijke vervoertechnieken']
# ['Bijdrageregeling milieuvriendelijke vervoertechnieken']
#
# BWBR0005730
# ['Handelsregisterwet']
# ['Aanwijzingen voor de regelgeving']
#
# BWBR0005736
# ['Vrijstellingsregeling Regeling zuigelingenvoeding (Warenwet)', 'Vrijstellingsregeling Regeling zuigelingenvoeding']
# ['Vrijstellingsregeling Regeling zuigelingenvoeding (Warenwet)']
#
# BWBR0005806
# ['Wet op de belasting van personenauto’s en motorrijwielen 1992']
# ["Wet op de belasting van personenauto's en motorrijwielen 1992"]
#
# BWBR0005846
# ['']
# ['Regeling onderwerpen examen geschiedenis en staatsinrichting 1995']
#
# BWBR0005913
# ['']
# ['Regeling gegevensverstrekking op grond van artikel 14b van de Wet op het consumentenkrediet']
#
# BWBR0005920
# ["Besluit uitkeringen Europese programma's Twente 1993"]
# ["Besluit uitkering Europese programma's Twente 1993"]
#
# BWBR0005972
# ['']
# ['Nadere regeling identificatie en registratie slachtdieren']
#
# BWBR0006049
# ['']
# ['Regeling invoer konijne- en hazevlees 1993']
#
# BWBR0006073
# ['Wet rijonderricht motorrijtuigen']
# ['Wet rijonderricht motorrijtuigen 1993']
#
# BWBR0006081
# ['Regeling bezwarenprocedure functiewaardering personeel basisonderwijs, (voortgezet) speciaal onderwijs, voortgezet onderwijs, verzorgingsinstellingen en centrale diensten', 'Regeling bezwarenprocedure functiewaardering personeel basisonderwijs,']
# ['Regeling bezwarenprocedure functiewaardering personeel basisonderwijs, (voortgezet) speciaal onderwijs, voortgezet onderwijs, verzorgingsinstellingen en centrale diensten']
#
# BWBR0006156
# ['']
# ['Warenwetregeling Methode van onderzoek voedingsvezelgehalte']
#
# BWBR0006173
# ['']
# ['Regeling uitvoering VFR-vluchten buiten de daglichtperiode']
#
# BWBR0006251
# ['']
# ['Wet op de beroepen in de individuele gezondheidszorg']
#
# BWBR0006273
# ['']
# ['Regeling aanwijzing publiekrechtelijke ziektekostenregelingen voor ambtenaren in verband met de beperking medeverzekering ingevolge de Ziekenfondswet']
#
# BWBR0006279
# ['Overgangsregeling gewijzigde ondersteuningsstructuur VE']
# ['Wijzigingsbesluit Rechtspositiebesluit onderwijspersoneel (5)']
#
# BWBR0006299
# ['Politiewet']
# ['Politiewet 1993']
#
# BWBR0006317
# ['Algemene wet erkenning EG-hoger-onderwijsdiploma’s']
# ["Algemene wet erkenning EG-hoger-onderwijsdiploma's"]
#
# BWBR0006343
# ['']
# ['Regeling blokkade verplaatsing mestproductie']
#
# BWBR0006344
# ['']
# ['Regeling gegevensverstrekking Wet verplaatsing mestproductie']
#
# BWBR0006381
# ['']
# ['Beschikking instantloterij']
#
# BWBR0006407
# ['Het Keuringsregulatief 1994']
# ['Keuringsregulatief 1994']
#
# BWBR0006416
# ['']
# ['Regeling vervoer niet volledig gekoeld varkensvlees']
#
# BWBR0006433
# ['']
# ['Sociaal statuut Nederlands bureau brandweerexamens']
#
# BWBR0006444
# ['Regeling subsidieplafond, verdelingsregels en aanwijzing bouwjaren met betrekking tot huisvestingsvoorzieningen b.a.o. en (v.)s.o. 1994', 'Regeling subsidieplafond, verdelingsregels en aanwijzing bouwjaren met betrekking tot huisvestingsvoorzieningen b.a.o. en']
# ['Regeling subsidieplafond, verdelingsregels en aanwijzing bouwjaren met betrekking tot huisvestingsvoorzieningen b.a.o. en (v.)s.o. 1994']
#
# BWBR0006490
# ['Regeling vervoerskostenvergoeding Wvg']
# ['Regeling vervoerskostenvergoeding W.v.g']
#
# BWBR0006501
# ['reglement van orde voor de ministerraad']
# ['Reglement van orde voor de ministerraad']
#
# BWBR0006512
# ['']
# ['Algemeen brandweerexamenreglement 1994']
#
# BWBR0006551
# ['']
# ['Organisatieregeling aanhoudings- en ondersteuningseenheid']
#
# BWBR0006552
# ['']
# ['Taakbeschikking bijzondere ambtenaren van politie']
#
# BWBR0006557
# ['']
# ['Regeling politiecellencomplex']
#
# BWBR0006558
# ['']
# ['Regeling rampenidentificatieteam politie']
#
# BWBR0006567
# ['Besluit integratie-uitkering WUW-middelen Gemeentefonds']
# ['Besluit integratie-uitkering WUW-middelen gemeentefonds']
#
# BWBR0006568
# ['regeling opsporingsbijstand Koninklijke marechaussee']
# ['Regeling opsporingsbijstand Koninklijke marechaussee']
#
# BWBR0006571
# ['']
# ['Instellingsregeling bijzondere bijstandseenheden Defensie']
#
# BWBR0006579
# ['']
# ['Instellingsbesluit ministeriële commissie voor wetgevingsbeleid en rechtshandhaving']
#
# BWBR0006585
# ['']
# ['Spaarloonregeling rijkspersoneel']
#
# BWBR0006586
# ['']
# ['Besluit vaststelling wisselkoers en prijsindexcijfer']
#
# BWBR0006631
# ['']
# ['Tegemoetkomingsregeling gebruik privé-ruimte']
#
# BWBR0006642
# ['Wet verevening pensioenrechten bij scheiding']
# ['Wet vaststelling Wet verevening pensioenrechten bij scheiding']
#
# BWBR0006647
# ['Reglement persoonsregistratie Sirene-Vreemdelingen Nederland']
# ['Besluit privacyreglementen N.S.I.S. en Sirene']
#
# BWBR0006655
# ['']
# ['Uitvoeringsregeling administratieve voorschriften S&O-vermindering']
#
# BWBR0006662
# ['']
# ['Keuzeregeling verlaging pensioenbijdrageverhaal']
#
# BWBR0006665
# ['']
# ['Regeling verzoek afvalbeheersbijdragen']
#
# BWBR0006677
# ['Controlereglement Skal-controle']
# ['Regeling stimulering biologische productiemethode']
#
# BWBR0006681
# ['']
# ['Regeling uniformkleding en onderscheidingstekenen rijksbrandweerpersoneel']
#
# BWBR0006705
# ['Welzijnswet']
# ['Welzijnswet 1994']
#
# BWBR0006706
# ['']
# ['Regeling inhoud kennisgevingen en meldingen Wet Milieugevaarlijke stoffen']
#
# BWBR0006709
# ['Stofomschrijving van het onderwerp ‘De Verenigde Staten (1787–1914): samenleving op de rails’ voor het examen geschiedenis en staatsinrichting', 'Stofomschrijving van het onderwerp ‘De Verenigde Staten']
# ['Stofomschrijving van het onderwerp ‘De Verenigde Staten (1787–1914): samenleving op de rails’ voor het examen geschiedenis en staatsinrichting']
#
# BWBR0006710
# ['']
# ["Thema's voor het centraal examen maatschappijleer 1997 en 1998"]
#
# BWBR0006712
# ['']
# ['Onderwerpen centraal en schriftelijk examen aardrijkskunde 1995–1996']
#
# BWBR0006714
# ['Besluit uitvoering artikel 577, tweede lid']
# ['Besluit uitvoering artikel 577, tweede lid (Wetboek van Strafvordering)']
#
# BWBR0006719
# ['Regeling formulieren stichting basisscholen en huisvesting in het b.o. en het (v.)s.o', 'Regeling formulieren stichting basisscholen en huisvesting in het b.o. en het']
# ['Regeling formulieren stichting basisscholen en huisvesting in het b.o. en het (v.)s.o']
#
# BWBR0006724
# ['']
# ['Besluit wijziging inkomensgrenzen WRB juli 1994']
#
# BWBR0006726
# ['']
# ['Regeling tarieven Gezondheids- en welzijnswet voor dieren']
#
# BWBR0006727
# ['Regeling keuring en handel dierlijke produkten']
# ['Regeling keuring en handel dierlijke producten']
#
# BWBR0006784
# ['']
# ['Warenwetregeling Vrijstelling verduurzaamde vruchtenprodukten']
#
# BWBR0006785
# ['']
# ['Regeling invoer van vlees, bestemd voor ander gebruik dan menselijke consumptie']
#
# BWBR0006820
# ['']
# ['Regeling budgetten Wet stimulering zeescheepvaart 1994']
#
# BWBR0006821
# ['']
# ['Regeling openstelling Wet stimulering zeescheepvaart 1994']
#
# BWBR0006822
# ['']
# ['Regeling structuurplan Wet stimulering zeescheepvaart']
#
# BWBR0006823
# ['']
# ['Regeling controleprotocol Wet stimulering zeescheepvaart']
#
# BWBR0006835
# ['']
# ['Klachtenregeling seksuele intimidatie burgerlijk rijkspersoneel']
#
# BWBR0006837
# ['']
# ['Samenwerkingsregeling bestrijding terroristische misdrijven']
#
# BWBR0006880
# ['']
# ['Regeling merkteken asbestverwijdering']
#
# BWBR0006917
# ['']
# ['Keuzeregeling verlaging pensioenbijdrage militair']
#
# BWBR0006953
# ['']
# ['Regeling aandachtstoffen Wet milieugevaarlijke stoffen 1994']
#
# BWBR0006973
# ['']
# ['Besluit vaststelling ziektevoorschriften EZ']
#
# BWBR0006990
# ['Besluit dierenvervoer']
# ['Besluit dierenvervoer 1994']
#
# BWBR0007028
# ['']
# ['Regeling meldingen Wvo tandartspraktijken']
#
# BWBR0007042
# ['Besluit instelling commissie advisering bezwaarschriften personeelsleden EZ. Dit besluit zal met de toelichting in de Staatscourant worden geplaatst']
# ['Besluit instelling commissie advisering bezwaarschriften personeelsleden EZ']
#
# BWBR0007045
# ['Warenwetbesluit Gezondheidscontroles levensmiddelen van dierlijke oorsprong (intraverkeer)', 'Warenwetbesluit Gezondheidscontroles levensmiddelen van dierlijke oorsprong']
# ['Warenwetbesluit Gezondheidscontroles levensmiddelen van dierlijke oorsprong (intraverkeer)']
#
# BWBR0007075
# ['']
# ['Warenwetregeling Melkeiwitten (caseïne en caseïnaten)']
#
# BWBR0007084
# ['Verordening waterkwaliteitsbeheer Hoogheemraadschap De Stichtse Rijnlanden']
# ['Instellingsbesluit reglementering van het Hoogheemraadschap De Stichtse Rijnlanden']
#
# BWBR0007087
# ['Warenwetregeling Gezondheidscontroles levensmiddelen van dierlijke oorsprong (intraverkeer)', 'Warenwetregeling Gezondheidscontroles levensmiddelen van dierlijke oorsprong']
# ['Warenwetregeling Gezondheidscontroles levensmiddelen van dierlijke oorsprong (intraverkeer)']
#
# BWBR0007089
# ['']
# ['Regeling erkenning bedrijfsvoorraad']
#
# BWBR0007093
# ['']
# ['Regeling procedures']
#
# BWBR0007097
# ['']
# ['Regeling verwijderen van voorwerpen']
#
# BWBR0007109
# ['']
# ['Tijdelijke bijdrageregeling spoorwegaansluitingen']
#
# BWBR0007117
# ['Gedrags- en Beroepsregels Accountants-Administratieconsulenten, bij afkorting GBAA']
# ['Gedrags- en Beroepsregels Accountants-Administratieconsulenten']
#
# BWBR0007118
# ['Rijksoctrooiwet']
# ['Rijksoctrooiwet 1995']
#
# BWBR0007138
# ['volgt: Brandweerregeling Burgerluchtvaartterreinen']
# ['Brandweerregeling Burgerluchtvaartterreinen']
#
# BWBR0007139
# ['']
# ['Besluit wijziging inkomensgrenzen WRB januari 1995']
#
# BWBR0007141
# ['']
# ['Regeling VFR-nachtvluchten en minimum vlieghoogten voor militaire luchtvaartuigen']
#
# BWBR0007154
# ['']
# ['Regeling aanwijzing belanghebbenden verstrekking diefstalgegevens kentekenregister']
#
# BWBR0007159
# ['']
# ['Uitvoeringsregeling belastingen op milieugrondslag']
#
# BWBR0007194
# ['Gedrags-en beroepsregels registeraccountants 1994, bij afkorting GBR-1994. Gelijktijdig met de inwerkingtreding van deze verordening wordt ingetrokken de verordening Gedrags- en beroepsregels registeraccountants van 8 november 1973 (Stcrt. 236), laatstelijk gewijzigd op 21 juni 1994 (Stcrt. 177)', 'Gedrags-en beroepsregels registeraccountants 1994, bij afkorting GBR-1994. Gelijktijdig met de inwerkingtreding van deze verordening wordt ingetrokken de verordening Gedrags- en beroepsregels registeraccountants van 8 november 1973']
# ['Gedrags-en beroepsregels registeraccountants 1994']
#
# BWBR0007233
# ['Besluit Stuurgroep Structurering Informatievoorziening Jeugdzorg. Een afschrift van dit Besluit zal worden gezonden naar de Algemene Rekenkamer']
# ['Besluit Stuurgroep Structurering Informatievoorziening Jeugdzorg']
#
# BWBR0007243
# ['Besluit wijziging toelatings- en registratievoorschriften bestrijdingsmiddelen']
# ['Besluit wijziging toelatingsvoorschriften bestrijdingsmiddelen']
#
# BWBR0007301
# ['Seniorenbeleid Onderwijspersoneel regeling (SOP-regeling-HO)', 'Seniorenbeleid Onderwijspersoneel regeling']
# ['Wijzigingsbesluit Rechtspositiebesluit onderwijspersoneel (6)']
#
# BWBR0007351
# ['Regeling stoffen (medische hulpmiddelen)', 'Regeling stoffen']
# ['Regeling stoffen (medische hulpmiddelen)']
#
# BWBR0007359
# ['Regeling Tegemoetkoming kosten Cito-toets en NT2-cursus']
# ['Regeling Tegemoetkoming kosten cito-toets en NT2-cursus']
#
# BWBR0007370
# ['Subsidieregeling ESF doelstelling 4 ’Scholing voor Behoud van Werk']
# ['Subsidieregeling ESF doelstelling 4 ’Scholing voor behoud van werk']
#
# BWBR0007376
# ['Archiefwet']
# ['Archiefwet 1995']
#
# BWBR0007401
# ['Besluit inzake het onderzoek naar buitenlandse contacten van aspirant-pleegouders']
# ['Besluit inzake het onderzoek naar buitenlandse contacten van aspirant-adoptiefouders']
#
# BWBR0007406
# ['besluit ICPR']
# ['Besluit ICPR']
#
# BWBR0007432
# ['Gemeenschappelijke regeling Bestuur Regio Utrecht']
# ['Besluit oplegging Gemeenschappelijke regeling Bestuur Regio Utrecht']
#
# BWBR0007439
# ['Regeling Communautair Initiatief Adapt']
# ['Subsidiëring communautair initiatief Adapt']
#
# BWBR0007445
# ['']
# ['Regeling onderwerpen examen geschiedenis en staatsinrichting 1998']
#
# BWBR0007447
# ['Regeling onderwerpen en stofomschrijvingen geschiedenis en staatsinrichting 1997']
# ['Regeling onderwerpen en stofomschrijving geschiedenis en staatsinrichting 1997']
#
# BWBR0007527
# ['Beperking examenstof wiskunde B v.w.o']
# ['Beperking examenprogramma wiskunde B v.w.o']
#
# BWBR0007530
# ['Beschikking begeleidingscommissie onderzoek VB-Accountants']
# ['Beschikking begeleidingscommissie onderzoek VB-accountants']
#
# BWBR0007555
# ['Regeling loodsgeldtarieven']
# ['Regeling Loodsgeldtarieven']
#
# BWBR0007601
# ['Regeling vaststelling mede te financieren bedrag MOOZ voor 1993 en voor 1995']
# ['Vaststelling mede te financieren bedrag MOOZ voor 1993 en 1995']
#
# BWBR0007627
# ['Definitieve vaststelling aanvaardbare beheerskosten ziekenfondsverzekering en AWBZ 1995’, wordt met de bijbehorende bijlage in de Nederlandse Staatscourant geplaatst']
# ['Definitieve vaststelling aanvaardbare beheerskosten ziekenfondsverzekering en AWBZ 1995']
#
# BWBR0007629
# ['Beschikking wijzigingpercentage levensonderhoud 1996']
# ['Beschikking wijzigingspercentage levensonderhoud 1996']
#
# BWBR0007642
# ['Besluit Platform Zorgtelematica’. Een afschrift van dit besluit zal worden gezonden aan de Algemene Rekenkamer']
# ['Besluit Platform Zorgtelematica']
#
# BWBR0007693
# ['Regeling vervroegde aflossing van leningen basisonderwijs en (voortgezet) speciaal onderwijs afgesloten in 1986', 'Regeling vervroegde aflossing van leningen basisonderwijs en']
# ['Regeling vervroegde aflossing van leningen basisonderwijs en (voortgezet) speciaal onderwijs afgesloten in 1986']
#
# BWBR0007800
# ['<<Besluit ziekte en arbeidsongeschiktheid voor onderwijspersoneel primair onderwijs>>']
# ['Besluit ziekte en arbeidsongeschiktheid voor onderwijspersoneel primair onderwijs']
#
# BWBR0007837
# ['Destructiebesluit']
# ['Destructiebesluit 1996']
#
# BWBR0007893
# ['Handelsregisterwet']
# ['Handelsregisterwet 1996']
#
# BWBR0007907
# ['Lozingenbesluit Wvo stedelijk afvalwater']
# ['Lozingenbesluit WVO stedelijk afvalwater']
#
# BWBR0007955
# ['Besluit instelling Stuurgroep uitvoering Wet op de orgaandonatie’. Een afschrift van dit besluit zal worden gezonden aan de Algemene Rekenkamer']
# ['Instelling Stuurgroep Uitvoering Wet op de orgaandonatie']
#
# BWBR0007961
# ['Regeling ’Extra investerings-impuls infrastructuur in het stads- en streekvervoer']
# ["Regeling 'Extra investeringsimpuls infrastructuur in het stads- en streekvervoer"]
#
# BWBR0007984
# ['Regeling vergoeding kalvereigenaren BSE 1996']
# ['Regeling tegemoetkoming schade kalvereigenaren BSE 1996']
#
# BWBR0007990
# ['Regeling vaststelling bedragen nascholing voortgezet onderwijs (vo) 1996-1997', 'Regeling vaststelling bedragen nascholing voortgezet onderwijs']
# ['Regeling vaststelling bedragen nascholing voortgezet onderwijs (vo) 1996-1997']
#
# BWBR0008068
# ['Regeling Nationale Coördinerende Instantie Leonardo da Vinci (1995–2000)', 'Regeling Nationale Coördinerende Instantie Leonardo da Vinci']
# ['Regeling nationale Coördinerende Instantie Leonardo da Vinci (1995-2000)']
#
# BWBR0008092
# ['']
# ['Besluit Wijziging inkomensgrenzen en eigen bijdragen WRB juli 1996']
#
# BWBR0008146
# ['Besluit Departementale uitgangspunten tarievenbeleid Dienst Wegverkeer']
# ['Besluit departementale uitgangspunten tarievenbeleid Dienst Wegverkeer']
#
# BWBR0008151
# ['Besluit decentralisatie arbeids- voorwaardenvorming academische ziekenhuizen']
# ['Besluit decentralisatie arbeidsvoorwaardenvorming academische ziekenhuizen']
#
# BWBR0008162
# ['Besluit rivierdijkversterking/ hoofdwaterkeringen Provinciefonds']
# ['Besluit rivierdijkversterking/hoofdwaterkeringen Provinciefonds']
#
# BWBR0008180
# ['Opheffingsbesluit Ministeriële Commissie Noordzee Aangelegenheden (MICONA)', 'Opheffingsbesluit Ministeriële Commissie Noordzee Aangelegenheden']
# ['Opheffingsbesluit Ministeriële Commissie Noordzee Aangelegenheden (MICONA)']
#
# BWBR0008202
# ['aanvullende voorschriften en beperkingen verbonden aan machtigingen voor zendinrichtingen voor het doen van onderzoekingen door verenigingen van radiozendamateurs']
# ['aanvullende voorschriften en beperkingen verbonden aan machtigingen voor zendinrichtingen voor het doen van onderzoekingen door verenigingen van radiozendamateurs 1996']
#
# BWBR0008211
# ['Mandaatbesluit personele bevoegdheden directeur-generaal voor Openbare Orde en Veiligheid. Dit besluit zal in de Staatscourant worden geplaatst']
# ['Mandaatbesluit personele bevoegdheden directeur-generaal Openbare Orde en Veiligheid']
#
# BWBR0008233
# ['Maatregel te boek gestelde luchtvaartuigen']
# ['Maatregel te boek gestelde luchtvaartuigen 1996']
#
# BWBR0008260
# ['Vrijstellingsregeling vermeldingen bij gasverpakkingen (Warenwet)', 'Vrijstellingsregeling vermeldingen bij gasverpakkingen']
# ['Vrijstellingsregeling vermeldingen bij gasverpakkingen (Warenwet)']
#
# BWBR0008265
# ['Verhaalsregeling vut-bijdrage sector Rijk bij buitengewoon verlof van lange duur']
# ['Buitengewoon verlof van lange duur bij de sector Rijk']
#
# BWBR0008308
# ['Beschikking wijzigingsper-centage levensonderhoud 1997']
# ['Beschikking wijzigingspercentage levensonderhoud 1997']
#
# BWBR0008363
# ['Extra vergoeding voor leermiddelen 1996 voor gefuseerde scholen in het kader van Toerusting en Bereikbaarheid (TenB)', 'Extra vergoeding voor leermiddelen 1996 voor gefuseerde scholen in het kader van Toerusting en Bereikbaarheid']
# ['Extra vergoeding voor leermiddelen 1996 voor gefuseerde scholen in het kader van Toerusting en Bereikbaarheid (TenB)']
#
# BWBR0008391
# ['Regeling samenvoeging van scholen in het primair onderwijs (po) per 1 augustus 1997', 'Regeling samenvoeging van scholen in het primair onderwijs']
# ['Regeling samenvoeging van scholen in het primair onderwijs (po) per 1 augustus 1997']
#
# BWBR0008417
# ['Overgangsregeling materiele instandhouding TenB-dislocaties']
# ['Overgangsregeling materiële instandhouding TenB-dislocaties']
#
# BWBR0008527
# ['vrijstellingsregeling sneeuw- en gladheidsbestrijding']
# ['Vrijstellingsregeling sneeuw- en gladheidsbestrijding']
#
# BWBR0008546
# ['Regeling Communautair Initiatief Adapt-II']
# ['Regeling Communautair Initiatief ADAPT-II']
#
# BWBR0008580
# ['Salarisbesluit werkervaringsplaatsen Ministerie van Binnenlandse Zaken']
# ['Salarisbesluit werkervaringsplaatsen']
#
# BWBR0008587
# ['persoonscertificaat duikploegleider bij de brandweer. De verkorte aanduiding is WSCS-WOD-F']
# ['Arbeidsomstandighedenregeling']
#
# BWBR0008604
# ['Nederlandse uitvoeringsvoorschriften belastingverdrag Nederland-Mexico']
# ['Nederlandse voorschriften tot uitvoering belastingverdrag Nederland-Mexico']
#
# BWBR0008677
# ['']
# ["Inhoudsomschrijving thema 'Criminaliteit en rechtsstaat' examen maatschappijleer vwo, schooljaren 1998-1999 en 1999-2000"]
#
# BWBR0008698
# ['Faciliteitenregeling roc-vorming 1997']
# ['Faciliteitenregeling ROC-vorming 1997']
#
# BWBR0008731
# ['Besluit naturalisatiegelden 1997']
# ['Besluit Naturalisatiegelden 1997']
#
# BWBR0008832
# ['Besluit uitvoering aangelegenheden door de directeur Financieel-economische zaken op grond van de Comptabiliteitswet']
# ['Besluit uitvoering aangelegenheden door de directeur Financieel- economische zaken op grond van de Comptabiliteitswet']
#
# BWBR0008851
# ['Regeling aandachtspunten voor de accountantscontrole Onafhankelijke Post en Telecommunicatie Autoriteit']
# ['Regeling aandachtspunten accountantscontrole OPTA']
#
# BWBR0008854
# ['Regeling rechtspositie vaste leden van de Onafhankelijke Post en Telecom-municatie Autoriteit']
# ['Regeling rechtspositie vaste leden van de Onafhankelijke Post en Telecommunicatie Autoriteit']
#
# BWBR0008875
# ['Besluit Adviseurs Beeldende Kunst 1997']
# ['Besluit adviseurs beeldende kunst 1997']
#
# BWBR0008891
# ['Besluit landelijk beleidskader gemeentelijk onderwijsachterstandenbeleid 1998–2002']
# ['Besluit landelijk beleidskader gemeentelijk onderwijsachterstandenbeleid']
#
# BWBR0008933
# ['Extra vergoeding voor leermiddelen 1997 voor gefuseerde scholen in het kader van Toerusting en Bereikbaarheid (TenB)', 'Extra vergoeding voor leermiddelen 1997 voor gefuseerde scholen in het kader van Toerusting en Bereikbaarheid']
# ['Extra vergoeding voor leermiddelen 1997 voor gefuseerde scholen in het kader van Toerusting en Bereikbaarheid (TenB)']
#
# BWBR0008993
# ['Aanwijzing macro-verstrekkingen-budget ziekenfondsverzekering 1998']
# ['Aanwijzing macro-verstrekkingenbudget ziekenfondsverzekering 1998']
#
# BWBR0009034
# ['Vrijstellingsregeling natuurlijk mineraal- en bronwater (Warenwet)', 'Vrijstellingsregeling natuurlijk mineraal- en bronwater']
# ['Vrijstellingsregeling natuurlijk mineraal- en bronwater (Warenwet)']
#
# BWBR0009088
# ['Tijdelijke regeling toelating voortgezet algemeen volwassenen onderwijs (vavo)', 'Tijdelijke regeling toelating voortgezet algemeen volwassenen onderwijs']
# ['Tijdelijke regeling toelating voortgezet algemeen volwassenen onderwijs (vavo)']
#
# BWBR0009179
# ['Besluit vaststelling van het deel van de premie van de Werkloosheidswet dat ten gunste komt van het Algemeen Werkloosheidsfonds']
# ['Regeling goedkeuring vaststelling premiepercentage Awf en vaststelling franchises WW']
#
# BWBR0009205
# ['Regeling verstrekkingen asielzoekers en andere categorieën vreemdelingen 1997']
# ['Regeling verstrekkingen asielzoekers en andere categorieën vreemdelingen 1997 (Rva 1997)']
#
# BWBR0009242
# ['Subsidieregeling emancipatieonder-steuning 1998']
# ['Subsidieregeling emancipatie-ondersteuning 1998']
#
# BWBR0009276
# ['Wet op de kamers van koophandel en fabrieken']
# ['Wet op de kamers van koophandel en fabrieken 1997']
#
# BWBR0009291
# ['Regeling tot vaststelling van het tijdvak voor de bepaling van het inkomen alsmede tot verstrekken door de Sociale verzekeringsbank van een verklaring over het inkomen van personen van 65 jaar of ouder']
# ['Regeling tot vaststelling van het tijdvak voor de bepaling van het inkomen alsmede tot verstrekken door de Sociale Verzekeringsbank van een verklaring over het inkomen van personen van 65 jaar of ouder']
#
# BWBR0009299
# ['Besluit rekening baten en lasten …']
# ['Verordening financiën bedrijfslichamen 1999']
#
# BWBR0009357
# ['Regeling samenloop kinderbijslag op grond van de Algemene Kinderbijslagwet met buitenlandse kinderbijslag of kinderbijslag op grond van een regeling van een volkenrechtelijke organisatie']
# ['Regeling samenloop kinderbijslag']
#
# BWBR0009434
# ['Besluit vaststelling investeringslijst Investeringsregeling markt en concurrentiekracht']
# ['Besluit vaststelling investeringslijst markt en concurrentiekracht']
#
# BWBR0009565
# ['Wet op de (re)integratie arbeidsgehandicapten', 'Wet op de']
# ['Wet op de (re)integratie arbeidsgehandicapten']
#
# BWBR0009587
# ['Regeling examenprogramma’s proﬁelen v.w.o./h.a.v.o. Nederlands en moderne vreemde talen']
# ['Regeling examenprogramma’s profielen v.w.o./h.a.v.o. Nederlands en moderne vreemde talen']
#
# BWBR0009593
# ['Regeling examenprogramma’s proﬁelen v.w.o./h.a.v.o. wiskunde']
# ['Regeling examenprogramma’s profielen v.w.o./h.a.v.o. wiskunde']
#
# BWBR0009594
# ['Regeling examenprogramma proﬁelen v.w.o./h.a.v.o. lichamelijke opvoeding 1']
# ['Regeling examenprogramma profielen v.w.o./h.a.v.o. lichamelijke opvoeding 1']
#
# BWBR0009596
# ['Regeling examenprogramma’s proﬁelen v.w.o./h.a.v.o. maatschappelijke vakken']
# ['Regeling examenprogramma’s profielen v.w.o./h.a.v.o. maatschappelijke vakken']
#
# BWBR0009609
# ['Reïntegratie-instrumentenbesluit Wet REA']
# ['Reïntegratie-instrumenten-besluit Wet REA']
#
# BWBR0009641
# ['Natuurbeschermingswet']
# ['Natuurbeschermingswet 1998']
#
# BWBR0009643
# ['Besluit Herinneringsmedaille vrijwillige politie 1948-1998']
# ['Besluit herinneringsmedaille vrijwillige politie 1948-1998']
#
# BWBR0009682
# ['voorlichtingspublicatie WPO/WEC/WVO']
# ['Regeling samenvoeging van scholen in het basisonderwijs en (voortgezet) speciaal onderwijs per 1 augustus 1998']
#
# BWBR0009732
# ['']
# ["Regeling thema's centraal examen geschiedenis h.a.v.o. (profielen) 2000 en stofomschrijving ‘oude stijl’ 2000"]
#
# BWBR0009755
# ['Elektriciteitswet']
# ['Elektriciteitswet 1998']
#
# BWBR0009772
# ['Centraal examen filosofie (profielen) 2000 en 2001 havo en 2001 en 2002 vwo', 'Centraal examen filosofie']
# ['Centraal examen filosofie (profielen) 2000 en 2001 havo en 2001 en 2002 vwo']
#
# BWBR0009781
# ['Regeling versterking en innovatie agrarisch onderwijs (VIA-regeling)', 'Regeling versterking en innovatie agrarisch onderwijs']
# ['Regeling versterking en innovatie agrarisch onderwijs (VIA-regeling)']
#
# BWBR0009815
# ['Besluit subsidie Nederlands Politie Instituut']
# ['Besluit subsidieverlening Nederlands Politie Instituut']
#
# BWBR0009827
# ['Privacyreglement registratie inhouding bezoldiging bij het Ministerie van Justitie 1998']
# ['Vaststelling Privacyreglement inhouding bezoldiging Ministerie van Justitie 1998']
#
# BWBR0009909
# ['Regeling aanwijzing nieuwkomers wegens verblijf voor een tijdelijk doel']
# ['Regeling aanwijzing nieuwkomers wegens verblijf voor tijdelijk doel']
#
# BWBR0009925
# ["Beleidsregel gemengde leerweg aan AOC's na bestuurlijke samenwerking 1999-2002"]
# ["Beleidsregel gemengde leerweg aan aoc's na bestuurlijke samenwerking 1999-2002"]
#
# BWBR0009927
# ["Wijziging programma's van eisen (v)so en vaststelling bedragen voor 1999", "Wijziging programma's van eisen"]
# ["Wijziging programma's van eisen (v)so en vaststelling bedragen voor 1999"]
#
# BWBR0009928
# ["wijziging programma's van eisen basisonderwijs en vaststelling bedragen voor 1999"]
# ["Wijziging programma's van eisen basisonderwijs en vaststelling bedragen voor 1999"]
#
# BWBR0009953
# ['']
# ['Besluit cliëntenvertrouwenspersoon jeugdhulpverlening en jeugdbescherming']
#
# BWBR0009962
# ['']
# ['Aanwijzing domeinenen centraal examen maatschappijleer havo, examenjaar 2000']
#
# BWBR0009987
# ['Subsidieregeling millenniumkosten in het primair onderwijzen het voorgezet speciaal onderwijs']
# ['Subsidieregeling millenniumkosten in het primair onderwijzen het voortgezet speciaal onderwijs']
#
# BWBR0009995
# ['Besluit aanwijzing openbare telecommunicatiediensten (geschillencommissie)', 'Besluit aanwijzing openbare telecommunicatiediensten']
# ...
#
# BWBR0045949
# ['Beleidsregel prestatiebeschrijving en tarieven advies crisis- en ondersteuningsteam (COT) 2022', 'Beleidsregel prestatiebeschrijving en tarieven advies crisis- en ondersteuningsteam']
# ['Beleidsregel prestatiebeschrijving en tarieven advies crisis- en ondersteuningsteam (COT) 2022']
#
# BWBR0045956
# ['']
# ['Beleidsregel macrobeheersinstrument geriatrische revalidatiezorg, eerstelijnsverblijf, geneeskundige zorg voor specifieke patiëntgroepen en medische verklaring 2022']
#
# BWBR0045964
# ['Regeling specifieke uitkering MKB-innovatiestimulering topsectoren (MIT)', 'Regeling specifieke uitkering MKB-innovatiestimulering topsectoren']
# ['Regeling specifieke uitkering MKB-innovatiestimulering topsectoren (MIT)']
#
# BWBR0045983
# ['Besluit uitvoering Crisis- en herstelwet (tweeëntwintigste tranche)', 'Besluit uitvoering Crisis- en herstelwet']
# ['Besluit uitvoering Crisis- en herstelwet (tweeëntwintigste tranche)']
#
# BWBR0045995
# ['Specifiek interventiebeleid NVWA tabak en rookwaren (IB02-SPEC 31, versie 13)', 'Specifiek interventiebeleid NVWA tabak en rookwaren']
# ['Specifiek interventiebeleid NVWA tabak en rookwaren (IB02-SPEC 31, versie 13)']
#
# BWBR0046023
# ['Regeling maatregelen bewakingszone hoogpathogene vogelgriep Ravels 2021.18 december 2021, 20:58 uur']
# ['Regeling maatregelen bewakingszone hoogpathogene vogelgriep Ravels 2021']
#
# BWBR0046037
# ['Beleidsregel beschikbaarheidbijdrage (medische) vervolgopleidingen 2022', 'Beleidsregel beschikbaarheidbijdrage']
# ['Beleidsregel beschikbaarheidbijdrage (medische) vervolgopleidingen 2022']
#
# BWBR0046099
# ['Regeling autoriteiten verordening (EU) 2018/848 en verordening (EU) 2017/62', 'Regeling autoriteiten verordening']
# ['Regeling autoriteiten verordening (EU) 2018/848 en verordening (EU) 2017/62']
#
# BWBR0046146
# ['Regeling verplichte financiële bijdragen onderzoeks- en innovatieagenda Nederlandse varkenssector 2021–2027']
# ['Besluit inwilliging AVV-verzoek POV Nederlandse varkenssector']
#
# BWBR0046157
# ['Regeling Informatiehuishouding Financiën 2022 (RINFIN 2022)', 'Regeling Informatiehuishouding Financiën 2022']
# ['Regeling Informatiehuishouding Financiën 2022 (RINFIN 2022)']
#
# BWBR0046166
# ['Tijdelijke vrijstelling ter bescherming van goederen bestemd voor de export naar Australië en Nieuw-Zeeland tegen bruin gemarmerde stinkwants (Halymorphahalys), 2022', 'Tijdelijke vrijstelling ter bescherming van goederen bestemd voor de export naar Australië en Nieuw-Zeeland tegen bruin gemarmerde stinkwants']
# ['Tijdelijke vrijstelling ter bescherming van goederen bestemd voor de export naar Australië en Nieuw-Zeeland tegen bruin gemarmerde stinkwants (Halymorpha halys), 2022']
#
# BWBR0046199
# ['Regeling maatregelen beschermings- en bewakingszone hoogpathogene vogelgriep Bocholt (België) 2022.17 januari 2022, 15:01 uur', 'Regeling maatregelen beschermings- en bewakingszone hoogpathogene vogelgriep Bocholt']
# ['Regeling maatregelen beschermings- en bewakingszone hoogpathogene vogelgriep Bocholt (België) 2022']
#
# BWBR0046200
# ['Regeling maatregelen beschermings- en bewakingszone hoogpathogene vogelgriep Bentelo 2022.14 januari 2022, 15:55 uur']
# ['Regeling maatregelen beschermings- en bewakingszone hoogpathogene vogelgriep Bentelo 2022']
#
# BWBR0046223
# ['Verzamelwet EZK']
# ['Verzamelwet EZK 2022']
#
# BWBR0046234
# ['Subsidieregeling Verduurzaming en Onderhoud Huurwoningen (SVOH)', 'Subsidieregeling Verduurzaming en Onderhoud Huurwoningen']
# ['Subsidieregeling Verduurzaming en Onderhoud Huurwoningen (SVOH)']
#
# BWBR0046249
# ['regeling ontheffing goedkeuring afmetingen en massa’s landbouw- of bosbouwvoertuigen en mobiele machines']
# ['Regeling ontheffing goedkeuring afmetingen en massa’s landbouw- of bosbouwvoertuigen en mobiele machines']
#
# BWBR0046254
# ['firmaproblematiek en terugwerkende kracht']
# ['Firmaproblematiek en terugwerkende kracht']
#
# BWBR0046309
# ['Nadere voorschriften controle- en overige Standaarden, bij afkorting NV COS']
# ['Nadere voorschriften controle- en overige Standaarden']
#
# BWBR0046405
# ['Regeling vergunningverlening windenergiegebied Hollandse Kust (west) kavel VII', 'Regeling vergunningverlening windenergiegebied Hollandse Kust']
# ['Regeling vergunningverlening windenergiegebied Hollandse Kust (west) kavel VII']
#
# BWBR0046407
# ['Regeling vergunningverlening windenergiegebied Hollandse Kust (west) kavel VI', 'Regeling vergunningverlening windenergiegebied Hollandse Kust']
# ['Regeling vergunningverlening windenergiegebied Hollandse Kust (west) kavel VI']
#
# BWBR0046444
# ['Verzamelwet OCW']
# ['Verzamelwet OCW 2022']
#
# BWBR0046495
# ['Besluit buitengewoon opsporingsambtenaar Ministerie van Landbouw Natuur en Voedselkwaliteit, Directoraat Generaal Natuur Visserij en Landelijk Gebied (DG NVLG) / Waddenunit 2022', 'Besluit buitengewoon opsporingsambtenaar Ministerie van Landbouw Natuur en Voedselkwaliteit, Directoraat Generaal Natuur Visserij en Landelijk Gebied']
# ['Besluit buitengewoon opsporingsambtenaar Ministerie van Landbouw Natuur en Voedselkwaliteit, Directoraat Generaal Natuur Visserij en Landelijk Gebied (DG NVLG) / Waddenunit 2022']
#
# BWBR0046507
# ['Regeling verplichte financiële bijdragen BO Sierteeltproducten']
# ['Besluit inwilliging AVV-verzoek onderzoek brancheorganisatie Sierteeltproducten']
#
# BWBR0046565
# ['Regeling registratieonderzoek eerstelijnsverblijf en Wlz crisiszorg vv']
# ['Regeling registratieonderzoek eerstelijnsverblijf en Wlz crisis-zorg vv']
#
# BWBR0046612
# ['Mandaatbesluit Wet open overheid']
# ['Mandaatbesluit Wet open overheid Eerste Kamer']
#
# BWBR0046689
# ['Specifiek interventiebeleid NVWA tabak en rookwaren (IB02-SPEC 31, versie 14)', 'Specifiek interventiebeleid NVWA tabak en rookwaren']
# ['Specifiek interventiebeleid NVWA tabak en rookwaren (IB02-SPEC 31, versie 14)']
#
# BWBR0046704
# ['Implementatiebesluit omnibusrichtlijn en -verordening ESFS-review']
# ['Implementatiebesluit omnibusrichtlijn ESFS-review']
#
# BWBR0046708
# ['Besluit participatiefonds']
# ['Besluit participatiefonds 2022']
#
# BWBR0046718
# ['Uitvoeringsregeling Meststoffenwet']
# ['Vrijstellingsregeling vroegtijdige toepassing rVDM-systeem']
#
# BWBR0046736
# ['Tijdelijke vrijstelling ter bescherming van de onbedekte teelt van kers, druif, pruim en blauwe bes tegen suzuki-fruitvlieg (Drosophila suzukii), 2022', 'Tijdelijke vrijstelling ter bescherming van de onbedekte teelt van kers, druif, pruim en blauwe bes tegen suzuki-fruitvlieg']
# ['Tijdelijke vrijstelling ter bescherming van de onbedekte teelt van kers, druif, pruim en blauwe bes tegen suzuki-fruitvlieg (Drosophila suzukii), 2022']
#
# BWBR0046742
# ['Tijdelijke vrijstelling ter bescherming van de onbedekte teelt van druif en kers tegen suzuki-fruitvlieg (Drosophila suzukii), 2022', 'Tijdelijke vrijstelling ter bescherming van de onbedekte teelt van druif en kers tegen suzuki-fruitvlieg']
# ['Tijdelijke vrijstelling ter bescherming van de onbedekte teelt van druif en kers tegen suzuki-fruitvlieg (Drosophila suzukii), 2022']
#
# BWBR0046787
# ['Beleidsregel ontheffingen Minister van EZK en Minister voor KE verbod artikel 5 duodecies Verordening (EU) nr 833/2014', 'Beleidsregel ontheffingen Minister van EZK en Minister voor KE verbod artikel 5 duodecies Verordening']
# ['Beleidsregel ontheffingen Minister van EZK en Minister voor KE verbod artikel 5 duodecies Verordening (EU) nr 833/2014']
#
# BWBR0046795
# ['']
# ['Beleidsregel macrobeheersinstrument kortdurende zorg 2023']
#
# BWBR0046824
# ['Beleidsregel nadere invulling Verordening (EG) 178/2002', 'Beleidsregel nadere invulling Verordening']
# ['Beleidsregel nadere invulling Verordening (EG) 178/2002']
#
# BWBR0046828
# ['Beleidsregel wijziging van de vergunningen windenergie op zee voor kavels VI en VII Hollandse Kust (west)', 'Beleidsregel wijziging van de vergunningen windenergie op zee voor kavels VI en VII Hollandse Kust']
# ['Beleidsregel wijziging van de vergunningen windenergie op zee voor kavels VI en VII Hollandse Kust (west)']
#
# BWBR0046945
# ['Aanwijzingsbesluit Uitvoering Van Beleid (Toetsingskamer STAP)', 'Aanwijzingsbesluit Uitvoering Van Beleid']
# ['Aanwijzingsbesluit Uitvoering Van Beleid (Toetsingskamer STAP)']
#
# BWBR0046972
# ['Beleidsbesluit aanpassing looptijd wegens (getemporiseerde) verhoging van de AOW-leeftijd', 'Beleidsbesluit aanpassing looptijd wegens']
# ['Beleidsbesluit aanpassing looptijd wegens (getemporiseerde) verhoging van de AOW-leeftijd']
#
# BWBR0047030
# ['Beleidsregel beschikbaarheidbijdrage (medische) vervolgopleidingen 2023', 'Beleidsregel beschikbaarheidbijdrage']
# ['Beleidsregel beschikbaarheidbijdrage (medische) vervolgopleidingen 2023']
#
# BWBR0047090
# ['Tijdelijke vrijstelling ter bescherming van goederen bestemd voor de export naar Australië en Nieuw-Zeeland tegen bruin gemarmerde stinkwants (Halymorpha halys), 2022-2', 'Tijdelijke vrijstelling ter bescherming van goederen bestemd voor de export naar Australië en Nieuw-Zeeland tegen bruin gemarmerde stinkwants']
# ['Tijdelijke vrijstelling ter bescherming van goederen bestemd voor de export naar Australië en Nieuw-Zeeland tegen bruin gemarmerde stinkwants (Halymorpha halys), 2022-2']
#
# BWBR0047121
# ['Besluit buitengewoon opsporingsambtenaar gemeente Breda 2022 (domein V)', 'Besluit buitengewoon opsporingsambtenaar gemeente Breda 2022']
# ['Besluit buitengewoon opsporingsambtenaar gemeente Breda 2022 (domein V)']
#
# BWBR0047349
# ['Beleidsregel normatieve huisvestingscomponent (nhc) en normatieve inventariscomponent (nic) gespecialiseerde ggz, forensische zorg en langdurige zorg', 'Beleidsregel normatieve huisvestingscomponent']
# ['Beleidsregel normatieve huisvestingscomponent (nhc) en normatieve inventariscomponent (nic) gespecialiseerde ggz, forensische zorg en langdurige zorg']
#
# BWBR0047352
# ['Beleidsregel prestatiebeschrijving en tarieven advies crisis- en ondersteuningsteam (COT) 2023', 'Beleidsregel prestatiebeschrijving en tarieven advies crisis- en ondersteuningsteam']
# ['Beleidsregel prestatiebeschrijving en tarieven advies crisis- en ondersteuningsteam (COT) 2023']
#
# BWBR0047377
# ['Specifiek interventiebeleid NVWA voedselveiligheid industriële productie, vis, zuivel en eieren (IB02-SPEC 39, versie 14)', 'Specifiek interventiebeleid NVWA voedselveiligheid industriële productie, vis, zuivel en eieren']
# ['Specifiek interventiebeleid NVWA voedselveiligheid industriële productie, vis, zuivel en eieren (IB02-SPEC 39, versie 14)']
#
# BWBR0047381
# ['Specifiek interventiebeleid NVWA Gastoestellen (IB02-SPEC 55, versie 01)', 'Specifiek interventiebeleid NVWA Gastoestellen']
# ['Specifiek interventiebeleid NVWA Gastoestellen (IB02-SPEC 55, versie 01)']
#
# BWBR0047391
# ['Specifiek interventiebeleid NVWA voedselcontact-materialen (IB02-SPEC 61, versie 01)', 'Specifiek interventiebeleid NVWA voedselcontact-materialen']
# ['Specifiek interventiebeleid NVWA voedselcontact-materialen (IB02-SPEC 61, versie 01)']
#
# BWBR0047409
# ['Specifiek interventiebeleid NVWA dierenwelzijn (IB02-SPEC 02, versie 06)', 'Specifiek interventiebeleid NVWA dierenwelzijn']
# ['Specifiek interventiebeleid NVWA dierenwelzijn (IB02-SPEC 02, versie 06)']
#
# BWBR0047410
# ['Specifiek interventiebeleid NVWA draagbaar klimmaterieel (IB02-SPEC 53, versie 01)', 'Specifiek interventiebeleid NVWA draagbaar klimmaterieel']
# ['Specifiek interventiebeleid NVWA draagbaar klimmaterieel (IB02-SPEC 53, versie 01)']
#
# BWBR0047411
# ['Specifiek interventiebeleid NVWA Kinderbedden en -boxen (IB02-SPEC 50, versie 01)', 'Specifiek interventiebeleid NVWA Kinderbedden en -boxen']
# ['Specifiek interventiebeleid NVWA Kinderbedden en -boxen (IB02-SPEC 50, versie 01)']
#
# BWBR0047415
# ['Subsidieregeling strategisch belangrijke onderzoeksprogramma’s (SBO)', 'Subsidieregeling strategisch belangrijke onderzoeksprogramma’s']
# ['Subsidieregeling strategisch belangrijke onderzoeksprogramma’s (SBO)']
#
# BWBR0047424
# ['Subtaak- en ondermandaatbesluit Human Resources & Bedrijfsvoering (Kerndepartement) 2022', 'Subtaak- en ondermandaatbesluit Human Resources & Bedrijfsvoering']
# ['Subtaak- en ondermandaatbesluit Human Resources & Bedrijfsvoering (Kerndepartement) 2022']
#
# BWBR0047512
# ['Besluit ondermandaat, volmacht en machtiging betreffende de uitvoering van de Wet open overheid van de algemeen directeur Midden- en kleinbedrijf']
# ['Besluit ondermandaat, volmacht en machtiging betreffende de uitvoering van de Wet open overheid van de algemeen directeur Midden- en kleinbedrijf 2022']
#
# BWBR0047545
# ['Regeling verplichte aanlevering minimale dataset (mds) medisch specialistische zorg', 'Regeling verplichte aanlevering minimale dataset']
# ['Regeling verplichte aanlevering minimale dataset (mds) medisch specialistische zorg']
#
# BWBR0047618
# ['Specifiek interventiebeleid NVWA voedselveiligheid bij horeca, ambachtelijke productie, retail en instellingen (IB02-SPEC 37, versie 07)', 'Specifiek interventiebeleid NVWA voedselveiligheid bij horeca, ambachtelijke productie, retail en instellingen']
# ['Specifiek interventiebeleid NVWA voedselveiligheid bij horeca, ambachtelijke productie, retail en instellingen (IB02-SPEC 37, versie 07)']
#
# BWBR0047731
# ['Regeling verplichte financiële bijdragen glastuinbouw ten behoeve van het gezamenlijk programma onderzoek en innovatie Kennis in je Kas']
# ['Besluit inwilliging AVV-verzoek Glastuinbouwsector Sierteeltproducten']
#
# BWBR0047732
# ['Regeling verplichte financiële bijdragen glastuinbouw t.b.v. gezamenlijk programma onderzoek en innovatie Kennis in je Kas']
# ['Besluit inwilliging AVV-verzoek Glastuinbouwsector (groenten en fruit onder glas)']
#
# BWBR0047740
# ['Nadere voorschriften controle- en overige Standaarden, bij afkorting NV COS']
# ['Nadere voorschriften controle- en overige Standaarden']
#
# BWBR0047906
# ['Besluit Mandaatregeling subsidie Koninklijke Bibliotheek 2022']
# ['Reglement van de Koninklijke Bibliotheek 2023']
#
# BWBR0047933
# ['Subsidieregeling startbijdrage mediation. De Regeling zal met de toelichting in de Staatscourant worden geplaatst']
# ['Subsidieregeling startbijdrage mediation']
#
# BWBR0047947
# ['Beleidsregel kaders medewerking defensie aan (defensie-) schietverenigingen, studentenweerbaarheidsverenigingen en defensieschietteams', 'Beleidsregel kaders medewerking defensie aan']
# ['Beleidsregel kaders medewerking defensie aan (defensie-) schietverenigingen, studentenweerbaarheidsverenigingen en defensieschietteams']
#
# BWBR0047964
# ['']
# ['Beleidsregels CAK termijnen eigen bijdrage Wlz en Wmo 2015']
#
# BWBR0047993
# ['Beleidsregel boeteoplegging Arbeidstijdenwet en Arbeidstijdenbesluit vervoer (wegvervoer) 2022', 'Beleidsregel boeteoplegging Arbeidstijdenwet en Arbeidstijdenbesluit vervoer']
# ['Beleidsregel boeteoplegging Arbeidstijdenwet en Arbeidstijdenbesluit vervoer (wegvervoer) 2022']
#
# BWBR0048013
# ['Tijdelijke vrijstelling ter bescherming van de teelt van peulvruchten (m.u.v. sojaboon), uien, sjalotten, prei (onbedekte teelt), bieslook (onbedekte teelt) en bloembollen en bloemknollen (onbedekte teelt) tegen éénjarige onkruiden, 2023', 'Tijdelijke vrijstelling ter bescherming van de teelt van peulvruchten']
# ['Tijdelijke vrijstelling ter bescherming van de teelt van peulvruchten (m.u.v. sojaboon), uien, sjalotten, prei (onbedekte teelt), bieslook (onbedekte teelt) en bloembollen en bloemknollen (onbedekte teelt) tegen éénjarige onkruiden, 2023']
#
# BWBR0048112
# ['Leidraad meldingsplichtige grensoverschrijdende constructies']
# ['Besluit meldingsplichtige grensoverschrijdende constructies']
#
# BWBR0048134
# ['Tijdelijke vrijstelling ter bescherming van de onbedekte teelt van druif en kers tegen suzuki-fruitvlieg (Drosophila suzukii), 2023', 'Tijdelijke vrijstelling ter bescherming van de onbedekte teelt van druif en kers tegen suzuki-fruitvlieg']
# ['Tijdelijke vrijstelling ter bescherming van de onbedekte teelt van druif en kers tegen suzuki-fruitvlieg (Drosophila suzukii), 2023']
#
# BWBR0048142
# ['Beleidsregel beschikbaarheidbijdrage (medische) vervolgopleidingen 2023', 'Beleidsregel beschikbaarheidbijdrage']
# ['Beleidsregel beschikbaarheidbijdrage (medische) vervolgopleidingen 2023']
#
# BWBR0048169
# ['Regeling Specifieke uitkering noodfonds energie amateursportverenigingen']
# ['Regeling Specifieke uitkering noodfonds energie amateursport-verenigingen']

# %% [markdown]
# ### Extrefs in the BWB
#
# In the BWB in XML form, `<extref>` tags are referces to other laws, regulations, and more.
# In a wider context, extref tags are fairly free-form in what link text they contain,
# yet within the set of laws they are used fairly consistently and provide fairly clean data.
#
# We are currently interested in those that point to laws, and those will contain a BRB-ids and look something like:
# `<extref verwijzing-id="2189982" doc="jci1.3:c:BWBR0015163&amp;artikel=5" bwb-id="BWBR0015163" label-id="4716344">artikel 5 van het Instellingsbesluit Productschap Vis</extref>`
# We should perhaps filter by it pointing to BWB documents with soort=wet, but can do that later.
#
# As we specifically look for repeated, clearer cases, we are not bothered to extract every reference - we are just looking for consistentas long as a majority is considered useful.

# %%
bwb_names_extref = collections.defaultdict(list)   # BWB-id -> list of name strings    (those names being what references from elsewhere call this BWB)

for xml_url in bwb_latestonly_xml.keys():
    tree = cached_parse( bwb_latestonly_xml, xml_url )
    #meta = wetsuite.helpers.koop_parse.bwb_toestand_usefuls(tree)

    for extref_tag in tree.iter(tag='extref'): # find all external references, regardless of context in the document

        # is the thing we point to marked with a BWB identifier   (this may miss some things, but the else: below should tell us)
        ref_bwb = extref_tag.get('bwb-id') # normalize?
        if ref_bwb is not None:
            # We might not care about things the above didn't already have names for
            #if ref_bwb not in bwb_name_self:
            #    continue

            # (parsing an extref tag might become a function eventually, but right now it's specific content in a specific dataset)

            if extref_tag.text is not None:

                name = name_from_extref_tag( extref_tag )
                if name is None:
                    #print( "SKIP, apparently boring name: %r"%wetsuite.helpers.etree.tostring(extref_tag).decode('utf8') )
                    continue

                if name.endswith(')') and '(' in name: 
                    i = name.rfind('(') # find last open bracket, if there are multiple
                    
                    one = cleanup_wet_title( name[:i].strip() )
                    bwb_names_extref[ref_bwb].append( one )
                    
                    # IF this seems to be in the form 'bla bla (wet bla)' or 'bla bla (blawet)', then add the bracket contents
                    two = cleanup_wet_title( name[i+1:-1].strip() ) # -1 is valid only as long as that endswith up there stays
                    if ' ' in two and 'wet' in two.lower():
                        bwb_names_extref[ref_bwb].append( two )
                else: # enter as-is
                    bwb_names_extref[ref_bwb].append( name )

                # Note that we're specifically recording every reference (there will be many duplicates), 
                #  so that we can count them later and 

        else: # not references to bwb entries 
            # some checks to ignore what we know of and might handle later,
            #  and to print out everything else to figure out what we don't handle yet
            if extref_tag.get('reeks') == 'Celex': # EU identifiers
                pass
            elif extref_tag.get('doc') == 'onbekend': # ?
                pass
            else: # currently a few dozen cases left, that's fine to ignore
                pass
                #print( 'UNKNOWN extref %r'%(wetsuite.helpers.etree.tostring(extref_tag).decode('u8')) )

# %%
# everything we just collected -- warning: about 300K lines of output
#pprint.pprint( bwb_names_extref )

# %% [markdown]
# ### Check: check whether what we collect looks reasonable
#
# The above extracted
# * `bwb_names_citeertitel` from metadata
# * `bwb_names_aanhaling`   from text
# * `bwb_names_extref`      from links
#    * _every_ occurence was added to a list, to be able to count which one is common. We can use `wetsuite.extras.word_cloud.count_normalized()`, which also lets us unify capitalization-only variation (and reports the most common capitalisation)
#
# We could do do various things with this, e.g.
# * count extref names (or _all_) -- to look at unusual cases
# * look at ambiguity, e.g. duplicates
# * names used for self, names used by others -- to search in

# %%
# Look at some hand picked examples

bwbrs = sorted(  set(bwb_names_citeertitel) | set( bwb_names_aanhaling) | set(bwb_names_extref)  )  # their keys,  so joins all bwb-ids that any part found
print( 'Distinct BWB-ids we found some names for: ',len(bwbrs) )

for example_bwbid in ('BWBR0031986', # here to point out it's mostly laws that have citeertotels and aanhaaling paragraphs - references to this may be more descriptive
                      'BWBR0005537', # here to point out we can find acronyms too  (though we may need some cleverer non-linear behaviour in count_normalized)
                      'BWBR0015703', # here to point out this one changed names
):
    print()
    print( ' --> ', example_bwbid )
    print( 'Citeer:              ', bwb_names_citeertitel.get(example_bwbid) )
    print( 'Aanhaal:             ', bwb_names_aanhaling.get(example_bwbid)   )
    print( 'Extref refs to this: ', len(bwb_names_extref.get(example_bwbid))   )
    print( '  distinct & count:  ', wetsuite.extras.word_cloud.count_normalized( bwb_names_extref.get(example_bwbid), min_count=1,   min_word_length=1, normalize_func=lambda x:x.lower().strip() ) )
    print( '  filtered:          ', wetsuite.extras.word_cloud.count_normalized( bwb_names_extref.get(example_bwbid), min_count=0.05, min_word_length=1, normalize_func=lambda x:x.lower().strip() ) )
# Out:
# Distinct BWB-ids we found some names for:  37336
#
#  -->  BWBR0031986
# Citeer:               None
# Aanhaal:              None
# Extref refs to this:  3
#   distinct & count:   {'Verordening fonds sociale aangelegenheden vleeswarenindustrie (PVV) 2012': 2, 'Verordening fonds voor onderzoek en ontwikkeling vleeswarenindustrie (PVV) 2012': 1}
#   filtered:           {'Verordening fonds sociale aangelegenheden vleeswarenindustrie (PVV) 2012': 2, 'Verordening fonds voor onderzoek en ontwikkeling vleeswarenindustrie (PVV) 2012': 1}
#
#  -->  BWBR0005537
# Citeer:               ['Algemene wet bestuursrecht']
# Aanhaal:              ['Algemene wet bestuursrecht']
# Extref refs to this:  8392
#   filtered:           {'Participatiewet': 542, 'Wet werk en bijstand': 387, 'WWB': 80}

# %% [markdown]
# ## Collect references from CVDR
#
# The CVDR XML has `<dcterms:source>` elements in its header which are references made in the text
#
# There are such entries which signify something like "we know this is a reference but aren't certain what to", we ignore those.
# To see an example that contains both, see e.g. [CVDR100088/1](https://repository.officiele-overheidspublicaties.nl/CVDR/100088/1/xml/100088_1.xml).
#
#
# <!-- -->
#
# The XML documents in the CVDR repository have extref tags,
# but they are a little more varied than those in BWB due to what these documents practically do in a legal sense:
# these extrefs are more often references to _specific parts_ of laws.
#
# This require more cleanup of more human wording,
# but the amount of data should give cleaner preferences for the main name,
# and the type of its use should also give more idea of what laws are more commonly referenced.

# %%
# NOTE: going through 160K documents will take a few minutes - also why this is split from the next cells

## Go through CVDR XMLs and collect... 

cvdr_lastonly_xml = wetsuite.datasets.load('cvdr-mostrecent-xml')


cvdr_sref_data   = {} # xml_url it came from   ->   [(type, orig, specref, None, source_text), ...]    (see cvdr_sourcerefs's documentation)
cvdr_extref_data = {} # xml_url it came from   ->   [extrefnode, ...]    (see cvdr_sourcerefs's documentation)

for xml_url in list(cvdr_lastonly_xml.data):
    tree = cached_parse( cvdr_lastonly_xml.data, xml_url )
    meta = wetsuite.helpers.koop_parse.cvdr_meta(tree, flatten=True)

    ## ...collect the <dcterms:source> references,
    # use an existing function. Which returns a list of tuples, we'll deal with their content below
    srefs = wetsuite.helpers.koop_parse.cvdr_sourcerefs(tree, ignore_without_id=True)   
    if len(srefs)>0:
        cvdr_sref_data[ xml_url ] = srefs

    ## ...collect extref tagsfrom the document overall, since these are often referces to mostly laws and other CVDR articles.
    extrefs = list( tree.iter(tag='extref') )
    if len(extrefs)>0:
        cvdr_extref_data[ xml_url ] = extrefs

# %%
## process the sourceref part of what we just collected
cvdr_sourceref_names = collections.defaultdict(list) # BWB-id -> list of names used
count_ignoring       = collections.defaultdict(int)  # type -> amount we ignored

for xml_url, sourceref_list in cvdr_sref_data.items():
    for type, orig, bwbr, parts, spectext in sourceref_list:
        if type=='BWB':
            #print()
            #print([spectext, bwbr, parts])

            # The text may often be something like "artikel 5 can van de wet Bla" or "Artikel 5, wet Bla" and we want just Bla
            #   try to find the name by taking off specific bits of reference
            #   the references themselves are fairly clean to start with, so this works moderately well
            name = cleanup_basics( spectext )

            cvdr_sourceref_names[bwbr].append( name )

            if 0:
                # this is unrelated -- was trying to see which keys are used in the jci idetails,  because jci doesn't actually seem to define that
                # this next line is most of them
                for known in ('boek', 'hoofdstuk', 'titeldeel', 'afdeling','afd', 'artikel', 'lid', 'paragraaf', 'bijlage'):
                    if known in parts:
                        parts.pop( known )
                if 'g' in parts:
                    g = parts.pop('g')
                if len(parts)>0:
                    print('PARTSLEFT in %s: %s'%(xml_url, parts), [spectext, bwbr, parts])
        else:
            count_ignoring[type] += 1

count_ignoring
# Out:
# defaultdict(int, {'CVDR': 3878})

# %%
# warning: ~50k lines
#cvdr_sourceref_names

# %%
## and process the extref part
# The contents are a little more varied than in the above BWB case, so we need some more content cleanup code

_jcilike1 = re.compile('1.[0-9]+:[cv]:(BW[BRWVB0-9]+)') # something like '1.0:v:BWBR0005537' which seems like an abuse of jci
_jcilike2 = re.compile('1.[0-9]+:(CVDR[0-9_]+)')        # something like '1.1:CVDR215805_1' which seems like a bastardization of jci

cvdr_extrefs = []

# try to keep track of how many cases we're using, or ignoring for cleanliness's sake
count_ignored  = 0
count_matched  = 0
count_division = collections.defaultdict(int)

for xml_url, extrefs in cvdr_extref_data.items():
#for xml_url, extrefs in list(cvdr_extref_data.items())[:5000]:
    for extref in extrefs:
        if extref.text is None:
            continue

        matching = False
        ignoring = 0  # meaning not, 1 meaning tentatively, 2 meaning thoroughly

        value = extref.attrib.get('doc', None).strip()
        # that value is often an ID or URL
        #   in theory the 'struct' attribute tell us how to interpret the value, but it's not there much of the time, so we try not to rely on it
        
        #print( 'VALUE   %r '%value)
        if re.match(r'[\[\]01243456789\s]', extref.text): # numbered but nameless references like '[1]'
            ignoring = 2
            count_division['justnumber'] += 1

        if value is None:
            ignoring = 2
            count_division['none'] += 1

        else: # value is not None:
            name         = name_from_extref_tag( extref )                        # should give a cleaner answer, but answers None more easily
            name_fuzzier = name_from_extref_tag( extref, allow_fuzzier=True )    # used as a fallback if the previous is None
                                                                                 #   the code for that is in specific sections, because it can vary per extref type
                                                                                 #   though note that means each section can forget, so... don't.
            _jcilike1m = _jcilike1.match( value )
            _jcilike2m = _jcilike2.match( value )

            if value == '':
                ignoring = 2
                count_division['empty'] += 1
            elif value.startswith('about:blank'):   # riiiight.
                ignoring = 2
                count_division['empty'] += 1
            elif value.startswith('bookmark://'):   
                ignoring = 2  
                count_division['pointless'] += 1
            elif value.startswith('mk:@MSITStore'): # that's a local file   (IE, CHM stuff)
                ignoring = 2
                count_division['local'] += 1
            elif value.startswith('file://'):       # more local files
                ignoring = 2
                count_division['local'] += 1
            elif value.startswith('Xopus.asp'):     # that's an internal reference, apparently https://www.koopoverheid.nl/documenten/instructies/2017/10/24/gebruikershandleiding-xopus-xml-editor
                ignoring = 2
                count_division['local'] += 1
            elif value.startswith('mailto:'):
                ignoring = 2  
                count_division['pointless'] += 1

            elif value.startswith('/cvdr'): # probably to a served image or PDF or such
                ignoring = 2
                count_division['relative'] += 1

            elif value.startswith('#'): # probably a page anchor - maybe interesting actually?
                ignoring = 2  
                count_division['samepage'] += 1

            ## cases we can probably use:
            elif value.startswith('http://wetten.overheid.nl/cgi-bin/deeplink/'):
                # will look like
                #   http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Burgerlijk%20Wetboek%20Boek%201
                #   http://wetten.overheid.nl/cgi-bin/deeplink/law1/bwbid=BWBR0005537/article=1:2
                # Those are not query parameters, and I've not found the standard this might be following, so some estimation is involved here
                rest = value[value.index('law1/')+5:]

                if rest.startswith('title%3D'): # probably inconsistent escaping?
                    ignoring = 1
                    count_division['badesc'] += 1
                elif rest.startswith('bwbid%3D'):
                    ignoring = 1
                    count_division['badesc'] += 1

                elif rest.startswith('title='): # quite a few of these

                    bwbid = resolve_deeplink( value ) # does fetches, and caches them. First run will be slower
                    if bwbid is None:
                        ignoring = 1 # 2?
                        count_division['could not resolve deeplink'] += 1
                    else:

                        if name is None and name_fuzzier is None:  # this is copied deeper into the logic (a few times) because it's a less common reason to give up / fall back
                            name = name_fuzzier

                            count_division['uninteresting extref text?'] += 1
                            ignoring = 2 # maybe 1 to report, unless we're printing:
                            #print('SKIP uninteresting extref text (None or %r from %r)'%( name_fuzzier, extref.text) )
                        else:
                            name = name or name_fuzzier
                            
                            tt = cleanup_basics( name )

                            if '/' in rest:
                                count_division['detailed title deeplink'] += 1
                                matching = True
                                cvdr_extrefs.append( ['BWB-deeplink-title-detailed', bwbid, tt])
                                #print(['TEST1.1', bwbid, tt, name])
                                #raise ValueError( 'SKIP FOR NOW, specific reference   in  %r'%rest )
                            else:
                                count_division['basic title deeplink'] += 1
                                matching = True
                                #title = urllib.parse.unquote(rest[6:])
                                #print(['TEST1.2', bwbid, tt, name])
                                cvdr_extrefs.append( ['BWB-deeplink-title', bwbid, tt]) # fall back to the below style
                                # TODO: actually fetch these to see what identifier they end up on to

                elif rest.startswith('bwbid='):
                    if name is None and name_fuzzier is None:  # this is copied deeper into the logic (a few times) because it's a less common reason to give up / fall back
                        name = name_fuzzier

                        count_division['uninteresting extref text?'] += 1
                        ignoring = 2 # maybe 1 to report, unless we're printing:
                        #print('SKIP uninteresting extref text (None or %r from %r)'%( name_fuzzier, extref.text) )
                    else:
                        name = name or name_fuzzier

                        if '/' in rest:
                            tt = cleanup_basics( name )
                            bwbid = urllib.parse.unquote( rest[rest.index('=')+1:rest.index('/')] )
                            #print(['TEST2.1', bwbid, name])
                            
                            ignoring = 1 # TEMPORARILY 2
                            count_division['deeplink too detailed; TODO'] += 1
                            #raise ValueError( 'SKIP FOR NOW, specific reference   in  %r'%rest )
                        else:
                            matching = True
                            bwbid = urllib.parse.unquote(rest[6:])
                            #print(['TEST2.2', bwbid, name])
                            cvdr_extrefs.append( ['BWB-deeplink-bwbid', bwbid, name]) # fall back to the below style

                else:
                    raise ValueError( 'TODO: deal with  %r'%rest )


            elif value.startswith('http://wetten.overheid.nl/') or value.startswith('https://wetten.overheid.nl/'):
                # non-deeplinks; assume these will look something like
                #   http://wetten.overheid.nl/BWBR0012059/geldigheidsdatum_24-09-2008#Hoofdstuk4_Artikel37
                # or
                #   http://wetten.overheid.nl/jci1.3:c:BWBR0001941&amp;artikel=2&amp;z=2017-05-25&amp;g=2017-05-25
                count_division['wetten.overheid.nl'] += 1

                won_match1 = re.search('wetten.overheid.nl/(BW[^/]+)(?:[/]|$)', value)
                won_match2 = re.search('wetten.overheid.nl/jci[0-9.]+:[cv]:(BW[0-9A-Z]+)(?:[&]|$)', value) # seems we could use
                
                if won_match1 is not None:
                    if name is None and name_fuzzier is None:
                        ignoring = 1
                        name = name_fuzzier
                    else:
                        matching = True 
                        name = name or name_fuzzier
                        #print(['WON1', won_match1.group(1), name, value] )
                        cvdr_extrefs.append( ['won1', won_match1.group(1), name])

                elif won_match2 is not None:
                    if name is None and name_fuzzier is None:
                        ignoring = 1
                        name = name_fuzzier
                    else:
                        matching = True 
                        name = name or name_fuzzier
                        #print(['WON2', won2_match1.group(1), name, value] )
                        cvdr_extrefs.append( ['won2', won_match2.group(1), name])

                else:
                    ignoring = 1
                    #print(['NOWON', value ])


            # other http[s]:// is probably less meaningful.   A few may still be usef for other reasons, but we are currently not looking for them
            elif value.lower().startswith('http://') or value.lower().startswith('https://'):
                ignoring = 1  # was TEMPORARILY 2, while figuring out the deeplink stuff
                count_division['otherlink; CONSIDER'] += 1
                # eg. http://decentrale.regelgeving.overheid.nl/ might still be interesting, but most of these are less interesting
                #print( value)

            elif value.lower().startswith('www.'):
                ignoring = 1
                count_division['otherlink; MAYBE'] += 1
                # these all seem unineresting
                #print( value)

            else: # This maybe should just be part of the same if-elif chain above, because there is no longer a clean split of cases

                name = name_from_extref_tag( extref )
                if name is None:
                    ignoring = 2  # (don't print identifier part if we skip it for text reference reasons)
                    count_division['boringname?'] += 1
                    #print('SKIP, apparently boring name: %r'%extref.text)

                elif value.startswith('CVDR://'): # 'CVDR://97153_2'
                    matching = True
                    ref = wetsuite.helpers.koop_parse.cvdr_parse_identifier( value[7:] )
                    cvdr_extrefs.append( ['CVDRurl', ref, name])

                elif value.startswith('BWB://'): # e.g. 'BWB://1.0:v:BWBR0011468&artikel=76'
                    try:
                        ref = wetsuite.helpers.meta.parse_jci( value[6:] )
                        cvdr_extrefs.append( ['BWBurl', ref, name])
                        matching = True 
                    except Exception as e:
                        print([value, e])
                        ignoring = 1 

                elif _jcilike1m is not None:
                    matching = True 
                    cvdr_extrefs.append( ['jcilike-bwb', _jcilike1m.group(1), name])

                elif _jcilike2m is not None:
                    matching = True 
                    cvdr_extrefs.append( ['jcilike-cvdr', _jcilike2m.group(1), name])

        if matching:
            count_matched += 1
        elif ignoring:
            count_ignored += 1

        if 0:  # report things we didn't handle,  and/or  couldn't decide on
            say = ''
            if not matching  and  ignoring==0:
                say = 'DID NOT RECOGNIZE:  '
            elif ignoring == 1:
                say = 'IGNORING, MAYBE LATER: '

            if say:
                extref.tail = None            
                print( say, wetsuite.helpers.etree.tostring( extref ).decode('utf8') )
                #print( 'ATTRIB ', extref.attrib )
                #print( 'DOC    ', doc)

print("Ignored %d and took information from %d items"%( count_ignored, count_matched) )
pprint.pprint( count_division )
# Out:
# ['BWB://1.0:v:271829_1', ValueError("'1.0:v:271829_1' does not look like a valid jci")]
# Ignored 75910 and took information from 51455 items
# defaultdict(<class 'int'>,
#             {'badesc': 39,
#              'basic title deeplink': 10539,
#              'boringname?': 9497,
#              'could not resolve deeplink': 5881,
#              'deeplink too detailed; TODO': 300,
#              'detailed title deeplink': 18164,
#              'empty': 443,
#              'justnumber': 18709,
#              'local': 2092,
#              'otherlink; CONSIDER': 23802,
#              'otherlink; MAYBE': 464,
#              'pointless': 722,
#              'relative': 21459,
#              'samepage': 5121,
#              'uninteresting extref text?': 4452,
#              'wetten.overheid.nl': 9521})

# %%
# peek at deeplinks that got resolved, and how many do not
list( resolved.items() )[:200]
# Out:
# [('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=%20
),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene wet inzake rijksbelastingen/article=6',
#   'BWBR0002320'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene wet inzake rijksbelastingen/article=7',
#   'BWBR0002320'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene wet inzake rijksbelastingen/article=76',
#   'BWBR0002320'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene wet inzake rijksbelastingen/article=8',
#   'BWBR0002320'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20%20wet%20bestuursrecht',
#   'BWBR0005537'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Arbeidsongeschiktheidswet',
#   'None'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Bijstandswet%20',
#   'None'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Kinderbijslagwet/article=7',
#   'BWBR0002368'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Nabestaandenwet%20',
#   'BWBR0007795'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Ouderdomswet',
#   'BWBR0002221'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Ouderdomswet/article=1',
#   'BWBR0002221'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Ouderdomswet/article=10',
#   'BWBR0002221'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Ouderdomswet/article=18',
#   'BWBR0002221'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Ouderdomswet/article=29',
#   'BWBR0002221'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Ouderdomswet/article=45',
#   'BWBR0002221'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Ouderdomswet/article=48',
#   'BWBR0002221'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Ouderdomswet/article=7a',
#   'BWBR0002221'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Ouderdomswet/article=9',
#   'BWBR0002221'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Termijnenwet',
#   'BWBR0002448'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Termijnenwet%20',
#   'BWBR0002448'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Termijnenwet%20/article=3',
#   'BWBR0002448'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Termijnenwet/article=3',
#   'BWBR0002448'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Termijnenwet/article=3%20',
#   'BWBR0002448'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Weduwen-%20en%20Wezenwet',
#   'None'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Weduwen-%20en%20Wezenwet/article=20',
#   'None'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Weduwen-%20en%20Wezenwet/article=47',
#   'None'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Weduwen-%20en%20Wezenwet/article=8',
#   'None'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Weduwenen%20Wezenwet',
#   'None'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bestuursrecht',
#   'BWBR0005537'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bestuursrecht%20',
#   'BWBR0005537'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bestuursrecht/article=1%3A3',
#   'BWBR0005537'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bestuursrecht/article=4%3A1',
#   'BWBR0005537'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bestuursrecht/article=4%3A2',
#   'BWBR0005537'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bestuursrecht/article=4%3A25',
#   'BWBR0005537'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bestuursrecht/article=4%3A35',
#   'BWBR0005537'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bestuursrecht/article=4%3A36',
#   'BWBR0005537'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bestuursrecht/article=4%3A4',
#   'BWBR0005537'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bestuursrecht/article=4%3A76',
#   'BWBR0005537'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bestuursrecht/article=4%3A77',
#   'BWBR0005537'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bestuursrecht/article=6%3A20',
#   'BWBR0005537'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bijzondere%20Ziektekosten',
#   'None'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bijzondere%20Ziektekosten%20',
#   'None'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bijzondere%20Ziektekosten%20/article=5',
#   'None'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bijzondere%20Ziektekosten/article=1',
#   'None'),
#  ('http://wetten.overheid.nl/cgi-bin/deeplink/law1/title=Algemene%20Wet%20Bijzondere%20Ziektekosten/date=2014-12-31',
#   'None')]

# %% [markdown]
# ### Summarize what we got from CVDR

# %%
# source refs
print( '%d source references, to %d BWB-ids'%( 
    sum(  list( len(names)   for _, names in cvdr_sourceref_names.items() )  ),  
    len(  cvdr_sourceref_names  ) 
) )

print('\nThe most common:')
#   we take from a dict and put into a list so we can sort by count
sortable = []
for bwbid, names in cvdr_sourceref_names.items():
    #print()
    name_count = wetsuite.extras.word_cloud.count_normalized( names, min_word_length=1, stopwords=[], min_count=0.3 )
    sortable.append( (sum(name_count.values()), bwbid, name_count) )
sortable.sort(key=lambda x:x[0], reverse=True) # first column (count) descending
pprint.pprint(sortable[:30])
# Out:
# 147291 source references, to 723 BWB-ids
#
# The most common:
# [(58699, 'BWBR0005416', {'Gemeentewet': 58699}),
#  (15707, 'BWBR0005537', {'Algemene wet bestuursrecht': 15707}),
#  (5805, 'BWBR0015703', {'Participatiewet': 5805}),
#  (5472, 'BWBR0035362', {'Wet maatschappelijke ondersteuning 2015': 5472}),
#  (2621, 'BWBR0003245', {'Wet milieubeheer': 2621}),
#  (2496, 'BWBR0034925', {'Jeugdwet': 2496}),
#  (2404, 'BWBR0005212', {'Paspoortwet': 2404}),
#  (2183, 'BWBR0033715', {'Wet basisregistratie personen': 2183}),
#  (2099,
#   'BWBR0041522',
#   {'Rechtspositiebesluit decentrale politieke ambtsdragers': 2099}),
#  (1541, 'BWBR0027466', {'Wet veiligheidsregio’s': 1541}),
#  (1536, 'BWBR0024779', {'Wet algemene bepalingen omgevingsrecht': 1536}),
#  (1493, 'BWBR0005108', {'Waterschapswet': 1493}),
#  (1396, 'BWBR0035933', {'Wet op de bedrijveninvesteringszones': 1396}),
#  (1392, 'BWBR0035303', {'Huisvestingswet 2014': 1392}),
#  (1251,
#   'BWBR0004044',
#   {'Wet inkomensvoorziening oudere en gedeeltelijk arbeidsongeschikte werkloze werknemers': 1251}),
#  (1193,
#   'BWBR0004163',
#   {'Wet inkomensvoorziening oudere en gedeeltelijk arbeidsongeschikte gewezen zelfstandigen': 1193}),
#  (1167, 'BWBR0007376', {'Archiefwet 1995': 1167}),
#  (1146, 'BWBR0005645', {'Provinciewet': 1146}),
#  (1054, 'BWBR0003420', {'Wet op het primair onderwijs': 1054}),
#  (1002, 'BWBR0002458', {'Drank- en Horecawet': 1002}),
#  (843, 'BWBR0003740', {'Wet gemeenschappelijke regelingen': 843}),
#  (800, 'BWBR0004770', {'Invorderingswet 1990': 800}),
#  (797, 'BWBR0017017', {'Wet kinderopvang': 797}),
#  (709, 'BWBR0003549', {'Wet op de expertisecentra': 709}),
#  (705, 'BWBR0002320', {'Algemene wet inzake rijksbelastingen': 705}),
#  (696, 'BWBR0002399', {'Wet op het voortgezet onderwijs': 696}),
#  (666, 'BWBR0006622', {'Wegenverkeerswet 1994': 666}),
#  (582, 'BWBR0006493', {'Besluit burgerlijke stand 1994': 582}),
#  (555, 'BWBR0031331', {'Wet gemeentelijke schuldhulpverlening': 555}),
#  (510, 'BWBR0005181', {'Woningwet': 510})]

# %%
print(  'Extracted %d interesting extrefs  (~%d different names)'%(
    len(cvdr_extrefs),
    len( set(nm   for _,_,nm  in cvdr_extrefs))
)  )
# Out:
# Extracted 51455 interesting extrefs  (~6081 different names)

# %%
# Go through what the above collected, put it into a dict like the previous sections did
cvdr_extrefs_filtered = collections.defaultdict(list)   # BWB-id -> list of name strings


print( '%d extrefs'%( len( cvdr_extrefs ) ) )

for typ, ref, text in cvdr_extrefs[:2000]:
    if typ in ('CVDRurl','jcilike-cvdr'): # not currently interested in these references
        continue
    
    if text is None:
        print( 'SKIP ', typ, ref, text )
        continue

    elif typ == 'BWB-deeplink-title':           # ref is a bwbid
        cvdr_extrefs_filtered[ref].append( text )
#        print( ref, text )
        #print( typ, ref, text)
        #if bwbid is not None:
        #    #print( ref)
        #    #print( typ, ref, text )
        #    cvdr_extrefs_filtered[bwbid].append( text )
        #else:
        #    print("DID NOT RESOLVE %r"%ref)

    elif typ == 'BWB-deeplink-title-detailed':  # ref is a bwbid (hopefully)
        # this may need a little more inspection
        cvdr_extrefs_filtered[ref].append( text )

    elif typ == 'BWBurl':               # ref is a parsed dict
        bwbid = ref.get('bwb')
        cvdr_extrefs_filtered[bwbid].append( text )

    elif typ == 'jcilike-bwb':               # ref is a bwb id
        cvdr_extrefs_filtered[ref].append( text )

    elif typ in ('won1','won2'):
        cvdr_extrefs_filtered[ref].append( text )

    else:
        print( 'UNHANDLED TYPE %r (%r, %r)' %( typ, ref, text ) )
# Out:
# 51455 extrefs

# %%
cvdr_extrefs_filtered
# Out:
# defaultdict(list,
#             {'BWBR0005416': ['Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'artikelen 156, tweede lid, aanhef en onderdeel h',
#               'Gemeentewet',
#               'artikelen 231, tweede lid, onderdeel a, en derde lid',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'artikelen 149',
#               '216',
#               '225',
#               '233a',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               '84',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'zesde lid, Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'artikelen 225',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               '169, derde lid',
#               '180, derde lid',
#               'Gemeentewet',
#               'Gemeentewet',
#               'derde en vierde lid',
#               'tweede en derde lid',
#               'tweede en derde lid',
#               'Gemeentewet',
#               '149 van de Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               '44, tweede en derde lid',
#               '95 tot en met 99',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'eerste lid sub h, Gemeentewet',
#               'Gemeentewet',
#               '213',
#               '213a',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'artikelen 231, tweede lid, onderdeel a, en derde lid',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'artikelen 156, tweede lid, aanhef en onderdeel h',
#               'Gemeentewet',
#               'Gemeentewet',
#               '213',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'artikelen 156, eerste en tweede lid, aanhef en onderdeel h',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'artikelen 82',
#               '83',
#               '84',
#               '91 t/m 94',
#               '157',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet',
#               'Gemeentewet'],
#              'BWBR0005537': ['Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               '4:14',
#               '4:15 Awb',
#               'Awb',
#               'Awb',
#               'Awb',
#               'Awb',
#               'Awb',
#               'Awb',
#               'Awb',
#               'eerste lid, Awb',
#               'Awb',
#               'Awb',
#               'Awb',
#               'artikelen 4:104',
#               'artikelen 7:4',
#               '8:42 Awb',
#               'Awb',
#               'Awb',
#               'Awb',
#               'Awb',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'tweede lid Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene Wet Bestuursrecht (afdeling 3.4)',
#               'Algemene wet bestuursrecht',
#               'Algemene Wet Bestuursrecht, afdeling 3.4',
#               'Awb',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht (Awb)',
#               'Algemene wet bestuursrecht',
#               'Awb',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Awb',
#               'Awb',
#               'Algemene wet bestuursrecht',
#               '4.2 Awb',
#               'onderdeel a, Awb',
#               'tweede en derde lid, Awb',
#               'Het derde lid van artikel 4:46 Awb',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht (Awb)',
#               'Awb',
#               'Algemene Wet Bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Algemene wet bestuursrecht',
#               'Wet inburgering',
#               'Algemene wet bestuursrecht',
#               'Awb',
#               'Awb',
#               'Awb',
#               'Awb',
#               'Algemene wet bestuursrecht',
#               'Awb',
#               'Awb',
#               'Algemene wet bestuursrecht',
#               'Awb',
#               'Awb',
#               'Awb',
#               'Algemene wet bestuursrecht',
#               'Awb',
#               'Awb',
#               'Awb',
#               'Awb',
#               'Awb',
#               'Awb',
#               'Awb',
#               'Awb'],
#              'BWBR0020449': ['Wet ruimtelijke ordening',
#               'Wet ruimtelijke ordening',
#               'Wet ruimtelijke ordening',
#               'Wet ruimtelijke ordening',
#               'Wet ruimtelijke ordening',
#               'Wet ruimtelijke ordening',
#               'Wet ruimtelijke ordening',
#               'Wet ruimtelijke ordening',
#               'Wet ruimtelijke ordening',
#               'Wet ruimtelijke ordening (Wro)',
#               'Wro'],
#              'BWBR0005181': ['Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet',
#               'Woningwet'],
#              'BWBR0005291': ['Boek 3 BW',
#               'Boek 3 BW',
#               'Boek 3 BW',
#               'Boek 3 BW',
#               'Boek 3 BW',
#               'Boek 3 BW',
#               'BW',
#               'BW',
#               'BW',
#               'Boek 3 BW',
#               'Boek 3 BW'],
#              'BWBR0003245': ['Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'artikelen 10.21',
#               'Wet milieubeheer',
#               'artikelen 10.21',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'artikelen 10.21',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet Milieubeheer',
#               'Wet Milieubeheer',
#               'Wet Milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'artikelen 10.21',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'artikelen 10.21',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'derde lid',
#               'Wet milieubeheer',
#               'Wet milieubeheer',
#               'Wet Milieubeheer',
#               'Wm',
#               'Wet milieubeheer'],
#              'BWBR0006622': ['Wegenverkeerswet 1994',
#               'Wegenverkeerswet 1994',
#               'Wegenverkeerswet',
#               'Wegenverkeerswet',
#               'Wegenverkeerswet 1994',
#               'Wegenverkeerswet 1994',
#               'Wegenverkeerswet 1994',
#               'Wegenverkeerswet 1994',
#               'Wegenverkeerswet',
#               'Wegenverkeerswet',
#               'Wegenverkeerswet',
#               'Wegenverkeerswet 1994',
#               'Wegenverkeerswet 1994',
#               'Wegenverkeerswet 1994',
#               'Wegenverkeerswet 1994',
#               'artikelen 8',
#               '162, derde lid',
#               'Wegenverkeerswet 1994',
#               'Wegenverkeerswet',
#               'Wegenverkeerswet 1994',
#               'Wegenverkeerswet 1994',
#               'Wegenverkeerswet 1994',
#               'Wegenverkeerswet 1994',
#               'Wegenverkeerswet 1994'],
#              'BWBR0003994': ['Wet bodembescherming',
#               'Wet bodembescherming',
#               'Wet bodembescherming',
#               'Wet bodembescherming',
#               'eerste lid, van die Wet',
#               'Wet bodembescherming',
#               'eerste lid, van die Wet'],
#              'BWBR0022929': ['Besluit Bodemkwaliteit',
#               'Besluit bodemkwaliteit'],
#              'BWBR0013707': ['Besluit Beheer Autowrakken',
#               'Besluit beheer autowrakken'],
#              'BWBR0002063': ['onder 3º, Wet op de economische delicten',
#               'Wet op de economische delicten'],
#              'BWBR0023798': ['Besluit ruimtelijke ordening',
#               'onder c, Besluit ruimtelijke ordening',
#               'Besluit ruimtelijke ordening',
#               'Besluit ruimtelijke ordening (Bro)'],
#              'BWBR0001903': ['Wetboek van Strafvordering',
#               'Sv',
#               'Sv',
#               'Wetboek van Strafvordering',
#               'Wetboek van Strafvordering'],
#              'BWBR0002471': ['Wet op de loonbelasting 1964',
#               'Wet op de loonbelasting 1964',
#               'Wet op de loonbelasting 1964',
#               'Wet op de loonbelasting 1964',
#               'Wet op de loonbelasting 1964',
#               'Wet op de loonbelasting 1964',
#               'Wet op de loonbelasting 1964',
#               'Wet op de loonbelasting 1964'],
#              'BWBR0004627': ['Kieswet',
#               'artikelen X1, eerste en derde lid',
#               'X6',
#               'Kieswet',
#               'Kieswet',
#               'Kieswet',
#               'Kieswet',
#               'Kieswet'],
#              'BWBR0012059': ['Uitvoeringsregeling loonbelasting 2001',
#               'Uitvoeringsregeling loonbelasting 2001'],
#              'BWBR0004045': ['Werkloosheidswet',
#               'van die wet',
#               'Werkloosheidswet',
#               'Werkloosheidswet'],
#              'BWBR0007119': ['Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'artikelen 17',
#               '18',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'artikelen 17',
#               '18',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'artikelen 17',
#               '18',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'artikelen 17',
#               '18',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'artikelen 17',
#               '18',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet Waardering Onroerende Zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'Wet waardering onroerende zaken',
#               'artikelen 17',
#               '18',
#               'Wet waardering onroerende zaken'],
#              'BWBR0001947': ['Ambtenarenwet',
#               'Ambtenarenwet',
#               'derde lid, Ambtenarenwet'],
#              'BWBR0024779': ['Wet algemene bepalingen omgevingsrecht',
#               'onder a, sub 3',
#               'onder a, sub 2',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'artikelen 2.1',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'eerste lid',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'eerste lid, onderdeel a, Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht (Wabo)',
#               'Wabo',
#               'onder a onder 2 Wabo',
#               'Wet algemene bepalingen 6) omgevingsrecht',
#               'Wabo',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht',
#               'Wet algemene bepalingen omgevingsrecht'],
#              'BWBR0027464': ['Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'onderdeel 8, van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 8, van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 9, 16 en 18 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 18, sub a van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 18, sub b, c en d, van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 3, of artikel 3, onderdeel 1, van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 3, of artikel 3, onderdeel 1 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 8 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 8 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 15 en 17 van bijlage II bij het Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'onderdeel 3, of artikel 3, onderdeel 1, van bijlage II bij het Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'onderdeel 8 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 8 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 8 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 16 en 18 van bijlage II bij het Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'bijlage II',
#               'Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'onderdeel 7 van bijlage II bij het Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'onderdeel 9, 16 en 18 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 18, sub a van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 18, sub b, c en d, van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 3, of artikel 3, onderdeel 1 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 7 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 7 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 15 en 17 van bijlage II bij het Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'onderdeel 3, of artikel 3, onderdeel 1, van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 12 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 7 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 7 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 7 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 16 en 18 van bijlage II bij het Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'onderdeel 3, of artikel 3, onderdeel 1, van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 7, van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 7, van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 9, 16 en 18 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 18, sub a van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 18, sub b, c en d, van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 3, of artikel 3, onderdeel 1, van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 3, of artikel 3, onderdeel 1 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 7 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 7 van bijlage II bij het Besluit omgevingsrecht',
#               'artikel.2, onderdeel 15 en 17 van bijlage II bij het Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'onderdeel 3, of artikel 3, onderdeel 1, van bijlage II bij het Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'onderdeel 7 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 7 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 7 van bijlage II bij het Besluit omgevingsrecht',
#               'artikel.2, onderdeel 16 en 18 van bijlage II bij het Besluit omgevingsrecht',
#               'onderdeel 3, of artikel 3, onderdeel 1, van bijlage II bij het Besluit omgevingsrecht',
#               'Besluit omgevingsrecht',
#               'Besluit omgevingsrecht (Bor)',
#               'Bor',
#               'Bor',
#               'Bor',
#               'onder a bijlage II Bor',
#               'onder b bijlage II Bor',
#               'bijlage II Bor',
#               'bijlage II Bor',
#               'bijlage II Bor',
#               'bijlage II Bor',
#               'bijlage II Bor',
#               'bijlage II Bor',
#               'bijlage II Bor',
#               'Bor',
#               'Besluit omgevingsrecht'],
#              'BWBR0007376': ['artikelen 30, eerste lid',
#               '31',
#               'Archiefwet 1995',
#               'Archiefwet 1995',
#               'Archiefwet 1995',
#               'artikelen 30, eerste lid',
#               'Archiefwet 1995 in artikel 1, onder c',
#               'Archiefwet 1995',
#               'Archiefwet 1995',
#               'artikelen 30, eerste lid',
#               'Archiefwet 1995 in artikel 1, onder c',
#               'Archiefwet 1995',
#               'Archiefwet 1995',
#               'Archiefwet 1995',
#               'Archiefwet 1995',
#               'artikelen 30, eerste lid',
#               'Archiefwet 1995',
#               'Archiefwet 1995',
#               'Archiefwet 1995'],
#              'BWBR0007748': ['Archiefbesluit 1995',
#               'Archiefbesluit 1995',
#               'Archiefbesluit 1995',
#               'Archiefbesluit 1995',
#               'Archiefbesluit 1995'],
#              'BWBR0004770': ['Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'artikelen 10',
#               'artikelen 31',
#               'artikelen 10',
#               'artikelen 55',
#               'artikelen 58',
#               '59',
#               'artikelen 63',
#               'artikelen 63c',
#               '68',
#               'artikelen 10',
#               'artikelen 10',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'artikelen 29',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingwet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingwet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingwet 1990',
#               'Invorderingswet 1990',
#               'in Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'artikelen 29',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990',
#               'Invorderingswet 1990'],
#              'BWBR0004766': ['Uitvoeringsregeling Invorderingswet 1990',
#               'Uitvoeringsregeling Invorderingswet 1990',
#               'artikelen 19a',
#               'Uitvoeringsregeling Invorderingswet 1990',
#               'Uitvoeringsregeling Invorderingswet 1990',
#               'Uitvoeringsregeling Invorderingswet 1990',
#               'Uitvoeringsregeling Invorderingswet 1990',
#               'Uitvoeringsregeling Invorderingswet 1990'],
#              'BWBR0004825': ['Reglement Verkeersregels en Verkeerstekens 1990 (R.V.V.)',
#               'Reglement verkeersregels en verkeerstekens 1990',
#               'Reglement verkeersregels en verkeerstekens 1990',
#               'Reglement verkeersregels en verkeerstekens 1990',
#               'verkeersbord E4 of E8',
#               'Reglement verkeersregels en verkeerstekens',
#               'Reglement verkeersregels en verkeerstekens',
#               'Reglement verkeersregels en verkeerstekens',
#               'art.1 Reglement verkeersregels en verkeerstekens 1990',
#               'Reglement verkeersregels en verkeerstekens 1990',
#               'eerste lid, Reglement verkeersregels en verkeerstekens 1990',
#               'RVV 1990'],
#              'BWBR0004772': ['Uitvoeringsbesluit Invorderingswet 1990'],
#              'BWBR0015703': ['Wwb',
#               'Wet werk en bijstand',
#               'van die wet',
#               'Wwb',
#               'Wwb',
#               'Wet werk en bijstand',
#               'Wwb',
#               'Wet werk en bijstand',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               'Wet werk en bijstand',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               '36 WWB',
#               'Wet werk en bijstand',
#               'wet',
#               'eerste lid, aanhef en onderdelen b en i',
#               'Wet werk en bijstand',
#               'Wet werk en bijstand',
#               'tweede lid',
#               'Wwb',
#               'eerste lid',
#               'Wet Werk en Bijstand',
#               'Wet werk en bijstand',
#               'WWB',
#               'tweede lid, onder d WWB',
#               'Wet werk en bijstand',
#               'Wet werk en bijstand (Wwb)',
#               'Wet werk en bijstand',
#               'Wwb',
#               'onder a. van de',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               'Wet werk en bijstand',
#               'Wet werk en bijstand',
#               'Wwb',
#               'Wwb',
#               'WWB',
#               'Wet werk en bijstand',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'artikelen 7 lid 1, sub a',
#               '8 lid 1, sub a',
#               '10, lid 1 WWB',
#               'WWB',
#               'WWB',
#               'eerste lid WWB',
#               'Wet werk en bijstand',
#               'Wet werk en bijstand (Wwb)',
#               'Wet werk en bijstand (Wwb)',
#               'en 50 Wwb',
#               'sub d Wwb',
#               'Wwb',
#               'artikelen 32 en 33',
#               'Wwb',
#               'tweede lid Wwb',
#               'Wwb',
#               'Wwb',
#               'tweede lid',
#               'sub c Wwb',
#               'Wwb',
#               'Wet werk en bijstand',
#               'Wet werk en bijstand',
#               'Wet werk en bijstand (WWB)',
#               'eerste lid, onder e en f',
#               'WWB',
#               'Wet werk en bijstand (Wwb)',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               'vijfde lid Wwb',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               'Wwb',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'sub j WWB',
#               'WWB',
#               'WWB',
#               'sub j WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'sub j WWB',
#               'WWB',
#               'WWB',
#               'sub j WWB',
#               'WWB',
#               'onder j WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'onderdeel o WWB',
#               'Wet werk en bijstand',
#               'sub o WWB',
#               'WWB',
#               'WWB',
#               'sub o WWB',
#               'WWB',
#               'sub o WWB',
#               'WWB',
#               'Wet werk en bijstand',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'onderdeel m WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'onder a WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               '2 en 4 WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'onder c WWB',
#               'onder c WWB',
#               'onder c WWB',
#               'WWB',
#               'WWB',
#               'onder c WWB',
#               'WWB',
#               'onder c WWB',
#               'onder c WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'onder h WWB',
#               'WWB',
#               'sub b en lid 3 WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'sub b WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'Wet werk en bijstand',
#               'WWB',
#               'WWB',
#               'WWB',
#               'Wet werk en bijstand',
#               'WWB',
#               'Wet werk en bijstand',
#               'Wet werk en bijstand',
#               'Wet werk en bijstand',
#               'WWB',
#               'WWB',
#               'WWB',
#               'onder j WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'onder j WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'eerste lid WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'onder d WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB',
#               'WWB'],
#              'BWBR0002645': ['Kostenwet invordering rijksbelastingen',
#               'Kostenwet invordering rijksbelastingen',
#               'Kostenwet invordering rijksbelastingen',
#               'Kostenwet invordering rijksbelastingen'],
#              'BWBR0002656': ['BW',
#               'Burgerlijk Wetboek',
#               'Burgerlijk Wetboek',
#               'Burgerlijk Wetboek',
#               'Burgerlijk Wetboek',
#               'Burgerlijk Wetboek',
#               'Burgerlijk Wetboek',
#               'Burgerlijk Wetboek',
#               'Burgerlijk',
#               'Burgerlijk Wetboek',
#               'Burgerlijk Wetboek',
#               'Burgerlijk Wetboek',
#               'Burgerlijk Wetboek',
#               'Burgerlijk Wetboek',
#               'Burgerlijk Wetboek',
#               'artikelen 157',
#               '401 van dat boek',
#               'Burgerlijk Wetboek',
#               'BW'],
#              'BWBR0001827': ['derde lid Rv',
#               'derde lid',
#               'tweede lid, Rv',
#               'Rv',
#               'eerste lid, Rv',
#               'Rv',
#               'Rv',
#               'Rv',
#               'Rv',
#               'tweede lid, Rv',
#               'Rv',
#               'Rv',
#               'Rv',
#               'artikelen 481 en volgende Rv',
#               'derde lid, Rv',
#               'artikelen 475 en volgende Rv',
#               'Rv',
#               'artikelen 475b',
#               '475d Rv',
#               'en volgende Rv',
#               'Rv',
#               'Rv',
#               'artikelen 475b',
#               '475d Rv',
#               'artikelen 456',
#               '538 en volgende Rv',
#               'Rv',
#               'derde lid, Rv',
#               'derde lid, Rv',
#               'derde lid, Rv',
#               'Rv',
#               'derde lid, Rv',
#               'derde lid, Rv',
#               'Rv',
#               'artikelen 475c',
#               'Wetboek van Burgerlijke Rechtsvordering',
#               'artikelen 479b tot en met 479g',
#               'Wetboek van Burgerlijke Rechtsvordering',
#               'artikelen 475c',
#               'Wetboek van Burgerlijke Rechtsvordering',
#               'artikelen 479b tot en met 479g',
#               'Wetboek van Burgerlijke Rechtsvordering',
#               'Wetboek van Burgerlijke Rechtsvordering'],
#              'BWBR0002320': ['AWR',
#               'AWR',
#               'AWR',
#               'AWR',
#               'artikelen 6',
#               '7',
#               '13',
#               'Algemene wet inzake rijksbelastingen',
#               'Algemene wet inzake rijksbelastingen',
#               'Algemene wet inzake rijksbelastingen',
#               'Algemene wet inzake rijksbelastingen',
#               'AWR',
#               'AWR',
#               'AWR',
#               'Algemene wet inzake rijksbelastingen',
#               'artikelen 6, derde lid',
#               '13, eerste lid',
#               'Algemene wet inzake rijksbelastingen'],
#              'BWBR0001854': ['artikelen 179',
#               '180 Sr',
#               'Sr',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               '424',
#               '426bis',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'artikelen 137c tot en met 137g',
#               '140',
#               '240b',
#               '242 tot en met 249',
#               '252',
#               '250a (oud)',
#               '273a',
#               '300 tot en met 303',
#               '416',
#               '417',
#               '417bis',
#               '426',
#               '429quater',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'titels XIV',
#               'XVIII',
#               'XX',
#               'XXII',
#               'Tweede Boek van het Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht',
#               'Wetboek van Strafrecht'],
#              'BWBR0005289': ['BW', 'BW', 'BW'],
#              'BWBR0002761': ['BW'],
#              'BWBR0018472': ['Awir'],
#              'BWBR0001860': ['FW',
#               'artikelen 53 tot en met 56',
#               '234',
#               '235',
#               'FW',
#               'artikelen 138',
#               '252 FW',
#               'FW',
#               'tweede lid, FW',
#               'FW',
#               'FW',
#               'FW',
#               'tweede lid, onderdeel b, FW',
#               'FW',
#               'Faillissementswet',
#               'FW',
#               'Faillissementswet',
#               'sub e FW'],
#              'BWBR0011453': ['WSF 2000',
#               'Wet Studiefinanciering',
#               'Wet Studiefinanciering',
#               'Wet Studiefinanciering',
#               'Wet Studiefinanciering',
#               'Wet Studiefinanciering',
#               'Wet Studiefinanciering',
#               'Wet studiefinanciering 2000',
#               'WSF 2000',
#               'Wet studiefinanciering 2000',
#               'Wet studiefinanciering 2000',
#               'WSF',
#               'Wet Studiefinanciering',
#               'Wet Studiefinanciering',
#               'WSF 2000',
#               'WSF 2000'],
#              'BWBR0012438': ['Wet tegemoetkoming onderwijsbijdrage en schoolkosten',
#               'Wet tegemoetkoming onderwijsbijdrage en schoolkosten',
#               'WTOS',
#               'wet tegemoetkoming onderwijsbijdrage',
#               'Wet tegemoetkoming onderwijsbijdrage en schoolkosten (WTOS)'],
#              'BWBR0018451': ['Wet op de zorgtoeslag'],
#              'BWBR0007466': ['Besluit gegevensverstrekking gemeentelijke belastingheffing',
#               'Besluit gegevensverstrekking'],
#              'BWBR0004815': ['Wet op het consumentenkrediet'],
#              'BWBR0002448': ['Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'ATW',
#               'ATW',
#               'Algemene termijnenwet',
#               'ATW',
#               'ATW',
#               'Algemene termijnenwet',
#               'ATW',
#               'ATW',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene termijnenwet',
#               'Algemene Termijnenwet',
#               'Algemene termijnenwet',
#               'De Algemene termijnenwet',
#               'Algemene Termijnenwet',
#               'Algemene Termijnenwet',
#               'Algemene termijnenwet'],
#              'BWBR0005212': ['Paspoortwet', 'Paspoortwet', 'Paspoortwet'],
#              'BWBR0005699': ['Wet op het bevolkingsonderzoek',
#               'Wet op het bevolkingsonderzoek',
#               'Wet op het bevolkingsonderzoek',
#               'Wet op het bevolkingsonderzoek',
#               'Wet op het bevolkingsonderzoek',
#               'Wet op het bevolkingsonderzoek',
#               'Wet op het bevolkingsonderzoek',
#               'Wet op het bevolkingsonderzoek'],
#              'BWBR0018906': ['Wet toelating zorginstellingen',
#               'Wet toelating zorginstellingen',
#               'Wet toelating zorginstellingen',
#               'Wet Toelating Zorginstellingen',
#               'Wet toelating zorginstellingen'],
#              'BWBR0011823': ['Vreemdelingenwet 2000',
#               'letters c, d, f, g, h, van voornoemde wet',
#               'Vreemdelingenwet 2000',
#               'letters c, d, f, g, h, van voornoemde wet',
#               'Vreemdelingenwet',
#               'Vreemdelingenwet',
#               'Vreemdelingenwet',
#               'Vreemdelingenwet 2000',
#               'letters c, d, f, g, h, van voornoemde wet',
#               'Vreemdelingenwet 2000',
#               'letters c, d, f, g en h van voornoemde wet'],
#              'BWBR0020379': ['Besluit maatschappelijke ondersteuning',
#               'van toepassing zijnde Besluit Maatschappelijke Ondersteuning',
#               'Besluit Maatschappelijke Ondersteuning',
# ...
#               'Winkeltijdenwet',
#               'Winkeltijdenwet',
#               'artikel 3, eerste, tweede en derde lid, van de Winkeltijdenwet',
#               'Winkeltijdenwet',
#               'artikel 2, eerste lid, aanhef en onder a. van de Winkeltijdenwet',
#               'Winkeltijdenwet',
#               'Winkeltijdenwet',
#               'Winkeltijdenwet',
#               'Winkeltijdenwet',
#               'Winkeltijdenwet',
#               'Winkeltijdenwet',
#               'Winkeltijdenwet',
#               'Winkeltijdenwet',
#               'Winkeltijdenwet'],
#              'BWBR0001941': ['Opiumwet',
#               'Opiumwet',
#               'Opiumwet',
#               'artikelen 2',
#               'Opiumwet',
#               'Opiumwet',
#               'Opiumwet',
#               'lijst I',
#               'II',
#               'Opiumwet',
#               'Opiumwet',
#               'Opiumwet',
#               'Opiumwet',
#               'Opiumwet',
#               '13b Opiumwet',
#               'artikelen 2',
#               '3 Opiumwet',
#               'Opiumwet',
#               'Opiumwet',
#               'Opiumwet',
#               'Opiumwet'],
#              'BWBR0005381': ['algemene maatregel van bestuur'],
#              'BWBR0013360': ['Besluit van 22 januari 2002, houdende nieuwe regels met betrekking tot consumenten- en professioneel vuurwerk (Vuurwerkbesluit)',
#               'Vuurwerkbesluit'],
#              'BWBR0007149': ['Wet arbeid vreemdelingen',
#               'Wet arbeid vreemdelingen',
#               'Wet arbeid vreemdelingen'],
#              'BWBR0001980': ['artikelen 2', 'Wet op de weerkorpsen'],
#              'BWBR0008804': ['artikelen 54',
#               'Wet wapens en munitie',
#               'Wet wapens en munitie',
#               'Wet Wapens en Munitie'],
#              'BWBR0001840': ['Grondwet', 'Grondwet', 'Grondwet'],
#              'BWBR0022762': ['Besluit algemene regels voor inrichtingen milieubeheer',
#               'artikelen 2.17',
#               '2.19',
#               'artikelen 2.17',
#               '2.19',
#               'Besluit algemene regels voor inrichtingen milieubeheer'],
#              'BWBR0003227': ['Wet geluidhinder',
#               'Wet geluidhinder',
#               'Wet geluidhinder',
#               'Wet geluidhinder'],
#              'BWBR0002120': ['Zondagswet'],
#              'BWBR0023466': ['Wet basisregistraties adressen en gebouwen'],
#              'BWBR0004364': ['Scheepvaartverkeerswet'],
#              'BWBR0003628': ['Binnenvaartpolitiereglement',
#               'Binnenvaartpolitiereglement',
#               'Binnenvaartpolitiereglement',
#               'Binnenvaartpolitiereglement',
#               'Binnenvaartpolitiereglement'],
#              'BWBR0025458': ['Waterwet',
#               'Waterwet',
#               'Waterwet',
#               'Waterwet',
#               'Waterwet',
#               'Waterwet'],
#              'BWBR0007578': ['Besluit geluidproductie sportmotoren'],
#              'BWBR0005009': ['Wet op de lijkbezorging',
#               'Wet op de lijkbezorging',
#               'Wet op de lijkbezorging',
#               'Wet op de lijkbezorging',
#               'Wet op de Lijkbezorging'],
#              'BWBR0014194': ['Wet justitiële en strafvorderlijke gegevens',
#               'Wet justitiële en strafvorderlijke gegevens',
#               'Wet justitiële en strafvorderlijke gegevens',
#               'Wet justitiële en strafvorderlijke gegevens',
#               'Wet justitiële en strafvorderlijke gegevens'],
#              'BWBR0004044': ['Ioaw',
#               'Wet inkomensvoorziening oudere en gedeeltelijk arbeidsongeschikte werkloze werknemers',
#               'Wet inkomensvoorziening voor oudere- en gedeeltelijk arbeidsongeschikte werkloze werknemers',
#               'Wet inkomensvoorziening oudere en gedeeltelijk arbeidsongeschikte werkloze werknemers',
#               'IOAW',
#               'IOAW',
#               'IOAW',
#               'IOAW',
#               'IOAW',
#               'Ioaw',
#               'Wet inkomensvoorziening oudere en gedeeltelijk arbeidsongeschikte werkloze werknemers',
#               'Wet inkomensvoorziening oudere en gedeeltelijk arbeidsongeschikte werkloze werknemers',
#               'IOAW',
#               'eerste lid IOAW',
#               'IOAW',
#               'IOAW',
#               'IOAW',
#               'IOAW',
#               'eerste lid IOAW',
#               'Wet inkomensvoorziening oudere en gedeeltelijk arbeidsongeschikte werkloze werknemers',
#               'onder f Ioaw respectievelijk Ioaz',
#               'Ioaw/Ioaz',
#               'Wet inkomensvoorziening voor oudere- en gedeeltelijk arbeidsongeschikte werkloze werknemers (Ioaw)',
#               'Ioaw',
#               'IOAW',
#               'Ioaw/Ioaz',
#               'Ioaw/Ioaz',
#               'IOAW',
#               'IOAW en de IOAZ',
#               'Ioaw/Ioaz',
#               'IOAW',
#               'IOAW',
#               'IOAW',
#               'IOAW',
#               'IOAW',
#               'IOAW',
#               'Ioaw',
#               'Ioaw',
#               'Ioaw'],
#              'BWBR0004163': ['Ioaz',
#               'Wet inkomensvoorziening oudere en gedeeltelijk arbeidsongeschikte gewezen zelfstandigen',
#               'Wet inkomensvoorziening voor oudere en gedeeltelijk arbeidsongeschikte gewezen zelfstandigen',
#               'Wet inkomensvoorziening oudere en gedeeltelijk arbeidsongeschikte gewezen zelfstandigen',
#               'IOAZ',
#               'IOAZ',
#               'IOAZ',
#               'IOAZ',
#               'IOAZ',
#               'Ioaz',
#               'Wet inkomensvoorziening oudere en gedeeltelijk arbeidsongeschikte gewezen zelfstandigen',
#               'Wet inkomensvoorziening oudere en gedeeltelijk arbeidsongeschikte gewezen zelfstandigen',
#               'IOAZ',
#               'IOAZ',
#               'IOAZ',
#               'IOAZ',
#               'IOAZ',
#               'Wet inkomensvoorziening oudere en gedeeltelijk arbeidsongeschikte gewezen zelfstandigen',
#               'Wet inkomensvoorziening voor oudere en gedeeltelijk arbeidsongeschikte gewezen zelfstandigen (Ioaz)',
#               'Ioaz',
#               'IOAZ',
#               'IOAZ',
#               'IOAZ',
#               'IOAZ',
#               'IOAZ',
#               'IOAZ',
#               'IOAZ',
#               'IOAZ',
#               'Ioaz'],
#              'BWBR0020611': ['artikelen 8',
#               '23 derde lid',
#               'Wi',
#               'Wet inburgering',
#               'Wi',
#               'Wi',
#               'vierde lid, Wi',
#               'Wi',
#               'Wi',
#               'Wi',
#               'Wi',
#               'Wi'],
#              'BWBR0007625': ['WEB',
#               'Wet educatie en beroepsonderwijs',
#               'Wet educatie en beroepsonderwijs',
#               'Wet Educatie en Beroepsonderwijs',
#               'Wet educatie en beroepsonderwijs'],
#              'BWBR0025039': ['Wet Participatiebudget'],
#              'BWBR0008903': ['Wet sociale werkvoorziening',
#               'Wsw',
#               'Wsw',
#               'Wsw',
#               'Wet sociale werkvoorziening',
#               'Wet sociale werkvoorziening',
#               'Wsw',
#               'Wet sociale werkvoorziening',
#               'Wsw',
#               'Wet sociale werkvoorziening (Wsw)',
#               'WSW',
#               'Wet sociale werkvoorziening',
#               'Wet sociale werkvoorziening',
#               'Wet sociale werkvoorziening',
#               'Wet sociale werkvoorziening',
#               'Wet sociale werkvoorziening'],
#              'BWBR0002221': ['Algemene Ouderdomswet'],
#              'BWBR0002368': ['Algemene Kinderbijslagwet',
#               'Algemene Kinderbijslagwet'],
#              'BWBR0009083': ['Wet Inschakeling Werkzoekenden, zoals dit artikel luidde op 31 december 2003'],
#              'BWBR0010994': ['Besluit In- en Doorstroombanen, zoals dit artikel luidde op 31 december 2003',
#               'Besluit In- en Doorstroombanen, zoals dit artikel luidde op 31 december 2003'],
#              'BWBR0013060': ['Wet structuur uitvoeringsorganisatie werk en inkomen',
#               'wet Suwi',
#               'Wet structuur uitvoeringsorganisatie werk en inkomen',
#               'Wet Suwi',
#               'Wet Suwi',
#               'Wet Suwi',
#               'Wet structuur uitvoeringsorganisatie werk en inkomen',
#               'Wet Suwi'],
#              'BWBR0015711': ['Besluit bijstandsverlening zelfstandigen 2004',
#               'Bbz',
#               'Bbz',
#               'Bbz',
#               'Besluit bijstandverlening zelfstandigen 2004'],
#              'BWBR0003718': ['Wet algemene regels herindeling',
#               'Wet algemene regels herindeling'],
#              'BWBR0004912': ['Besluit gemeentelijke parkeerbelastingen'],
#              'BWBR0030530': ['Wet, houdende regeling van een grondslag voor de heffing van rechten voor de Nederlandse identiteitskaart'],
#              'BWBR0006493': ['Besluit burgerlijke stand 1994',
#               'Besluit burgerlijke stand 1994',
#               'Besluit burgerlijke stand 1994'],
#              'BWBR0033715': ['artikelen 3.8, eerste lid',
#               'Wet basisregistratie personen',
#               'Wet basisregistratie personen'],
#              'BWBR0003740': ['Wet gemeenschappelijke regelingen',
#               'Wet gemeenschappelijke regelingen'],
#              'BWBR0008657': ['Wet werk en arbeidsondersteuning jonggehandicapten',
#               'Wajong'],
#              'BWBR0013798': ['Wet bevordering integriteitsbeoordelingen door het openbaar bestuur',
#               'Wet bevordering integriteitsbeoordeling door het openbaar bestuur',
#               'wet BIBOB',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet bevordering integriteitsbeoordelingen door het openbaar bestuur',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob',
#               'Wet Bibob'],
#              'BWBR0032203': ['Aanbestedingswet 2012'],
#              'BWBR0009755': ['Elektriciteitswet 1998'],
#              'BWBR0019031': ['Uitvoeringsbesluit Meststoffenwet'],
#              'BWBR0013402': ['Wet ammoniak en veehouderij'],
#              'BWBR0020396': ['Wet geurhinder en veehouderij'],
#              'BWBR0013399': ['Reconstructiewet concentratiegebieden'],
#              'BWBR0007689': ['Besluit kennis en inzicht sociale hygiëne Drank- en Horecawet'],
#              'BWBR0011700': ['Besluit eisen inrichtingen Drank- en Horecawet'],
#              'BWBR0027431': ['Crisis- en herstelwet', 'Crisis- en herstelwet'],
#              'BWBR0037173': ['Wet kwaliteit, klachten en geschillen zorg',
#               'Wkkgz',
#               'Wet kwaliteit, klachten en geschillen zorg'],
#              'BWBR0014606': ['BBV',
#               'Besluit begroting en verantwoording provincies en gemeenten',
#               'Besluit begroting en verantwoording provincies en gemeenten'],
#              'BWBR0006723': ['wet GBA'],
#              'BWBR0007953': ['Vrijstellingenbesluit Winkeltijdenwet',
#               'Vrijstellingenbesluit Winkeltijdenwet',
#               'Vrijstellingenbesluit Winkeltijdenwet'],
#              'BWBR0007795': ['Algemene nabestaandenwet',
#               'Anw',
#               'Anw (Algemene nabestaandenwet)',
#               'Algemene Nabestaandenwet',
#               'Algemene Nabestaandenwet',
#               'Algemene Nabestaandenwet',
#               'Algemene Nabestaandenwet'],
#              'BWBR0005290': ['burgerlijk',
#               'Burgerlijk Wetboek van',
#               'Burgerlijk Wetboek',
#               'Burgerlijk Wetboek'],
#              'BWBR0018450': ['Zorgverzekeringswet',
#               'Zorgverzekeringswet',
#               'Zorgverzekeringswet',
#               'Zorgverzekeringswet',
#               'Zorgverzekeringswet',
#               'eerste lid Zorgverzekeringswet'],
#              'BWBR0025045': ['Wet stimulering arbeidsparticipatie (STAP)'],
#              'BWBR0011987': ['Wet Financiering Decentrale Overheden',
#               'Wet fido',
#               'Wet financiering decentrale overheden',
#               'Wet Fido',
#               'Wet Fido',
#               'Wet Fido'],
#              'BWBR0012076': ['Regeling uitzettingen en derivaten decentrale overheden',
#               'Regeling Uitzetting Decentrale Overheden',
#               'Regeling Uitzetting Decentrale Overheden'],
#              'BWBR0012075': ['Uitvoeringsregeling financiering decentrale overheden'],
#              'BWBR0021162': ['Wet op de Archeologische monumentenzorg'],
#              'BWBR0003420': ['Wet op het primair onderwijs',
#               'Wet op het primair onderwijs',
#               'Wet op het primair onderwijs',
#               'Wet op het basisonderwijs'],
#              'BWBR0003549': ['Wet op de expertisecentra',
#               'Wet op de expertisecentra',
#               'Wet op de expertisecentra',
#               'Wet op de expertisecentra'],
#              'BWBR0011470': ['Wet personenvervoer 2000'],
#              'BWBR0027431#Hoofdstuk2_Afdeling6_Artikel210': ['Crisis en herstelwet',
#               'Crisis- en'],
#              'BWBR0027956': ['wet Ontwikkelingskansen door Kwaliteit en Educatie',
#               'OKE',
#               'Wet OKE'],
#              'BWBR0001939': ['Natuurschoonwet 1928'],
#              'BWBR0002386': ['Wet gewetensbezwaren militaire dienst'],
#              'BWBR0019316': ['Asbestverwijderingsbesluit 2005',
#               'Asbestverwijderingsbesluit 2005',
#               'Asbestverwijderingsbesluit 2005',
#               'Asbestverwijderingsbesluit 2005'],
#              'BWBR0013546': ['Regeling Europese afvalstoffenlijst',
#               'Regeling Europese afvalstoffenlijst'],
#              'BWBR0006466': ['Wet op de stads- en dorpsvernieuwing'],
#              'BWBR0023913': ['Invoeringswet Wet ruimtelijke ordening'],
#              'BWBR0016876': ['Wet kenbaarheid publiekrechtelijke beperkingen onroerende zaken'],
#              'BWBR0002747': ['Wet op de ondernemingsraden (WOR), met name',
#               'Wet op de ondernemingsraden',
#               'Wet op de ondernemingsraden',
#               'Wet op de ondernemingsraden',
#               'Wet op de ondernemingsraden'],
#              'BWBR0004914': ['Rangschikkingsbesluit Natuurschoonwet 1928'],
#              'BWBR0011373': ['Speelautomaten besluit',
#               'Speelautomatenbesluit 2000'],
#              'BWBR0027466': ['Wet veiligheidsregio’s'],
#              'BWBR0010346': ['Arbeidsomstandighedenwet'],
#              'BWBR0002628': ['Leerplichtwet 1969',
#               'Leerplichtwet 1969',
#               'Leerplichtwet 1969',
#               'Leerplichtwet 1969'],
#              'BWBR0009612': ['wet Flexibiliteit en Zekerheid',
#               'wet Flexibiliteit en Zekerheid',
#               'Wet Flexibiliteit en Zekerheid',
#               'Wet Flexibiliteit en Zekerheid',
#               'wet Flexibiliteit en Zekerheid',
#               'wet Flexibiliteit en Zekerheid',
#               'Wet Flexibiliteit en Zekerheid',
#               'Wet Flexibiliteit en Zekerheid',
#               'wet Flexibiliteit en Zekerheid',
#               'wet Flexibiliteit en Zekerheid',
#               'Wet Flexibiliteit en Zekerheid',
#               'Wet Flexibiliteit en Zekerheid',
#               'wet Flexibiliteit en Zekerheid',
#               'wet Flexibiliteit en Zekerheid',
#               'Wet Flexibiliteit en Zekerheid',
#               'Wet Flexibiliteit en Zekerheid'],
#              'BWBR0018715': ['Regeling zorgverzekering'],
#              'BWBR0001888': ['ZW'],
#              'BWBR0002524': ['WAO'],
#              'BWBR0008656': ['Waz'],
#              'BWBR0006368': ['Wet op de rechtsbijstand'],
#              'BWBR0009730': ['Wet Schuldsanering natuurlijke personen',
#               'Wet Schuldsanering Natuurlijke Personen']})

# %%
sortable = []
for bwbid, names in cvdr_extrefs_filtered.items():
    #print(bwbid, names)
    name_count = wetsuite.extras.word_cloud.count_normalized( names, min_word_length=1, stopwords=[], min_count=0.3 )
    sortable.append( (sum(name_count.values()), bwbid, name_count) )
sortable.sort(key=lambda x:x[0], reverse=True)
pprint.pprint(sortable)
# Out:
# [(184, 'BWBR0005416', {'Gemeentewet': 184}),
#  (154, 'BWBR0015703', {'WWB': 116, 'Wwb': 38}),
#  (124, 'BWBR0005537', {'Algemene wet bestuursrecht': 88, 'Awb': 36}),
#  (68, 'BWBR0004770', {'Invorderingswet 1990': 68}),
#  (47,
#   'BWBR0027464',
#   {'Besluit omgevingsrecht': 22,
#    'bijlage II Bor': 7,
#    'onderdeel 3, of artikel 3, onderdeel 1, van bijlage II bij het Besluit omgevingsrecht': 7,
#    'onderdeel 7 van bijlage II bij het Besluit omgevingsrecht': 11}),
#  (42, 'BWBR0024779', {'Wet algemene bepalingen omgevingsrecht': 42}),
#  (39, 'BWBR0003245', {'Wet milieubeheer': 39}),
#  (34, 'BWBR0002448', {'Algemene termijnenwet': 34}),
#  (30, 'BWBR0007119', {'Wet waardering onroerende zaken': 30}),
#  (28,
#   'BWBR0017017',
#   {'Wet kinderopvang': 7,
#    'Wet kinderopvang en kwaliteitseisen peuterspeelzalen': 21}),
#  (25, 'BWBR0005181', {'Woningwet': 25}),
#  (25,
#   'BWBR0001827',
#   {'Rv': 14, 'Wetboek van Burgerlijke Rechtsvordering': 5, 'derde lid, Rv': 6}),
#  (24, 'BWBR0004044', {'IOAW': 18, 'Ioaw': 6}),
#  (22, 'BWBR0006622', {'Wegenverkeerswet': 6, 'Wegenverkeerswet 1994': 16}),
#  (20, 'BWBR0001854', {'Wetboek van Strafrecht': 20}),
#  (20, 'BWBR0013798', {'Wet Bibob': 20}),
#  (18, 'BWBR0004163', {'IOAZ': 18}),
#  (16, 'BWBR0007376', {'Archiefwet 1995': 12, 'artikelen 30, eerste lid': 4}),
#  (16,
#   'BWBR0009612',
#   {'Wet Flexibiliteit en Zekerheid': 8, 'wet Flexibiliteit en Zekerheid': 8}),
#  (15,
#   'BWBR0011453',
#   {'WSF 2000': 4,
#    'Wet Studiefinanciering': 8,
#    'Wet studiefinanciering 2000': 3}),
#  (15, 'BWBR0007952', {'Winkeltijdenwet': 15}),
#  (15, 'BWBR0001941', {'Opiumwet': 15}),
#  (14, 'BWBR0002656', {'Burgerlijk Wetboek': 14}),
#  (14, 'BWBR0027471', {'Regeling omgevingsrecht': 14}),
#  (14, 'BWBR0002469', {'Wet op de kansspelen': 14}),
#  (14, 'BWBR0008903', {'Wet sociale werkvoorziening': 9, 'Wsw': 5}),
#  (13, 'BWBR0002320', {'AWR': 7, 'Algemene wet inzake rijksbelastingen': 6}),
#  (11, 'BWBR0005291', {'BW': 3, 'Boek 3 BW': 8}),
#  (10,
#   'BWBR0011823',
#   {'Vreemdelingenwet': 3,
#    'Vreemdelingenwet 2000': 4,
#    'letters c, d, f, g, h, van voornoemde wet': 3}),
#  (9, 'BWBR0020449', {'Wet ruimtelijke ordening': 9}),
#  (9, 'BWBR0002458', {'Drank- en Horecawet': 9}),
#  (8, 'BWBR0002471', {'Wet op de loonbelasting 1964': 8}),
#  (8, 'BWBR0001860', {'FW': 8}),
#  (8, 'BWBR0005699', {'Wet op het bevolkingsonderzoek': 8}),
#  (8, 'BWBR0020611', {'Wi': 8}),
#  (7, 'BWBR0003994', {'Wet bodembescherming': 5, 'eerste lid, van die Wet': 2}),
#  (7, 'BWBR0004766', {'Uitvoeringsregeling Invorderingswet 1990': 7}),
#  (7,
#   'BWBR0004825',
#   {'Reglement verkeersregels en verkeerstekens': 3,
#    'Reglement verkeersregels en verkeerstekens 1990': 4}),
#  (7,
#   'BWBR0013060',
#   {'Wet Suwi': 4, 'Wet structuur uitvoeringsorganisatie werk en inkomen': 3}),
#  (6, 'BWBR0004627', {'Kieswet': 6}),
#  (6, 'BWBR0030461', {'Bouwbesluit': 4, 'Bouwbesluit 2012': 2}),
#  (6,
#   'BWBR0022762',
#   {'2.19': 2,
#    'Besluit algemene regels voor inrichtingen milieubeheer': 2,
#    'artikelen 2.17': 2}),
#  (6, 'BWBR0025458', {'Waterwet': 6}),
#  (6,
#   'BWBR0011987',
#   {'Wet Fido': 3,
#    'Wet Financiering Decentrale Overheden': 1,
#    'Wet fido': 1,
#    'Wet financiering decentrale overheden': 1}),
#  (5, 'BWBR0001903', {'Sv': 2, 'Wetboek van Strafvordering': 3}),
#  (5, 'BWBR0007748', {'Archiefbesluit 1995': 5}),
#  (5,
#   'BWBR0012438',
#   {'WTOS': 1,
#    'Wet tegemoetkoming onderwijsbijdrage en schoolkosten': 2,
#    'Wet tegemoetkoming onderwijsbijdrage en schoolkosten (WTOS)': 1,
#    'wet tegemoetkoming onderwijsbijdrage': 1}),
#  (5, 'BWBR0004318', {'Wet openbare manifestaties': 5}),
#  (5, 'BWBR0009950', {'Telecommunicatiewet': 5}),
#  (5, 'BWBR0003628', {'Binnenvaartpolitiereglement': 5}),
#  (5, 'BWBR0014194', {'Wet justitiële en strafvorderlijke gegevens': 5}),
#  (5,
#   'BWBR0007625',
#   {'WEB': 1,
#    'Wet Educatie en Beroepsonderwijs': 1,
#    'Wet educatie en beroepsonderwijs': 3}),
#  (5,
#   'BWBR0015711',
#   {'Bbz': 3,
#    'Besluit bijstandsverlening zelfstandigen 2004': 1,
#    'Besluit bijstandverlening zelfstandigen 2004': 1}),
#  (5, 'BWBR0018450', {'Zorgverzekeringswet': 5}),
#  (4,
#   'BWBR0023798',
#   {'Besluit ruimtelijke ordening': 2,
#    'Besluit ruimtelijke ordening (Bro)': 1,
#    'onder c, Besluit ruimtelijke ordening': 1}),
#  (4, 'BWBR0004045', {'Werkloosheidswet': 3, 'van die wet': 1}),
#  (4, 'BWBR0002645', {'Kostenwet invordering rijksbelastingen': 4}),
#  (4, 'BWBR0018906', {'Wet toelating zorginstellingen': 4}),
#  (4,
#   'BWBR0020379',
#   {'Besluit Maatschappelijke Ondersteuning': 2,
#    'Besluit maatschappelijke ondersteuning': 1,
#    'van toepassing zijnde Besluit Maatschappelijke Ondersteuning': 1}),
#  (4, 'BWBR0008331', {'Wet beheer rijkswaterstaatswerken': 4}),
#  (4,
#   'BWBR0008804',
#   {'Wet Wapens en Munitie': 1, 'Wet wapens en munitie': 2, 'artikelen 54': 1}),
#  (4, 'BWBR0003227', {'Wet geluidhinder': 4}),
#  (4, 'BWBR0005009', {'Wet op de lijkbezorging': 4}),
#  (4, 'BWBR0007795', {'Algemene Nabestaandenwet': 4}),
#  (4,
#   'BWBR0005290',
#   {'Burgerlijk Wetboek': 2, 'Burgerlijk Wetboek van': 1, 'burgerlijk': 1}),
#  (4,
#   'BWBR0003420',
#   {'Wet op het basisonderwijs': 1, 'Wet op het primair onderwijs': 3}),
#  (4, 'BWBR0003549', {'Wet op de expertisecentra': 4}),
#  (4, 'BWBR0019316', {'Asbestverwijderingsbesluit 2005': 4}),
#  (4, 'BWBR0002747', {'Wet op de ondernemingsraden': 4}),
#  (4, 'BWBR0002628', {'Leerplichtwet 1969': 4}),
#  (3, 'BWBR0001947', {'Ambtenarenwet': 2, 'derde lid, Ambtenarenwet': 1}),
#  (3, 'BWBR0005289', {'BW': 3}),
#  (3, 'BWBR0005212', {'Paspoortwet': 3}),
#  (3, 'BWBR0007149', {'Wet arbeid vreemdelingen': 3}),
#  (3, 'BWBR0001840', {'Grondwet': 3}),
#  (3, 'BWBR0006493', {'Besluit burgerlijke stand 1994': 3}),
#  (3,
#   'BWBR0033715',
#   {'Wet basisregistratie personen': 2, 'artikelen 3.8, eerste lid': 1}),
#  (3,
#   'BWBR0037173',
#   {'Wet kwaliteit, klachten en geschillen zorg': 2, 'Wkkgz': 1}),
#  (3,
#   'BWBR0014606',
#   {'BBV': 1, 'Besluit begroting en verantwoording provincies en gemeenten': 2}),
#  (3, 'BWBR0007953', {'Vrijstellingenbesluit Winkeltijdenwet': 3}),
#  (3,
#   'BWBR0012076',
#   {'Regeling Uitzetting Decentrale Overheden': 2,
#    'Regeling uitzettingen en derivaten decentrale overheden': 1}),
#  (3,
#   'BWBR0027956',
#   {'OKE': 1,
#    'Wet OKE': 1,
#    'wet Ontwikkelingskansen door Kwaliteit en Educatie': 1}),
#  (2, 'BWBR0022929', {'Besluit Bodemkwaliteit': 1, 'Besluit bodemkwaliteit': 1}),
#  (2,
#   'BWBR0013707',
#   {'Besluit Beheer Autowrakken': 1, 'Besluit beheer autowrakken': 1}),
#  (2,
#   'BWBR0002063',
#   {'Wet op de economische delicten': 1,
#    'onder 3º, Wet op de economische delicten': 1}),
#  (2, 'BWBR0012059', {'Uitvoeringsregeling loonbelasting 2001': 2}),
#  (2,
#   'BWBR0007466',
#   {'Besluit gegevensverstrekking': 1,
#    'Besluit gegevensverstrekking gemeentelijke belastingheffing': 1}),
#  (2,
#   'BWBR0013360',
#   {'Besluit van 22 januari 2002, houdende nieuwe regels met betrekking tot consumenten- en professioneel vuurwerk (Vuurwerkbesluit)': 1,
#    'Vuurwerkbesluit': 1}),
#  (2, 'BWBR0001980', {'Wet op de weerkorpsen': 1, 'artikelen 2': 1}),
#  (2, 'BWBR0002368', {'Algemene Kinderbijslagwet': 2}),
#  (2,
#   'BWBR0010994',
#   {'Besluit In- en Doorstroombanen, zoals dit artikel luidde op 31 december 2003': 2}),
#  (2, 'BWBR0003718', {'Wet algemene regels herindeling': 2}),
#  (2, 'BWBR0003740', {'Wet gemeenschappelijke regelingen': 2}),
#  (2,
#   'BWBR0008657',
#   {'Wajong': 1, 'Wet werk en arbeidsondersteuning jonggehandicapten': 1}),
#  (2, 'BWBR0027431', {'Crisis- en herstelwet': 2}),
#  (2,
#   'BWBR0027431#Hoofdstuk2_Afdeling6_Artikel210',
#   {'Crisis en herstelwet': 1, 'Crisis- en': 1}),
#  (2, 'BWBR0013546', {'Regeling Europese afvalstoffenlijst': 2}),
#  (2,
#   'BWBR0011373',
#   {'Speelautomaten besluit': 1, 'Speelautomatenbesluit 2000': 1}),
#  (2,
#   'BWBR0009730',
#   {'Wet Schuldsanering Natuurlijke Personen': 1,
#    'Wet Schuldsanering natuurlijke personen': 1}),
#  (1, 'BWBR0004772', {'Uitvoeringsbesluit Invorderingswet 1990': 1}),
#  (1, 'BWBR0002761', {'BW': 1}),
#  (1, 'BWBR0018472', {'Awir': 1}),
#  (1, 'BWBR0018451', {'Wet op de zorgtoeslag': 1}),
#  (1, 'BWBR0004815', {'Wet op het consumentenkrediet': 1}),
#  (1, 'BWBR0001867', {'Waterstaatswet 1900': 1}),
#  (1, 'BWBR0001842', {'Onteigeningswet': 1}),
#  (1, 'BWBR0001936', {'Belemmeringenwet Privaatrecht': 1}),
#  (1, 'BWBR0005381', {'algemene maatregel van bestuur': 1}),
#  (1, 'BWBR0002120', {'Zondagswet': 1}),
#  (1, 'BWBR0023466', {'Wet basisregistraties adressen en gebouwen': 1}),
#  (1, 'BWBR0004364', {'Scheepvaartverkeerswet': 1}),
#  (1, 'BWBR0007578', {'Besluit geluidproductie sportmotoren': 1}),
#  (1, 'BWBR0025039', {'Wet Participatiebudget': 1}),
#  (1, 'BWBR0002221', {'Algemene Ouderdomswet': 1}),
#  (1,
#   'BWBR0009083',
#   {'Wet Inschakeling Werkzoekenden, zoals dit artikel luidde op 31 december 2003': 1}),
#  (1, 'BWBR0004912', {'Besluit gemeentelijke parkeerbelastingen': 1}),
#  (1,
#   'BWBR0030530',
#   {'Wet, houdende regeling van een grondslag voor de heffing van rechten voor de Nederlandse identiteitskaart': 1}),
#  (1, 'BWBR0032203', {'Aanbestedingswet 2012': 1}),
#  (1, 'BWBR0009755', {'Elektriciteitswet 1998': 1}),
#  (1, 'BWBR0019031', {'Uitvoeringsbesluit Meststoffenwet': 1}),
#  (1, 'BWBR0013402', {'Wet ammoniak en veehouderij': 1}),
#  (1, 'BWBR0020396', {'Wet geurhinder en veehouderij': 1}),
#  (1, 'BWBR0013399', {'Reconstructiewet concentratiegebieden': 1}),
#  (1,
#   'BWBR0007689',
#   {'Besluit kennis en inzicht sociale hygiëne Drank- en Horecawet': 1}),
#  (1, 'BWBR0011700', {'Besluit eisen inrichtingen Drank- en Horecawet': 1}),
#  (1, 'BWBR0006723', {'wet GBA': 1}),
#  (1, 'BWBR0025045', {'Wet stimulering arbeidsparticipatie (STAP)': 1}),
#  (1,
#   'BWBR0012075',
#   {'Uitvoeringsregeling financiering decentrale overheden': 1}),
#  (1, 'BWBR0021162', {'Wet op de Archeologische monumentenzorg': 1}),
#  (1, 'BWBR0011470', {'Wet personenvervoer 2000': 1}),
#  (1, 'BWBR0001939', {'Natuurschoonwet 1928': 1}),
#  (1, 'BWBR0002386', {'Wet gewetensbezwaren militaire dienst': 1}),
#  (1, 'BWBR0006466', {'Wet op de stads- en dorpsvernieuwing': 1}),
#  (1, 'BWBR0023913', {'Invoeringswet Wet ruimtelijke ordening': 1}),
#  (1,
#   'BWBR0016876',
#   {'Wet kenbaarheid publiekrechtelijke beperkingen onroerende zaken': 1}),
#  (1, 'BWBR0004914', {'Rangschikkingsbesluit Natuurschoonwet 1928': 1}),
#  (1, 'BWBR0027466', {'Wet veiligheidsregio’s': 1}),
#  (1, 'BWBR0010346', {'Arbeidsomstandighedenwet': 1}),
#  (1, 'BWBR0018715', {'Regeling zorgverzekering': 1}),
#  (1, 'BWBR0001888', {'ZW': 1}),
#  (1, 'BWBR0002524', {'WAO': 1}),
#  (1, 'BWBR0008656', {'Waz': 1}),
#  (1, 'BWBR0006368', {'Wet op de rechtsbijstand': 1})]

# %% [markdown]
# ## Finally do something with all that data
#
# to review, we made
# * `bwb_names_citeertitel`,
# * `bwb_names_aanhaling`,
# * `bwb_names_extref`,
# * `cvdr_sourceref_names`,
# * `cvdr_extrefs_filtered`
#
# ...each a dict from BWB-id to a list of names used to refer to it

# %% [markdown]
# ### Report ambiguous names

# %%
conflict_data = collections.defaultdict(set) # name -> list of bwbids

for bwbid in bwb_names_citeertitel:
    for name in set( bwb_names_citeertitel[bwbid] ):
        #if len(name) > 5: # quick way to focus on abbreviations
        #    continue
        conflict_data[name].add(bwbid)

for bwbid in bwb_names_aanhaling:
    for name in set( bwb_names_aanhaling[bwbid] ):
        #if len(name) > 5:
        #    continue
        conflict_data[name].add(bwbid)

for bwbid in bwb_names_extref:
    for name in set( bwb_names_extref[bwbid] ):
        #if len(name) > 5:
        #    continue
        conflict_data[name].add(bwbid)

for bwbid in cvdr_extrefs_filtered:
    for name in set( cvdr_extrefs_filtered[bwbid] ):
        #if len(name) > 5:
        #    continue
        conflict_data[name].add(bwbid)

for name, bwbids in conflict_data.items():
    if len(bwbids)>1:
        print(" %r can refer to any of %r"%(name, sorted(bwbids)))

# A bunch of those seems to be mistakes. 
#   Probably one of the sections above lets through too much of a mess.
#   TODO: figure out where they are from (maybe have the structs carry through the origin XML?)
# Out:
#  'Wetboek van Burgerlijke Rechtsvordering' can refer to any of ['BWBR0001827', 'BWBR0039872']
#  'Wet op de rechterlijke organisatie' can refer to any of ['BWBR0001830', 'BWBR0002170']
#  'Wet algemene bepalingen' can refer to any of ['BWBR0001833', 'BWBR0024779']
#  'Grondwet' can refer to any of ['BWBR0001840', 'BWBR0027961']
#  'Wet op de Parlementaire Enquête' can refer to any of ['BWBR0001841', 'BWBR0023825']
#  'Wetboek van Strafrecht' can refer to any of ['BWBR0001854', 'BWBR0001903']
#  'Waterstaatswet 1900' can refer to any of ['BWBR0001867', 'BWBR0002505']
#  'Rijksoctrooiwet' can refer to any of ['BWBR0001879', 'BWBR0007118']
#  'Ziektewet' can refer to any of ['BWBR0001888', 'BWBR0001987', 'BWBR0002460', 'BWBR0002524']
#  'Veewet' can refer to any of ['BWBR0001900', 'BWBR0006727']
#  'Wetboek van Strafvordering' can refer to any of ['BWBR0001854', 'BWBR0001903', 'BWBR0001926', 'BWBR0019359', 'BWBR0028681']
#  'Opiumwet' can refer to any of ['BWBR0001941', 'BWBR0003060', 'BWBR0003063']
#  'Warenwet' can refer to any of ['BWBR0001969', 'BWBR0018370']
#  'Wet buitengewoon pensioen zeelieden-oorlogsslachtoffers' can refer to any of ['BWBR0002035', 'BWBR0002049']
#  'Garantiewet Burgerlijk Overheidspersoneel Indonesië' can refer to any of ['BWBR0002060', 'BWBR0002083']
#  'Wet op de economische delicten' can refer to any of ['BWBR0001903', 'BWBR0002063', 'BWBR0003549']
#  'Wet op de gevaarlijke werktuigen' can refer to any of ['BWBR0002087', 'BWBR0005884']
#  'ONTHEFFING VAN HET BEPAALDE IN ARTIKEL 6, EERSTE LID, VAN HET BUITENGEWOON BESLUIT ARBEIDSVERHOUDINGEN 1945' can refer to any of ['BWBR0002095', 'BWBR0002103']
#  'Wet bestuursrechtspraak bedrijfsorganisatie' can refer to any of ['BWBR0002144', 'BWBR0002170']
#  'Besluit bekostiging WEC' can refer to any of ['BWBR0003549', 'BWBR0003862', 'BWBR0004259', 'BWBR0046160']
#  'Aanwijzing havens' can refer to any of ['BWBR0004325', 'BWBR0004479']
#  'Scheepvaartverkeerswet' can refer to any of ['BWBR0002505', 'BWBR0004364']
#  'Postwet' can refer to any of ['BWBR0004423', 'BWBR0025572']
#  'Regeling ter verbetering van de vakbekwaamheid van in de landbouw werkzame personen' can refer to any of ['BWBR0004441', 'BWBR0007396']
#  'Kadasterwet' can refer to any of ['BWBR0004541', 'BWBR0043565']
#  'Uitvoering artikel 19 In- en uitvoerwet' can refer to any of ['BWBR0004546', 'BWBR0005302']
#  'Wet op de waterhuishouding' can refer to any of ['BWBR0002505', 'BWBR0004575', 'BWBR0004778']
#  'Wet administratiefrechtelijke handhaving verkeersvoorschriften' can refer to any of ['BWBR0001903', 'BWBR0004581']
#  'Kieswet' can refer to any of ['BWBR0004627', 'BWBR0004632']
#  'Verplaatsingskostenbesluit 1989' can refer to any of ['BWBR0004630', 'BWBR0004633', 'BWBR0005889']
#  'Kiesbesluit' can refer to any of ['BWBR0004627', 'BWBR0004632']
#  'Wet op de uitoefening van de diergeneeskunde 1990' can refer to any of ['BWBR0004730', 'BWBR0022416']
#  'Invorderingswet 1990' can refer to any of ['BWBR0001926', 'BWBR0004770', 'BWBR0012139']
#  'Besluit financiering uitvoeringsorganisatie Bijzondere Ziektekostenverzekering' can refer to any of ['BWBR0004783', 'BWBR0018059']
#  'Wet militair tuchtrecht' can refer to any of ['BWBR0004788', 'BWBR0039696']
#  'Wet militaire strafrechtspraak' can refer to any of ['BWBR0001869', 'BWBR0004789']
#  'Wet toezicht beleggingsinstellingen' can refer to any of ['BWBR0004809', 'BWBR0007477']
#  'Besteedbare middelen ter dekking van de kosten van verstrekkingen en vergoedingen ziekenfondsverzekering 1991' can refer to any of ['BWBR0004906', 'BWBR0005516']
#  'Rangschikkingsbesluit Natuurschoonwet 1928' can refer to any of ['BWBR0001939', 'BWBR0004914']
#  'Besluit ICPR' can refer to any of ['BWBR0004927', 'BWBR0007406']
#  'Wet assurantiebemiddelingsbedrijf' can refer to any of ['BWBR0004993', 'BWBR0028566']
#  'Wet op de lijkbezorging' can refer to any of ['BWBR0005009', 'BWBR0012410']
#  'Compensatieregeling vakonderwijs basisonderwijs' can refer to any of ['BWBR0005046', 'BWBR0005969']
#  'Woningwet' can refer to any of ['BWBR0002379', 'BWBR0003045', 'BWBR0005181', 'BWBR0005667', 'BWBR0008659', 'BWBR0009387', 'BWBR0012727']
#  'Besluit aanwijzing bijzondere medische verrichtingen' can refer to any of ['BWBR0005209', 'BWBR0022191']
#  'Wet openbaarheid van bestuur' can refer to any of ['BWBR0002698', 'BWBR0004815', 'BWBR0005252', 'BWBR0005461', 'BWBR0005523', 'BWBR0036083']
#  'Besluit zorgaanspraken bijzondere ziektekostenverzekering' can refer to any of ['BWBR0005283', 'BWBR0008946']
#  'Scheepvaartreglement voor het Kanaal van Gent naar Terneuzen' can refer to any of ['BWBR0005315', 'BWBR0007749']
#  'Besluit correctiefactoren runderen A' can refer to any of ['BWBR0011299', 'BWBR0024195']
#  'Postbesluit' can refer to any of ['BWBR0011334', 'BWBR0025577']
#  'Vergoedingenregeling leden Adviescollege toetsing administratieve lasten' can refer to any of ['BWBR0011337', 'BWBR0022603']
#  'Regeling financieel beheer ZorgOnderzoek Nederland' can refer to any of ['BWBR0011355', 'BWBR0037297']
#  'Wijzigingsbesluit Besluit hardheidsgevallen herstructurering varkenshouderij' can refer to any of ['BWBR0011384', 'BWBR0013988']
#  'Verordening beroeps- en gedragsregels' can refer to any of ['BWBR0011435', 'BWBR0030484']
#  'Wet bescherming persoonsgegevens' can refer to any of ['BWBR0002058', 'BWBR0011468', 'BWBR0012756', 'BWBR0028067']
#  'Wet personenvervoer 2000' can refer to any of ['BWBR0011470', 'BWBR0011982']
#  'Openstelling en subsidieplafond Stimuleringsregeling inrichting duurzame glastuinbouwgebieden' can refer to any of ['BWBR0011471', 'BWBR0013750']
#  'Vaststelling subsidieplafond Matra Projecten Programma' can refer to any of ['BWBR0011518', 'BWBR0013919']
#  'Uitvoeringsregeling Gaswet' can refer to any of ['BWBR0011555', 'BWBR0015468']
#  'Tijdelijke woonzorgstimuleringsregeling' can refer to any of ['BWBR0011624', 'BWBR0011625']
#  'Verordening representativiteit organisaties' can refer to any of ['BWBR0011641', 'BWBR0014995']
#  'Vreemdelingenwet 2000' can refer to any of ['BWBR0011823', 'BWBR0011825']
#  'HGIS-Cultuurprogramma 2000-2002' can refer to any of ['BWBR0011846', 'BWBR0012117']
#  'Instellingswet Raad voor strafrechtstoepassing en jeugdbescherming' can refer to any of ['BWBR0011940', 'BWBR0036510']
#  'Besluit personenvervoer 2000' can refer to any of ['BWBR0011470', 'BWBR0011982']
#  'Uitvoeringsregeling inkomstenbelasting 2001' can refer to any of ['BWBR0012031', 'BWBR0012066']
#  'Wet verplichte deelneming in een bedrijfstakpensioenfonds 2000' can refer to any of ['BWBR0012074', 'BWBR0012092']
#  'Besluit voorkoming dubbele belasting 2001' can refer to any of ['BWBR0012095', 'BWBR0013995']
#  'Controlevoorschriften Remigratiewet' can refer to any of ['BWBR0012125', 'BWBR0035265']
#  'Wijzigingsbesluit Besluit donorregister' can refer to any of ['BWBR0012217', 'BWBR0037840']
#  'Besluit aanvullende arbeidsongeschiktheids- en invaliditeitsvoorzieningen militairen' can refer to any of ['BWBR0006040', 'BWBR0012223']
#  'Besluit subsidie bewindvoerder schuldsanering' can refer to any of ['BWBR0012226', 'BWBR0033711']
#  'Besluit Stuurgroep Weesgeneesmiddelen' can refer to any of ['BWBR0012404', 'BWBR0018404']
#  'Besluit verantwoording stedelijke vernieuwing' can refer to any of ['BWBR0011821', 'BWBR0012490']
#  'Instellingsbesluit Monitorcomité ESF-EQUAL' can refer to any of ['BWBR0012491', 'BWBR0026614']
#  'Vaststelling bedrag bedoeld in artikel 7, eerste lid, onderdeel b, Kostenregeling Wet toezicht beleggingsinstellingen' can refer to any of ['BWBR0012521', 'BWBR0013721']
#  'Besluit van 15 januari 2011' can refer to any of ['BWBR0029486', 'BWBR0029487']
#  'Regeling eenmalig bedrag' can refer to any of ['BWBR0029752', 'BWBR0029920']
#  'Subsidieregeling VVN 2010' can refer to any of ['BWBR0028985', 'BWBR0029014']
#  'Regeling bezoldiging en beheerskosten bestuursorganen volksgezondheid 2011' can refer to any of ['BWBR0019253', 'BWBR0030162']
#  'aanwijzing transitiemodel' can refer to any of ['BWBR0030318', 'BWBR0030586']
#  'Stichting Nederlands Fonds voor de Film' can refer to any of ['BWBR0030064', 'BWBR0034481', 'BWBR0037025', 'BWBR0042761', 'BWBR0044731']
#  'Deelreglement Filmactiviteiten' can refer to any of ['BWBR0030647', 'BWBR0032475', 'BWBR0034453', 'BWBR0037219', 'BWBR0038767', 'BWBR0042003', 'BWBR0042761', 'BWBR0044640']
#  'Deelreglement Distributie' can refer to any of ['BWBR0030071', 'BWBR0032477', 'BWBR0036085', 'BWBR0038759', 'BWBR0041999', 'BWBR0044551', 'BWBR0047796']
#  'Aanwijzingen inzake externe contacten van rijksambtenaren' can refer to any of ['BWBR0031968', 'BWBR0044590']
#  'Verordening fonds voor onderzoek en ontwikkeling vleeswarenindustrie (PVV) 2012' can refer to any of ['BWBR0031985', 'BWBR0031986']
#  'Verordening fonds gezondheidszorg (PVV) 2012' can refer to any of ['BWBR0031979', 'BWBR0031980']
#  'Verordening fonds kwaliteitsverbetering (PVV) 2012' can refer to any of ['BWBR0031979', 'BWBR0031980', 'BWBR0031981']
#  'Bestuursreglement' can refer to any of ['BWBR0033149', 'BWBR0039246']
#  'bekendmakingsbesluit' can refer to any of ['BWBR0033305', 'BWBR0047936']
#  'Verordening op het bestuur 2012' can refer to any of ['BWBR0031872', 'BWBR0031875']
#  'spoorstaven van electrische spoor- en tramwegen' can refer to any of ['BWBR0001921', 'BWBR0001922']
#  'Verordening op de Raad voor Geschillen 2012' can refer to any of ['BWBR0031870', 'BWBR0031880']
#  'Staatssecretaris van Volksgezondheid, Welzijn en Sport van 15 december 2015, houdende de aanwijzing van zorgkantoren' can refer to any of ['BWBR0035987', 'BWBR0037424']
#  'zorgkantoren' can refer to any of ['BWBR0035987', 'BWBR0044616']
#  'Minister voor Buitenlandse Handel en Ontwikkelingssamenwerking van 13 juni 2014' can refer to any of ['BWBR0035227', 'BWBR0035228']
#  'Minister voor Buitenlandse Handel en Ontwikkelingssamenwerking van 3 juni 2015' can refer to any of ['BWBR0036675', 'BWBR0036676']
#  'Reglement Vervangingsfonds voor het Primair Onderwijs' can refer to any of ['BWBR0033449', 'BWBR0035144']
#  'huishoudelijk reglement van het Fonds' can refer to any of ['BWBR0032480', 'BWBR0044007']
#  'Koninkrijk 2013' can refer to any of ['BWBR0020401', 'BWBR0033883']
#  'Regeling gespecialiseerde GGZ' can refer to any of ['BWBR0034230', 'BWBR0036169']
#  'Regeling kostenverevening reductie CO' can refer to any of ['BWBR0030463', 'BWBR0036075']
#  'mandaatregeling kinderopvang' can refer to any of ['BWBR0019658', 'BWBR0035118']
#  'Besluit van 14 december 2010' can refer to any of ['BWBR0024299', 'BWBR0029172']
#  'Regeling mandaat- en machtiging NRGD' can refer to any of ['BWBR0036155', 'BWBR0038642']
#  'Reglement Stimuleringsmaatregel Filmproductie in Nederland' can refer to any of ['BWBR0035122', 'BWBR0041796', 'BWBR0044642', 'BWBR0047791']
#  'Reglement lid 1 sub g.)' can refer to any of ['BWBR0035122', 'BWBR0044642']
#  'gemeente Amsterdam 2014' can refer to any of ['BWBR0035345', 'BWBR0036208']
#  'Algemeen Reglement van het Mondriaan Fonds' can refer to any of ['BWBR0032717', 'BWBR0038798', 'BWBR0044527']
#  'rijksoverheid' can refer to any of ['BWBR0018553', 'BWBR0022054']
#  'Beleidsregels Buitengewoon opsporingsambtenaar' can refer to any of ['BWBR0036694', 'BWBR0038102', 'BWBR0039766']
#  'NIWO' can refer to any of ['BWBR0037047', 'BWBR0039057', 'BWBR0040349']
#  'inmiddels vervallen besluit van 12 februari 2013' can refer to any of ['BWBR0032700', 'BWBR0032924']
#  'Ministerie van Economische Zaken 2015' can refer to any of ['BWBR0036128', 'BWBR0036130', 'BWBR0036131', 'BWBR0036132', 'BWBR0036134', 'BWBR0036135', 'BWBR0036136', 'BWBR0036137', 'BWBR0036142', 'BWBR0036410', 'BWBR0036917']
#  'gemeente Amsterdam 2010' can refer to any of ['BWBR0029103', 'BWBR0029104', 'BWBR0029158']
#  'Stadsdeel Amsterdam-Noord van de gemeente Amsterdam 2011' can refer to any of ['BWBR0029519', 'BWBR0029809']
#  'BBV' can refer to any of ['BWBR0014606', 'BWBR0035711']
#  'Nadere voorschriften Controle- en overige standaarden' can refer to any of ['BWBR0036433', 'BWBR0042011', 'BWBR0044893']
#  'Wetboek van Burgerlijke Rechtsvordering en de Algemene wet bestuursrecht in verband met vereenvoudiging en digitalisering van het procesrecht' can refer to any of ['BWBR0038329', 'BWBR0038353']
#  'Bovengenoemde regeling' can refer to any of ['BWBR0036883', 'BWBR0038375']
#  'Besluit organisatie, mandaat, volmacht en machtiging Kansspelautoriteit' can refer to any of ['BWBR0036935', 'BWBR0038391', 'BWBR0042096']
#  'NV COS' can refer to any of ['BWBR0044893', 'BWBR0046309']
#  'NWO-subsidieregeling' can refer to any of ['BWBR0037253', 'BWBR0039531']
#  'Deelreglement Ontwikkeling' can refer to any of ['BWBR0038762', 'BWBR0042196', 'BWBR0044508']
#  'Interne klokkenluidersregeling' can refer to any of ['BWBR0038940', 'BWBR0040909']
#  'Algemeen Subsidiereglement' can refer to any of ['BWBR0039127', 'BWBR0045516']
#  'Besluit buitengewoon opsporingsambtenaar DCMR Milieudienst Rijnmond' can refer to any of ['BWBR0031854', 'BWBR0039378']
#  'regeling Uitvoeringsverslag en Financieel verslag Wlz-uitvoerder' can refer to any of ['BWBR0038964', 'BWBR0042144']
#  'bevoegdhedenregeling' can refer to any of ['BWBR0039247', 'BWBR0043094', 'BWBR0045229']
#  'Bevoegdhedenregeling' can refer to any of ['BWBR0039247', 'BWBR0043094']
#  'Ministerie van Economische Zaken 2016' can refer to any of ['BWBR0036143', 'BWBR0038518', 'BWBR0038603', 'BWBR0038633']
#  'Ministerie van Economische Zaken en Klimaat' can refer to any of ['BWBR0040201', 'BWBR0040903', 'BWBR0041776', 'BWBR0042703']
#  'Besluit buitengewoon opsporingsambtenaar Sportvisserij Oost-Nederland' can refer to any of ['BWBR0032946', 'BWBR0040537']
#  'directeur-generaal van het directoraat-generaal Rijksvoorlichtingsdienst' can refer to any of ['BWBR0030312', 'BWBR0040553']
#  'voorafgaande regeling' can refer to any of ['BWBR0039760', 'BWBR0040314', 'BWBR0041929']
#  'Besluit buitengewoon opsporingsambtenaar Nederlandse Kustwacht' can refer to any of ['BWBR0032971', 'BWBR0040693']
#  'Nadere regel ‘Verplichte aanlevering minimale dataset gespecialiseerde ggz' can refer to any of ['BWBR0038299', 'BWBR0041321']
#  'Normbedragenbesluit' can refer to any of ['BWBR0039152', 'BWBR0043119', 'BWBR0046180']
#  'Besluit mandaat, volmacht en machtiging Commissariaat voor de Media 2015' can refer to any of ['BWBR0036713', 'BWBR0036715']
#  'beleidsregel ‘Generalistische basis-ggz' can refer to any of ['BWBR0039717', 'BWBR0042489']
#  'Regeling declaratievoorschriften, administratievoorschriften en informatieverstrekking Wlz' can refer to any of ['BWBR0040314', 'BWBR0041929']
#  'Ministerie van Landbouw, Natuur en Voedselkwaliteit 2018' can refer to any of ['BWBR0041602', 'BWBR0041615']
#  'Deelreglement Realisering' can refer to any of ['BWBR0040559', 'BWBR0042190', 'BWBR0044509', 'BWBR0047792']
#  'Besluit normbedragen voorzieningen UWV' can refer to any of ['BWBR0042344', 'BWBR0043119', 'BWBR0046180']
#  'Ministerie van Economische Zaken en Klimaat 2019' can refer to any of ['BWBR0041845', 'BWBR0041849', 'BWBR0041889']
#  'Legal Status (Local Staff) Regulations 2020' can refer to any of ['BWBR0042874', 'BWBR0045662']
#  'gemeente ’s-Hertogenbosch, domein I' can refer to any of ['BWBR0036343', 'BWBR0043220']
#  'Minister voor Buitenlandse Handel en Ontwikkelingssamenwerking van 22 november 2019, nr. MINBUZA.2019.4593-20, tot vaststelling van beleidsregels voor subsidiëring op grond van de Subsidieregeling Ministerie van Buitenlandse Zaken 2006 (' can refer to any of ['BWBR0042838', 'BWBR0042839', 'BWBR0042842']
#  'regeling uitvoeringsverslag en financieel verslag' can refer to any of ['BWBR0043284', 'BWBR0046172']
#  'Regeling uitvoeringsverslag en financieel verslag' can refer to any of ['BWBR0043284', 'BWBR0046172']
#  'compensatieregeling' can refer to any of ['BWBR0043573', 'BWBR0044059']
#  'besluit van 6 mei 2020' can refer to any of ['BWBR0043492', 'BWBR0043672']
#  'Beleidsregel' can refer to any of ['BWBR0043439', 'BWBR0048145']
#  'provinciale organen, ontvangen of opgemaakt vanaf 1 januari 2014' can refer to any of ['BWBR0034675', 'BWBR0040372']
#  'commissaris van de Koning als rijksorgaan 2014' can refer to any of ['BWBR0034674', 'BWBR0040373']
#  'Inschrijvingsvoorwaarden Advocatuur 2021' can refer to any of ['BWBR0044503', 'BWBR0046016']
#  'Besluit van de Minister van Volksgezondheid, Welzijn en Sport van 28 mei 2021, kenmerk 2361911-1009138-WJZ, houdende aanpassing van het Besluit van de Minister van Volksgezondheid, Welzijn en Sport van 11 december 2020, kenmerk 1793063-215168-WJZ, houdende aanwijzing van ambtenaren voor de uitoefening van het toezicht op de naleving van hoofdstuk Va van de Wet publieke gezondheid in verband met de bestrijding van de epidemie van covid-19 (Stcrt. 2020, 66366) en het verlenen van mandaat aan de Inspectie Leefomgeving en Transport' can refer to any of ['BWBR0044481', 'BWBR0045182']
#  'Beleidsregel Prestaties en tarieven geestelijke gezondheidszorg en forensische zorg' can refer to any of ['BWBR0045810', 'BWBR0047033']
#  'Regeling declaratievoorschriften, administratievoorschriften en informatieverstrekking Wlz relevant 2021' can refer to any of ['BWBR0045403', 'BWBR0046390']
#  'Beleidsregel prestatiebeschrijvingen en tarieven zorgzwaartepakketten en volledig pakket thuis' can refer to any of ['BWBR0046135', 'BWBR0046734']
#  'Minister van Landbouw, Natuur en Voedselkwaliteit van 1 maart 2021' can refer to any of ['BWBR0044889', 'BWBR0044890']
#  'Beleidsregel huisartsenzorg en multidisciplinaire zorg' can refer to any of ['BWBR0046175', 'BWBR0047255']
#  'Minister van Volksgezondheid, Welzijn en Sport van 20 november 2012' can refer to any of ['BWBR0032297', 'BWBR0032308']
#  'KBvG' can refer to any of ['BWBR0031841', 'BWBR0041301']
#  'Minister van Landbouw, Natuur en Voedselkwaliteit van 24 februari 2022' can refer to any of ['BWBR0046411', 'BWBR0046412']
#  'artikelen 8' can refer to any of ['BWBR0006622', 'BWBR0020611']
#  'van die wet' can refer to any of ['BWBR0004045', 'BWBR0015703']
#  'eerste lid' can refer to any of ['BWBR0015703', 'BWBR0024779']
#  'artikelen 6' can refer to any of ['BWBR0002320', 'BWBR0017017']
#  '13' can refer to any of ['BWBR0002320', 'BWBR0002469']
#  'artikelen 2' can refer to any of ['BWBR0001941', 'BWBR0001980']

# %% [markdown]
# ### Merge all useful bits

# %%
merged_data = [] # data for a name-searching webpage: 
# list of   [BWBR, [self names], [other names] ]

merged_ids = set()
merged_ids.update( bwb_names_citeertitel )
merged_ids.update( bwb_names_aanhaling )
merged_ids.update( bwb_names_extref )

for bwbid in sorted(merged_ids, reverse=True):
    self_names  = []
    other_names = []
    
    if bwbid in bwb_names_citeertitel:
        for name in bwb_names_citeertitel[bwbid]:
            if name not in self_names:
                self_names.append( name )

    if bwbid in bwb_names_aanhaling:
        for name in bwb_names_aanhaling[bwbid]:
            if name not in self_names:
                self_names.append( name )

    if bwbid in cvdr_sourceref_names:
        for name in cvdr_sourceref_names[bwbid]:
            if name not in other_names:
                other_names.append( name )


    # the next two are messier sources, so we try to be stricter about what we take from it

    if bwbid in bwb_names_extref:
        name_count = wetsuite.extras.word_cloud.count_normalized( bwb_names_extref[bwbid], normalize_func=lambda s:s.lower(), min_word_length=1, stopwords=[], min_count=0.001 )
        for name, count in name_count.items():
            #if count >= 3:
            #print('ADD   %-12s  %4s   %r' %( bwbid, count, name ))
            if name not in self_names and name not in other_names:
                other_names.append(name)

    if bwbid in cvdr_extrefs_filtered:
        name_count = wetsuite.extras.word_cloud.count_normalized( cvdr_extrefs_filtered[bwbid], normalize_func=lambda s:s.lower(), min_word_length=1, stopwords=[], min_count=0.001 )
        for name, count in name_count.items():
            #if count >= 3:
            #print('ADD   %-12s  %4s   %r' %( bwbid, count, name ))
            if name not in self_names and name not in other_names:
                other_names.append(name)


    merged_data.append([ bwbid, self_names, other_names ] )

# %%
# some examples as sanity check
pprint.pprint( random.sample( merged_data, 7 ) )
#pprint.pprint( merged_data )
# Out:
# [['BWBR0022833',
#   ['Besluit adviescommissie restitutieverzoeken cultuurgoederen en Tweede '
#    'Wereldoorlog'],
#   ['Besluit adviescommissie restitutieverzoeken en cultuurgoederen en Tweede '
#    'Wereldoorlog',
#    'artikel 4, tweede lid, van dat besluit']],
#  ['BWBR0017054', ['VWS-intrekkingsregeling dor hout 2004'], []],
#  ['BWBR0019874', ['Circulaire Besluit beheer sociale-huursector mei 2006'], []],
#  ['BWBR0026157', ['Instellingsbesluit Rathenau Instituut'], []],
#  ['BWBR0041118',
#   ['Regeling zintuiglijk gehandicaptenzorg'],
#   ['Regeling Zintuiglijk gehandicaptenzorg']],
#  ['BWBR0039622',
#   ['Wijzigingsbesluit instelling Autoriteit Nucleaire Veiligheid en '
#    'Stralingsbescherming'],
#   []],
#  ['BWBR0032753',
#   ['Prestatiebeschrijvingsbeschikking (DM type 2, VRM, COPD) 2013'],
#   []]]

# %%
from importlib import reload
reload( wetsuite.helpers.localdata )

wet_store = wetsuite.helpers.localdata.open_store('wetnamen.db', key_type=str, value_type=None, inst=wetsuite.helpers.localdata.MsgpackKV)
wet_store._put_meta('valtype','msgpack')
wet_store._put_meta('description','''
This dataset tries to give the varied names for each law.
                    

This is a map from BWB-ID to two lists:
- the name the law has for itself
- the varied names other things use for it

The collection is currently a bit dirty.
''')

for bwbid, self_names, other_names in merged_data:
     wet_store.put( key=bwbid, value=[self_names, other_names], commit=False )
wet_store.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/www/coding/wetsuite/notebooks/extras_datacollect_wetnamen.ipynb Cell 35 line <cell line: 17>()
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras_datacollect_wetnamen.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> wet_store._put_meta('valtype','msgpack')
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras_datacollect_wetnamen.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> wet_store._put_meta('description','''
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras_datacollect_wetnamen.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> This dataset tries to give the varied names for each law.
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras_datacollect_wetnamen.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras_datacollect_wetnamen.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> The collection is currently a bit dirty.
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras_datacollect_wetnamen.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> ''')
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras_datacollect_wetnamen.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> for bwbid, self_names, other_names in merged_data:
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras_datacollect_wetnamen.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>      wet_store.put( key=bwbid, value=[self_names, other_names], commit=False )
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras_datacollect_wetnamen.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> wet_store.commit()
#
# NameError: name 'merged_data' is not defined
