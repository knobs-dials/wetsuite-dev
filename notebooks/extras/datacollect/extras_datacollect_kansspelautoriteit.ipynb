# %% [markdown]
# <a href="https://colab.research.google.com/github/knobs-dials/wetsuite-dev/blob/main/notebooks/extras/datacollect/extras_datacollect_kansspelautoriteit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Purpose of this notebook
#
# Collect data from contents PDFs under https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/
#
# We are not aware of any API, so are currently collecting information based on scraping web pages.

# %% [markdown]
# NOTE: This is how a dataset was created.
# In the process we will give an example of extracting data from a website, reorganizing that data and, as it turns out, of applying OCR out of necessity.
#
# If you only care about how to _use_ that dataset, see [using_dataset_kansspelautoriteit.ipynb](../using_dataset_kansspelautoriteit.ipynb) instead.
#
# If you _do_ want to read this code, e.g. to get a start at doing your own OCR processing, read on...
# (note also that this code relies on poppler (for PDF parsing) and easyOCR (for OCR), neither of which are quite trivial installs)

# %% [markdown]
# ### Preparation
# imports we will use, and some helper functions.

# %%
#imports
import hashlib, urllib, json, json, pprint, textwrap, re, pprint, random

import bs4, numpy

import wetsuite.helpers.localdata
import wetsuite.helpers.meta
import wetsuite.helpers.net
import wetsuite.helpers.format
import wetsuite.helpers.strings
import wetsuite.helpers.date
import wetsuite.extras.pdf
import wetsuite.extras.ocr


# helpers we'll use later
def hash(data: bytes):
    ' calculate SHA1 hash of some data. '
    s1h = hashlib.sha1()
    s1h.update( data )
    return s1h.hexdigest()


def find_eur_money(s:str, minimum=0):
    ''' Given a string, returns a list of substrings that look like money amounts, e.g.
            find_eur_money('   EUR 10,-  ')       == ['10']
            find_eur_money('   EUR 10.    ')      == ['10']
            find_eur_money('   EUR100.000,-')     == ['100000']
            find_eur_money('   EUR100000  ')      == ['100000']
            find_eur_money('   \u20ac100.000')    == ['100000']   # but not commas, because Dutch uses that as a digit.  That should probably be configurable
            find_eur_money('   \u20ac 100000')    == ['100000']
            find_eur_money('   \u20ac 100000  ')  == ['100000']
        (where \u20ac is the euro symbol's unicode codepoint, expressed how python takes it)
    '''
    ret = []
    # the with-text-context was partially for debug, but might actually be useful to return
    for before, match_str, match_object, after in wetsuite.helpers.strings.findall_with_context(r"(?:EUR|\u20ac)\s*([0-9.]+)\b", s, 20):
        cap = match_object.groups()[0].replace('.','')
        try:
            if int(cap) < minimum:
                continue
        except ValueError as ve: # not parseable as number? Remove
            pass
        #print( '[%s]%s[%s] -> %r'%(before, match_str, after, cap) )
        ret.append(cap)
    return ret

# %% [markdown]
# ### Fetching the data

# %%
# Use a local store so that we only need to fetch the PDFs once, only render PDF pages once 
import wetsuite.helpers.localdata
pdfstore   = wetsuite.helpers.localdata.LocalKV('kansspel_pdfstore.db', key_type=str, value_type=bytes )     # URL -> PDF file bytestring
ocrstore   = wetsuite.helpers.localdata.LocalKV('kansspel_ocrstore.db', key_type=str, value_type=bytes )     # page-specific key -> json as bytes

# %% [markdown]
# #### Fetching case summaries
#
# What we have is a website we can look at.
# What we want is metadata and text per case.
#
# Let's first scrape the webpage to figure out all cases, all documents that relate to each case
#
# These fetches aren't cached, because the amount of cases will change, and case details can change as they progress.

# %%
# The purpose of this section is to fill the following variable:
extracted_cases = []  # list of (casename, [list of document dicts], [same-sized list of ocr results])

maxpage  = 9999999  # will be set to the actual number of pages by the first (well, every) page we fetch
cur_page = 0        # zero-based counting in the pagination

print( "FETCHING CASE SUMMARIES" )
while cur_page <= maxpage:
    page_url = 'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=%d'%cur_page
    print( page_url )
                
    page_data = wetsuite.helpers.net.download(page_url)
    soup = bs4.BeautifulSoup( page_data, 'lxml' )

    # get the amount of pages, from the pagination links
    pagelinks = soup.select('a[class~="pager_step"][class~="pagina"]')   # CSS selector looking for both of those classes set in a whitespace-token list
    maxpage = int( pagelinks[-1].get('data-page') )                      # -1: last of those we see on the page

    print( "page %d of %d"%( cur_page+1, maxpage+1 ) ) # numbering is zero-based,  print out one-based for humans

    # fetch all links to specific case detail pages
    for detail_page_a in soup.select('#results a[class~="siteLink"]'): # pick out the links (URLs) of the detail page of each case
        detail_page_url = detail_page_a.get('href') # these are already absolute  (otherwise we'd have to urljoin them)
        case_name = detail_page_a.text.replace('/','_')
        case_dict = {
            'name':case_name,
            'date_range':[],
            'money':[],
            'ecli':[],
            'case_detail_url':detail_page_url,
        }

        print()
        print( '  Case: %r'%(case_name) )

        # Note: the date shown here and on the detail page may be the start date?   It may still useful to distinguish cases for repeat offenders




        ### fetch that case's detail page, and find all PDF links on it ##########################################################
        detail_page_data = wetsuite.helpers.net.download( detail_page_url )
        detail_soup = bs4.BeautifulSoup( detail_page_data, 'lxml' )

        # This section used to be three lines long, 
        #   until we decided that hey, maybe that status would be nice to have.
        #   then we discovered this is a free-form mess
        #   and this is the hand-crafted combination of of exception cases that will probably break in the future.


        #print( detail_page_url )
        
        ## Construct a list of dicts, one for each document,  with keys 'title', 'status', and 'pdf_url'
        doc_dicts = [] #  will be that list of dicts
        cur       = {} # 'currently collecting into this' dict 

        def check_add_clear():
            global doc_dicts, cur
            ''' if there's sensible content, we add it to our list of docs.
                clears cur for next document
            '''
            # if effectively empty, do nothing at all
            if len(cur.keys())==1  and  'title' in cur  and  cur['title']=='': # effectively empty. Also one of a handful of exception cases
                pass
            elif len(cur)>0: # effectively empty
                # fail if it's incomplete, so that I fix it   (or accept it as an edge case)
                if 'title' not in cur:
                    print('SKIP: scraping code is missing title, cur=%r'%cur)
                
                # temporarily removed, the case that triggers this is fixable
                elif 'pdf_url' not in cur:
                    print( 'SKIP: scraping code is missing pdf_url, cur=%r'%cur)
                
                #if 'status' not in cur:
                #    raise ValueError('scraping code is missing status, cur=%r'%cur) that happens, see e.g. https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/n1-interactive/ or https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/1x-corp-exinvest/
                
                #print("ADD %r"%cur)
                else:
                    doc_dicts.append(cur)
            cur = {}


        # this whole part used to be short, and readable(ish), but the pages are a bit messy so it ended up with a lot of exception cases.
        pdflinks = list( detail_soup.select('a[class~="importLink"][class~="pdf"]') )   # (now) used only to find the content block that contains these

        # (and things like select('div[class~="grid-blok"] div[class~="grid-element"] div[class~="grid-inside"] div[class~="iprox-content"]') is not specific enough, that's a general template
        if len(pdflinks)==0:
            print("WARNING - no content?")
        else:
            # We expect a sequence of one or more of: 
            # - h2              (title)
            # - p with a inside (link)
            # - h2-or-h3        (the header saubg "status")
            # - p               (the actual status text)            

            # ...but I've seen an initial paragraph in front of it. 
            # ...and a header and a paragraph in front of it.
            child = pdflinks[0].parent.previous_element # try to position on the first document's title header. Parent would be the p
            while child.name is None and child.previous_sibling is not None: # find previous non-text node.   ...there must be a better way of doing this.
                child = child.previous_sibling
            #print( 'Chosen starting spot: ', child )

            while child is not None:
                #print( child )
                if child.name: # filter out text nodes (iirc)
                    pdflinks = list( child.select('a[class~="importLink"][class~="pdf"]') )
                    has_pdflinks = len(pdflinks) > 0
                    alltext = (''.join(child.findAll(text=True))).strip().lower().strip(':')

                    # augmenting some things we find
                    case_dict['money'].extend( find_eur_money(alltext, minimum=5001) )
                    case_dict['ecli'].extend( wetsuite.helpers.meta.findall_ecli(alltext, rstrip_dot=True) )

                    #print( "LOOKING AT %r"% str(child).strip() )
                    if child.name in ('h2','h3'):
                        if has_pdflinks: # weird case in https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/vriendenloterij/
                            cur['pdf_url'] = urllib.parse.urljoin( detail_page_url, pdflinks[0].get('href') )   # make relative URLs absolute
                            if 'title' not in cur: # would be overwritten in almost all cases
                                cur['title'] = alltext # but helps deal with https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/1x-corp-exinvest/
                        else:
                            if alltext == 'status': # header that just says 'status'
                                #print('HEADER - "status"')
                                pass 
                            else: # probably a title
                                #print('HEADER - title?')
                                check_add_clear() # starts a new one, so:
                                cur['title'] = child.text
                    elif child.name == 'p':
                        if len(cur)==0: # dict empty?
                            pass # probably an initial paragraph
                        else:
                            if has_pdflinks: #elif 'pdf_url' not in cur:
                                #print('FIRST P - PDF URL')
                                cur['pdf_url'] = urllib.parse.urljoin( detail_page_url, pdflinks[0].get('href') )   # make relative URLs absolute
                            else: #elif 'pdf_url' in cur: # status text
                                #print('SECOND P - STATUS TEXT')
                                cur['status'] = child.text
                child = child.next_sibling
            check_add_clear()

    
            #
            #pprint.pprint( doc_dicts )
            print( '    # documents: %d'%len(doc_dicts) )


        extracted_cases.append( (case_dict, doc_dicts, []) )
        #break  #  during debug: stop after first case on page

    cur_page += 1
    #break  #  during debug: stop after first page
# Out:
# FETCHING CASE SUMMARIES
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=0
# page 1 of 7
#
#   Case: 'Hillside New Media Malta Plc'
#     # documents: 4
#
#   Case: 'Betent B.V.'
#     # documents: 1
#
#   Case: 'Cloudflare'
#     # documents: 2
#
#   Case: 'Cloudflare'
#     # documents: 2
#
#   Case: 'Holland Casino'
#     # documents: 4
#
#   Case: 'Betent'
#     # documents: 5
#
#   Case: 'Bingoal Nederland B.V.'
#     # documents: 5
#
#   Case: 'Vriendenloterij N.V.'
# SKIP: scraping code is missing pdf_url, cur={'title': '30 mei 2023'}
#     # documents: 4
#
#   Case: 'Nationale Postcode Loterij N.V.'
# SKIP: scraping code is missing pdf_url, cur={'title': '30 mei 2023'}
#     # documents: 4
#
#   Case: 'GoldWin Limited'
#     # documents: 2
#
#   Case: 'MKC Limited'
#     # documents: 2
#
#   Case: 'Blue High House S.A.'
#     # documents: 2
#
#   Case: 'L.C.S Limited'
#     # documents: 4
#
#   Case: 'JOI Gaming Ltd'
#     # documents: 5
#
#   Case: 'Play North Limited'
# SKIP: scraping code is missing pdf_url, cur={'title': 'Openbaarmakingsbesluit Play North', 'status': 'Tegen dit besluit kan bezwaar worden gemaakt.'}
#     # documents: 2
#
#   Case: 'Betent'
# SKIP: scraping code is missing pdf_url, cur={'title': 'Openbaarmakingsbesluit\xa0Betent', 'status': 'Tegen dit besluit kan bezwaar worden gemaakt.'}
#     # documents: 2
#
#   Case: 'NetX Betting'
#     # documents: 2
#
#   Case: 'GoldWin Ltd'
#     # documents: 2
#
#   Case: 'Merkur Casino Almere B.V.'
#     # documents: 2
#
#   Case: 'Winning Poker Network'
#     # documents: 2
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=1
# page 2 of 7
#
#   Case: 'Red Ridge Marketing'
#     # documents: 2
#
#   Case: 'Probe Investments Limited'
#     # documents: 5
#
#   Case: 'Betpoint Group Limited'
#     # documents: 2
#
#   Case: 'N1 Interactive Limited'
#     # documents: 5
#
#   Case: 'Videoslots Limited'
#     # documents: 2
#
#   Case: 'Fairload Limited'
#     # documents: 5
#
#   Case: 'Equinox Dynamic N.V. & Domiseda and Partners s.r.o.'
#     # documents: 5
#
#   Case: 'Bingoal Nederland B.V.'
#     # documents: 4
#
#   Case: 'Shark77.Ltd'
#     # documents: 5
#
#   Case: 'Holland Casino N.V.'
#     # documents: 6
#
#   Case: 'Toto Online B.V.'
#     # documents: 0
#
#   Case: 'Nationale Postcode Loterij N.V.'
#     # documents: 2
#
#   Case: 'M.K.C Limited'
#     # documents: 2
#
#   Case: 'Gammix Limited'
#     # documents: 4
#
#   Case: 'Red Ridge Marketing'
#     # documents: 4
#
#   Case: 'Performing Media Limited'
#     # documents: 2
#
#   Case: 'Linkerik B.V.'
#     # documents: 4
#
#   Case: 'Onlinecasinobonus.nl'
#     # documents: 2
#
#   Case: 'LCB CORP'
#     # documents: 2
#
#   Case: 'Casinoscout.nl'
#     # documents: 2
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=2
# page 3 of 7
#
#   Case: 'Slots Dev'
#     # documents: 2
#
#   Case: 'Online Casino Ground ltd'
#     # documents: 2
#
#   Case: 'Tipico Co. Ltd'
#     # documents: 2
#
#   Case: 'BSB Shop'
#     # documents: 2
#
#   Case: 'Luxury Bingo'
#     # documents: 2
#
#   Case: 'N1 Interactive Limited'
#     # documents: 5
#
#   Case: 'Staatsloterij B.V.'
#     # documents: 4
#
#   Case: 'Raging Rhino N.V.'
#     # documents: 2
#
#   Case: 'Lovelto Mar LTD'
#     # documents: 4
#
#   Case: '1X Corp N.V._Exinvest Limited'
#     # documents: 4
#
#   Case: 'WL Deal'
#     # documents: 2
#
#   Case: 'Virtual Coin Gaming N.V.'
#     # documents: 6
#
#   Case: 'Clipboard Publications B.V.'
#     # documents: 2
#
#   Case: 'Kelner Automaten Service'
#     # documents: 0
#
#   Case: 'Schinveld BV'
#     # documents: 5
#
#   Case: 'Voormalig exploitant Dordrecht'
#     # documents: 2
#
#   Case: 'Voormalig exploitant Amersfoort'
#     # documents: 2
#
#   Case: 'Royal Panda Limited'
#     # documents: 5
#
#   Case: 'LeoVegas Gaming p.l.c.'
#     # documents: 4
#
#   Case: 'Pokerstars'
#     # documents: 5
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=3
# page 4 of 7
#
#   Case: 'Chance Publications Malta Ltd'
#     # documents: 3
#
#   Case: 'Unibet'
#     # documents: 2
#
#   Case: 'Bwin'
#     # documents: 5
#
#   Case: 'Simbat Entertainment Systems en Spinity'
#     # documents: 7
#
#   Case: 'Com Coin Operated Machines'
#     # documents: 2
#
#   Case: 'Casumo'
#     # documents: 5
#
#   Case: 'Innovation Labs en Gaming Innovation Group'
#     # documents: 6
#
#   Case: 'Content Publishing Limited'
#     # documents: 5
#
#   Case: 'Exploiteren zonder vergunning in café'
#     # documents: 4
#
#   Case: 'WHG (International) Limited'
#     # documents: 5
#
#   Case: 'Voormalig exploitant Abcoude'
#     # documents: 2
#
#   Case: 'CyberRock Entertainment N.V. en Honeydew Trading Limited.'
#     # documents: 6
#
#   Case: 'Mr Green Limited'
#     # documents: 4
#
#   Case: 'ITC Lounge Plaza'
#     # documents: 2
#
#   Case: 'Corona Limited'
#     # documents: 4
#
#   Case: 'Café restaurant De Kruik'
#     # documents: 2
#
#   Case: 'Bet-at-home'
#     # documents: 4
#
#   Case: 'Visionairy iGaming'
#     # documents: 4
#
#   Case: 'VriendenLoterij N.V.'
#     # documents: 8
#
#   Case: 'BankGiro Loterij N.V.'
#     # documents: 8
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=4
# page 5 of 7
#
#   Case: 'Nationale Postcode Loterij N.V.'
#     # documents: 10
#
#   Case: 'Lotto B.V.'
#     # documents: 12
#
#   Case: 'Staatsloterij B.V.'
#     # documents: 8
#
#   Case: 'Holland Casino N.V.'
#     # documents: 4
#
#   Case: 'Catena Operations Limited'
#     # documents: 2
#
#   Case: 'Weddenopvoetbal.org'
#     # documents: 4
#
#   Case: 'JvG speelautomaten'
#     # documents: 2
#
#   Case: 'Trustfulgames.com Limited'
#     # documents: 7
#
#   Case: 'L.S.A. B.V'
#     # documents: 4
#
#   Case: 'M-automaten exploitatie'
#     # documents: 2
#
#   Case: 'Wedwinkel Rotterdam'
#     # documents: 2
#
#   Case: 'Friese ondernemer'
#     # documents: 1
#
#   Case: 'Holland Gaming'
#     # documents: 2
#
#   Case: 'Olders Amusementsautomaten B.V.'
#     # documents: 1
#
#   Case: 'Duitse loterijen'
#     # documents: 2
#
#   Case: 'Dolle Pret in Almelo B.V.'
#     # documents: 2
#
#   Case: 'Redslots'
#     # documents: 4
#
#   Case: 'Café _ Bar Bağci'
#     # documents: 4
#
#   Case: 'Total E Soft Limited en XKL Limited'
#     # documents: 4
#
#   Case: 'Belhuis _ Internetcafé Ephesus'
#     # documents: 2
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=5
# page 6 of 7
#
#   Case: 'V.O.F. AULON'
#     # documents: 2
#
#   Case: 'V.O.F. Bosma Amusement'
#     # documents: 2
#
#   Case: 'Stichting Sport Twente'
#     # documents: 4
#
#   Case: 'Thee- en koffiehuis Kayseri'
#     # documents: 4
#
#   Case: 'Eetcafé De Gouw'
#     # documents: 4
#
#   Case: 'Co Gaming Limited (voorheen Come On Europe Limited)'
#     # documents: 4
#
#   Case: 'Stichting Trefcentrum Brinkstraat'
#     # documents: 4
#
#   Case: 'Imperial E-club Limited'
#     # documents: 4
#
#   Case: 'Stichting Bil Kazan'
#     # documents: 4
#
#   Case: '7Red.com'
# WARNING - no content?
#
#   Case: 'Villa Mountain View'
#     # documents: 4
#
#   Case: 'GT Beheersorganisatie'
#     # documents: 2
#
#   Case: 'Koffiehuis Vadi'
#     # documents: 2
#
#   Case: 'Gooische Bingo Show'
#     # documents: 2
#
#   Case: 'Globalstars'
#     # documents: 4
#
#   Case: 'Grand Café Randenbroek'
#     # documents: 4
#
#   Case: 'Onisac Limited en Mansion Online Casino Limited'
#     # documents: 9
#
#   Case: 'Café Lucky'
#     # documents: 4
#
#   Case: 'Star SAT Electronica'
#     # documents: 2
#
#   Case: 'Call Internet City'
#     # documents: 4
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=6
# page 7 of 6
#
#   Case: 'Huizenloterij'
#     # documents: 4

# %%
# Each case is currently an incomplete structure,  like  (case_dict, doc_dicts, will_explain_below):
extracted_cases[0]
# Out:
# ({'name': 'Hillside New Media Malta Plc',
#   'date_range': [],
#   'money': [],
#   'ecli': [],
#   'case_detail_url': 'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/hillside-new-media-malta-plc/'},
#  [{'title': 'Beslissing op bezwaar Hillside',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15402_01-304-549_beslissing_op_bezwaar.pdf',
#    'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep worden ingesteld bij de rechtbank.'},
#   {'title': 'Advies BAC\xa0Hillside',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15402_bac_advies_hillside.pdf'},
#   {'title': 'Openbaarmakingsbesluit Hillside',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15402_01-304-539_openbaarmakingsbesluit_woo_bob.pdf',
#    'status': 'Tegen dit openbaarmakingsbesluit kan bezwaar worden gemaakt.'},
#   {'title': 'Sanctiebesluit Hillside',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15402_01-285-941_besluit-signed_openbare_versie.pdf'}],
#  [])

# %% [markdown]
# ### Fetch the PDFs, OCR them
#
# What we have is the basic fetched metadata and links to the PDF.
# What we want is the documents as well.
#
# In the below, we do two or three tasks that could be separated: 'fetch PDFs' and 'renders page and OCRs then'.
# We could separate these and that might be preferable for people adapting this code for their own needs,
# yet doing both at once means we don't have to stuff quite as many things in temporary variables,
# and this notebook is single-purpose anyway - it just needs get the job done.
#
#
# This produces OCR results in a rawer form, namely a list of (text fragments, its positions) and does not use that yet.
# It sets this data on the same data structure (that third tuple item inited as []) - the section below actually uses it.
# Which is perhaps somewhat confusing.
#
# Doing the OCR for a hundred documents takes a few hours, which is why we cache the raw OCR results.

# %%
print( "FETCHing PDFs,  OCRing pages" )

for case_i, case_tuple in enumerate(extracted_cases):
    case_dict, case_doc_dicts, _ = case_tuple
    case_name = case_dict['name']

    print('------------------------')
    print( "ENUM: %s"%case_i)
    print( "NAME: %s"%case_name)
    print( "DICTS: %s"%pprint.pformat(case_doc_dicts))
    for case_doc_dict in case_doc_dicts:   # for each PDF document in the case
        pdf_url = case_doc_dict['pdf_url']

        print( "== %s =="%wetsuite.helpers.format.url_basename( pdf_url ) )
        pdfbytes, _ = wetsuite.helpers.localdata.cached_fetch( pdfstore, pdf_url )
        doc_page_fragments = [] # list of lists:   [   [page1fragment1,page1fragment2], [page2fragment1,page2fragment2], etc.  ]   

        ## Render PDF images as images
        # (we previously used wetsuite.datacollect.pdf.page_text but found out that wasn't enough)
        page_images = list( wetsuite.extras.pdf.pages_as_images(pdfbytes, dpi=200) )  # TODO: cache these too
        # high DPI and antialiasing does a _little_ better on things like periods and colons, but less than you'ld think.

        ## For each page image, get OCR. This ic cached because this is sloooow, and PDFs are unlikely to change
        for page_i, page_image in enumerate(page_images):
            page_key = 'ocr::%s::%s'%(page_i, pdf_url)

            if page_key in ocrstore:
                print('     OCR - CACHED  for page %d of %d'%(page_i+1, len(page_images)))
                page_ocr_results = json.loads( ocrstore.get(page_key) )
            else: # generate and cache
                print('     OCR - DOING  for page %d of %d'%(page_i+1, len(page_images)))
                page_ocr_results = wetsuite.extras.ocr.easyocr( page_image, use_gpu=True ) # CONSIDER: prefer?

                ocrstore.put( page_key, json.dumps(page_ocr_results).encode('utf8') )

            #page_image.save( '%s__%s__page_%03d.png'%(case_name,  hash(pdfbytes), page_i+1) )
            # DEBUG: Draw OCR results on the page it came from, and save as PNG:
            #eval_image = wetsuite.extras.ocr.easyocr_draw_eval( page_image, page_ocr_results )
            #eval_image.save('%s__%s__page_%03d-boxes.png'%(case_name,  hash(pdfbytes), page_i+1))

            # I think this is here to potentially merge PDF text objects into the same sort of structure. As is it does nothing.
            page_fragments = []   # fragments of text in a page,  which in the case of EasyOCR will typically be lines at a time
            for bbox, text, cert in page_ocr_results:
                page_fragments.append( (bbox, text, cert) ) 
            doc_page_fragments.append( page_fragments ) # yes, this is currently just page_ocr_results, the idea was that the above might augment/simplify that

        extracted_cases[case_i][2].append( doc_page_fragments )
# Out:
# FETCHing PDFs,  OCRing pages
# ------------------------
# ENUM: 0
# NAME: Hillside New Media Malta Plc
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15402_01-304-549_beslissing_op_bezwaar.pdf',
#   'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep '
#             'worden ingesteld bij de rechtbank.',
#   'title': 'Beslissing op bezwaar Hillside'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15402_bac_advies_hillside.pdf',
#   'title': 'Advies BAC\xa0Hillside'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15402_01-304-539_openbaarmakingsbesluit_woo_bob.pdf',
#   'status': 'Tegen dit openbaarmakingsbesluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit Hillside'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15402_01-285-941_besluit-signed_openbare_versie.pdf',
#   'title': 'Sanctiebesluit Hillside'}]
# == 15402_01-304-549_beslissing_op_bezwaar.pdf ==
#      OCR - DOING  for page 1 of 3
# first use of ocr() - loading EasyOCR model (into GPU)
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:252: UserWarning: Accessing the model URLs via the internal dictionary of the module is deprecated since 0.13 and will be removed in 0.15. Please access them via the appropriate Weights Enum instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#      OCR - DOING  for page 2 of 3
#      OCR - DOING  for page 3 of 3
# == 15402_bac_advies_hillside.pdf ==
#      OCR - DOING  for page 1 of 13
#      OCR - DOING  for page 2 of 13
#      OCR - DOING  for page 3 of 13
#      OCR - DOING  for page 4 of 13
#      OCR - DOING  for page 5 of 13
#      OCR - DOING  for page 6 of 13
#      OCR - DOING  for page 7 of 13
#      OCR - DOING  for page 8 of 13
#      OCR - DOING  for page 9 of 13
#      OCR - DOING  for page 10 of 13
#      OCR - DOING  for page 11 of 13
#      OCR - DOING  for page 12 of 13
#      OCR - DOING  for page 13 of 13
# == 15402_01-304-539_openbaarmakingsbesluit_woo_bob.pdf ==
#      OCR - DOING  for page 1 of 4
#      OCR - DOING  for page 2 of 4
#      OCR - DOING  for page 3 of 4
#      OCR - DOING  for page 4 of 4
# == 15402_01-285-941_besluit-signed_openbare_versie.pdf ==
#      OCR - CACHED  for page 1 of 15
#      OCR - CACHED  for page 2 of 15
#      OCR - CACHED  for page 3 of 15
#      OCR - CACHED  for page 4 of 15
#      OCR - CACHED  for page 5 of 15
#      OCR - CACHED  for page 6 of 15
#      OCR - CACHED  for page 7 of 15
#      OCR - CACHED  for page 8 of 15
#      OCR - CACHED  for page 9 of 15
#      OCR - CACHED  for page 10 of 15
#      OCR - CACHED  for page 11 of 15
#      OCR - CACHED  for page 12 of 15
#      OCR - CACHED  for page 13 of 15
#      OCR - CACHED  for page 14 of 15
#      OCR - CACHED  for page 15 of 15
# ------------------------
# ENUM: 1
# NAME: Betent B.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15998_01-302-172_betent_sanctiebesluit_openbaar.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Boetebesluit Betent B.V.'}]
# == 15998_01-302-172_betent_sanctiebesluit_openbaar.pdf ==
#      OCR - CACHED  for page 1 of 18
#      OCR - CACHED  for page 2 of 18
#      OCR - CACHED  for page 3 of 18
#      OCR - CACHED  for page 4 of 18
#      OCR - CACHED  for page 5 of 18
#      OCR - CACHED  for page 6 of 18
#      OCR - CACHED  for page 7 of 18
#      OCR - CACHED  for page 8 of 18
#      OCR - CACHED  for page 9 of 18
#      OCR - CACHED  for page 10 of 18
#      OCR - CACHED  for page 11 of 18
#      OCR - CACHED  for page 12 of 18
#      OCR - CACHED  for page 13 of 18
#      OCR - CACHED  for page 14 of 18
#      OCR - CACHED  for page 15 of 18
#      OCR - CACHED  for page 16 of 18
#      OCR - CACHED  for page 17 of 18
#      OCR - CACHED  for page 18 of 18
# ------------------------
# ENUM: 2
# NAME: Cloudflare
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_bindende_aanwijzing_20231103_01-302-244.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Bindende aanwijzing Cloudflare'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_obm_woo_ba_cloudflare_20231103_01-302-246.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit openbaarmaking Cloudflare'}]
# == besluit_bindende_aanwijzing_20231103_01-302-244.pdf ==
#      OCR - CACHED  for page 1 of 9
#      OCR - CACHED  for page 2 of 9
#      OCR - CACHED  for page 3 of 9
#      OCR - CACHED  for page 4 of 9
#      OCR - CACHED  for page 5 of 9
#      OCR - CACHED  for page 6 of 9
#      OCR - CACHED  for page 7 of 9
#      OCR - CACHED  for page 8 of 9
#      OCR - CACHED  for page 9 of 9
# == besluit_obm_woo_ba_cloudflare_20231103_01-302-246.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 3
# NAME: Cloudflare
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_bindende_aanwijzing_cloudflare_20231016_01-302-181.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit bindende aanwijzing Cloudflare'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_woo_bindende_aanwijzing_cloudflare_20231016_01-302-184.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit openbaarmaking Cloudflare'}]
# == besluit_bindende_aanwijzing_cloudflare_20231016_01-302-181.pdf ==
#      OCR - CACHED  for page 1 of 8
#      OCR - CACHED  for page 2 of 8
#      OCR - CACHED  for page 3 of 8
#      OCR - CACHED  for page 4 of 8
#      OCR - CACHED  for page 5 of 8
#      OCR - CACHED  for page 6 of 8
#      OCR - CACHED  for page 7 of 8
#      OCR - CACHED  for page 8 of 8
# == besluit_openbaarmaking_woo_bindende_aanwijzing_cloudflare_20231016_01-302-184.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 4
# NAME: Holland Casino
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20231026_01-293-519_openbare_versie_besluit_bindende_aanwijzing_hc_cdb_1.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Besluit bindende aanwijzing Holland Casino N.V.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20231026_01-293-518_openbare_versie_openbaarmakingsbesluit_bindende_aanwijzing_hc_cdb_002_.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Besluit openbaarmaking Holland Casino N.V.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/16369-01-305-776_hc_bob_aanwijzing.pdf',
#   'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep '
#             'worden ingesteld bij de rechtbank.',
#   'title': 'Beslissing op bezwaar\xa0Holland Casino N.V.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/16369_besluit_openbaarmaking_bob_hc.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit openbaarmaking Holland Casino N.V.'}]
# == 20231026_01-293-519_openbare_versie_besluit_bindende_aanwijzing_hc_cdb_1.pdf ==
#      OCR - CACHED  for page 1 of 37
#      OCR - CACHED  for page 2 of 37
#      OCR - CACHED  for page 3 of 37
#      OCR - CACHED  for page 4 of 37
#      OCR - CACHED  for page 5 of 37
#      OCR - CACHED  for page 6 of 37
#      OCR - CACHED  for page 7 of 37
#      OCR - CACHED  for page 8 of 37
#      OCR - CACHED  for page 9 of 37
#      OCR - CACHED  for page 10 of 37
#      OCR - CACHED  for page 11 of 37
#      OCR - CACHED  for page 12 of 37
#      OCR - CACHED  for page 13 of 37
#      OCR - CACHED  for page 14 of 37
#      OCR - CACHED  for page 15 of 37
#      OCR - CACHED  for page 16 of 37
#      OCR - CACHED  for page 17 of 37
#      OCR - CACHED  for page 18 of 37
#      OCR - CACHED  for page 19 of 37
#      OCR - CACHED  for page 20 of 37
#      OCR - CACHED  for page 21 of 37
#      OCR - CACHED  for page 22 of 37
#      OCR - CACHED  for page 23 of 37
#      OCR - CACHED  for page 24 of 37
#      OCR - CACHED  for page 25 of 37
#      OCR - CACHED  for page 26 of 37
#      OCR - CACHED  for page 27 of 37
#      OCR - CACHED  for page 28 of 37
#      OCR - CACHED  for page 29 of 37
#      OCR - CACHED  for page 30 of 37
#      OCR - CACHED  for page 31 of 37
#      OCR - CACHED  for page 32 of 37
#      OCR - CACHED  for page 33 of 37
#      OCR - CACHED  for page 34 of 37
#      OCR - CACHED  for page 35 of 37
#      OCR - CACHED  for page 36 of 37
#      OCR - CACHED  for page 37 of 37
# == 20231026_01-293-518_openbare_versie_openbaarmakingsbesluit_bindende_aanwijzing_hc_cdb_002_.pdf ==
#      OCR - CACHED  for page 1 of 6
#      OCR - CACHED  for page 2 of 6
#      OCR - CACHED  for page 3 of 6
#      OCR - CACHED  for page 4 of 6
#      OCR - CACHED  for page 5 of 6
#      OCR - CACHED  for page 6 of 6
# == 16369-01-305-776_hc_bob_aanwijzing.pdf ==
#      OCR - DOING  for page 1 of 19
#      OCR - DOING  for page 2 of 19
#      OCR - DOING  for page 3 of 19
#      OCR - DOING  for page 4 of 19
#      OCR - DOING  for page 5 of 19
#      OCR - DOING  for page 6 of 19
#      OCR - DOING  for page 7 of 19
#      OCR - DOING  for page 8 of 19
#      OCR - DOING  for page 9 of 19
#      OCR - DOING  for page 10 of 19
#      OCR - DOING  for page 11 of 19
#      OCR - DOING  for page 12 of 19
#      OCR - DOING  for page 13 of 19
#      OCR - DOING  for page 14 of 19
#      OCR - DOING  for page 15 of 19
#      OCR - DOING  for page 16 of 19
#      OCR - DOING  for page 17 of 19
#      OCR - DOING  for page 18 of 19
#      OCR - DOING  for page 19 of 19
# == 16369_besluit_openbaarmaking_bob_hc.pdf ==
#      OCR - DOING  for page 1 of 3
#      OCR - DOING  for page 2 of 3
#      OCR - DOING  for page 3 of 3
# ------------------------
# ENUM: 5
# NAME: Betent
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15403_01-301-226_beslissing_op_bezwaar_betent.pdf',
#   'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep '
#             'worden ingesteld bij de rechtbank.',
#   'title': 'Besluit op bezwaar Betent'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15403_01-301-226_openbaarmakingsbesluit_woo_bob_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingbesluit besluit op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15403_01-300-884_bac_advies_betent.pdf',
#   'title': 'BAC-advies Betent'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/betent_15403_sanctiebesluit.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Betent'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15403_01-301-226_openbaarmakingsbesluit_betent.pdf',
#   'status': 'Tegen dit besluit\xa0is bezwaar gemaakt.',
#   'title': 'Besluit openbaarmaking Betent'}]
# == 15403_01-301-226_beslissing_op_bezwaar_betent.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 15403_01-301-226_openbaarmakingsbesluit_woo_bob_ov.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 15403_01-300-884_bac_advies_betent.pdf ==
#      OCR - CACHED  for page 1 of 11
#      OCR - CACHED  for page 2 of 11
#      OCR - CACHED  for page 3 of 11
#      OCR - CACHED  for page 4 of 11
#      OCR - CACHED  for page 5 of 11
#      OCR - CACHED  for page 6 of 11
#      OCR - CACHED  for page 7 of 11
#      OCR - CACHED  for page 8 of 11
#      OCR - CACHED  for page 9 of 11
#      OCR - CACHED  for page 10 of 11
#      OCR - CACHED  for page 11 of 11
# == betent_15403_sanctiebesluit.pdf ==
#      OCR - CACHED  for page 1 of 14
#      OCR - CACHED  for page 2 of 14
#      OCR - CACHED  for page 3 of 14
#      OCR - CACHED  for page 4 of 14
#      OCR - CACHED  for page 5 of 14
#      OCR - CACHED  for page 6 of 14
#      OCR - CACHED  for page 7 of 14
#      OCR - CACHED  for page 8 of 14
#      OCR - CACHED  for page 9 of 14
#      OCR - CACHED  for page 10 of 14
#      OCR - CACHED  for page 11 of 14
#      OCR - CACHED  for page 12 of 14
#      OCR - CACHED  for page 13 of 14
#      OCR - CACHED  for page 14 of 14
# == 15403_01-301-226_openbaarmakingsbesluit_betent.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 6
# NAME: Bingoal Nederland B.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/beslissing_op_bezwaar_bingoal.pdf',
#   'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep '
#             'worden ingesteld bij de rechtbank.',
#   'title': 'Besluit op bezwaar Bingoal Nederland B.V.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_bingoal_woo_bob.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit besluit op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/bac_advies_bingoal.pdf',
#   'title': 'BAC-advies Bingoal Nederland B.V.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-288-556_15404_sanctiebesluit_bingoal.pdf',
#   'status': 'Tegen dit besluit\xa0is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15404_bingoal_openbaarmakingsbesluit_002_.pdf',
#   'status': 'Tegen dit besluit\xa0is\xa0bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit'}]
# == beslissing_op_bezwaar_bingoal.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == openbaarmakingsbesluit_bingoal_woo_bob.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == bac_advies_bingoal.pdf ==
#      OCR - CACHED  for page 1 of 15
#      OCR - CACHED  for page 2 of 15
#      OCR - CACHED  for page 3 of 15
#      OCR - CACHED  for page 4 of 15
#      OCR - CACHED  for page 5 of 15
#      OCR - CACHED  for page 6 of 15
#      OCR - CACHED  for page 7 of 15
#      OCR - CACHED  for page 8 of 15
#      OCR - CACHED  for page 9 of 15
#      OCR - CACHED  for page 10 of 15
#      OCR - CACHED  for page 11 of 15
#      OCR - CACHED  for page 12 of 15
#      OCR - CACHED  for page 13 of 15
#      OCR - CACHED  for page 14 of 15
#      OCR - CACHED  for page 15 of 15
# == 01-288-556_15404_sanctiebesluit_bingoal.pdf ==
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == 15404_bingoal_openbaarmakingsbesluit_002_.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 7
# NAME: Vriendenloterij N.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/bob_lod_vl_openbare_versie.pdf',
#   'status': 'Tegen deze beslissing op bezwaar kan beroep worden ingesteld bij '
#             'de rechtbank.',
#   'title': 'Besluit op bezwaar Vriendenloterij N.V.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_bob_vl_openbare_versie.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt',
#   'title': 'Besluit openbaarmaking besluit op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230523_01-291-294_openbaar_besluit_last_onder_dwangsom_vl_spellen.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Besluit last onder dwangsom Vriendenloterij N.V.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230523_01-291-296_openbare_versie_openbaarmakingsbesluit_woo_vl_last.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Besluit openbaarmaking Vriendenloterij N.V.'}]
# == bob_lod_vl_openbare_versie.pdf ==
#      OCR - CACHED  for page 1 of 6
#      OCR - CACHED  for page 2 of 6
#      OCR - CACHED  for page 3 of 6
#      OCR - CACHED  for page 4 of 6
#      OCR - CACHED  for page 5 of 6
#      OCR - CACHED  for page 6 of 6
# == besluit_openbaarmaking_bob_vl_openbare_versie.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 20230523_01-291-294_openbaar_besluit_last_onder_dwangsom_vl_spellen.pdf ==
#      OCR - CACHED  for page 1 of 30
#      OCR - CACHED  for page 2 of 30
#      OCR - CACHED  for page 3 of 30
#      OCR - CACHED  for page 4 of 30
#      OCR - CACHED  for page 5 of 30
#      OCR - CACHED  for page 6 of 30
#      OCR - CACHED  for page 7 of 30
#      OCR - CACHED  for page 8 of 30
#      OCR - CACHED  for page 9 of 30
#      OCR - CACHED  for page 10 of 30
#      OCR - CACHED  for page 11 of 30
#      OCR - CACHED  for page 12 of 30
#      OCR - CACHED  for page 13 of 30
#      OCR - CACHED  for page 14 of 30
#      OCR - CACHED  for page 15 of 30
#      OCR - CACHED  for page 16 of 30
#      OCR - CACHED  for page 17 of 30
#      OCR - CACHED  for page 18 of 30
#      OCR - CACHED  for page 19 of 30
#      OCR - CACHED  for page 20 of 30
#      OCR - CACHED  for page 21 of 30
#      OCR - CACHED  for page 22 of 30
#      OCR - CACHED  for page 23 of 30
#      OCR - CACHED  for page 24 of 30
#      OCR - CACHED  for page 25 of 30
#      OCR - CACHED  for page 26 of 30
#      OCR - CACHED  for page 27 of 30
#      OCR - CACHED  for page 28 of 30
#      OCR - CACHED  for page 29 of 30
#      OCR - CACHED  for page 30 of 30
# == 20230523_01-291-296_openbare_versie_openbaarmakingsbesluit_woo_vl_last.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 8
# NAME: Nationale Postcode Loterij N.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/bob_lod_npl_openbare_versie.pdf',
#   'status': 'Tegen deze beslissing op bezwaar kan beroep worden ingesteld bij '
#             'de rechtbank.',
#   'title': 'Besluit op bezwaar Nationale Postcode Loterij N.V.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_bob_npl_openbare_versie.pdf',
#   'status': 'Tegen deze beslissing op bezwaar kan beroep worden ingesteld bij '
#             'de rechtbank.',
#   'title': 'Besluit openbaarmaking besluit op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230523_01-291-288_openbaar_besluit_last_onder_dwangsom_npl_spellen.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Besluit Last onder dwangsom Nationale Postcode Loterij N.V.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230523_01-291-290_openbare_versie_openbaarmakingsbesluit_woo_npl_last.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Besluit openbaarmaking Nationale Postcode Loterij N.V.'}]
# == bob_lod_npl_openbare_versie.pdf ==
#      OCR - CACHED  for page 1 of 6
#      OCR - CACHED  for page 2 of 6
#      OCR - CACHED  for page 3 of 6
#      OCR - CACHED  for page 4 of 6
#      OCR - CACHED  for page 5 of 6
#      OCR - CACHED  for page 6 of 6
# == besluit_openbaarmaking_bob_npl_openbare_versie.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 20230523_01-291-288_openbaar_besluit_last_onder_dwangsom_npl_spellen.pdf ==
#      OCR - CACHED  for page 1 of 31
#      OCR - CACHED  for page 2 of 31
#      OCR - CACHED  for page 3 of 31
#      OCR - CACHED  for page 4 of 31
#      OCR - CACHED  for page 5 of 31
#      OCR - CACHED  for page 6 of 31
#      OCR - CACHED  for page 7 of 31
#      OCR - CACHED  for page 8 of 31
#      OCR - CACHED  for page 9 of 31
#      OCR - CACHED  for page 10 of 31
#      OCR - CACHED  for page 11 of 31
#      OCR - CACHED  for page 12 of 31
#      OCR - CACHED  for page 13 of 31
#      OCR - CACHED  for page 14 of 31
#      OCR - CACHED  for page 15 of 31
#      OCR - CACHED  for page 16 of 31
#      OCR - CACHED  for page 17 of 31
#      OCR - CACHED  for page 18 of 31
#      OCR - CACHED  for page 19 of 31
#      OCR - CACHED  for page 20 of 31
#      OCR - CACHED  for page 21 of 31
#      OCR - CACHED  for page 22 of 31
#      OCR - CACHED  for page 23 of 31
#      OCR - CACHED  for page 24 of 31
#      OCR - CACHED  for page 25 of 31
#      OCR - CACHED  for page 26 of 31
#      OCR - CACHED  for page 27 of 31
#      OCR - CACHED  for page 28 of 31
#      OCR - CACHED  for page 29 of 31
#      OCR - CACHED  for page 30 of 31
#      OCR - CACHED  for page 31 of 31
# == 20230523_01-291-290_openbare_versie_openbaarmakingsbesluit_woo_npl_last.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 9
# NAME: GoldWin Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/16442_boetebesluit_goldwin.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Boetebesluit GoldWin Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/16442_01-299-883_openbaarmakingsbesluit_goldwin.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit\xa0GoldWin Limited'}]
# == 16442_boetebesluit_goldwin.pdf ==
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == 16442_01-299-883_openbaarmakingsbesluit_goldwin.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 10
# NAME: MKC Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/16402_boetebesluit_mkc_limited.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Boetebesluit\xa0MKC Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/16402_01-299-881_openbaarmakingsbesluit_mkc_limited.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit\xa0MKC Limited'}]
# == 16402_boetebesluit_mkc_limited.pdf ==
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == 16402_01-299-881_openbaarmakingsbesluit_mkc_limited.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 11
# NAME: Blue High House S.A.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230929_01-296-617_besluit_lod_1a_blue_high_house_s-a-.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit last onder dwangsom Blue High House S.A.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230929_01-296-618_besluit_openbaarmaking_woo_blue_high_house_s-a-.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Openbaarmakingsbesluit Blue High House S.A.'}]
# == 20230929_01-296-617_besluit_lod_1a_blue_high_house_s-a-.pdf ==
#      OCR - CACHED  for page 1 of 12
#      OCR - CACHED  for page 2 of 12
#      OCR - CACHED  for page 3 of 12
#      OCR - CACHED  for page 4 of 12
#      OCR - CACHED  for page 5 of 12
#      OCR - CACHED  for page 6 of 12
#      OCR - CACHED  for page 7 of 12
#      OCR - CACHED  for page 8 of 12
#      OCR - CACHED  for page 9 of 12
#      OCR - CACHED  for page 10 of 12
#      OCR - CACHED  for page 11 of 12
#      OCR - CACHED  for page 12 of 12
# == 20230929_01-296-618_besluit_openbaarmaking_woo_blue_high_house_s-a-.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 12
# NAME: L.C.S Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_lcs_limited.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Boetebesluit L.C.S Limited (12 oktober 2023)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_lcs_limited.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt',
#   'title': 'Openbaarmakingsbesluit L.C.S Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20220817_01_265_500_-_besluit_lod_sons-of-slots_ov.pdf',
#   'status': 'Naar aanleiding van het besluit is gecontroleerd, hierbij is '
#             'geconstateerd dat de overtredingen zijn gestaakt.\xa0Tegen dit '
#             'besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Last onder dwangsom\xa0L.C.S Limited (1\xa0september 2022)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20220817_01_265_499_-_besluit_openbaarmaking_ov.pdf',
#   'status': 'Naar aanleiding van het besluit is gecontroleerd, hierbij is '
#             'geconstateerd dat de overtredingen zijn gestaakt.\xa0Tegen dit '
#             'besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit tot openbaarmaking\xa0L.C.S Limited (1\xa0september 2022)'}]
# == sanctiebesluit_lcs_limited.pdf ==
#      OCR - CACHED  for page 1 of 21
#      OCR - CACHED  for page 2 of 21
#      OCR - CACHED  for page 3 of 21
#      OCR - CACHED  for page 4 of 21
#      OCR - CACHED  for page 5 of 21
#      OCR - CACHED  for page 6 of 21
#      OCR - CACHED  for page 7 of 21
#      OCR - CACHED  for page 8 of 21
#      OCR - CACHED  for page 9 of 21
#      OCR - CACHED  for page 10 of 21
#      OCR - CACHED  for page 11 of 21
#      OCR - CACHED  for page 12 of 21
#      OCR - CACHED  for page 13 of 21
#      OCR - CACHED  for page 14 of 21
#      OCR - CACHED  for page 15 of 21
#      OCR - CACHED  for page 16 of 21
#      OCR - CACHED  for page 17 of 21
#      OCR - CACHED  for page 18 of 21
#      OCR - CACHED  for page 19 of 21
#      OCR - CACHED  for page 20 of 21
#      OCR - CACHED  for page 21 of 21
# == besluit_openbaarmaking_lcs_limited.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 20220817_01_265_500_-_besluit_lod_sons-of-slots_ov.pdf ==
#      OCR - CACHED  for page 1 of 11
#      OCR - CACHED  for page 2 of 11
#      OCR - CACHED  for page 3 of 11
#      OCR - CACHED  for page 4 of 11
#      OCR - CACHED  for page 5 of 11
#      OCR - CACHED  for page 6 of 11
#      OCR - CACHED  for page 7 of 11
#      OCR - CACHED  for page 8 of 11
#      OCR - CACHED  for page 9 of 11
#      OCR - CACHED  for page 10 of 11
#      OCR - CACHED  for page 11 of 11
# == 20220817_01_265_499_-_besluit_openbaarmaking_ov.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 13
# NAME: JOI Gaming Ltd
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/ov_beslissing_op_bezwaar_joi_gaming_limited.pdf',
#   'status': 'In deze zaak is beroep ingesteld.',
#   'title': 'Besluit op bezwaar JOI Gaming Ltd'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/ov_openbaarmakingsbesluit_woo_bob_joi_gaming_limited.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit bij besluit op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/ov_bac_advies_joi_gaming_limited.pdf',
#   'title': 'BAC-advies'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_joi_gaming_ltd_10_januari_2023_.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_joi_gaming_ltd.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit'}]
# == ov_beslissing_op_bezwaar_joi_gaming_limited.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == ov_openbaarmakingsbesluit_woo_bob_joi_gaming_limited.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == ov_bac_advies_joi_gaming_limited.pdf ==
#      OCR - CACHED  for page 1 of 11
#      OCR - CACHED  for page 2 of 11
#      OCR - CACHED  for page 3 of 11
#      OCR - CACHED  for page 4 of 11
#      OCR - CACHED  for page 5 of 11
#      OCR - CACHED  for page 6 of 11
#      OCR - CACHED  for page 7 of 11
#      OCR - CACHED  for page 8 of 11
#      OCR - CACHED  for page 9 of 11
#      OCR - CACHED  for page 10 of 11
#      OCR - CACHED  for page 11 of 11
# == sanctiebesluit_joi_gaming_ltd_10_januari_2023_.pdf ==
#      OCR - CACHED  for page 1 of 14
#      OCR - CACHED  for page 2 of 14
#      OCR - CACHED  for page 3 of 14
#      OCR - CACHED  for page 4 of 14
#      OCR - CACHED  for page 5 of 14
#      OCR - CACHED  for page 6 of 14
#      OCR - CACHED  for page 7 of 14
#      OCR - CACHED  for page 8 of 14
#      OCR - CACHED  for page 9 of 14
#      OCR - CACHED  for page 10 of 14
#      OCR - CACHED  for page 11 of 14
#      OCR - CACHED  for page 12 of 14
#      OCR - CACHED  for page 13 of 14
#      OCR - CACHED  for page 14 of 14
# == openbaarmakingsbesluit_joi_gaming_ltd.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 14
# NAME: Play North Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230831_01-292-391_aanwijzing_pn_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit aanwijzing Play North'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230619_01-292-392_besluit_op_bezwaar_pn_ov.pdf',
#   'status': 'Er is geen beroep ingesteld.\xa0 Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit op bezwaar'}]
# == 20230831_01-292-391_aanwijzing_pn_ov.pdf ==
#      OCR - CACHED  for page 1 of 14
#      OCR - CACHED  for page 2 of 14
#      OCR - CACHED  for page 3 of 14
#      OCR - CACHED  for page 4 of 14
#      OCR - CACHED  for page 5 of 14
#      OCR - CACHED  for page 6 of 14
#      OCR - CACHED  for page 7 of 14
#      OCR - CACHED  for page 8 of 14
#      OCR - CACHED  for page 9 of 14
#      OCR - CACHED  for page 10 of 14
#      OCR - CACHED  for page 11 of 14
#      OCR - CACHED  for page 12 of 14
#      OCR - CACHED  for page 13 of 14
#      OCR - CACHED  for page 14 of 14
# == 20230619_01-292-392_besluit_op_bezwaar_pn_ov.pdf ==
#      OCR - CACHED  for page 1 of 27
#      OCR - CACHED  for page 2 of 27
#      OCR - CACHED  for page 3 of 27
#      OCR - CACHED  for page 4 of 27
#      OCR - CACHED  for page 5 of 27
#      OCR - CACHED  for page 6 of 27
#      OCR - CACHED  for page 7 of 27
#      OCR - CACHED  for page 8 of 27
#      OCR - CACHED  for page 9 of 27
#      OCR - CACHED  for page 10 of 27
#      OCR - CACHED  for page 11 of 27
#      OCR - CACHED  for page 12 of 27
#      OCR - CACHED  for page 13 of 27
#      OCR - CACHED  for page 14 of 27
#      OCR - CACHED  for page 15 of 27
#      OCR - CACHED  for page 16 of 27
#      OCR - CACHED  for page 17 of 27
#      OCR - CACHED  for page 18 of 27
#      OCR - CACHED  for page 19 of 27
#      OCR - CACHED  for page 20 of 27
#      OCR - CACHED  for page 21 of 27
#      OCR - CACHED  for page 22 of 27
#      OCR - CACHED  for page 23 of 27
#      OCR - CACHED  for page 24 of 27
#      OCR - CACHED  for page 25 of 27
#      OCR - CACHED  for page 26 of 27
#      OCR - CACHED  for page 27 of 27
# ------------------------
# ENUM: 15
# NAME: Betent
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230831_01-292-887_aanwijzing_betent_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit aanwijzing Betent'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230831_01-292-888_besluit_op_bezwaar_ov.pdf',
#   'status': 'Er is geen beroep ingesteld.\xa0\xa0Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit op bezwaar'}]
# == 20230831_01-292-887_aanwijzing_betent_ov.pdf ==
#      OCR - CACHED  for page 1 of 11
#      OCR - CACHED  for page 2 of 11
#      OCR - CACHED  for page 3 of 11
#      OCR - CACHED  for page 4 of 11
#      OCR - CACHED  for page 5 of 11
#      OCR - CACHED  for page 6 of 11
#      OCR - CACHED  for page 7 of 11
#      OCR - CACHED  for page 8 of 11
#      OCR - CACHED  for page 9 of 11
#      OCR - CACHED  for page 10 of 11
#      OCR - CACHED  for page 11 of 11
# == 20230831_01-292-888_besluit_op_bezwaar_ov.pdf ==
#      OCR - CACHED  for page 1 of 17
#      OCR - CACHED  for page 2 of 17
#      OCR - CACHED  for page 3 of 17
#      OCR - CACHED  for page 4 of 17
#      OCR - CACHED  for page 5 of 17
#      OCR - CACHED  for page 6 of 17
#      OCR - CACHED  for page 7 of 17
#      OCR - CACHED  for page 8 of 17
#      OCR - CACHED  for page 9 of 17
#      OCR - CACHED  for page 10 of 17
#      OCR - CACHED  for page 11 of 17
#      OCR - CACHED  for page 12 of 17
#      OCR - CACHED  for page 13 of 17
#      OCR - CACHED  for page 14 of 17
#      OCR - CACHED  for page 15 of 17
#      OCR - CACHED  for page 16 of 17
#      OCR - CACHED  for page 17 of 17
# ------------------------
# ENUM: 16
# NAME: NetX Betting
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_lod_1a_netx_betting_limited_ov_.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit last onder dwangsom NetX Betting'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_ov_.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking NetX Betting'}]
# == besluit_lod_1a_netx_betting_limited_ov_.pdf ==
#      OCR - CACHED  for page 1 of 14
#      OCR - CACHED  for page 2 of 14
#      OCR - CACHED  for page 3 of 14
#      OCR - CACHED  for page 4 of 14
#      OCR - CACHED  for page 5 of 14
#      OCR - CACHED  for page 6 of 14
#      OCR - CACHED  for page 7 of 14
#      OCR - CACHED  for page 8 of 14
#      OCR - CACHED  for page 9 of 14
#      OCR - CACHED  for page 10 of 14
#      OCR - CACHED  for page 11 of 14
#      OCR - CACHED  for page 12 of 14
#      OCR - CACHED  for page 13 of 14
#      OCR - CACHED  for page 14 of 14
# == besluit_openbaarmaking_ov_.pdf ==
#      OCR - CACHED  for page 1 of 6
#      OCR - CACHED  for page 2 of 6
#      OCR - CACHED  for page 3 of 6
#      OCR - CACHED  for page 4 of 6
#      OCR - CACHED  for page 5 of 6
#      OCR - CACHED  for page 6 of 6
# ------------------------
# ENUM: 17
# NAME: GoldWin Ltd
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230420_01-291-425_besluit_lod_goldwin_ltd_ov_.pdf',
#   'title': 'Besluit last onder dwangsom GoldWin Ltd'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230420_01-191-426_besluit_openbaarmaking_ov_.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit tot openbaarmaking GoldWin Ltd'}]
# == 20230420_01-291-425_besluit_lod_goldwin_ltd_ov_.pdf ==
#      OCR - CACHED  for page 1 of 12
#      OCR - CACHED  for page 2 of 12
#      OCR - CACHED  for page 3 of 12
#      OCR - CACHED  for page 4 of 12
#      OCR - CACHED  for page 5 of 12
#      OCR - CACHED  for page 6 of 12
#      OCR - CACHED  for page 7 of 12
#      OCR - CACHED  for page 8 of 12
#      OCR - CACHED  for page 9 of 12
#      OCR - CACHED  for page 10 of 12
#      OCR - CACHED  for page 11 of 12
#      OCR - CACHED  for page 12 of 12
# == 20230420_01-191-426_besluit_openbaarmaking_ov_.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 18
# NAME: Merkur Casino Almere B.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-289-330_15484_sanctiebesluit_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Sanctiebesluit'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-289-336_15484_openbaarmakingsbesluit_woo_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt',
#   'title': 'Openbaarmakingsbesluit'}]
# == 01-289-330_15484_sanctiebesluit_ov.pdf ==
#      OCR - CACHED  for page 1 of 16
#      OCR - CACHED  for page 2 of 16
#      OCR - CACHED  for page 3 of 16
#      OCR - CACHED  for page 4 of 16
#      OCR - CACHED  for page 5 of 16
#      OCR - CACHED  for page 6 of 16
#      OCR - CACHED  for page 7 of 16
#      OCR - CACHED  for page 8 of 16
#      OCR - CACHED  for page 9 of 16
#      OCR - CACHED  for page 10 of 16
#      OCR - CACHED  for page 11 of 16
#      OCR - CACHED  for page 12 of 16
#      OCR - CACHED  for page 13 of 16
#      OCR - CACHED  for page 14 of 16
#      OCR - CACHED  for page 15 of 16
#      OCR - CACHED  for page 16 of 16
# == 01-289-336_15484_openbaarmakingsbesluit_woo_ov.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 19
# NAME: Winning Poker Network
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230228_01-285-044_lod_openbare_versie_beveiligd.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Sanctiebesluit Winning Poker Network'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20220228_01-287-832_besluit_openbaarmaking_openbare_versie_beveiligd.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit Winning Poker Network'}]
# == 20230228_01-285-044_lod_openbare_versie_beveiligd.pdf ==
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == 20220228_01-287-832_besluit_openbaarmaking_openbare_versie_beveiligd.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 20
# NAME: Red Ridge Marketing
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-286-861_15395_sanctiebesluit_ov.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Sanctiebesluit Red Ridge Marketing'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15395_openbaarmakingsbesluit_ov.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Openbaarmakingsbesluit Red Ridge Marketing'}]
# == 01-286-861_15395_sanctiebesluit_ov.pdf ==
#      OCR - CACHED  for page 1 of 16
#      OCR - CACHED  for page 2 of 16
#      OCR - CACHED  for page 3 of 16
#      OCR - CACHED  for page 4 of 16
#      OCR - CACHED  for page 5 of 16
#      OCR - CACHED  for page 6 of 16
#      OCR - CACHED  for page 7 of 16
#      OCR - CACHED  for page 8 of 16
#      OCR - CACHED  for page 9 of 16
#      OCR - CACHED  for page 10 of 16
#      OCR - CACHED  for page 11 of 16
#      OCR - CACHED  for page 12 of 16
#      OCR - CACHED  for page 13 of 16
#      OCR - CACHED  for page 14 of 16
#      OCR - CACHED  for page 15 of 16
#      OCR - CACHED  for page 16 of 16
# == 15395_openbaarmakingsbesluit_ov.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 21
# NAME: Probe Investments Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15269_01-294-564_beslissing_op_bezwaar_ov.pdf',
#   'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep '
#             'worden ingesteld bij de rechtbank.',
#   'title': 'Beslissing op bezwaar Probe'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15269_01-294-565_openbaarmakingsbesluit_woo_bob_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit beslissing op bezwaar Probe'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15269_01-293-484_bac_advies_ov.pdf',
#   'title': 'BAC Advies Probe'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15269_01-281-231_sanctiebesluit_probe_investments_limited_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Probe'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15269_01-281-234_besluit_openbaarmaking_probe_investments_limited_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit Probe'}]
# == 15269_01-294-564_beslissing_op_bezwaar_ov.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 15269_01-294-565_openbaarmakingsbesluit_woo_bob_ov.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 15269_01-293-484_bac_advies_ov.pdf ==
#      OCR - CACHED  for page 1 of 20
#      OCR - CACHED  for page 2 of 20
#      OCR - CACHED  for page 3 of 20
#      OCR - CACHED  for page 4 of 20
#      OCR - CACHED  for page 5 of 20
#      OCR - CACHED  for page 6 of 20
#      OCR - CACHED  for page 7 of 20
#      OCR - CACHED  for page 8 of 20
#      OCR - CACHED  for page 9 of 20
#      OCR - CACHED  for page 10 of 20
#      OCR - CACHED  for page 11 of 20
#      OCR - CACHED  for page 12 of 20
#      OCR - CACHED  for page 13 of 20
#      OCR - CACHED  for page 14 of 20
#      OCR - CACHED  for page 15 of 20
#      OCR - CACHED  for page 16 of 20
#      OCR - CACHED  for page 17 of 20
#      OCR - CACHED  for page 18 of 20
#      OCR - CACHED  for page 19 of 20
#      OCR - CACHED  for page 20 of 20
# == 15269_01-281-231_sanctiebesluit_probe_investments_limited_ov.pdf ==
#      OCR - CACHED  for page 1 of 27
#      OCR - CACHED  for page 2 of 27
#      OCR - CACHED  for page 3 of 27
#      OCR - CACHED  for page 4 of 27
#      OCR - CACHED  for page 5 of 27
#      OCR - CACHED  for page 6 of 27
#      OCR - CACHED  for page 7 of 27
#      OCR - CACHED  for page 8 of 27
#      OCR - CACHED  for page 9 of 27
#      OCR - CACHED  for page 10 of 27
#      OCR - CACHED  for page 11 of 27
#      OCR - CACHED  for page 12 of 27
#      OCR - CACHED  for page 13 of 27
#      OCR - CACHED  for page 14 of 27
#      OCR - CACHED  for page 15 of 27
#      OCR - CACHED  for page 16 of 27
#      OCR - CACHED  for page 17 of 27
#      OCR - CACHED  for page 18 of 27
#      OCR - CACHED  for page 19 of 27
#      OCR - CACHED  for page 20 of 27
#      OCR - CACHED  for page 21 of 27
#      OCR - CACHED  for page 22 of 27
#      OCR - CACHED  for page 23 of 27
#      OCR - CACHED  for page 24 of 27
#      OCR - CACHED  for page 25 of 27
#      OCR - CACHED  for page 26 of 27
#      OCR - CACHED  for page 27 of 27
# == 15269_01-281-234_besluit_openbaarmaking_probe_investments_limited_ov.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 22
# NAME: Betpoint Group Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/ov_15164_01-281-226_sanctiebesluit_betpoint.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Betpoint'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/ov_15164_01-281-229_betpoint_openbaarmaking.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit Betpoint'}]
# == ov_15164_01-281-226_sanctiebesluit_betpoint.pdf ==
#      OCR - CACHED  for page 1 of 31
#      OCR - CACHED  for page 2 of 31
#      OCR - CACHED  for page 3 of 31
#      OCR - CACHED  for page 4 of 31
#      OCR - CACHED  for page 5 of 31
#      OCR - CACHED  for page 6 of 31
#      OCR - CACHED  for page 7 of 31
#      OCR - CACHED  for page 8 of 31
#      OCR - CACHED  for page 9 of 31
#      OCR - CACHED  for page 10 of 31
#      OCR - CACHED  for page 11 of 31
#      OCR - CACHED  for page 12 of 31
#      OCR - CACHED  for page 13 of 31
#      OCR - CACHED  for page 14 of 31
#      OCR - CACHED  for page 15 of 31
#      OCR - CACHED  for page 16 of 31
#      OCR - CACHED  for page 17 of 31
#      OCR - CACHED  for page 18 of 31
#      OCR - CACHED  for page 19 of 31
#      OCR - CACHED  for page 20 of 31
#      OCR - CACHED  for page 21 of 31
#      OCR - CACHED  for page 22 of 31
#      OCR - CACHED  for page 23 of 31
#      OCR - CACHED  for page 24 of 31
#      OCR - CACHED  for page 25 of 31
#      OCR - CACHED  for page 26 of 31
#      OCR - CACHED  for page 27 of 31
#      OCR - CACHED  for page 28 of 31
#      OCR - CACHED  for page 29 of 31
#      OCR - CACHED  for page 30 of 31
#      OCR - CACHED  for page 31 of 31
# == ov_15164_01-281-229_betpoint_openbaarmaking.pdf ==
#      OCR - CACHED  for page 1 of 6
#      OCR - CACHED  for page 2 of 6
#      OCR - CACHED  for page 3 of 6
#      OCR - CACHED  for page 4 of 6
#      OCR - CACHED  for page 5 of 6
#      OCR - CACHED  for page 6 of 6
# ------------------------
# ENUM: 23
# NAME: N1 Interactive Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-292-870-beslissing_op_bezwaar_15244_ov.pdf',
#   'status': 'Tegen deze beslissing op bezwaar is inmiddels beroep ingesteld '
#             'bij de rechtbank.',
#   'title': 'Beslissing op bezwaar N1 Interactive Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-292-895_besluit_openbaarmaking_15244_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit beslissing op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15244_01-291-871_bac_advies_ov_1.pdf',
#   'title': 'BAC Advies N1'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-281-253_sanctiebesluit_15244_ov.pdf',
# ...
#   'status': 'Tegen dit sanctiebesluit is bezwaar ingediend',
#   'title': 'Sanctiebesluit Onisac\xa0Limited en Mansion Online Casino '
#            'Limited\xa0\xa0(9 april 2019)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/openbaarmakingsbesluit_sanctiebesluit_onisac.pdf',
#   'status': 'Tegen dit besluit is bezwaar ingediend',
#   'title': 'Besluit openbaarmaking sanctiebesluit Onisac\xa0Limited en Mansion '
#            'Online Casino Limited (9 april 2019)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/7845_00_021_663_-_sanctiebesluit_openbaar.pdf',
#   'status': 'In deze zaak is hoger beroep ingesteld en de Raad van State heeft '
#             'www.raadvanstate.nl/uitspraken/zoeken-in-uitspraken/tekst-uitspraak.html?id=96664&summary_only=&q= '
#             'gedaan op 26 september 2018.',
#   'title': 'Sanctiebesluit Onisac Limited en Mansion Online Casino Limited (4 '
#            'november 2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/7845_00_021_664-_openbaarmaking_openbaar.pdf',
#   'status': 'In deze zaak is hoger beroep ingesteld en de Raad van State heeft '
#             'www.raadvanstate.nl/uitspraken/zoeken-in-uitspraken/tekst-uitspraak.html?id=96664&summary_only=&q= '
#             'gedaan op 26 september 2018.',
#   'title': 'Besluit openbaarmaking Onisac Limited en Mansion Online Casino '
#            'Limited\xa0(4 november 2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/7845_-_advies_bac_ov_pdf.pdf',
#   'title': 'Advies BAC\xa0 Onisac Limited en Mansion Online Casino Limited '
#            '(154 kB)\xa0(4 november 2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/7845_-_beslissing_op_bezwaar_ov_pdf.pdf',
#   'status': 'Tegen deze beslissing op bezwaar is inmiddels beroep ingesteld '
#             'bij de rechtbank.',
#   'title': 'Beslissing op bezwaar Onisac Limited en Mansion Online Casino '
#            'Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/8051_-_besluit_openbaarmaking_bob_ov_pdf.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking Onisac Limited en Mansion Online Casino '
#            'Limited BOB (4 november 2013)'}]
# == 190625_besluit_openbaarmaking_bob_onisac_openbaar_003.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 190704_bob_en_bac.pdf ==
#      OCR - CACHED  for page 1 of 12
#      OCR - CACHED  for page 2 of 12
#      OCR - CACHED  for page 3 of 12
#      OCR - CACHED  for page 4 of 12
#      OCR - CACHED  for page 5 of 12
#      OCR - CACHED  for page 6 of 12
#      OCR - CACHED  for page 7 of 12
#      OCR - CACHED  for page 8 of 12
#      OCR - CACHED  for page 9 of 12
#      OCR - CACHED  for page 10 of 12
#      OCR - CACHED  for page 11 of 12
#      OCR - CACHED  for page 12 of 12
# == sanctiebesluit_onisac.pdf ==
#      OCR - CACHED  for page 1 of 15
#      OCR - CACHED  for page 2 of 15
#      OCR - CACHED  for page 3 of 15
#      OCR - CACHED  for page 4 of 15
#      OCR - CACHED  for page 5 of 15
#      OCR - CACHED  for page 6 of 15
#      OCR - CACHED  for page 7 of 15
#      OCR - CACHED  for page 8 of 15
#      OCR - CACHED  for page 9 of 15
#      OCR - CACHED  for page 10 of 15
#      OCR - CACHED  for page 11 of 15
#      OCR - CACHED  for page 12 of 15
#      OCR - CACHED  for page 13 of 15
#      OCR - CACHED  for page 14 of 15
#      OCR - CACHED  for page 15 of 15
# == openbaarmakingsbesluit_sanctiebesluit_onisac.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 7845_00_021_663_-_sanctiebesluit_openbaar.pdf ==
#      OCR - CACHED  for page 1 of 30
#      OCR - CACHED  for page 2 of 30
#      OCR - CACHED  for page 3 of 30
#      OCR - CACHED  for page 4 of 30
#      OCR - CACHED  for page 5 of 30
#      OCR - CACHED  for page 6 of 30
#      OCR - CACHED  for page 7 of 30
#      OCR - CACHED  for page 8 of 30
#      OCR - CACHED  for page 9 of 30
#      OCR - CACHED  for page 10 of 30
#      OCR - CACHED  for page 11 of 30
#      OCR - CACHED  for page 12 of 30
#      OCR - CACHED  for page 13 of 30
#      OCR - CACHED  for page 14 of 30
#      OCR - CACHED  for page 15 of 30
#      OCR - CACHED  for page 16 of 30
#      OCR - CACHED  for page 17 of 30
#      OCR - CACHED  for page 18 of 30
#      OCR - CACHED  for page 19 of 30
#      OCR - CACHED  for page 20 of 30
#      OCR - CACHED  for page 21 of 30
#      OCR - CACHED  for page 22 of 30
#      OCR - CACHED  for page 23 of 30
#      OCR - CACHED  for page 24 of 30
#      OCR - CACHED  for page 25 of 30
#      OCR - CACHED  for page 26 of 30
#      OCR - CACHED  for page 27 of 30
#      OCR - CACHED  for page 28 of 30
#      OCR - CACHED  for page 29 of 30
#      OCR - CACHED  for page 30 of 30
# == 7845_00_021_664-_openbaarmaking_openbaar.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# == 7845_-_advies_bac_ov_pdf.pdf ==
#      OCR - CACHED  for page 1 of 17
#      OCR - CACHED  for page 2 of 17
#      OCR - CACHED  for page 3 of 17
#      OCR - CACHED  for page 4 of 17
#      OCR - CACHED  for page 5 of 17
#      OCR - CACHED  for page 6 of 17
#      OCR - CACHED  for page 7 of 17
#      OCR - CACHED  for page 8 of 17
#      OCR - CACHED  for page 9 of 17
#      OCR - CACHED  for page 10 of 17
#      OCR - CACHED  for page 11 of 17
#      OCR - CACHED  for page 12 of 17
#      OCR - CACHED  for page 13 of 17
#      OCR - CACHED  for page 14 of 17
#      OCR - CACHED  for page 15 of 17
#      OCR - CACHED  for page 16 of 17
#      OCR - CACHED  for page 17 of 17
# == 7845_-_beslissing_op_bezwaar_ov_pdf.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 8051_-_besluit_openbaarmaking_bob_ov_pdf.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# ------------------------
# ENUM: 117
# NAME: Café Lucky
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5464/besluit_op_bezwaar_openbaar_cafe_lucky.pdf',
#   'status': 'Tegen de beslissing van de rechtbank is geen hoger beroep '
#             'ingesteld. De uitspraak van de rechtbank is thans onherroepelijk.',
#   'title': 'Besluit op bezwaar inclusief advies BAC Café Lucky (28 maart '
#            '2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5464/besluit_openbaarmaking_bob_openbaar_cafe_lucky.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking Café Lucky\xa0(28 maart 2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5464/7938_-_00_018_637_sanctiebesluit_openbare_versie.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Café Lucky\xa0(14 november 2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5464/7938_besluit_openbaarmaking_cafe_lucky.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Besluit openbaarmaking Cafe Lucky (14 november 2013)'}]
# == besluit_op_bezwaar_openbaar_cafe_lucky.pdf ==
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == besluit_openbaarmaking_bob_openbaar_cafe_lucky.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 7938_-_00_018_637_sanctiebesluit_openbare_versie.pdf ==
#      OCR - CACHED  for page 1 of 16
#      OCR - CACHED  for page 2 of 16
#      OCR - CACHED  for page 3 of 16
#      OCR - CACHED  for page 4 of 16
#      OCR - CACHED  for page 5 of 16
#      OCR - CACHED  for page 6 of 16
#      OCR - CACHED  for page 7 of 16
#      OCR - CACHED  for page 8 of 16
#      OCR - CACHED  for page 9 of 16
#      OCR - CACHED  for page 10 of 16
#      OCR - CACHED  for page 11 of 16
#      OCR - CACHED  for page 12 of 16
#      OCR - CACHED  for page 13 of 16
#      OCR - CACHED  for page 14 of 16
#      OCR - CACHED  for page 15 of 16
#      OCR - CACHED  for page 16 of 16
# == 7938_besluit_openbaarmaking_cafe_lucky.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 118
# NAME: Star SAT Electronica
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5463/7971_-_00_019_052_sanctiebesluit_openbare_versie.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Sanctiebesluit Star Sat Electronica(935 kB)\xa0( 21 november '
#            '2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5463/7971_besluit_openbaarmaking_star_sat_electronica.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking Star Sat Electronica (202 kB)\xa0(21 '
#            'november 2013)'}]
# == 7971_-_00_019_052_sanctiebesluit_openbare_versie.pdf ==
#      OCR - CACHED  for page 1 of 14
#      OCR - CACHED  for page 2 of 14
#      OCR - CACHED  for page 3 of 14
#      OCR - CACHED  for page 4 of 14
#      OCR - CACHED  for page 5 of 14
#      OCR - CACHED  for page 6 of 14
#      OCR - CACHED  for page 7 of 14
#      OCR - CACHED  for page 8 of 14
#      OCR - CACHED  for page 9 of 14
#      OCR - CACHED  for page 10 of 14
#      OCR - CACHED  for page 11 of 14
#      OCR - CACHED  for page 12 of 14
#      OCR - CACHED  for page 13 of 14
#      OCR - CACHED  for page 14 of 14
# == 7971_besluit_openbaarmaking_star_sat_electronica.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# ------------------------
# ENUM: 119
# NAME: Call Internet City
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5462/besluit_op_bezwaar_openbaar_call_internet_city.pdf',
#   'status': 'Tegen deze beslissing is geen beroep ingesteld. De beslissing is '
#             'thans onherroepelijk.',
#   'title': 'Besluit op bezwaar Call Internet City\xa0(1 april 2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5462/7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking BOB Call Internet City\xa0\xa0\xa0(10 april '
#            '2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5462/7970_sanctiebesluit_call_internet_city.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Call Internet City\xa0(21 november\xa02013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5462/7970_besluit_openbaarmaking_call_internet_city.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking Call Internet City\xa0(21 november 2013)'}]
# == besluit_op_bezwaar_openbaar_call_internet_city.pdf ==
#      OCR - CACHED  for page 1 of 9
#      OCR - CACHED  for page 2 of 9
#      OCR - CACHED  for page 3 of 9
#      OCR - CACHED  for page 4 of 9
#      OCR - CACHED  for page 5 of 9
#      OCR - CACHED  for page 6 of 9
#      OCR - CACHED  for page 7 of 9
#      OCR - CACHED  for page 8 of 9
#      OCR - CACHED  for page 9 of 9
# == 7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 7970_sanctiebesluit_call_internet_city.pdf ==
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == 7970_besluit_openbaarmaking_call_internet_city.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# ------------------------
# ENUM: 120
# NAME: Huizenloterij
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_020_754_kennisgeving_als_bedoeld_in_art_5_50_lid_2_sub_a_awb_openbaar.pdf',
#   'title': 'Beslissing huizenloterij (1571 kB)\xa0(14 januari 2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_020_755_besluit_tot_openbaarmaking_openbaar.pdf',
#   'title': 'Besluit\xa0openbaarmaking huizenloteij (243 kB)\xa0(14 januari '
#            '2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_026_508_en_8140_-_00_026_510_besluit_op_bezwaar_openbaar1.pdf',
#   'status': 'In deze zaak is beroep ingesteld en de rechtbank heeft uitspraak '
#             'gedaan op 17 februari 2015. Het beroep is ongegrond verklaard.',
#   'title': 'Besluit op bezwaar huizenloterij (1076 kB)\xa0(30 april 2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_025_509_en_8140_-_00_026_511_besluit_openbaarmaking_bob_openbaar1.pdf',
#   'status': 'Het hoger beroep tegen de uitspraak van de rechtbank is '
#             'ingetrokken. De uitspraak van de rechtbank is thans definitief.',
#   'title': 'Besluit openbaarmaking BOB\xa0(191 kB)\xa0(30 april 2014)'}]
# == 7982_-_00_020_754_kennisgeving_als_bedoeld_in_art_5_50_lid_2_sub_a_awb_openbaar.pdf ==
#      OCR - CACHED  for page 1 of 26
#      OCR - CACHED  for page 2 of 26
#      OCR - CACHED  for page 3 of 26
#      OCR - CACHED  for page 4 of 26
#      OCR - CACHED  for page 5 of 26
#      OCR - CACHED  for page 6 of 26
#      OCR - CACHED  for page 7 of 26
#      OCR - CACHED  for page 8 of 26
#      OCR - CACHED  for page 9 of 26
#      OCR - CACHED  for page 10 of 26
#      OCR - CACHED  for page 11 of 26
#      OCR - CACHED  for page 12 of 26
#      OCR - CACHED  for page 13 of 26
#      OCR - CACHED  for page 14 of 26
#      OCR - CACHED  for page 15 of 26
#      OCR - CACHED  for page 16 of 26
#      OCR - CACHED  for page 17 of 26
#      OCR - CACHED  for page 18 of 26
#      OCR - CACHED  for page 19 of 26
#      OCR - CACHED  for page 20 of 26
#      OCR - CACHED  for page 21 of 26
#      OCR - CACHED  for page 22 of 26
#      OCR - CACHED  for page 23 of 26
#      OCR - CACHED  for page 24 of 26
#      OCR - CACHED  for page 25 of 26
#      OCR - CACHED  for page 26 of 26
# == 7982_-_00_020_755_besluit_tot_openbaarmaking_openbaar.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 7982_-_00_026_508_en_8140_-_00_026_510_besluit_op_bezwaar_openbaar1.pdf ==
#      OCR - CACHED  for page 1 of 15
#      OCR - CACHED  for page 2 of 15
#      OCR - CACHED  for page 3 of 15
#      OCR - CACHED  for page 4 of 15
#      OCR - CACHED  for page 5 of 15
#      OCR - CACHED  for page 6 of 15
#      OCR - CACHED  for page 7 of 15
#      OCR - CACHED  for page 8 of 15
#      OCR - CACHED  for page 9 of 15
#      OCR - CACHED  for page 10 of 15
#      OCR - CACHED  for page 11 of 15
#      OCR - CACHED  for page 12 of 15
#      OCR - CACHED  for page 13 of 15
#      OCR - CACHED  for page 14 of 15
#      OCR - CACHED  for page 15 of 15
# == 7982_-_00_025_509_en_8140_-_00_026_511_besluit_openbaarmaking_bob_openbaar1.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3

# %%
# A case now looks like:
extracted_cases[0]
# Out:
# ({'name': 'Hillside New Media Malta Plc',
#   'date_range': [],
#   'money': [],
#   'ecli': [],
#   'case_detail_url': 'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/hillside-new-media-malta-plc/'},
#  [{'title': 'Beslissing op bezwaar Hillside',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15402_01-304-549_beslissing_op_bezwaar.pdf',
#    'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep worden ingesteld bij de rechtbank.'},
#   {'title': 'Advies BAC\xa0Hillside',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15402_bac_advies_hillside.pdf'},
#   {'title': 'Openbaarmakingsbesluit Hillside',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15402_01-304-539_openbaarmakingsbesluit_woo_bob.pdf',
#    'status': 'Tegen dit openbaarmakingsbesluit kan bezwaar worden gemaakt.'},
#   {'title': 'Sanctiebesluit Hillside',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15402_01-285-941_besluit-signed_openbare_versie.pdf'}],
#  [[[([(901, 195), (1147, 195), (1147, 235), (901, 235)],
#      'Kansspelautoriteit',
#      0.9960750515832989),
#     ([(194, 372), (354, 372), (354, 404), (194, 404)],
#      'OPENBAAR',
#      0.9986728101627489),
#     ([(195, 496), (1407, 496), (1407, 535), (195, 535)],
#      'Besluit van de raad van bestuur van de Kansspelautoriteit op de bezwaarschriften van',
#      0.8473283408133617),
#     ([(195, 537), (1399, 537), (1399, 577), (195, 577)],
#      'Hillside New Media Malta Plc tegen het besluit van 21 februari 2023 tot oplegging van',
#      0.7656150902015025),
#     ([(193, 579), (731, 579), (731, 617), (193, 617)],
#      'een bestuurlijke boete van € 400.000,',
#      0.9018066623784328),
#     ([(753, 579), (895, 579), (895, 617), (753, 617)],
#      '(kenmerk',
#      0.9771388067049551),
#     ([(903, 585), (917, 585), (917, 607), (903, 607)],
#      '1',
#      0.9999438532127591),
#     ([(914, 577), (1369, 577), (1369, 617), (914, 617)],
#      '5402/01.285.941) en tegen het',
#      0.798548610925524),
#     ([(195, 619), (1437, 619), (1437, 661), (195, 661)],
#      'besluit van 24 februari 2023 (kenmerk 15402/01.285.943) tot openbaarmaking van het',
#      0.5851906600990795),
#     ([(194, 664), (398, 664), (398, 696), (194, 696)],
#      'sanctiebesluit.',
#      0.9942535701184224),
#     ([(196, 748), (282, 748), (282, 780), (196, 780)],
#      'Zaak:',
#      0.9999907237043121),
#     ([(396, 748), (548, 748), (548, 778), (396, 778)],
#      '15402.001',
#      0.8568043940809004),
#     ([(196, 790), (338, 790), (338, 820), (196, 820)],
#      'Kenmerk:',
#      0.9849253712952847),
#     ([(396, 790), (726, 790), (726, 820), (396, 820)],
#      '15402.001/01.304.536',
#      0.9222873734061959),
#     ([(193, 829), (877, 829), (877, 867), (193, 867)],
#      'Openbaarmaking onder: 15402.001/01.304.549',
#      0.5701553469847206),
#     ([(452, 948), (840, 948), (840, 1028), (452, 1028)],
#      'Besluit op',
#      0.9426487582506258),
#     ([(857, 953), (1187, 953), (1187, 1019), (857, 1019)],
#      'bezwaar',
#      0.999953275666825),
#     ([(251, 1089), (460, 1089), (460, 1152), (251, 1152)],
#      'Inleiding',
#      0.9943914484504963),
#     ([(197, 1195), (217, 1195), (217, 1219), (197, 1219)],
#      '1',
#      0.9999821186865034),
#     ([(243, 1189), (1385, 1189), (1385, 1230), (243, 1230)],
#      'Op 6 april 2023 is door Hillside bezwaar gemaakt tegen de besluiten van de raad',
#      0.5241977207744515),
#     ([(245, 1233), (1443, 1233), (1443, 1271), (245, 1271)],
#      'van bestuur van de Kansspelautoriteit van 21 februari 2023 en 24 februari 2023 met',
#      0.7811347055309114),
#     ([(246, 1275), (676, 1275), (676, 1308), (246, 1308)],
#      'kenmerken 15402/01.285.941',
#      0.8153815507826181),
#     ([(683, 1274), (1431, 1274), (1431, 1313), (683, 1313)],
#      'en 15402/01.285.943. Bij brief van 24 mei 2023 zijn',
#      0.6068091987488379),
#     ([(243, 1313), (815, 1313), (815, 1356), (243, 1356)],
#      'de gronden van het bezwaar aangevuld.',
#      0.8343192793992422),
#     ([(194, 1402), (220, 1402), (220, 1430), (194, 1430)], '2', 1.0),
#     ([(245, 1396), (1389, 1396), (1389, 1439), (245, 1439)],
#      'De raad van bestuur verwijst voor een uitgebreide beschrijving van de procedure',
#      0.8824720517076718),
#     ([(246, 1441), (1405, 1441), (1405, 1474), (246, 1474)],
#      'naar randnummers 1-12 van het advies van de Adviescommissie bezwaarschriften',
#      0.7504107932617103),
#     ([(243, 1483), (947, 1483), (947, 1521), (243, 1521)],
#      'van de Kansspelautoriteit (hierna: de commissie) .',
#      0.8589886994519902),
#     ([(196, 1588), (228, 1588), (228, 1622), (196, 1622)],
#      '2',
#      0.9999996423721633),
#     ([(254, 1580), (634, 1580), (634, 1630), (254, 1630)],
#      'Ontvankelijkheid',
#      0.9999793169743691),
#     ([(196, 1678), (222, 1678), (222, 1706), (196, 1706)],
#      '3 .',
#      0.9296696186065674),
#     ([(245, 1672), (1375, 1672), (1375, 1713), (245, 1713)],
#      'De bezwaarschriften zijn ingediend binnen zes weken na bekendmaking van het',
#      0.8840589395889341),
#     ([(243, 1712), (1329, 1712), (1329, 1756), (243, 1756)],
#      'besluit. De gronden van het bezwaar zijn binnen de daartoe gestelde termijn',
#      0.7496989371456745),
#     ([(242, 1758), (1419, 1758), (1419, 1799), (242, 1799)],
#      'aangevuld. De bezwaarschriften voldoen ook aan de overige door de Algemene wet',
#      0.6591900709912788),
#     ([(243, 1796), (1171, 1796), (1171, 1839), (243, 1839)],
#      'bestuursrecht gestelde eisen zodat de bezwaren ontvankelijk zijn.',
#      0.7231003313033894),
#     ([(196, 1904), (228, 1904), (228, 1940), (196, 1940)],
#      '3',
#      0.9999995231628986),
#     ([(254, 1898), (508, 1898), (508, 1950), (254, 1950)],
#      'Hoorzitting',
#      0.9999914455530563)],
#    [([(194, 202), (354, 202), (354, 234), (194, 234)],
#      'OPENBAAR',
#      0.9986728101627489),
#     ([(881, 187), (1130, 187), (1130, 235), (881, 235)],
#      'Kansspelautoriteit',
#      0.9999906714487399),
#     ([(1316, 210), (1508, 210), (1508, 234), (1316, 234)],
#      'Kansspelautoriteit',
#      0.9999987074957091),
#     ([(1316, 244), (1388, 244), (1388, 268), (1316, 268)],
#      'Datum',
#      0.9999790483521992),
#     ([(1316, 276), (1492, 276), (1492, 300), (1316, 300)],
#      '12 december 2023',
#      0.8314324745288285),
#     ([(1316, 310), (1456, 310), (1456, 334), (1316, 334)],
#      'Ons kenmerk',
#      0.9912756359671162),
#     ([(1317, 345), (1533, 345), (1533, 365), (1317, 365)],
#      '15402.001/01.304.536',
#      0.46171987524565694),
#     ([(197, 411), (217, 411), (217, 433), (197, 433)], '4', 1.0),
#     ([(245, 401), (1313, 401), (1313, 446), (245, 446)],
#      'Bezwaarmaker heeft geen gebruik gemaakt om tijdens een hoorzitting haar',
#      0.8225245545259251),
#     ([(243, 443), (809, 443), (809, 487), (243, 487)],
#      'bezwaarschrift mondeling toe te lichten.',
#      0.7089480503134863),
#     ([(198, 552), (228, 552), (228, 584), (198, 584)],
#      '4',
#      0.9999982118614561),
#     ([(257, 547), (407, 547), (407, 589), (257, 589)],
#      'Advies',
#      0.9997442015492819),
#     ([(196, 642), (220, 642), (220, 670), (196, 670)],
#      '5',
#      0.9999991655351472),
#     ([(245, 636), (1351, 636), (1351, 679), (245, 679)],
#      'Naar aanleiding van de bezwaarschriften heeft de adviescommissie een advies',
#      0.744192479446014),
#     ([(243, 680), (1389, 680), (1389, 719), (243, 719)],
#      'uitgebracht aan de raad van bestuur. Dit advies is bij deze beslissing op bezwaar',
#      0.728664994853797),
#     ([(242, 719), (1263, 719), (1263, 764), (242, 764)],
#      'gevoegd en maakt integraal onderdeel uit van de beslissing op bezwaar .',
#      0.9670939832920529),
#     ([(196, 808), (220, 808), (220, 836), (196, 836)],
#      '6',
#      0.9969314885813375),
#     ([(245, 803), (1413, 803), (1413, 846), (245, 846)],
#      'De adviescommissie heeft geadviseerd om de bezwaren ongegrond te verklaren en',
#      0.8675806951394983),
#     ([(244, 850), (1256, 850), (1256, 882), (244, 882)],
#      'de besluiten van 21 februari 2023 en 24 februari 2023 in stand te laten.',
#      0.5536284109305529),
#     ([(196, 952), (228, 952), (228, 988), (196, 988)],
#      '5',
#      0.9313814855433281),
#     ([(252, 946), (732, 946), (732, 998), (252, 998)],
#      'Overige opmerkingen',
#      0.984353733701502),
#     ([(196, 1044), (220, 1044), (220, 1070), (196, 1070)],
#      '7',
#      0.9999995231628986),
#     ([(245, 1040), (1243, 1040), (1243, 1079), (245, 1079)],
#      'De commissie ziet geen aanleiding voor een vergoeding van de kosten.',
#      0.7890750682583837),
#     ([(200, 1144), (224, 1144), (224, 1176), (200, 1176)],
#      '6',
#      0.9989892415526391),
#     ([(255, 1139), (413, 1139), (413, 1181), (255, 1181)],
#      'Besluit',
#      0.999995989935413),
#     ([(195, 1231), (867, 1231), (867, 1269), (195, 1269)],
#      'De raad van bestuur van de Kansspelautoriteit:',
#      0.8359389197405807),
#     ([(257, 1323), (277, 1323), (277, 1345), (257, 1345)],
#      'a',
#      0.9943755304711885),
#     ([(303, 1311), (1283, 1311), (1283, 1353), (303, 1353)],
#      'stelt vast dat de adviescommissie heeft geadviseerd om de bezwaren',
#      0.9864658441240284),
#     ([(302, 1356), (651, 1356), (651, 1396), (302, 1396)],
#      'ongegrond te verklaren;',
#      0.9999912503334736),
#     ([(254, 1400), (280, 1400), (280, 1428), (254, 1428)],
#      'b',
#      0.9991595127690402),
#     ([(303, 1398), (1369, 1398), (1369, 1437), (303, 1437)],
#      'stelt vast dat het advies inhoudelijk concludent is en zorgvuldig tot stand is',
#      0.6390654012350474),
#     ([(302, 1437), (453, 1437), (453, 1479), (302, 1479)],
#      'gekomen;',
#      0.9999943523156936),
#     ([(255, 1489), (275, 1489), (275, 1511), (255, 1511)],
#      'C',
#      0.49575875850863227),
#     ([(303, 1477), (983, 1477), (983, 1522), (303, 1522)],
#      'ziet geen reden om af te wijken van het advies;',
#      0.7663253742620257),
#     ([(254, 1526), (284, 1526), (284, 1554), (254, 1554)],
#      'd.',
#      0.9991417451959106),
#     ([(303, 1522), (1215, 1522), (1215, 1564), (303, 1564)],
#      'verklaart de bezwaren ongegrond en handhaaft de besluiten van',
#      0.7034054258618538),
#     ([(303, 1563), (847, 1563), (847, 1601), (303, 1601)],
#      '21 februari 2023 en 24 februari 2023;',
#      0.6325103191142508),
#     ([(257, 1613), (277, 1613), (277, 1635), (257, 1635)],
#      'e',
#      0.9993426688247133),
#     ([(303, 1602), (1411, 1602), (1411, 1645), (303, 1645)],
#      'verwijst overeenkomstig artikel 3:49 van de Algemene wet bestuursrecht voor',
#      0.9035215757012848),
#     ([(303, 1644), (1145, 1644), (1145, 1687), (303, 1687)],
#      'de motivering van het besluit naar het uitgebrachte advies;',
#      0.8516500597459418),
#     ([(257, 1695), (271, 1695), (271, 1717), (257, 1717)],
#      'f',
#      0.9999465949513251),
#     ([(305, 1689), (1021, 1689), (1021, 1729), (305, 1729)],
#      'wijst het verzoek om vergoeding van de kosten af.',
#      0.8565239593288768),
#     ([(192, 1789), (687, 1789), (687, 1832), (192, 1832)],
#      "'s-Gravenhage, 12 december 2023",
#      0.8860376200860217),
#     ([(195, 1906), (865, 1906), (865, 1945), (195, 1945)],
#      'De raad van bestuur van de Kansspelautoriteit,',
#      0.5830266164483562),
#     ([(196, 1996), (254, 1996), (254, 2028), (196, 2028)],
#      'W.g-',
#      0.8686829209327698)],
#    [([(194, 202), (354, 202), (354, 234), (194, 234)],
#      'OPENBAAR',
#      0.9986728101627489),
#     ([(881, 187), (1130, 187), (1130, 235), (881, 235)],
#      'Kansspelautoriteit',
#      0.9999906714487399),
#     ([(1316, 210), (1508, 210), (1508, 234), (1316, 234)],
#      'Kansspelautoriteit',
#      0.9999987074957091),
#     ([(1316, 244), (1388, 244), (1388, 268), (1316, 268)],
#      'Datum',
#      0.9999790483521992),
#     ([(1316, 276), (1492, 276), (1492, 300), (1316, 300)],
#      '12 december 2023',
#      0.8314324745288285),
#     ([(1316, 310), (1456, 310), (1456, 334), (1316, 334)],
#      'Ons kenmerk',
#      0.9912756359671162),
#     ([(1317, 345), (1533, 345), (1533, 365), (1317, 365)],
#      '15402.001/01.304.536',
#      0.46171987524565694),
#     ([(194, 450), (248, 450), (248, 480), (194, 480)],
#      'drs.',
#      0.9983910918235779),
#     ([(260, 449), (498, 449), (498, 482), (260, 482)],
#      'René J.P . Jansen',
#      0.6371952939430315),
#     ([(196, 492), (340, 492), (340, 522), (196, 522)],
#      'Voorzitter',
#      0.9999823575790914),
#     ([(198, 572), (731, 572), (731, 611), (198, 611)],
#      'Verzonden op: 15 december 2023',
#      0.9122037840415096),
#     ([(194, 696), (311, 696), (311, 735), (194, 735)],
#      'Beroep',
#      0.9999658843101555),
#     ([(195, 738), (1417, 738), (1417, 780), (195, 780)],
#      'Tegen dit besluit kan een belanghebbende beroep instellen bij de sector bestuursrecht',
#      0.6248764311872733),
#     ([(198, 782), (510, 782), (510, 814), (198, 814)],
#      'van de rechtbank Den',
#      0.729607876748073),
#     ([(605, 779), (1023, 779), (1023, 817), (605, 817)],
#      'Postbus 20302, 2500 EH Den',
#      0.9661002778323514),
#     ([(197, 862), (1325, 862), (1325, 904), (197, 904)],
#      'Het beroepschrift moet binnen zes weken na de dag van bekendmaking door de',
#      0.7572779346798423),
#     ([(195, 905), (1355, 905), (1355, 946), (195, 946)],
#      'rechtbank zijn ontvangen. Het beroepschrift moet op grond van artikel 6:5 van de',
#      0.708705353610441),
#     ([(197, 949), (889, 949), (889, 985), (197, 985)],
#      'Algemene wet bestuursrecht zijn ondertekend en',
#      0.995823921422615),
#     ([(896, 950), (1392, 950), (1392, 980), (896, 980)],
#      'moet ten minste bevatten de naam',
#      0.9433057720215461),
#     ([(1398, 954), (1436, 954), (1436, 978), (1398, 978)],
#      'en',
#      0.9999976397772992),
#     ([(195, 987), (1415, 987), (1415, 1029), (195, 1029)],
#      'adres van de indiener; de dagtekening; de omschrijving van het besluit waartegen het',
#      0.5802337819094107),
#     ([(195, 1030), (445, 1030), (445, 1069), (195, 1069)],
#      'beroep is gericht;',
#      0.7580550380709166),
#     ([(450, 1038), (486, 1038), (486, 1062), (450, 1062)],
#      'ZO',
#      0.4888298839412345),
#     ([(491, 1029), (1401, 1029), (1401, 1069), (491, 1069)],
#      'mogelijk een afschrift van dit besluit, en de gronden waarop het',
#      0.8369495001087237),
#     ([(195, 1073), (455, 1073), (455, 1111), (195, 1111)],
#      'beroepschrift rust.',
#      0.9902606526000203),
#     ([(198, 1149), (1434, 1149), (1434, 1197), (198, 1197)],
#      'Van de indiener van het beroepschrift wordt griffierecht geheven door de griffier van de',
#      0.619984814800617),
#     ([(195, 1198), (953, 1198), (953, 1238), (195, 1238)],
#      'rechtbank. Nadere informatie over de hoogte van het',
#      0.9287168120349598),
#     ([(949, 1192), (1339, 1192), (1339, 1237), (949, 1237)],
#      'griffierecht en de wijze van',
#      0.8653757892121177),
#     ([(196, 1242), (512, 1242), (512, 1272), (196, 1272)],
#      'betalen wordt door de',
#      0.9592831849265733),
#     ([(510, 1235), (997, 1235), (997, 1280), (510, 1280)],
#      'griffie van de rechtbank verstrekt.',
#      0.728238741759959),
#     ([(195, 1322), (1219, 1322), (1219, 1361), (195, 1361)],
#      'Er kan ook digitaal beroep worden ingesteld bij genoemde rechtbank via',
#      0.7313270796366164),
#     ([(195, 1363), (787, 1363), (787, 1404), (195, 1404)],
#      'http:/ /loket.rechtspraak.nl/bestuursrecht.',
#      0.6982524173292376),
#     ([(794, 1366), (1412, 1366), (1412, 1398), (794, 1398)],
#      'Daarvoor moet de indiener beschikken over',
#      0.8234080846721256),
#     ([(195, 1407), (761, 1407), (761, 1445), (195, 1445)],
#      'een elektronische handtekening (DigiD).',
#      0.8093734186692225),
#     ([(771, 1404), (1373, 1404), (1373, 1445), (771, 1445)],
#      'Kijk op de genoemde site voor de precieze',
#      0.9988219132118118),
#     ([(198, 1450), (386, 1450), (386, 1480), (198, 1480)],
#      'voorwaarden.',
#      0.9640105035080605),
#     ([(517, 779), (602, 790), (597, 820), (512, 809)],
#      'Haag,',
#      0.9939462265162611),
#     ([(1027, 777), (1113, 790), (1108, 821), (1021, 809)],
#      'Haag.',
#      0.8552304291213106)]],
#   [[([(194, 102), (354, 102), (354, 132), (194, 132)],
#      'OPENBAAR',
#      0.9998400474109437),
#     ([(195, 199), (489, 199), (489, 237), (195, 237)],
#      'Kansspelautoriteit',
#      0.9999979769489769),
#     ([(195, 237), (749, 237), (749, 273), (195, 273)],
#      'Adviescommissie bezwaarschriften',
#      0.9920952871230722),
#     ([(195, 315), (1439, 315), (1439, 353), (195, 353)],
#      'Advies inzake het bezwaar van Hillside New Media Malta Plc tegen het sanctiebesluit van',
#      0.9287727753798588),
#     ([(195, 351), (674, 351), (674, 389), (195, 389)],
#      '21 februari 2023, kenmerk 15402',
#      0.879800093743151),
#     ([(701, 355), (1415, 355), (1415, 393), (701, 393)],
#      '01.285.941, tot het opleggen van een bestuurlijke',
#      0.6947684139042533),
#     ([(195, 393), (1411, 393), (1411, 431), (195, 431)],
#      'boete van € 400.000,- , en inzake het bezwaar tegen het besluit van 24 februari 2023,',
#      0.5917859258887866),
#     ([(195, 429), (1243, 429), (1243, 471), (195, 471)],
#      'kenmerk 15402 / 01.285.943, tot openbaarmaking van het sanctiebesluit.',
#      0.8106946240839271),
#     ([(196, 512), (222, 512), (222, 540), (196, 540)],
#      '1_',
#      0.5260258670566659),
#     ([(292, 507), (577, 507), (577, 547), (292, 547)],
#      'Procedureverloop',
#      0.999969630972348),
#     ([(196, 590), (220, 590), (220, 618), (196, 618)],
#      '1 _',
#      0.5313097348238143),
#     ([(243, 586), (1391, 586), (1391, 625), (243, 625)],
#      'Uit de stukken is de Adviescommissie bezwaarschriften van de Kansspelautoriteit',
#      0.8599825075124774),
#     ([(243, 627), (577, 627), (577, 663), (243, 663)],
#      '(hierna: de commissie)',
#      0.9665243598496457),
#     ([(604, 626), (785, 626), (785, 666), (604, 666)],
#      'samengevat',
#      0.9999666375772989),
#     ([(813, 622), (1143, 622), (1143, 666), (813, 666)],
#      'het volgende gebleken.',
#      0.9985204318748124),
#     ([(196, 706), (220, 706), (220, 734), (196, 734)],
#      '2',
#      0.9999996423721633),
#     ([(245, 700), (1437, 700), (1437, 744), (245, 744)],
#      'De Kansspelautoriteit is ambtshalve een onderzoek gestart naar de naleving van het',
#      0.739845477447481),
#     ([(243, 739), (1337, 739), (1337, 782), (243, 782)],
#      'verbod om kansspelreclame te richten op minderjarigen en jongvolwassenen.',
#      0.8613329580527201),
#     ([(1354, 744), (1396, 744), (1396, 774), (1354, 774)],
#      'De',
#      0.9999827198358404),
#     ([(241, 775), (1445, 775), (1445, 823), (241, 823)],
#      'bevindingen van dit onderzoek zijn weergegeven in het rapport en het sanctiebesluit.',
#      0.959412117101788),
#     ([(196, 862), (220, 862), (220, 890), (196, 890)],
#      '3 _',
#      0.5451779961585999),
#     ([(243, 857), (1317, 857), (1317, 897), (243, 897)],
#      'Op 22 april 2022 hebben toezichthouders van de Kansspelautoriteit (hierna:',
#      0.8466084618095994),
#     ([(240, 894), (1421, 894), (1421, 937), (240, 937)],
#      'toezichthouders) een informatieverzoek gestuurd naar Hillside New Media Malta Plc',
#      0.9483834725954454),
#     ([(243, 935), (491, 935), (491, 973), (243, 973)],
#      '(hierna: Hillside) .',
#      0.607912216596915),
#     ([(196, 1014), (220, 1014), (220, 1040), (196, 1040)],
#      '4 ',
#      0.8122370163227961),
#     ([(243, 1010), (1437, 1010), (1437, 1051), (243, 1051)],
#      'Op 10 mei 2022 heeft Hillside schriftelijk gereageerd op het informatieverzoek en de',
#      0.8632072981096679),
#     ([(241, 1046), (730, 1046), (730, 1094), (241, 1094)],
#      'gevraagde gegevens aangeleverd .',
#      0.9077248359986684),
#     ([(196, 1130), (222, 1130), (222, 1158), (196, 1158)],
#      '5.',
#      0.9997741846540945),
#     ([(243, 1126), (1417, 1126), (1417, 1168), (243, 1168)],
#      'Op 20 oktober 2022 hebben toezichthouders van de Kansspelautoriteit een rapport',
#      0.5875071659085565),
#     ([(242, 1164), (1439, 1164), (1439, 1207), (242, 1207)],
#      'opgesteld. In het rapport is geconstateerd dat Hillside artikel 2, vierde lid, aanhef en',
#      0.6448998236949753),
#     ([(242, 1203), (365, 1203), (365, 1242), (242, 1242)],
#      'onder a,',
#      0.9729579400687564),
#     ([(372, 1208), (588, 1208), (588, 1238), (372, 1238)],
#      'van het Besluit',
#      0.8096554773531133),
#     ([(589, 1201), (1343, 1201), (1343, 1246), (589, 1246)],
#      'werving, reclame en verslavingspreventie kansspelen',
#      0.7732699998192623),
#     ([(243, 1244), (1291, 1244), (1291, 1286), (243, 1286)],
#      '(hierna: Bwrvk) heeft overtreden. Het rapport is toegezonden aan Hillside.',
#      0.794821242017766),
#     ([(194, 1322), (220, 1322), (220, 1350), (194, 1350)],
#      '6 ',
#      0.3921270567917712),
#     ([(245, 1317), (1457, 1317), (1457, 1359), (245, 1359)],
#      'Bij brief van 27 oktober 2022 is Hillside in de gelegenheid gesteld om een schriftelijke',
#      0.6956242809429348),
#     ([(240, 1352), (1436, 1352), (1436, 1400), (240, 1400)],
#      'en/of mondelinge zienswijze te geven op het rapport. Bij brief van 2 december 2022',
#      0.736804656073846),
#     ([(241, 1396), (1301, 1396), (1301, 1438), (241, 1438)],
#      'is namens Hillside een schriftelijke zienswijze op het rapport ingediend. Op',
#      0.955548457713673),
#     ([(244, 1429), (1459, 1429), (1459, 1477), (244, 1477)],
#      '15 december 2022 is Hillside in de gelegenheid gesteld om haar zienswijze mondeling',
#      0.9270476750760263),
#     ([(241, 1471), (763, 1471), (763, 1513), (241, 1513)],
#      'toe te lichten tijdens een hoorzitting .',
#      0.7239264032774991),
#     ([(196, 1556), (220, 1556), (220, 1582), (196, 1582)],
#      '7 ',
#      0.7865924942781458),
#     ([(243, 1548), (1321, 1548), (1321, 1591), (243, 1591)],
#      'Op 18 januari 2023 is het verslag van de hoorzitting per e-mail naar Hillside',
#      0.654032456877212),
#     ([(243, 1590), (1453, 1590), (1453, 1629), (243, 1629)],
#      'verzonden. Op 25 januari 2023 heeft Hillside haar opmerkingen over het verslag naar',
#      0.7803381111035511),
#     ([(243, 1626), (693, 1626), (693, 1669), (243, 1669)],
#      'de Kansspelautoriteit gezonden.',
#      0.9866000508078068),
#     ([(194, 1710), (220, 1710), (220, 1738), (194, 1738)],
#      '8',
#      0.9999986886982448),
#     ([(243, 1706), (1319, 1706), (1319, 1744), (243, 1744)],
#      'In het sanctiebesluit van 21 februari 2023 heeft de raad van bestuur van de',
#      0.7988724722100767),
#     ([(245, 1746), (1425, 1746), (1425, 1785), (245, 1785)],
#      'Kansspelautoriteit (hierna: de raad van bestuur) aan Hillside een bestuurlijke boete',
#      0.7470987538909435),
#     ([(243, 1785), (605, 1785), (605, 1823), (243, 1823)],
#      'opgelegd van € 400.000,',
#      0.8696969205535867),
#     ([(617, 1781), (1411, 1781), (1411, 1823), (617, 1823)],
#      'vanwege overtreding van artikel 2, vierde lid, aanhef en',
#      0.8510936373415378),
#     ([(243, 1823), (585, 1823), (585, 1859), (243, 1859)],
#      'onder a, van het Bwrvk.',
#      0.8078535664787776),
#     ([(194, 1904), (218, 1904), (218, 1932), (194, 1932)],
#      '9',
#      0.9999989271166818),
#     ([(243, 1901), (1365, 1901), (1365, 1941), (243, 1941)],
#      'In het openbaarmakingsbesluit van 24 februari 2023 heeft de raad van bestuur',
#      0.6335359737622082),
#     ([(243, 1941), (1432, 1941), (1432, 1979), (243, 1979)],
#      'besloten om het sanctiebesluit van 21 februari 2023 en het openbaarmakingsbesluit',
#      0.7432277305949414),
#     ([(241, 1976), (527, 1976), (527, 2020), (241, 2020)],
#      'openbaar te maken.',
#      0.9842377911412247),
#     ([(212, 2116), (716, 2116), (716, 2144), (212, 2144)],
#      'Artikel 2, derde en vierde lid, van het Bwrvk',
#      0.7512634693596107)],
#    [([(194, 102), (354, 102), (354, 132), (194, 132)],
#      'OPENBAAR',
#      0.9998400474109437),
#     ([(195, 198), (1425, 198), (1425, 237), (195, 237)],
#      '10. Bij brief en e-mail van 6 april 2023 heeft Hillside pro forma bezwaar gemaakt tegen',
#      0.7224797303765255),
#     ([(243, 235), (1043, 235), (1043, 278), (243, 278)],
#      'het sanctiebesluit en tegen het openbaarmakingsbesluit.',
#      0.8265956046157652),
#     ([(195, 312), (1416, 312), (1416, 351), (195, 351)],
#      '11. Bij brief en e-mail van 13 april 2023 is aan Hillside uitstel verleend tot het indienen',
#      0.6186489311253435),
#     ([(243, 348), (1443, 348), (1443, 389), (243, 389)],
#      'van de aanvullende gronden. Bij brief van 24 mei 2023 heeft Hillside de gronden van',
#      0.7898970475148697),
#     ([(243, 388), (527, 388), (527, 431), (243, 431)],
#      'bezwaar aangevuld.',
#      0.939936474789216),
#     ([(195, 460), (1433, 460), (1433, 503), (195, 503)],
#      '12. Hillside is in de gelegenheid gesteld om tijdens een hoorzitting op 30 juni 2023 haar',
#      0.5820388751178992),
#     ([(241, 497), (1427, 497), (1427, 545), (241, 545)],
#      'bezwaarschrift mondeling toe te lichten. Zij heeft van die gelegenheid geen gebruik',
#      0.8449486113360671),
#     ([(242, 540), (381, 540), (381, 581), (242, 581)],
#      'gemaakt.',
#      0.9162114315114117),
#     ([(196, 626), (220, 626), (220, 654), (196, 654)],
#      '2',
#      0.9999988079074598),
#     ([(294, 622), (953, 622), (953, 662), (294, 662)],
#      'Bezwaargronden tegen het sanctiebesluit',
#      0.699441733761971),
#     ([(196, 694), (596, 694), (596, 726), (196, 726)],
#      '13.In bezwaar heeft Hillside',
#      0.8652561049486454),
#     ([(625, 695), (807, 695), (807, 731), (625, 731)],
#      'samengevat',
#      0.9999726692496433),
#     ([(835, 689), (1327, 689), (1327, 731), (835, 731)],
#      'het volgende naar voren gebracht:',
#      0.9446309682365394),
#     ([(294, 776), (318, 776), (318, 800), (294, 800)],
#      'a',
#      0.9733039010859699),
#     ([(343, 766), (1377, 766), (1377, 809), (343, 809)],
#      'Volgens Hillside is het verzenden van reclame in de vorm van inhoudelijk',
#      0.7306374499672895),
#     ([(342, 805), (1329, 805), (1329, 848), (342, 848)],
#      'generieke emailberichten aan jongvolwassenen als onderdeel van een',
#      0.9867395557909497),
#     ([(340, 842), (1459, 842), (1459, 891), (340, 891)],
#      'generieke mailingcampagne aan alle ingeschreven, gecontroleerde en opted-in',
#      0.70431586564406),
#     ([(341, 883), (1435, 883), (1435, 927), (341, 927)],
#      'spelers geen overtreding van artikel 2, vierde lid, aanhef en onder a, van het',
#      0.8172948014312753),
#     ([(345, 928), (441, 928), (441, 958), (345, 958)],
#      'Bwrvk.',
#      0.5776512560295158),
#     ([(294, 1006), (318, 1006), (318, 1034), (294, 1034)],
#      'b',
#      0.9998530203471354),
#     ([(342, 1002), (1105, 1002), (1105, 1043), (342, 1043)],
#      'Volgens Hillside is de boeteoplegging in strijd met het',
#      0.7001074557597083),
#     ([(341, 1035), (1284, 1035), (1284, 1083), (341, 1083)],
#      'rechtszekerheidsbeginsel en het lex-certa beginsel omdat de norm',
#      0.8977962364589503),
#     ([(343, 1081), (981, 1081), (981, 1119), (343, 1119)],
#      'onvoldoende duidelijk  bepaald of kenbaar is.',
#      0.5662136901831379),
#     ([(295, 1167), (315, 1167), (315, 1189), (295, 1189)],
#      'c',
#      0.28715514050748325),
#     ([(343, 1158), (1393, 1158), (1393, 1197), (343, 1197)],
#      'Volgens Hillside is het opleggen van een bestuurlijke boete van €400.000,',
#      0.6991737443805297),
#     ([(343, 1194), (1363, 1194), (1363, 1237), (343, 1237)],
#      'niet passend en geboden. Daarom had moeten worden afgezien van het',
#      0.817814770315161),
#     ([(343, 1239), (535, 1239), (535, 1275), (343, 1275)],
#      'opleggen van',
#      0.9316112904215987),
#     ([(541, 1236), (1359, 1236), (1359, 1275), (541, 1275)],
#      'een boete, dan wel had de boetehoogte gematigd moeten',
#      0.9134012832810143),
#     ([(345, 1275), (457, 1275), (457, 1307), (345, 1307)],
#      'worden.',
#      0.9997248704922982),
#     ([(294, 1352), (318, 1352), (318, 1380), (294, 1380)],
#      'd',
#      0.9999819994782833),
#     ([(343, 1349), (1447, 1349), (1447, 1389), (343, 1389)],
#      'Volgens Hillside is het opleggen van een bestuurlijke boete onrechtmatig en is',
#      0.9423936987535951),
#     ([(342, 1386), (1271, 1386), (1271, 1427), (342, 1427)],
#      'daardoor ook het openbaarmakingsbesluit ten onrechte genomen.',
#      0.8365054631865844),
#     ([(196, 1472), (222, 1472), (222, 1500), (196, 1500)],
#      '3_',
#      0.7872612932169933),
#     ([(294, 1470), (540, 1470), (540, 1502), (294, 1502)],
#      'Juridisch kader',
#      0.9230319958020391),
#     ([(196, 1542), (342, 1542), (342, 1574), (196, 1574)],
#      '14. Artikel',
#      0.6039173577908362),
#     ([(397, 1540), (1355, 1540), (1355, 1582), (397, 1582)],
#      'tweede lid, van de Wet op de kansspelen (hierna: Wok) bepaalt dat',
#      0.7788214503482072),
#     ([(243, 1575), (1411, 1575), (1411, 1620), (243, 1620)],
#      'houders van een vergunning op grond van de Wok op zorgvuldige en evenwichtige',
#      0.8543029896270947),
#     ([(245, 1615), (1353, 1615), (1353, 1657), (245, 1657)],
#      'wijze vorm moeten geven aan wervings- en reclameactiviteiten, waarbij in het',
#      0.6816223476757647),
#     ([(242, 1654), (1001, 1654), (1001, 1698), (242, 1698)],
#      'bijzonder wordt gewaakt tegen onmatige deelneming.',
#      0.9867959349171298),
#     ([(195, 1734), (1445, 1734), (1445, 1774), (195, 1774)],
#      '15.Artikel 35a, eerste lid, van de Wok bepaalt dat de Kansspelautoriteit een bestuurlijke',
#      0.866001222166782),
#     ([(243, 1771), (1361, 1771), (1361, 1816), (243, 1816)],
#      'boete kan opleggen wegens overtreding van de voorschriften vastgesteld bij of',
#      0.8920142444830587),
#     ([(245, 1811), (1407, 1811), (1407, 1851), (245, 1851)],
#      'krachtens onder andere artikel 4a van de Wok. In het tweede lid is bepaald dat de',
#      0.7273534171523872),
#     ([(242, 1850), (1427, 1850), (1427, 1891), (242, 1891)],
#      'bestuurlijke boete die voor een overtreding als bedoeld in het eerste lid kan worden',
#      0.7151597528508634),
#     ([(243, 1887), (1460, 1887), (1460, 1930), (243, 1930)],
#      'opgelegd ten hoogste het bedrag van de zesde categorie, bedoeld in artikel 23, vierde',
#      0.7470004660596052),
#     ([(243, 1927), (1449, 1927), (1449, 1967), (243, 1967)],
#      'lid, van het Wetboek van Strafrecht of, indien dat meer is, tien procent van de omzet',
#      0.6308785889402043),
#     ([(243, 1966), (1079, 1966), (1079, 2007), (243, 2007)],
#      'in het boekjaar voorafgaande aan de beschikking bedraagt.',
#      0.8855198940417249),
#     ([(1439, 2179), (1457, 2179), (1457, 2203), (1439, 2203)],
#      '2',
#      0.9999994039536411),
#     ([(345, 1539), (399, 1547), (394, 1580), (339, 1572)],
#      '4a,',
#      0.9974088942250423)],
#    [([(194, 102), (354, 102), (354, 132), (194, 132)],
#      'OPENBAAR',
#      0.9998400474109437),
#     ([(195, 199), (1435, 199), (1435, 237), (195, 237)],
#      "16.In artikel 1, aanhef en onder e, van het Bwrvk zijn 'wervings- en reclameactiviteiten",
#      0.8308548321355373),
#     ([(242, 232), (661, 232), (661, 277), (242, 277)],
#      'gedefinieerd als: iedere vorm',
#      0.7616146971914747),
#     ([(665, 235), (1449, 235), (1449, 279), (665, 279)],
#      'van communicatie waarmee vergunninghouders  al dan',
#      0.6734065328816337),
#     ([(243, 271), (1415, 271), (1415, 315), (243, 315)],
#      'niet met behulp van derden, direct of indirect hun diensten of goederen aanprijzen .',
#      0.6601856184876291),
#     ([(195, 351), (929, 351), (929, 390), (195, 390)],
#      '17.In artikel 1, aanhef en onder f, van het Bwrvk is',
#      0.8513403958604057),
#     ([(937, 349), (1455, 349), (1455, 393), (937, 393)],
#      "bonus' gedefinieerd als: een goed of",
#      0.9337464980504359),
#     ([(243, 389), (1440, 389), (1440, 434), (243, 434)],
#      'een dienst, waaronder gratis speeltegoed, aangeboden om spelers voor de vergunde',
#      0.6372469118993851),
#     ([(243, 431), (1419, 431), (1419, 471), (243, 471)],
#      'kansspelen te werven of te behouden of om reclame voor die kansspelen te maken.',
#      0.6142608681521525),
#     ([(195, 509), (1303, 509), (1303, 547), (195, 547)],
#      '18.Artikel 2 vierde lid, onder a, van het Bwrvk bepaalt dat de houder van een',
#      0.625322386308033),
#     ([(242, 541), (1318, 541), (1318, 590), (242, 590)],
#      'vergunning tot het organiseren van kansspelen op afstand zijn wervings- en',
#      0.9417260547966263),
#     ([(243, 586), (1397, 586), (1397, 625), (243, 625)],
#      'reclameactiviteiten voor kansspelen niet richt op personen in de leeftijdscategorie',
#      0.8468470092451765),
#     ([(242, 626), (551, 626), (551, 663), (242, 663)],
#      'tussen 18 en 24 jaar.',
#      0.7997437130513823),
#     ([(195, 699), (1441, 699), (1441, 740), (195, 740)],
#      '19.Artikel 2ab, eerste lid, van het Bwrvkz bepaalt dat de houder van een vergunning tot',
#      0.7606186512094195),
#     ([(243, 735), (1318, 735), (1318, 780), (243, 780)],
#      'het organiseren van kansspelen op afstand alleen zodanig specifiek gerichte',
#      0.839216596211611),
#     ([(243, 774), (1333, 774), (1333, 819), (243, 819)],
#      'wervings- en reclameactiviteiten ontplooit voor die kansspelen dat deze geen',
#      0.8500960301826619),
#     ([(242, 817), (1347, 817), (1347, 855), (242, 855)],
#      'personen bereiken als bedoeld in artikel 2, derde en vierde lid, van het Bwrvk.',
#      0.7551398936294994),
#     ([(193, 891), (1189, 891), (1189, 934), (193, 934)],
#      '20. Artikel 12, aanhef en onder i, van de Regeling werving, reclame en',
#      0.6207527825376387),
#     ([(243, 932), (1203, 932), (1203, 974), (243, 974)],
#      'verslavingspreventie kansspelen (hierna: de Rwrvk) bepaalt dat het',
#      0.731446637733143),
#     ([(243, 971), (1459, 971), (1459, 1013), (243, 1013)],
#      'verslavingspreventiebeleid van de houder van een vergunning tot het organiseren van',
#      0.8610378847331444),
#     ([(243, 1008), (1451, 1008), (1451, 1050), (243, 1050)],
#      'een speelcasino, tot het aanwezig hebben van een of meer kansspelautomaten in een',
#      0.555283801431058),
#     ([(242, 1046), (1349, 1046), (1349, 1090), (242, 1090)],
#      'speelautomatenhal, of tot het organiseren van kansspelen op afstand, in ieder',
#      0.7002186725558902),
#     ([(243, 1089), (1175, 1089), (1175, 1127), (243, 1127)],
#      'een beschrijving bevat van de wijze waarop de implementatie van',
#      0.8088370279562525),
#     ([(242, 1120), (1434, 1120), (1434, 1169), (242, 1169)],
#      'verslavingspreventieve maatregelen en voorzieningen in zijn organisatie alsmede de',
#      0.9580111936115878),
#     ([(242, 1165), (1331, 1165), (1331, 1205), (242, 1205)],
#      'passende en effectieve toepassing van deze maatregelen en voorzieningen is',
#      0.9064165045393147),
#     ([(243, 1202), (947, 1202), (947, 1245), (243, 1245)],
#      'gewaarborgd . Bij deze beschrijving wordt in ieder',
#      0.832406765953179),
#     ([(1033, 1205), (1325, 1205), (1325, 1243), (1033, 1243)],
#      'bijzondere aandacht',
#      0.971908265218385),
#     ([(242, 1240), (1409, 1240), (1409, 1284), (242, 1284)],
#      'geschonken aan de wijze waarop de vergunninghouder voorkomt dat wervings - en',
#      0.5222965803066367),
#     ([(243, 1280), (1437, 1280), (1437, 1322), (243, 1322)],
#      'reclameactiviteiten gericht zijn op maatschappelijk kwetsbare groepen van personen',
#      0.8046882621247866),
#     ([(243, 1321), (1233, 1321), (1233, 1361), (243, 1361)],
#      'als bedoeld in artikel 2, derde lid, van het besluit en jongvolwassenen.',
#      0.6963064426505703),
#     ([(196, 1404), (220, 1404), (220, 1428), (196, 1428)],
#      '4',
#      0.9999977350247811),
#     ([(293, 1397), (813, 1397), (813, 1439), (293, 1439)],
#      'Overwegingen van de commissie',
#      0.9354939647109194),
#     ([(246, 1480), (304, 1480), (304, 1508), (246, 1508)],
#      '4.1.',
#      0.9408402579164331),
#     ([(345, 1477), (1193, 1477), (1193, 1515), (345, 1515)],
#      'Ten aanzien van de ontvankelijkheid van het bezwaar',
#      0.8457338881272278),
#     ([(193, 1555), (1253, 1555), (1253, 1593), (193, 1593)],
#      '21. Het bezwaarschrift is tijdig ingediend en voldoet aan alle vereisten voor',
#      0.7381605809871227),
#     ([(242, 1592), (489, 1592), (489, 1633), (242, 1633)],
#      'ontvankelijkheid.',
#      0.9986873542841647),
#     ([(246, 1674), (300, 1674), (300, 1702), (246, 1702)],
#      '4.2',
#      0.9945564866065979),
#     ([(345, 1671), (813, 1671), (813, 1707), (345, 1707)],
#      'Ten aanzien van de bezwaren',
#      0.9948510679801533),
#     ([(195, 1749), (1405, 1749), (1405, 1787), (195, 1787)],
#      '22.De commissie merkt op dat artikel 2, vierde lid, aanhef en onder a, het Bwrvk een',
#      0.8127624672502338),
#     ([(242, 1783), (1376, 1783), (1376, 1831), (242, 1831)],
#      'verbod bevat voor vergunninghouders om wervings- en reclameactiviteiten voor',
#      0.8441531750597275),
#     ([(243, 1825), (1361, 1825), (1361, 1865), (243, 1865)],
#      'kansspelen te richten op personen in de leeftijdscategorie tussen 18 en 24 jaar',
#      0.6600874398607511),
#     ([(243, 1867), (519, 1867), (519, 1905), (243, 1905)],
#      '(jongvolwassenen)',
#      0.9999633960644088),
#     ([(193, 1940), (1297, 1940), (1297, 1982), (193, 1982)],
#      '23. Niet in geschil is dat Hillside in de periode van 26 oktober 2021 tot en met',
#      0.560582265912935),
#     ([(1302, 1944), (1442, 1944), (1442, 1976), (1302, 1976)],
#      '1 februari',
#      0.9234747332689397),
#     ([(244, 1975), (1271, 1975), (1271, 2024), (244, 2024)],
#      '2022 meerdere bij haar geregistreerde jongvolwassen spelers veelvuldig',
#      0.9760088711439788),
#     ([(243, 2019), (1379, 2019), (1379, 2059), (243, 2059)],
#      'reclameberichten heeft gestuurd, in de vorm van e-mails waarin het aanbod van',
#      0.7756985193386935),
#     ([(211, 2113), (757, 2113), (757, 2149), (211, 2149)],
#      'Dit artikel is per 1 juli 2023 in werking getreden',
#      0.5749801859023272),
#     ([(1439, 2177), (1457, 2177), (1457, 2203), (1439, 2203)],
#      '3',
#      0.9999992847443906),
#     ([(1347, 1054), (1432, 1048), (1433, 1082), (1348, 1088)],
#      'geval',
#      0.9999752098767573),
#     ([(946, 1210), (1030, 1204), (1031, 1238), (946, 1244)],
#      'geval',
#      0.9501108011556485)],
#    [([(194, 102), (354, 102), (354, 132), (194, 132)],
#      'OPENBAAR',
#      0.9998400474109437),
#     ([(245, 199), (1387, 199), (1387, 237), (245, 237)],
#      'Hillside werd aangeprezen  waaronder bonussen. Bij brief van 10 mei 2022 heeft',
#      0.7567742728162263),
#     ([(245, 235), (1377, 235), (1377, 276), (245, 276)],
#      'Hillside immers erkend dat zij promotionele e-mails, waaronder bonussen, heeft',
#      0.8282600244321039),
#     ([(242, 270), (1336, 270), (1336, 318), (242, 318)],
#      'verzonden aan alle in aanmerking komende geregistreerde spelers die ervoor',
#      0.8681219078421201),
#     ([(242, 311), (885, 311), (885, 353), (242, 353)],
#      'gekozen hebben om marketing te ontvangen.',
#      0.8702093877126816),
#     ([(893, 311), (1431, 311), (1431, 353), (893, 353)],
#      'Daarmee is de overtreding van artikel',
#      0.9578536746936333),
#     ([(245, 351), (1422, 351), (1422, 393), (245, 393)],
#      '2, vierde lid, aanhef en onder a, van het Bwrvk volgens de commissie een gegeven .',
#      0.6957552461322409),
#     ([(195, 428), (1463, 428), (1463, 468), (195, 468)],
#      '24. Voordat de commissie ingaat op de door Hillside aangevoerde bezwaargronden  merkt',
#      0.5821940237187726),
#     ([(243, 466), (1457, 466), (1457, 507), (243, 507)],
#      'de commissie in algemene zin op dat Hillside onvoldoende waarde lijkt te hechten aan',
#      0.6366684394776396),
#     ([(243, 504), (1427, 504), (1427, 547), (243, 547)],
#      'de algemene eis dat een vergunninghouder bij zijn reclame- en wervingsactiviteiten',
#      0.9332503716429343),
#     ([(243, 538), (1366, 538), (1366, 587), (243, 587)],
#      'moet bijdragen aan de doelstellingen van het Nederlandse kansspelbeleid.3 Dat',
#      0.8163174270743837),
#     ([(245, 579), (1453, 579), (1453, 624), (245, 624)],
#      'Hillside bekend is met deze doelstellingen, blijkt volgens de commissie uit het feit dat',
#      0.6644238345904268),
#     ([(245, 619), (1457, 619), (1457, 661), (245, 661)],
#      'Hillside in haar bezwaarschrift meerdere keren verwijst naar de kanalisatiedoelstelling',
#      0.8945631247489435),
#     ([(245, 657), (1429, 657), (1429, 701), (245, 701)],
#      'van de Wet kansspelen op afstand, en stelt in lijn met de kanalisatiedoelstelling van',
#      0.753990121306778),
#     ([(243, 700), (1067, 700), (1067, 739), (243, 739)],
#      'de wetgever reclame te maken voor haar kansspelaanbod .',
#      0.7984208810981392),
#     ([(1077, 700), (1415, 700), (1415, 739), (1077, 739)],
#      'Daarbij lijkt Hillside een',
#      0.863042446722427),
#     ([(245, 739), (1367, 739), (1367, 779), (245, 779)],
#      'van de andere doelstellingen, te weten het beschermen van kwetsbare groepen',
#      0.7077676443269786),
#     ([(243, 776), (1391, 776), (1391, 817), (243, 817)],
#      '(waartoe jongvolwassenen onmiskenbaar behoren) tegen onmatige deelname, te',
#      0.7017351796273174),
#     ([(242, 814), (1267, 814), (1267, 857), (242, 857)],
#      'vergeten, althans minder belangrijk te vinden. Mede gelet op de recente',
#      0.9111792496163205),
#     ([(243, 850), (1458, 850), (1458, 898), (243, 898)],
#      'maatschappelijke en politieke discussies over ongerichte reclame en de zorgplicht van',
#      0.7340478761502299),
#     ([(243, 895), (1409, 895), (1409, 935), (243, 935)],
#      'aanbieders van online kansspelen  waarbij deskundigen geregeld hun zorgen uiten',
#      0.7705237318655078),
#     ([(243, 933), (1367, 933), (1367, 973), (243, 973)],
#      'over het verhoogde risico van kansspelverslaving bij jongvolwassenen, vindt de',
#      0.8085553611241368),
#     ([(243, 970), (1037, 970), (1037, 1011), (243, 1011)],
#      'commissie dat Hillside hierin ernstig tekort is geschoten.',
#      0.8593266680198292),
#     ([(1047, 973), (1453, 973), (1453, 1011), (1047, 1011)],
#      'De uitleg van Hillside dat als',
#      0.9269993572974088),
#     ([(240, 1008), (1371, 1008), (1371, 1051), (240, 1051)],
#      'jongvolwassenen hebben aangegeven dat zij mails willen ontvangen, zij die ook',
#      0.8247492333921472),
#     ([(242, 1049), (1323, 1049), (1323, 1090), (242, 1090)],
#      'ontvangen  is wat dat betreft tekenend. Daarmee heeft Hillside onterecht de',
#      0.7861665441506493),
#     ([(243, 1089), (1429, 1089), (1429, 1127), (243, 1127)],
#      'verantwoordelijkheid neergelegd bij jongvolwassenen, in plaats van deze kwetsbare',
#      0.6876762100263472),
#     ([(242, 1126), (701, 1126), (701, 1167), (242, 1167)],
#      'groep in bescherming te nemen.',
#      0.7438308033390458),
#     ([(195, 1202), (1374, 1202), (1374, 1246), (195, 1246)],
#      '25.De commissie gaat hieronder nader in op de door Hillside aangevoerde gronden.',
#      0.9636214142445332),
#     ([(245, 1280), (845, 1280), (845, 1321), (245, 1321)],
#      '4.2.1. Ten aanzien van gronden a en b',
#      0.8443745305003973),
#     ([(195, 1357), (1317, 1357), (1317, 1401), (195, 1401)],
#      '26. Hillside stelt dat er geen sprake is van een overtreding, omdat de door haar',
#      0.7392357352816716),
#     ([(243, 1395), (1313, 1395), (1313, 1440), (243, 1440)],
#      'verstuurde reclameberichten niet enkel gericht waren aan jongvolwassenen.',
#      0.7757895722875242),
#     ([(1324, 1402), (1450, 1402), (1450, 1432), (1324, 1432)],
#      'Evenmin',
#      0.9999703974907987),
#     ([(245, 1436), (1199, 1436), (1199, 1477), (245, 1477)],
#      'waren de reclameberichten qua inhoud gericht op jongvolwassenen.',
#      0.9474733163831327),
#     ([(1210, 1442), (1306, 1442), (1306, 1472), (1210, 1472)],
#      'Er was',
#      0.6647716981007571),
#     ([(1309, 1437), (1414, 1437), (1414, 1479), (1309, 1479)],
#      'sprake',
#      0.9999920186067003),
#     ([(244, 1482), (360, 1482), (360, 1510), (244, 1510)],
#      'van een',
#      0.8831403909302616),
#     ([(362, 1475), (1445, 1475), (1445, 1517), (362, 1517)],
#      'generieke mailingcampagne, waarbij de reclame weliswaar jongvolwassenen',
#      0.7665860566023046),
#     ([(243, 1511), (1443, 1511), (1443, 1555), (243, 1555)],
#      'heeft bereikt, maar waarbij de reclame zich niet heeft geconcentreerd op deze groep.',
#      0.7071322909704852),
#     ([(245, 1555), (1415, 1555), (1415, 1591), (245, 1591)],
#      'Hillside meent dat de raad van bestuur artikel 2, vierde lid, aanhef en onder a, van',
#      0.713617056694258),
#     ([(245, 1593), (1361, 1593), (1361, 1633), (245, 1633)],
#      'het Bwrvk ten onrechte als een totaalverbod interpreteert op het versturen van',
#      0.8153286755517095),
#     ([(243, 1633), (805, 1633), (805, 1671), (243, 1671)],
#      'reclameberichten aan jongvolwassenen.',
#      0.9132619380284207),
#     ([(193, 1710), (1420, 1710), (1420, 1751), (193, 1751)],
#      '27. Volgens Hillside zou de overtreden rechtsnorm  zoals vastgelegd in artikel 2, vierde',
#      0.6919745447305569),
#     ([(243, 1749), (1247, 1749), (1247, 1785), (243, 1785)],
#      'lid, aanhef en onder a, van het Bwrvk, onduidelijk zijn en verkeerd zijn',
#      0.6170085180556072),
#     ([(242, 1786), (1445, 1786), (1445, 1826), (242, 1826)],
#      'geïnterpreteerd door de raad van bestuur. Volgens Hillside is deze norm in strijd met',
#      0.8150988790438929),
#     ([(243, 1827), (1023, 1827), (1023, 1865), (243, 1865)],
#      'het rechtszekerheidsbeginsel en het lex certa-beginsel .',
#      0.9470817886924393),
#     ([(195, 1900), (1333, 1900), (1333, 1939), (195, 1939)],
#      '28. Volgens Hillside ziet de overtreden norm alleen op de inhoud en vorm van de',
#      0.6856558474975376),
#     ([(245, 1939), (1439, 1939), (1439, 1979), (245, 1979)],
#      'wervings- en reclameactiviteiten, niet op het bereik daarvan. Volgens Hillside zou de',
#      0.8569948548727174),
#     ([(243, 1979), (1272, 1979), (1272, 2019), (243, 2019)],
#      'raad van bestuur ten onrechte een ruimere uitleg van de norm hanteren.',
#      0.776049022326613),
#     ([(1280, 1982), (1382, 1982), (1382, 2012), (1280, 2012)],
#      'Dit zou',
#      0.4217788462024121),
#     ([(242, 2011), (1425, 2011), (1425, 2060), (242, 2060)],
#      'volgens Hillside onder meer blijken uit de toelichting van de wetgever bij het Bwrvk',
#      0.7671340052216096),
#     ([(210, 2113), (474, 2113), (474, 2146), (210, 2146)],
#      'Staatsblad 2021, 37, p',
#      0.9628080171477988),
#     ([(482, 2118), (520, 2118), (520, 2142), (482, 2142)],
#      '47.',
#      0.6364075676241522)],
#    [([(194, 102), (354, 102), (354, 132), (194, 132)],
#      'OPENBAAR',
#      0.9998400474109437),
#     ([(243, 197), (1391, 197), (1391, 239), (243, 239)],
#      'en de Rwrvk en uit het feit dat de Kansspelautoriteit boetes heeft opgelegd aan 4',
#      0.768788970634322),
#     ([(244, 240), (346, 240), (346, 270), (244, 270)],
#      'andere',
#      0.9999898772548426),
#     ([(347, 233), (1458, 233), (1458, 282), (347, 282)],
#      'vergunninghouders (TOTO Online BV, JOI Gaming Ltd, Betent B.V., en Bingoal',
#      0.7396048668611457),
#     ([(245, 273), (1429, 273), (1429, 316), (245, 316)],
#      'Nederland N.V.) voor vergelijkbare overtredingen. Volgens Hillside zouden ook deze',
#      0.5257863234835389),
#     ([(243, 312), (1407, 312), (1407, 352), (243, 352)],
#      'vergunninghouders de overtreden norm onduidelijk vinden en de overtreden norm',
#      0.8505610748374024),
#     ([(243, 353), (843, 353), (843, 393), (243, 393)],
#      'anders uitleggen dan de raad van bestuur.',
#      0.8662488143784497),
#     ([(851, 353), (1271, 353), (1271, 389), (851, 389)],
#      'Daaruit leidt Hillside af dat er',
#      0.8313614725972679),
#     ([(243, 393), (1429, 393), (1429, 429), (243, 429)],
#      'onduidelijkheid bestond over de reikwijdte van artikel 2, vierde lid, aanhef en onder',
#      0.7264813843600111),
#     ([(243, 431), (1007, 431), (1007, 471), (243, 471)],
#      'a, van het Bwrvkı met name over de term "gericht op\'',
#      0.543073371813817),
#     ([(193, 504), (1397, 504), (1397, 545), (193, 545)],
#      '29. Van enige onduidelijkheid over de overtreden norm is volgens de commissie geen',
#      0.7892650965968109),
#     ([(241, 544), (348, 544), (348, 585), (241, 585)],
#      'sprake.',
#      0.986257527629186),
#     ([(357, 543), (1443, 543), (1443, 585), (357, 585)],
#      'De commissie is van oordeel dat de wet- en regelgeving op dit punt duidelijk',
#      0.9445381505135766),
# ...
#      'van het',
#      0.8322662128017154),
#     ([[255, 1563], [1439, 1563], [1439, 1603], [255, 1603]],
#      'Bwrvk, een verbod op het sturen van reclameberichten aan jongvolwassenen bevat.',
#      0.8219671337406743),
#     ([[255, 1598], [1435, 1598], [1435, 1643], [255, 1643]],
#      'Zoals uitgebreid toegelicht in paragraaf 5.2 volgt de Kansspelautoriteit Hillside daar',
#      0.7591209022085351),
#     ([[254, 1642], [352, 1642], [352, 1674], [254, 1674]],
#      'niet in.',
#      0.6641095042128957),
#     ([[363, 1637], [1355, 1637], [1355, 1679], [363, 1679]],
#      'Van een vergunninghouder mag worden verwacht dat die de geldende',
#      0.7643826044675006),
#     ([[253, 1674], [1390, 1674], [1390, 1722], [253, 1722]],
#      'wettelijke regels en andere voorwaarden kent en naleeft. Hillside had kunnen en',
#      0.7364509212484831),
#     ([[255, 1719], [1411, 1719], [1411, 1755], [255, 1755]],
#      'moeten weten dat zij artikel 2, vierde lid, aanhef en onder a, van het Bwrvk heeft',
#      0.5540137370403778),
#     ([[252, 1756], [1395, 1756], [1395, 1797], [252, 1797]],
#      'overtreden door reclameberichten te versturen aan jongvolwassenen via e-mails.',
#      0.6875233900642964),
#     ([[256, 1798], [498, 1798], [498, 1828], [256, 1828]],
#      'Dit maakt dat de',
#      0.8369035273625576),
#     ([[498, 1790], [1321, 1790], [1321, 1835], [498, 1835]],
#      'overtreding niet alleen ernstig is, maar ook aan Hillside te',
#      0.8196031376576928),
#     ([[253, 1835], [425, 1835], [425, 1871], [253, 1871]],
#      'verwijten is-',
#      0.522480851865109),
#     ([[196, 1918], [244, 1918], [244, 1948], [196, 1948]],
#      '66.',
#      0.9999215393248215),
#     ([[253, 1915], [1283, 1915], [1283, 1953], [253, 1953]],
#      'Ondanks het feit dat Hillside bekend was met de leeftijd van alle bij haar',
#      0.9103721586142421),
#     ([[253, 1951], [1197, 1951], [1197, 1994], [253, 1994]],
#      'geregistreerde spelers en ondanks het feit dat het verwijderen van',
#      0.7357432881984877),
#     ([[215, 2062], [757, 2062], [757, 2099], [215, 2099]],
#      'Kamerstukken II 2021/22, 24 557, nr.',
#      0.6657663655446661),
#     ([[766, 2064], [826, 2064], [826, 2096], [766, 2096]],
#      '191-',
#      0.9528997540473938),
#     ([[1240, 2108], [1440, 2108], [1440, 2140], [1240, 2140]],
#      'Pagina 13 van 15',
#      0.9530795220148988),
#     ([[752, 418], [836, 412], [837, 446], [752, 452]],
#      'geval',
#      0.9999863521131679)],
#    [([[196, 202], [354, 202], [354, 232], [196, 232]],
#      'OPENBAAR',
#      0.9997857580625014),
#     ([[883, 195], [1129, 195], [1129, 235], [883, 235]],
#      'Kansspelautoriteit',
#      0.9999202545972062),
#     ([[1316, 208], [1510, 208], [1510, 234], [1316, 234]],
#      'Kansspelautoriteit',
#      0.9999989322791986),
#     ([[1317, 245], [1387, 245], [1387, 265], [1317, 265]],
#      'Datum',
#      0.9999913634491684),
#     ([[1316, 276], [1474, 276], [1474, 300], [1316, 300]],
#      '21 februari 2023',
#      0.7635328545152678),
#     ([[1317, 311], [1457, 311], [1457, 331], [1317, 331]],
#      'Ons kenmerk',
#      0.8666306171284494),
#     ([[1316, 342], [1500, 342], [1500, 368], [1316, 368]],
#      '15402/ 01.285.941',
#      0.8932720939401867),
#     ([[251, 409], [1405, 409], [1405, 447], [251, 447]],
#      'jongvolwassenen van de mailinglijst technisch mogelijk en uitvoerbaar was, heeft',
#      0.7681626311425928),
#     ([[254, 444], [1441, 444], [1441, 488], [254, 488]],
#      'Hillside haar wervings- en reclameactiviteiten gericht op een aanzienlijk deel van de',
#      0.7218219905868104),
#     ([[255, 487], [1143, 487], [1143, 525], [255, 525]],
#      'bij haar geregistreerde jongvolwassen, in de vorm van e-mails.',
#      0.590731910075635),
#     ([[1153, 488], [1338, 488], [1338, 520], [1153, 520]],
#      'Hillside bleef',
#      0.9304649122701996),
#     ([[255, 524], [1339, 524], [1339, 564], [255, 564]],
#      'hiermee doorgaan  ook toen de Kansspelautoriteit medio december 2021 ten',
#      0.6848917012883932),
#     ([[253, 559], [1365, 559], [1365, 604], [253, 604]],
#      'aanzien van bonussen nogmaalss duidelijk had gemaakt dat bonussen ook een',
#      0.8028860611688029),
#     ([[255, 599], [1323, 599], [1323, 642], [255, 642]],
#      'wervings- en reclameactiviteit zijn, dat de algemene regels ten aanzien van',
#      0.6053263938453082),
#     ([[252, 636], [1412, 636], [1412, 684], [252, 684]],
#      'wervings- en reclameactiviteiten ook op bonussen van toepassing zijn en dat voor',
#      0.9496829100075066),
#     ([[253, 678], [1439, 678], [1439, 720], [253, 720]],
#      'aanbieders van online kansspelen geldt dat bonussen niet gericht mogen worden op',
#      0.7141870722164684),
#     ([[251, 721], [505, 721], [505, 759], [251, 759]],
#      'jongvolwassenen.',
#      0.9900207891111754),
#     ([[194, 824], [750, 824], [750, 872], [194, 872]],
#      '7.4 Overige omstandigheden',
#      0.9943427356595144),
#     ([[196, 872], [240, 872], [240, 902], [196, 902]],
#      '67 .',
#      0.9164049625396729),
#     ([[255, 869], [1369, 869], [1369, 907], [255, 907]],
#      'Het overtreden van de norm uit artikel 2, vierde lid, aanhef en onder a van het',
#      0.796712564178823),
#     ([[254, 905], [1437, 905], [1437, 947], [254, 947]],
#      'Bwrvk is een standaard onderdeel van de bedrijfsvoering geweest. Dit is reden voor',
#      0.81739637734999),
#     ([[255, 943], [1405, 943], [1405, 986], [255, 986]],
#      'de Kansspelautoriteit om het begaan van deze overtreding zwaar aan Hillside aan',
#      0.6629158486733596),
#     ([[254, 988], [414, 988], [414, 1020], [254, 1020]],
#      'te rekenen',
#      0.9996775215360476),
#     ([[196, 1066], [240, 1066], [240, 1096], [196, 1096]],
#      '68.',
#      0.9998008904397986),
#     ([[253, 1058], [1366, 1058], [1366, 1106], [253, 1106]],
#      'Hillside heeft de overtreding (naar eigen zeggen) gestaakt per 1 februari 2022.',
#      0.7768212563313592),
#     ([[1376, 1066], [1418, 1066], [1418, 1096], [1376, 1096]],
#      'De',
#      0.9999855015148964),
#     ([[255, 1101], [727, 1101], [727, 1141], [255, 1141]],
#      'Kansspelautoriteit acht dit echter',
#      0.8729865424760886),
#     ([[805, 1096], [1393, 1096], [1393, 1141], [805, 1141]],
#      'omstandigheid die de overtreding minder',
#      0.9883951242962455),
#     ([[253, 1137], [857, 1137], [857, 1179], [253, 1179]],
#      'verwijtbaar maakt. Dat de overtreding per',
#      0.699925136322209),
#     ([[861, 1139], [1417, 1139], [1417, 1179], [861, 1179]],
#      '1 februari 2022 is gestaakt, neemt niet',
#      0.8368962358509038),
#     ([[255, 1179], [1421, 1179], [1421, 1219], [255, 1219]],
#      'weg dat Hillside vanaf 26 oktober 2021 reclameberichten aan jongvolwassen heeft',
#      0.7688965190927142),
#     ([[252, 1215], [391, 1215], [391, 1257], [252, 1257]],
#      'gestuurd.',
#      0.9988501739689479),
#     ([[195, 1327], [261, 1327], [261, 1363], [195, 1363]],
#      '7.5',
#      0.9705079197883606),
#     ([[273, 1318], [550, 1318], [550, 1372], [273, 1372]],
#      'Boetebepaling',
#      0.9999623740698717),
#     ([[196, 1368], [240, 1368], [240, 1398], [196, 1398]],
#      '69.',
#      0.999577148012807),
#     ([[253, 1362], [1421, 1362], [1421, 1405], [253, 1405]],
#      'Gelet op het bovenstaande acht de Kansspelautoriteit het passend en geboden dat',
#      0.8515916530550447),
#     ([[253, 1403], [798, 1403], [798, 1446], [253, 1446]],
#      'een boete wordt opgelegd aan Hillside _',
#      0.730921472891832),
#     ([[196, 1484], [240, 1484], [240, 1514], [196, 1514]],
#      '70.',
#      0.9988656352645857),
#     ([[253, 1477], [1351, 1477], [1351, 1522], [253, 1522]],
#      'Gelet op de ernst en de verwijtbaarheid zoals hierboven toegelicht, wordt een',
#      0.7509329599879642),
#     ([[254, 1517], [655, 1517], [655, 1559], [254, 1559]],
#      'basisbedrag van € 350.000,',
#      0.7428038094662719),
#     ([[666, 1519], [903, 1519], [903, 1559], [666, 1559]],
#      'passend geacht.',
#      0.9707507116063153),
#     ([[191, 1597], [242, 1597], [242, 1634], [191, 1634]],
#      '71.',
#      0.9943959258913145),
#     ([[255, 1595], [1333, 1595], [1333, 1638], [255, 1638]],
#      'Daar komt bij dat deze overtreding gedurende langere tijd onderdeel van de',
#      0.7891913193428828),
#     ([[254, 1635], [1285, 1635], [1285, 1677], [254, 1677]],
#      'bedrijfsvoering van Hillside is geweest. Daarom wordt een verhoging van',
#      0.8841840448558272),
#     ([[253, 1674], [1357, 1674], [1357, 1716], [253, 1716]],
#      '€ 50.000, - passend geacht. Dat Hillside betoogt zelf gestopt te zijn in februari',
#      0.5255412175834906),
#     ([[255, 1712], [1439, 1712], [1439, 1753], [255, 1753]],
#      '2022, is in deze niet boeteverlagend. Gelet hierop kiest de Kansspelautoriteit er wel',
#      0.8220743664891441),
#     ([[254, 1756], [432, 1756], [432, 1786], [254, 1786]],
#      'voor om het',
#      0.8095158392738595),
#     ([[433, 1747], [964, 1747], [964, 1795], [433, 1795]],
#      'boetebedrag niet verder te verhogen.',
#      0.9107991294211378),
#     ([[196, 1834], [240, 1834], [240, 1864], [196, 1864]],
#      '72.',
#      0.9986179740118427),
#     ([[255, 1826], [1441, 1826], [1441, 1871], [255, 1871]],
#      'Alles afwegende stelt de Kansspelautoriteit de boete vast op een totaalbedrag van €',
#      0.8438240672586435),
#     ([[255, 1871], [389, 1871], [389, 1907], [255, 1907]],
#      '400.000,',
#      0.9970155928959368),
#     ([[413, 1868], [1408, 1868], [1408, 1910], [413, 1910]],
#      'Dit bedrag wordt, gelet op de omstandigheden van het geval, passend',
#      0.739040557503013),
#     ([[254, 1916], [292, 1916], [292, 1940], [254, 1940]],
#      'en',
#      0.9999956167305686),
#     ([[295, 1906], [538, 1906], [538, 1950], [295, 1950]],
#      'geboden geacht.',
#      0.8767516970203171),
#     ([[215, 2031], [1419, 2031], [1419, 2069], [215, 2069]],
#      'Zie ook Kamerstukken II 2013/14, 33 996, nr.3 (p. 28) en de NvT bij het Bwrvk: Stb.',
#      0.546083505553073),
#     ([[192, 2061], [455, 2061], [455, 2101], [192, 2101]],
#      '2021, 37 (p. 175).',
#      0.6742234314197084),
#     ([[1240, 2108], [1440, 2108], [1440, 2138], [1240, 2138]],
#      'Pagina 14 van 15',
#      0.5404832520888868),
#     ([[725, 1106], [801, 1100], [802, 1134], [726, 1140]],
#      'geen',
#      0.9999938011169434)],
#    [([[196, 202], [354, 202], [354, 232], [196, 232]],
#      'OPENBAAR',
#      0.9997857580625014),
#     ([[883, 195], [1129, 195], [1129, 235], [883, 235]],
#      'Kansspelautoriteit',
#      0.9999202545972062),
#     ([[1316, 208], [1510, 208], [1510, 234], [1316, 234]],
#      'Kansspelautoriteit',
#      0.9999989322791986),
#     ([[1317, 245], [1387, 245], [1387, 265], [1317, 265]],
#      'Datum',
#      0.9999913634491684),
#     ([[1316, 276], [1474, 276], [1474, 300], [1316, 300]],
#      '21 februari 2023',
#      0.7635328545152678),
#     ([[1317, 311], [1457, 311], [1457, 331], [1317, 331]],
#      'Ons kenmerk',
#      0.8666306171284494),
#     ([[1316, 342], [1500, 342], [1500, 366], [1316, 366]],
#      '15402/ 01.285.941',
#      0.6754824573828346),
#     ([[196, 416], [228, 416], [228, 450], [196, 450]], '8', 1.0),
#     ([[255, 411], [415, 411], [415, 453], [255, 453]],
#      'Besluit',
#      0.999995043739641),
#     ([[195, 500], [865, 500], [865, 541], [195, 541]],
#      'De raad van bestuur van de Kansspelautoriteit:',
#      0.6640115958885673),
#     ([[247, 587], [267, 587], [267, 609], [247, 609]],
#      'a',
#      0.9714201562164568),
#     ([[293, 577], [1364, 577], [1364, 617], [293, 617]],
#      'stelt vast dat Hillside artikel 2, vierde lid, aanhef en onder a, van het Bwrvk',
#      0.9523866257433007),
#     ([[295, 615], [1333, 615], [1333, 658], [295, 658]],
#      'heeft overtreden door haar wervings- en reclameactiviteiten te richten op',
#      0.9305371067383382),
#     ([[294, 656], [1335, 656], [1335, 695], [294, 695]],
#      'personen in de leeftijdscategorie tussen 18 en 24 jaar (jongvolwassenen) .',
#      0.5148760375328626),
#     ([[246, 698], [270, 698], [270, 726], [246, 726]],
#      'b',
#      0.9996520583549149),
#     ([[293, 695], [943, 695], [943, 733], [293, 733]],
#      'legt aan Hillside een boete op van € 400.000,',
#      0.8054192192609699),
#     ([[194, 774], [234, 774], [234, 804], [194, 804]],
#      "'s-",
#      0.713259004430373),
#     ([[228, 769], [670, 769], [670, 814], [228, 814]],
#      'Gravenhage, 21 februari 2023,',
#      0.6833132255794516),
#     ([[195, 850], [865, 850], [865, 891], [195, 891]],
#      'De raad van bestuur van de Kansspelautoriteit,',
#      0.763051310086528),
#     ([[196, 936], [252, 936], [252, 964], [196, 964]],
#      'W.g',
#      0.9962645364615943),
#     ([[196, 1012], [433, 1012], [433, 1044], [196, 1044]],
#      'René J.P. Jansen',
#      0.6317391583289698),
#     ([[196, 1056], [338, 1056], [338, 1086], [196, 1086]],
#      'voorzitter',
#      0.9999956648064969),
#     ([[198, 1131], [702, 1131], [702, 1162], [198, 1162]],
#      'VERZONDEN OP 24 FEBRUARI 2023',
#      0.7731352264092965),
#     ([[196, 1212], [306, 1212], [306, 1238], [196, 1238]],
#      'Bezwaar',
#      0.9999755340195329),
#     ([[194, 1248], [1391, 1248], [1391, 1288], [194, 1288]],
#      'Tegen dit besluit kan degene wiens belang rechtstreeks bij dit besluit is betrokken, binnen zes',
#      0.7054599434784453),
#     ([[196, 1294], [468, 1294], [468, 1326], [196, 1326]],
#      'weken na de dag van',
#      0.7549328055683394),
#     ([[470, 1287], [1419, 1287], [1419, 1329], [470, 1329]],
#      'bekendmaking van dit besluit een gemotiveerd bezwaarschrift indienen bij',
#      0.8199444148975918),
#     ([[193, 1329], [1383, 1329], [1383, 1369], [193, 1369]],
#      'de Kansspelautoriteit, afdeling Juridische Zaken en Vergunningen, Postbus 298, 2501 CG Den',
#      0.6479038039057777),
#     ([[193, 1372], [1413, 1372], [1413, 1412], [193, 1412]],
#      'Haag. U kunt uw bezwaarschrift ook digitaal indienen, door het in PDF-formaat te e-mailen naar',
#      0.6670601505337042),
#     ([[191, 1412], [557, 1412], [557, 1453], [191, 1453]],
#      'griffie@kansspelautoriteit. nI.',
#      0.5566311394649817),
#     ([[193, 1455], [1157, 1455], [1157, 1495], [193, 1495]],
#      'Let wel: het instellen van bezwaar schort de werking van dit besluit niet op.',
#      0.943198933105669),
#     ([[196, 1544], [324, 1544], [324, 1572], [196, 1572]],
#      'Kunt u de',
#      0.7900090610053798),
#     ([[324, 1537], [1427, 1537], [1427, 1579], [324, 1579]],
#      'beslissing op uw bezwaarschrift niet afwachten vanwege een spoedeisend belang? Dan',
#      0.6805260025439135),
#     ([[195, 1583], [1345, 1583], [1345, 1619], [195, 1619]],
#      'kunt u bij de sector bestuursrecht van de rechtbank in uw arrondissement een verzoek om',
#      0.7336692496732574),
#     ([[195, 1622], [601, 1622], [601, 1663], [195, 1663]],
#      'voorlopige voorziening indienen',
#      0.7615081529785032),
#     ([[194, 1707], [385, 1707], [385, 1743], [194, 1743]],
#      'Betaling_boete',
#      0.9484331654070985),
#     ([[195, 1749], [1095, 1749], [1095, 1785], [195, 1785]],
#      'Boetes dienen binnen zes weken nadat het besluit op de in artikel 3:41',
#      0.815943330360123),
#     ([[1102, 1752], [1380, 1752], [1380, 1784], [1102, 1784]],
#      'van de Algemene wet',
#      0.997756277049801),
#     ([[195, 1787], [1427, 1787], [1427, 1830], [195, 1830]],
#      'bestuursrecht voorgeschreven wijze bekend is gemaakt; te zijn betaald op bankrekeningnummer',
#      0.8073705690404469),
#     ([[194, 1834], [692, 1834], [692, 1864], [194, 1864]],
#      'IBAN NLOZABNA0501634479 ten name',
#      0.36407637935269077),
#     ([[698, 1838], [746, 1838], [746, 1862], [698, 1862]],
#      'van',
#      0.9998430106503889),
#     ([[751, 1832], [1363, 1832], [1363, 1870], [751, 1870]],
#      'Kansspelautoriteit, Den Haag, Nederland, onder',
#      0.841760053205618),
#     ([[195, 1875], [1337, 1875], [1337, 1913], [195, 1913]],
#      'vermelding van het kenmerk van dit besluit. Na het verstrijken van deze termijn wordt de',
#      0.7596327485353641),
#     ([[192, 1913], [799, 1913], [799, 1953], [192, 1953]],
#      'geldboete vermeerderd met de wettelijke rente',
#      0.854313094939728),
#     ([[1240, 2108], [1440, 2108], [1440, 2140], [1240, 2140]],
#      'Pagina 15 van 15',
#      0.8076304683506246)]]])

# %% [markdown]
# ### Analyse raw OCR output into structured text
#
# Take those OCR fragments and separate off headers, group into paragraphs and such.
#
# A lot of this isn't necessary to produce the text, **but** with bit of tweaking specific to this document layout,
# we can give cleaner output.
#
# Which is also why it's separate from the previous code cell.
#
# <!-- -->
#
# It's also _long_ because a bunch of specific augmentation goes on here.
# It's separate so that we can tweak and re-run it easily.
#
# It's still little more than a bunch of math on numbers, so takes less than a minute.

# %%
# a bunch of helpers
from wetsuite.extras.ocr import doc_extent, page_fragment_filter, bbox_max_x, bbox_max_y, bbox_min_x, bbox_min_y, bbox_height

verbose = False

dataset_cases = [] # distinct name, has a different structure

for case_i, case_tuple in enumerate(extracted_cases):
    case_dict, case_doc_dicts, ocrdata = case_tuple
    case_name = case_dict['name']

    print( 'CASE %d: %s'%(case_i, case_name) )

    case_docs = [] #this part's main output, becomes a dict per case (with keys like 'url', 'pages')
    assert len(case_doc_dicts) == len(ocrdata)

    case_doc_dates = set() # or maybe count?

    ## for each document, analyze the OCR fragments and sort it into more directly useful data
    for doc_i in range(len(case_doc_dicts)): #ocrdata should have the same length
        pdf_dict = case_doc_dicts[doc_i]
        doc_ocr  = ocrdata[doc_i]


        pdf_url = pdf_dict['pdf_url']
        print( '  DOC %d:  %s'%(doc_i,   wetsuite.helpers.format.url_basename( pdf_url ) ) )


        doc_pages = [] # the main output for a document - a list of dicts that each detail a page
        doc_dates = [] # picks out dates from the headers

        doc_wide_extent = doc_extent( doc_ocr ) # the area outside there is no text at all, throughout all of the page's document
        #print( 'doc_min_x, doc_max_x, doc_min_y, doc_max_y', extent )

        for page_i, page in enumerate( doc_ocr ): # page is now all text framents on a page, a list of all (bbox, text, cert) 
            if verbose:
                print( '   PAGE %s ---------------------------------------------------------------------------'%(page_i) )

            ### Determine margins
            # so that we can have logic that extract text that hopefully flows between pages
            head_y_ary, foot_y_ary = [], []
            # - Top margin defined by lowest box extent of 
            #    - "Kansspenautoriteit" (not really necessary)
            #    - "OPENBAAR"
            #    - "Ons kenmerk" plus one extra box's worth
            matches = page_fragment_filter( page, r'^Kansspelautoriteit$', q_max_y=0.25, extent=doc_wide_extent )
            for bbox, text, cert in matches:
                #print ('    [page %d] Kansspelautoriteit MATCH: %s %s %s'%(page_i, bbox, text, cert))
                head_y_ary.append( bbox_max_y(bbox) )
            matches = page_fragment_filter( page, r'^OPENBAAR$', q_max_y=0.3, q_max_x=0.35, extent=doc_wide_extent )
            for bbox, text, cert in matches:
                #print ('    [page %d] OPENBAAR MATCH: %s %s %s'%(page_i, bbox, text, cert))
                head_y_ary.append( bbox_max_y(bbox) )
            matches = page_fragment_filter( page, r'Ons kenmerk', q_max_y=0.25, extent=doc_wide_extent )
            for bbox, text, cert in matches:
                #print ('    [page %d] Ons kenmerk MATCH: %s %s %s'%(page_i, bbox, text, cert))
                head_y_ary.append( bbox_max_y(bbox) + 1.2* bbox_height(bbox) ) # we expect one more line of the same height below it (times fudge factor, for expected whitespace)
            
            # - Bottom margin defined by highest box y of "agina [0-9]+ van [0-9]+" in the bottom right
            matches = page_fragment_filter( page, r'Pagina', q_min_x=0.7, q_min_y=0.75, extent=doc_wide_extent ) # the rest, e.g. (\s*[0-9]+\s*van\s*[0-9]+)?, is optional because it's sometimes detected separately, or not at all
            for bbox, text, cert in matches: # 
                #print ('    [page %d] Pagina MATCH: %s %s %s'%(page_i, bbox, text, cert))
                foot_y_ary.append( bbox_min_y(bbox)  )
            if len(foot_y_ary)==0: # look harder for page - a lone number to the bottom right that matches roughly with the page number we think it is is probably also the page number
                pages_around = '|'.join( str(pag)  for pag in range(page_i-1, page_i+2) )
                matches = page_fragment_filter( page, r'^(%s)$'%pages_around, q_min_y=0.75, q_min_x=0.7, extent=doc_wide_extent )
                for bbox, text, cert in matches: # (\s*[0-9]+\s*van\s*[0-9]+)?
                    #print ('    [page %d] Bare pagina MATCH: %s %s %s'%(page_i, bbox, text, cert))
                    foot_y_ary.append( bbox_min_y(bbox)  )

            if len(head_y_ary)==0:
                head_bot_y = None
            else:
                head_bot_y = max(head_y_ary)

            if len(foot_y_ary)==0:
                foot_top_y = None
            else:
                foot_top_y = min(foot_y_ary)

            if verbose:
                print("    page head_y: ", head_bot_y) # TODO: call this head_bot_y (and probably rename h)
                print("    page foot_y: ", foot_top_y) # TODO: call this foot_top_y


            ### Figure out some things about the page
            ## list-iten X position
            # Most of these documents have numbering on their headers and paragraphs
            # these list-iten numbers at the start of lines are not detected consistently by OCR,
            # nor are they linguistic information, so attempt to remove them.
            # We like to be sure (to not remove such things from actual text), so 
            lnum_righty = []
            matches = page_fragment_filter( page, r'^[0-9.]+$', q_max_x=0.2, q_min_y=head_bot_y,q_max_y=foot_top_y, extent=doc_wide_extent ) 
            for bbox, text, cert in matches:
                if verbose:
                    print ('    [page %d] LI NUM MATCH: %s %s %s'%(page_i, bbox, text, cert))
                lnum_righty.append( bbox_max_x(bbox)  )            
            if len(lnum_righty) < 4: # not sure enough - be more conservative
                lnum_righty = doc_wide_extent[0] + 20 # TODO: avoid that constant
            else:
                lnum_righty = max(lnum_righty)

            ## average box size
            box_heights = []
            for bbox, text, cert in page:
                box_heights.append( bbox_height( bbox ) )
            median_boxheight = numpy.median(box_heights)
            #print(box_heights)
            #print("Median bbox height: %d"%median_boxheight)


            ### Group and process fragments   (in passes, to make logic like 'is this the last thing in the body' easier)
            # - separate into head, body, foot
            # - polish the body, e.g. 
            #   'is this the last thing on the page AFTER we removed the footer' logic easier
            #   replace '-' at end of paragraph with '.'

            page_contents = {
                'head_fragments':[],
                'body_fragments':[],
                'misc_fragments':[],
                'foot_fragments':[],
                'body_text':[],
            }


            ## Sort fragments into header, body, and footer
            prev_topy, prev_boty = 0,0 
            for frag_i, (bbox, text, cert) in enumerate(page):
                topleft, topright, botright, botleft = bbox
                topy, boty = topleft[1], botright[1]

                text = re.sub('[_-]\s*$','.', text) # mistaken for period sometimes. Could be more thorough, but this is a start

                if head_bot_y is not None and topy < head_bot_y :
                    page_contents['head_fragments'].append( (bbox, text, cert) )

                elif foot_top_y is not None and boty > foot_top_y: # CONSIDER: also remove numbers from left of boxes that start at the -- IF we think it's such a number.
                    page_contents['foot_fragments'].append( (bbox, text, cert) )

                elif wetsuite.helpers.strings.is_numeric( text) and topleft[0] < lnum_righty+5:
                    pass
                    #page_contents['misc_fragments'].append( (bbox, text, cert) )

                else: #probably useful body
                    #print( '      %6s  %12s %-12s  fs:%-5s  %s '%( keep_ignore, topleft, botright, boxheight, text ) )
                    page_contents['body_fragments'].append( (bbox, text, cert) )

                    case_dict['money'].extend( find_eur_money(text, minimum=5001) )

                prev_topy, prev_boty = topy, boty

            ## Header stuff. Little smartness yet.
            head_text = [] 
            for body_frag_i, (bbox, text, cert) in enumerate(page_contents['head_fragments']):
                head_text.append(text)

                _, dts = wetsuite.helpers.date.find_dates_in_text(text)
                for dt in dts:
                    if dt is not None:
                        case_doc_dates.add( dt )
                        doc_dates.append( wetsuite.helpers.date.format_date(dt) )
                # CONSIDER: getting out kenmerk


            foot_text = [] 
            for body_frag_i, (bbox, text, cert) in enumerate(page_contents['foot_fragments']):
                foot_text.append(text)

            ## Figure out body's paragraphs, seprate where sensible
            body_text = [] 
            temp_par  = []
            prev_topy, prev_boty, prev_boxheight, prev_text = 0,0, 0, ''
            def flush_par():
                global temp_par, body_text
                if len(temp_par)>0:
                    body_text.append( ' '.join(temp_par) )
                    temp_par=[] 


            for body_frag_i, (bbox, text, cert) in enumerate(page_contents['body_fragments']):
                topleft, topright, botright, botleft = bbox
                topy, boty = topleft[1], botright[1]
                boxheight = bbox_height(bbox) # is a good indicator of font size

                same_line            = (boty - prev_boty) < 0.6*boxheight
                current_line_shorter = len(text) < 0.5 * len(prev_text) 
                prev_line_shorter    = 0.5 * len(prev_text) < len(text)

                #if topy-prev_boty > -5:
                #    print( "                                                   [ydist %d (%s->%s)]"%(topy-prev_boty, prev_boty, topy) )

                #if topy < prev_boty by roughly boxheight it's the same line

                if topy < prev_boty-200:
                    if verbose:
                        print( "LARGE DECREASE IN Y HUH?")
                        print( '      %12s %-12s  fs:%-5s  %s '%( topleft, botright, boxheight, text ) )
                    #continue
                    break
                    
                if prev_boty!=0  and  topy-prev_boty > median_boxheight: 
                    if verbose:
                        print( "                                                   [YSEP %d (%s->%s)]"%(topy-prev_boty, prev_boty, topy) )
                    flush_par()

                elif prev_boty!=0  and  topy-prev_boty > 0.6*median_boxheight: 
                    if verbose:
                        print( "                                                   [YSEP %d (%s->%s)]"%(topy-prev_boty, prev_boty, topy) )
                    flush_par()

                elif (boxheight > 1.25 * prev_boxheight)  and  current_line_shorter  and  not same_line:  # larger text, and shorter
                    # A large title of a new section is generally  caught by YSEP, actually
                    #print( 'size diff;   line diff?  botdiff is %d,  relative to 0.5*boxheight=%d'%( (boty-prev_boty),  0.5*boxheight ) )

                    if verbose:
                        print( "                                                   [LARGER_TEXT %s->%s]"%(prev_boxheight, boxheight) )
                    flush_par()

                elif boxheight < 0.8 * prev_boxheight  and  prev_line_shorter  and not same_line: # font smaller than the previous line, and the previous line was shorter
                    if verbose:
                        print( "                                                   [SMALLER_TEXT %s->%s]"%(prev_boxheight, boxheight) )
                    flush_par()

                temp_par.append( text )

                if verbose:
                    print( '      %12s %-12s  fs:%-5s  %s '%( topleft, botright, boxheight, text ) )

                prev_topy, prev_boty, prev_boxheight, prev_text = topy, boty,  boxheight, text

            flush_par()

            del page_contents['body_fragments']
            del page_contents['head_fragments']
            del page_contents['foot_fragments']
            del page_contents['misc_fragments']

            page_contents['head_text'] = head_text
            page_contents['body_text'] = body_text
            page_contents['foot_text'] = foot_text

            doc_pages.append( page_contents )

            #print( 'body_text' )
            #pprint.pprint( page_contents['body_text'] )
            #for par in page_contents['body_text']:
            #    for line in textwrap.wrap(par):
            #        print( '[%s]'%line )
            #    print()

        case_docs.append( 
            {
                'url':pdf_url, 
                'pages':doc_pages,
                'header_dates':doc_dates,
                'status':pdf_dict.get('status'),
            }
        )

        # summarize document
        #pprint.pprint( doc_contents )

        if 0:
            for page in doc_pages:
                for temp_par in page['body_text']:
                    for line in textwrap.wrap(temp_par):
                        print( '%s'%line )
                    print()



    date_range = ()
    if len(case_doc_dates)>0:
        date_range = (
            wetsuite.helpers.date.format_date( min(case_doc_dates) ), 
            wetsuite.helpers.date.format_date( max(case_doc_dates) )
        )

    dataset_cases.append( { 
                'name': case_name,
                'docs': case_docs,
        'date_range': date_range,

        # CONSIDER: maybe just start with case_dict so we don't have to manually do:
                'money': case_dict['money'],
                'ecli': case_dict['ecli'],
    'case_detail_url': case_dict['case_detail_url'],
    } )

print( len(dataset_cases) )
# Out:
# CASE 0: Hillside New Media Malta Plc
#   DOC 0:  15402_01-304-549_beslissing_op_bezwaar.pdf
#   DOC 1:  15402_bac_advies_hillside.pdf
#   DOC 2:  15402_01-304-539_openbaarmakingsbesluit_woo_bob.pdf
#   DOC 3:  15402_01-285-941_besluit-signed_openbare_versie.pdf
# CASE 1: Betent B.V.
#   DOC 0:  15998_01-302-172_betent_sanctiebesluit_openbaar.pdf
# CASE 2: Cloudflare
#   DOC 0:  besluit_bindende_aanwijzing_20231103_01-302-244.pdf
#   DOC 1:  besluit_obm_woo_ba_cloudflare_20231103_01-302-246.pdf
# CASE 3: Cloudflare
#   DOC 0:  besluit_bindende_aanwijzing_cloudflare_20231016_01-302-181.pdf
#   DOC 1:  besluit_openbaarmaking_woo_bindende_aanwijzing_cloudflare_20231016_01-302-184.pdf
# CASE 4: Holland Casino
#   DOC 0:  20231026_01-293-519_openbare_versie_besluit_bindende_aanwijzing_hc_cdb_1.pdf
#   DOC 1:  20231026_01-293-518_openbare_versie_openbaarmakingsbesluit_bindende_aanwijzing_hc_cdb_002_.pdf
#   DOC 2:  16369-01-305-776_hc_bob_aanwijzing.pdf
#   DOC 3:  16369_besluit_openbaarmaking_bob_hc.pdf
# CASE 5: Betent
#   DOC 0:  15403_01-301-226_beslissing_op_bezwaar_betent.pdf
#   DOC 1:  15403_01-301-226_openbaarmakingsbesluit_woo_bob_ov.pdf
#   DOC 2:  15403_01-300-884_bac_advies_betent.pdf
#   DOC 3:  betent_15403_sanctiebesluit.pdf
#   DOC 4:  15403_01-301-226_openbaarmakingsbesluit_betent.pdf
# CASE 6: Bingoal Nederland B.V.
#   DOC 0:  beslissing_op_bezwaar_bingoal.pdf
#   DOC 1:  openbaarmakingsbesluit_bingoal_woo_bob.pdf
#   DOC 2:  bac_advies_bingoal.pdf
#   DOC 3:  01-288-556_15404_sanctiebesluit_bingoal.pdf
#   DOC 4:  15404_bingoal_openbaarmakingsbesluit_002_.pdf
# CASE 7: Vriendenloterij N.V.
#   DOC 0:  bob_lod_vl_openbare_versie.pdf
#   DOC 1:  besluit_openbaarmaking_bob_vl_openbare_versie.pdf
#   DOC 2:  20230523_01-291-294_openbaar_besluit_last_onder_dwangsom_vl_spellen.pdf
#   DOC 3:  20230523_01-291-296_openbare_versie_openbaarmakingsbesluit_woo_vl_last.pdf
# CASE 8: Nationale Postcode Loterij N.V.
#   DOC 0:  bob_lod_npl_openbare_versie.pdf
#  'docs': [{'url': 'https://kansspelautoriteit.nl/publish/library/32/15402_01-304-549_beslissing_op_bezwaar.pdf',
#    'pages': [{'body_text': ['Besluit van de raad van bestuur van de Kansspelautoriteit op de bezwaarschriften van Hillside New Media Malta Plc tegen het besluit van 21 februari 2023 tot oplegging van een bestuurlijke boete van € 400.000, (kenmerk 1 5402/01.285.941) en tegen het besluit van 24 februari 2023 (kenmerk 15402/01.285.943) tot openbaarmaking van het sanctiebesluit.',
#       'Zaak: 15402.001 Kenmerk: 15402.001/01.304.536 Openbaarmaking onder: 15402.001/01.304.549',
#       'Besluit op bezwaar',
#       'Inleiding',
#       'Op 6 april 2023 is door Hillside bezwaar gemaakt tegen de besluiten van de raad van bestuur van de Kansspelautoriteit van 21 februari 2023 en 24 februari 2023 met kenmerken 15402/01.285.941 en 15402/01.285.943. Bij brief van 24 mei 2023 zijn de gronden van het bezwaar aangevuld.',
#       'De raad van bestuur verwijst voor een uitgebreide beschrijving van de procedure',
#       'naar randnummers 1-12 van het advies van de Adviescommissie bezwaarschriften van de Kansspelautoriteit (hierna: de commissie) .',
#       'Ontvankelijkheid',
#       '3 . De bezwaarschriften zijn ingediend binnen zes weken na bekendmaking van het besluit. De gronden van het bezwaar zijn binnen de daartoe gestelde termijn aangevuld. De bezwaarschriften voldoen ook aan de overige door de Algemene wet bestuursrecht gestelde eisen zodat de bezwaren ontvankelijk zijn.',
#       'Hoorzitting'],
#      'head_text': ['Kansspelautoriteit', 'OPENBAAR'],
#      'foot_text': []},
#     {'body_text': ['Bezwaarmaker heeft geen gebruik gemaakt om tijdens een hoorzitting haar bezwaarschrift mondeling toe te lichten.',
#       'Advies',
#       'Naar aanleiding van de bezwaarschriften heeft de adviescommissie een advies uitgebracht aan de raad van bestuur. Dit advies is bij deze beslissing op bezwaar gevoegd en maakt integraal onderdeel uit van de beslissing op bezwaar .',
#       'De adviescommissie heeft geadviseerd om de bezwaren ongegrond te verklaren en',
#       'de besluiten van 21 februari 2023 en 24 februari 2023 in stand te laten.',
#       'Overige opmerkingen',
#       'De commissie ziet geen aanleiding voor een vergoeding van de kosten.',
#       'Besluit',
#       'De raad van bestuur van de Kansspelautoriteit:',
#       'a stelt vast dat de adviescommissie heeft geadviseerd om de bezwaren ongegrond te verklaren; b stelt vast dat het advies inhoudelijk concludent is en zorgvuldig tot stand is gekomen; C ziet geen reden om af te wijken van het advies; d. verklaart de bezwaren ongegrond en handhaaft de besluiten van 21 februari 2023 en 24 februari 2023; e verwijst overeenkomstig artikel 3:49 van de Algemene wet bestuursrecht voor de motivering van het besluit naar het uitgebrachte advies; f wijst het verzoek om vergoeding van de kosten af.',
#       "'s-Gravenhage, 12 december 2023",
#       'De raad van bestuur van de Kansspelautoriteit,',
#       'W.g.'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15402.001/01.304.536'],
#      'foot_text': []},
#     {'body_text': ['drs. René J.P . Jansen Voorzitter',
#       'Verzonden op: 15 december 2023',
#       'Beroep Tegen dit besluit kan een belanghebbende beroep instellen bij de sector bestuursrecht van de rechtbank Den Postbus 20302, 2500 EH Den',
#       'Het beroepschrift moet binnen zes weken na de dag van bekendmaking door de rechtbank zijn ontvangen. Het beroepschrift moet op grond van artikel 6:5 van de Algemene wet bestuursrecht zijn ondertekend en moet ten minste bevatten de naam en adres van de indiener; de dagtekening; de omschrijving van het besluit waartegen het beroep is gericht; ZO mogelijk een afschrift van dit besluit, en de gronden waarop het beroepschrift rust.',
#       'Van de indiener van het beroepschrift wordt griffierecht geheven door de griffier van de rechtbank. Nadere informatie over de hoogte van het griffierecht en de wijze van',
#       'betalen wordt door de griffie van de rechtbank verstrekt.',
#       'Er kan ook digitaal beroep worden ingesteld bij genoemde rechtbank via http:/ /loket.rechtspraak.nl/bestuursrecht. Daarvoor moet de indiener beschikken over een elektronische handtekening (DigiD). Kijk op de genoemde site voor de precieze voorwaarden.'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15402.001/01.304.536'],
#      'foot_text': []}],
#    'header_dates': ['2023-12-12', '2023-12-12'],
#    'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep worden ingesteld bij de rechtbank.'},
#   {'url': 'https://kansspelautoriteit.nl/publish/library/32/15402_bac_advies_hillside.pdf',
#    'pages': [{'body_text': ['Adviescommissie bezwaarschriften',
#       'Advies inzake het bezwaar van Hillside New Media Malta Plc tegen het sanctiebesluit van 21 februari 2023, kenmerk 15402 01.285.941, tot het opleggen van een bestuurlijke boete van € 400.000,- , en inzake het bezwaar tegen het besluit van 24 februari 2023, kenmerk 15402 / 01.285.943, tot openbaarmaking van het sanctiebesluit.',
#       'Procedureverloop',
#       '1 . Uit de stukken is de Adviescommissie bezwaarschriften van de Kansspelautoriteit (hierna: de commissie) samengevat het volgende gebleken.',
#       'De Kansspelautoriteit is ambtshalve een onderzoek gestart naar de naleving van het verbod om kansspelreclame te richten op minderjarigen en jongvolwassenen. De bevindingen van dit onderzoek zijn weergegeven in het rapport en het sanctiebesluit.',
#       '3 . Op 22 april 2022 hebben toezichthouders van de Kansspelautoriteit (hierna: toezichthouders) een informatieverzoek gestuurd naar Hillside New Media Malta Plc (hierna: Hillside) .',
#       'Op 10 mei 2022 heeft Hillside schriftelijk gereageerd op het informatieverzoek en de gevraagde gegevens aangeleverd .',
#       'Op 20 oktober 2022 hebben toezichthouders van de Kansspelautoriteit een rapport opgesteld. In het rapport is geconstateerd dat Hillside artikel 2, vierde lid, aanhef en onder a, van het Besluit werving, reclame en verslavingspreventie kansspelen (hierna: Bwrvk) heeft overtreden. Het rapport is toegezonden aan Hillside.',
#       'Bij brief van 27 oktober 2022 is Hillside in de gelegenheid gesteld om een schriftelijke en/of mondelinge zienswijze te geven op het rapport. Bij brief van 2 december 2022 is namens Hillside een schriftelijke zienswijze op het rapport ingediend. Op 15 december 2022 is Hillside in de gelegenheid gesteld om haar zienswijze mondeling toe te lichten tijdens een hoorzitting .',
#       'Op 18 januari 2023 is het verslag van de hoorzitting per e-mail naar Hillside verzonden. Op 25 januari 2023 heeft Hillside haar opmerkingen over het verslag naar de Kansspelautoriteit gezonden.',
#       'In het sanctiebesluit van 21 februari 2023 heeft de raad van bestuur van de Kansspelautoriteit (hierna: de raad van bestuur) aan Hillside een bestuurlijke boete opgelegd van € 400.000, vanwege overtreding van artikel 2, vierde lid, aanhef en onder a, van het Bwrvk.',
#       'In het openbaarmakingsbesluit van 24 februari 2023 heeft de raad van bestuur besloten om het sanctiebesluit van 21 februari 2023 en het openbaarmakingsbesluit openbaar te maken.',
#       'Artikel 2, derde en vierde lid, van het Bwrvk'],
#      'head_text': ['OPENBAAR', 'Kansspelautoriteit'],
#      'foot_text': []},
#     {'body_text': ['10. Bij brief en e-mail van 6 april 2023 heeft Hillside pro forma bezwaar gemaakt tegen het sanctiebesluit en tegen het openbaarmakingsbesluit.',
#       '11. Bij brief en e-mail van 13 april 2023 is aan Hillside uitstel verleend tot het indienen van de aanvullende gronden. Bij brief van 24 mei 2023 heeft Hillside de gronden van bezwaar aangevuld.',
#       '12. Hillside is in de gelegenheid gesteld om tijdens een hoorzitting op 30 juni 2023 haar bezwaarschrift mondeling toe te lichten. Zij heeft van die gelegenheid geen gebruik gemaakt.',
#       '2 Bezwaargronden tegen het sanctiebesluit',
#       '13.In bezwaar heeft Hillside samengevat het volgende naar voren gebracht:',
#       'a Volgens Hillside is het verzenden van reclame in de vorm van inhoudelijk generieke emailberichten aan jongvolwassenen als onderdeel van een generieke mailingcampagne aan alle ingeschreven, gecontroleerde en opted-in spelers geen overtreding van artikel 2, vierde lid, aanhef en onder a, van het Bwrvk.',
#       'b Volgens Hillside is de boeteoplegging in strijd met het rechtszekerheidsbeginsel en het lex-certa beginsel omdat de norm',
#       'onvoldoende duidelijk  bepaald of kenbaar is.',
#       'c Volgens Hillside is het opleggen van een bestuurlijke boete van €400.000, niet passend en geboden. Daarom had moeten worden afgezien van het opleggen van een boete, dan wel had de boetehoogte gematigd moeten worden.',
#       'd Volgens Hillside is het opleggen van een bestuurlijke boete onrechtmatig en is daardoor ook het openbaarmakingsbesluit ten onrechte genomen.',
#       '3. Juridisch kader',
#       '14. Artikel tweede lid, van de Wet op de kansspelen (hierna: Wok) bepaalt dat houders van een vergunning op grond van de Wok op zorgvuldige en evenwichtige wijze vorm moeten geven aan wervings- en reclameactiviteiten, waarbij in het bijzonder wordt gewaakt tegen onmatige deelneming.',
#       '15.Artikel 35a, eerste lid, van de Wok bepaalt dat de Kansspelautoriteit een bestuurlijke boete kan opleggen wegens overtreding van de voorschriften vastgesteld bij of krachtens onder andere artikel 4a van de Wok. In het tweede lid is bepaald dat de bestuurlijke boete die voor een overtreding als bedoeld in het eerste lid kan worden opgelegd ten hoogste het bedrag van de zesde categorie, bedoeld in artikel 23, vierde lid, van het Wetboek van Strafrecht of, indien dat meer is, tien procent van de omzet in het boekjaar voorafgaande aan de beschikking bedraagt.'],
#      'head_text': ['OPENBAAR'],
#      'foot_text': ['2']},
#     {'body_text': ["16.In artikel 1, aanhef en onder e, van het Bwrvk zijn 'wervings- en reclameactiviteiten gedefinieerd als: iedere vorm van communicatie waarmee vergunninghouders  al dan niet met behulp van derden, direct of indirect hun diensten of goederen aanprijzen .",
#       "17.In artikel 1, aanhef en onder f, van het Bwrvk is bonus' gedefinieerd als: een goed of een dienst, waaronder gratis speeltegoed, aangeboden om spelers voor de vergunde kansspelen te werven of te behouden of om reclame voor die kansspelen te maken.",
#       '18.Artikel 2 vierde lid, onder a, van het Bwrvk bepaalt dat de houder van een vergunning tot het organiseren van kansspelen op afstand zijn wervings- en',
#       'reclameactiviteiten voor kansspelen niet richt op personen in de leeftijdscategorie tussen 18 en 24 jaar.',
#       '19.Artikel 2ab, eerste lid, van het Bwrvkz bepaalt dat de houder van een vergunning tot het organiseren van kansspelen op afstand alleen zodanig specifiek gerichte wervings- en reclameactiviteiten ontplooit voor die kansspelen dat deze geen personen bereiken als bedoeld in artikel 2, derde en vierde lid, van het Bwrvk.',
#       '20. Artikel 12, aanhef en onder i, van de Regeling werving, reclame en verslavingspreventie kansspelen (hierna: de Rwrvk) bepaalt dat het verslavingspreventiebeleid van de houder van een vergunning tot het organiseren van een speelcasino, tot het aanwezig hebben van een of meer kansspelautomaten in een speelautomatenhal, of tot het organiseren van kansspelen op afstand, in ieder een beschrijving bevat van de wijze waarop de implementatie van verslavingspreventieve maatregelen en voorzieningen in zijn organisatie alsmede de passende en effectieve toepassing van deze maatregelen en voorzieningen is gewaarborgd . Bij deze beschrijving wordt in ieder bijzondere aandacht geschonken aan de wijze waarop de vergunninghouder voorkomt dat wervings - en reclameactiviteiten gericht zijn op maatschappelijk kwetsbare groepen van personen als bedoeld in artikel 2, derde lid, van het besluit en jongvolwassenen.',
#       '4 Overwegingen van de commissie',
#       '4.1. Ten aanzien van de ontvankelijkheid van het bezwaar',
#       '21. Het bezwaarschrift is tijdig ingediend en voldoet aan alle vereisten voor ontvankelijkheid.',
#       '4.2 Ten aanzien van de bezwaren',
#       '22.De commissie merkt op dat artikel 2, vierde lid, aanhef en onder a, het Bwrvk een verbod bevat voor vergunninghouders om wervings- en reclameactiviteiten voor kansspelen te richten op personen in de leeftijdscategorie tussen 18 en 24 jaar (jongvolwassenen)',
#       '23. Niet in geschil is dat Hillside in de periode van 26 oktober 2021 tot en met 1 februari 2022 meerdere bij haar geregistreerde jongvolwassen spelers veelvuldig reclameberichten heeft gestuurd, in de vorm van e-mails waarin het aanbod van',
#       'Dit artikel is per 1 juli 2023 in werking getreden'],
#      'head_text': ['OPENBAAR'],
#      'foot_text': ['3']},
#     {'body_text': ['Hillside werd aangeprezen  waaronder bonussen. Bij brief van 10 mei 2022 heeft Hillside immers erkend dat zij promotionele e-mails, waaronder bonussen, heeft verzonden aan alle in aanmerking komende geregistreerde spelers die ervoor gekozen hebben om marketing te ontvangen. Daarmee is de overtreding van artikel 2, vierde lid, aanhef en onder a, van het Bwrvk volgens de commissie een gegeven .',
#       '44.Dat 5 vergunninghouders een (vrijwel) identieke overtreding hebben begaan, betekent volgens de commissie nog niet dat er sprake is van onduidelijkheid over de reikwijdte van artikel 2, vierde lid, aanhef en onder a, van het Bwrvk. Het betekent hoogstens dat 5 vergunninghouders een op zichzelf duidelijke norm verkeerd hebben geïnterpreteerd. De overige vergunninghouders hebben de norm destijds op een andere manier geïnterpreteerd, althans geen wervings- en reclameactiviteiten gericht op jongvolwassenen.',
#       '45.Dat 4 andere vergunninghouders dezelfde norm op een verkeerde manier hebben geïnterpreteerd en daarmee een (vrijwel) identieke overtreding hebben begaan als Hillside, betekent volgens de commissie evenmin dat de overtreden norm onduidelijk is Zodra een bepaalde norm onduidelijk moet worden geacht, omdat andere vergunninghouders dezelfde overtreding (hebben) begaan of de norm (ook) verkeerd interpreteren, zou het opleggen van een sanctie door de raad van bestuur de facto niet meer mogelijk zijn. Marktpartijen zouden dan eenvoudig onderling afspraken kunnen maken om een bepaalde regel die hen niet bevalt anders uit te leggen en zodoende rechtmatig tot stand gekomen wet- en regelgeving stelselmatig kunnen omzeilen, dan wel naast zich neer kunnen leggen.',
#       '46.In het licht van het in randnummer 38 genoemde verbod op ongerichte reclamelı waarmee wordt beoogd het risico op kansspelverslaving onder jongvolwassenen en andere kwetsbare groepen terug te dringen, zou een dergelijke uitleg bovendien een volstrekt verkeerd signaal zijn. Het spreekt voor zich dat de commissie dit standpunt dan ook niet volgt.',
#       'https:L/kansspelautoriteit nlnieuwsL2022Lseptemberlmarkt-online-kansspelen-stabielL 10 https:L/kansspelautoriteit nl/veilig-spelenLveilig-online-gokken[kansspelwijzer-online-gokkenl 11 Staatsblad 2023, 120'],
#      'head_text': ['OPENBAAR'],
#      'foot_text': ['8']},
#     {'body_text': ['47.Ten aanzien van het standpunt van Hillside dat uit de toelichting bij artikel 12 van de Regeling werving  reclame en verslavingspreventie kansspelen op afstand (hierna: Rwrvk) niet blijkt dat de wetgever met richten op\' tevens heeft bedoeld richten aan" overweegt de commissie het volgende.',
#       '48.In de toelichting12 op artikel 12 van de Rwrvk staat het volgende (onderstreping commissie):',
#       "'De vergunninghouder die kansspelen organiseert op afstand mag wervings- en reclameactiviteiten niet richten_op maatschappelijk kwetsbare groepen van personen, waaronder minderjarigen en personen die kenmerken van risicovol speelgedrag vertonen; enook niet op ionqvolwassenen. De vergunninghouder dient in zijn beleid te beschrijven welke maatregelen hij neemt om zijn wervings- en reclameactiviteiten niet te richten_aan hen. Hierbij valt te denken aan het verwijderen van personen van de mailinglijst, voor zover de vergunninghouder bij hen signalen van risicovol speelgedrag heeft geconstateerd.",
#       '49.Uit deze toelichting op artikel 12 van de Rwrvk blijkt volgens de commissie dat de wetgever met \'richten op\' tevens heeft bedoeld "richten aan Dit is niet beperkt tot de groep personen die signalen van risicovol speelgedrag vertonen. Uit artikel 2, derde lid, van het Bwrvk en de eerste zin van het citaat uit de toelichting blijkt dat onder maatschappelijk kwetsbare groepen ook worden verstaan personen die kenmerken van risicovol speelgedrag vertonen. In de laatste zin van het citaat uit de toelichting heeft de wetgever een voorbeeld gegeven dat gaat over deze specifieke groep.',
#       '55. Ten aanzien van het door Hillside in randnummer 80 van het bezwaarschrift aangevoerde standpunt over (het uitblijven van) duidelijke communicatie over de norm door de Kansspelautoriteit, is de commissie van oordeel dat de wet- en regelgeving op dit voldoende duidelijk is en geen verdere uitleg behoeft. Dat Hillside deze norm anders heeft geïnterpreteerd, valt de raad van bestuur niet te verwijten. Volgens de commissie mag van een professionele partij als Hillside redelijkerwijs worden verwacht dat zij zich heeft verdiept in de toepasselijke regelgeving en de toelichting daarop  in het bijzonder waar het haar zorgplicht voor het beschermen van jongvolwassenen tegen onmatige deelname betreft.',
#       '56.Op grond van bovenstaande overwegingen is de commissie van oordeel dat de raad van bestuur de overtreden norm, zoals vastgelegd in artikel 2, vierde lid, aanhef en onder a, van het Bwrvk, op de juiste manier heeft geïnterpreteerd . Volgens de commissie is er dan ook geen sprake van strijd met het rechtszekerheidsbeginsel en het lex certa-beginsel .',
#       '4.2.2. Ten aanzien van grond c',
#       '57 . Hillside betoogt dat de opgelegde boete niet passend en geboden is. Volgens Hillside had afgezien moeten worden van het opleggen van een boete, dan wel had de boetehoogte moeten worden gematigd.',
#       '58.De commissie stelt voorop dat de raad van bestuur beleidsruimte heeft bij het opleggen van een boete. Het enkele feit dat de raad van bestuur ook een andere'],
#      'head_text': ['OPENBAAR'],
#      'foot_text': ['10']},
#     {'body_text': ['maatregel kon opleggen, betekent nog niet dat een boete onrechtmatig is De commissie stelt vast dat in paragraaf 7 van het sanctiebesluit uitvoerig is gemotiveerd dat sprake is van een ernstige en verwijtbare overtreding en dat het daarom passend en geboden is om Hillside hiervoor een boete op te leggen.',
#       '59. Een punitieve sanctie heeft als doel generale en specifieke preventie van de overtreding. Een punitieve sanctie heeft een afschrikwekkende werking. Het enkel opleggen van een herstelsanctie zou tot gevolg hebben dat een vergunde aanbieder ongestraft wervings- en reclameactiviteiten kan (blijven) richten aan jongvolwassenen, totdat er een herstelsanctie wordt opgelegd. Een herstelsanctie heeft immers geen, of in veel mindere mate, afschrikwekkende werking. Hetzelfde geldt ten aanzien van een waarschuwing of een normoverdragend gesprek. Op grond hiervan is de commissie van oordeel dat het opleggen van een boete evenredig is aan de geconstateerde overtreding. Bovendien is dit in lijn met andere sanctiebesluiten bij vergelijkbare overtredingen. In dit kader verwijst de commissie ook naar randnummer 41 van dit advies.',
#       '60.De omstandigheid dat naast Hillside nog 4 andere vergunninghouders een boete hebben gekregen voor vergelijkbare overtredingen in een vergelijkbare periode bevestigt volgens de commissie juist dat de raad van bestuur niet in strijd met het gelijkheidsbeginsel heeft gehandeld, daar in alle gevallen sprake is van een situatie waarbij gedurende een periode van meerdere maanden veelvuldig reclameberichten aan jongvolwassenen zijn gestuurd.',
#       '61.De situaties waar Hillside naar verwijst in randnummers 93, 96-99, 114 van de aanvullende gronden hebben niet in een vergelijkbare periode en tijd14 (met uitzondering van randnummer 97) plaatsgevonden en hebben bovendien geen betrekking op eenzelfde situatie. Deze voorbeelden acht de commissie dan ook niet relevant.',
#       'Nu volgens de commissie de bezwaren van Hillside ten aanzien van de onrechtmatigheid van het sanctiebesluit geen stand kunnen houden  kan ook het bezwaar van Hillside dat het openbaarmakingsbesluit ten onrechte is genomen geen stand houden. Derhalve is er geen sprake van onevenredige benadeling. 71'],
#      'head_text': ['OPENBAAR'],
#      'foot_text': ['12']},
#     {'body_text': ['5. Conclusie',
#       '72. Op grond van het bovenstaande adviseert de adviescommissie de bezwaren tegen het sanctie- en openbaarmakingsbesluit ongegrond te verklaren en de beschikkingen, met aanvulling van de motivering zoals weergegeven in dit advies, in stand te laten. De commissie ziet ook geen aanleiding voor een vergoeding van de kosten.',
#       '73.Het advies is aldus vastgesteld te Den Haag op 30 november 2023, door de Adviescommissie bezwaarschriften van de Kansspelautoriteit, bestaande uit mevrouw mr A. Koppe (voorzitter)  mr. drs. A.C.M. Mulder en mr. K. Hollemans.',
#       'Namens de adviescommissie de voorzitter,',
#       'W.g.',
#       'mr. A Koppe'],
#      'head_text': ['OPENBAAR'],
#      'foot_text': ['13']}],
#    'header_dates': [],
#    'status': None},
#   {'url': 'https://kansspelautoriteit.nl/publish/library/32/15402_01-304-539_openbaarmakingsbesluit_woo_bob.pdf',
#    'pages': [{'body_text': ['Besluit als bedoeld in artikel 3.1 van de Wet open overheid.',
#       'Zaak: 15402 Kenmerk: 15402.001/01.304.538 Openbaarmaking onder: 15402.001/01.304.539',
#       'Besluit tot openbaarmaking',
#       'Besluit van de raad van bestuur van de Kansspelautoriteit tot openbaarmaking van het besluit op bezwaar van Hillside New Media Malta Plc (hierna: Hillside) van 12 december',
#       'Inleiding',
#       'In het besluit van 12 december 2023 met kenmerk 15402.001/ 01.304.536 heeft de raad van bestuur van de Kansspelautoriteit (hierna: de Kansspelautoriteit) de bezwaren van Hillside tegen het besluit tot het opleggen van een bestuurlijke boete en het besluit tot openbaarmaking ongegrond verklaard.',
#       'Overwegingen',
#       'De Kansspelautoriteit maakt besluiten in beginsel openbaar op grond van artikel 3.1 van de Wet open overheid (hierna: Woo).',
#       "De Kansspelautoriteit hecht eraan besluiten openbaar te maken vanwege het maatschappelijk belang om de consument te informeren over dan wel te waarschuwen voor bepaalde handelspraktijken van aanbieders van kansspelen en de risico's die consumenten daarbij Iopen. Dat geldt niet alleen voor sanctiebesluiten maar ook voor beslissingen op bezwaarschriften die zijn ingediend tegen sanctiebesluiten. Consumenten kunnen hiermee kennisnemen van de beslissingen die de Kansspelautoriteit geeft genomen na heroverweging en van de overwegingen die aan die besluiten ten grondslag liggen."],
#      'head_text': ['Kansspelautoriteit', 'OPENBAAR'],
#      'foot_text': []},
#     {'body_text': ['Daarnaast beoogt de Kansspelautoriteit met de openbaarmaking van besluiten transparantie te bieden met betrekking tot het functioneren van haar organisatie . Hiertoe geeft zij actief voorlichting over de uitvoering van aan haar opgedragen taken',
#       'Slechts indien het belang van een onderneming om openbaarmaking in een concreet geval te voorkomen zwaarder weegt dan het hierboven omschreven maatschappelijk belang, zal hierop een uitzondering worden gemaakt.',
#       '6 . Hillside heeft geen gebruik gemaakt van de gelegenheid om tijdens een hoorzitting haar bezwaren mondeling toe te lichten.',
#       'Hillside heeft in het bezwaarschrift aangevoerd dat het openbaarmakingsbesluit onrechtmatig zou zijn vanwege de onrechtmatigheid van het sanctiebesluit.',
#       'In dit geval is niet gebleken van feiten en omstandigheden op grond waarvan aanleiding bestaat om af te zien van openbaarmaking van het besluit op bezwaar .',
#       'De Kansspelautoriteit overweegt daarbij dat er geen aanleiding is te veronderstellen dat het besluit op bezwaar van 12 december 2023 in rechte geen stand zal houden. Naar het oordeel van de Kansspelautoriteit is afdoende aangetoond dat sprake is van een overtreding van artikel 2, vierde lid, aanhef en onder a van het Besluit werving, reclame en verslavingspreventie kansspelen. Daarvoor en voor de overige argumenten van Hillside verwijst de Kansspelautoriteit naar het advies van de adviescommissie.',
#       '10. De Kansspelautoriteit wijst erop dat de namen van natuurlijke personen en de namen van rechtspersonen die in het onderzoek zijn genoemd, maar van wie geen overtreding is vastgesteld, nimmer openbaar worden gemaakt. Verwijzingen naar namen die genoemd worden in jurisprudentie en reeds openbaar gemaakte besluiten van de Kansspelautoriteit vallen hier niet onder. Daarnaast zullen de gegevens die de raad van bestuur als bedrijfsvertrouwelijk beschouwt eveneens niet openbaar worden gemaakt.'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15402.001/01.304.538'],
#      'foot_text': []},
#     {'body_text': ['11.Van andere belangen of omstandigheden als bedoeld in de artikelen 5.1 . eerste tweede en vijfde lid, en 5.2 van de Woo, op grond waarvan zou moeten worden afgezien van openbaarmaking, is de Kansspelautoriteit niet gebleken.',
#       'Besluit',
#       '12.Op grond van het voorgaande zal de Kansspelautoriteit overgaan tot openbaarmaking van het besluit op bezwaar van Hillside van 12 december 2023 met kenmerk 15402.001/01.304.536. Tevens zal dit besluit tot openbaarmaking openbaar worden gemaakt.',
#       '13. In de openbaar te maken besluiten blijft vermelding van de namen van alle in de zaak betrokken natuurlijke personen achterwege. Ook blijft achterwege openbaarmaking van de namen van rechtspersonen ten aanzien van wie geen overtreding wordt vastgesteld en geen sanctie wordt opgelegd.',
#       '14. Openbaarmaking geschiedt door middel van publicatie op de website WWw.kansspelautoriteit.nI.',
#       'Den 14 december 2023',
#       'Hoogachtend,',
#       'De raad van bestuur van de Kansspelautoriteit, namens deze,',
#       'W.g.',
#       'mr. Laurence M.A. Gimbrere Hoofd afdeling Juridische Zaken en Vergunningen',
# ...
#       'Ook hetgeen Hillside heeft opgemerkt ten aanzien van de spelbeleving baat haar niet. Dit staat los van de overtreden norm. Bij het sturen van reclame per e-mail het immers niet om spelbeleving, maar om wervings- en reclameactiviteiten gericht op jongvolwassenen.',
#       'De vergelijking met en de opmerkingen over de bij besluit van 25 november 2022 opgelegde boete aan een andere aanbieder, kunnen Hillside evenmin baten. De opmerkingen van Hillside zien immers op dat specifieke besluit en de feiten en omstandigheden in die zaak en zijn niet relevant voor het thans voorliggende besluit. Hillside is geen belanghebbende bij dat besluit. Bovendien is dit besluit onherroepelijk, nu hiertegen geen bezwaar of beroep is ingesteld. Voor zover Hillside heeft willen betogen dat haar opmerkingen ook zien op haar situatie, zijn deze meegenomen in de motivering van het thans voorliggende besluit.',
#       'De Kansspelautoriteit concludeert dat het standpunt van Hillside dat de overtreden norm pas na 1 februari 2022 een totaalverbod op wervings- en reclameactiviteiten gericht op jongvolwassenen behelst, niet kan worden gevolgd. Ook voor 1 februari 2022 was duidelijk wat er in artikel 2, vierde lid, aanhef en onder a, van het Bwrvk is bepaald. Hillside had maatregelen moeten nemen om haar wervings- en reclameactiviteiten niet te richten op jongvolwassenen. Zij had de bij haar geregistreerde jongvolwassenen moeten uitsluiten van haar wervings- en reclameactiviteiten per e-mail, bijvoorbeeld door deze personen te verwijderen van de mailinglijst, gelijk personen waarbij de vergunninghouder signalen van risicovol speelgedrag heeft geconstateerd. Dit is technisch mogelijk en uitvoerbaar, zeker nu Hillside vanaf het moment van registratie bekend is met de leeftijd van alle bij haar geregistreerde spelers.',
#       '5.2.2 Er moet geen sanctie opgelegd worden',
#       'Mondelinge zienswijze Hillside heeft tijdens de hoorzitting betoogd dat, als al sprake zou zijn van een overtreding, het opleggen van een sanctie niet opportuun is. Aan dat betoog legt zij ten grondslag dat een andere (offline) aanbieder kennelijk jarenlang de wet heeft overtreden en dat dit niet is gesanctioneerd. Deze aanbieder had ook reclame in de vorm van e-mailberichten verstuurd naar jongvolwassenen. Hillside heeft kopieën van e-mails overgelegd om dat te onderbouwen. Ook konden jongvolwassenen'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '21 februari 2023',
#       'Ons kenmerk',
#       '15402/ 01.285.941'],
#      'foot_text': ['Pagina 10 van 15']},
#     {'body_text': ['gebruik maken van een loyaliteitsprogramma. Hillside, een nieuwe toetreder van de markt, heeft het voorbeeld van deze (offline) aanbieder gevolgd. Het is om die reden onevenredig, willekeurig en in strijd met het lex certa-beginsel om aan Hillside een sanctie op te leggen.',
#       "Bovendien heeft de Kansspelautoriteit in een ander geval, dat van de Nationale Postcode Loterij, breder levende twijfels over de invulling en afbakening' van een bepaalde norm doorslaggevend geacht bij de beslissing om géén boete op te leggen voor een geconstateerde overtreding. Nu zich dergelijke twijfels ook in het geval van Hillside voordoen, zou ook in het van Hillside moeten worden afgezien van het opleggen van een boete, aldus Hillside.",
#       'Beoordeling Zoals uitgebreid uiteengezet in paragraaf 5.2.1 volgt de Kansspelautoriteit het standpunt over de (on)duidelijkheid van de overtreden norm niet. Van strijd met het lex certa-beginsel of enig ander beginsel van behoorlijk bestuur is volgens de Kansspelautoriteit geen sprake. Uit wat Hillside aanvoert en heeft overgelegd, blijkt niet dat zij ervan uit mocht gaan dat zij de overtreding mocht begaan, noch dat zij daarvoor niet beboet zou worden.',
#       'Anders dan Hillside heeft betoogd en zoals hiervoor uitvoerig uiteengezet, was en is er enkele twijfel over de invulling en afbakening van de thans in het geding zijnde norm. Het gaat hier om het versturen van e-mailberichten met reclame aan jongvolwassenen hetgeen een feitelijk gegeven niet om het inzetten van een rolmodel, zoals het geval was bij de Nationale Postcode Loterij. Reeds daarom zou een beroep op het gelijkheidsbeginsel niet kunnen slagen.',
#       'Conclusie overtreding',

#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '21 februari 2023',
#       'Ons kenmerk',
#       '15402/ 01.285.941'],
#      'foot_text': ['Pagina 12 van 15']},
#     {'body_text': ['Daarbij is ook van belang dat in dit short odd-kansspelen werden aangeboden, namelijk online sportweddenschappen en online casinospelen. Uit de (wetenschappelijke) literatuur is bekend dat bij short-odd kansspelen meer verslaafde spelers te vinden zijn dan bij Iong odd-kansspelen, zoals loterijen. Bij zulke kansspelen speelt verslavingsproblematiek derhalve een extra grote rol van betekenis.',
#       "De Kansspelautoriteit verwijst daarbij ter illustratie naar de uitspraak van de Afdeling van 22 februari 2017, waarin overwogen wordt: 'Naast het feit dat er geen direct contact is tussen de consument en de marktdeelnemer, vormen de zeer gemakkelijke en permanente toegang tot kansspelen die op internet worden aangeboden, alsook de potentieel grote omvang en hoge frequentie van het betrokken internationale aanbod, in een omgeving die bovendien wordt gekenmerkt door het isolement van de speler, een klimaat van anonimiteit en het ontbreken van sociale controle, evenzoveel factoren die een toename van gokverslaving en geldverkwisting door gokken en dus ook van de negatieve sociale en morele gevolgen daarvan in de hand werken (zie onder meer het arrest van het HvJ van 8 september 2010, Carmen Media Group  ECLI:EU:C:2010.505, punten 102 en 103 en de daar aangehaalde rechtspraak) . Niet voor niets is een van de speerpunten in de Wok en het Nederlandse kansspelbeleid het beschermen van jongvolwassenen binnen het legale aanbod. 8",
#       'Verwijtbaarheid 64 . Bij de beoordeling van de verwijtbaarheid van de overtreding door Hillside acht de Kansspelautoriteit de volgende omstandigheden van belang .',
#       'Hillside heeft zich op het standpunt gesteld dat pas op 1 februari 2022 voor de sector duidelijk is geworden dat artikel 2, vierde lid, aanhef en onder a, van het Bwrvk, een verbod op het sturen van reclameberichten aan jongvolwassenen bevat. Zoals uitgebreid toegelicht in paragraaf 5.2 volgt de Kansspelautoriteit Hillside daar niet in. Van een vergunninghouder mag worden verwacht dat die de geldende wettelijke regels en andere voorwaarden kent en naleeft. Hillside had kunnen en',
#       'moeten weten dat zij artikel 2, vierde lid, aanhef en onder a, van het Bwrvk heeft overtreden door reclameberichten te versturen aan jongvolwassenen via e-mails. Dit maakt dat de overtreding niet alleen ernstig is, maar ook aan Hillside te verwijten is.',
#       'Ondanks het feit dat Hillside bekend was met de leeftijd van alle bij haar geregistreerde spelers en ondanks het feit dat het verwijderen van',
#       'Kamerstukken II 2021/22, 24 557, nr. 191.'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '21 februari 2023',
#       'Ons kenmerk',
#       '15402/ 01.285.941'],
#      'foot_text': ['Pagina 13 van 15']},
#     {'body_text': ['jongvolwassenen van de mailinglijst technisch mogelijk en uitvoerbaar was, heeft Hillside haar wervings- en reclameactiviteiten gericht op een aanzienlijk deel van de bij haar geregistreerde jongvolwassen, in de vorm van e-mails. Hillside bleef hiermee doorgaan  ook toen de Kansspelautoriteit medio december 2021 ten aanzien van bonussen nogmaalss duidelijk had gemaakt dat bonussen ook een wervings- en reclameactiviteit zijn, dat de algemene regels ten aanzien van wervings- en reclameactiviteiten ook op bonussen van toepassing zijn en dat voor aanbieders van online kansspelen geldt dat bonussen niet gericht mogen worden op jongvolwassenen.',
#       '7.4 Overige omstandigheden 67 . Het overtreden van de norm uit artikel 2, vierde lid, aanhef en onder a van het Bwrvk is een standaard onderdeel van de bedrijfsvoering geweest. Dit is reden voor de Kansspelautoriteit om het begaan van deze overtreding zwaar aan Hillside aan te rekenen',
#       'Hillside heeft de overtreding (naar eigen zeggen) gestaakt per 1 februari 2022. De Kansspelautoriteit acht dit echter omstandigheid die de overtreding minder verwijtbaar maakt. Dat de overtreding per 1 februari 2022 is gestaakt, neemt niet weg dat Hillside vanaf 26 oktober 2021 reclameberichten aan jongvolwassen heeft gestuurd.',
#       'Boetebepaling',
#       'Gelet op het bovenstaande acht de Kansspelautoriteit het passend en geboden dat een boete wordt opgelegd aan Hillside .',
#       'Gelet op de ernst en de verwijtbaarheid zoals hierboven toegelicht, wordt een basisbedrag van € 350.000, passend geacht.',
#       'Daar komt bij dat deze overtreding gedurende langere tijd onderdeel van de bedrijfsvoering van Hillside is geweest. Daarom wordt een verhoging van € 50.000, - passend geacht. Dat Hillside betoogt zelf gestopt te zijn in februari 2022, is in deze niet boeteverlagend. Gelet hierop kiest de Kansspelautoriteit er wel voor om het boetebedrag niet verder te verhogen.',
#       'Alles afwegende stelt de Kansspelautoriteit de boete vast op een totaalbedrag van € 400.000, Dit bedrag wordt, gelet op de omstandigheden van het geval, passend en geboden geacht.',
#       'Zie ook Kamerstukken II 2013/14, 33 996, nr.3 (p. 28) en de NvT bij het Bwrvk: Stb. 2021, 37 (p. 175).'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '21 februari 2023',
#       'Ons kenmerk',
#       '15402/ 01.285.941'],
#      'foot_text': ['Pagina 14 van 15']},
#     {'body_text': ['Besluit',
#       'De raad van bestuur van de Kansspelautoriteit:',
#       'a stelt vast dat Hillside artikel 2, vierde lid, aanhef en onder a, van het Bwrvk heeft overtreden door haar wervings- en reclameactiviteiten te richten op personen in de leeftijdscategorie tussen 18 en 24 jaar (jongvolwassenen) . b legt aan Hillside een boete op van € 400.000,',
#       "'s. Gravenhage, 21 februari 2023,",
#       'De raad van bestuur van de Kansspelautoriteit,',
#       'W.g',
#       'René J.P. Jansen voorzitter',
#       'VERZONDEN OP 24 FEBRUARI 2023',
#       'Bezwaar Tegen dit besluit kan degene wiens belang rechtstreeks bij dit besluit is betrokken, binnen zes weken na de dag van bekendmaking van dit besluit een gemotiveerd bezwaarschrift indienen bij de Kansspelautoriteit, afdeling Juridische Zaken en Vergunningen, Postbus 298, 2501 CG Den Haag. U kunt uw bezwaarschrift ook digitaal indienen, door het in PDF-formaat te e-mailen naar griffie@kansspelautoriteit. nI. Let wel: het instellen van bezwaar schort de werking van dit besluit niet op.',
#       'Kunt u de beslissing op uw bezwaarschrift niet afwachten vanwege een spoedeisend belang? Dan kunt u bij de sector bestuursrecht van de rechtbank in uw arrondissement een verzoek om voorlopige voorziening indienen',
#       'Betaling_boete Boetes dienen binnen zes weken nadat het besluit op de in artikel 3:41 van de Algemene wet bestuursrecht voorgeschreven wijze bekend is gemaakt; te zijn betaald op bankrekeningnummer IBAN NLOZABNA0501634479 ten name van Kansspelautoriteit, Den Haag, Nederland, onder vermelding van het kenmerk van dit besluit. Na het verstrijken van deze termijn wordt de geldboete vermeerderd met de wettelijke rente'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '21 februari 2023',
#       'Ons kenmerk',
#       '15402/ 01.285.941'],
#      'foot_text': ['Pagina 15 van 15']}],
#    'header_dates': ['2023-02-21',
#     '2023-02-21',
#     '2023-02-21',
#     '2023-02-21',
#     '2023-02-21',
#     '2023-02-21',
#     '2023-02-21',
#     '2023-02-21',
#     '2023-02-21',
#     '2023-02-21',
#     '2023-02-21',
#     '2023-02-21',
#     '2023-02-21',
#     '2023-02-21'],
#    'status': None}],
#  'date_range': ('2023-02-21', '2023-12-12'),
#  'money': ['400000',
#   '400000',
#   '400000',
#   '400000',
#   '350000',
#   '600000',
#   '350000',
#   '350000',
#   '50000',
#   '400000'],
#  'ecli': [],
#  'case_detail_url': 'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/hillside-new-media-malta-plc/'}

# %% [markdown]
# # Write out
#
# Now write that augmented structure into something we can call a dataset

# %%
kse = wetsuite.helpers.localdata.MsgpackKV('kansspelautoriteit_extracted.db', key_type=str)

# %%
kse._put_meta('description', '''This is a plaintext form of the set of documents you can find under https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/ as PDFs.

        Since almost half of those PDFs do not have a text stream, this data is entirely OCR'd,
        so expect some typical OCR errors.  The OCR quality seems fairly decent, and some effort was made to remove headers and footers,
        yet there are some leftovers  like _ instead of . and = instead of :


        The data is a fairly nested structure of python objects (or JSON, before it's parsed).
        - .data is a list of cases.

        - each case is a dict, with a 
            - 'name', 
            - 'docs' (a list) 
            - and some extracted information like mentioned money amounts, the apparent date span of the case

        - each document in that mentioned list is is a dict, with keys like
            - 'url' - to the PDF it came from
            - 'status' - from the detail page (if we could find it - not 100%) 
            - extracted informations like 'header_dates' (comes from PDF contents)
            - 'pages' (a list)

        - each page in that list is a dict, which has keys:
            - 'body_text' - a list, which containts text fragments that are _almost_ like paragraphs 
                except that text may continue between pages anyway - currently still up to you to detect - 
                plus the post-OCR processing isn't perfect.
            - 'foot_text' - generally just [ "Pagina 1 van 27" ]
            - 'head_text' - fragments like []"Kansspelautoriteit", "OPENBAAR"] but also the date and kenmerk lines


        (TODO: update this example)
        For example (body text edited for brevity), one case's dict, with one document:
            { # dict for a case
                'name': 'Toto Online B.V.',  # case's name
                'docs': [                    # list of PDF documents in this case
                    { # dict detailing first document in case
                        'url': 'https://kansspelautoriteit.nl/publish/library/32/01_278_071_15091_sanctiebesluit_toto_ov.pdf',
                        'pages': [
                            {  # first page's dict   (currently contains only body's text fragments; idea was to split off header contents)
                                'body_text':[  # first page's text fragments
                                    'Besluit van de raad van [more sentence]',
                                    'Zaak: 15091 Kenmerk: 15091 [more kenmerk]',
                                    'Besluit',
                                    'Inleiding',
                                    'De raad van bestuur van de Kansspelautoriteit [more paragraph]'
                                ]
                            },
                            { # second page's dict
                                'body_text': [   # second page text fragment
                                'heeft heeft ontvangen sinds hij daar [more paragraph]',
                                'De toezichthouders zijn naar aanleiding [more paragraph]'
                                ]
                            } 
                            # ...more pages
                        ], 
                    }, # end of document dict
                    # ...more documents
                ]
            }
        ''')

# %%
for d in dataset_cases:
    kse.put( d.get('case_detail_url'), d)
