# %% [markdown]
# <a href="https://colab.research.google.com/github/scarfboy/wetsuite-dev/blob/main/examples/dataset_kansspelautoriteit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Purpose of this notebook
#
# Collect data from contents PDFs under https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/
#
# We are not aware of any API, so are currently collecting information based on scraping web pages.

# %% [markdown]
# NOTE: This is how a dataset was created. If you only care about how to _use_ that dataset, see [using_dataset_kansspelautoriteit.ipynb](../using_dataset_kansspelautoriteit.ipynb) instead.
#
# In the process we will give an example of extracting data from a website like that, reorganizing that data and, as it turns out, of applying OCR.
#
# If you _do_ want to read this code, e.g. to get a start at doing your own OCR processing, read on...
# (note also that this code relies on poppler (for PDF parsing) and easyOCR (for OCR), neither of which are quite trivial installs)

# %% [markdown]
# ### Preparation
# imports we will use, and some helper functions.

# %%
#imports
import hashlib, urllib, json, json, pprint, textwrap, re

import bs4, numpy

import wetsuite.helpers.localdata
import wetsuite.helpers.meta
import wetsuite.helpers.net
import wetsuite.helpers.format
import wetsuite.helpers.strings
import wetsuite.helpers.date
import wetsuite.extras.pdf
import wetsuite.extras.ocr


# helpers
def hash(data: bytes):
    ' calculate SHA1 hash of some data. '
    s1h = hashlib.sha1()
    s1h.update( data )
    return s1h.hexdigest()


def find_eur_money(s:str, minimum=0):
    ''' Given a string, returns a list of substrings that look like money amounts, e.g.
            find_eur_money('   EUR 10,-  ')       == ['10']
            find_eur_money('   EUR 10.    ')      == ['10']
            find_eur_money('   EUR100.000,-')     == ['100000']
            find_eur_money('   EUR100000  ')      == ['100000']
            find_eur_money('   \u20ac100.000')    == ['100000']   # but not commas, because Dutch uses that as a digit.  That should probably be configurable
            find_eur_money('   \u20ac 100000')    == ['100000']
            find_eur_money('   \u20ac 100000  ')  == ['100000']
    '''
    ret = []
    # the with-context was partially for debug, but might actually be useful to return
    for before, match_str, match_object, after in wetsuite.helpers.strings.findall_with_context(r"(?:EUR|\u20ac)\s*([0-9.]+)\b", s, 20):
        cap = match_object.groups()[0].replace('.','')
        try:
            if int(cap) < minimum:
                continue
        except ValueError as ve: # not parseable as number? Remove
            pass
        #print( '[%s]%s[%s] -> %r'%(before, match_str, after, cap) )
        ret.append(cap)
    return ret

# %% [markdown]
# ### Fetching the data

# %%
# Use a local store so that we only need to fetch the PDFs once, only render PDF pages once 
import wetsuite.helpers.localdata
pdfstore   = wetsuite.helpers.localdata.open_store('kansspel_pdfstore.db', key_type=str, value_type=bytes )     # URL -> PDF file bytestring
ocrstore   = wetsuite.helpers.localdata.open_store('kansspel_ocrstore.db', key_type=str, value_type=bytes )     # page-specific key -> json as bytes

# %% [markdown]
# #### Fetching case summaries
# Let's first scrape the webpage to figure out all cases, all documents that relate to each case
#
# This part isn't cached, because the details can change.

# %%
# The purpose of this section is to fill the following variable:
extracted_cases = []  # list of (casename, [list of document dicts], [same-sized list of ocr results])

maxpage  = 9999999  # will be set to the actual number of pages by the first (well, every) page we fetch
cur_page = 0        # zero-based counting in the pagination

print( "FETCHING CASE SUMMARIES" )
while cur_page <= maxpage:
    page_url = 'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=%d'%cur_page
    print( page_url )
                
    page_data = wetsuite.helpers.net.download(page_url)
    soup = bs4.BeautifulSoup( page_data, 'lxml' )

    # get the amount of pages, from the pagination links
    pagelinks = soup.select('a[class~="pager_step"][class~="pagina"]')   # CSS selector looking for both of those classes set in a whitespace-token list
    maxpage = int( pagelinks[-1].get('data-page') )                      # -1: last of those we see on the page

    print( "page %d of %d"%( cur_page+1, maxpage+1 ) ) # numbering is zero-based,  print out one-based for humans

    # fetch all links to specific case detail pages
    for detail_page_a in soup.select('#results a[class~="siteLink"]'): # pick out the links (URLs) of the detail page of each case
        detail_page_url = detail_page_a.get('href') # these are already absolute  (otherwise we'd have to urljoin them)
        case_name = detail_page_a.text.replace('/','_')
        case_dict = {
            'name':case_name,
            'date_range':[],
            'money':[],
            'ecli':[],
            'case_detail_url':detail_page_url,
        }

        print()
        print( '  Case: %r'%(case_name) )

        # Note: the date shown here and on the detail page may be the start date?   It may still useful to distinguish cases for repeat offenders


        ### fetch that case's detail page, and find all PDF links on it
        # This section used to be three lines long, until we decided that hey, maybe that status would be nice to have.
        # Then we discovered this is a free-form mess
        # and this is the hand-crafted combination of of exception cases that will probably break in the future.

        #if detail_page_url in (
        #    #'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/toto-online/',
        #    #'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/1x-corp-exinvest/',
        #          status is voor beiden eersten
        #    #'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/vriendenloterij/',
        #    #'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/redslots/',
        #):
        #    print("SKIP FOR NOW: %r"%detail_page_url)
        #    continue


        #print( detail_page_url )
        detail_page_data = wetsuite.helpers.net.download( detail_page_url )
        detail_soup = bs4.BeautifulSoup( detail_page_data, 'lxml' )
        
        ## Construct a list of dicts, one for each document, with keys 'title', 'status', and 'pdf_url'
        doc_dicts, cur = [], {}

        def check_add_clear():
            global doc_dicts, cur
            ''' if there's sensible content, we add it to our list of docs.
                clears cur for next document
            '''
            # if effectively empty, do nothing at all
            if len(cur.keys())==1  and  'title' in cur  and  cur['title']=='': # effectively empty. Also one of a handful of exception cases
                pass
            elif len(cur)>0: # effectively empty
                # fail if it's incomplete, so that I fix it.
                if 'title' not in cur:
                    raise ValueError('scraping code is missing title, cur=%r'%cur)
                if 'pdf_url' not in cur:
                    raise ValueError('scraping code is missing pdf_url, cur=%r'%cur)
                #if 'status' not in cur:
                #    raise ValueError('scraping code is missing status, cur=%r'%cur) that happens, see e.g. https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/n1-interactive/ or https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/1x-corp-exinvest/
                #print("ADD %r"%cur)
                doc_dicts.append(cur)
            cur = {}


        pdflinks = list( detail_soup.select('a[class~="importLink"][class~="pdf"]') ) # used only to find the content block now, we need more structure from the page
        # (and things like select('div[class~="grid-blok"] div[class~="grid-element"] div[class~="grid-inside"] div[class~="iprox-content"]') is not specific enough, that's a general template
        if len(pdflinks)==0:
            print("WARNING - no content?")
        else:
            # This whole part used to be short, and readable(ish), but the pages are a bit messy so it ended up with a lot of exception cases.

            # a sequence of one or more:  h2 (title) p (link) h2-or-h3 "status" p (status text)            
            # but I've seen an initial paragraph in front of it. and a header and a paragraph in front of it.
            child = pdflinks[0].parent.previous_element # try to position on the first document's title header. Parent would be the P
            while child.name is None and child.previous_sibling is not None: # find previous non-text node.  There must be a better way of doing this.
                child = child.previous_sibling
            #print( 'Chosen starting spot: ', child )

            while child is not None:
                if child.name: # filter out text nodes (iirc)
                    pdflinks = list( child.select('a[class~="importLink"][class~="pdf"]') )
                    has_pdflinks = len(pdflinks) > 0
                    alltext = (''.join(child.findAll(text=True))).strip().lower().strip(':')

                    # augmenting some things we find
                    case_dict['money'].extend( find_eur_money(alltext, minimum=5001) )
                    case_dict['ecli'].extend( wetsuite.helpers.meta.findall_ecli(alltext, rstrip_dot=True) )

                    #print( "LOOKING AT %r"% str(child).strip() )
                    if child.name in ('h2','h3'):
                        if has_pdflinks: # weird case in https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/vriendenloterij/
                            cur['pdf_url'] = urllib.parse.urljoin( detail_page_url, pdflinks[0].get('href') )   # make relative URLs absolute
                            if 'title' not in cur: # would be overwritten in almost all cases
                                cur['title'] = alltext # but helps deal with https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/1x-corp-exinvest/
                        else:
                            if alltext == 'status': # header that just says 'status'
                                #print('HEADER - "status"')
                                pass 
                            else: # probably a title
                                #print('HEADER - title?')
                                check_add_clear() # starts a new one, so:
                                cur['title'] = child.text
                    elif child.name == 'p':
                        if len(cur)==0: # dict empty?
                            pass # probably an initial paragraph
                        else:
                            if has_pdflinks: #elif 'pdf_url' not in cur:
                                #print('FIRST P - PDF URL')
                                cur['pdf_url'] = urllib.parse.urljoin( detail_page_url, pdflinks[0].get('href') )   # make relative URLs absolute
                            else: #elif 'pdf_url' in cur: # status text
                                #print('SECOND P - STATUS TEXT')
                                cur['status'] = child.text
                child = child.next_sibling
            check_add_clear()

            #import pprint
            #pprint.pprint( doc_dicts )
            print( '    # documents: %d'%len(doc_dicts) )


        extracted_cases.append( (case_dict, doc_dicts, []) )
        #break  # debug: stop after first case on page

    cur_page += 1
    #break  # debug: stop after first page
# Out:
# FETCHING CASE SUMMARIES
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=0
# page 1 of 6
#
#   Case: 'NetX Betting'
#     # documents: 2
#
#   Case: 'Bingoal Nederland B.V.'
#     # documents: 2
#
#   Case: 'Vriendenloterij N.V.'
#     # documents: 2
#
#   Case: 'Nationale Postcode Loterij N.V.'
#     # documents: 2
#
#   Case: 'GoldWin Ltd'
#     # documents: 2
#
#   Case: 'Merkur Casino Almere B.V.'
#     # documents: 2
#
#   Case: 'Betent'
#     # documents: 1
#
#   Case: 'Winning Poker Network'
#     # documents: 2
#
#   Case: 'Red Ridge Marketing'
#     # documents: 2
#
#   Case: 'Hillside New Media Malta Plc'
#     # documents: 2
#
#   Case: 'Probe Investments Limited'
#     # documents: 5
#
#   Case: 'Betpoint Group Limited'
#     # documents: 2
#
#   Case: 'N1 Interactive Limited'
#     # documents: 5
#
#   Case: 'Videoslots Limited'
#     # documents: 2
#
#   Case: 'Fairload Limited'
#     # documents: 5
#
#   Case: 'Equinox Dynamic N.V. & Domiseda and Partners s.r.o.'
#     # documents: 5
#
#   Case: 'Bingoal Nederland B.V.'
#     # documents: 4
#
#   Case: 'JOI Gaming Ltd'
#     # documents: 2
#
#   Case: 'Shark77.Ltd'
#     # documents: 5
#
#   Case: 'Holland Casino N.V.'
#     # documents: 6
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=1
# page 2 of 6
#
#   Case: 'Toto Online B.V.'
#     # documents: 0
#
#   Case: 'Nationale Postcode Loterij N.V.'
#     # documents: 2
#
#   Case: 'M.K.C Limited'
#     # documents: 2
#
#   Case: 'L.C.S Limited'
#     # documents: 2
#
#   Case: 'Gammix Limited'
#     # documents: 4
#
#   Case: 'Red Ridge Marketing'
#     # documents: 4
#
#   Case: 'Performing Media Limited'
#     # documents: 2
#
#   Case: 'Linkerik B.V.'
#     # documents: 4
#
#   Case: 'Onlinecasinobonus.nl'
#     # documents: 2
#
#   Case: 'LCB CORP'
#     # documents: 2
#
#   Case: 'Casinoscout.nl'
#     # documents: 2
#
#   Case: 'Online Casino Ground ltd'
#     # documents: 2
#
#   Case: 'Slots Dev'
#     # documents: 2
#
#   Case: 'Tipico Co. Ltd'
#     # documents: 2
#
#   Case: 'BSB Shop'
#     # documents: 2
#
#   Case: 'Luxury Bingo'
#     # documents: 2
#
#   Case: 'N1 Interactive Limited'
#     # documents: 5
#
#   Case: 'Staatsloterij B.V.'
#     # documents: 4
#
#   Case: 'Raging Rhino N.V.'
#     # documents: 2
#
#   Case: 'Lovelto Mar LTD'
#     # documents: 4
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=2
# page 3 of 6
#
#   Case: '1X Corp N.V._Exinvest Limited'
#     # documents: 4
#
#   Case: 'WL Deal'
#     # documents: 2
#
#   Case: 'Virtual Coin Gaming N.V.'
#     # documents: 6
#
#   Case: 'Clipboard Publications B.V.'
#     # documents: 2
#
#   Case: 'Kelner Automaten Service'
#     # documents: 0
#
#   Case: 'Schinveld BV'
#     # documents: 5
#
#   Case: 'Voormalig exploitant Dordrecht'
#     # documents: 2
#
#   Case: 'Voormalig exploitant Amersfoort'
#     # documents: 2
#
#   Case: 'Royal Panda Limited'
#     # documents: 5
#
#   Case: 'LeoVegas Gaming'
#     # documents: 4
#
#   Case: 'Pokerstars'
#     # documents: 5
#
#   Case: 'Chance Publications Malta Ltd'
#     # documents: 3
#
#   Case: 'Unibet'
#     # documents: 2
#
#   Case: 'Bwin'
#     # documents: 5
#
#   Case: 'Simbat Entertainment Systems en Spinity'
#     # documents: 6
#
#   Case: 'Com Coin Operated Machines'
#     # documents: 2
#
#   Case: 'Casumo'
#     # documents: 5
#
#   Case: 'Innovation Labs en Gaming Innovation Group'
#     # documents: 6
#
#   Case: 'Content Publishing Limited'
#     # documents: 5
#
#   Case: 'Exploiteren zonder vergunning in café'
#     # documents: 4
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=3
# page 4 of 6
#
#   Case: 'WHG (International) Limited'
#     # documents: 5
#
#   Case: 'Voormalig exploitant Abcoude'
#     # documents: 2
#
#   Case: 'CyberRock Entertainment N.V. en Honeydew Trading Limited.'
#     # documents: 6
#
#   Case: 'Mr Green Limited'
#     # documents: 4
#
#   Case: 'ITC Lounge Plaza'
#     # documents: 2
#
#   Case: 'Corona Limited'
#     # documents: 4
#
#   Case: 'Café restaurant De Kruik'
#     # documents: 2
#
#   Case: 'Bet-at-home'
#     # documents: 4
#
#   Case: 'Visionairy iGaming'
#     # documents: 4
#
#   Case: 'VriendenLoterij N.V.'
#     # documents: 8
#
#   Case: 'BankGiro Loterij N.V.'
#     # documents: 8
#
#   Case: 'Nationale Postcode Loterij N.V.'
#     # documents: 10
#
#   Case: 'Lotto B.V.'
#     # documents: 12
#
#   Case: 'Staatsloterij B.V.'
#     # documents: 8
#
#   Case: 'Holland Casino N.V.'
#     # documents: 4
#
#   Case: 'Catena Operations Limited'
#     # documents: 2
#
#   Case: 'Weddenopvoetbal.org'
#     # documents: 4
#
#   Case: 'JvG speelautomaten'
#     # documents: 2
#
#   Case: 'Trustfulgames.com Limited'
#     # documents: 7
#
#   Case: 'L.S.A. B.V'
#     # documents: 4
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=4
# page 5 of 6
#
#   Case: 'M-automaten exploitatie'
#     # documents: 2
#
#   Case: 'Wedwinkel Rotterdam'
#     # documents: 2
#
#   Case: 'Friese ondernemer'
#     # documents: 1
#
#   Case: 'Holland Gaming'
#     # documents: 2
#
#   Case: 'Olders Amusementsautomaten B.V.'
#     # documents: 1
#
#   Case: 'Duitse loterijen'
#     # documents: 2
#
#   Case: 'Dolle Pret in Almelo B.V.'
#     # documents: 2
#
#   Case: 'Redslots'
#     # documents: 4
#
#   Case: 'Café _ Bar Bağci'
#     # documents: 4
#
#   Case: 'Total E Soft Limited en XKL Limited'
#     # documents: 4
#
#   Case: 'Belhuis _ Internetcafé Ephesus'
#     # documents: 2
#
#   Case: 'V.O.F. AULON'
#     # documents: 2
#
#   Case: 'V.O.F. Bosma Amusement'
#     # documents: 2
#
#   Case: 'Stichting Sport Twente'
#     # documents: 4
#
#   Case: 'Thee- en koffiehuis Kayseri'
#     # documents: 4
#
#   Case: 'Eetcafé De Gouw'
#     # documents: 4
#
#   Case: 'Co Gaming Limited (voorheen Come On Europe Limited)'
#     # documents: 4
#
#   Case: 'Stichting Trefcentrum Brinkstraat'
#     # documents: 4
#
#   Case: 'Imperial E-club Limited'
#     # documents: 4
#
#   Case: 'Stichting Bil Kazan'
#     # documents: 4
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=5
# page 6 of 5
#
#   Case: '7Red.com'
# WARNING - no content?
#
#   Case: 'Villa Mountain View'
#     # documents: 4
#
#   Case: 'GT Beheersorganisatie'
#     # documents: 2
#
#   Case: 'Koffiehuis Vadi'
#     # documents: 2
#
#   Case: 'Gooische Bingo Show'
#     # documents: 2
#
#   Case: 'Globalstars'
#     # documents: 4
#
#   Case: 'Grand Café Randenbroek'
#     # documents: 4
#
#   Case: 'Onisac Limited en Mansion Online Casino Limited'
#     # documents: 9
#
#   Case: 'Café Lucky'
#     # documents: 4
#
#   Case: 'Star SAT Electronica'
#     # documents: 2
#
#   Case: 'Call Internet City'
#     # documents: 4
#
#   Case: 'Huizenloterij'
#     # documents: 4

# %%
# that produces a structure like (example for one case):
extracted_cases[0]
# Out:
# ({'name': 'NetX Betting',
#   'date_range': [],
#   'money': [],
#   'ecli': [],
#   'case_detail_url': 'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/netx-betting/'},
#  [{'title': 'Besluit last onder dwangsom NetX Betting',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_lod_1a_netx_betting_limited_ov_.pdf',
#    'status': 'Tegen dit besluit kan bezwaar worden gemaakt.'},
#   {'title': 'Besluit openbaarmaking NetX Betting',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_ov_.pdf',
#    'status': 'Tegen dit besluit kan bezwaar worden gemaakt.'}],
#  [])

# %% [markdown]
# ### Fetch the PDFs, OCR them
#
# The above fetched metadata and links to the PDF, but not yet the documents.
#
# We could have split up the 'fetch PDFs' and 'renders page and OCRs then', and stil might.
# This way we don't have to remember quite as much, and it's single-purpose anyway.
#
# This produces OCR results in their raw form -- (a bunch of text fragments with their positions) and does not use it yet.
# It sets this data on the same data structure (that third tuple item inited as []) - the section below actually uses it.
# Which is perhaps somewhat confusing.
#
# Doing the OCR for a hundred documents takes a few hours, which is why we cache the raw OCR results.

# %%
print( "FETCH PDFs,  OCRing pages" )

for case_i, case_tuple in enumerate(extracted_cases):
    case_dict, case_doc_dicts, _ = case_tuple
    case_name = case_dict['name']

    print('------------------------')
    print( "ENUM: %s"%case_i)
    print( "NAME: %s"%case_name)
    print( "DICTS: %s"%pprint.pformat(case_doc_dicts))
    for case_doc_dict in case_doc_dicts:   # for each PDF document in the case
        pdf_url = case_doc_dict['pdf_url']

        print( "== %s =="%wetsuite.helpers.format.url_basename( pdf_url ) )
        pdfbytes, _ = wetsuite.helpers.localdata.cached_fetch( pdfstore, pdf_url )
        doc_page_fragments = [] # list of lists:   [   [page1fragment1,page1fragment2], [page2fragment1,page2fragment2], etc.  ]   

        #if 0:   
        #    doc_text_pages == list( wetsuite.datacollect.pdf.page_text( pdfbytes ) )
        #else:

        # Render PDF images as images
        page_images = list( wetsuite.extras.pdf.pages_as_images(pdfbytes, dpi=200, antialiasing=True) )  # TODO: cache these too
        # high DPI and antialiasing does a _little_ better on things like periods and colons, but less than you'ld think.

        # For each page image, get OCR. This ic cached because this is sloooow, and PDFs are unlikely to change
        for page_i, page_image in enumerate(page_images):
            page_key = 'ocr::%s::%s'%(page_i, pdf_url)

            if page_key in ocrstore:
                print('     OCR - CACHED  for page %d of %d'%(page_i+1, len(page_images)))
                page_ocr_results = json.loads( ocrstore.get(page_key) )
            else: # generate and cache
                print('     OCR - DOING  for page %d of %d'%(page_i+1, len(page_images)))
                page_ocr_results = wetsuite.extras.ocr.easyocr( page_image, use_gpu=True ) # CONSIDER: prefer?

                ocrstore.put( page_key, json.dumps(page_ocr_results).encode('utf8') )

            #page_image.save( '%s__%s__page_%03d.png'%(case_name,  hash(pdfbytes), page_i+1) )
            # DEBUG: Draw OCR results on the page it came from, and save as PNG:
            #eval_image = wetsuite.extras.ocr.easyocr_draw_eval( page_image, page_ocr_results )
            #eval_image.save('%s__%s__page_%03d-boxes.png'%(case_name,  hash(pdfbytes), page_i+1))

            # I think this is here to potentially merge PDF text objects into the same sort of structure. As is it does nothing.
            page_fragments = []   # fragments of text in a page,  which in the case of EasyOCR will typically be lines at a time
            for bbox, text, cert in page_ocr_results:
                page_fragments.append( (bbox, text, cert) ) 
            doc_page_fragments.append( page_fragments ) # yes, this is currently just page_ocr_results, the idea was that the above might augment/simplify that

        extracted_cases[case_i][2].append( doc_page_fragments )
# Out:
# FETCH PDFs,  OCRing pages
# ------------------------
# ENUM: 0
# NAME: NetX Betting
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_lod_1a_netx_betting_limited_ov_.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit last onder dwangsom NetX Betting'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_ov_.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit openbaarmaking NetX Betting'}]
# == besluit_lod_1a_netx_betting_limited_ov_.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 14
# first use of ocr() - loading EasyOCR model (into GPU)
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:252: UserWarning: Accessing the model URLs via the internal dictionary of the module is deprecated since 0.13 and will be removed in 0.15. Please access them via the appropriate Weights Enum instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#      OCR - DOING  for page 2 of 14
#      OCR - DOING  for page 3 of 14
#      OCR - DOING  for page 4 of 14
#      OCR - DOING  for page 5 of 14
#      OCR - DOING  for page 6 of 14
#      OCR - DOING  for page 7 of 14
#      OCR - DOING  for page 8 of 14
#      OCR - DOING  for page 9 of 14
#      OCR - DOING  for page 10 of 14
#      OCR - DOING  for page 11 of 14
#      OCR - DOING  for page 12 of 14
#      OCR - DOING  for page 13 of 14
#      OCR - DOING  for page 14 of 14
# == besluit_openbaarmaking_ov_.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 6
#      OCR - DOING  for page 2 of 6
#      OCR - DOING  for page 3 of 6
#      OCR - DOING  for page 4 of 6
#      OCR - DOING  for page 5 of 6
#      OCR - DOING  for page 6 of 6
# ------------------------
# ENUM: 1
# NAME: Bingoal Nederland B.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-288-556_15404_sanctiebesluit_bingoal.pdf',
#   'status': 'Tegen dit besluit\xa0is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15404_bingoal_openbaarmakingsbesluit_002_.pdf',
#   'status': 'Tegen dit besluit\xa0is\xa0bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit'}]
# == 01-288-556_15404_sanctiebesluit_bingoal.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == 15404_bingoal_openbaarmakingsbesluit_002_.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 2
# NAME: Vriendenloterij N.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230523_01-291-294_openbaar_besluit_last_onder_dwangsom_vl_spellen.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit last onder dwangsom Vriendenloterij N.V.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230523_01-291-296_openbare_versie_openbaarmakingsbesluit_woo_vl_last.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit openbaarmaking Vriendenloterij N.V.'}]
# == 20230523_01-291-294_openbaar_besluit_last_onder_dwangsom_vl_spellen.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 30
#      OCR - CACHED  for page 2 of 30
#      OCR - CACHED  for page 3 of 30
#      OCR - CACHED  for page 4 of 30
#      OCR - CACHED  for page 5 of 30
#      OCR - CACHED  for page 6 of 30
#      OCR - CACHED  for page 7 of 30
#      OCR - CACHED  for page 8 of 30
#      OCR - CACHED  for page 9 of 30
#      OCR - CACHED  for page 10 of 30
#      OCR - CACHED  for page 11 of 30
#      OCR - CACHED  for page 12 of 30
#      OCR - CACHED  for page 13 of 30
#      OCR - CACHED  for page 14 of 30
#      OCR - CACHED  for page 15 of 30
#      OCR - CACHED  for page 16 of 30
#      OCR - CACHED  for page 17 of 30
#      OCR - CACHED  for page 18 of 30
#      OCR - CACHED  for page 19 of 30
#      OCR - CACHED  for page 20 of 30
#      OCR - CACHED  for page 21 of 30
#      OCR - CACHED  for page 22 of 30
#      OCR - CACHED  for page 23 of 30
#      OCR - CACHED  for page 24 of 30
#      OCR - CACHED  for page 25 of 30
#      OCR - CACHED  for page 26 of 30
#      OCR - CACHED  for page 27 of 30
#      OCR - CACHED  for page 28 of 30
#      OCR - CACHED  for page 29 of 30
#      OCR - CACHED  for page 30 of 30
# == 20230523_01-291-296_openbare_versie_openbaarmakingsbesluit_woo_vl_last.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 3
# NAME: Nationale Postcode Loterij N.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230523_01-291-288_openbaar_besluit_last_onder_dwangsom_npl_spellen.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit Last onder dwangsom Nationale Postcode Loterij N.V.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230523_01-291-290_openbare_versie_openbaarmakingsbesluit_woo_npl_last.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit openbaarmaking Nationale Postcode Loterij N.V.'}]
# == 20230523_01-291-288_openbaar_besluit_last_onder_dwangsom_npl_spellen.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 31
#      OCR - CACHED  for page 2 of 31
#      OCR - CACHED  for page 3 of 31
#      OCR - CACHED  for page 4 of 31
#      OCR - CACHED  for page 5 of 31
#      OCR - CACHED  for page 6 of 31
#      OCR - CACHED  for page 7 of 31
#      OCR - CACHED  for page 8 of 31
#      OCR - CACHED  for page 9 of 31
#      OCR - CACHED  for page 10 of 31
#      OCR - CACHED  for page 11 of 31
#      OCR - CACHED  for page 12 of 31
#      OCR - CACHED  for page 13 of 31
#      OCR - CACHED  for page 14 of 31
#      OCR - CACHED  for page 15 of 31
#      OCR - CACHED  for page 16 of 31
#      OCR - CACHED  for page 17 of 31
#      OCR - CACHED  for page 18 of 31
#      OCR - CACHED  for page 19 of 31
#      OCR - CACHED  for page 20 of 31
#      OCR - CACHED  for page 21 of 31
#      OCR - CACHED  for page 22 of 31
#      OCR - CACHED  for page 23 of 31
#      OCR - CACHED  for page 24 of 31
#      OCR - CACHED  for page 25 of 31
#      OCR - CACHED  for page 26 of 31
#      OCR - CACHED  for page 27 of 31
#      OCR - CACHED  for page 28 of 31
#      OCR - CACHED  for page 29 of 31
#      OCR - CACHED  for page 30 of 31
#      OCR - CACHED  for page 31 of 31
# == 20230523_01-291-290_openbare_versie_openbaarmakingsbesluit_woo_npl_last.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 4
# NAME: GoldWin Ltd
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230420_01-291-425_besluit_lod_goldwin_ltd_ov_.pdf',
#   'title': 'Besluit last onder dwangsom GoldWin Ltd'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230420_01-191-426_besluit_openbaarmaking_ov_.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit tot openbaarmaking GoldWin Ltd'}]
# == 20230420_01-291-425_besluit_lod_goldwin_ltd_ov_.pdf ==
# A b'%PDF-1.6'
#      OCR - CACHED  for page 1 of 12
#      OCR - CACHED  for page 2 of 12
#      OCR - CACHED  for page 3 of 12
#      OCR - CACHED  for page 4 of 12
#      OCR - CACHED  for page 5 of 12
#      OCR - CACHED  for page 6 of 12
#      OCR - CACHED  for page 7 of 12
#      OCR - CACHED  for page 8 of 12
#      OCR - CACHED  for page 9 of 12
#      OCR - CACHED  for page 10 of 12
#      OCR - CACHED  for page 11 of 12
#      OCR - CACHED  for page 12 of 12
# == 20230420_01-191-426_besluit_openbaarmaking_ov_.pdf ==
# A b'%PDF-1.6'
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 5
# NAME: Merkur Casino Almere B.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-289-330_15484_sanctiebesluit_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Sanctiebesluit'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-289-336_15484_openbaarmakingsbesluit_woo_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt',
#   'title': 'Openbaarmakingsbesluit'}]
# == 01-289-330_15484_sanctiebesluit_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 16
#      OCR - CACHED  for page 2 of 16
#      OCR - CACHED  for page 3 of 16
#      OCR - CACHED  for page 4 of 16
#      OCR - CACHED  for page 5 of 16
#      OCR - CACHED  for page 6 of 16
#      OCR - CACHED  for page 7 of 16
#      OCR - CACHED  for page 8 of 16
#      OCR - CACHED  for page 9 of 16
#      OCR - CACHED  for page 10 of 16
#      OCR - CACHED  for page 11 of 16
#      OCR - CACHED  for page 12 of 16
#      OCR - CACHED  for page 13 of 16
#      OCR - CACHED  for page 14 of 16
#      OCR - CACHED  for page 15 of 16
#      OCR - CACHED  for page 16 of 16
# == 01-289-336_15484_openbaarmakingsbesluit_woo_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 6
# NAME: Betent
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/betent_15403_openbaarmakingsbesluit.pdf',
#   'status': 'Tegen dit besluit kan nog bezwaar worden gemaakt.',
#   'title': '19 april 2023'}]
# == betent_15403_openbaarmakingsbesluit.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 7
# NAME: Winning Poker Network
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230228_01-285-044_lod_openbare_versie_beveiligd.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Sanctiebesluit Winning Poker Network'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20220228_01-287-832_besluit_openbaarmaking_openbare_versie_beveiligd.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit Winning Poker Network'}]
# == 20230228_01-285-044_lod_openbare_versie_beveiligd.pdf ==
# A b'%PDF-1.6'
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == 20220228_01-287-832_besluit_openbaarmaking_openbare_versie_beveiligd.pdf ==
# A b'%PDF-1.6'
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 8
# NAME: Red Ridge Marketing
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-286-861_15395_sanctiebesluit_ov.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Sanctiebesluit Red Ridge Marketing'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15395_openbaarmakingsbesluit_ov.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Openbaarmakingsbesluit Red Ridge Marketing'}]
# == 01-286-861_15395_sanctiebesluit_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 16
#      OCR - CACHED  for page 2 of 16
#      OCR - CACHED  for page 3 of 16
#      OCR - CACHED  for page 4 of 16
#      OCR - CACHED  for page 5 of 16
#      OCR - CACHED  for page 6 of 16
#      OCR - CACHED  for page 7 of 16
#      OCR - CACHED  for page 8 of 16
#      OCR - CACHED  for page 9 of 16
#      OCR - CACHED  for page 10 of 16
#      OCR - CACHED  for page 11 of 16
#      OCR - CACHED  for page 12 of 16
#      OCR - CACHED  for page 13 of 16
#      OCR - CACHED  for page 14 of 16
#      OCR - CACHED  for page 15 of 16
#      OCR - CACHED  for page 16 of 16
# == 15395_openbaarmakingsbesluit_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 9
# NAME: Hillside New Media Malta Plc
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15402_01-285-941_besluit-signed_openbare_versie.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Sanctiebesluit Hillside'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-287-123_openbaarmakingsbesluit_woo_openbare_versie.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit Hillside'}]
# == 15402_01-285-941_besluit-signed_openbare_versie.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 15
#      OCR - CACHED  for page 2 of 15
#      OCR - CACHED  for page 3 of 15
#      OCR - CACHED  for page 4 of 15
#      OCR - CACHED  for page 5 of 15
#      OCR - CACHED  for page 6 of 15
#      OCR - CACHED  for page 7 of 15
#      OCR - CACHED  for page 8 of 15
#      OCR - CACHED  for page 9 of 15
#      OCR - CACHED  for page 10 of 15
#      OCR - CACHED  for page 11 of 15
#      OCR - CACHED  for page 12 of 15
#      OCR - CACHED  for page 13 of 15
#      OCR - CACHED  for page 14 of 15
#      OCR - CACHED  for page 15 of 15
# == 01-287-123_openbaarmakingsbesluit_woo_openbare_versie.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# ------------------------
# ENUM: 10
# NAME: Probe Investments Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15269_01-294-564_beslissing_op_bezwaar_ov.pdf',
#   'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep '
#             'worden ingesteld bij de rechtbank.',
#   'title': 'Beslissing op bezwaar Probe'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15269_01-294-565_openbaarmakingsbesluit_woo_bob_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit beslissing op bezwaar Probe'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15269_01-293-484_bac_advies_ov.pdf',
#   'title': 'BAC Advies Probe'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15269_01-281-231_sanctiebesluit_probe_investments_limited_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Probe'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15269_01-281-234_besluit_openbaarmaking_probe_investments_limited_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit Probe'}]
# == 15269_01-294-564_beslissing_op_bezwaar_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 3
#      OCR - DOING  for page 2 of 3
#      OCR - DOING  for page 3 of 3
# == 15269_01-294-565_openbaarmakingsbesluit_woo_bob_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 4
#      OCR - DOING  for page 2 of 4
#      OCR - DOING  for page 3 of 4
#      OCR - DOING  for page 4 of 4
# == 15269_01-293-484_bac_advies_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 20
#      OCR - DOING  for page 2 of 20
#      OCR - DOING  for page 3 of 20
#      OCR - DOING  for page 4 of 20
#      OCR - DOING  for page 5 of 20
#      OCR - DOING  for page 6 of 20
#      OCR - DOING  for page 7 of 20
#      OCR - DOING  for page 8 of 20
#      OCR - DOING  for page 9 of 20
#      OCR - DOING  for page 10 of 20
#      OCR - DOING  for page 11 of 20
#      OCR - DOING  for page 12 of 20
#      OCR - DOING  for page 13 of 20
#      OCR - DOING  for page 14 of 20
#      OCR - DOING  for page 15 of 20
#      OCR - DOING  for page 16 of 20
#      OCR - DOING  for page 17 of 20
#      OCR - DOING  for page 18 of 20
#      OCR - DOING  for page 19 of 20
#      OCR - DOING  for page 20 of 20
# == 15269_01-281-231_sanctiebesluit_probe_investments_limited_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 27
#      OCR - CACHED  for page 2 of 27
#      OCR - CACHED  for page 3 of 27
#      OCR - CACHED  for page 4 of 27
#      OCR - CACHED  for page 5 of 27
#      OCR - CACHED  for page 6 of 27
#      OCR - CACHED  for page 7 of 27
#      OCR - CACHED  for page 8 of 27
#      OCR - CACHED  for page 9 of 27
#      OCR - CACHED  for page 10 of 27
#      OCR - CACHED  for page 11 of 27
#      OCR - CACHED  for page 12 of 27
#      OCR - CACHED  for page 13 of 27
#      OCR - CACHED  for page 14 of 27
#      OCR - CACHED  for page 15 of 27
#      OCR - CACHED  for page 16 of 27
#      OCR - CACHED  for page 17 of 27
#      OCR - CACHED  for page 18 of 27
#      OCR - CACHED  for page 19 of 27
#      OCR - CACHED  for page 20 of 27
#      OCR - CACHED  for page 21 of 27
#      OCR - CACHED  for page 22 of 27
#      OCR - CACHED  for page 23 of 27
#      OCR - CACHED  for page 24 of 27
#      OCR - CACHED  for page 25 of 27
#      OCR - CACHED  for page 26 of 27
#      OCR - CACHED  for page 27 of 27
# == 15269_01-281-234_besluit_openbaarmaking_probe_investments_limited_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 11
# NAME: Betpoint Group Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/ov_15164_01-281-226_sanctiebesluit_betpoint.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Betpoint'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/ov_15164_01-281-229_betpoint_openbaarmaking.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit Betpoint'}]
# == ov_15164_01-281-226_sanctiebesluit_betpoint.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 31
#      OCR - CACHED  for page 2 of 31
#      OCR - CACHED  for page 3 of 31
#      OCR - CACHED  for page 4 of 31
#      OCR - CACHED  for page 5 of 31
#      OCR - CACHED  for page 6 of 31
#      OCR - CACHED  for page 7 of 31
#      OCR - CACHED  for page 8 of 31
#      OCR - CACHED  for page 9 of 31
#      OCR - CACHED  for page 10 of 31
#      OCR - CACHED  for page 11 of 31
#      OCR - CACHED  for page 12 of 31
#      OCR - CACHED  for page 13 of 31
#      OCR - CACHED  for page 14 of 31
#      OCR - CACHED  for page 15 of 31
#      OCR - CACHED  for page 16 of 31
#      OCR - CACHED  for page 17 of 31
#      OCR - CACHED  for page 18 of 31
#      OCR - CACHED  for page 19 of 31
#      OCR - CACHED  for page 20 of 31
#      OCR - CACHED  for page 21 of 31
#      OCR - CACHED  for page 22 of 31
#      OCR - CACHED  for page 23 of 31
#      OCR - CACHED  for page 24 of 31
#      OCR - CACHED  for page 25 of 31
#      OCR - CACHED  for page 26 of 31
#      OCR - CACHED  for page 27 of 31
#      OCR - CACHED  for page 28 of 31
#      OCR - CACHED  for page 29 of 31
#      OCR - CACHED  for page 30 of 31
#      OCR - CACHED  for page 31 of 31
# == ov_15164_01-281-229_betpoint_openbaarmaking.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 6
#      OCR - CACHED  for page 2 of 6
#      OCR - CACHED  for page 3 of 6
#      OCR - CACHED  for page 4 of 6
#      OCR - CACHED  for page 5 of 6
#      OCR - CACHED  for page 6 of 6
# ------------------------
# ENUM: 12
# NAME: N1 Interactive Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-292-870-beslissing_op_bezwaar_15244_ov.pdf',
#   'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep '
#             'worden ingesteld bij de rechtbank.',
#   'title': 'Beslissing op bezwaar N1 Interactive Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-292-895_besluit_openbaarmaking_15244_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit beslissing op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15244_01-291-871_bac_advies_ov_1.pdf',
#   'title': 'BAC Advies N1'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-281-253_sanctiebesluit_15244_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit N1 Interactive Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-281-256_openbaarmakingbesluit_15244_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit'}]
# == 01-292-870-beslissing_op_bezwaar_15244_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 3
#      OCR - DOING  for page 2 of 3
#      OCR - DOING  for page 3 of 3
# == 01-292-895_besluit_openbaarmaking_15244_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 3
#      OCR - DOING  for page 2 of 3
#      OCR - DOING  for page 3 of 3
# == 15244_01-291-871_bac_advies_ov_1.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 14
#      OCR - DOING  for page 2 of 14
#      OCR - DOING  for page 3 of 14
#      OCR - DOING  for page 4 of 14
#      OCR - DOING  for page 5 of 14
#      OCR - DOING  for page 6 of 14
#      OCR - DOING  for page 7 of 14
#      OCR - DOING  for page 8 of 14
#      OCR - DOING  for page 9 of 14
#      OCR - DOING  for page 10 of 14
#      OCR - DOING  for page 11 of 14
#      OCR - DOING  for page 12 of 14
#      OCR - DOING  for page 13 of 14
#      OCR - DOING  for page 14 of 14
# == 01-281-253_sanctiebesluit_15244_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 28
#      OCR - CACHED  for page 2 of 28
#      OCR - CACHED  for page 3 of 28
#      OCR - CACHED  for page 4 of 28
#      OCR - CACHED  for page 5 of 28
#      OCR - CACHED  for page 6 of 28
#      OCR - CACHED  for page 7 of 28
#      OCR - CACHED  for page 8 of 28
#      OCR - CACHED  for page 9 of 28
#      OCR - CACHED  for page 10 of 28
#      OCR - CACHED  for page 11 of 28
#      OCR - CACHED  for page 12 of 28
#      OCR - CACHED  for page 13 of 28
#      OCR - CACHED  for page 14 of 28
#      OCR - CACHED  for page 15 of 28
#      OCR - CACHED  for page 16 of 28
#      OCR - CACHED  for page 17 of 28
#      OCR - CACHED  for page 18 of 28
#      OCR - CACHED  for page 19 of 28
#      OCR - CACHED  for page 20 of 28
#      OCR - CACHED  for page 21 of 28
#      OCR - CACHED  for page 22 of 28
#      OCR - CACHED  for page 23 of 28
#      OCR - CACHED  for page 24 of 28
#      OCR - CACHED  for page 25 of 28
#      OCR - CACHED  for page 26 of 28
#      OCR - CACHED  for page 27 of 28
#      OCR - CACHED  for page 28 of 28
# == 01-281-256_openbaarmakingbesluit_15244_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 13
# NAME: Videoslots Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15167_01-281-259_sanctiebesluit_videoslots_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Videoslots Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-281-262_openbaarmakingsbesluit_videoslots_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit Videoslots Limited'}]
# == 15167_01-281-259_sanctiebesluit_videoslots_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 30
#      OCR - CACHED  for page 2 of 30
#      OCR - CACHED  for page 3 of 30
#      OCR - CACHED  for page 4 of 30
#      OCR - CACHED  for page 5 of 30
#      OCR - CACHED  for page 6 of 30
#      OCR - CACHED  for page 7 of 30
#      OCR - CACHED  for page 8 of 30
#      OCR - CACHED  for page 9 of 30
#      OCR - CACHED  for page 10 of 30
#      OCR - CACHED  for page 11 of 30
#      OCR - CACHED  for page 12 of 30
#      OCR - CACHED  for page 13 of 30
#      OCR - CACHED  for page 14 of 30
#      OCR - CACHED  for page 15 of 30
#      OCR - CACHED  for page 16 of 30
#      OCR - CACHED  for page 17 of 30
#      OCR - CACHED  for page 18 of 30
#      OCR - CACHED  for page 19 of 30
#      OCR - CACHED  for page 20 of 30
#      OCR - CACHED  for page 21 of 30
#      OCR - CACHED  for page 22 of 30
#      OCR - CACHED  for page 23 of 30
#      OCR - CACHED  for page 24 of 30
#      OCR - CACHED  for page 25 of 30
#      OCR - CACHED  for page 26 of 30
#      OCR - CACHED  for page 27 of 30
#      OCR - CACHED  for page 28 of 30
#      OCR - CACHED  for page 29 of 30
#      OCR - CACHED  for page 30 of 30
# == 01-281-262_openbaarmakingsbesluit_videoslots_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 14
# NAME: Fairload Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15151_01-294-550_beslissing_op_bezwaar-ov.pdf',
#   'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep '
#             'worden ingesteld bij de rechtbank.',
#   'title': 'Beslissing op bezwaar Fairload Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15151_01-294-553-openbaarmakingsbesluit_woo_bob_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit beslissing op bezwaar Fairload Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15151_bac_advies_ov.pdf',
#   'title': 'BAC Advies Fairload Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15151_ov_fairload_sanctiebesluit_def.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Fairload Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15151_01-281-217_ov_fairload_openbaarmaking.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit Fairload Limited'}]
# == 15151_01-294-550_beslissing_op_bezwaar-ov.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 3
#      OCR - DOING  for page 2 of 3
#      OCR - DOING  for page 3 of 3
# == 15151_01-294-553-openbaarmakingsbesluit_woo_bob_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 4
#      OCR - DOING  for page 2 of 4
#      OCR - DOING  for page 3 of 4
#      OCR - DOING  for page 4 of 4
# == 15151_bac_advies_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 22
#      OCR - DOING  for page 2 of 22
#      OCR - DOING  for page 3 of 22
#      OCR - DOING  for page 4 of 22
#      OCR - DOING  for page 5 of 22
#      OCR - DOING  for page 6 of 22
#      OCR - DOING  for page 7 of 22
#      OCR - DOING  for page 8 of 22
#      OCR - DOING  for page 9 of 22
#      OCR - DOING  for page 10 of 22
#      OCR - DOING  for page 11 of 22
#      OCR - DOING  for page 12 of 22
#      OCR - DOING  for page 13 of 22
#      OCR - DOING  for page 14 of 22
#      OCR - DOING  for page 15 of 22
#      OCR - DOING  for page 16 of 22
#      OCR - DOING  for page 17 of 22
#      OCR - DOING  for page 18 of 22
#      OCR - DOING  for page 19 of 22
#      OCR - DOING  for page 20 of 22
#      OCR - DOING  for page 21 of 22
#      OCR - DOING  for page 22 of 22
# == 15151_ov_fairload_sanctiebesluit_def.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 28
#      OCR - CACHED  for page 2 of 28
#      OCR - CACHED  for page 3 of 28
#      OCR - CACHED  for page 4 of 28
#      OCR - CACHED  for page 5 of 28
#      OCR - CACHED  for page 6 of 28
#      OCR - CACHED  for page 7 of 28
#      OCR - CACHED  for page 8 of 28
#      OCR - CACHED  for page 9 of 28
#      OCR - CACHED  for page 10 of 28
#      OCR - CACHED  for page 11 of 28
#      OCR - CACHED  for page 12 of 28
#      OCR - CACHED  for page 13 of 28
#      OCR - CACHED  for page 14 of 28
#      OCR - CACHED  for page 15 of 28
#      OCR - CACHED  for page 16 of 28
#      OCR - CACHED  for page 17 of 28
#      OCR - CACHED  for page 18 of 28
#      OCR - CACHED  for page 19 of 28
#      OCR - CACHED  for page 20 of 28
#      OCR - CACHED  for page 21 of 28
#      OCR - CACHED  for page 22 of 28
#      OCR - CACHED  for page 23 of 28
#      OCR - CACHED  for page 24 of 28
#      OCR - CACHED  for page 25 of 28
#      OCR - CACHED  for page 26 of 28
#      OCR - CACHED  for page 27 of 28
#      OCR - CACHED  for page 28 of 28
# == 15151_01-281-217_ov_fairload_openbaarmaking.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 6
#      OCR - CACHED  for page 2 of 6
#      OCR - CACHED  for page 3 of 6
#      OCR - CACHED  for page 4 of 6
#      OCR - CACHED  for page 5 of 6
#      OCR - CACHED  for page 6 of 6
# ------------------------
# ENUM: 15
# NAME: Equinox Dynamic N.V. & Domiseda and Partners s.r.o.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-281-220_sanctiebesluit_2022_openbaar.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_equinox_dynamic_domiseda.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Openbaarmakingsbesluit'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15255_01-293-635_beslissing_op_bezwaar_ov.pdf',
#   'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep '
#             'worden ingesteld bij de rechtbank.',
#   'title': 'Beslissing op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15255_01-293-637_bac_advies_def_ov.pdf',
#   'title': 'BAC Advies'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-293-636_openbaarmakingsbesluit_woo_bob_15255_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit bij beslissing op bezwaar'}]
# == 01-281-220_sanctiebesluit_2022_openbaar.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 16
#      OCR - CACHED  for page 2 of 16
#      OCR - CACHED  for page 3 of 16
#      OCR - CACHED  for page 4 of 16
#      OCR - CACHED  for page 5 of 16
#      OCR - CACHED  for page 6 of 16
#      OCR - CACHED  for page 7 of 16
#      OCR - CACHED  for page 8 of 16
#      OCR - CACHED  for page 9 of 16
#      OCR - CACHED  for page 10 of 16
#      OCR - CACHED  for page 11 of 16
#      OCR - CACHED  for page 12 of 16
#      OCR - CACHED  for page 13 of 16
#      OCR - CACHED  for page 14 of 16
#      OCR - CACHED  for page 15 of 16
#      OCR - CACHED  for page 16 of 16
# == openbaarmakingsbesluit_equinox_dynamic_domiseda.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# == 15255_01-293-635_beslissing_op_bezwaar_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 3
#      OCR - DOING  for page 2 of 3
#      OCR - DOING  for page 3 of 3
# == 15255_01-293-637_bac_advies_def_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 12
#      OCR - DOING  for page 2 of 12
#      OCR - DOING  for page 3 of 12
#      OCR - DOING  for page 4 of 12
#      OCR - DOING  for page 5 of 12
#      OCR - DOING  for page 6 of 12
#      OCR - DOING  for page 7 of 12
#      OCR - DOING  for page 8 of 12
#      OCR - DOING  for page 9 of 12
#      OCR - DOING  for page 10 of 12
#      OCR - DOING  for page 11 of 12
#      OCR - DOING  for page 12 of 12
# == 01-293-636_openbaarmakingsbesluit_woo_bob_15255_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 3
#      OCR - DOING  for page 2 of 3
#      OCR - DOING  for page 3 of 3
# ------------------------
# ENUM: 16
# NAME: Bingoal Nederland B.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_bingoal_8_febrauri_2023.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Bingoal Nederland B.V. (9 november 2022)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_bingoal_8_februari_2023.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingbesluit Bingoal Nederland B.V. (9 november 2022)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-289-608_advies_bac_bingoal_nederland_b-v_ov.pdf',
#   'status': 'Tegen dit besluit is beroep ingesteld.',
#   'title': 'Beslissing op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-289-607_openbaarmakingsbesluit_ov.pdf',
#   'status': 'Tegen dit besluit is beroep ingesteld.',
#   'title': 'Openbaarmakingsbesluit beslissing op bezwaar'}]
# == sanctiebesluit_bingoal_8_febrauri_2023.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 18
#      OCR - CACHED  for page 2 of 18
#      OCR - CACHED  for page 3 of 18
#      OCR - CACHED  for page 4 of 18
#      OCR - CACHED  for page 5 of 18
#      OCR - CACHED  for page 6 of 18
#      OCR - CACHED  for page 7 of 18
#      OCR - CACHED  for page 8 of 18
#      OCR - CACHED  for page 9 of 18
#      OCR - CACHED  for page 10 of 18
#      OCR - CACHED  for page 11 of 18
#      OCR - CACHED  for page 12 of 18
#      OCR - CACHED  for page 13 of 18
#      OCR - CACHED  for page 14 of 18
#      OCR - CACHED  for page 15 of 18
#      OCR - CACHED  for page 16 of 18
#      OCR - CACHED  for page 17 of 18
#      OCR - CACHED  for page 18 of 18
# == openbaarmakingsbesluit_bingoal_8_februari_2023.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 01-289-608_advies_bac_bingoal_nederland_b-v_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 15
#      OCR - CACHED  for page 2 of 15
#      OCR - CACHED  for page 3 of 15
#      OCR - CACHED  for page 4 of 15
#      OCR - CACHED  for page 5 of 15
#      OCR - CACHED  for page 6 of 15
#      OCR - CACHED  for page 7 of 15
#      OCR - CACHED  for page 8 of 15
#      OCR - CACHED  for page 9 of 15
#      OCR - CACHED  for page 10 of 15
#      OCR - CACHED  for page 11 of 15
#      OCR - CACHED  for page 12 of 15
#      OCR - CACHED  for page 13 of 15
#      OCR - CACHED  for page 14 of 15
#      OCR - CACHED  for page 15 of 15
# == 01-289-607_openbaarmakingsbesluit_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 17
# NAME: JOI Gaming Ltd
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_joi_gaming_ltd_10_januari_2023_.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit JOI Gaming Ltd (10 januari 2023)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_joi_gaming_ltd.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit JOI Gaming Ltd'}]
# == sanctiebesluit_joi_gaming_ltd_10_januari_2023_.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 14
#      OCR - CACHED  for page 2 of 14
#      OCR - CACHED  for page 3 of 14
#      OCR - CACHED  for page 4 of 14
#      OCR - CACHED  for page 5 of 14
#      OCR - CACHED  for page 6 of 14
#      OCR - CACHED  for page 7 of 14
#      OCR - CACHED  for page 8 of 14
#      OCR - CACHED  for page 9 of 14
#      OCR - CACHED  for page 10 of 14
#      OCR - CACHED  for page 11 of 14
#      OCR - CACHED  for page 12 of 14
#      OCR - CACHED  for page 13 of 14
#      OCR - CACHED  for page 14 of 14
# == openbaarmakingsbesluit_joi_gaming_ltd.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 18
# NAME: Shark77.Ltd
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/beslissing_op_bezwaar_ov.pdf',
#   'status': 'Tegen dit besluit kan beroep worden ingesteld.',
#   'title': 'Beslissing op bezwaar Shark77.Ltd'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_woo_bob_ov.pdf',
#   'status': 'Tegen dit besluit kan beroep worden ingesteld.',
#   'title': 'Openbaarmakingsbesluit beslissing op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/advies_bac_shark77_ov.pdf',
#   'title': 'BAC Advies Shark 77.Ltd'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_shark77.pdf',
#   'status': 'Tegen dit besluit\xa0is\xa0bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Shark77.Ltd'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_shark77.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Dit besluit is thans '
#             'onherroepelijk.',
#   'title': 'Openbaarmakingsbesluit Shark77.Ltd'}]
# == beslissing_op_bezwaar_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 3
#      OCR - DOING  for page 2 of 3
#      OCR - DOING  for page 3 of 3
# == openbaarmakingsbesluit_woo_bob_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 4
#      OCR - DOING  for page 2 of 4
#      OCR - DOING  for page 3 of 4
#      OCR - DOING  for page 4 of 4
# == advies_bac_shark77_ov.pdf ==
# A b'%PDF-1.5'
#      OCR - DOING  for page 1 of 14
#      OCR - DOING  for page 2 of 14
#      OCR - DOING  for page 3 of 14
#      OCR - DOING  for page 4 of 14
#      OCR - DOING  for page 5 of 14
#      OCR - DOING  for page 6 of 14
#      OCR - DOING  for page 7 of 14
#      OCR - DOING  for page 8 of 14
#      OCR - DOING  for page 9 of 14
#      OCR - DOING  for page 10 of 14
#      OCR - DOING  for page 11 of 14
#      OCR - DOING  for page 12 of 14
#      OCR - DOING  for page 13 of 14
#      OCR - DOING  for page 14 of 14
# == sanctiebesluit_shark77.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 22
#      OCR - CACHED  for page 2 of 22
#      OCR - CACHED  for page 3 of 22
#      OCR - CACHED  for page 4 of 22
#      OCR - CACHED  for page 5 of 22
#      OCR - CACHED  for page 6 of 22
#      OCR - CACHED  for page 7 of 22
#      OCR - CACHED  for page 8 of 22
#      OCR - CACHED  for page 9 of 22
#      OCR - CACHED  for page 10 of 22
#      OCR - CACHED  for page 11 of 22
#      OCR - CACHED  for page 12 of 22
#      OCR - CACHED  for page 13 of 22
#      OCR - CACHED  for page 14 of 22
#      OCR - CACHED  for page 15 of 22
#      OCR - CACHED  for page 16 of 22
#      OCR - CACHED  for page 17 of 22
#      OCR - CACHED  for page 18 of 22
#      OCR - CACHED  for page 19 of 22
#      OCR - CACHED  for page 20 of 22
#      OCR - CACHED  for page 21 of 22
#      OCR - CACHED  for page 22 of 22
# == openbaarmakingsbesluit_shark77.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 19
# NAME: Holland Casino N.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01_252_792_lod_hc.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Holland Casino N.V.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01_252_795_openbaarmakingsbesluit.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Besluit tot openbaarmaking'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01_263_938_bob_lod_hc.pdf',
#   'status': 'Tegen deze beslissing op bezwaar is inmiddels beroep ingesteld '
#             'bij de rechtbank.',
#   'title': 'Beslissing op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01_263_939_besluit_openbaarmaking_beslissing_op_bezwaar_holland_casino_n_v.pdf',
#   'status': 'Tegen dit besluit is inmiddels beroep ingesteld bij de rechtbank.',
#   'title': 'Besluit tot openbaarmaking'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01_264_668_invorderingsbeschikking_lod_hc.pdf',
#   'status': 'Tegen dit besluit is inmiddels beroep ingesteld bij de rechtbank.',
#   'title': 'Invorderingsbesluit'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01_268_588_besluit_tot_openbaarmaking_holland_casino_n_v.pdf',
#   'status': 'Tegen dit besluit is inmiddels beroep ingesteld bij de rechtbank.',
#   'title': 'Besluit tot openbaarmaking'}]
# == 01_252_792_lod_hc.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 9
#      OCR - CACHED  for page 2 of 9
#      OCR - CACHED  for page 3 of 9
#      OCR - CACHED  for page 4 of 9
#      OCR - CACHED  for page 5 of 9
#      OCR - CACHED  for page 6 of 9
#      OCR - CACHED  for page 7 of 9
#      OCR - CACHED  for page 8 of 9
#      OCR - CACHED  for page 9 of 9
# == 01_252_795_openbaarmakingsbesluit.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 01_263_938_bob_lod_hc.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == 01_263_939_besluit_openbaarmaking_beslissing_op_bezwaar_holland_casino_n_v.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 01_264_668_invorderingsbeschikking_lod_hc.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 8
#      OCR - CACHED  for page 2 of 8
#      OCR - CACHED  for page 3 of 8
#      OCR - CACHED  for page 4 of 8
#      OCR - CACHED  for page 5 of 8
#      OCR - CACHED  for page 6 of 8
#      OCR - CACHED  for page 7 of 8
#      OCR - CACHED  for page 8 of 8
# == 01_268_588_besluit_tot_openbaarmaking_holland_casino_n_v.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 20
# NAME: Toto Online B.V.
# DICTS: []
# ------------------------
# ENUM: 21
# NAME: Nationale Postcode Loterij N.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_npl.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Waarschuwing Nationale Postcode Loterij N.V.\xa0(2 november 2022)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_npl.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit tot openbaarmaking\xa0Nationale Postcode Loterij N.V.\xa0'
#            '(2 november 2022)'}]
# == sanctiebesluit_npl.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == openbaarmakingsbesluit_npl.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 7
#      OCR - CACHED  for page 2 of 7
#      OCR - CACHED  for page 3 of 7
#      OCR - CACHED  for page 4 of 7
#      OCR - CACHED  for page 5 of 7
#      OCR - CACHED  for page 6 of 7
#      OCR - CACHED  for page 7 of 7
# ------------------------
# ENUM: 22
# NAME: M.K.C Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20220823_01_265_505_-_besluit_last_onder_dwangsom_ov.pdf',
#   'status': 'Naar aanleiding van het besluit is gecontroleerd, hierbij is '
#             'geconstateerd dat de overtredingen zijn gestaakt.\xa0Tegen dit '
#             'besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Last onder dwangsom\xa0L.C.S Limited (7 september 2022)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20220823_01_265_507_-_besluit_openbaarmaking_ov.pdf',
#   'status': 'Naar aanleiding van het besluit is gecontroleerd, hierbij is '
#             'geconstateerd dat de overtredingen zijn gestaakt.\xa0Tegen dit '
#             'besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit tot openbaarmaking\xa0L.C.S Limited (7 september 2022)'}]
# == 20220823_01_265_505_-_besluit_last_onder_dwangsom_ov.pdf ==
# A b'%PDF-1.6'
#      OCR - CACHED  for page 1 of 11
#      OCR - CACHED  for page 2 of 11
#      OCR - CACHED  for page 3 of 11
#      OCR - CACHED  for page 4 of 11
#      OCR - CACHED  for page 5 of 11
#      OCR - CACHED  for page 6 of 11
#      OCR - CACHED  for page 7 of 11
#      OCR - CACHED  for page 8 of 11
#      OCR - CACHED  for page 9 of 11
#      OCR - CACHED  for page 10 of 11
#      OCR - CACHED  for page 11 of 11
# == 20220823_01_265_507_-_besluit_openbaarmaking_ov.pdf ==
# A b'%PDF-1.6'
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 23
# NAME: L.C.S Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20220817_01_265_500_-_besluit_lod_sons-of-slots_ov.pdf',
#   'status': 'Naar aanleiding van het besluit is gecontroleerd, hierbij is '
#             'geconstateerd dat de overtredingen zijn gestaakt.\xa0Tegen dit '
#             'besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Last onder dwangsom\xa0L.C.S Limited (1\xa0september 2022)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20220817_01_265_499_-_besluit_openbaarmaking_ov.pdf',
#   'status': 'Naar aanleiding van het besluit is gecontroleerd, hierbij is '
#             'geconstateerd dat de overtredingen zijn gestaakt.\xa0Tegen dit '
#             'besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit tot openbaarmaking\xa0L.C.S Limited (1\xa0september 2022)'}]
# == 20220817_01_265_500_-_besluit_lod_sons-of-slots_ov.pdf ==
# A b'%PDF-1.6'
#      OCR - CACHED  for page 1 of 11
#      OCR - CACHED  for page 2 of 11
#      OCR - CACHED  for page 3 of 11
#      OCR - CACHED  for page 4 of 11
#      OCR - CACHED  for page 5 of 11
#      OCR - CACHED  for page 6 of 11
#      OCR - CACHED  for page 7 of 11
#      OCR - CACHED  for page 8 of 11
#      OCR - CACHED  for page 9 of 11
#      OCR - CACHED  for page 10 of 11
#      OCR - CACHED  for page 11 of 11
# == 20220817_01_265_499_-_besluit_openbaarmaking_ov.pdf ==
# A b'%PDF-1.6'
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 24
# NAME: Gammix Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230216_01-285-641_invorderingsbesluit_gammix.pdf',
#   'status': 'Tegen dit besluit kan bezwaar gemaakt worden.',
#   'title': 'Invorderingsbesluit Gammix Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230216_01-285-642_besluit_openbaarmaking_gammix.pdf',
# ...
#   'status': 'Tegen dit besluit is bezwaar ingediend',
#   'title': 'Besluit openbaarmaking sanctiebesluit Onisac\xa0Limited en Mansion '
#            'Online Casino Limited (9 april 2019)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/7845_00_021_663_-_sanctiebesluit_openbaar.pdf',
#   'status': 'In deze zaak is hoger beroep ingesteld en de Raad van State heeft '
#             'www.raadvanstate.nl/uitspraken/zoeken-in-uitspraken/tekst-uitspraak.html?id=96664&summary_only=&q= '
#             'gedaan op 26 september 2018.',
#   'title': 'Sanctiebesluit Onisac Limited en Mansion Online Casino Limited (4 '
#            'november 2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/7845_00_021_664-_openbaarmaking_openbaar.pdf',
#   'status': 'In deze zaak is hoger beroep ingesteld en de Raad van State heeft '
#             'www.raadvanstate.nl/uitspraken/zoeken-in-uitspraken/tekst-uitspraak.html?id=96664&summary_only=&q= '
#             'gedaan op 26 september 2018.',
#   'title': 'Besluit openbaarmaking Onisac Limited en Mansion Online Casino '
#            'Limited\xa0(4 november 2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/7845_-_advies_bac_ov_pdf.pdf',
#   'title': 'Advies BAC\xa0 Onisac Limited en Mansion Online Casino Limited '
#            '(154 kB)\xa0(4 november 2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/7845_-_beslissing_op_bezwaar_ov_pdf.pdf',
#   'status': 'Tegen deze beslissing op bezwaar is inmiddels beroep ingesteld '
#             'bij de rechtbank.',
#   'title': 'Beslissing op bezwaar Onisac Limited en Mansion Online Casino '
#            'Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/8051_-_besluit_openbaarmaking_bob_ov_pdf.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking Onisac Limited en Mansion Online Casino '
#            'Limited BOB (4 november 2013)'}]
# == 190625_besluit_openbaarmaking_bob_onisac_openbaar_003.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 190704_bob_en_bac.pdf ==
# A b'%PDF-1.6'
#      OCR - CACHED  for page 1 of 12
#      OCR - CACHED  for page 2 of 12
#      OCR - CACHED  for page 3 of 12
#      OCR - CACHED  for page 4 of 12
#      OCR - CACHED  for page 5 of 12
#      OCR - CACHED  for page 6 of 12
#      OCR - CACHED  for page 7 of 12
#      OCR - CACHED  for page 8 of 12
#      OCR - CACHED  for page 9 of 12
#      OCR - CACHED  for page 10 of 12
#      OCR - CACHED  for page 11 of 12
#      OCR - CACHED  for page 12 of 12
# == sanctiebesluit_onisac.pdf ==
# A b'%PDF-1.4'
#      OCR - CACHED  for page 1 of 15
#      OCR - CACHED  for page 2 of 15
#      OCR - CACHED  for page 3 of 15
#      OCR - CACHED  for page 4 of 15
#      OCR - CACHED  for page 5 of 15
#      OCR - CACHED  for page 6 of 15
#      OCR - CACHED  for page 7 of 15
#      OCR - CACHED  for page 8 of 15
#      OCR - CACHED  for page 9 of 15
#      OCR - CACHED  for page 10 of 15
#      OCR - CACHED  for page 11 of 15
#      OCR - CACHED  for page 12 of 15
#      OCR - CACHED  for page 13 of 15
#      OCR - CACHED  for page 14 of 15
#      OCR - CACHED  for page 15 of 15
# == openbaarmakingsbesluit_sanctiebesluit_onisac.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 7845_00_021_663_-_sanctiebesluit_openbaar.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 30
#      OCR - CACHED  for page 2 of 30
#      OCR - CACHED  for page 3 of 30
#      OCR - CACHED  for page 4 of 30
#      OCR - CACHED  for page 5 of 30
#      OCR - CACHED  for page 6 of 30
#      OCR - CACHED  for page 7 of 30
#      OCR - CACHED  for page 8 of 30
#      OCR - CACHED  for page 9 of 30
#      OCR - CACHED  for page 10 of 30
#      OCR - CACHED  for page 11 of 30
#      OCR - CACHED  for page 12 of 30
#      OCR - CACHED  for page 13 of 30
#      OCR - CACHED  for page 14 of 30
#      OCR - CACHED  for page 15 of 30
#      OCR - CACHED  for page 16 of 30
#      OCR - CACHED  for page 17 of 30
#      OCR - CACHED  for page 18 of 30
#      OCR - CACHED  for page 19 of 30
#      OCR - CACHED  for page 20 of 30
#      OCR - CACHED  for page 21 of 30
#      OCR - CACHED  for page 22 of 30
#      OCR - CACHED  for page 23 of 30
#      OCR - CACHED  for page 24 of 30
#      OCR - CACHED  for page 25 of 30
#      OCR - CACHED  for page 26 of 30
#      OCR - CACHED  for page 27 of 30
#      OCR - CACHED  for page 28 of 30
#      OCR - CACHED  for page 29 of 30
#      OCR - CACHED  for page 30 of 30
# == 7845_00_021_664-_openbaarmaking_openbaar.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# == 7845_-_advies_bac_ov_pdf.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 17
#      OCR - CACHED  for page 2 of 17
#      OCR - CACHED  for page 3 of 17
#      OCR - CACHED  for page 4 of 17
#      OCR - CACHED  for page 5 of 17
#      OCR - CACHED  for page 6 of 17
#      OCR - CACHED  for page 7 of 17
#      OCR - CACHED  for page 8 of 17
#      OCR - CACHED  for page 9 of 17
#      OCR - CACHED  for page 10 of 17
#      OCR - CACHED  for page 11 of 17
#      OCR - CACHED  for page 12 of 17
#      OCR - CACHED  for page 13 of 17
#      OCR - CACHED  for page 14 of 17
#      OCR - CACHED  for page 15 of 17
#      OCR - CACHED  for page 16 of 17
#      OCR - CACHED  for page 17 of 17
# == 7845_-_beslissing_op_bezwaar_ov_pdf.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 8051_-_besluit_openbaarmaking_bob_ov_pdf.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# ------------------------
# ENUM: 108
# NAME: Café Lucky
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5464/besluit_op_bezwaar_openbaar_cafe_lucky.pdf',
#   'status': 'Tegen de beslissing van de rechtbank is geen hoger beroep '
#             'ingesteld. De uitspraak van de rechtbank is thans onherroepelijk.',
#   'title': 'Besluit op bezwaar inclusief advies BAC Café Lucky (28 maart '
#            '2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5464/besluit_openbaarmaking_bob_openbaar_cafe_lucky.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking Café Lucky\xa0(28 maart 2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5464/7938_-_00_018_637_sanctiebesluit_openbare_versie.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Café Lucky\xa0(14 november 2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5464/7938_besluit_openbaarmaking_cafe_lucky.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Besluit openbaarmaking Cafe Lucky (14 november 2013)'}]
# == besluit_op_bezwaar_openbaar_cafe_lucky.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == besluit_openbaarmaking_bob_openbaar_cafe_lucky.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 7938_-_00_018_637_sanctiebesluit_openbare_versie.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 16
#      OCR - CACHED  for page 2 of 16
#      OCR - CACHED  for page 3 of 16
#      OCR - CACHED  for page 4 of 16
#      OCR - CACHED  for page 5 of 16
#      OCR - CACHED  for page 6 of 16
#      OCR - CACHED  for page 7 of 16
#      OCR - CACHED  for page 8 of 16
#      OCR - CACHED  for page 9 of 16
#      OCR - CACHED  for page 10 of 16
#      OCR - CACHED  for page 11 of 16
#      OCR - CACHED  for page 12 of 16
#      OCR - CACHED  for page 13 of 16
#      OCR - CACHED  for page 14 of 16
#      OCR - CACHED  for page 15 of 16
#      OCR - CACHED  for page 16 of 16
# == 7938_besluit_openbaarmaking_cafe_lucky.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 109
# NAME: Star SAT Electronica
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5463/7971_-_00_019_052_sanctiebesluit_openbare_versie.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Sanctiebesluit Star Sat Electronica(935 kB)\xa0( 21 november '
#            '2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5463/7971_besluit_openbaarmaking_star_sat_electronica.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking Star Sat Electronica (202 kB)\xa0(21 '
#            'november 2013)'}]
# == 7971_-_00_019_052_sanctiebesluit_openbare_versie.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 14
#      OCR - CACHED  for page 2 of 14
#      OCR - CACHED  for page 3 of 14
#      OCR - CACHED  for page 4 of 14
#      OCR - CACHED  for page 5 of 14
#      OCR - CACHED  for page 6 of 14
#      OCR - CACHED  for page 7 of 14
#      OCR - CACHED  for page 8 of 14
#      OCR - CACHED  for page 9 of 14
#      OCR - CACHED  for page 10 of 14
#      OCR - CACHED  for page 11 of 14
#      OCR - CACHED  for page 12 of 14
#      OCR - CACHED  for page 13 of 14
#      OCR - CACHED  for page 14 of 14
# == 7971_besluit_openbaarmaking_star_sat_electronica.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# ------------------------
# ENUM: 110
# NAME: Call Internet City
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5462/besluit_op_bezwaar_openbaar_call_internet_city.pdf',
#   'status': 'Tegen deze beslissing is geen beroep ingesteld. De beslissing is '
#             'thans onherroepelijk.',
#   'title': 'Besluit op bezwaar Call Internet City\xa0(1 april 2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5462/7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking BOB Call Internet City\xa0\xa0\xa0(10 april '
#            '2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5462/7970_sanctiebesluit_call_internet_city.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Call Internet City\xa0(21 november\xa02013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5462/7970_besluit_openbaarmaking_call_internet_city.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking Call Internet City\xa0(21 november 2013)'}]
# == besluit_op_bezwaar_openbaar_call_internet_city.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 9
#      OCR - CACHED  for page 2 of 9
#      OCR - CACHED  for page 3 of 9
#      OCR - CACHED  for page 4 of 9
#      OCR - CACHED  for page 5 of 9
#      OCR - CACHED  for page 6 of 9
#      OCR - CACHED  for page 7 of 9
#      OCR - CACHED  for page 8 of 9
#      OCR - CACHED  for page 9 of 9
# == 7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 7970_sanctiebesluit_call_internet_city.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == 7970_besluit_openbaarmaking_call_internet_city.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# ------------------------
# ENUM: 111
# NAME: Huizenloterij
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_020_754_kennisgeving_als_bedoeld_in_art_5_50_lid_2_sub_a_awb_openbaar.pdf',
#   'title': 'Beslissing huizenloterij (1571 kB)\xa0(14 januari 2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_020_755_besluit_tot_openbaarmaking_openbaar.pdf',
#   'title': 'Besluit\xa0openbaarmaking huizenloteij (243 kB)\xa0(14 januari '
#            '2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_026_508_en_8140_-_00_026_510_besluit_op_bezwaar_openbaar1.pdf',
#   'status': 'In deze zaak is beroep ingesteld en de rechtbank heeft uitspraak '
#             'gedaan op 17 februari 2015. Het beroep is ongegrond verklaard.',
#   'title': 'Besluit op bezwaar huizenloterij (1076 kB)\xa0(30 april 2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_025_509_en_8140_-_00_026_511_besluit_openbaarmaking_bob_openbaar1.pdf',
#   'status': 'Het hoger beroep tegen de uitspraak van de rechtbank is '
#             'ingetrokken. De uitspraak van de rechtbank is thans definitief.',
#   'title': 'Besluit openbaarmaking BOB\xa0(191 kB)\xa0(30 april 2014)'}]
# == 7982_-_00_020_754_kennisgeving_als_bedoeld_in_art_5_50_lid_2_sub_a_awb_openbaar.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 26
#      OCR - CACHED  for page 2 of 26
#      OCR - CACHED  for page 3 of 26
#      OCR - CACHED  for page 4 of 26
#      OCR - CACHED  for page 5 of 26
#      OCR - CACHED  for page 6 of 26
#      OCR - CACHED  for page 7 of 26
#      OCR - CACHED  for page 8 of 26
#      OCR - CACHED  for page 9 of 26
#      OCR - CACHED  for page 10 of 26
#      OCR - CACHED  for page 11 of 26
#      OCR - CACHED  for page 12 of 26
#      OCR - CACHED  for page 13 of 26
#      OCR - CACHED  for page 14 of 26
#      OCR - CACHED  for page 15 of 26
#      OCR - CACHED  for page 16 of 26
#      OCR - CACHED  for page 17 of 26
#      OCR - CACHED  for page 18 of 26
#      OCR - CACHED  for page 19 of 26
#      OCR - CACHED  for page 20 of 26
#      OCR - CACHED  for page 21 of 26
#      OCR - CACHED  for page 22 of 26
#      OCR - CACHED  for page 23 of 26
#      OCR - CACHED  for page 24 of 26
#      OCR - CACHED  for page 25 of 26
#      OCR - CACHED  for page 26 of 26
# == 7982_-_00_020_755_besluit_tot_openbaarmaking_openbaar.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 7982_-_00_026_508_en_8140_-_00_026_510_besluit_op_bezwaar_openbaar1.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 15
#      OCR - CACHED  for page 2 of 15
#      OCR - CACHED  for page 3 of 15
#      OCR - CACHED  for page 4 of 15
#      OCR - CACHED  for page 5 of 15
#      OCR - CACHED  for page 6 of 15
#      OCR - CACHED  for page 7 of 15
#      OCR - CACHED  for page 8 of 15
#      OCR - CACHED  for page 9 of 15
#      OCR - CACHED  for page 10 of 15
#      OCR - CACHED  for page 11 of 15
#      OCR - CACHED  for page 12 of 15
#      OCR - CACHED  for page 13 of 15
#      OCR - CACHED  for page 14 of 15
#      OCR - CACHED  for page 15 of 15
# == 7982_-_00_025_509_en_8140_-_00_026_511_besluit_openbaarmaking_bob_openbaar1.pdf ==
# A b'%PDF-1.5'
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3

# %%
# A case now looks like:
extracted_cases[0]
# Out:
# ({'name': 'Bingoal Nederland B.V.',
#   'date_range': [],
#   'money': [],
#   'ecli': [],
#   'case_detail_url': 'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/bingoal-nederland-0/'},
#  [{'title': 'Sanctiebesluit',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-288-556_15404_sanctiebesluit_bingoal.pdf',
#    'status': 'Tegen dit besluit\xa0is bezwaar gemaakt.'},
#   {'title': 'Openbaarmakingsbesluit',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15404_bingoal_openbaarmakingsbesluit_002_.pdf',
#    'status': 'Tegen dit besluit\xa0is\xa0bezwaar gemaakt.'}],
#  [[[([[901, 195], [1147, 195], [1147, 235], [901, 235]],
#      'Kansspelautoriteit',
#      0.9999940713236027),
#     ([[196, 372], [354, 372], [354, 404], [196, 404]],
#      'OPENBAAR',
#      0.9998506269477122),
#     ([[195, 569], [1433, 569], [1433, 609], [195, 609]],
#      'Besluit van de raad van bestuur van de Kansspelautoriteit als bedoeld in artikel 35a',
#      0.9089226683073498),
#     ([[195, 603], [1393, 603], [1393, 645], [195, 645]],
#      'van de Wet op de kansspelen tot oplegging van een boete aan Bingoal Nederland',
#      0.5885393895653034),
#     ([[196, 640], [252, 640], [252, 668], [196, 668]],
#      'B.V',
#      0.579577624797821),
#     ([[196, 712], [386, 712], [386, 744], [196, 744]],
#      'Zaak: 15404',
#      0.9995287736533217),
#     ([[196, 752], [446, 752], [446, 784], [196, 784]],
#      'Kenmerk: 15404',
#      0.9892448883869335),
#     ([[474, 750], [648, 750], [648, 782], [474, 782]],
#      '01.288.553',
#      0.9998910889474955),
#     ([[193, 789], [977, 789], [977, 827], [193, 827]],
#      'Openbaarmaking onder kenmerk: 15404/01.288.556',
#      0.8543948589761851),
#     ([[684, 876], [956, 876], [956, 948], [684, 948]],
#      'Besluit',
#      0.999994503056213),
#     ([[198, 1052], [222, 1052], [222, 1082], [198, 1082]],
#      '1',
#      0.999993562708724),
#     ([[252, 1044], [458, 1044], [458, 1096], [252, 1096]],
#      'Inleiding',
#      0.9999989271161063),
#     ([[196, 1100], [220, 1100], [220, 1128], [196, 1128]],
#      '1',
#      0.8361549347199008),
#     ([[255, 1096], [1437, 1096], [1437, 1137], [255, 1137]],
#      'De raad van bestuur van de Kansspelautoriteit (hierna: Kansspelautoriteit) is belast',
#      0.6707992907250192),
#     ([[255, 1133], [1379, 1133], [1379, 1175], [255, 1175]],
#      'met het toezicht op de naleving van het bepaalde bij of krachtens de Wet op de',
#      0.6851376706097259),
#     ([[255, 1171], [1375, 1171], [1375, 1215], [255, 1215]],
#      'kansspelen (hierna: Wok) en onderliggende regelgeving, waaronder het Besluit',
#      0.6960420268667223),
#     ([[255, 1214], [1245, 1214], [1245, 1255], [255, 1255]],
#      'werving, reclame en verslavingspreventie kansspelen (hierna: Bwrvk).',
#      0.6993726174713129),
#     ([[196, 1294], [220, 1294], [220, 1322], [196, 1322]],
#      '2',
#      0.9999995231628986),
#     ([[255, 1289], [1349, 1289], [1349, 1332], [255, 1332]],
#      'Op grond van artikel 2, vierde lid, aanhef en onder a, van het Bwrvk mag een',
#      0.7351600575388298),
#     ([[255, 1328], [1429, 1328], [1429, 1370], [255, 1370]],
#      'houder van een vergunning tot het organiseren van kansspelen op afstand (hierna:',
#      0.8543294743047946),
#     ([[253, 1364], [1356, 1364], [1356, 1412], [253, 1412]],
#      'vergunninghouder) zijn wervings- en reclameactiviteiten voor kansspelen niet',
#      0.686093165522726),
#     ([[253, 1406], [1169, 1406], [1169, 1448], [253, 1448]],
#      'richten op personen in de leeftijdscategorie tussen 18 en 24 jaar',
#      0.9053910166399111),
#     ([[253, 1445], [1435, 1445], [1435, 1490], [253, 1490]],
#      '(jongvolwassenen) omdat die groep bij deze vorm van kansspelen een hoger risico',
#      0.8287533579803174),
#     ([[253, 1484], [773, 1484], [773, 1525], [253, 1525]],
#      'loopt om kansspelverslaafd te raken.',
#      0.6086018557866134),
#     ([[196, 1570], [220, 1570], [220, 1598], [196, 1598]],
#      '3 _',
#      0.5847946501280054),
#     ([[254, 1564], [1407, 1564], [1407, 1606], [254, 1606]],
#      'Bingoal Nederland B.V. (hierna: Bingoal) heeft in de periode van 12 oktober 2021',
#      0.9413845313425732),
#     ([[253, 1602], [1341, 1602], [1341, 1646], [253, 1646]],
#      'tot en met 15 maart 2022 reclame gestuurd aan jongvolwassenen. Dit is een',
#      0.6581525627373301),
#     ([[252, 1638], [1259, 1638], [1259, 1683], [252, 1683]],
#      'overtreding van artikel 2, vierde lid, aanhef en onder a, van het Bwrvk.',
#      0.6630572186262468),
#     ([[1268, 1646], [1342, 1646], [1342, 1676], [1268, 1676]],
#      'Deze',
#      0.9939257933500779),
#     ([[252, 1679], [877, 1679], [877, 1721], [252, 1721]],
#      'overtreding wordt aan Bingoal toegerekend.',
#      0.9835756620170008),
#     ([[196, 1768], [220, 1768], [220, 1792], [196, 1792]],
#      '4',
#      0.9999977350247811),
#     ([[255, 1761], [889, 1761], [889, 1804], [255, 1804]],
#      'Er wordt een boete opgelegd van € 400.000,',
#      0.9665114167308393),
#     ([[196, 1846], [222, 1846], [222, 1874], [196, 1874]],
#      '5.',
#      0.5024524532936498),
#     ([[255, 1843], [1001, 1843], [1001, 1883], [255, 1883]],
#      'De Kansspelautoriteit zet dat hieronder nader uiteen.',
#      0.6385973709119824),
#     ([[1254, 2148], [1440, 2148], [1440, 2180], [1254, 2180]],
#      'Pagina 1 van 13',
#      0.94985695327791)],
#    [([[196, 202], [354, 202], [354, 232], [196, 232]],
#      'OPENBAAR',
#      0.9997857580625014),
#     ([[883, 195], [1129, 195], [1129, 235], [883, 235]],
#      'Kansspelautoriteit',
#      0.9999202545972062),
#     ([[1316, 208], [1510, 208], [1510, 234], [1316, 234]],
#      'Kansspelautoriteit',
#      0.9999989322791986),
#     ([[1317, 245], [1387, 245], [1387, 265], [1317, 265]],
#      'Datum',
#      0.9999913634491684),
#     ([[1318, 276], [1432, 276], [1432, 302], [1318, 302]],
#      '4 april 2023',
#      0.6756293676352894),
#     ([[1317, 311], [1457, 311], [1457, 331], [1317, 331]],
#      'Ons kenmerk',
#      0.8666306171284494),
#     ([[1317, 345], [1379, 345], [1379, 365], [1317, 365]],
#      '15404',
#      0.9134207890774737),
#     ([[1395, 345], [1505, 345], [1505, 365], [1395, 365]],
#      '01.288.556',
#      0.7301870744668644),
#     ([[198, 416], [228, 416], [228, 450], [198, 450]],
#      '2',
#      0.9999958276792178),
#     ([[253, 411], [497, 411], [497, 453], [253, 453]],
#      'Onderzoek',
#      0.8048283429796456),
#     ([[198, 496], [258, 496], [258, 528], [198, 528]],
#      '2.1',
#      0.933701159267223),
#     ([[273, 491], [441, 491], [441, 531], [273, 531]],
#      'Reclame',
#      0.751763953480481),
#     ([[196, 540], [220, 540], [220, 568], [196, 568]],
#      '6',
#      0.9999995231628986),
#     ([[255, 533], [1389, 533], [1389, 577], [255, 577]],
#      'De Kansspelautoriteit is ambtshalve een onderzoek gestart naar de naleving van',
#      0.9445793870687339),
#     ([[255, 574], [1413, 574], [1413, 616], [255, 616]],
#      'het verbod om kansspelreclame te richten op minderjarigen en jongvolwassenen. 1',
#      0.8546490049546192),
#     ([[255, 611], [1414, 611], [1414, 654], [255, 654]],
#      'Uit signalen uit de mediaz en diverse meldingen die de Kansspelautoriteit ontving,',
#      0.7572959438179138),
#     ([[252, 649], [1436, 649], [1436, 697], [252, 697]],
#      'leek te volgen dat vergunninghouders deze regels niet altijd nakomen. Alle houders',
#      0.8168826817986554),
#     ([[256, 698], [308, 698], [308, 724], [256, 724]],
#      'van',
#      0.9998337194070285),
#     ([[315, 689], [1427, 689], [1427, 732], [315, 732]],
#      'een vergunning voor het organiseren van online kansspelen die in de periode 1',
#      0.6553927438435648),
#     ([[253, 727], [1363, 727], [1363, 770], [253, 770]],
#      'oktober 2021 tot en met 1 april 2022 actief waren in Nederland zijn tijdens dit',
#      0.6563632796831811),
#     ([[254, 772], [574, 772], [574, 804], [254, 804]],
#      'onderzoek onderzocht.',
#      0.9963359701165927),
#     ([[196, 840], [220, 840], [220, 866], [196, 866]],
#      '7',
#      0.9999988079074598),
#     ([[255, 837], [1267, 837], [1267, 875], [255, 875]],
#      'Op 22 april 2022 hebben toezichthouders van de Kansspelautoriteit een',
#      0.9550361270991552),
#     ([[252, 873], [841, 873], [841, 915], [252, 915]],
#      'informatieverzoek gestuurd naar Bingoal.',
#      0.8419605560725819),
#     ([[196, 946], [220, 946], [220, 972], [196, 972]],
#      '8 ',
#      0.4223826512328838),
#     ([[255, 942], [1369, 942], [1369, 983], [255, 983]],
#      'De toezichthouders hebben Bingoal gevraagd om de volgende gegevens aan te',
#      0.7778050528032541),
#     ([[254, 982], [374, 982], [374, 1014], [254, 1014]],
#      'leveren:',
#      0.9675371170576527),
#     ([[257, 1055], [277, 1055], [277, 1077], [257, 1077]],
#      'a',
#      0.9714201562164568),
#     ([[305, 1046], [1389, 1046], [1389, 1086], [305, 1086]],
#      'Alle door Bingoal verstuurde e-mails aan 18 actieve spelers onder de 24 jaar',
#      0.8582646597805076),
#     ([[305, 1084], [556, 1084], [556, 1125], [305, 1125]],
#      'oud in de periode',
#      0.7755709791114277),
#     ([[561, 1084], [1421, 1084], [1421, 1125], [561, 1125]],
#      '1 oktober 2021 tot 1 april 2022 en enkel over de periode dat',
#      0.7935817012834042),
#     ([[303, 1125], [887, 1125], [887, 1165], [303, 1165]],
#      'zij een actief account hadden bij Bingoal.',
#      0.6603234146017333),
#     ([[256, 1194], [286, 1194], [286, 1222], [256, 1222]],
#      'b.',
#      0.9986801316738338),
#     ([[304, 1186], [1378, 1186], [1378, 1234], [304, 1234]],
#      'Alle door Bingoal verstuurde e-mails aan 18 voormalige spelers onder de 24',
#      0.8183791252434183),
#     ([[301, 1228], [1394, 1228], [1394, 1269], [301, 1269]],
#      'jaar oud in de periode 1 oktober 2021 tot 1 april 2022 en enkel in de periode',
#      0.7349774617242861),
#     ([[304, 1272], [430, 1272], [430, 1302], [304, 1302]],
#      'dat deze',
#      0.9542096823591584),
#     ([[430, 1264], [543, 1264], [543, 1312], [430, 1312]],
#      'spelers',
#      0.9961283458066164),
#     ([[619, 1269], [1091, 1269], [1091, 1309], [619, 1309]],
#      'account bij Bingoal meer hadden.',
#      0.8585361671078682),
#     ([[254, 1344], [282, 1344], [282, 1368], [254, 1368]],
#      'c.',
#      0.28312713460678146),
#     ([[303, 1335], [1367, 1335], [1367, 1376], [303, 1376]],
#      'Alle door Bingoal verstuurde berichten/notificaties via de online app aan 18',
#      0.8477730687203249),
#     ([[303, 1371], [1291, 1371], [1291, 1414], [303, 1414]],
#      'actieve spelers onder de 24 jaar oud in de periode 1 oktober 2021 tot',
#      0.8717784513319893),
#     ([[1297, 1381], [1311, 1381], [1311, 1403], [1297, 1403]],
#      '1',
#      0.9993336119173968),
#     ([[1319, 1377], [1389, 1377], [1389, 1413], [1319, 1413]],
#      'april',
#      0.9999521256752667),
#     ([[306, 1414], [386, 1414], [386, 1446], [306, 1446]],
#      '2022.',
#      0.9987519803971114),
#     ([[256, 1484], [280, 1484], [280, 1512], [256, 1512]],
#      'd_',
#      0.973421345443221),
#     ([[305, 1477], [1350, 1477], [1350, 1520], [305, 1520]],
#      'Het totaal aantal spelers in de leeftijd van 18 tot 24 jaar dat in de periode',
#      0.739782153519222),
#     ([[307, 1518], [1199, 1518], [1199, 1561], [307, 1561]],
#      '1 oktober 2021 tot 1 april 2022 bij Bingoal geregistreerd stond.',
#      0.7149478882662461),
#     ([[255, 1585], [1399, 1585], [1399, 1623], [255, 1623]],
#      'De toezichthouders hebben in het informatieverzoek de wijze van selectie van de',
#      0.6569328742528715),
#     ([[252, 1622], [1413, 1622], [1413, 1665], [252, 1665]],
#      'spelersdossiers aangegeven  om op deze manier een representatieve weergave te',
#      0.7607960738304635),
#     ([[252, 1662], [413, 1662], [413, 1704], [252, 1704]],
#      'ontvangen.',
#      0.9537244506970892),
#     ([[194, 1734], [220, 1734], [220, 1762], [194, 1762]],
#      '9_',
#      0.9718005227834352),
#     ([[255, 1729], [1407, 1729], [1407, 1771], [255, 1771]],
#      'Op 12 mei 2022 heeft Bingoal schriftelijk gereageerd op het informatieverzoek en',
#      0.7312734097451955),
#     ([[255, 1764], [781, 1764], [781, 1809], [255, 1809]],
#      'de gevraagde gegevens aangeleverd.',
#      0.6343984591975442),
#     ([[198, 1840], [260, 1840], [260, 1872], [198, 1872]],
#      '2.2',
#      0.9929210543632507),
#     ([[277, 1835], [555, 1835], [555, 1875], [277, 1875]],
#      'De betrokkene',
#      0.9999792033829716),
#     ([[196, 1884], [240, 1884], [240, 1914], [196, 1914]],
#      '10.',
#      0.9968554747583387),
#     ([[255, 1880], [1399, 1880], [1399, 1924], [255, 1924]],
#      'Bingoal is gevestigd aan de Laneaustraat 119-133, 1020 te Brussel , België. Zij is',
#      0.7226118668345495),
#     ([[254, 1918], [1413, 1918], [1413, 1960], [254, 1960]],
#      'vergunninghouder voor het organiseren van kansspelen op afstand, als bedoeld in',
#      0.8546375200757476),
#     ([[253, 1958], [1375, 1958], [1375, 1999], [253, 1999]],
#      'artikel 31a van de Wok. Op 29 september 2021 heeft de Kansspelautoriteit een',
#      0.8471011608572935),
#     ([[212, 2042], [716, 2042], [716, 2072], [212, 2072]],
#      'Artikel 2, derde en vierde lid, van het Bwrvk-',
#      0.8086674034654484),
#     ([[212, 2070], [738, 2070], [738, 2098], [212, 2098]],
#      'https: / /www bnnvara.nl/kassa/videos/576539_',
#      0.4646520813878245),
#     ([[1254, 2108], [1332, 2108], [1332, 2136], [1254, 2136]],
#      'Pagina',
#      0.9999936246199173),
#     ([[1338, 2108], [1440, 2108], [1440, 2134], [1338, 2134]],
#      '2 van 13',
#      0.7642994590452109),
#     ([[539, 1274], [615, 1268], [617, 1302], [540, 1308]],
#      'geen',
#      0.9999942779541016)],
#    [([[196, 202], [354, 202], [354, 232], [196, 232]],
#      'OPENBAAR',
#      0.9997857580625014),
#     ([[883, 195], [1129, 195], [1129, 235], [883, 235]],
#      'Kansspelautoriteit',
#      0.9999202545972062),
#     ([[1316, 208], [1510, 208], [1510, 234], [1316, 234]],
#      'Kansspelautoriteit',
#      0.9999989322791986),
#     ([[1317, 245], [1387, 245], [1387, 265], [1317, 265]],
#      'Datum',
#      0.9999913634491684),
#     ([[1318, 276], [1432, 276], [1432, 302], [1318, 302]],
#      '4 april 2023',
#      0.6756293676352894),
#     ([[1317, 311], [1457, 311], [1457, 331], [1317, 331]],
#      'Ons kenmerk',
#      0.8666306171284494),
#     ([[1317, 345], [1379, 345], [1379, 365], [1317, 365]],
#      '15404',
#      0.9134207890774737),
#     ([[1395, 345], [1505, 345], [1505, 365], [1395, 365]],
#      '01.288.556',
#      0.7301870744668644),
#     ([[253, 409], [1031, 409], [1031, 447], [253, 447]],
#      'vergunning verleend onder kenmerk 1701/01.247.169.',
#      0.9376434600859865),
#     ([[1039, 406], [1421, 406], [1421, 448], [1039, 448]],
#      'Deze vergunning geldt van',
#      0.9083108309532634),
#     ([[258, 448], [676, 448], [676, 480], [258, 480]],
#      '1 oktober 2021 tot en met 30',
#      0.9082382541198384),
#     ([[676, 441], [922, 441], [922, 490], [676, 490]],
#      'september 2026.',
#      0.9170252301576839),
#     ([[196, 516], [240, 516], [240, 546], [196, 546]],
#      '11.',
#      0.9757683114104196),
#     ([[255, 513], [1202, 513], [1202, 553], [255, 553]],
#      "Bingoal biedt online kansspelen aan via de website wwwbinqoaLnl'",
#      0.8494961798531213),
#     ([[198, 626], [228, 626], [228, 662], [198, 662]],
#      '3',
#      0.9999949932161059),
#     ([[253, 621], [439, 621], [439, 673], [253, 673]],
#      'Rapport',
#      0.9999971614154921),
#     ([[196, 682], [240, 682], [240, 712], [196, 712]],
#      '12.',
#      0.9961653404791112),
#     ([[255, 677], [1295, 677], [1295, 720], [255, 720]],
#      'De toezichthouders hebben op grond van de resultaten van het hierboven',
#      0.7333750018507883),
#     ([[252, 719], [1415, 719], [1415, 762], [252, 762]],
#      'genoemde onderzoek op 20 oktober 2022 een rapport opgesteld. In het rapport is',
#      0.6542336002660615),
#     ([[252, 760], [1417, 760], [1417, 802], [252, 802]],
#      'geconstateerd dat Bingoal in de periode van 12 oktober 2021 tot en met 15 maart',
#      0.7481731952210383),
#     ([[253, 801], [1361, 801], [1361, 841], [253, 841]],
#      '2022, artikel 2, vierde lid, aanhef en onder a, van het Bwrvk heeft overtreden .',
#      0.6180386739087039),
#     ([[196, 890], [242, 890], [242, 920], [196, 920]],
#      '13.',
#      0.9991020875270538),
#     ([[255, 884], [1337, 884], [1337, 928], [255, 928]],
#      'Bingoal heeft gedurende deze periode per e-mail aan bij haar geregistreerde',
#      0.8304915177887017),
#     ([[251, 926], [1389, 926], [1389, 968], [251, 968]],
#      'jongvolwassen spelers veelvuldig reclameberichten gestuurd, waarin het aanbod',
#      0.8796565064241881),
#     ([[254, 976], [308, 976], [308, 1002], [254, 1002]],
#      'van',
#      0.9998707468012268),
#     ([[314, 970], [1007, 970], [1007, 1011], [314, 1011]],
#      'Bingoal werd aangeprezen  waaronder bonussen.',
#      0.7446761361631861),
#     ([[196, 1050], [244, 1050], [244, 1080], [196, 1080]],
#      '14 .',
#      0.7672558426856995),
#     ([[255, 1045], [1433, 1045], [1433, 1089], [255, 1089]],
#      'Het rapport is met de bijbehorende stukken per aangetekende post verzonden naar',
#      0.7933148239722755),
#     ([[255, 1087], [847, 1087], [847, 1127], [255, 1127]],
#      'het adres en het e-mailadres van Bingoal.',
#      0.7068178122885675),
#     ([[200, 1200], [228, 1200], [228, 1232], [200, 1232]],
#      '4',
#      0.9999473101880909),
#     ([[252, 1194], [496, 1194], [496, 1244], [252, 1244]],
#      'Zienswijze',
#      0.9999860142495672),
#     ([[196, 1254], [244, 1254], [244, 1286], [196, 1286]],
#      '15.',
#      0.9996848546186723),
#     ([[255, 1252], [1231, 1252], [1231, 1291], [255, 1291]],
#      'Bij brief van 8 november 2022 is Bingoal uitgenodigd om, voordat de',
#      0.7577434079523429),
#     ([[255, 1295], [1407, 1295], [1407, 1336], [255, 1336]],
#      'Kansspelautoriteit een besluit op het rapport neemt, een zienswijze naar voren te',
#      0.7127239702927258),
#     ([[253, 1333], [382, 1333], [382, 1377], [253, 1377]],
#      'brengen.',
#      0.9773075155857454),
#     ([[196, 1422], [244, 1422], [244, 1452], [196, 1452]],
#      '16.',
#      0.9993871339518365),
#     ([[255, 1417], [1363, 1417], [1363, 1459], [255, 1459]],
#      'Bij brief van 6 december 2022 heeft Bingoal een schriftelijke zienswijze op het',
#      0.6142198602899519),
#     ([[252, 1461], [495, 1461], [495, 1502], [252, 1502]],
#      'rapport gegeven.',
#      0.9684246579137312),
#     ([[196, 1546], [240, 1546], [240, 1578], [196, 1578]],
#      '17.',
#      0.9953075774535224),
#     ([[255, 1545], [1087, 1545], [1087, 1583], [255, 1583]],
#      'Op 12 december 2022 hebben [persoon 1] en [persoon 2]',
#      0.8496418793863483),
#     ([[1099, 1545], [1329, 1545], [1329, 1583], [1099, 1583]],
#      '[advocaat 1] en',
#      0.9966264085921177),
#     ([[252, 1581], [1433, 1581], [1433, 1626], [252, 1626]],
#      '[advocaat 2], namens Bingoal de zienswijze mondeling toegelicht. Op 15 december',
#      0.8321474017578387),
#     ([[255, 1626], [1391, 1626], [1391, 1667], [255, 1667]],
#      '2022 is het verslag van de hoorzitting per e-mail naar Bingoal verzonden. Op 20',
#      0.8045268719538226),
#     ([[253, 1665], [1291, 1665], [1291, 1710], [253, 1710]],
#      'december 2022 heeft Bingoal haar opmerkingen over het verslag naar de',
#      0.8382651316988067),
#     ([[255, 1709], [923, 1709], [923, 1753], [255, 1753]],
#      'Kansspelautoriteit gezonden met twee bijlagen.',
#      0.7214172484930297),
#     ([[198, 1780], [258, 1780], [258, 1812], [198, 1812]],
#      '4.1',
#      0.9855106090648487),
#     ([[271, 1771], [626, 1771], [626, 1820], [271, 1820]],
#      'Inhoud zienswijze',
#      0.749792964080422),
#     ([[196, 1828], [244, 1828], [244, 1860], [196, 1860]],
#      '18.',
#      0.9991006423653079),
#     ([[255, 1827], [1431, 1827], [1431, 1865], [255, 1865]],
#      'Bingoal ontkent niet dat zij van 12 oktober 2021 tot en met 15 maart 2022 e-mails',
#      0.9335591069326552),
#     ([[255, 1866], [967, 1866], [967, 1908], [255, 1908]],
#      'met reclame aan jongvolwassenen heeft gestuurd.',
#      0.9064548886314824),
#     ([[196, 1996], [240, 1996], [240, 2026], [196, 2026]],
#      '19.',
#      0.9969891475208034),
#     ([[255, 1989], [1213, 1989], [1213, 2034], [255, 2034]],
#      'Bingoal betwist evenwel dat haar e-mails specifiek waren gericht op',
#      0.7962362370934556),
#     ([[250, 2029], [1389, 2029], [1389, 2077], [250, 2077]],
#      'jongvolwassenen en dus tot overtreding van de norm hebben geleid. Het betreft',
#      0.6751330245291198),
#     ([[1254, 2108], [1332, 2108], [1332, 2136], [1254, 2136]],
#      'Pagina',
#      0.9999936246199173),
#     ([[1338, 2108], [1440, 2108], [1440, 2134], [1338, 2134]],
#      '3 van 13',
#      0.9417498510375052)],
#    [([[196, 202], [354, 202], [354, 232], [196, 232]],
#      'OPENBAAR',
#      0.9997857580625014),
#     ([[883, 195], [1129, 195], [1129, 235], [883, 235]],
#      'Kansspelautoriteit',
#      0.9999202545972062),
#     ([[1316, 208], [1510, 208], [1510, 234], [1316, 234]],
#      'Kansspelautoriteit',
#      0.9999989322791986),
#     ([[1317, 245], [1387, 245], [1387, 265], [1317, 265]],
#      'Datum',
#      0.9999913634491684),
#     ([[1318, 276], [1432, 276], [1432, 302], [1318, 302]],
#      '4 april 2023',
#      0.6756293676352894),
#     ([[1317, 311], [1457, 311], [1457, 331], [1317, 331]],
#      'Ons kenmerk',
#      0.8666306171284494),
#     ([[1317, 345], [1379, 345], [1379, 365], [1317, 365]],
#      '15404',
#      0.9134207890774737),
#     ([[1395, 345], [1505, 345], [1505, 365], [1395, 365]],
#      '01.288.556',
#      0.7301870744668644),
#     ([[252, 408], [873, 408], [873, 456], [252, 456]],
#      'algemene reclame-uitingen richting spelers.',
#      0.8971826788334225),
#     ([[879, 413], [1299, 413], [1299, 454], [879, 454]],
#      'Dat Bingoal met haar e-mails',
#      0.9910858469577056),
#     ([[251, 454], [1357, 454], [1357, 495], [251, 495]],
#      'jongvolwassenen heeft bereikt betekent niet dat Bingoal de norm uit artikel 2,',
#      0.6826485164039949),
#     ([[253, 495], [1381, 495], [1381, 535], [253, 535]],
#      'vierde lid, aanhef en onder a, van het Bwrvk heeft overtreden. In deze bepaling',
#      0.7249115184328492),
#     ([[255, 537], [733, 537], [733, 579], [255, 579]],
#      'wordt gesproken over "richten op\'',
#      0.9978339598749345),
#     ([[746, 539], [1118, 539], [1118, 572], [746, 572]],
#      'en niet over "richten aan" .',
#      0.711857943987854),
#     ([[1127, 539], [1361, 539], [1361, 577], [1127, 577]],
#      'Deze norm is op',
#      0.9959151020968595),
#     ([[255, 581], [1397, 581], [1397, 619], [255, 619]],
#      'meerdere wijzen uitlegbaar en is daarom in strijd met het lex certa beginsel. Het',
#      0.8952678355021338),
#     ([[253, 617], [1413, 617], [1413, 662], [253, 662]],
#      'verbod dat is opgenomen in het artikel ziet op de inhoud van de reclame-uiting en',
#      0.8946795034669021),
#     ([[253, 661], [553, 661], [553, 703], [253, 703]],
#      'niet op de reikwijdte.',
#      0.8116388630610506),
#     ([[561, 659], [1403, 659], [1403, 703], [561, 703]],
#      'In dit kader wijst Bingoal enerzijds op de taalkundige uitleg',
#      0.4946908279232841),
#     ([[256, 710], [310, 710], [310, 738], [256, 738]],
#      'van',
#      0.9998476218643518),
#     ([[325, 704], [1437, 704], [1437, 745], [325, 745]],
#      '\'richten aan" en anderzijds op de wetshistorische uitleg van het artikel. Bingoal',
#      0.6198122220616193),
#     ([[253, 743], [1371, 743], [1371, 786], [253, 786]],
#      'stelt dan ook dat zij haar wervings- en reclameactiviteiten niet heeft gericht op',
#      0.9343560480058937),
#     ([[251, 789], [739, 789], [739, 827], [251, 827]],
#      'jongvolwassenen en dat zij artikel',
#      0.969399028776897),
#     ([[793, 789], [1404, 789], [1404, 825], [793, 825]],
#      'tweede lid, van de Wok en artikel 2, vierde',
#      0.9205317555969736),
#     ([[253, 831], [1101, 831], [1101, 867], [253, 867]],
#      'lid, aanhef en onder a, van het Bwrvk niet heeft overtreden.',
#      0.6991256088082688),
#     ([[196, 916], [240, 916], [240, 946], [196, 946]],
#      '20 .',
#      0.7313705682754517),
#     ([[255, 911], [1391, 911], [1391, 954], [255, 954]],
#      'Bingoal stelt voorts dat de Kansspelautoriteit de markt had moeten wijzen op de',
#      0.7053180326357134),
#     ([[253, 955], [717, 955], [717, 993], [253, 993]],
#      'interpretatie van het wetsartikel.',
#      0.9738678762835559),
#     ([[725, 953], [1429, 953], [1429, 995], [725, 995]],
#      'Via de brancheorganisatie heeft Bingoal begrepen',
#      0.694395733198499),
#     ([[253, 997], [1301, 997], [1301, 1033], [253, 1033]],
#      'dat er in de hele markt onduidelijkheid was over wat er bedoeld werd met',
#      0.7734329511342203),
#     ([[1314, 998], [1418, 998], [1418, 1030], [1314, 1030]],
#      'richten',
#      0.9999980174968082),
#     ([[253, 1041], [299, 1041], [299, 1077], [253, 1077]],
#      "op'",
#      0.9979183874763216),
#     ([[320, 1037], [1353, 1037], [1353, 1080], [320, 1080]],
#      'Bingoal stelt dat het niet opportuun en evenredig is om een sanctie op te',
#      0.667574938128672),
#     ([[253, 1079], [1441, 1079], [1441, 1122], [253, 1122]],
#      'leggen; indien toch een sanctie wordt opgelegd zou dat hooguit een op de toekomst',
#      0.7399772473801836),
#     ([[251, 1118], [757, 1118], [757, 1161], [251, 1161]],
#      'gerichte herstelsanctie moeten zijn.',
#      0.9279279829863089),
#     ([[196, 1208], [238, 1208], [238, 1238], [196, 1238]],
#      '21_',
#      0.9717229462735705),
#     ([[255, 1200], [1399, 1200], [1399, 1245], [255, 1245]],
#      'Bingoal stelt dat bij de hoogte van een eventuele boete rekening gehouden moet',
#      0.8248215050849862),
#     ([[255, 1246], [1411, 1246], [1411, 1288], [255, 1288]],
#      'worden met het onderscheid tussen vergund en onvergund kansspelaanbod en de',
#      0.9605267361653856),
#     ([[255, 1286], [1361, 1286], [1361, 1327], [255, 1327]],
#      'kanalisatiegedachte. Illegale kansspelaanbieders houden zich aan geen enkele',
#      0.579477430219067),
#     ([[253, 1327], [1291, 1327], [1291, 1370], [253, 1370]],
#      'regelgeving, terwijl Bingoal zich aan de wetgeving met betrekking tot het',
#      0.8037086983410113),
#     ([[253, 1371], [1435, 1371], [1435, 1411], [253, 1411]],
#      'aanbieden van kansspelen houdt. Er is nooit de intentie geweest om de regelgeving',
#      0.7910651838597156),
#     ([[253, 1413], [1321, 1413], [1321, 1453], [253, 1453]],
#      'te overtreden. Bingoal vindt dat het opleggen van een boete tussen de EUR',
#      0.4844495052144362),
#     ([[255, 1455], [381, 1455], [381, 1491], [255, 1491]],
#      '100.000,',
#      0.9939613480822389),
#     ([[403, 1455], [581, 1455], [581, 1493], [403, 1493]],
#      'en 500.000,',
#      0.8696322024770209),
#     ([[593, 1455], [1423, 1455], [1423, 1496], [593, 1496]],
#      'leidt tot een effectief voordeel van onvergunde aanbieders',
#      0.8188972619567175),
#     ([[253, 1493], [1339, 1493], [1339, 1537], [253, 1537]],
#      'ten opzichte van vergunde aanbieders. Bingoal stelt dat een eventuele boete',
#      0.8657665521742313),
#     ([[253, 1537], [1373, 1537], [1373, 1579], [253, 1579]],
#      'daarom lager zou moeten zijn dan voornoemde bedragen die zijn opgelegd aan',
#      0.8428769552120133),
#     ([[251, 1581], [646, 1581], [646, 1619], [251, 1619]],
#      'illegale kansspelaanbieders.',
#      0.985880251905779),
#     ([[196, 1690], [228, 1690], [228, 1726], [196, 1726]],
#      '5',
#      0.9999988079074598),
#     ([[249, 1675], [758, 1675], [758, 1738], [249, 1738]],
#      'Juridische beoordeling',
#      0.9992017241601318),
#     ([[195, 1769], [259, 1769], [259, 1805], [195, 1805]],
#      '5.1',
#      0.9936753629981501),
#     ([[276, 1764], [750, 1764], [750, 1812], [276, 1812]],
#      'De wettelijke bepalingen',
#      0.9964619228293057),
#     ([[196, 1820], [240, 1820], [240, 1850], [196, 1850]],
#      '22.',
#      0.9985995322138254),
#     ([[256, 1820], [352, 1820], [352, 1850], [256, 1850]],
#      'Artikel',
#      0.999985221309313),
#     ([[407, 1816], [1365, 1816], [1365, 1857], [407, 1857]],
#      'tweede lid, van de Wok bepaalt dat houders van een vergunning op',
#      0.8525326309261809),
#     ([[251, 1855], [1399, 1855], [1399, 1898], [251, 1898]],
#      'grond van de Wok op zorgvuldige en evenwichtige wijze vorm moeten geven aan',
#      0.864334265101819),
#     ([[254, 1896], [1373, 1896], [1373, 1940], [254, 1940]],
#      'wervings- en reclameactiviteiten  waarbij in het bijzonder wordt gewaakt tegen',
#      0.6399109412108478),
#     ([[252, 1939], [573, 1939], [573, 1982], [252, 1982]],
#      'onmatige deelneming.',
#      0.9763933499920369),
#     ([[1254, 2108], [1332, 2108], [1332, 2136], [1254, 2136]],
#      'Pagina',
#      0.9999936246199173),
#     ([[1338, 2108], [1440, 2108], [1440, 2134], [1338, 2134]],
#      '4 van 13',
#      0.9037963008555452),
#     ([[743, 789], [792, 795], [787, 823], [738, 816]],
#      '4a,',
#      0.9961956769740646),
#     ([[357, 1817], [406, 1824], [401, 1853], [352, 1846]],
#      '4a,',
#      0.9988135424533934)],
#    [([[196, 202], [354, 202], [354, 232], [196, 232]],
#      'OPENBAAR',
#      0.9997857580625014),
#     ([[883, 195], [1129, 195], [1129, 235], [883, 235]],
#      'Kansspelautoriteit',
#      0.9999202545972062),
#     ([[1316, 208], [1510, 208], [1510, 234], [1316, 234]],
#      'Kansspelautoriteit',
#      0.9999989322791986),
#     ([[1317, 245], [1387, 245], [1387, 265], [1317, 265]],
#      'Datum',
#      0.9999913634491684),
#     ([[1318, 276], [1432, 276], [1432, 302], [1318, 302]],
#      '4 april 2023',
#      0.6756293676352894),
#     ([[1317, 311], [1457, 311], [1457, 331], [1317, 331]],
#      'Ons kenmerk',
#      0.8666306171284494),
#     ([[1317, 345], [1379, 345], [1379, 365], [1317, 365]],
#      '15404',
#      0.9134207890774737),
#     ([[1395, 345], [1505, 345], [1505, 365], [1395, 365]],
#      '01.288.556',
#      0.7301870744668644),
#     ([[196, 416], [240, 416], [240, 446], [196, 446]],
#      '23 .',
#      0.9350728392601013),
#     ([[255, 412], [1279, 412], [1279, 454], [255, 454]],
#      'Artikel 35a, eerste lid, van de Wok bepaalt dat de Kansspelautoriteit een',
#      0.8192330406708821),
#     ([[254, 451], [1293, 451], [1293, 495], [254, 495]],
#      'bestuurlijke boete kan opleggen wegens overtreding van de voorschriften',
#      0.6024563143862942),
#     ([[253, 497], [1417, 497], [1417, 535], [253, 535]],
#      'vastgesteld bij of krachtens onder andere artikel 4a van de Wok. In het tweede lid',
#      0.7909013351435218),
#     ([[253, 535], [1377, 535], [1377, 577], [253, 577]],
#      'is bepaald dat de bestuurlijke boete die voor een overtreding als bedoeld in het',
#      0.6080575596079699),
#     ([[253, 578], [1379, 578], [1379, 621], [253, 621]],
#      'eerste lid kan worden opgelegd ten hoogste het bedrag van de zesde categorie,',
#      0.650093266717593),
#     ([[255, 619], [1443, 619], [1443, 659], [255, 659]],
#      'bedoeld in artikel 23, vierde lid, van het Wetboek van Strafrecht of, indien dat meer',
#      0.7082752524317304),
#     ([[253, 659], [1372, 659], [1372, 703], [253, 703]],
#      'is, tien procent van de omzet in het boekjaar voorafgaande aan de beschikking',
#      0.6698498036817754),
#     ([[254, 703], [391, 703], [391, 745], [254, 745]],
#      'bedraagt.',
#      0.9966169577357122),
#     ([[196, 790], [244, 790], [244, 822], [196, 822]],
#      '24 .',
#      0.5811663396131249),
#     ([[253, 784], [1415, 784], [1415, 828], [253, 828]],
#      "In artikel 1, aanhef en sub e, van het Bwrvk zijn 'wervings- en reclameactiviteiten",
#      0.7103271246364037),
#     ([[252, 827], [1399, 827], [1399, 869], [252, 869]],
#      'gedefinieerd als: iedere vorm van communicatie waarmee vergunninghouders, al',
#      0.824905388186511),
#     ([[255, 867], [1327, 867], [1327, 911], [255, 911]],
#      'dan niet met behulp van derden, direct of indirect hun diensten of goederen',
#      0.8597140599555162),
#     ([[253, 915], [407, 915], [407, 953], [253, 953]],
#      'aanprijzen',
#      0.918014782860379),
#     ([[196, 998], [244, 998], [244, 1030], [196, 1030]],
#      '25.',
#      0.686874270439148),
#     ([[253, 995], [659, 995], [659, 1033], [253, 1033]],
#      'In artikel 1, aanhef en sub f,',
#      0.613158054276978),
#     ([[666, 998], [906, 998], [906, 1030], [666, 1030]],
#      'van het Bwrvk is',
#      0.9700035116286955),
#     ([[915, 993], [1435, 993], [1435, 1036], [915, 1036]],
#      "bonus' gedefinieerd als: een goed of",
#      0.7511305986495612),
#     ([[253, 1035], [1309, 1035], [1309, 1079], [253, 1079]],
#      'een dienst, waaronder gratis speeltegoed, aangeboden om spelers voor de',
#      0.9468599933308285),
#     ([[252, 1079], [1425, 1079], [1425, 1121], [252, 1121]],
#      'vergunde kansspelen te werven of te behouden of om reclame voor die kansspelen',
#      0.8210986877416656),
#     ([[254, 1124], [396, 1124], [396, 1156], [254, 1156]],
#      'te maken.',
#      0.9908308940697939),
#     ([[196, 1208], [244, 1208], [244, 1238], [196, 1238]],
#      '26.',
#      0.9997886398349403),
#     ([[255, 1203], [1401, 1203], [1401, 1244], [255, 1244]],
#      'Artikel 2, vierde lid, aanhef en onder a, van het Bwrvk bepaalt dat de houder van',
#      0.69028907902534),
#     ([[253, 1243], [1387, 1243], [1387, 1287], [253, 1287]],
#      'een vergunning tot het organiseren van kansspelen op afstand zijn wervings- en',
#      0.7569506524583711),
#     ([[253, 1288], [1409, 1288], [1409, 1328], [253, 1328]],
#      'reclameactiviteiten voor kansspelen niet richt op personen in de leeftijdscategorie',
#      0.8407609752599153),
#     ([[253, 1331], [561, 1331], [561, 1369], [253, 1369]],
#      'tussen 18 en 24 jaar.',
#      0.8859120270411461),
#     ([[196, 1416], [238, 1416], [238, 1446], [196, 1446]],
#      '27_',
#      0.6078200340270996),
#     ([[255, 1409], [1165, 1409], [1165, 1454], [255, 1454]],
#      'Artikel 12, aanhef, onder i, van de Regeling werving, reclame en',
#      0.5415868333510412),
#     ([[253, 1454], [1227, 1454], [1227, 1496], [253, 1496]],
#      'verslavingspreventie kansspelen3 (hierna: de Rwrvk) bepaalt dat het',
#      0.6975564143228395),
#     ([[253, 1492], [1411, 1492], [1411, 1537], [253, 1537]],
#      'verslavingspreventiebeleid van de houder van een vergunning tot het organiseren',
#      0.7150871522729465),
#     ([[255, 1537], [1429, 1537], [1429, 1577], [255, 1577]],
#      'van een speelcasino, tot het aanwezig hebben van een of meer kansspelautomaten',
#      0.7347688779986475),
#     ([[253, 1578], [1375, 1578], [1375, 1620], [253, 1620]],
#      'in een speelautomatenhal, of tot het organiseren van kansspelen op afstand, in',
#      0.8576011636958446),
#     ([[254, 1622], [332, 1622], [332, 1654], [254, 1654]],
#      'ieder',
#      0.9999841130046352),
#     ([[418, 1626], [474, 1626], [474, 1654], [418, 1654]],
#      'een',
#      0.9999612513354031),
#     ([[477, 1615], [1354, 1615], [1354, 1663], [477, 1663]],
#      'beschrijving bevat van de wijze waarop de implementatie van',
#      0.8531264728989274),
#     ([[253, 1659], [1401, 1659], [1401, 1704], [253, 1704]],
#      'verslavingspreventieve maatregelen en voorzieningen in zijn organisatie alsmede',
#      0.958769807634305),
#     ([[255, 1701], [1387, 1701], [1387, 1746], [255, 1746]],
#      'de passende en effectieve toepassing van deze maatregelen en voorzieningen is',
#      0.7313326266023258),
#     ([[253, 1747], [1337, 1747], [1337, 1785], [253, 1785]],
#      'gewaarborgd. Bij deze beschrijving wordt in ieder geval bijzondere aandacht',
#      0.8804226482654723),
#     ([[252, 1784], [1421, 1784], [1421, 1828], [252, 1828]],
#      'geschonken aan de wijze waarop de vergunninghouder voorkomt dat wervings- en',
#      0.868641617774601),
#     ([[253, 1828], [1307, 1828], [1307, 1869], [253, 1869]],
#      'reclameactiviteiten gericht zijn op maatschappelijk kwetsbare groepen van',
#      0.8341301567020699),
#     ([[252, 1870], [1385, 1870], [1385, 1911], [252, 1911]],
#      'personen als bedoeld in artikel 2, derde lid, van het besluit en jongvolwassenen.',
#      0.6952116208285367),
#     ([[210, 2065], [1227, 2065], [1227, 2101], [210, 2101]],
#      'Regeling van de Minister voor Rechtsbescherming van 21 januari 2021, Stcrt. 2021, 4507.',
#      0.8034947202523995),
#     ([[1254, 2108], [1440, 2108], [1440, 2136], [1254, 2136]],
#      'Pagina 5 van 13',
#      0.8099044497688632),
#     ([[331, 1626], [416, 1620], [417, 1654], [332, 1660]],
#      'geval',
#      0.9999877915397694)],
#    [([[196, 202], [354, 202], [354, 232], [196, 232]],
#      'OPENBAAR',
#      0.9997857580625014),
#     ([[883, 195], [1129, 195], [1129, 235], [883, 235]],
#      'Kansspelautoriteit',
#      0.9999202545972062),
#     ([[1316, 208], [1510, 208], [1510, 234], [1316, 234]],
#      'Kansspelautoriteit',
#      0.9999989322791986),
#     ([[1317, 245], [1387, 245], [1387, 265], [1317, 265]],
#      'Datum',
#      0.9999913634491684),
#     ([[1318, 276], [1432, 276], [1432, 302], [1318, 302]],
#      '4 april 2023',
#      0.6756293676352894),
#     ([[1317, 311], [1457, 311], [1457, 331], [1317, 331]],
#      'Ons kenmerk',
#      0.8666306171284494),
#     ([[1317, 345], [1379, 345], [1379, 365], [1317, 365]],
#      '15404',
#      0.9134207890774737),
#     ([[1395, 345], [1505, 345], [1505, 365], [1395, 365]],
#      '01.288.556',
#      0.7301870744668644),
#     ([[192, 402], [850, 402], [850, 456], [192, 456]],
#      '5.2 Beoordeling van de zienswijze',
#      0.9526040657121915),
#     ([[195, 487], [287, 487], [287, 523], [195, 523]],
#      '5.2.1',
#      0.42517186976295973),
#     ([[296, 478], [1040, 478], [1040, 528], [296, 528]],
#      'De reikwijdte van de norm was onduidelijk',
#      0.8844569981254502),
#     ([[196, 532], [244, 532], [244, 562], [196, 562]],
#      '28 .',
#      0.875231146812439),
#     ([[255, 527], [1286, 527], [1286, 569], [255, 569]],
#      'Volgens Bingoal is artikel 2, vierde lid, aanhef en onder a, van het Bwrvk',
#      0.6946806137972676),
#     ([[252, 567], [1385, 567], [1385, 612], [252, 612]],
#      'onduidelijk. Bingoal heeft de bepaling zo gelezen dat de inhoud van de reclame-',
#      0.6668020410038599),
#     ([[253, 613], [935, 613], [935, 651], [253, 651]],
#      'uiting niet gericht mag zijn op jongvolwassenen.',
#      0.5683012690048599),
#     ([[945, 612], [1357, 612], [1357, 651], [945, 651]],
#      'De Kansspelautoriteit legt de',
#      0.7717982468778982),
#     ([[255, 654], [975, 654], [975, 695], [255, 695]],
#      'bepaling anders uit en meent dat de wetgever met',
#      0.8136465924165975),
#     ([[987, 654], [1378, 654], [1378, 693], [987, 693]],
#      'gericht op" ook zou hebben',
#      0.8488630432009352),
#     ([[255, 697], [553, 697], [553, 735], [255, 735]],
#      'bedoeld "gericht aan\'',
#      0.8002641901352878),
#     ([[575, 695], [1367, 695], [1367, 738], [575, 738]],
#      'of dat die begrippen dezelfde betekenis zouden hebben,',
#      0.8538524804091403),
#     ([[253, 737], [457, 737], [457, 777], [253, 777]],
#      'aldus Bingoal.',
#      0.7694080620774125),
#     ([[196, 818], [240, 818], [240, 848], [196, 848]],
#      '29 .',
#      0.4246146003312483),
#     ([[254, 808], [1212, 808], [1212, 857], [254, 857]],
#      'Volgens Bingoal heeft "gericht op" taalkundig een andere betekenis.',
#      0.8277382294441384),
#     ([[1219, 817], [1403, 817], [1403, 855], [1219, 855]],
#      'De wetgever',
#      0.9861945700726666),
#     ([[255, 851], [1309, 851], [1309, 894], [255, 894]],
#      'had "richten aan" specifiek op moeten nemen in de wetsbepaling als dit de',
#      0.8471872155929865),
#     ([[254, 888], [1413, 888], [1413, 933], [254, 933]],
#      'bedoeling zou zijn van de wetgever. De toelichting bij artikel 2, vierde lid, van het',
#      0.646457438938494),
#     ([[255, 929], [1423, 929], [1423, 971], [255, 971]],
#      'Bwrvk heeft het over de inhoud van een reclame-uiting en niet over het bereik van',
#      0.7976072627537537),
#     ([[253, 973], [527, 973], [527, 1009], [253, 1009]],
#      'een reclame-uiting.',
#      0.9497910584374223),
#     ([[196, 1054], [240, 1054], [240, 1084], [196, 1084]],
#      '30.',
#      0.9991069047348956),
#     ([[255, 1047], [1440, 1047], [1440, 1091], [255, 1091]],
#      'De toelichting bij het Besluit kansspelen op afstand, waarbij het artikel in het Bwrvk',
#      0.8155021866818478),
#     ([[253, 1091], [1431, 1091], [1431, 1131], [253, 1131]],
#      'ook is gewijzigd, zegt volgens Bingoal niets over een wijziging over de interpretatie',
#      0.658106219059202),
#     ([[254, 1132], [430, 1132], [430, 1162], [254, 1162]],
#      'van de term',
#      0.9999535609946374),
#     ([[444, 1127], [597, 1127], [597, 1167], [444, 1167]],
#      '\'richten op"',
#      0.9843238310907799),
#     ([[621, 1128], [1420, 1128], [1420, 1172], [621, 1172]],
#      'De tekst voor "jongvolwassenen" is ongewijzigd in stand',
#      0.8717255870392735),
#     ([[251, 1165], [1415, 1165], [1415, 1207], [251, 1207]],
#      'gelaten. De Kansspelautoriteit hanteert ten onrechte een ruimere uitleg en had de',
#      0.6571402769166849),
#     ([[255, 1205], [659, 1205], [659, 1247], [255, 1247]],
#      'markt hierop moeten wijzen.',
#      0.7527654345515995),
#     ([[194, 1280], [367, 1280], [367, 1323], [194, 1323]],
#      'Beoordeling',
#      0.9610650015944395),
#     ([[196, 1326], [240, 1326], [240, 1356], [196, 1356]],
#      '31.',
#      0.9977261451444819),
#     ([[255, 1322], [1303, 1322], [1303, 1364], [255, 1364]],
#      'Volgens de Kansspelautoriteit is het evident dat Bingoal haar wervings- en',
#      0.9807745277553465),
#     ([[253, 1359], [1411, 1359], [1411, 1402], [253, 1402]],
#      'reclameactiviteiten heeft gericht op jongvolwassenen én dat zij daarmee artikel 2,',
#      0.7087216387373213),
#     ([[253, 1399], [1421, 1399], [1421, 1441], [253, 1441]],
#      'vierde lid, aanhef en onder a, van het Bwrvk heeft overtreden. Anders dan Bingoal',
#      0.8023611252407928),
#     ([[254, 1439], [1324, 1439], [1324, 1482], [254, 1482]],
#      'betoogt, was én is op grond van de wet- en regelgeving en de bijbehorende',
#      0.6346162410414434),
#     ([[252, 1475], [1431, 1475], [1431, 1518], [252, 1518]],
#      'toelichting duidelijk wat de norm in artikel 2, vierde lid, aanhef en onder a, van het',
#      0.5295667308641848),
#     ([[256, 1518], [468, 1518], [468, 1550], [256, 1550]],
#      'Bwrvk inhoudt.',
#      0.5099755650091192),
#     ([[196, 1598], [240, 1598], [240, 1628], [196, 1628]],
#      '32.',
#      0.9966578483581543),
#     ([[256, 1596], [820, 1596], [820, 1628], [256, 1628]],
#      'Zo worden in het vierde lid van artikel 2',
#      0.9784112569852423),
#     ([[827, 1595], [1293, 1595], [1293, 1635], [827, 1635]],
#      'van het Bwrvk twee doelgroepen',
#      0.8172464784508192),
#     ([[252, 1632], [1383, 1632], [1383, 1674], [252, 1674]],
#      'genoemd: jongvolwassenen en personen die staan ingeschreven in het Centraal',
#      0.7838200395660372),
#     ([[252, 1671], [907, 1671], [907, 1712], [252, 1712]],
#      'register uitsluiting kansspelen (hierna: Cruks) .',
#      0.5349004484556972),
#     ([[915, 1673], [1437, 1673], [1437, 1711], [915, 1711]],
#      'In de toelichting bij artikel 2 van het',
#      0.7568118451657484),
#     ([[254, 1712], [1193, 1712], [1193, 1751], [254, 1751]],
#      'Bwrvk staat over personen die staan ingeschreven in Cruks dat de',
#      0.6236524274540474),
#     ([[253, 1751], [518, 1751], [518, 1789], [253, 1789]],
#      'vergunninghouder',
#      0.9736386102105681),
#     ([[531, 1747], [1435, 1747], [1435, 1790], [531, 1790]],
#      'weet dat het hierbij gaat om personen die geen gebruik wensen',
#      0.9751556413409337),
#     ([[253, 1787], [765, 1787], [765, 1830], [253, 1830]],
#      'te maken van zijn kansspeldiensten.',
#      0.9288067412783414),
#     ([[775, 1789], [1439, 1789], [1439, 1827], [775, 1827]],
#      'Hij kan deze personen identificeren en van zijn',
#      0.7217525747786748),
#     ([[252, 1822], [866, 1822], [866, 1870], [252, 1870]],
#      'wervings- en reclameactiviteiten uitsluiten: ~',
#      0.5545926104829819),
#     ([[881, 1827], [1376, 1827], [1376, 1869], [881, 1869]],
#      'Nu in het vierde lid dezelfde regels',
#      0.9322476097679593),
#     ([[251, 1863], [1395, 1863], [1395, 1908], [251, 1908]],
#      'gelden voor personen die staan ingeschreven in Cruks en voor jongvolwassenen,',
#      0.8637548611021244),
#     ([[255, 1902], [1289, 1902], [1289, 1946], [255, 1946]],
#      'heeft deze toelichting ook betrekking op jongvolwassenen, ook al worden',
#      0.7873192454475515),
#     ([[251, 1942], [897, 1942], [897, 1983], [251, 1983]],
#      'jongvolwassenen hier niet expliciet genoemd.',
#      0.8838715253621057),
#     ([[1254, 2108], [1332, 2108], [1332, 2136], [1254, 2136]],
#      'Pagina',
#      0.9999936246199173),
#     ([[1338, 2108], [1440, 2108], [1440, 2134], [1338, 2134]],
#      '6 van 13',
#      0.9873571501746753)],
#    [([[196, 202], [354, 202], [354, 232], [196, 232]],
#      'OPENBAAR',
#      0.9997857580625014),
#     ([[883, 195], [1129, 195], [1129, 235], [883, 235]],
#      'Kansspelautoriteit',
#      0.9999202545972062),
#     ([[1316, 208], [1510, 208], [1510, 234], [1316, 234]],
#      'Kansspelautoriteit',
#      0.9999989322791986),
#     ([[1317, 245], [1387, 245], [1387, 265], [1317, 265]],
#      'Datum',
#      0.9999913634491684),
#     ([[1318, 276], [1432, 276], [1432, 302], [1318, 302]],
#      '4 april 2023',
#      0.6756293676352894),
#     ([[1317, 311], [1457, 311], [1457, 331], [1317, 331]],
#      'Ons kenmerk',
#      0.8666306171284494),
#     ([[1317, 345], [1379, 345], [1379, 365], [1317, 365]],
#      '15404',
#      0.9134207890774737),
#     ([[1395, 345], [1505, 345], [1505, 365], [1395, 365]],
#      '01.288.556',
#      0.7301870744668644),
#     ([[196, 410], [240, 410], [240, 442], [196, 442]],
#      '33.',
#      0.999465864290287),
#     ([[253, 409], [1385, 409], [1385, 447], [253, 447]],
#      'Ook op andere manieren blijkt dat de bedoeling van de wetgever is geweest dat',
#      0.639565693182737),
#     ([[255, 443], [1437, 443], [1437, 488], [255, 488]],
#      'wervings- en reclameactiviteiten niet gericht mogen worden op jongvolwassenen en',
#      0.8379789214239466),
#     ([[253, 483], [1359, 483], [1359, 526], [253, 526]],
#      'dat daaronder ook valt het sturen van reclameberichten aan jongvolwassenen.',
#      0.6804580116249429),
#     ([[196, 566], [240, 566], [240, 596], [196, 596]],
#      '34 .',
#      0.5033229245688161),
#     ([[256, 564], [732, 564], [732, 596], [256, 596]],
#      'Zo is in het derde lid van artikel 2',
#      0.8465987515897065),
#     ([[738, 558], [1312, 558], [1312, 606], [738, 606]],
#      'van het Bwrvk bepaald dat wervings- en',
#      0.8257909214319508),
#     ([[253, 600], [1403, 600], [1403, 642], [253, 642]],
#      'reclameactiviteiten niet gericht mogen worden op kwetsbare groepen, waaronder',
#      0.8458599007509661),
#     ([[254, 639], [461, 639], [461, 682], [254, 682]],
#      'minderjarigen.',
#      0.9206984216198791),
#     ([[469, 640], [1433, 640], [1433, 682], [469, 682]],
#      'De uitleg van Bingoal volgend, zou deze bepaling betekenen dat het',
#      0.7972546101431338),
#     ([[253, 678], [1305, 678], [1305, 719], [253, 719]],
#      'niet is toegestaan om reclame voor online kansspelen te maken gericht op',
#      0.6021476896115893),
#     ([[254, 717], [1197, 717], [1197, 760], [254, 760]],
#      'minderjarigen, maar dat het wel toegestaan zou zijn om algemene',
#      0.8404847539966837),
#     ([[252, 755], [1397, 755], [1397, 798], [252, 798]],
#      'reclameberichten aan minderjarigen te sturen, ongeacht of zij mogen deelnemen',
#      0.7579111382113617),
#     ([[253, 794], [1381, 794], [1381, 836], [253, 836]],
#      'aan kansspelen. Het spreekt voor zich dat de Kansspelautoriteit deze uitleg niet',
#      0.7322651622101504),
#     ([[253, 837], [337, 837], [337, 873], [253, 873]],
#      'volgt.',
#      0.9983001752566609),
#     ([[196, 918], [242, 918], [242, 950], [196, 950]],
#      '35.',
#      0.9996227768834963),
#     ([[253, 917], [1123, 917], [1123, 955], [253, 955]],
#      'In artikel 12 van de Rwrvk is daarnaast bepaald wat er in het',
#      0.7294741398363768),
#     ([[253, 955], [1385, 955], [1385, 993], [253, 993]],
#      'verslavingspreventiebeleid van een vergunninghouder moet staan. In onderdeel',
#      0.9140738013106409),
#     ([[253, 993], [1305, 993], [1305, 1033], [253, 1033]],
#      'van dit artikel staat: "de wijze waarop de vergunninghouder voorkomt dat',
#      0.6490623424141398),
#     ([[255, 1030], [1438, 1030], [1438, 1071], [255, 1071]],
#      'wervings- en reclameactiviteiten gericht zijn op maatschappelijk kwetsbare groepen',
#      0.69741653461561),
#     ([[256, 1076], [308, 1076], [308, 1102], [256, 1102]],
#      'van',
#      0.977242648601532),
# ...
#      'De',
#      0.7130999527937291),
#     ([[286, 1833], [1315, 1833], [1315, 1872], [286, 1872]],
#      'Kansspelautoriteit hecht eraan sanctiebesluiten openbaar te maken vanwege het',
#      0.8439071487007264),
#     ([[245, 1867], [1409, 1867], [1409, 1909], [245, 1909]],
#      'maatschappelijk belang om de consument te informeren over dan wel te waarschuwen voor',
#      0.9682815821953956)],
#    [([[196, 202], [354, 202], [354, 232], [196, 232]],
#      'OPENBAAR',
#      0.9997857580625014),
#     ([[893, 189], [1142, 189], [1142, 237], [893, 237]],
#      'Kansspelautoriteit',
#      0.9996329859208789),
#     ([[1318, 208], [1510, 208], [1510, 234], [1318, 234]],
#      'Kansspelautoriteit',
#      0.9999974292383579),
#     ([[1318, 244], [1388, 244], [1388, 268], [1318, 268]],
#      'Datum',
#      0.8033320288859517),
#     ([[1334, 276], [1432, 276], [1432, 302], [1334, 302]],
#      'april 2023',
#      0.9964210758085321),
#     ([[1316, 308], [1458, 308], [1458, 335], [1316, 335]],
#      'Ons kenmerk',
#      0.9841986432472228),
#     ([[1316, 344], [1492, 344], [1492, 368], [1316, 368]],
#      '15404/01.288.554',
#      0.8353747216306868),
#     ([[243, 399], [1397, 399], [1397, 435], [243, 435]],
#      "bepaalde praktijken van aanbieders van kansspelen en de risico's die consumenten daarbij",
#      0.8158148388281575),
#     ([[240, 433], [1417, 433], [1417, 471], [240, 471]],
#      'lopen. Daarnaast beoogt de Kansspelautoriteit met de openbaarmaking van sanctiebesluiten',
#      0.8600305302848732),
#     ([[242, 465], [1263, 465], [1263, 506], [242, 506]],
#      'transparantie te bieden met betrekking tot het functioneren van zijn organisatie.',
#      0.7979914415894921),
#     ([[1272, 470], [1432, 470], [1432, 500], [1272, 500]],
#      'Ten slotte is',
#      0.9938379422014085),
#     ([[242, 501], [1425, 501], [1425, 541], [242, 541]],
#      'openbaarmaking van belang in verband met de preventieve werking die van sanctiebesluiten',
#      0.7843498408271388),
#     ([[243, 535], [1081, 535], [1081, 576], [243, 576]],
#      'kan uitgaan naar andere ondernemingen en natuurlijke personen.',
#      0.8531498617100669),
#     ([[197, 611], [217, 611], [217, 635], [197, 635]],
#      '6 ',
#      0.7596623951978098),
#     ([[245, 607], [1347, 607], [1347, 645], [245, 645]],
#      'De Kansspelautoriteit acht openbaarmaking ook in dit concrete geval in het belang van',
#      0.8171375425511183),
#     ([[243, 643], [1369, 643], [1369, 679], [243, 679]],
#      'consumenten die aldus kennis kunnen nemen van het feit dat ten aanzien van Bingoal is',
#      0.731938798311186),
#     ([[242, 675], [1411, 675], [1411, 717], [242, 717]],
#      'vastgesteld dat zij in strijd heeft gehandeld met artikel 2, vierde lid, aanhef en onder a, van',
#      0.8703803129632128),
#     ([[243, 710], [1099, 710], [1099, 752], [243, 752]],
#      'het Bwrvk en dat de Kansspelautoriteit hiertegen heeft opgetreden.',
#      0.7358455910916993),
#     ([[197, 787], [217, 787], [217, 811], [197, 811]],
#      '7',
#      0.9999988079074598),
#     ([[246, 786], [284, 786], [284, 812], [246, 812]],
#      'De',
#      0.9840389129242653),
#     ([[286, 782], [1061, 782], [1061, 821], [286, 821]],
#      'Kansspelautoriteit neemt hierbij het volgende in aanmerking.',
#      0.9657192016898913),
#     ([[194, 856], [218, 856], [218, 882], [194, 882]],
#      '8',
#      0.9999992847443906),
#     ([[245, 850], [1343, 850], [1343, 889], [245, 889]],
#      'De Afdeling bestuursrechtspraak van de Raad van State (hierna: de Afdeling) heeft bij',
#      0.7325460799990229),
#     ([[242, 888], [1167, 888], [1167, 926], [242, 926]],
#      'uitspraak van 10 november 2010, ECLI:NL:RVS:2010.B03468, bepaald:',
#      0.788670584157776),
#     ([[1182, 890], [1420, 890], [1420, 920], [1182, 920]],
#      'Het boetebesluit is',
#      0.7731728640160936),
#     ([[244, 928], [294, 928], [294, 952], [244, 952]],
#      'een',
#      0.9999932551025371),
#     ([[299, 923], [1331, 923], [1331, 959], [299, 959]],
#      'bevoegd genomen besluit in het kader van een aan het college door de wetgever',
#      0.7550046749631577),
#     ([[242, 957], [1353, 957], [1353, 996], [242, 996]],
#      'toegekende taak om toezicht te houden op de naleving van regelgeving en de daarmee',
#      0.8694480791098087),
#     ([[242, 988], [1337, 988], [1337, 1033], [242, 1033]],
#      'samenhangende bevoegdheid om handhavend op te treden tegen overtreding van die',
#      0.8692396156002236),
#     ([[243, 1029], [401, 1029], [401, 1065], [243, 1065]],
#      'regelgeving.',
#      0.9942480423015487),
#     ([[408, 1029], [1392, 1029], [1392, 1062], [408, 1062]],
#      'In het kader van deze toezichthoudende taak past dat boetebesluiten worden',
#      0.5890833799300773),
#     ([[242, 1061], [1401, 1061], [1401, 1101], [242, 1101]],
#      'gepubliceerd, zodat bekendheid wordt gegeven aan de wijze van uitvoering van deze taak"',
#      0.6521670609376989),
#     ([[243, 1099], [471, 1099], [471, 1135], [243, 1135]],
#      '(overweging 2.5).',
#      0.9898147847314975),
#     ([[195, 1171], [215, 1171], [215, 1195], [195, 1195]],
#      '9',
#      0.8018052745907539),
#     ([[243, 1164], [1311, 1164], [1311, 1205], [243, 1205]],
#      'Ten aanzien van de vereiste belangenafweging bepaalde de Afdeling in voornoemde',
#      0.8455296522272778),
#     ([[242, 1200], [1379, 1200], [1379, 1239], [242, 1239]],
#      'uitspraak: "Van een onevenredige benadeling zal in gevallen als de onderhavige naar het',
#      0.6218060275881718),
#     ([[243, 1234], [1387, 1234], [1387, 1275], [243, 1275]],
#      'oordeel van de Afdeling sprake kunnen zijn als het boetebesluit uiteindelijk in rechte geen',
#      0.9916290366310387),
#     ([[243, 1271], [1421, 1271], [1421, 1310], [243, 1310]],
#      'stand houdt en de betrokken rechtspersoon ten onrechte als overtreder kenbaar is gemaakt.',
#      0.7355462127316632),
#     ([[243, 1303], [1263, 1303], [1263, 1344], [243, 1344]],
#      'Of sprake is van onevenredige benadeling hangt dan af van een oordeel over de',
#      0.7428987782931353),
#     ([[243, 1343], [711, 1343], [711, 1379], [243, 1379]],
#      'rechtmatigheid van het boetebesluit.',
#      0.8903806605696829),
#     ([[196, 1414], [236, 1414], [236, 1444], [196, 1444]],
#      '10.',
#      0.9980659784601443),
#     ([[245, 1413], [1385, 1413], [1385, 1449], [245, 1449]],
#      'De Kansspelautoriteit wijst erop dat de namen van natuurlijke personen en de namen van',
#      0.7502001002824427),
#     ([[242, 1443], [1329, 1443], [1329, 1485], [242, 1485]],
#      'rechtspersonen die in het onderzoek zijn genoemd, maar van wie geen overtreding is',
#      0.9292899891404189),
#     ([[242, 1479], [1365, 1479], [1365, 1520], [242, 1520]],
#      'vastgesteld, nimmer openbaar worden gemaakt. Verwijzingen naar namen die genoemd',
#      0.7060515884310656),
#     ([[245, 1514], [1391, 1514], [1391, 1554], [245, 1554]],
#      'worden in jurisprudentie en reeds openbaar gemaakte besluiten van de Kansspelautoriteit',
#      0.7735334326613355),
#     ([[243, 1553], [1281, 1553], [1281, 1590], [243, 1590]],
#      'vallen hier niet onder. Daarnaast zullen de gegevens die de Kansspelautoriteit als',
#      0.9560745989517105),
#     ([[245, 1587], [1187, 1587], [1187, 1623], [245, 1623]],
#      'bedrijfsvertrouwelijk beschouwt eveneens niet openbaar worden gemaakt.',
#      0.9279351180187694),
#     ([[195, 1655], [1311, 1655], [1311, 1695], [195, 1695]],
#      '11. Openbaarmaking geschiedt met het oog op de hiervoor weergegeven belangen: het',
#      0.6697224507542845),
#     ([[242, 1690], [1413, 1690], [1413, 1727], [242, 1727]],
#      'informeren van consumenten, generale en speciale preventie en transparantie van het werk',
#      0.7157187512436392),
#     ([[243, 1727], [1289, 1727], [1289, 1763], [243, 1763]],
#      'van de Kansspelautoriteit. Openbaarmaking is derhalve zeer relevant. Gelet op de',
#      0.7711484852711155),
#     ([[243, 1760], [1369, 1760], [1369, 1799], [243, 1799]],
#      'belangenafweging die de Kansspelautoriteit in de randnummers hiervoor heeft gemaakt,',
#      0.9208417956885447),
#     ([[245, 1793], [1249, 1793], [1249, 1833], [245, 1833]],
#      'weegt het belang van openbaarmaking volgens de Kansspelautoriteit zwaarder .',
#      0.6887073050685573)],
#    [([[196, 202], [354, 202], [354, 232], [196, 232]],
#      'OPENBAAR',
#      0.9997857580625014),
#     ([[893, 189], [1142, 189], [1142, 237], [893, 237]],
#      'Kansspelautoriteit',
#      0.9996329859208789),
#     ([[1318, 208], [1510, 208], [1510, 234], [1318, 234]],
#      'Kansspelautoriteit',
#      0.9999974292383579),
#     ([[1318, 244], [1388, 244], [1388, 268], [1318, 268]],
#      'Datum',
#      0.8033320288859517),
#     ([[1334, 276], [1432, 276], [1432, 302], [1334, 302]],
#      'april 2023',
#      0.9964210758085321),
#     ([[1316, 308], [1458, 308], [1458, 335], [1316, 335]],
#      'Ons kenmerk',
#      0.9841986432472228),
#     ([[1316, 344], [1492, 344], [1492, 368], [1316, 368]],
#      '15404/01.288.554',
#      0.8353747216306868),
#     ([[196, 400], [236, 400], [236, 430], [196, 430]],
#      '12.',
#      0.9876199330058844),
#     ([[245, 399], [1437, 399], [1437, 435], [245, 435]],
#      'De Kansspelautoriteit heeft geen aanleiding te veronderstellen dat het sanctiebesluit in rechte',
#      0.8965516892177638),
#     ([[243, 432], [1405, 432], [1405, 470], [243, 470]],
#      'geen stand zal houden. Naar het oordeel van de Kansspelautoriteit is afdoende aangetoond',
#      0.6133863315192342),
#     ([[243, 467], [1373, 467], [1373, 506], [243, 506]],
#      'dat er sprake is van een overtreding van artikel 2, vierde lid, aanhef en onder a, van het',
#      0.6527370437590599),
#     ([[246, 506], [332, 506], [332, 532], [246, 532]],
#      'Bwrvk.',
#      0.9689687350091579),
#     ([[196, 576], [234, 576], [234, 602], [196, 602]],
#      '13_',
#      0.9305253200821816),
#     ([[244, 574], [562, 574], [562, 604], [244, 604]],
#      'Indien een sanctie wordt',
#      0.8040241197674753),
#     ([[564, 572], [1417, 572], [1417, 612], [564, 612]],
#      'opgelegd staan verschillende rechtsmiddelen open. Hetzelfde geldt',
#      0.9405259119131261),
#     ([[243, 609], [569, 609], [569, 645], [243, 645]],
#      'voor de openbaarmaking.',
#      0.9624707106098497),
#     ([[196, 680], [234, 680], [234, 708], [196, 708]],
#      '14_',
#      0.9731198847047412),
#     ([[243, 677], [1343, 677], [1343, 716], [243, 716]],
#      'Van belangen of omstandigheden, op grond waarvan zou moeten worden afgezien van',
#      0.7054380152225078),
#     ([[243, 711], [961, 711], [961, 749], [243, 749]],
#      'openbaarmaking, is de Kansspelautoriteit niet gebleken.',
#      0.6525374705850735),
#     ([[196, 822], [226, 822], [226, 856], [196, 856]],
#      '3',
#      0.9999933242909265),
#     ([[255, 817], [403, 817], [403, 859], [255, 859]],
#      'Besluit',
#      0.9999967108462834),
#     ([[195, 899], [1441, 899], [1441, 939], [195, 939]],
#      '15. Op grond van het voorgaande zal de Kansspelautoriteit overgaan tot openbaarmaking van het',
#      0.8489701262438176),
#     ([[246, 936], [386, 936], [386, 966], [246, 966]],
#      'besluit van',
#      0.9806161054909157),
#     ([[393, 941], [409, 941], [409, 963], [393, 963]],
#      '4',
#      0.9338902189780289),
#     ([[413, 935], [885, 935], [885, 972], [413, 972]],
#      'april 2023 met kenmerk 01.288.553.',
#      0.8742357208827369),
#     ([[891, 935], [1427, 935], [1427, 971], [891, 971]],
#      'Tevens zal dit besluit tot openbaarmaking',
#      0.8314551058725711),
#     ([[242, 969], [593, 969], [593, 1007], [242, 1007]],
#      'openbaar worden gemaakt.',
#      0.5629030111925786),
#     ([[195, 1038], [1319, 1038], [1319, 1078], [195, 1078]],
#      '16. In het openbaar te maken besluit blijft vermelding van de namen van alle in de zaak',
#      0.9080594089976279),
#     ([[244, 1073], [803, 1073], [803, 1112], [244, 1112]],
#      'betrokken natuurlijke personen achterwege.',
#      0.993942046917677),
#     ([[811, 1075], [1401, 1075], [1401, 1113], [811, 1113]],
#      'Ook zullen de bedrijfsvertrouwelijke gegevens',
#      0.9921307646024297),
#     ([[243, 1109], [647, 1109], [647, 1147], [243, 1147]],
#      'niet openbaar gemaakt worden',
#      0.9891270552893431),
#     ([[196, 1182], [236, 1182], [236, 1210], [196, 1210]],
#      '17.',
#      0.9979154288058454),
#     ([[252, 1177], [1129, 1177], [1129, 1217], [252, 1217]],
#      'Openbaarmaking geschiedt door middel van publicatie op de website',
#      0.6899749104152352),
#     ([[247, 1223], [311, 1223], [311, 1243], [247, 1243]],
#      'WWW',
#      0.9974578811227808),
#     ([[312, 1212], [585, 1212], [585, 1252], [312, 1252]],
#      'kansspelautoriteit.nl.',
#      0.5780210064159326),
#     ([[195, 1284], [505, 1284], [505, 1322], [195, 1322]],
#      'Den Haag, 4 april 2023,',
#      0.7974875224874728),
#     ([[195, 1354], [798, 1354], [798, 1390], [195, 1390]],
#      'De raad van bestuur van de Kansspelautoriteit,',
#      0.8973022823145699),
#     ([[196, 1389], [375, 1389], [375, 1422], [196, 1422]],
#      'namens deze,',
#      0.9258966980686719),
#     ([[196, 1470], [246, 1470], [246, 1496], [196, 1496]],
#      'W.g',
#      0.5766208171844482),
#     ([[196, 1568], [238, 1568], [238, 1592], [196, 1592]],
#      'mr_',
#      0.8920812606811523),
#     ([[248, 1564], [560, 1564], [560, 1594], [248, 1594]],
#      'Laurence M.A. Gimbrere',
#      0.8407325616103726),
#     ([[195, 1593], [825, 1593], [825, 1633], [195, 1633]],
#      'Hoofd afdeling Juridische Zaken en Vergunningen',
#      0.7901235605734998),
#     ([[195, 1656], [603, 1656], [603, 1692], [195, 1692]],
#      'VERZONDEN OP 5 april 2023',
#      0.9603056443386205),
#     ([[193, 1745], [1391, 1745], [1391, 1786], [193, 1786]],
#      'Tegen dit besluit kan degene wiens belang rechtstreeks bij dit besluit is betrokken; binnen zes',
#      0.5720595064726154),
#     ([[195, 1776], [1421, 1776], [1421, 1815], [195, 1815]],
#      'weken na de dag van bekendmaking van dit besluit een gemotiveerd bezwaarschrift indienen bij',
#      0.904456971825214),
#     ([[193, 1809], [1383, 1809], [1383, 1845], [193, 1845]],
#      'de Kansspelautoriteit, afdeling Juridische Zaken en Vergunningen, Postbus 298, 2501 CG Den',
#      0.5150006467473957),
#     ([[193, 1836], [1415, 1836], [1415, 1876], [193, 1876]],
#      'Haag. U kunt uw bezwaarschrift ook digitaal indienen, door het in PDF-formaat te e-mailen naar',
#      0.5879987221311189),
#     ([[269, 1869], [561, 1869], [561, 1905], [269, 1905]],
#      '@kansspelautoriteit.nI.',
#      0.8014682957842483),
#     ([[191, 1870], [274, 1865], [275, 1900], [192, 1906]],
#      'griffie',
#      0.6965302209785553)],
#    [([[196, 202], [354, 202], [354, 232], [196, 232]],
#      'OPENBAAR',
#      0.9997857580625014),
#     ([[893, 189], [1142, 189], [1142, 237], [893, 237]],
#      'Kansspelautoriteit',
#      0.9996329859208789),
#     ([[1318, 208], [1510, 208], [1510, 234], [1318, 234]],
#      'Kansspelautoriteit',
#      0.9999974292383579),
#     ([[1318, 244], [1388, 244], [1388, 268], [1318, 268]],
#      'Datum',
#      0.8033320288859517),
#     ([[1334, 276], [1432, 276], [1432, 302], [1334, 302]],
#      'april 2023',
#      0.9964210758085321),
#     ([[1316, 308], [1458, 308], [1458, 335], [1316, 335]],
#      'Ons kenmerk',
#      0.9841986432472228),
#     ([[1316, 344], [1492, 344], [1492, 368], [1316, 368]],
#      '15404/01.288.554',
#      0.8353747216306868),
#     ([[193, 429], [1157, 429], [1157, 465], [193, 465]],
#      'Let wel: het instellen van bezwaar schort de werking van dit besluit niet op.',
#      0.8361039840610015),
#     ([[194, 462], [324, 462], [324, 490], [194, 490]],
#      'Kunt u de',
#      0.9389547784800018),
#     ([[324, 456], [493, 456], [493, 497], [324, 497]],
#      'beslissing op',
#      0.9988434084491749),
#     ([[497, 455], [1427, 455], [1427, 495], [497, 495]],
#      'uw bezwaarschrift niet afwachten vanwege een spoedeisend belang? Dan',
#      0.8416023847515824),
#     ([[196, 492], [1344, 492], [1344, 524], [196, 524]],
#      'kunt u bij de sector bestuursrecht van de rechtbank in uw arrondissement een verzoek om',
#      0.7104074016573948),
#     ([[195, 517], [601, 517], [601, 557], [195, 557]],
#      'voorlopige voorziening indienen',
#      0.9986812795772482)]]])

# %% [markdown]
# ### Analyse raw OCR output into structured text
#
# Take those OCR fagments and separate off headers, group into paragraphs, and such
#
# This is separate from the above because this took a bunch of tweaking specific to this document layout.
#
# It's also long because a bunch of specific augmentation goes on here.
#
# It amounts to a bunch of math on numbers so takes less than a minutye It's separate so that we can tweak and re-run it easily.

# %%
# a bunch of helpers
from wetsuite.extras.ocr import doc_extent, page_fragment_filter, bbox_max_x, bbox_max_y, bbox_min_x, bbox_min_y, bbox_height

verbose = False

dataset_cases = [] # distinct name, has a different structure

for case_i, case_tuple in enumerate(extracted_cases):
    case_dict, case_doc_dicts, ocrdata = case_tuple
    case_name = case_dict['name']

    print( 'CASE %d: %s'%(case_i, case_name) )

    case_docs = [] #this part's main output, becomes a dict per case (with keys like 'url', 'pages')
    assert len(case_doc_dicts) == len(ocrdata)

    case_doc_dates = set() # or maybe count?

    ## for each document, analyze the OCR fragments and sort it into more directly useful data
    for doc_i in range(len(case_doc_dicts)): #ocrdata should have the same length
        pdf_dict = case_doc_dicts[doc_i]
        doc_ocr  = ocrdata[doc_i]


        pdf_url = pdf_dict['pdf_url']
        print( '  DOC %d:  %s'%(doc_i,   wetsuite.helpers.format.url_basename( pdf_url ) ) )


        doc_pages = [] # the main output for a document - a list of dicts that each detail a page
        doc_dates = [] # picks out dates from the headers

        doc_wide_extent = doc_extent( doc_ocr ) # the area outside there is no text at all, throughout all of the page's document
        #print( 'doc_min_x, doc_max_x, doc_min_y, doc_max_y', extent )

        for page_i, page in enumerate( doc_ocr ): # page is now all text framents on a page, a list of all (bbox, text, cert) 
            if verbose:
                print( '   PAGE %s ---------------------------------------------------------------------------'%(page_i) )

            ### Determine margins
            # so that we can have logic that extract text that hopefully flows between pages
            head_y_ary, foot_y_ary = [], []
            # - Top margin defined by lowest box extent of 
            #    - "Kansspenautoriteit" (not really necessary)
            #    - "OPENBAAR"
            #    - "Ons kenmerk" plus one extra box's worth
            matches = page_fragment_filter( page, r'^Kansspelautoriteit$', q_max_y=0.25, extent=doc_wide_extent )
            for bbox, text, cert in matches:
                #print ('    [page %d] Kansspelautoriteit MATCH: %s %s %s'%(page_i, bbox, text, cert))
                head_y_ary.append( bbox_max_y(bbox) )
            matches = page_fragment_filter( page, r'^OPENBAAR$', q_max_y=0.3, q_max_x=0.35, extent=doc_wide_extent )
            for bbox, text, cert in matches:
                #print ('    [page %d] OPENBAAR MATCH: %s %s %s'%(page_i, bbox, text, cert))
                head_y_ary.append( bbox_max_y(bbox) )
            matches = page_fragment_filter( page, r'Ons kenmerk', q_max_y=0.25, extent=doc_wide_extent )
            for bbox, text, cert in matches:
                #print ('    [page %d] Ons kenmerk MATCH: %s %s %s'%(page_i, bbox, text, cert))
                head_y_ary.append( bbox_max_y(bbox) + 1.2* bbox_height(bbox) ) # we expect one more line of the same height below it (times fudge factor, for expected whitespace)
            
            # - Bottom margin defined by highest box y of "agina [0-9]+ van [0-9]+" in the bottom right
            matches = page_fragment_filter( page, r'Pagina', q_min_x=0.7, q_min_y=0.75, extent=doc_wide_extent ) # the rest, e.g. (\s*[0-9]+\s*van\s*[0-9]+)?, is optional because it's sometimes detected separately, or not at all
            for bbox, text, cert in matches: # 
                #print ('    [page %d] Pagina MATCH: %s %s %s'%(page_i, bbox, text, cert))
                foot_y_ary.append( bbox_min_y(bbox)  )
            if len(foot_y_ary)==0: # look harder for page - a lone number to the bottom right that matches roughly with the page number we think it is is probably also the page number
                pages_around = '|'.join( str(pag)  for pag in range(page_i-1, page_i+2) )
                matches = page_fragment_filter( page, r'^(%s)$'%pages_around, q_min_y=0.75, q_min_x=0.7, extent=doc_wide_extent )
                for bbox, text, cert in matches: # (\s*[0-9]+\s*van\s*[0-9]+)?
                    #print ('    [page %d] Bare pagina MATCH: %s %s %s'%(page_i, bbox, text, cert))
                    foot_y_ary.append( bbox_min_y(bbox)  )

            if len(head_y_ary)==0:
                head_bot_y = None
            else:
                head_bot_y = max(head_y_ary)

            if len(foot_y_ary)==0:
                foot_top_y = None
            else:
                foot_top_y = min(foot_y_ary)

            if verbose:
                print("    page head_y: ", head_bot_y) # TODO: call this head_bot_y (and probably rename h)
                print("    page foot_y: ", foot_top_y) # TODO: call this foot_top_y


            ### Figure out some things about the page
            ## list-iten X position
            # Most of these documents have numbering on their headers and paragraphs
            # these list-iten numbers at the start of lines are not detected consistently by OCR,
            # nor are they linguistic information, so attempt to remove them.
            # We like to be sure (to not remove such things from actual text), so 
            lnum_righty = []
            matches = page_fragment_filter( page, r'^[0-9.]+$', q_max_x=0.2, q_min_y=head_bot_y,q_max_y=foot_top_y, extent=doc_wide_extent ) 
            for bbox, text, cert in matches:
                if verbose:
                    print ('    [page %d] LI NUM MATCH: %s %s %s'%(page_i, bbox, text, cert))
                lnum_righty.append( bbox_max_x(bbox)  )            
            if len(lnum_righty) < 4: # not sure enough - be more conservative
                lnum_righty = doc_wide_extent[0] + 20 # TODO: avoid that constant
            else:
                lnum_righty = max(lnum_righty)

            ## average box size
            box_heights = []
            for bbox, text, cert in page:
                box_heights.append( bbox_height( bbox ) )
            median_boxheight = numpy.median(box_heights)
            #print(box_heights)
            #print("Median bbox height: %d"%median_boxheight)


            ### Group and process fragments   (in passes, to make logic like 'is this the last thing in the body' easier)
            # - separate into head, body, foot
            # - polish the body, e.g. 
            #   'is this the last thing on the page AFTER we removed the footer' logic easier
            #   replace '-' at end of paragraph with '.'

            page_contents = {
                'head_fragments':[],
                'body_fragments':[],
                'misc_fragments':[],
                'foot_fragments':[],
                'body_text':[],
            }


            ## Sort fragments into header, body, and footer
            prev_topy, prev_boty = 0,0 
            for frag_i, (bbox, text, cert) in enumerate(page):
                topleft, topright, botright, botleft = bbox
                topy, boty = topleft[1], botright[1]

                text = re.sub('[_-]\s*$','.', text) # mistaken for period sometimes. Could be more thorough, but this is a start

                if head_bot_y is not None and topy < head_bot_y :
                    page_contents['head_fragments'].append( (bbox, text, cert) )

                elif foot_top_y is not None and boty > foot_top_y: # CONSIDER: also remove numbers from left of boxes that start at the -- IF we think it's such a number.
                    page_contents['foot_fragments'].append( (bbox, text, cert) )

                elif wetsuite.helpers.strings.is_numeric( text) and topleft[0] < lnum_righty+5:
                    pass
                    #page_contents['misc_fragments'].append( (bbox, text, cert) )

                else: #probably useful body
                    #print( '      %6s  %12s %-12s  fs:%-5s  %s '%( keep_ignore, topleft, botright, boxheight, text ) )
                    page_contents['body_fragments'].append( (bbox, text, cert) )

                    case_dict['money'].extend( find_eur_money(text, minimum=5001) )

                prev_topy, prev_boty = topy, boty

            ## Header stuff. Little smartness yet.
            head_text = [] 
            for body_frag_i, (bbox, text, cert) in enumerate(page_contents['head_fragments']):
                head_text.append(text)

                _, dts = wetsuite.helpers.date.find_dates_in_text(text)
                for dt in dts:
                    if dt is not None:
                        case_doc_dates.add( dt )
                        doc_dates.append( wetsuite.helpers.date.format_date(dt) )
                # CONSIDER: getting out kenmerk


            foot_text = [] 
            for body_frag_i, (bbox, text, cert) in enumerate(page_contents['foot_fragments']):
                foot_text.append(text)

            ## Figure out body's paragraphs, seprate where sensible
            body_text = [] 
            temp_par  = []
            prev_topy, prev_boty, prev_boxheight, prev_text = 0,0, 0, ''
            def flush_par():
                global temp_par, body_text
                if len(temp_par)>0:
                    body_text.append( ' '.join(temp_par) )
                    temp_par=[] 


            for body_frag_i, (bbox, text, cert) in enumerate(page_contents['body_fragments']):
                topleft, topright, botright, botleft = bbox
                topy, boty = topleft[1], botright[1]
                boxheight = bbox_height(bbox) # is a good indicator of font size

                same_line            = (boty - prev_boty) < 0.6*boxheight
                current_line_shorter = len(text) < 0.5 * len(prev_text) 
                prev_line_shorter    = 0.5 * len(prev_text) < len(text)

                #if topy-prev_boty > -5:
                #    print( "                                                   [ydist %d (%s->%s)]"%(topy-prev_boty, prev_boty, topy) )

                #if topy < prev_boty by roughly boxheight it's the same line

                if topy < prev_boty-200:
                    if verbose:
                        print( "LARGE DECREASE IN Y HUH?")
                        print( '      %12s %-12s  fs:%-5s  %s '%( topleft, botright, boxheight, text ) )
                    #continue
                    break
                    
                if prev_boty!=0  and  topy-prev_boty > median_boxheight: 
                    if verbose:
                        print( "                                                   [YSEP %d (%s->%s)]"%(topy-prev_boty, prev_boty, topy) )
                    flush_par()

                elif prev_boty!=0  and  topy-prev_boty > 0.6*median_boxheight: 
                    if verbose:
                        print( "                                                   [YSEP %d (%s->%s)]"%(topy-prev_boty, prev_boty, topy) )
                    flush_par()

                elif (boxheight > 1.25 * prev_boxheight)  and  current_line_shorter  and  not same_line:  # larger text, and shorter
                    # A large title of a new section is generally  caught by YSEP, actually
                    #print( 'size diff;   line diff?  botdiff is %d,  relative to 0.5*boxheight=%d'%( (boty-prev_boty),  0.5*boxheight ) )

                    if verbose:
                        print( "                                                   [LARGER_TEXT %s->%s]"%(prev_boxheight, boxheight) )
                    flush_par()

                elif boxheight < 0.8 * prev_boxheight  and  prev_line_shorter  and not same_line: # font smaller than the previous line, and the previous line was shorter
                    if verbose:
                        print( "                                                   [SMALLER_TEXT %s->%s]"%(prev_boxheight, boxheight) )
                    flush_par()

                temp_par.append( text )

                if verbose:
                    print( '      %12s %-12s  fs:%-5s  %s '%( topleft, botright, boxheight, text ) )

                prev_topy, prev_boty, prev_boxheight, prev_text = topy, boty,  boxheight, text

            flush_par()

            del page_contents['body_fragments']
            del page_contents['head_fragments']
            del page_contents['foot_fragments']
            del page_contents['misc_fragments']

            page_contents['head_text'] = head_text
            page_contents['body_text'] = body_text
            page_contents['foot_text'] = foot_text

            doc_pages.append( page_contents )

            #print( 'body_text' )
            #pprint.pprint( page_contents['body_text'] )
            #for par in page_contents['body_text']:
            #    for line in textwrap.wrap(par):
            #        print( '[%s]'%line )
            #    print()

        case_docs.append( 
            {
                'url':pdf_url, 
                'pages':doc_pages,
                'header_dates':doc_dates,
                'status':pdf_dict.get('status'),
            }
        )

        # summarize document
        #pprint.pprint( doc_contents )

        if 0:
            for page in doc_pages:
                for temp_par in page['body_text']:
                    for line in textwrap.wrap(temp_par):
                        print( '%s'%line )
                    print()



    date_range = ()
    if len(case_doc_dates)>0:
        date_range = (
            wetsuite.helpers.date.format_date( min(case_doc_dates) ), 
            wetsuite.helpers.date.format_date( max(case_doc_dates) )
        )

    dataset_cases.append( { 
                'name': case_name,
                'docs': case_docs,
        'date_range': date_range,

        # CONSIDER: maybe just start with case_dict so we don't have to manually do:
                'money': case_dict['money'],
                'ecli': case_dict['ecli'],
    'case_detail_url': case_dict['case_detail_url'],
    } )

print( len(dataset_cases) )
# Out:
# CASE 0: NetX Betting
#   DOC 0:  besluit_lod_1a_netx_betting_limited_ov_.pdf
#   DOC 1:  besluit_openbaarmaking_ov_.pdf
# CASE 1: Bingoal Nederland B.V.
#   DOC 0:  01-288-556_15404_sanctiebesluit_bingoal.pdf
#   DOC 1:  15404_bingoal_openbaarmakingsbesluit_002_.pdf
# CASE 2: Vriendenloterij N.V.
#   DOC 0:  20230523_01-291-294_openbaar_besluit_last_onder_dwangsom_vl_spellen.pdf
#   DOC 1:  20230523_01-291-296_openbare_versie_openbaarmakingsbesluit_woo_vl_last.pdf
# CASE 3: Nationale Postcode Loterij N.V.
#   DOC 0:  20230523_01-291-288_openbaar_besluit_last_onder_dwangsom_npl_spellen.pdf
#   DOC 1:  20230523_01-291-290_openbare_versie_openbaarmakingsbesluit_woo_npl_last.pdf
# CASE 4: GoldWin Ltd
#   DOC 0:  20230420_01-291-425_besluit_lod_goldwin_ltd_ov_.pdf
#   DOC 1:  20230420_01-191-426_besluit_openbaarmaking_ov_.pdf
# CASE 5: Merkur Casino Almere B.V.
#   DOC 0:  01-289-330_15484_sanctiebesluit_ov.pdf
#   DOC 1:  01-289-336_15484_openbaarmakingsbesluit_woo_ov.pdf
# CASE 6: Betent
#   DOC 0:  betent_15403_openbaarmakingsbesluit.pdf
# CASE 7: Winning Poker Network
#   DOC 0:  20230228_01-285-044_lod_openbare_versie_beveiligd.pdf
#   DOC 1:  20220228_01-287-832_besluit_openbaarmaking_openbare_versie_beveiligd.pdf
# CASE 8: Red Ridge Marketing
#   DOC 0:  01-286-861_15395_sanctiebesluit_ov.pdf
#   DOC 1:  15395_openbaarmakingsbesluit_ov.pdf
# CASE 9: Hillside New Media Malta Plc
#   DOC 0:  15402_01-285-941_besluit-signed_openbare_versie.pdf
#   DOC 1:  01-287-123_openbaarmakingsbesluit_woo_openbare_versie.pdf
# CASE 10: Probe Investments Limited
#   DOC 0:  15269_01-294-564_beslissing_op_bezwaar_ov.pdf
#   DOC 1:  15269_01-294-565_openbaarmakingsbesluit_woo_bob_ov.pdf
#   DOC 2:  15269_01-293-484_bac_advies_ov.pdf
#   DOC 3:  15269_01-281-231_sanctiebesluit_probe_investments_limited_ov.pdf
#   DOC 4:  15269_01-281-234_besluit_openbaarmaking_probe_investments_limited_ov.pdf
# CASE 11: Betpoint Group Limited
#   DOC 0:  ov_15164_01-281-226_sanctiebesluit_betpoint.pdf
#   DOC 1:  ov_15164_01-281-229_betpoint_openbaarmaking.pdf
# CASE 12: N1 Interactive Limited
#   DOC 0:  01-292-870-beslissing_op_bezwaar_15244_ov.pdf
#   DOC 1:  01-292-895_besluit_openbaarmaking_15244_ov.pdf
#   DOC 2:  15244_01-291-871_bac_advies_ov_1.pdf
#   DOC 3:  01-281-253_sanctiebesluit_15244_ov.pdf
#   DOC 4:  01-281-256_openbaarmakingbesluit_15244_ov.pdf
# CASE 13: Videoslots Limited
#   DOC 0:  15167_01-281-259_sanctiebesluit_videoslots_ov.pdf
#   DOC 1:  01-281-262_openbaarmakingsbesluit_videoslots_ov.pdf
# CASE 14: Fairload Limited
#   DOC 0:  15151_01-294-550_beslissing_op_bezwaar-ov.pdf
#   DOC 1:  15151_01-294-553-openbaarmakingsbesluit_woo_bob_ov.pdf
#   DOC 2:  15151_bac_advies_ov.pdf
#   DOC 3:  15151_ov_fairload_sanctiebesluit_def.pdf
#   DOC 4:  15151_01-281-217_ov_fairload_openbaarmaking.pdf
# CASE 15: Equinox Dynamic N.V. & Domiseda and Partners s.r.o.
#   DOC 0:  01-281-220_sanctiebesluit_2022_openbaar.pdf
#   DOC 1:  openbaarmakingsbesluit_equinox_dynamic_domiseda.pdf
#   DOC 2:  15255_01-293-635_beslissing_op_bezwaar_ov.pdf
#   DOC 3:  15255_01-293-637_bac_advies_def_ov.pdf
#   DOC 4:  01-293-636_openbaarmakingsbesluit_woo_bob_15255_ov.pdf
# CASE 16: Bingoal Nederland B.V.
#   DOC 0:  sanctiebesluit_bingoal_8_febrauri_2023.pdf
#   DOC 1:  openbaarmakingsbesluit_bingoal_8_februari_2023.pdf
#   DOC 2:  01-289-608_advies_bac_bingoal_nederland_b-v_ov.pdf
#   DOC 3:  01-289-607_openbaarmakingsbesluit_ov.pdf
# CASE 17: JOI Gaming Ltd
#   DOC 0:  sanctiebesluit_joi_gaming_ltd_10_januari_2023_.pdf
#   DOC 1:  openbaarmakingsbesluit_joi_gaming_ltd.pdf
# CASE 18: Shark77.Ltd
#   DOC 0:  beslissing_op_bezwaar_ov.pdf
#   DOC 1:  openbaarmakingsbesluit_woo_bob_ov.pdf
#   DOC 2:  advies_bac_shark77_ov.pdf
#   DOC 3:  sanctiebesluit_shark77.pdf
#   DOC 4:  openbaarmakingsbesluit_shark77.pdf
# CASE 19: Holland Casino N.V.
#   DOC 0:  01_252_792_lod_hc.pdf
#   DOC 1:  01_252_795_openbaarmakingsbesluit.pdf
#   DOC 2:  01_263_938_bob_lod_hc.pdf
#   DOC 3:  01_263_939_besluit_openbaarmaking_beslissing_op_bezwaar_holland_casino_n_v.pdf
#   DOC 4:  01_264_668_invorderingsbeschikking_lod_hc.pdf
#   DOC 5:  01_268_588_besluit_tot_openbaarmaking_holland_casino_n_v.pdf
# CASE 20: Toto Online B.V.
# CASE 21: Nationale Postcode Loterij N.V.
#   DOC 0:  sanctiebesluit_npl.pdf
#   DOC 1:  openbaarmakingsbesluit_npl.pdf
# CASE 22: M.K.C Limited
#   DOC 0:  20220823_01_265_505_-_besluit_last_onder_dwangsom_ov.pdf
#   DOC 1:  20220823_01_265_507_-_besluit_openbaarmaking_ov.pdf
# CASE 23: L.C.S Limited
#   DOC 0:  20220817_01_265_500_-_besluit_lod_sons-of-slots_ov.pdf
#   DOC 1:  20220817_01_265_499_-_besluit_openbaarmaking_ov.pdf
# CASE 24: Gammix Limited
#   DOC 0:  20230216_01-285-641_invorderingsbesluit_gammix.pdf
#   DOC 1:  20230216_01-285-642_besluit_openbaarmaking_gammix.pdf
#   DOC 2:  20220707_01_270_078_-_lod_gammix_ov.pdf
#   DOC 3:  20220707_01_270_081_-_besluit_openbaarmaking_gammix_ov.pdf
# CASE 25: Red Ridge Marketing
#   DOC 0:  20220412_01_263_969_besluit_lod_ov_1.pdf
#   DOC 1:  20220412_01_263_968_besluit_openbaarmaking_wob_ov_1.pdf
#   DOC 2:  20230323_01-288-427_invorderingsbesluit_ov.pdf
#   DOC 3:  20230324_01-288-428_besluit_openbaarmaking_woo_invordering_ov.pdf
# CASE 26: Performing Media Limited
#   DOC 0:  last_onder_dwangsom_performing_media_limited.pdf
#   DOC 1:  besluit_tot_openbaarmaking_performing_media_limited.pdf
# CASE 27: Linkerik B.V.
#   DOC 0:  besluit_last_onder_dwangsom_14508.pdf
#   DOC 1:  besluit_openbaarmaking_14508.pdf
#   DOC 2:  invorderingsbesluit_linkerik_b-v_ov_.pdf
#   DOC 3:  besluit_openbaarmaking_linkerik_b-v-ov_.pdf
# CASE 28: Onlinecasinobonus.nl
#   DOC 0:  last_onder_dwangsom_onlinecasinobonus_nl.pdf
#   DOC 1:  besluit_openbaarmaking_onlinecasinobonus_nl.pdf
# CASE 29: LCB CORP
#   DOC 0:  lcb_corp_lod_20211213_01_252_632_lod_nl_lcb_org_ov.pdf
#   DOC 1:  lcb_corp_besluit_openbaarmaking_20211213_01_252_633.pdf
# CASE 30: Casinoscout.nl
#   DOC 0:  casinoscout_nl_besluit_openbaarmaking_ov.pdf
#   DOC 1:  casinoscout_nl_lod.pdf
# CASE 31: Online Casino Ground ltd
#   DOC 0:  last_onder_dwangsom_online_casino_ground_ltd.pdf
#   DOC 1:  besluit_openbaarmaking_online_casino_ground_ltd.pdf
# CASE 32: Slots Dev
#   DOC 0:  last_onder_dwangsom_slots_dev.pdf
#   DOC 1:  besluit_openbaarmaking_slots_dev.pdf
# CASE 33: Tipico Co. Ltd
#   DOC 0:  besluit_tipico_openbaar.pdf
#   DOC 1:  openbaarmakingsbesluit_tipico_openbaar.pdf
# CASE 34: BSB Shop
#   DOC 0:  besluit_last_onder_dwangsom_bsb_shop.pdf
#   DOC 1:  besluit_openbaarmaking_bsb_shop.pdf
# CASE 35: Luxury Bingo
#   DOC 0:  besluit_lxury_bingo.pdf
#   DOC 1:  besluit_openbaarmaking_luxery_bingo.pdf
# CASE 36: N1 Interactive Limited
#   DOC 0:  beslissing_op_bezwaar_n1_interactive_ltd.pdf
#   DOC 1:  besluit_openbaarmaking_n1_interactive_ltd.pdf
#   DOC 2:  bac_advies_n1_interactive_ltd.pdf
#   DOC 3:  besluit_n1_interactive_limited_ov.pdf
#   DOC 4:  openbaarmakingsbesluit_interactive_limited.pdf
# CASE 37: Staatsloterij B.V.
#   DOC 0:  20220118_-_01_256_290_intrekkingsbesluit.pdf
#   DOC 1:  20220224_-_01_258_184_openbaarmakingsbesluit_intrekkingsbesluit.pdf
#   DOC 2:  sanctiebesluit_staatsloterij.pdf
#   DOC 3:  besluit_tot_openbaarmaking_staatsloterij.pdf
# CASE 38: Raging Rhino N.V.
#   DOC 0:  sanctiebesluit_raging_rhino_n_v.pdf
#   DOC 1:  besluit_tot_openbaarmaking_raging_rhino_n_v.pdf
# CASE 39: Lovelto Mar LTD
#   DOC 0:  01_237_092_-_invorderingsbeschikking_ov.pdf
#   DOC 1:  01_237_093_-_besluit_openb_invorderingsbeschikking_ov.pdf
#   DOC 2:  lod_ov.pdf
#   DOC 3:  01_077_647_-_besluit_openbaarmaking_-_ov_1.pdf
# CASE 40: 1X Corp N.V._Exinvest Limited
#   DOC 0:  12924_advies_bac_ov.pdf
#   DOC 1:  12924_besluit_openbaarmaking_bob_ov.pdf
#   DOC 2:  12924_-_01_047_552_sanctiebesluit_-_openbare_versie_met_logo_1.pdf
#   DOC 3:  12924_-_01_047_553_openbaarmakingsbesluit_-_openbare_versie_met_logo_1.pdf
# CASE 41: WL Deal
#   DOC 0:  01_079_482_besluit_lod_wl_deal_openbaar.pdf
#   DOC 1:  01_079_484_besluit_openbaarmaking_lod_wl_deal_openbaar.pdf
# CASE 42: Virtual Coin Gaming N.V.
#   DOC 0:  besluit_op_bezwaar_virtual_coin_gaming.pdf
#   DOC 1:  advies_van_de_adviescommissie_bezwaarschriften.pdf
#   DOC 2:  besluit_openbaarmaking_virtual_coin_gaming.pdf
#   DOC 3:  besluit_openbaarmaking_betalingsweigering_virtual_coin_gaming_n_v.pdf
#   DOC 4:  sanctiebesluit_futgalaxy_openbaar.pdf
#   DOC 5:  besluit_openbaarmaking_futgalaxy_openbaar.pdf
# CASE 43: Clipboard Publications B.V.
#   DOC 0:  20200806_01_073_790_lod_bevorderen_ov.pdf
#   DOC 1:  20200806_01_073_815_besluit_openbaarmaking_ov_1.pdf
# CASE 44: Kelner Automaten Service
# CASE 45: Schinveld BV
#   DOC 0:  beslissing_op_bezwaar.pdf
#   DOC 1:  advies_bac.pdf
#   DOC 2:  besluit_openbaarmaking_schinveld_bv.pdf
#   DOC 3:  sanctiebesluit_schinveld_bv.pdf
#   DOC 4:  openbaarmakingsbesluit_schinveld_bv.pdf
# CASE 46: Voormalig exploitant Dordrecht
#   DOC 0:  01_066_052_besluit_lob_openbaar.pdf
#   DOC 1:  01_066_053_besluit_openbaarmaking_lob_openbaar.pdf
# CASE 47: Voormalig exploitant Amersfoort
#   DOC 0:  01_062_613_besluit_lob_openbaar.pdf
#   DOC 1:  01_062_614_besluit_openbaarmaking_lob_openbaar.pdf
# CASE 48: Royal Panda Limited
#   DOC 0:  13384_002_beslissing_op_bezwaar_ov.pdf
#   DOC 1:  13384_002_bac_advies_ov.pdf
#   DOC 2:  13384_002_besluit_openbaarmaking_ov.pdf
#   DOC 3:  sanctiebesluit_rp_openbaar_1.pdf
#   DOC 4:  openbaarmakingsbesluit_rp.pdf
# CASE 49: LeoVegas Gaming
#   DOC 0:  13385_002_beslissing_op_bezwaar_ov_002.pdf
#   DOC 1:  13385_002_bac_advies_ov_002_2.pdf
#   DOC 2:  sanctiebesluit_lv_openbaar_002.pdf
#   DOC 3:  openbaarmaking_lv_openbaar.pdf
# CASE 50: Pokerstars
#   DOC 0:  13366_-_bob_-_pokerstars_ov.pdf
#   DOC 1:  13366_bac-advies_pokerstars_ov.pdf
#   DOC 2:  13366_-_besluit_openbaarmaking_bob_-_pokerstars_ov.pdf
#   DOC 3:  besluit_pokerstars.pdf
#   DOC 4:  openbaarmakingsbesluit_pokerstars.pdf
# CASE 51: Chance Publications Malta Ltd
#   DOC 0:  invorderingsbeschikking.pdf
#   DOC 1:  01_061_945_last_onder_dwangsom_openbare_versie.pdf
#   DOC 2:  01_061_946_besluit_openbaarmaking_lod_openbare_versie.pdf
# CASE 52: Unibet
#   DOC 0:  13365_sanctie_besluit_ov.pdf
#   DOC 1:  13365_openbaarmakingsbesluit_ov.pdf
# CASE 53: Bwin
#   DOC 0:  13367_001_01_067_148_openbare_versie_beslissing_op_bezwaar.pdf
#   DOC 1:  13367_001_01_064_921_bac-advies-_openbaar.pdf
#   DOC 2:  13367_002_01_067_145_besluit_openbaarmaking_bob-_openbaar.pdf
#   DOC 3:  13367_-_sanctiebesluit_bwin_openbare_versie.pdf
#   DOC 4:  13367_-_besluit_openbaarmaking_bwin_openbare_versie.pdf
# CASE 54: Simbat Entertainment Systems en Spinity
#   DOC 0:  besluit_openbaarmaking_betalingsweigering_simbat_openbaar.pdf
#   DOC 1:  besluit_openbaarmaking_betalingsweigering_spinity.pdf
#   DOC 2:  03_10474_besluit_op_bezwaar_openbare_versie_1.pdf
#   DOC 3:  07_10474_openbaarmaking_bob_openbare_versie.pdf
#   DOC 4:  01_10474_sanctiebesluit_openbare_versie_1.pdf
#   DOC 5:  02_10474_-_openbaarmakingsbesluit_openbare_versie.pdf
# CASE 55: Com Coin Operated Machines
#   DOC 0:  besluit_last_onder_dwangsom.pdf
#   DOC 1:  besluit_openbaarmaking_lod.pdf
# CASE 56: Casumo
#   DOC 0:  13078_besluit_op_bezwaar_ov.pdf
#   DOC 1:  13078_-_advies_bac_casumo_ov.pdf
#   DOC 2:  13078_bombob_ov.pdf
#   DOC 3:  13878_-_sanctiebesluit.pdf
#   DOC 4:  13078_-_openbaarmakingsbesluit.pdf
# CASE 57: Innovation Labs en Gaming Innovation Group
#   DOC 0:  openbaar_-_last_onder_dwangsom_ill.pdf
#   DOC 1:  openbaar_-_last_onder_dwangsom_gig.pdf
#   DOC 2:  openbaar_-_besluit_openbaarmaking_last_onder_dwangsom_ill.pdf
#   DOC 3:  openbaar_-_besluit_openbaarmaking_last_onder_dwangsom_gig.pdf
#   DOC 4:  openbaar_-_beslissing_op_bezwaar_ill_en_gig.pdf
#   DOC 5:  openbaar_-_besluit_tot_openbaarmaking_van_de_beslissing_op_bezwaar_ill_en_gig.pdf
# CASE 58: Content Publishing Limited
#   DOC 0:  uitspraak_rechtbank_den_haag_van_10_januari_2019.pdf
#   DOC 1:  primair_besluit_tot_oplegging_last_onder_dwangsom_1.pdf
#   DOC 2:  openbaarmakingsbesluit_van_het_primaire_besluit.pdf
#   DOC 3:  besluit_op_het_bezwaar_tegen_de_last_onder_dwangsom.pdf
#   DOC 4:  openbaarmakingsbesluit_van_de_beslissing_op_bezwaar.pdf
# CASE 59: Exploiteren zonder vergunning in café
#   DOC 0:  besluit_01_047_464.pdf
#   DOC 1:  besluit_tot_openbaarmaking_13052.pdf
#   DOC 2:  01_037_509_besluit_last_onder_bestuursdwang.pdf
#   DOC 3:  01_037_510_besluit_openbaarmaking.pdf
# CASE 60: WHG (International) Limited
#   DOC 0:  12920_besluit_openbaarmaking_openbaar.pdf
#   DOC 1:  12920_bac_advies_whg_openbaar.pdf
#   DOC 2:  12920_bac_advies_whg_openbaar.pdf
#   DOC 3:  sanctiebesluit_whg.pdf
#   DOC 4:  openbaarmakingsbesluit_whg.pdf
# CASE 61: Voormalig exploitant Abcoude
#   DOC 0:  01_044_953_besluit_last_onder_bestuursdwang_openbaar.pdf
#   DOC 1:  01_044_954_besluit_openbaarmaking_lob_openbaar.pdf
# CASE 62: CyberRock Entertainment N.V. en Honeydew Trading Limited.
#   DOC 0:  besluit_openbaarmaking_betalingsweigering_cyberrock_honeydew_ov.pdf
#   DOC 1:  12863_beslissing_op_bezwaar_cyberrock.pdf
#   DOC 2:  12863_advies_van_de_commissie.pdf
#   DOC 3:  13324_besluit_tot_openbaarmaking_bob_cyber_rock.pdf
#   DOC 4:  12863_-_sanctiebesluit_docx.pdf
#   DOC 5:  12863_besluit_tot_openbaarmaking.pdf
# CASE 63: Mr Green Limited
#   DOC 0:  beslissing_op_bezwaar_mr_green_1.pdf
#   DOC 1:  besluit_openbaarmaking_beslissing_op_bezwaar.pdf
#   DOC 2:  sanctiebesluit_mr_green.pdf
#   DOC 3:  besluit_tot_openbaarmaking_mr_green.pdf
# CASE 64: ITC Lounge Plaza
#   DOC 0:  sanctiebesluit_itc_lounge_plaza.pdf
#   DOC 1:  besluit_tot_openbaarmaking_itc_lounge_plaza.pdf
# CASE 65: Corona Limited
#   DOC 0:  beslissing_op_bezwaar_corona.pdf
#   DOC 1:  besluit_openbaarmaking_bob_corona.pdf
#   DOC 2:  12517_-_sanctiebesluit_ov_def_def.pdf
#   DOC 3:  12517_-_openbaarmakingsbesluit_ov.pdf
# CASE 66: Café restaurant De Kruik
#   DOC 0:  last_onder_dwangsom_cafe_restaurant_de_kruik.pdf
#   DOC 1:  besluit_openbaarmaking_cafe_restaurant_de_kruik.pdf
# CASE 67: Bet-at-home
#   DOC 0:  20190103-01_048_080_besluit_op_bezwaar.pdf
#   DOC 1:  20190103-01_048_077_besluit_tot_openbaarmaking.pdf
#   DOC 2:  sanctiebesluit_bet-at-home.pdf
#   DOC 3:  besluit_tot_openbaarmaking_bet-at-home.pdf
# CASE 68: Visionairy iGaming
#   DOC 0:  openbaarmakingsbesluit_v_i_g_openbaar.pdf
#   DOC 1:  openbaarmakingsbesluit_bestuurder_openbaar.pdf
#   DOC 2:  sanctiebesluit_visionairy_igaming.pdf
#   DOC 3:  besluit_tot_openbaarmaking_visionairy_igaming.pdf
# CASE 69: VriendenLoterij N.V.
#   DOC 0:  besluit_intrekken_lod_2.pdf
#   DOC 1:  besluit_openbaarmaking_intrekking_lod_2.pdf
#   DOC 2:  besluit_op_bezwaar_last_onder_dwangsom_npl_bgl_en_vl.pdf
#   DOC 3:  besluit_tot_openbaarmaking_bob_npl_bgl_en_vd.pdf
#   DOC 4:  last_onder_dwangsom_vriendenloterij_n_v.pdf
#   DOC 5:  openbaarmaking_last_onder_dwangsom_vriendenloterij_n_v.pdf
#   DOC 6:  besluit_last_onder_dwangsom_gdl.pdf
#   DOC 7:  besluit_openbaarmaking_last_onder_dwangsom_gdl.pdf
# CASE 70: BankGiro Loterij N.V.
#   DOC 0:  besluit_intrekken_lod_1.pdf
#   DOC 1:  besluit_openbaarmaking_intrekking_lod_1.pdf
#   DOC 2:  besluit_op_bezwaar_last_onder_dwangsom_npl_bgl_en_vl.pdf
#   DOC 3:  besluit_tot_openbaarmaking_bob_npl_bgl_en_vd.pdf
#   DOC 4:  last_onder_dwangsom_bankgiro_loterij_n_v.pdf
#   DOC 5:  openbaarmaking_last_onder_dwangsom_bankgiro_loterij_n_v.pdf
#   DOC 6:  besluit_last_onder_dwangsom_gdl.pdf
#   DOC 7:  besluit_openbaarmaking_last_onder_dwangsom_gdl.pdf
# CASE 71: Nationale Postcode Loterij N.V.
#   DOC 0:  besluit_intrekken_lod.pdf
#   DOC 1:  besluit_openbaarmaking_intrekking_lod.pdf
#   DOC 2:  190520-01_056_018-01_057_548_invorderingsbeschikking_-_npl_-_openbaar.pdf
#   DOC 3:  190520-01_056_019-01_057_549_besluit_openbaarmaking_invorderingsbeschikking_-_npl_-_openbaar.pdf
#   DOC 4:  besluit_op_bezwaar_last_onder_dwangsom_npl_bgl_en_vl.pdf
#   DOC 5:  besluit_tot_openbaarmaking_bob_npl_bgl_en_vd.pdf
#   DOC 6:  last_onder_dwangsom_nationale_postcode_loterij_n_v.pdf
#   DOC 7:  openbaarmaking_last_onder_dwangsom_nationale_postcode_loterij_n_v.pdf
#   DOC 8:  besluit_last_onder_dwangsom_gdl.pdf
#   DOC 9:  besluit_openbaarmaking_last_onder_dwangsom_gdl.pdf
# CASE 72: Lotto B.V.
#   DOC 0:  20220901_-_01_272_228_openbare_versie_besluit_opheffen_last_lotto.pdf
#   DOC 1:  20220901_-_01_273_365_besluit_tot_openbaarmaking_opheffing_lod_van_19-10-2017.pdf
#   DOC 2:  20211025_-_01_249_821_openbare_versie_invorderingsbeschikking_toto_def_002.pdf
#   DOC 3:  openbaarmakingsbesluit_lotto_11.pdf
#   DOC 4:  invorderingsbeschikking_lotto.pdf
#   DOC 5:  openbaarmakingsbesluit_lotto.pdf
#   DOC 6:  01_047_588_-_01_046_119_invorderingsbeschikking_-_lotto_-_def_openbaar_002.pdf
#   DOC 7:  01_047_589_besluit_openbaarmaking_invorderingsbeschikking_-_lotto_-_def_openbaar_002.pdf
#   DOC 8:  besluit_op_bezwaar_last_onder_dwansom_staatsloterij_en_lotto.pdf
#   DOC 9:  besluit_tot_openbaarmaking_bob_staatloterij_en_lotto.pdf
#   DOC 10:  last_onder_dwangsom_lotto_b_v.pdf
#   DOC 11:  openbaarmaking_last_onder_dwangsom_lotto_b_v.pdf
# CASE 73: Staatsloterij B.V.
#   DOC 0:  20220114_-_01_255_681_openbare_versie_besluit_opheffen_last_staatsloterij.pdf
#   DOC 1:  20220114_-_01_255_680_openbaarmakingsbesluit_staatsloterij.pdf
#   DOC 2:  01_047_590_-_01_046_120_invorderingsbeschikking_-_staatsloterij_-_def_openbaar.pdf
#   DOC 3:  01_049_931_besluit_openbaarmaking_invorderingsbeschikking_-_staatsloterij_-_def_openbaar.pdf
#   DOC 4:  besluit_op_bezwaar_last_onder_dwansom_staatsloterij_en_lotto.pdf
#   DOC 5:  besluit_tot_openbaarmaking_bob_staatloterij_en_lotto.pdf
#   DOC 6:  last_onder_dwangsom_staatsloterij_b_v.pdf
#   DOC 7:  openbaarmaking_last_onder_dwangsom_staatsloterij_b_v.pdf
# CASE 74: Holland Casino N.V.
#   DOC 0:  20220114_-_01_255_682_openbare_versie_besluit_tot_opheffen_last_holland_casino.pdf
#   DOC 1:  20220114_-_01_255_677_openbaarmakingsbesluit_hc.pdf
#   DOC 2:  last_onder_dwangsom_holland_casino.pdf
#   DOC 3:  openbaarmaking_last_onder_dwangsom_holland_casino.pdf
# CASE 75: Catena Operations Limited
#   DOC 0:  besluit_last_onder_dwangsom_catena_operations_limited.pdf
#   DOC 1:  besluit_openbaarmaking_last_onder_dwangsom_catena_operations_limited.pdf
# CASE 76: Weddenopvoetbal.org
#   DOC 0:  10762_-_01_022_342_en_10868_-_01_022_343_besluit_op_bezwaar_openbaar.pdf
#   DOC 1:  10762_-_01_022_344_en_10868_-_01_022_345_besluit_tot_openbaarmaking_openbaar.pdf
#   DOC 2:  besluit_tot_openbaarmaking_besluit_op_bezwaar_weddenopvoetbal_org.pdf
#   DOC 3:  besluit_last_onder_dwangsom_weddenopvoetbal_org.pdf
# CASE 77: JvG speelautomaten
#   DOC 0:  besluit_last_onder_dwangsom_jvg_amusement_vending_b_v.pdf
#   DOC 1:  openbaarmakingsbesluit_jvg_amusement_bending_b_v.pdf
# CASE 78: Trustfulgames.com Limited
#   DOC 0:  besluit_openbaarmaking_betalingsweigering_trustfulgames.pdf
#   DOC 1:  besluit_openbaarmaking_betalingsweigering_bestuurder_1.pdf
#   DOC 2:  besluit_openbaarmaking_betalingsweigering_bestuurder_2.pdf
#   DOC 3:  10507_-_sanctiebesluit_adviescommissie_003.pdf
#   DOC 4:  10507_-_besluit_tot_openbaarmaking_003.pdf
#   DOC 5:  sanctiebesluit_trustfulgames.pdf
#   DOC 6:  besluit_tot_openbaarmaking_trustfulgames.pdf
# CASE 79: L.S.A. B.V
#   DOC 0:  ecli_nl_rvs_2019_11_uitspraak_inzake_lob_lsa_bv.pdf
#   DOC 1:  besluit_tot_openbaarmaking.pdf
#   DOC 2:  besluit_last_onder_bestuursdwang_02112016_geanonimiseerd.pdf
#   DOC 3:  besluit_openbaarmaking_-_openbare_versie_op_briefpapier.pdf
# CASE 80: M-automaten exploitatie
#   DOC 0:  00_082_720_openbare_versie_last_onder_bestuursdwang.pdf
#   DOC 1:  00_082_721_openbare_versie_besluit_tot_opehbaarmaking.pdf
# CASE 81: Wedwinkel Rotterdam
#   DOC 0:  sanctiebesluit_wedwinkel.pdf
#   DOC 1:  openbaarmakingsbesluit_wedwinkel.pdf
# CASE 82: Friese ondernemer
#   DOC 0:  besluit_last_onder_bestuursdwang.pdf
# CASE 83: Holland Gaming
#   DOC 0:  besluit_op_bezwaar_holland_gaming.pdf
#   DOC 1:  besluit_tot_openbaarmaking_holland_gaming.pdf
# CASE 84: Olders Amusementsautomaten B.V.
#   DOC 0:  besluit_last_bestuursdwang_-_olders_amusementsautomaten_bv_-_geanonimiseerde_versie_voor_publicatie.pdf
# CASE 85: Duitse loterijen
#   DOC 0:  10072_-_00_071_137_en_10136_-_00_071_138_besluit_openbaar.pdf
#   DOC 1:  10072_-_00_071_140_en_10136_-_00_071_141_besluit_openbaarmaking_openbaar.pdf
# CASE 86: Dolle Pret in Almelo B.V.
#   DOC 0:  last_onder_dwangsom_dolle_pret_in_almelo.pdf
#   DOC 1:  besluit_tot_openbaarmaking_dolle_pret_in_almelo.pdf
# CASE 87: Redslots
#   DOC 0:  besluit_openbaarmaking_betalingsweigering_bluemay_enterprises_n_v_-_red.pdf
#   DOC 1:  besluit_tot_openbaarmaking_bob_redslots.pdf
#   DOC 2:  sanctiebesluit_redslots.pdf
#   DOC 3:  besluit_tot_openbaarmaking_redslots.pdf
# CASE 88: Café _ Bar Bağci
#   DOC 0:  besluit_op_bezwaar_cafe_-_bar_bagci.pdf
#   DOC 1:  besluit_tot_openbaarmaking_cafe_-_bar_bagci_2.pdf
#   DOC 2:  sanctiebesluit_cafe_-_bar_bagci.pdf
#   DOC 3:  besluit_tot_openbaarmaking_cafe_-_bar_bagci.pdf
# CASE 89: Total E Soft Limited en XKL Limited
#   DOC 0:  besluit_op_bezwaar_total_e_soft.pdf
#   DOC 1:  besluit_tot_openbaarmaking_total_e_soft.pdf
#   DOC 2:  sanctiebesluit_total_e_soft_limited_en_xkl_limited.pdf
#   DOC 3:  besluit_tot_openbaarmaking_total_e_soft_limited_en_xkl_limited.pdf
# CASE 90: Belhuis _ Internetcafé Ephesus
#   DOC 0:  sanctiebesluit_belhuis_-_internetcafe_ephesus.pdf
#   DOC 1:  besluit_tot_openbaarmaking_belhuis_-_internetcafe_ephesus.pdf
# CASE 91: V.O.F. AULON
#   DOC 0:  besluit_v_o_f_aulon.pdf
#   DOC 1:  besluit_tot_openbaarmaking_v_o_f_aulon.pdf
# CASE 92: V.O.F. Bosma Amusement
#   DOC 0:  besluit_v_o_f_bosma_amusement.pdf
#   DOC 1:  besluit_tot_openbaarmaking_v_o_f_bosma_amusement.pdf
# CASE 93: Stichting Sport Twente
#   DOC 0:  sanctiebesluit_stichting_sport_twente.pdf
#   DOC 1:  besluit_tot_openbaarmaking_stichting_sport_twente.pdf
#   DOC 2:  besluit_op_bezwaar_stichting_sport_twente.pdf
#   DOC 3:  besluit_tot_openbaarmaking_stichting_sport_twente_2.pdf
# CASE 94: Thee- en koffiehuis Kayseri
#   DOC 0:  besluit_op_bezwaar_kayseri.pdf
#   DOC 1:  besluit_tot_openbaarmaking_kayseri.pdf
#   DOC 2:  sanctiebesluit_thee-_en_koffiehuis_kayseri.pdf
#   DOC 3:  besluit_tot_openbaarmaking_thee-_en_koffiehuis_kayseri.pdf
# CASE 95: Eetcafé De Gouw
#   DOC 0:  besluit_op_bezwaar_eetcafe_de_gouw.pdf
#   DOC 1:  besluit_openbaarmaking_eetcafe_de_gouw.pdf
#   DOC 2:  sanctiebesluit_eetcafe_de_gouw_1.pdf
#   DOC 3:  besluit_tot_openbaarmaking_eetcafe_de_gouw_1.pdf
# CASE 96: Co Gaming Limited (voorheen Come On Europe Limited)
#   DOC 0:  besluit_op_bezwaar_co_gaming_limited.pdf
#   DOC 1:  besluit_tot_openbaarmaking_co_gaming_limited.pdf
#   DOC 2:  1_sanctiebesluit_come_on.pdf
#   DOC 3:  besluit_tot_openbaarmaking_come_on.pdf
# CASE 97: Stichting Trefcentrum Brinkstraat
#   DOC 0:  besluit_op_bezwaar_stichting_trefcentrum_brinkstraat.pdf
#   DOC 1:  besluit_openbaarmaking_stichting_trefcentrum_brinkstraat.pdf
#   DOC 2:  sanctiebesluit_stichting_trefcentrum_brinkstraat.pdf
#   DOC 3:  besluit_tot_openbaarmaking_stichting_trefcentrum_brinkstraat.pdf
# CASE 98: Imperial E-club Limited
#   DOC 0:  besluit_op_bezwaar_imperial_e-club_limited.pdf
#   DOC 1:  besluit_tot_openbaarmaking_bob_imperial_e-club_limited.pdf
#   DOC 2:  sanctiebesluit_imperial_e-club_limited.pdf
#   DOC 3:  besluit_tot_openbaarmaking_imperial_e-club_limited.pdf
# CASE 99: Stichting Bil Kazan
#   DOC 0:  besluit_op_bezwaar_stichting_bil_kazan.pdf
#   DOC 1:  7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf
#   DOC 2:  sanctiebesluit_stichting_biil_kazan_1.pdf
#   DOC 3:  besluit_tot_openbaarmaking_stichting_bil_kazan_1.pdf
# CASE 100: 7Red.com
# CASE 101: Villa Mountain View
#   DOC 0:  besluit_op_bezwaar_villa_mountain_view.pdf
#   DOC 1:  besluit_tot_openbaarmaking_villa_mountain_view.pdf
#   DOC 2:  sanctiebesluit_villa_mountain_view.pdf
#   DOC 3:  besluit_openbaarmaking_villa_mountain_view.pdf
# CASE 102: GT Beheersorganisatie
#   DOC 0:  sanctiebesluit_gt_beheersorganisatie.pdf
#   DOC 1:  besluit_tot_openbaarmaking_gt_beheersorganisatie.pdf
# CASE 103: Koffiehuis Vadi
#   DOC 0:  sanctiebesluit_koffiehuis_vadi_-_openbaar.pdf
#   DOC 1:  besluit_tot_openbaarmaking_koffiehuis_vadi_-_openbaar.pdf
# CASE 104: Gooische Bingo Show
#   DOC 0:  8090_-_00_023_231_sanctiebesluit_gooische_bingo_show.pdf
#   DOC 1:  8090_-_00_023_232_openbaarmakingsbesluit_gooische_bingo_show.pdf
# CASE 105: Globalstars
#   DOC 0:  7822_sanctiebesluit_globalstars.pdf
#   DOC 1:  7822_besluit_openbaarmaking_globalstars.pdf
#   DOC 2:  7822_-_00_019_152_besluit_op_bezwaar_inclusief_advies_bac_-_openbare_versie.pdf
#   DOC 3:  7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf
# CASE 106: Grand Café Randenbroek
#   DOC 0:  besluit_op_bezwaar_openbaar_cafe_randenbroek.pdf
#   DOC 1:  besluit_openbaarmaking_bob_openbaar_cafe_randenbroek.pdf
#   DOC 2:  7861_sanctiebesluit_grand_cafe_randenbroek.pdf
#   DOC 3:  7861_besluit_openbaarmaking_grand_cafe_randenbroek.pdf
# CASE 107: Onisac Limited en Mansion Online Casino Limited
#   DOC 0:  190625_besluit_openbaarmaking_bob_onisac_openbaar_003.pdf
#   DOC 1:  190704_bob_en_bac.pdf
#   DOC 2:  sanctiebesluit_onisac.pdf
#   DOC 3:  openbaarmakingsbesluit_sanctiebesluit_onisac.pdf
#   DOC 4:  7845_00_021_663_-_sanctiebesluit_openbaar.pdf
#   DOC 5:  7845_00_021_664-_openbaarmaking_openbaar.pdf
#   DOC 6:  7845_-_advies_bac_ov_pdf.pdf
#   DOC 7:  7845_-_beslissing_op_bezwaar_ov_pdf.pdf
#   DOC 8:  8051_-_besluit_openbaarmaking_bob_ov_pdf.pdf
# CASE 108: Café Lucky
#   DOC 0:  besluit_op_bezwaar_openbaar_cafe_lucky.pdf
#   DOC 1:  besluit_openbaarmaking_bob_openbaar_cafe_lucky.pdf
#   DOC 2:  7938_-_00_018_637_sanctiebesluit_openbare_versie.pdf
#   DOC 3:  7938_besluit_openbaarmaking_cafe_lucky.pdf
# CASE 109: Star SAT Electronica
#   DOC 0:  7971_-_00_019_052_sanctiebesluit_openbare_versie.pdf
#   DOC 1:  7971_besluit_openbaarmaking_star_sat_electronica.pdf
# CASE 110: Call Internet City
#   DOC 0:  besluit_op_bezwaar_openbaar_call_internet_city.pdf
#   DOC 1:  7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf
#   DOC 2:  7970_sanctiebesluit_call_internet_city.pdf
#   DOC 3:  7970_besluit_openbaarmaking_call_internet_city.pdf
# CASE 111: Huizenloterij
#   DOC 0:  7982_-_00_020_754_kennisgeving_als_bedoeld_in_art_5_50_lid_2_sub_a_awb_openbaar.pdf
#   DOC 1:  7982_-_00_020_755_besluit_tot_openbaarmaking_openbaar.pdf
#   DOC 2:  7982_-_00_026_508_en_8140_-_00_026_510_besluit_op_bezwaar_openbaar1.pdf
#   DOC 3:  7982_-_00_025_509_en_8140_-_00_026_511_besluit_openbaarmaking_bob_openbaar1.pdf
# 112

# %% [markdown]
# # Write out
#
# Now write that augmented structure into something we can call a dataset

# %%
with open('kansspelautoriteit_plain.json', 'wb') as f:
    dataset = {
        'description':'''This is a plaintext form of the set of documents you can find under https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/ as PDFs.

        Since almost half of those PDFs do not have a text stream, this data is entirely OCR'd,
        so expect some typical OCR errors.  The OCR quality seems fairly decent, and some effort was made to remove headers and footers,
        yet there are some leftovers  like _ instead of . and = instead of :


        The data is a fairly nested structure of python objects (or JSON, before it's parsed).
        - .data is a list of cases.

        - each case is a dict, with a 
            - 'name', 
            - 'docs' (a list) 
            - and some extracted information like mentioned money amounts, the apparent date span of the case

        - each document in that mentioned list is is a dict, with keys like
            - 'url' - to the PDF it came from
            - 'status' - from the detail page (if we could find it - not 100%) 
            - extracted informations like 'header_dates' (comes from PDF contents)
            - 'pages' (a list)

        - each page in that list is a dict, which has keys:
            - 'body_text' - a list, which containts text fragments that are _almost_ like paragraphs 
                except that text may continue between pages anyway - currently still up to you to detect - 
                plus the post-OCR processing isn't perfect.
            - 'foot_text' - generally just [ "Pagina 1 van 27" ]
            - 'head_text' - fragments like []"Kansspelautoriteit", "OPENBAAR"] but also the date and kenmerk lines


        (TODO: update this example)
        For example (body text edited for brevity), one case's dict, with one document:
            { # dict for a case
                'name': 'Toto Online B.V.',  # case's name
                'docs': [                    # list of PDF documents in this case
                    { # dict detailing first document in case
                        'url': 'https://kansspelautoriteit.nl/publish/library/32/01_278_071_15091_sanctiebesluit_toto_ov.pdf',
                        'pages': [
                            {  # first page's dict   (currently contains only body's text fragments; idea was to split off header contents)
                                'body_text':[  # first page's text fragments
                                    'Besluit van de raad van [more sentence]',
                                    'Zaak: 15091 Kenmerk: 15091 [more kenmerk]',
                                    'Besluit',
                                    'Inleiding',
                                    'De raad van bestuur van de Kansspelautoriteit [more paragraph]'
                                ]
                            },
                            { # second page's dict
                                'body_text': [   # second page text fragment
                                'heeft heeft ontvangen sinds hij daar [more paragraph]',
                                'De toezichthouders zijn naar aanleiding [more paragraph]'
                                ]
                            } 
                            # ...more pages
                        ], 
                    }, # end of document dict
                    # ...more documents
                ]
            }
        ''',
        'data':dataset_cases,
    }

    f.write( json.dumps( dataset ).encode('u8') )
