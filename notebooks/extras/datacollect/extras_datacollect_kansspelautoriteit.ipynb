# %% [markdown]
# <a href="https://colab.research.google.com/github/knobs-dials/wetsuite-dev/blob/main/notebooks/extras/datacollect/extras_datacollect_kansspelautoriteit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Purpose of this notebook
#
# Collect data from contents PDFs under https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/
#
# We are not aware of any API, so are currently collecting information based on scraping web pages.

# %% [markdown]
# NOTE: This is how a dataset was created. If you only care about how to _use_ that dataset, see [using_dataset_kansspelautoriteit.ipynb](../using_dataset_kansspelautoriteit.ipynb) instead.
#
# In the process we will give an example of extracting data from a website like that, reorganizing that data and, as it turns out, of applying OCR.
#
# If you _do_ want to read this code, e.g. to get a start at doing your own OCR processing, read on...
# (note also that this code relies on poppler (for PDF parsing) and easyOCR (for OCR), neither of which are quite trivial installs)

# %% [markdown]
# ### Preparation
# imports we will use, and some helper functions.

# %%
#imports
import hashlib, urllib, json, json, pprint, textwrap, re, pprint, random

import bs4, numpy

import wetsuite.helpers.localdata
import wetsuite.helpers.meta
import wetsuite.helpers.net
import wetsuite.helpers.format
import wetsuite.helpers.strings
import wetsuite.helpers.date
import wetsuite.extras.pdf
import wetsuite.extras.ocr


# helpers we'll use later
def hash(data: bytes):
    ' calculate SHA1 hash of some data. '
    s1h = hashlib.sha1()
    s1h.update( data )
    return s1h.hexdigest()


def find_eur_money(s:str, minimum=0):
    ''' Given a string, returns a list of substrings that look like money amounts, e.g.
            find_eur_money('   EUR 10,-  ')       == ['10']
            find_eur_money('   EUR 10.    ')      == ['10']
            find_eur_money('   EUR100.000,-')     == ['100000']
            find_eur_money('   EUR100000  ')      == ['100000']
            find_eur_money('   \u20ac100.000')    == ['100000']   # but not commas, because Dutch uses that as a digit.  That should probably be configurable
            find_eur_money('   \u20ac 100000')    == ['100000']
            find_eur_money('   \u20ac 100000  ')  == ['100000']
    '''
    ret = []
    # the with-context was partially for debug, but might actually be useful to return
    for before, match_str, match_object, after in wetsuite.helpers.strings.findall_with_context(r"(?:EUR|\u20ac)\s*([0-9.]+)\b", s, 20):
        cap = match_object.groups()[0].replace('.','')
        try:
            if int(cap) < minimum:
                continue
        except ValueError as ve: # not parseable as number? Remove
            pass
        #print( '[%s]%s[%s] -> %r'%(before, match_str, after, cap) )
        ret.append(cap)
    return ret

# %% [markdown]
# ### Fetching the data

# %%
# Use a local store so that we only need to fetch the PDFs once, only render PDF pages once 
import wetsuite.helpers.localdata
pdfstore   = wetsuite.helpers.localdata.LocalKV('kansspel_pdfstore.db', key_type=str, value_type=bytes )     # URL -> PDF file bytestring
ocrstore   = wetsuite.helpers.localdata.LocalKV('kansspel_ocrstore.db', key_type=str, value_type=bytes )     # page-specific key -> json as bytes

# %% [markdown]
# #### Fetching case summaries
# Let's first scrape the webpage to figure out all cases, all documents that relate to each case
#
# This part isn't cached, because the details can change.

# %%
# The purpose of this section is to fill the following variable:
extracted_cases = []  # list of (casename, [list of document dicts], [same-sized list of ocr results])

maxpage  = 9999999  # will be set to the actual number of pages by the first (well, every) page we fetch
cur_page = 0        # zero-based counting in the pagination

print( "FETCHING CASE SUMMARIES" )
while cur_page <= maxpage:
    page_url = 'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=%d'%cur_page
    print( page_url )
                
    page_data = wetsuite.helpers.net.download(page_url)
    soup = bs4.BeautifulSoup( page_data, 'lxml' )

    # get the amount of pages, from the pagination links
    pagelinks = soup.select('a[class~="pager_step"][class~="pagina"]')   # CSS selector looking for both of those classes set in a whitespace-token list
    maxpage = int( pagelinks[-1].get('data-page') )                      # -1: last of those we see on the page

    print( "page %d of %d"%( cur_page+1, maxpage+1 ) ) # numbering is zero-based,  print out one-based for humans

    # fetch all links to specific case detail pages
    for detail_page_a in soup.select('#results a[class~="siteLink"]'): # pick out the links (URLs) of the detail page of each case
        detail_page_url = detail_page_a.get('href') # these are already absolute  (otherwise we'd have to urljoin them)
        case_name = detail_page_a.text.replace('/','_')
        case_dict = {
            'name':case_name,
            'date_range':[],
            'money':[],
            'ecli':[],
            'case_detail_url':detail_page_url,
        }

        print()
        print( '  Case: %r'%(case_name) )

        # Note: the date shown here and on the detail page may be the start date?   It may still useful to distinguish cases for repeat offenders




        ### fetch that case's detail page, and find all PDF links on it ##########################################################
        detail_page_data = wetsuite.helpers.net.download( detail_page_url )
        detail_soup = bs4.BeautifulSoup( detail_page_data, 'lxml' )

        # This section used to be three lines long, 
        #   until we decided that hey, maybe that status would be nice to have.
        #   then we discovered this is a free-form mess
        #   and this is the hand-crafted combination of of exception cases that will probably break in the future.


        #print( detail_page_url )
        
        ## Construct a list of dicts, one for each document,  with keys 'title', 'status', and 'pdf_url'
        doc_dicts = [] #  will be that list of dicts
        cur       = {} # 'currently collecting into this' dict 

        def check_add_clear():
            global doc_dicts, cur
            ''' if there's sensible content, we add it to our list of docs.
                clears cur for next document
            '''
            # if effectively empty, do nothing at all
            if len(cur.keys())==1  and  'title' in cur  and  cur['title']=='': # effectively empty. Also one of a handful of exception cases
                pass
            elif len(cur)>0: # effectively empty
                # fail if it's incomplete, so that I fix it   (or accept it as an edge case)
                if 'title' not in cur:
                    print('SKIP: scraping code is missing title, cur=%r'%cur)
                
                # temporarily removed, the case that triggers this is fixable
                elif 'pdf_url' not in cur:
                    print( 'SKIP: scraping code is missing pdf_url, cur=%r'%cur)
                
                #if 'status' not in cur:
                #    raise ValueError('scraping code is missing status, cur=%r'%cur) that happens, see e.g. https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/n1-interactive/ or https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/1x-corp-exinvest/
                
                #print("ADD %r"%cur)
                else:
                    doc_dicts.append(cur)
            cur = {}


        # this whole part used to be short, and readable(ish), but the pages are a bit messy so it ended up with a lot of exception cases.
        pdflinks = list( detail_soup.select('a[class~="importLink"][class~="pdf"]') )   # (now) used only to find the content block that contains these

        # (and things like select('div[class~="grid-blok"] div[class~="grid-element"] div[class~="grid-inside"] div[class~="iprox-content"]') is not specific enough, that's a general template
        if len(pdflinks)==0:
            print("WARNING - no content?")
        else:
            # We expect a sequence of one or more of: 
            # - h2              (title)
            # - p with a inside (link)
            # - h2-or-h3        (the header saubg "status")
            # - p               (the actual status text)            

            # ...but I've seen an initial paragraph in front of it. 
            # ...and a header and a paragraph in front of it.
            child = pdflinks[0].parent.previous_element # try to position on the first document's title header. Parent would be the p
            while child.name is None and child.previous_sibling is not None: # find previous non-text node.   ...there must be a better way of doing this.
                child = child.previous_sibling
            #print( 'Chosen starting spot: ', child )

            while child is not None:
                #print( child )
                if child.name: # filter out text nodes (iirc)
                    pdflinks = list( child.select('a[class~="importLink"][class~="pdf"]') )
                    has_pdflinks = len(pdflinks) > 0
                    alltext = (''.join(child.findAll(text=True))).strip().lower().strip(':')

                    # augmenting some things we find
                    case_dict['money'].extend( find_eur_money(alltext, minimum=5001) )
                    case_dict['ecli'].extend( wetsuite.helpers.meta.findall_ecli(alltext, rstrip_dot=True) )

                    #print( "LOOKING AT %r"% str(child).strip() )
                    if child.name in ('h2','h3'):
                        if has_pdflinks: # weird case in https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/vriendenloterij/
                            cur['pdf_url'] = urllib.parse.urljoin( detail_page_url, pdflinks[0].get('href') )   # make relative URLs absolute
                            if 'title' not in cur: # would be overwritten in almost all cases
                                cur['title'] = alltext # but helps deal with https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/1x-corp-exinvest/
                        else:
                            if alltext == 'status': # header that just says 'status'
                                #print('HEADER - "status"')
                                pass 
                            else: # probably a title
                                #print('HEADER - title?')
                                check_add_clear() # starts a new one, so:
                                cur['title'] = child.text
                    elif child.name == 'p':
                        if len(cur)==0: # dict empty?
                            pass # probably an initial paragraph
                        else:
                            if has_pdflinks: #elif 'pdf_url' not in cur:
                                #print('FIRST P - PDF URL')
                                cur['pdf_url'] = urllib.parse.urljoin( detail_page_url, pdflinks[0].get('href') )   # make relative URLs absolute
                            else: #elif 'pdf_url' in cur: # status text
                                #print('SECOND P - STATUS TEXT')
                                cur['status'] = child.text
                child = child.next_sibling
            check_add_clear()

    
            #
            #pprint.pprint( doc_dicts )
            print( '    # documents: %d'%len(doc_dicts) )


        extracted_cases.append( (case_dict, doc_dicts, []) )
        #break  #  during debug: stop after first case on page

    cur_page += 1
    #break  #  during debug: stop after first page
# Out:
# FETCHING CASE SUMMARIES
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=0
# page 1 of 6
#
#   Case: 'GoldWin Limited'
#     # documents: 2
#
#   Case: 'MKC Limited'
#     # documents: 2
#
#   Case: 'Blue High House S.A.'
#     # documents: 2
#
#   Case: 'L.C.S Limited'
#     # documents: 4
#
#   Case: 'Play North Limited'
# SKIP: scraping code is missing pdf_url, cur={'title': 'Openbaarmakingsbesluit Play North', 'status': 'Tegen dit besluit kan bezwaar worden gemaakt.'}
#     # documents: 2
#
#   Case: 'Betent'
# SKIP: scraping code is missing pdf_url, cur={'title': 'Openbaarmakingsbesluit\xa0Betent', 'status': 'Tegen dit besluit kan bezwaar worden gemaakt.'}
#     # documents: 2
#
#   Case: 'NetX Betting'
#     # documents: 2
#
#   Case: 'Bingoal Nederland B.V.'
#     # documents: 2
#
#   Case: 'Vriendenloterij N.V.'
#     # documents: 2
#
#   Case: 'Nationale Postcode Loterij N.V.'
#     # documents: 2
#
#   Case: 'GoldWin Ltd'
#     # documents: 2
#
#   Case: 'Merkur Casino Almere B.V.'
#     # documents: 2
#
#   Case: 'Betent'
#     # documents: 1
#
#   Case: 'Winning Poker Network'
#     # documents: 2
#
#   Case: 'Red Ridge Marketing'
#     # documents: 2
#
#   Case: 'Hillside New Media Malta Plc'
#     # documents: 2
#
#   Case: 'Probe Investments Limited'
#     # documents: 5
#
#   Case: 'Betpoint Group Limited'
#     # documents: 2
#
#   Case: 'N1 Interactive Limited'
#     # documents: 5
#
#   Case: 'Videoslots Limited'
#     # documents: 2
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=1
# page 2 of 6
#
#   Case: 'Fairload Limited'
#     # documents: 5
#
#   Case: 'Equinox Dynamic N.V. & Domiseda and Partners s.r.o.'
#     # documents: 5
#
#   Case: 'Bingoal Nederland B.V.'
#     # documents: 4
#
#   Case: 'JOI Gaming Ltd'
#     # documents: 5
#
#   Case: 'Shark77.Ltd'
#     # documents: 5
#
#   Case: 'Holland Casino N.V.'
#     # documents: 6
#
#   Case: 'Toto Online B.V.'
#     # documents: 0
#
#   Case: 'Nationale Postcode Loterij N.V.'
#     # documents: 2
#
#   Case: 'M.K.C Limited'
#     # documents: 2
#
#   Case: 'Gammix Limited'
#     # documents: 4
#
#   Case: 'Red Ridge Marketing'
#     # documents: 4
#
#   Case: 'Performing Media Limited'
#     # documents: 2
#
#   Case: 'Linkerik B.V.'
#     # documents: 4
#
#   Case: 'Onlinecasinobonus.nl'
#     # documents: 2
#
#   Case: 'LCB CORP'
#     # documents: 2
#
#   Case: 'Casinoscout.nl'
#     # documents: 2
#
#   Case: 'Online Casino Ground ltd'
#     # documents: 2
#
#   Case: 'Slots Dev'
#     # documents: 2
#
#   Case: 'Tipico Co. Ltd'
#     # documents: 2
#
#   Case: 'BSB Shop'
#     # documents: 2
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=2
# page 3 of 6
#
#   Case: 'Luxury Bingo'
#     # documents: 2
#
#   Case: 'N1 Interactive Limited'
#     # documents: 5
#
#   Case: 'Staatsloterij B.V.'
#     # documents: 4
#
#   Case: 'Raging Rhino N.V.'
#     # documents: 2
#
#   Case: 'Lovelto Mar LTD'
#     # documents: 4
#
#   Case: '1X Corp N.V._Exinvest Limited'
#     # documents: 4
#
#   Case: 'WL Deal'
#     # documents: 2
#
#   Case: 'Virtual Coin Gaming N.V.'
#     # documents: 6
#
#   Case: 'Clipboard Publications B.V.'
#     # documents: 2
#
#   Case: 'Kelner Automaten Service'
#     # documents: 0
#
#   Case: 'Schinveld BV'
#     # documents: 5
#
#   Case: 'Voormalig exploitant Dordrecht'
#     # documents: 2
#
#   Case: 'Voormalig exploitant Amersfoort'
#     # documents: 2
#
#   Case: 'Royal Panda Limited'
#     # documents: 5
#
#   Case: 'LeoVegas Gaming p.l.c.'
#     # documents: 4
#
#   Case: 'Pokerstars'
#     # documents: 5
#
#   Case: 'Chance Publications Malta Ltd'
#     # documents: 3
#
#   Case: 'Unibet'
#     # documents: 2
#
#   Case: 'Bwin'
#     # documents: 5
#
#   Case: 'Simbat Entertainment Systems en Spinity'
#     # documents: 7
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=3
# page 4 of 6
#
#   Case: 'Com Coin Operated Machines'
#     # documents: 2
#
#   Case: 'Casumo'
#     # documents: 5
#
#   Case: 'Innovation Labs en Gaming Innovation Group'
#     # documents: 6
#
#   Case: 'Content Publishing Limited'
#     # documents: 5
#
#   Case: 'Exploiteren zonder vergunning in café'
#     # documents: 4
#
#   Case: 'WHG (International) Limited'
#     # documents: 5
#
#   Case: 'Voormalig exploitant Abcoude'
#     # documents: 2
#
#   Case: 'CyberRock Entertainment N.V. en Honeydew Trading Limited.'
#     # documents: 6
#
#   Case: 'Mr Green Limited'
#     # documents: 4
#
#   Case: 'ITC Lounge Plaza'
#     # documents: 2
#
#   Case: 'Corona Limited'
#     # documents: 4
#
#   Case: 'Café restaurant De Kruik'
#     # documents: 2
#
#   Case: 'Bet-at-home'
#     # documents: 4
#
#   Case: 'Visionairy iGaming'
#     # documents: 4
#
#   Case: 'VriendenLoterij N.V.'
#     # documents: 8
#
#   Case: 'BankGiro Loterij N.V.'
#     # documents: 8
#
#   Case: 'Nationale Postcode Loterij N.V.'
#     # documents: 10
#
#   Case: 'Lotto B.V.'
#     # documents: 12
#
#   Case: 'Staatsloterij B.V.'
#     # documents: 8
#
#   Case: 'Holland Casino N.V.'
#     # documents: 4
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=4
# page 5 of 6
#
#   Case: 'Catena Operations Limited'
#     # documents: 2
#
#   Case: 'Weddenopvoetbal.org'
#     # documents: 4
#
#   Case: 'JvG speelautomaten'
#     # documents: 2
#
#   Case: 'Trustfulgames.com Limited'
#     # documents: 7
#
#   Case: 'L.S.A. B.V'
#     # documents: 4
#
#   Case: 'M-automaten exploitatie'
#     # documents: 2
#
#   Case: 'Wedwinkel Rotterdam'
#     # documents: 2
#
#   Case: 'Friese ondernemer'
#     # documents: 1
#
#   Case: 'Holland Gaming'
#     # documents: 2
#
#   Case: 'Olders Amusementsautomaten B.V.'
#     # documents: 1
#
#   Case: 'Duitse loterijen'
#     # documents: 2
#
#   Case: 'Dolle Pret in Almelo B.V.'
#     # documents: 2
#
#   Case: 'Redslots'
#     # documents: 4
#
#   Case: 'Café _ Bar Bağci'
#     # documents: 4
#
#   Case: 'Total E Soft Limited en XKL Limited'
#     # documents: 4
#
#   Case: 'Belhuis _ Internetcafé Ephesus'
#     # documents: 2
#
#   Case: 'V.O.F. AULON'
#     # documents: 2
#
#   Case: 'V.O.F. Bosma Amusement'
#     # documents: 2
#
#   Case: 'Stichting Sport Twente'
#     # documents: 4
#
#   Case: 'Thee- en koffiehuis Kayseri'
#     # documents: 4
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=5
# page 6 of 5
#
#   Case: 'Eetcafé De Gouw'
#     # documents: 4
#
#   Case: 'Co Gaming Limited (voorheen Come On Europe Limited)'
#     # documents: 4
#
#   Case: 'Stichting Trefcentrum Brinkstraat'
#     # documents: 4
#
#   Case: 'Imperial E-club Limited'
#     # documents: 4
#
#   Case: 'Stichting Bil Kazan'
#     # documents: 4
#
#   Case: '7Red.com'
# WARNING - no content?
#
#   Case: 'Villa Mountain View'
#     # documents: 4
#
#   Case: 'GT Beheersorganisatie'
#     # documents: 2
#
#   Case: 'Koffiehuis Vadi'
#     # documents: 2
#
#   Case: 'Gooische Bingo Show'
#     # documents: 2
#
#   Case: 'Globalstars'
#     # documents: 4
#
#   Case: 'Grand Café Randenbroek'
#     # documents: 4
#
#   Case: 'Onisac Limited en Mansion Online Casino Limited'
#     # documents: 9
#
#   Case: 'Café Lucky'
#     # documents: 4
#
#   Case: 'Star SAT Electronica'
#     # documents: 2
#
#   Case: 'Call Internet City'
#     # documents: 4
#
#   Case: 'Huizenloterij'
#     # documents: 4

# %%
# that produces a structure like (example for one case):
extracted_cases[0]
# Out:
# ({'name': 'GoldWin Limited',
#   'date_range': [],
#   'money': [],
#   'ecli': [],
#   'case_detail_url': 'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/goldwin-limited/'},
#  [{'title': 'Boetebesluit GoldWin Limited',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/16442_boetebesluit_goldwin.pdf',
#    'status': 'Tegen dit besluit kan bezwaar worden gemaakt.'},
#   {'title': 'Openbaarmakingsbesluit\xa0GoldWin Limited',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/16442_01-299-883_openbaarmakingsbesluit_goldwin.pdf',
#    'status': 'Tegen dit besluit kan bezwaar worden gemaakt.'}],
#  [])

# %% [markdown]
# ### Fetch the PDFs, OCR them
#
# The above fetched metadata and links to the PDF, but not yet the documents.
#
# We could have split up the 'fetch PDFs' and 'renders page and OCRs then', and stil might.
# This way we don't have to remember quite as much, and it's single-purpose anyway.
#
# This produces OCR results in their raw form -- (a bunch of text fragments with their positions) and does not use it yet.
# It sets this data on the same data structure (that third tuple item inited as []) - the section below actually uses it.
# Which is perhaps somewhat confusing.
#
# Doing the OCR for a hundred documents takes a few hours, which is why we cache the raw OCR results.

# %%
print( "FETCHing PDFs,  OCRing pages" )

for case_i, case_tuple in enumerate(extracted_cases):
    case_dict, case_doc_dicts, _ = case_tuple
    case_name = case_dict['name']

    print('------------------------')
    print( "ENUM: %s"%case_i)
    print( "NAME: %s"%case_name)
    print( "DICTS: %s"%pprint.pformat(case_doc_dicts))
    for case_doc_dict in case_doc_dicts:   # for each PDF document in the case
        pdf_url = case_doc_dict['pdf_url']

        print( "== %s =="%wetsuite.helpers.format.url_basename( pdf_url ) )
        pdfbytes, _ = wetsuite.helpers.localdata.cached_fetch( pdfstore, pdf_url )
        doc_page_fragments = [] # list of lists:   [   [page1fragment1,page1fragment2], [page2fragment1,page2fragment2], etc.  ]   

        #if 0:   
        #    doc_text_pages == list( wetsuite.datacollect.pdf.page_text( pdfbytes ) )
        #else:

        # Render PDF images as images
        page_images = list( wetsuite.extras.pdf.pages_as_images(pdfbytes, dpi=200, antialiasing=True) )  # TODO: cache these too
        # high DPI and antialiasing does a _little_ better on things like periods and colons, but less than you'ld think.

        # For each page image, get OCR. This ic cached because this is sloooow, and PDFs are unlikely to change
        for page_i, page_image in enumerate(page_images):
            page_key = 'ocr::%s::%s'%(page_i, pdf_url)

            if page_key in ocrstore:
                print('     OCR - CACHED  for page %d of %d'%(page_i+1, len(page_images)))
                page_ocr_results = json.loads( ocrstore.get(page_key) )
            else: # generate and cache
                print('     OCR - DOING  for page %d of %d'%(page_i+1, len(page_images)))
                page_ocr_results = wetsuite.extras.ocr.easyocr( page_image, use_gpu=True ) # CONSIDER: prefer?

                ocrstore.put( page_key, json.dumps(page_ocr_results).encode('utf8') )

            #page_image.save( '%s__%s__page_%03d.png'%(case_name,  hash(pdfbytes), page_i+1) )
            # DEBUG: Draw OCR results on the page it came from, and save as PNG:
            #eval_image = wetsuite.extras.ocr.easyocr_draw_eval( page_image, page_ocr_results )
            #eval_image.save('%s__%s__page_%03d-boxes.png'%(case_name,  hash(pdfbytes), page_i+1))

            # I think this is here to potentially merge PDF text objects into the same sort of structure. As is it does nothing.
            page_fragments = []   # fragments of text in a page,  which in the case of EasyOCR will typically be lines at a time
            for bbox, text, cert in page_ocr_results:
                page_fragments.append( (bbox, text, cert) ) 
            doc_page_fragments.append( page_fragments ) # yes, this is currently just page_ocr_results, the idea was that the above might augment/simplify that

        extracted_cases[case_i][2].append( doc_page_fragments )
# Out:
# FETCH PDFs,  OCRing pages
# ------------------------
# ENUM: 0
# NAME: GoldWin Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/16442_boetebesluit_goldwin.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Boetebesluit GoldWin Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/16442_01-299-883_openbaarmakingsbesluit_goldwin.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit\xa0GoldWin Limited'}]
# == 16442_boetebesluit_goldwin.pdf ==
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == 16442_01-299-883_openbaarmakingsbesluit_goldwin.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 1
# NAME: MKC Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/16402_boetebesluit_mkc_limited.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Boetebesluit\xa0MKC Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/16402_01-299-881_openbaarmakingsbesluit_mkc_limited.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit\xa0MKC Limited'}]
# == 16402_boetebesluit_mkc_limited.pdf ==
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == 16402_01-299-881_openbaarmakingsbesluit_mkc_limited.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 2
# NAME: Blue High House S.A.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230929_01-296-617_besluit_lod_1a_blue_high_house_s-a-.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit last onder dwangsom Blue High House S.A.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230929_01-296-618_besluit_openbaarmaking_woo_blue_high_house_s-a-.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit Blue High House S.A.'}]
# == 20230929_01-296-617_besluit_lod_1a_blue_high_house_s-a-.pdf ==
#      OCR - CACHED  for page 1 of 12
#      OCR - CACHED  for page 2 of 12
#      OCR - CACHED  for page 3 of 12
#      OCR - CACHED  for page 4 of 12
#      OCR - CACHED  for page 5 of 12
#      OCR - CACHED  for page 6 of 12
#      OCR - CACHED  for page 7 of 12
#      OCR - CACHED  for page 8 of 12
#      OCR - CACHED  for page 9 of 12
#      OCR - CACHED  for page 10 of 12
#      OCR - CACHED  for page 11 of 12
#      OCR - CACHED  for page 12 of 12
# == 20230929_01-296-618_besluit_openbaarmaking_woo_blue_high_house_s-a-.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 3
# NAME: L.C.S Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_lcs_limited.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Boetebesluit L.C.S Limited (12 oktober 2023)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_lcs_limited.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt',
#   'title': 'Openbaarmakingsbesluit L.C.S Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20220817_01_265_500_-_besluit_lod_sons-of-slots_ov.pdf',
#   'status': 'Naar aanleiding van het besluit is gecontroleerd, hierbij is '
#             'geconstateerd dat de overtredingen zijn gestaakt.\xa0Tegen dit '
#             'besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Last onder dwangsom\xa0L.C.S Limited (1\xa0september 2022)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20220817_01_265_499_-_besluit_openbaarmaking_ov.pdf',
#   'status': 'Naar aanleiding van het besluit is gecontroleerd, hierbij is '
#             'geconstateerd dat de overtredingen zijn gestaakt.\xa0Tegen dit '
#             'besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit tot openbaarmaking\xa0L.C.S Limited (1\xa0september 2022)'}]
# == sanctiebesluit_lcs_limited.pdf ==
#      OCR - CACHED  for page 1 of 21
#      OCR - CACHED  for page 2 of 21
#      OCR - CACHED  for page 3 of 21
#      OCR - CACHED  for page 4 of 21
#      OCR - CACHED  for page 5 of 21
#      OCR - CACHED  for page 6 of 21
#      OCR - CACHED  for page 7 of 21
#      OCR - CACHED  for page 8 of 21
#      OCR - CACHED  for page 9 of 21
#      OCR - CACHED  for page 10 of 21
#      OCR - CACHED  for page 11 of 21
#      OCR - CACHED  for page 12 of 21
#      OCR - CACHED  for page 13 of 21
#      OCR - CACHED  for page 14 of 21
#      OCR - CACHED  for page 15 of 21
#      OCR - CACHED  for page 16 of 21
#      OCR - CACHED  for page 17 of 21
#      OCR - CACHED  for page 18 of 21
#      OCR - CACHED  for page 19 of 21
#      OCR - CACHED  for page 20 of 21
#      OCR - CACHED  for page 21 of 21
# == besluit_openbaarmaking_lcs_limited.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 20220817_01_265_500_-_besluit_lod_sons-of-slots_ov.pdf ==
#      OCR - CACHED  for page 1 of 11
#      OCR - CACHED  for page 2 of 11
#      OCR - CACHED  for page 3 of 11
#      OCR - CACHED  for page 4 of 11
#      OCR - CACHED  for page 5 of 11
#      OCR - CACHED  for page 6 of 11
#      OCR - CACHED  for page 7 of 11
#      OCR - CACHED  for page 8 of 11
#      OCR - CACHED  for page 9 of 11
#      OCR - CACHED  for page 10 of 11
#      OCR - CACHED  for page 11 of 11
# == 20220817_01_265_499_-_besluit_openbaarmaking_ov.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 4
# NAME: Play North Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230831_01-292-391_aanwijzing_pn_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit aanwijzing Play North'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230619_01-292-392_besluit_op_bezwaar_pn_ov.pdf',
#   'status': 'Er is geen beroep ingesteld.\xa0 Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit op bezwaar'}]
# == 20230831_01-292-391_aanwijzing_pn_ov.pdf ==
#      OCR - CACHED  for page 1 of 14
#      OCR - CACHED  for page 2 of 14
#      OCR - CACHED  for page 3 of 14
#      OCR - CACHED  for page 4 of 14
#      OCR - CACHED  for page 5 of 14
#      OCR - CACHED  for page 6 of 14
#      OCR - CACHED  for page 7 of 14
#      OCR - CACHED  for page 8 of 14
#      OCR - CACHED  for page 9 of 14
#      OCR - CACHED  for page 10 of 14
#      OCR - CACHED  for page 11 of 14
#      OCR - CACHED  for page 12 of 14
#      OCR - CACHED  for page 13 of 14
#      OCR - CACHED  for page 14 of 14
# == 20230619_01-292-392_besluit_op_bezwaar_pn_ov.pdf ==
#      OCR - DOING  for page 1 of 27
# first use of ocr() - loading EasyOCR model (into GPU)
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:252: UserWarning: Accessing the model URLs via the internal dictionary of the module is deprecated since 0.13 and will be removed in 0.15. Please access them via the appropriate Weights Enum instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#      OCR - DOING  for page 2 of 27
#      OCR - DOING  for page 3 of 27
#      OCR - DOING  for page 4 of 27
#      OCR - DOING  for page 5 of 27
#      OCR - DOING  for page 6 of 27
#      OCR - DOING  for page 7 of 27
#      OCR - DOING  for page 8 of 27
#      OCR - DOING  for page 9 of 27
#      OCR - DOING  for page 10 of 27
#      OCR - DOING  for page 11 of 27
#      OCR - DOING  for page 12 of 27
#      OCR - DOING  for page 13 of 27
#      OCR - DOING  for page 14 of 27
#      OCR - DOING  for page 15 of 27
#      OCR - DOING  for page 16 of 27
#      OCR - DOING  for page 17 of 27
#      OCR - DOING  for page 18 of 27
#      OCR - DOING  for page 19 of 27
#      OCR - DOING  for page 20 of 27
#      OCR - DOING  for page 21 of 27
#      OCR - DOING  for page 22 of 27
#      OCR - DOING  for page 23 of 27
#      OCR - DOING  for page 24 of 27
#      OCR - DOING  for page 25 of 27
#      OCR - DOING  for page 26 of 27
#      OCR - DOING  for page 27 of 27
# ------------------------
# ENUM: 5
# NAME: Betent
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230831_01-292-887_aanwijzing_betent_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit aanwijzing Betent'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230831_01-292-888_besluit_op_bezwaar_ov.pdf',
#   'status': 'Er is geen beroep ingesteld.\xa0\xa0Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit op bezwaar'}]
# == 20230831_01-292-887_aanwijzing_betent_ov.pdf ==
#      OCR - DOING  for page 1 of 11
#      OCR - DOING  for page 2 of 11
#      OCR - DOING  for page 3 of 11
#      OCR - DOING  for page 4 of 11
#      OCR - DOING  for page 5 of 11
#      OCR - DOING  for page 6 of 11
#      OCR - DOING  for page 7 of 11
#      OCR - DOING  for page 8 of 11
#      OCR - DOING  for page 9 of 11
#      OCR - DOING  for page 10 of 11
#      OCR - DOING  for page 11 of 11
# == 20230831_01-292-888_besluit_op_bezwaar_ov.pdf ==
#      OCR - DOING  for page 1 of 17
#      OCR - DOING  for page 2 of 17
#      OCR - DOING  for page 3 of 17
#      OCR - DOING  for page 4 of 17
#      OCR - DOING  for page 5 of 17
#      OCR - DOING  for page 6 of 17
#      OCR - DOING  for page 7 of 17
#      OCR - DOING  for page 8 of 17
#      OCR - DOING  for page 9 of 17
#      OCR - DOING  for page 10 of 17
#      OCR - DOING  for page 11 of 17
#      OCR - DOING  for page 12 of 17
#      OCR - DOING  for page 13 of 17
#      OCR - DOING  for page 14 of 17
#      OCR - DOING  for page 15 of 17
#      OCR - DOING  for page 16 of 17
#      OCR - DOING  for page 17 of 17
# ------------------------
# ENUM: 6
# NAME: NetX Betting
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_lod_1a_netx_betting_limited_ov_.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit last onder dwangsom NetX Betting'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_ov_.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking NetX Betting'}]
# == besluit_lod_1a_netx_betting_limited_ov_.pdf ==
#      OCR - CACHED  for page 1 of 14
#      OCR - CACHED  for page 2 of 14
#      OCR - CACHED  for page 3 of 14
#      OCR - CACHED  for page 4 of 14
#      OCR - CACHED  for page 5 of 14
#      OCR - CACHED  for page 6 of 14
#      OCR - CACHED  for page 7 of 14
#      OCR - CACHED  for page 8 of 14
#      OCR - CACHED  for page 9 of 14
#      OCR - CACHED  for page 10 of 14
#      OCR - CACHED  for page 11 of 14
#      OCR - CACHED  for page 12 of 14
#      OCR - CACHED  for page 13 of 14
#      OCR - CACHED  for page 14 of 14
# == besluit_openbaarmaking_ov_.pdf ==
#      OCR - CACHED  for page 1 of 6
#      OCR - CACHED  for page 2 of 6
#      OCR - CACHED  for page 3 of 6
#      OCR - CACHED  for page 4 of 6
#      OCR - CACHED  for page 5 of 6
#      OCR - CACHED  for page 6 of 6
# ------------------------
# ENUM: 7
# NAME: Bingoal Nederland B.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-288-556_15404_sanctiebesluit_bingoal.pdf',
#   'status': 'Tegen dit besluit\xa0is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15404_bingoal_openbaarmakingsbesluit_002_.pdf',
#   'status': 'Tegen dit besluit\xa0is\xa0bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit'}]
# == 01-288-556_15404_sanctiebesluit_bingoal.pdf ==
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == 15404_bingoal_openbaarmakingsbesluit_002_.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 8
# NAME: Vriendenloterij N.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230523_01-291-294_openbaar_besluit_last_onder_dwangsom_vl_spellen.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit last onder dwangsom Vriendenloterij N.V.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230523_01-291-296_openbare_versie_openbaarmakingsbesluit_woo_vl_last.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit openbaarmaking Vriendenloterij N.V.'}]
# == 20230523_01-291-294_openbaar_besluit_last_onder_dwangsom_vl_spellen.pdf ==
#      OCR - CACHED  for page 1 of 30
#      OCR - CACHED  for page 2 of 30
#      OCR - CACHED  for page 3 of 30
#      OCR - CACHED  for page 4 of 30
#      OCR - CACHED  for page 5 of 30
#      OCR - CACHED  for page 6 of 30
#      OCR - CACHED  for page 7 of 30
#      OCR - CACHED  for page 8 of 30
#      OCR - CACHED  for page 9 of 30
#      OCR - CACHED  for page 10 of 30
#      OCR - CACHED  for page 11 of 30
#      OCR - CACHED  for page 12 of 30
#      OCR - CACHED  for page 13 of 30
#      OCR - CACHED  for page 14 of 30
#      OCR - CACHED  for page 15 of 30
#      OCR - CACHED  for page 16 of 30
#      OCR - CACHED  for page 17 of 30
#      OCR - CACHED  for page 18 of 30
#      OCR - CACHED  for page 19 of 30
#      OCR - CACHED  for page 20 of 30
#      OCR - CACHED  for page 21 of 30
#      OCR - CACHED  for page 22 of 30
#      OCR - CACHED  for page 23 of 30
#      OCR - CACHED  for page 24 of 30
#      OCR - CACHED  for page 25 of 30
#      OCR - CACHED  for page 26 of 30
#      OCR - CACHED  for page 27 of 30
#      OCR - CACHED  for page 28 of 30
#      OCR - CACHED  for page 29 of 30
#      OCR - CACHED  for page 30 of 30
# == 20230523_01-291-296_openbare_versie_openbaarmakingsbesluit_woo_vl_last.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 9
# NAME: Nationale Postcode Loterij N.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230523_01-291-288_openbaar_besluit_last_onder_dwangsom_npl_spellen.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit Last onder dwangsom Nationale Postcode Loterij N.V.'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230523_01-291-290_openbare_versie_openbaarmakingsbesluit_woo_npl_last.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit openbaarmaking Nationale Postcode Loterij N.V.'}]
# == 20230523_01-291-288_openbaar_besluit_last_onder_dwangsom_npl_spellen.pdf ==
#      OCR - CACHED  for page 1 of 31
#      OCR - CACHED  for page 2 of 31
#      OCR - CACHED  for page 3 of 31
#      OCR - CACHED  for page 4 of 31
#      OCR - CACHED  for page 5 of 31
#      OCR - CACHED  for page 6 of 31
#      OCR - CACHED  for page 7 of 31
#      OCR - CACHED  for page 8 of 31
#      OCR - CACHED  for page 9 of 31
#      OCR - CACHED  for page 10 of 31
#      OCR - CACHED  for page 11 of 31
#      OCR - CACHED  for page 12 of 31
#      OCR - CACHED  for page 13 of 31
#      OCR - CACHED  for page 14 of 31
#      OCR - CACHED  for page 15 of 31
#      OCR - CACHED  for page 16 of 31
#      OCR - CACHED  for page 17 of 31
#      OCR - CACHED  for page 18 of 31
#      OCR - CACHED  for page 19 of 31
#      OCR - CACHED  for page 20 of 31
#      OCR - CACHED  for page 21 of 31
#      OCR - CACHED  for page 22 of 31
#      OCR - CACHED  for page 23 of 31
#      OCR - CACHED  for page 24 of 31
#      OCR - CACHED  for page 25 of 31
#      OCR - CACHED  for page 26 of 31
#      OCR - CACHED  for page 27 of 31
#      OCR - CACHED  for page 28 of 31
#      OCR - CACHED  for page 29 of 31
#      OCR - CACHED  for page 30 of 31
#      OCR - CACHED  for page 31 of 31
# == 20230523_01-291-290_openbare_versie_openbaarmakingsbesluit_woo_npl_last.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 10
# NAME: GoldWin Ltd
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230420_01-291-425_besluit_lod_goldwin_ltd_ov_.pdf',
#   'title': 'Besluit last onder dwangsom GoldWin Ltd'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230420_01-191-426_besluit_openbaarmaking_ov_.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Besluit tot openbaarmaking GoldWin Ltd'}]
# == 20230420_01-291-425_besluit_lod_goldwin_ltd_ov_.pdf ==
#      OCR - CACHED  for page 1 of 12
#      OCR - CACHED  for page 2 of 12
#      OCR - CACHED  for page 3 of 12
#      OCR - CACHED  for page 4 of 12
#      OCR - CACHED  for page 5 of 12
#      OCR - CACHED  for page 6 of 12
#      OCR - CACHED  for page 7 of 12
#      OCR - CACHED  for page 8 of 12
#      OCR - CACHED  for page 9 of 12
#      OCR - CACHED  for page 10 of 12
#      OCR - CACHED  for page 11 of 12
#      OCR - CACHED  for page 12 of 12
# == 20230420_01-191-426_besluit_openbaarmaking_ov_.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 11
# NAME: Merkur Casino Almere B.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-289-330_15484_sanctiebesluit_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Sanctiebesluit'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-289-336_15484_openbaarmakingsbesluit_woo_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt',
#   'title': 'Openbaarmakingsbesluit'}]
# == 01-289-330_15484_sanctiebesluit_ov.pdf ==
#      OCR - CACHED  for page 1 of 16
#      OCR - CACHED  for page 2 of 16
#      OCR - CACHED  for page 3 of 16
#      OCR - CACHED  for page 4 of 16
#      OCR - CACHED  for page 5 of 16
#      OCR - CACHED  for page 6 of 16
#      OCR - CACHED  for page 7 of 16
#      OCR - CACHED  for page 8 of 16
#      OCR - CACHED  for page 9 of 16
#      OCR - CACHED  for page 10 of 16
#      OCR - CACHED  for page 11 of 16
#      OCR - CACHED  for page 12 of 16
#      OCR - CACHED  for page 13 of 16
#      OCR - CACHED  for page 14 of 16
#      OCR - CACHED  for page 15 of 16
#      OCR - CACHED  for page 16 of 16
# == 01-289-336_15484_openbaarmakingsbesluit_woo_ov.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 12
# NAME: Betent
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/betent_15403_openbaarmakingsbesluit.pdf',
#   'status': 'Tegen dit besluit kan nog bezwaar worden gemaakt.',
#   'title': '19 april 2023'}]
# == betent_15403_openbaarmakingsbesluit.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 13
# NAME: Winning Poker Network
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230228_01-285-044_lod_openbare_versie_beveiligd.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Sanctiebesluit Winning Poker Network'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20220228_01-287-832_besluit_openbaarmaking_openbare_versie_beveiligd.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit Winning Poker Network'}]
# == 20230228_01-285-044_lod_openbare_versie_beveiligd.pdf ==
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == 20220228_01-287-832_besluit_openbaarmaking_openbare_versie_beveiligd.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 14
# NAME: Red Ridge Marketing
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-286-861_15395_sanctiebesluit_ov.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Sanctiebesluit Red Ridge Marketing'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15395_openbaarmakingsbesluit_ov.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Openbaarmakingsbesluit Red Ridge Marketing'}]
# == 01-286-861_15395_sanctiebesluit_ov.pdf ==
#      OCR - CACHED  for page 1 of 16
#      OCR - CACHED  for page 2 of 16
#      OCR - CACHED  for page 3 of 16
#      OCR - CACHED  for page 4 of 16
#      OCR - CACHED  for page 5 of 16
#      OCR - CACHED  for page 6 of 16
#      OCR - CACHED  for page 7 of 16
#      OCR - CACHED  for page 8 of 16
#      OCR - CACHED  for page 9 of 16
#      OCR - CACHED  for page 10 of 16
#      OCR - CACHED  for page 11 of 16
#      OCR - CACHED  for page 12 of 16
#      OCR - CACHED  for page 13 of 16
#      OCR - CACHED  for page 14 of 16
#      OCR - CACHED  for page 15 of 16
#      OCR - CACHED  for page 16 of 16
# == 15395_openbaarmakingsbesluit_ov.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 15
# NAME: Hillside New Media Malta Plc
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15402_01-285-941_besluit-signed_openbare_versie.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Sanctiebesluit Hillside'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-287-123_openbaarmakingsbesluit_woo_openbare_versie.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit Hillside'}]
# == 15402_01-285-941_besluit-signed_openbare_versie.pdf ==
#      OCR - CACHED  for page 1 of 15
#      OCR - CACHED  for page 2 of 15
#      OCR - CACHED  for page 3 of 15
#      OCR - CACHED  for page 4 of 15
#      OCR - CACHED  for page 5 of 15
#      OCR - CACHED  for page 6 of 15
#      OCR - CACHED  for page 7 of 15
#      OCR - CACHED  for page 8 of 15
#      OCR - CACHED  for page 9 of 15
#      OCR - CACHED  for page 10 of 15
#      OCR - CACHED  for page 11 of 15
#      OCR - CACHED  for page 12 of 15
#      OCR - CACHED  for page 13 of 15
#      OCR - CACHED  for page 14 of 15
#      OCR - CACHED  for page 15 of 15
# == 01-287-123_openbaarmakingsbesluit_woo_openbare_versie.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# ------------------------
# ENUM: 16
# NAME: Probe Investments Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15269_01-294-564_beslissing_op_bezwaar_ov.pdf',
#   'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep '
#             'worden ingesteld bij de rechtbank.',
#   'title': 'Beslissing op bezwaar Probe'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15269_01-294-565_openbaarmakingsbesluit_woo_bob_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit beslissing op bezwaar Probe'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15269_01-293-484_bac_advies_ov.pdf',
#   'title': 'BAC Advies Probe'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15269_01-281-231_sanctiebesluit_probe_investments_limited_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Probe'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15269_01-281-234_besluit_openbaarmaking_probe_investments_limited_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit Probe'}]
# == 15269_01-294-564_beslissing_op_bezwaar_ov.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 15269_01-294-565_openbaarmakingsbesluit_woo_bob_ov.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 15269_01-293-484_bac_advies_ov.pdf ==
#      OCR - CACHED  for page 1 of 20
#      OCR - CACHED  for page 2 of 20
#      OCR - CACHED  for page 3 of 20
#      OCR - CACHED  for page 4 of 20
#      OCR - CACHED  for page 5 of 20
#      OCR - CACHED  for page 6 of 20
#      OCR - CACHED  for page 7 of 20
#      OCR - CACHED  for page 8 of 20
#      OCR - CACHED  for page 9 of 20
#      OCR - CACHED  for page 10 of 20
#      OCR - CACHED  for page 11 of 20
#      OCR - CACHED  for page 12 of 20
#      OCR - CACHED  for page 13 of 20
#      OCR - CACHED  for page 14 of 20
#      OCR - CACHED  for page 15 of 20
#      OCR - CACHED  for page 16 of 20
#      OCR - CACHED  for page 17 of 20
#      OCR - CACHED  for page 18 of 20
#      OCR - CACHED  for page 19 of 20
#      OCR - CACHED  for page 20 of 20
# == 15269_01-281-231_sanctiebesluit_probe_investments_limited_ov.pdf ==
#      OCR - CACHED  for page 1 of 27
#      OCR - CACHED  for page 2 of 27
#      OCR - CACHED  for page 3 of 27
#      OCR - CACHED  for page 4 of 27
#      OCR - CACHED  for page 5 of 27
#      OCR - CACHED  for page 6 of 27
#      OCR - CACHED  for page 7 of 27
#      OCR - CACHED  for page 8 of 27
#      OCR - CACHED  for page 9 of 27
#      OCR - CACHED  for page 10 of 27
#      OCR - CACHED  for page 11 of 27
#      OCR - CACHED  for page 12 of 27
#      OCR - CACHED  for page 13 of 27
#      OCR - CACHED  for page 14 of 27
#      OCR - CACHED  for page 15 of 27
#      OCR - CACHED  for page 16 of 27
#      OCR - CACHED  for page 17 of 27
#      OCR - CACHED  for page 18 of 27
#      OCR - CACHED  for page 19 of 27
#      OCR - CACHED  for page 20 of 27
#      OCR - CACHED  for page 21 of 27
#      OCR - CACHED  for page 22 of 27
#      OCR - CACHED  for page 23 of 27
#      OCR - CACHED  for page 24 of 27
#      OCR - CACHED  for page 25 of 27
#      OCR - CACHED  for page 26 of 27
#      OCR - CACHED  for page 27 of 27
# == 15269_01-281-234_besluit_openbaarmaking_probe_investments_limited_ov.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 17
# NAME: Betpoint Group Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/ov_15164_01-281-226_sanctiebesluit_betpoint.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Betpoint'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/ov_15164_01-281-229_betpoint_openbaarmaking.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit Betpoint'}]
# == ov_15164_01-281-226_sanctiebesluit_betpoint.pdf ==
#      OCR - CACHED  for page 1 of 31
#      OCR - CACHED  for page 2 of 31
#      OCR - CACHED  for page 3 of 31
#      OCR - CACHED  for page 4 of 31
#      OCR - CACHED  for page 5 of 31
#      OCR - CACHED  for page 6 of 31
#      OCR - CACHED  for page 7 of 31
#      OCR - CACHED  for page 8 of 31
#      OCR - CACHED  for page 9 of 31
#      OCR - CACHED  for page 10 of 31
#      OCR - CACHED  for page 11 of 31
#      OCR - CACHED  for page 12 of 31
#      OCR - CACHED  for page 13 of 31
#      OCR - CACHED  for page 14 of 31
#      OCR - CACHED  for page 15 of 31
#      OCR - CACHED  for page 16 of 31
#      OCR - CACHED  for page 17 of 31
#      OCR - CACHED  for page 18 of 31
#      OCR - CACHED  for page 19 of 31
#      OCR - CACHED  for page 20 of 31
#      OCR - CACHED  for page 21 of 31
#      OCR - CACHED  for page 22 of 31
#      OCR - CACHED  for page 23 of 31
#      OCR - CACHED  for page 24 of 31
#      OCR - CACHED  for page 25 of 31
#      OCR - CACHED  for page 26 of 31
#      OCR - CACHED  for page 27 of 31
#      OCR - CACHED  for page 28 of 31
#      OCR - CACHED  for page 29 of 31
#      OCR - CACHED  for page 30 of 31
#      OCR - CACHED  for page 31 of 31
# == ov_15164_01-281-229_betpoint_openbaarmaking.pdf ==
#      OCR - CACHED  for page 1 of 6
#      OCR - CACHED  for page 2 of 6
#      OCR - CACHED  for page 3 of 6
#      OCR - CACHED  for page 4 of 6
#      OCR - CACHED  for page 5 of 6
#      OCR - CACHED  for page 6 of 6
# ------------------------
# ENUM: 18
# NAME: N1 Interactive Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-292-870-beslissing_op_bezwaar_15244_ov.pdf',
#   'status': 'Tegen deze beslissing op bezwaar is inmiddels beroep ingesteld '
#             'bij de rechtbank.',
#   'title': 'Beslissing op bezwaar N1 Interactive Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-292-895_besluit_openbaarmaking_15244_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit beslissing op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15244_01-291-871_bac_advies_ov_1.pdf',
#   'title': 'BAC Advies N1'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-281-253_sanctiebesluit_15244_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit N1 Interactive Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-281-256_openbaarmakingbesluit_15244_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit'}]
# == 01-292-870-beslissing_op_bezwaar_15244_ov.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 01-292-895_besluit_openbaarmaking_15244_ov.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 15244_01-291-871_bac_advies_ov_1.pdf ==
#      OCR - CACHED  for page 1 of 14
#      OCR - CACHED  for page 2 of 14
#      OCR - CACHED  for page 3 of 14
#      OCR - CACHED  for page 4 of 14
#      OCR - CACHED  for page 5 of 14
#      OCR - CACHED  for page 6 of 14
#      OCR - CACHED  for page 7 of 14
#      OCR - CACHED  for page 8 of 14
#      OCR - CACHED  for page 9 of 14
#      OCR - CACHED  for page 10 of 14
#      OCR - CACHED  for page 11 of 14
#      OCR - CACHED  for page 12 of 14
#      OCR - CACHED  for page 13 of 14
#      OCR - CACHED  for page 14 of 14
# == 01-281-253_sanctiebesluit_15244_ov.pdf ==
#      OCR - CACHED  for page 1 of 28
#      OCR - CACHED  for page 2 of 28
#      OCR - CACHED  for page 3 of 28
#      OCR - CACHED  for page 4 of 28
#      OCR - CACHED  for page 5 of 28
#      OCR - CACHED  for page 6 of 28
#      OCR - CACHED  for page 7 of 28
#      OCR - CACHED  for page 8 of 28
#      OCR - CACHED  for page 9 of 28
#      OCR - CACHED  for page 10 of 28
#      OCR - CACHED  for page 11 of 28
#      OCR - CACHED  for page 12 of 28
#      OCR - CACHED  for page 13 of 28
#      OCR - CACHED  for page 14 of 28
#      OCR - CACHED  for page 15 of 28
#      OCR - CACHED  for page 16 of 28
#      OCR - CACHED  for page 17 of 28
#      OCR - CACHED  for page 18 of 28
#      OCR - CACHED  for page 19 of 28
#      OCR - CACHED  for page 20 of 28
#      OCR - CACHED  for page 21 of 28
#      OCR - CACHED  for page 22 of 28
#      OCR - CACHED  for page 23 of 28
#      OCR - CACHED  for page 24 of 28
#      OCR - CACHED  for page 25 of 28
#      OCR - CACHED  for page 26 of 28
#      OCR - CACHED  for page 27 of 28
#      OCR - CACHED  for page 28 of 28
# == 01-281-256_openbaarmakingbesluit_15244_ov.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 19
# NAME: Videoslots Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15167_01-281-259_sanctiebesluit_videoslots_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Videoslots Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-281-262_openbaarmakingsbesluit_videoslots_ov.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit Videoslots Limited'}]
# == 15167_01-281-259_sanctiebesluit_videoslots_ov.pdf ==
#      OCR - CACHED  for page 1 of 30
#      OCR - CACHED  for page 2 of 30
#      OCR - CACHED  for page 3 of 30
#      OCR - CACHED  for page 4 of 30
#      OCR - CACHED  for page 5 of 30
#      OCR - CACHED  for page 6 of 30
#      OCR - CACHED  for page 7 of 30
#      OCR - CACHED  for page 8 of 30
#      OCR - CACHED  for page 9 of 30
#      OCR - CACHED  for page 10 of 30
#      OCR - CACHED  for page 11 of 30
#      OCR - CACHED  for page 12 of 30
#      OCR - CACHED  for page 13 of 30
#      OCR - CACHED  for page 14 of 30
#      OCR - CACHED  for page 15 of 30
#      OCR - CACHED  for page 16 of 30
#      OCR - CACHED  for page 17 of 30
#      OCR - CACHED  for page 18 of 30
#      OCR - CACHED  for page 19 of 30
#      OCR - CACHED  for page 20 of 30
#      OCR - CACHED  for page 21 of 30
#      OCR - CACHED  for page 22 of 30
#      OCR - CACHED  for page 23 of 30
#      OCR - CACHED  for page 24 of 30
#      OCR - CACHED  for page 25 of 30
#      OCR - CACHED  for page 26 of 30
#      OCR - CACHED  for page 27 of 30
#      OCR - CACHED  for page 28 of 30
#      OCR - CACHED  for page 29 of 30
#      OCR - CACHED  for page 30 of 30
# == 01-281-262_openbaarmakingsbesluit_videoslots_ov.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# ------------------------
# ENUM: 20
# NAME: Fairload Limited
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15151_01-294-550_beslissing_op_bezwaar-ov.pdf',
#   'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep '
#             'worden ingesteld bij de rechtbank.',
#   'title': 'Beslissing op bezwaar Fairload Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15151_01-294-553-openbaarmakingsbesluit_woo_bob_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit beslissing op bezwaar Fairload Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/18/15151_bac_advies_ov.pdf',
#   'title': 'BAC Advies Fairload Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15151_ov_fairload_sanctiebesluit_def.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Fairload Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15151_01-281-217_ov_fairload_openbaarmaking.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit Fairload Limited'}]
# == 15151_01-294-550_beslissing_op_bezwaar-ov.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 15151_01-294-553-openbaarmakingsbesluit_woo_bob_ov.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 15151_bac_advies_ov.pdf ==
#      OCR - CACHED  for page 1 of 22
#      OCR - CACHED  for page 2 of 22
#      OCR - CACHED  for page 3 of 22
#      OCR - CACHED  for page 4 of 22
#      OCR - CACHED  for page 5 of 22
#      OCR - CACHED  for page 6 of 22
#      OCR - CACHED  for page 7 of 22
#      OCR - CACHED  for page 8 of 22
#      OCR - CACHED  for page 9 of 22
#      OCR - CACHED  for page 10 of 22
#      OCR - CACHED  for page 11 of 22
#      OCR - CACHED  for page 12 of 22
#      OCR - CACHED  for page 13 of 22
#      OCR - CACHED  for page 14 of 22
#      OCR - CACHED  for page 15 of 22
#      OCR - CACHED  for page 16 of 22
#      OCR - CACHED  for page 17 of 22
#      OCR - CACHED  for page 18 of 22
#      OCR - CACHED  for page 19 of 22
#      OCR - CACHED  for page 20 of 22
#      OCR - CACHED  for page 21 of 22
#      OCR - CACHED  for page 22 of 22
# == 15151_ov_fairload_sanctiebesluit_def.pdf ==
#      OCR - CACHED  for page 1 of 28
#      OCR - CACHED  for page 2 of 28
#      OCR - CACHED  for page 3 of 28
#      OCR - CACHED  for page 4 of 28
#      OCR - CACHED  for page 5 of 28
#      OCR - CACHED  for page 6 of 28
#      OCR - CACHED  for page 7 of 28
#      OCR - CACHED  for page 8 of 28
#      OCR - CACHED  for page 9 of 28
#      OCR - CACHED  for page 10 of 28
#      OCR - CACHED  for page 11 of 28
#      OCR - CACHED  for page 12 of 28
#      OCR - CACHED  for page 13 of 28
#      OCR - CACHED  for page 14 of 28
#      OCR - CACHED  for page 15 of 28
#      OCR - CACHED  for page 16 of 28
#      OCR - CACHED  for page 17 of 28
#      OCR - CACHED  for page 18 of 28
#      OCR - CACHED  for page 19 of 28
#      OCR - CACHED  for page 20 of 28
#      OCR - CACHED  for page 21 of 28
#      OCR - CACHED  for page 22 of 28
#      OCR - CACHED  for page 23 of 28
#      OCR - CACHED  for page 24 of 28
#      OCR - CACHED  for page 25 of 28
#      OCR - CACHED  for page 26 of 28
#      OCR - CACHED  for page 27 of 28
#      OCR - CACHED  for page 28 of 28
# == 15151_01-281-217_ov_fairload_openbaarmaking.pdf ==
#      OCR - CACHED  for page 1 of 6
#      OCR - CACHED  for page 2 of 6
#      OCR - CACHED  for page 3 of 6
#      OCR - CACHED  for page 4 of 6
#      OCR - CACHED  for page 5 of 6
#      OCR - CACHED  for page 6 of 6
# ------------------------
# ENUM: 21
# NAME: Equinox Dynamic N.V. & Domiseda and Partners s.r.o.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-281-220_sanctiebesluit_2022_openbaar.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_equinox_dynamic_domiseda.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Openbaarmakingsbesluit'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15255_01-293-635_beslissing_op_bezwaar_ov.pdf',
#   'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep '
#             'worden ingesteld bij de rechtbank.',
#   'title': 'Beslissing op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/15255_01-293-637_bac_advies_def_ov.pdf',
#   'title': 'BAC Advies'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-293-636_openbaarmakingsbesluit_woo_bob_15255_ov.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit bij beslissing op bezwaar'}]
# == 01-281-220_sanctiebesluit_2022_openbaar.pdf ==
#      OCR - CACHED  for page 1 of 16
#      OCR - CACHED  for page 2 of 16
#      OCR - CACHED  for page 3 of 16
#      OCR - CACHED  for page 4 of 16
#      OCR - CACHED  for page 5 of 16
#      OCR - CACHED  for page 6 of 16
#      OCR - CACHED  for page 7 of 16
#      OCR - CACHED  for page 8 of 16
#      OCR - CACHED  for page 9 of 16
#      OCR - CACHED  for page 10 of 16
#      OCR - CACHED  for page 11 of 16
#      OCR - CACHED  for page 12 of 16
#      OCR - CACHED  for page 13 of 16
#      OCR - CACHED  for page 14 of 16
#      OCR - CACHED  for page 15 of 16
#      OCR - CACHED  for page 16 of 16
# == openbaarmakingsbesluit_equinox_dynamic_domiseda.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# == 15255_01-293-635_beslissing_op_bezwaar_ov.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 15255_01-293-637_bac_advies_def_ov.pdf ==
#      OCR - CACHED  for page 1 of 12
#      OCR - CACHED  for page 2 of 12
#      OCR - CACHED  for page 3 of 12
#      OCR - CACHED  for page 4 of 12
#      OCR - CACHED  for page 5 of 12
#      OCR - CACHED  for page 6 of 12
#      OCR - CACHED  for page 7 of 12
#      OCR - CACHED  for page 8 of 12
#      OCR - CACHED  for page 9 of 12
#      OCR - CACHED  for page 10 of 12
#      OCR - CACHED  for page 11 of 12
#      OCR - CACHED  for page 12 of 12
# == 01-293-636_openbaarmakingsbesluit_woo_bob_15255_ov.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# ------------------------
# ENUM: 22
# NAME: Bingoal Nederland B.V.
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_bingoal_8_febrauri_2023.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Bingoal Nederland B.V. (9 november 2022)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_bingoal_8_februari_2023.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingbesluit Bingoal Nederland B.V. (9 november 2022)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-289-608_advies_bac_bingoal_nederland_b-v_ov.pdf',
#   'status': 'Tegen dit besluit is beroep ingesteld.',
#   'title': 'Beslissing op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/01-289-607_openbaarmakingsbesluit_ov.pdf',
#   'status': 'Tegen dit besluit is beroep ingesteld.',
#   'title': 'Openbaarmakingsbesluit beslissing op bezwaar'}]
# == sanctiebesluit_bingoal_8_febrauri_2023.pdf ==
#      OCR - CACHED  for page 1 of 18
#      OCR - CACHED  for page 2 of 18
#      OCR - CACHED  for page 3 of 18
#      OCR - CACHED  for page 4 of 18
#      OCR - CACHED  for page 5 of 18
#      OCR - CACHED  for page 6 of 18
#      OCR - CACHED  for page 7 of 18
#      OCR - CACHED  for page 8 of 18
#      OCR - CACHED  for page 9 of 18
#      OCR - CACHED  for page 10 of 18
#      OCR - CACHED  for page 11 of 18
#      OCR - CACHED  for page 12 of 18
#      OCR - CACHED  for page 13 of 18
#      OCR - CACHED  for page 14 of 18
#      OCR - CACHED  for page 15 of 18
#      OCR - CACHED  for page 16 of 18
#      OCR - CACHED  for page 17 of 18
#      OCR - CACHED  for page 18 of 18
# == openbaarmakingsbesluit_bingoal_8_februari_2023.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 01-289-608_advies_bac_bingoal_nederland_b-v_ov.pdf ==
#      OCR - CACHED  for page 1 of 15
#      OCR - CACHED  for page 2 of 15
#      OCR - CACHED  for page 3 of 15
#      OCR - CACHED  for page 4 of 15
#      OCR - CACHED  for page 5 of 15
#      OCR - CACHED  for page 6 of 15
#      OCR - CACHED  for page 7 of 15
#      OCR - CACHED  for page 8 of 15
#      OCR - CACHED  for page 9 of 15
#      OCR - CACHED  for page 10 of 15
#      OCR - CACHED  for page 11 of 15
#      OCR - CACHED  for page 12 of 15
#      OCR - CACHED  for page 13 of 15
#      OCR - CACHED  for page 14 of 15
#      OCR - CACHED  for page 15 of 15
# == 01-289-607_openbaarmakingsbesluit_ov.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 23
# NAME: JOI Gaming Ltd
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_joi_gaming_ltd_10_januari_2023_.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit (10 januari 2023)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_joi_gaming_ltd.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Openbaarmakingsbesluit'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/ov_beslissing_op_bezwaar_joi_gaming_limited.pdf',
#   'status': 'In deze zaak is de beslissing op bezwaar genomen en kan beroep '
#             'worden ingesteld bij de rechtbank.',
#   'title': 'Besluit op bezwaar'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/ov_bac_advies_joi_gaming_limited.pdf',
#   'title': 'BAC-advies'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/ov_openbaarmakingsbesluit_woo_bob_joi_gaming_limited.pdf',
#   'status': 'Tegen dit besluit kan bezwaar worden gemaakt.',
#   'title': 'Openbaarmakingsbesluit bij besluit op bezwaar'}]
# == sanctiebesluit_joi_gaming_ltd_10_januari_2023_.pdf ==
#      OCR - CACHED  for page 1 of 14
#      OCR - CACHED  for page 2 of 14
#      OCR - CACHED  for page 3 of 14
#      OCR - CACHED  for page 4 of 14
#      OCR - CACHED  for page 5 of 14
#      OCR - CACHED  for page 6 of 14
#      OCR - CACHED  for page 7 of 14
#      OCR - CACHED  for page 8 of 14
#      OCR - CACHED  for page 9 of 14
#      OCR - CACHED  for page 10 of 14
#      OCR - CACHED  for page 11 of 14
#      OCR - CACHED  for page 12 of 14
#      OCR - CACHED  for page 13 of 14
#      OCR - CACHED  for page 14 of 14
# == openbaarmakingsbesluit_joi_gaming_ltd.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == ov_beslissing_op_bezwaar_joi_gaming_limited.pdf ==
#      OCR - DOING  for page 1 of 3
#      OCR - DOING  for page 2 of 3
#      OCR - DOING  for page 3 of 3
# == ov_bac_advies_joi_gaming_limited.pdf ==
#      OCR - DOING  for page 1 of 11
#      OCR - DOING  for page 2 of 11
#      OCR - DOING  for page 3 of 11
#      OCR - DOING  for page 4 of 11
#      OCR - DOING  for page 5 of 11
#      OCR - DOING  for page 6 of 11
#      OCR - DOING  for page 7 of 11
#      OCR - DOING  for page 8 of 11
#      OCR - DOING  for page 9 of 11
#      OCR - DOING  for page 10 of 11
#      OCR - DOING  for page 11 of 11
# == ov_openbaarmakingsbesluit_woo_bob_joi_gaming_limited.pdf ==
#      OCR - DOING  for page 1 of 4
#      OCR - DOING  for page 2 of 4
#      OCR - DOING  for page 3 of 4
#      OCR - DOING  for page 4 of 4
# ------------------------
# ENUM: 24
# NAME: Shark77.Ltd
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/beslissing_op_bezwaar_ov.pdf',
# ...
#   'status': 'Tegen dit sanctiebesluit is bezwaar ingediend',
#   'title': 'Sanctiebesluit Onisac\xa0Limited en Mansion Online Casino '
#            'Limited\xa0\xa0(9 april 2019)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/openbaarmakingsbesluit_sanctiebesluit_onisac.pdf',
#   'status': 'Tegen dit besluit is bezwaar ingediend',
#   'title': 'Besluit openbaarmaking sanctiebesluit Onisac\xa0Limited en Mansion '
#            'Online Casino Limited (9 april 2019)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/7845_00_021_663_-_sanctiebesluit_openbaar.pdf',
#   'status': 'In deze zaak is hoger beroep ingesteld en de Raad van State heeft '
#             'www.raadvanstate.nl/uitspraken/zoeken-in-uitspraken/tekst-uitspraak.html?id=96664&summary_only=&q= '
#             'gedaan op 26 september 2018.',
#   'title': 'Sanctiebesluit Onisac Limited en Mansion Online Casino Limited (4 '
#            'november 2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/7845_00_021_664-_openbaarmaking_openbaar.pdf',
#   'status': 'In deze zaak is hoger beroep ingesteld en de Raad van State heeft '
#             'www.raadvanstate.nl/uitspraken/zoeken-in-uitspraken/tekst-uitspraak.html?id=96664&summary_only=&q= '
#             'gedaan op 26 september 2018.',
#   'title': 'Besluit openbaarmaking Onisac Limited en Mansion Online Casino '
#            'Limited\xa0(4 november 2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/7845_-_advies_bac_ov_pdf.pdf',
#   'title': 'Advies BAC\xa0 Onisac Limited en Mansion Online Casino Limited '
#            '(154 kB)\xa0(4 november 2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/7845_-_beslissing_op_bezwaar_ov_pdf.pdf',
#   'status': 'Tegen deze beslissing op bezwaar is inmiddels beroep ingesteld '
#             'bij de rechtbank.',
#   'title': 'Beslissing op bezwaar Onisac Limited en Mansion Online Casino '
#            'Limited'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5465/8051_-_besluit_openbaarmaking_bob_ov_pdf.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking Onisac Limited en Mansion Online Casino '
#            'Limited BOB (4 november 2013)'}]
# == 190625_besluit_openbaarmaking_bob_onisac_openbaar_003.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 190704_bob_en_bac.pdf ==
#      OCR - CACHED  for page 1 of 12
#      OCR - CACHED  for page 2 of 12
#      OCR - CACHED  for page 3 of 12
#      OCR - CACHED  for page 4 of 12
#      OCR - CACHED  for page 5 of 12
#      OCR - CACHED  for page 6 of 12
#      OCR - CACHED  for page 7 of 12
#      OCR - CACHED  for page 8 of 12
#      OCR - CACHED  for page 9 of 12
#      OCR - CACHED  for page 10 of 12
#      OCR - CACHED  for page 11 of 12
#      OCR - CACHED  for page 12 of 12
# == sanctiebesluit_onisac.pdf ==
#      OCR - CACHED  for page 1 of 15
#      OCR - CACHED  for page 2 of 15
#      OCR - CACHED  for page 3 of 15
#      OCR - CACHED  for page 4 of 15
#      OCR - CACHED  for page 5 of 15
#      OCR - CACHED  for page 6 of 15
#      OCR - CACHED  for page 7 of 15
#      OCR - CACHED  for page 8 of 15
#      OCR - CACHED  for page 9 of 15
#      OCR - CACHED  for page 10 of 15
#      OCR - CACHED  for page 11 of 15
#      OCR - CACHED  for page 12 of 15
#      OCR - CACHED  for page 13 of 15
#      OCR - CACHED  for page 14 of 15
#      OCR - CACHED  for page 15 of 15
# == openbaarmakingsbesluit_sanctiebesluit_onisac.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 7845_00_021_663_-_sanctiebesluit_openbaar.pdf ==
#      OCR - CACHED  for page 1 of 30
#      OCR - CACHED  for page 2 of 30
#      OCR - CACHED  for page 3 of 30
#      OCR - CACHED  for page 4 of 30
#      OCR - CACHED  for page 5 of 30
#      OCR - CACHED  for page 6 of 30
#      OCR - CACHED  for page 7 of 30
#      OCR - CACHED  for page 8 of 30
#      OCR - CACHED  for page 9 of 30
#      OCR - CACHED  for page 10 of 30
#      OCR - CACHED  for page 11 of 30
#      OCR - CACHED  for page 12 of 30
#      OCR - CACHED  for page 13 of 30
#      OCR - CACHED  for page 14 of 30
#      OCR - CACHED  for page 15 of 30
#      OCR - CACHED  for page 16 of 30
#      OCR - CACHED  for page 17 of 30
#      OCR - CACHED  for page 18 of 30
#      OCR - CACHED  for page 19 of 30
#      OCR - CACHED  for page 20 of 30
#      OCR - CACHED  for page 21 of 30
#      OCR - CACHED  for page 22 of 30
#      OCR - CACHED  for page 23 of 30
#      OCR - CACHED  for page 24 of 30
#      OCR - CACHED  for page 25 of 30
#      OCR - CACHED  for page 26 of 30
#      OCR - CACHED  for page 27 of 30
#      OCR - CACHED  for page 28 of 30
#      OCR - CACHED  for page 29 of 30
#      OCR - CACHED  for page 30 of 30
# == 7845_00_021_664-_openbaarmaking_openbaar.pdf ==
#      OCR - CACHED  for page 1 of 5
#      OCR - CACHED  for page 2 of 5
#      OCR - CACHED  for page 3 of 5
#      OCR - CACHED  for page 4 of 5
#      OCR - CACHED  for page 5 of 5
# == 7845_-_advies_bac_ov_pdf.pdf ==
#      OCR - CACHED  for page 1 of 17
#      OCR - CACHED  for page 2 of 17
#      OCR - CACHED  for page 3 of 17
#      OCR - CACHED  for page 4 of 17
#      OCR - CACHED  for page 5 of 17
#      OCR - CACHED  for page 6 of 17
#      OCR - CACHED  for page 7 of 17
#      OCR - CACHED  for page 8 of 17
#      OCR - CACHED  for page 9 of 17
#      OCR - CACHED  for page 10 of 17
#      OCR - CACHED  for page 11 of 17
#      OCR - CACHED  for page 12 of 17
#      OCR - CACHED  for page 13 of 17
#      OCR - CACHED  for page 14 of 17
#      OCR - CACHED  for page 15 of 17
#      OCR - CACHED  for page 16 of 17
#      OCR - CACHED  for page 17 of 17
# == 7845_-_beslissing_op_bezwaar_ov_pdf.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 8051_-_besluit_openbaarmaking_bob_ov_pdf.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# ------------------------
# ENUM: 113
# NAME: Café Lucky
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5464/besluit_op_bezwaar_openbaar_cafe_lucky.pdf',
#   'status': 'Tegen de beslissing van de rechtbank is geen hoger beroep '
#             'ingesteld. De uitspraak van de rechtbank is thans onherroepelijk.',
#   'title': 'Besluit op bezwaar inclusief advies BAC Café Lucky (28 maart '
#            '2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5464/besluit_openbaarmaking_bob_openbaar_cafe_lucky.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking Café Lucky\xa0(28 maart 2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5464/7938_-_00_018_637_sanctiebesluit_openbare_versie.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Café Lucky\xa0(14 november 2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5464/7938_besluit_openbaarmaking_cafe_lucky.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Besluit openbaarmaking Cafe Lucky (14 november 2013)'}]
# == besluit_op_bezwaar_openbaar_cafe_lucky.pdf ==
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == besluit_openbaarmaking_bob_openbaar_cafe_lucky.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 7938_-_00_018_637_sanctiebesluit_openbare_versie.pdf ==
#      OCR - CACHED  for page 1 of 16
#      OCR - CACHED  for page 2 of 16
#      OCR - CACHED  for page 3 of 16
#      OCR - CACHED  for page 4 of 16
#      OCR - CACHED  for page 5 of 16
#      OCR - CACHED  for page 6 of 16
#      OCR - CACHED  for page 7 of 16
#      OCR - CACHED  for page 8 of 16
#      OCR - CACHED  for page 9 of 16
#      OCR - CACHED  for page 10 of 16
#      OCR - CACHED  for page 11 of 16
#      OCR - CACHED  for page 12 of 16
#      OCR - CACHED  for page 13 of 16
#      OCR - CACHED  for page 14 of 16
#      OCR - CACHED  for page 15 of 16
#      OCR - CACHED  for page 16 of 16
# == 7938_besluit_openbaarmaking_cafe_lucky.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# ------------------------
# ENUM: 114
# NAME: Star SAT Electronica
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5463/7971_-_00_019_052_sanctiebesluit_openbare_versie.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Sanctiebesluit Star Sat Electronica(935 kB)\xa0( 21 november '
#            '2013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5463/7971_besluit_openbaarmaking_star_sat_electronica.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking Star Sat Electronica (202 kB)\xa0(21 '
#            'november 2013)'}]
# == 7971_-_00_019_052_sanctiebesluit_openbare_versie.pdf ==
#      OCR - CACHED  for page 1 of 14
#      OCR - CACHED  for page 2 of 14
#      OCR - CACHED  for page 3 of 14
#      OCR - CACHED  for page 4 of 14
#      OCR - CACHED  for page 5 of 14
#      OCR - CACHED  for page 6 of 14
#      OCR - CACHED  for page 7 of 14
#      OCR - CACHED  for page 8 of 14
#      OCR - CACHED  for page 9 of 14
#      OCR - CACHED  for page 10 of 14
#      OCR - CACHED  for page 11 of 14
#      OCR - CACHED  for page 12 of 14
#      OCR - CACHED  for page 13 of 14
#      OCR - CACHED  for page 14 of 14
# == 7971_besluit_openbaarmaking_star_sat_electronica.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# ------------------------
# ENUM: 115
# NAME: Call Internet City
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5462/besluit_op_bezwaar_openbaar_call_internet_city.pdf',
#   'status': 'Tegen deze beslissing is geen beroep ingesteld. De beslissing is '
#             'thans onherroepelijk.',
#   'title': 'Besluit op bezwaar Call Internet City\xa0(1 april 2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5462/7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking BOB Call Internet City\xa0\xa0\xa0(10 april '
#            '2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5462/7970_sanctiebesluit_call_internet_city.pdf',
#   'status': 'Tegen dit besluit is bezwaar gemaakt.',
#   'title': 'Sanctiebesluit Call Internet City\xa0(21 november\xa02013)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5462/7970_besluit_openbaarmaking_call_internet_city.pdf',
#   'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans '
#             'onherroepelijk.',
#   'title': 'Besluit openbaarmaking Call Internet City\xa0(21 november 2013)'}]
# == besluit_op_bezwaar_openbaar_call_internet_city.pdf ==
#      OCR - CACHED  for page 1 of 9
#      OCR - CACHED  for page 2 of 9
#      OCR - CACHED  for page 3 of 9
#      OCR - CACHED  for page 4 of 9
#      OCR - CACHED  for page 5 of 9
#      OCR - CACHED  for page 6 of 9
#      OCR - CACHED  for page 7 of 9
#      OCR - CACHED  for page 8 of 9
#      OCR - CACHED  for page 9 of 9
# == 7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# == 7970_sanctiebesluit_call_internet_city.pdf ==
#      OCR - CACHED  for page 1 of 13
#      OCR - CACHED  for page 2 of 13
#      OCR - CACHED  for page 3 of 13
#      OCR - CACHED  for page 4 of 13
#      OCR - CACHED  for page 5 of 13
#      OCR - CACHED  for page 6 of 13
#      OCR - CACHED  for page 7 of 13
#      OCR - CACHED  for page 8 of 13
#      OCR - CACHED  for page 9 of 13
#      OCR - CACHED  for page 10 of 13
#      OCR - CACHED  for page 11 of 13
#      OCR - CACHED  for page 12 of 13
#      OCR - CACHED  for page 13 of 13
# == 7970_besluit_openbaarmaking_call_internet_city.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3
# ------------------------
# ENUM: 116
# NAME: Huizenloterij
# DICTS: [{'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_020_754_kennisgeving_als_bedoeld_in_art_5_50_lid_2_sub_a_awb_openbaar.pdf',
#   'title': 'Beslissing huizenloterij (1571 kB)\xa0(14 januari 2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_020_755_besluit_tot_openbaarmaking_openbaar.pdf',
#   'title': 'Besluit\xa0openbaarmaking huizenloteij (243 kB)\xa0(14 januari '
#            '2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_026_508_en_8140_-_00_026_510_besluit_op_bezwaar_openbaar1.pdf',
#   'status': 'In deze zaak is beroep ingesteld en de rechtbank heeft uitspraak '
#             'gedaan op 17 februari 2015. Het beroep is ongegrond verklaard.',
#   'title': 'Besluit op bezwaar huizenloterij (1076 kB)\xa0(30 april 2014)'},
#  {'pdf_url': 'https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_025_509_en_8140_-_00_026_511_besluit_openbaarmaking_bob_openbaar1.pdf',
#   'status': 'Het hoger beroep tegen de uitspraak van de rechtbank is '
#             'ingetrokken. De uitspraak van de rechtbank is thans definitief.',
#   'title': 'Besluit openbaarmaking BOB\xa0(191 kB)\xa0(30 april 2014)'}]
# == 7982_-_00_020_754_kennisgeving_als_bedoeld_in_art_5_50_lid_2_sub_a_awb_openbaar.pdf ==
#      OCR - CACHED  for page 1 of 26
#      OCR - CACHED  for page 2 of 26
#      OCR - CACHED  for page 3 of 26
#      OCR - CACHED  for page 4 of 26
#      OCR - CACHED  for page 5 of 26
#      OCR - CACHED  for page 6 of 26
#      OCR - CACHED  for page 7 of 26
#      OCR - CACHED  for page 8 of 26
#      OCR - CACHED  for page 9 of 26
#      OCR - CACHED  for page 10 of 26
#      OCR - CACHED  for page 11 of 26
#      OCR - CACHED  for page 12 of 26
#      OCR - CACHED  for page 13 of 26
#      OCR - CACHED  for page 14 of 26
#      OCR - CACHED  for page 15 of 26
#      OCR - CACHED  for page 16 of 26
#      OCR - CACHED  for page 17 of 26
#      OCR - CACHED  for page 18 of 26
#      OCR - CACHED  for page 19 of 26
#      OCR - CACHED  for page 20 of 26
#      OCR - CACHED  for page 21 of 26
#      OCR - CACHED  for page 22 of 26
#      OCR - CACHED  for page 23 of 26
#      OCR - CACHED  for page 24 of 26
#      OCR - CACHED  for page 25 of 26
#      OCR - CACHED  for page 26 of 26
# == 7982_-_00_020_755_besluit_tot_openbaarmaking_openbaar.pdf ==
#      OCR - CACHED  for page 1 of 4
#      OCR - CACHED  for page 2 of 4
#      OCR - CACHED  for page 3 of 4
#      OCR - CACHED  for page 4 of 4
# == 7982_-_00_026_508_en_8140_-_00_026_510_besluit_op_bezwaar_openbaar1.pdf ==
#      OCR - CACHED  for page 1 of 15
#      OCR - CACHED  for page 2 of 15
#      OCR - CACHED  for page 3 of 15
#      OCR - CACHED  for page 4 of 15
#      OCR - CACHED  for page 5 of 15
#      OCR - CACHED  for page 6 of 15
#      OCR - CACHED  for page 7 of 15
#      OCR - CACHED  for page 8 of 15
#      OCR - CACHED  for page 9 of 15
#      OCR - CACHED  for page 10 of 15
#      OCR - CACHED  for page 11 of 15
#      OCR - CACHED  for page 12 of 15
#      OCR - CACHED  for page 13 of 15
#      OCR - CACHED  for page 14 of 15
#      OCR - CACHED  for page 15 of 15
# == 7982_-_00_025_509_en_8140_-_00_026_511_besluit_openbaarmaking_bob_openbaar1.pdf ==
#      OCR - CACHED  for page 1 of 3
#      OCR - CACHED  for page 2 of 3
#      OCR - CACHED  for page 3 of 3

# %%
# A case now looks like:
extracted_cases[0]
# Out:
# ({'name': 'GoldWin Limited',
#   'date_range': [],
#   'money': [],
#   'ecli': [],
#   'case_detail_url': 'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/goldwin-limited/'},
#  [{'title': 'Boetebesluit GoldWin Limited',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/16442_boetebesluit_goldwin.pdf',
#    'status': 'Tegen dit besluit kan bezwaar worden gemaakt.'},
#   {'title': 'Openbaarmakingsbesluit\xa0GoldWin Limited',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/16442_01-299-883_openbaarmakingsbesluit_goldwin.pdf',
#    'status': 'Tegen dit besluit kan bezwaar worden gemaakt.'}],
#  [[[([[899, 189], [1148, 189], [1148, 237], [899, 237]],
#      'Kansspelautoriteit',
#      0.9999867376930548),
#     ([[196, 372], [354, 372], [354, 404], [196, 404]],
#      'OPENBAAR',
#      0.9998503319014985),
#     ([[195, 536], [1431, 536], [1431, 577], [195, 577]],
#      'Besluit van de raad van bestuur van de Kansspelautoriteit als bedoeld in artikel 35a',
#      0.8512861033246355),
#     ([[195, 579], [1343, 579], [1343, 617], [195, 617]],
#      'van de Wet op de kansspelen tot oplegging van een boete aan GoldWin Limited.',
#      0.7059455476051052),
#     ([[196, 654], [386, 654], [386, 686], [196, 686]],
#      'Zaak: 16442',
#      0.9963949098164673),
#     ([[196, 694], [522, 694], [522, 726], [196, 726]],
#      'Kenmerk: 01.299.858',
#      0.7384209769394008),
#     ([[193, 730], [693, 730], [693, 770], [193, 770]],
#      'Openbaarmaking onder kenmerk:',
#      0.7920160361899551),
#     ([[703, 731], [879, 731], [879, 767], [703, 767]],
#      '01.299.854',
#      0.9274855982573947),
#     ([[687, 821], [957, 821], [957, 889], [687, 889]],
#      'Besluit',
#      0.9989029632569253),
#     ([[289, 978], [500, 978], [500, 1042], [289, 1042]],
#      'Inleiding',
#      0.9999800522127363),
#     ([[197, 1091], [217, 1091], [217, 1115], [197, 1115]],
#      '1',
#      0.8698445431615788),
#     ([[273, 1084], [1407, 1084], [1407, 1125], [273, 1125]],
#      'De raad van bestuur van de Kansspelautoriteit (hierna: de Kansspelautoriteit) is',
#      0.8535698006902975),
#     ([[272, 1121], [1360, 1121], [1360, 1169], [272, 1169]],
#      'belast met het toezicht op de naleving van de Wet op de kansspelen (hierna:',
#      0.8362736835239265),
#     ([[276, 1172], [356, 1172], [356, 1204], [276, 1204]],
#      'Wok) .',
#      0.4178038336670872),
#     ([[367, 1167], [1361, 1167], [1361, 1210], [367, 1210]],
#      'De Wok bevat een verbod op het gelegenheid geven tot deelname aan',
#      0.8780359220142557),
#     ([[273, 1209], [1349, 1209], [1349, 1249], [273, 1249]],
#      'kansspelen zonder vergunning. Het handhaven van dit verbod is één van de',
#      0.7242585515848609),
#     ([[272, 1249], [1441, 1249], [1441, 1291], [272, 1291]],
#      'prioriteiten van de Kansspelautoriteit. In dit besluit stelt de Kansspelautoriteit vast',
#      0.612351043239894),
#     ([[273, 1295], [1225, 1295], [1225, 1333], [273, 1333]],
#      'dat GoldWin Limited (hierna: GoldWin) dit verbod heeft overtreden.',
#      0.7184648424174308),
#     ([[1234, 1296], [1440, 1296], [1440, 1328], [1234, 1328]],
#      'Daarom wordt',
#      0.9967961362188834),
#     ([[273, 1332], [1321, 1332], [1321, 1375], [273, 1375]],
#      'haar een boete van € 6.794.000,- opgelegd. De Kansspelautoriteit zet dat',
#      0.7916761553360533),
#     ([[273, 1377], [605, 1377], [605, 1413], [273, 1413]],
#      'hieronder nader uiteen.',
#      0.9913936383664917),
#     ([[198, 1488], [226, 1488], [226, 1524], [198, 1524]],
#      '2',
#      0.9999897480273745),
#     ([[295, 1481], [1161, 1481], [1161, 1525], [295, 1525]],
#      'Onderzoek naar website en betrokkene',
#      0.8426122535085325),
#     ([[197, 1565], [259, 1565], [259, 1601], [197, 1601]],
#      '2.1',
#      0.639621281309525),
#     ([[297, 1563], [509, 1563], [509, 1601], [297, 1601]],
#      'De website',
#      0.9983984203903336),
#     ([[196, 1654], [220, 1654], [220, 1682], [196, 1682]],
#      '2',
#      0.9999995231628986),
#     ([[273, 1650], [1367, 1650], [1367, 1690], [273, 1690]],
#      'De Kansspelautoriteit heeft op 22 december 2022 de website westcasino.com',
#      0.7806571533942954),
#     ([[273, 1688], [1391, 1688], [1391, 1731], [273, 1731]],
#      '(hierna: de website) onderzocht. Daarbij is onder meer het volgende gebleken.',
#      0.9234476259370393),
#     ([[254, 1752], [1122, 1752], [1122, 1803], [254, 1803]],
#      '2.1.1 Gelegenheid tot deelneming aan kansspelen',
#      0.9067977518614343),
#     ([[196, 1806], [220, 1806], [220, 1834], [196, 1834]],
#      '3',
#      0.9999945163801982),
#     ([[275, 1801], [1377, 1801], [1377, 1840], [275, 1840]],
#      'De website was bereikbaar vanaf een Nederlands IP-adres en het was voor de',
#      0.7975943706433667),
#     ([[271, 1844], [1439, 1844], [1439, 1888], [271, 1888]],
#      'toezichthouder mogelijk om met Nederlandse (adres)gegevens een account aan te',
#      0.986736991588045),
#     ([[274, 1886], [1281, 1886], [1281, 1927], [274, 1927]],
#      'maken, daarop in te loggen, een storting te doen en deel te nemen aan',
#      0.5733140835342734),
#     ([[273, 1929], [445, 1929], [445, 1967], [273, 1967]],
#      'kansspelen.',
#      0.9557152791356378),
#     ([[459, 1927], [1377, 1927], [1377, 1968], [459, 1968]],
#      'Er waren geen technische maatregelen genomen om deelnemers',
#      0.7374789401606878),
#     ([[273, 1971], [1109, 1971], [1109, 2009], [273, 2009]],
#      'vanuit Nederland de toegang tot de kansspelen te beletten.',
#      0.7507979817449972),
#     ([[213, 2073], [941, 2073], [941, 2109], [213, 2109]],
#      'Bijlage 15573/01.281.308/01 t/m 15573/01.281.308/04 .',
#      0.5954749425744755),
#     ([[1254, 2150], [1440, 2150], [1440, 2178], [1254, 2178]],
#      'Pagina 1 van 13',
#      0.8537166233457553)],
#    [([[196, 202], [354, 202], [354, 234], [196, 234]],
#      'OPENBAAR',
#      0.9998503319014985),
#     ([[901, 189], [1150, 189], [1150, 237], [901, 237]],
#      'Kansspelautoriteit',
#      0.9999914300996261),
#     ([[1318, 208], [1510, 208], [1510, 234], [1318, 234]],
#      'Kansspelautoriteit',
#      0.9999987074957091),
#     ([[1318, 244], [1388, 244], [1388, 268], [1318, 268]],
#      'Datum',
#      0.9999757429984504),
#     ([[1318, 276], [1474, 276], [1474, 300], [1318, 300]],
#      '10 oktober 2023',
#      0.9973421120582678),
#     ([[1316, 310], [1458, 310], [1458, 334], [1316, 334]],
#      'Ons kenmerk',
#      0.9998587735718668),
#     ([[1318, 344], [1522, 344], [1522, 368], [1318, 368]],
#      '16442/01.299.858 en',
#      0.994131453834111),
#     ([[1316, 376], [1492, 376], [1492, 400], [1316, 400]],
#      '16442/01.299.854',
#      0.6311470340454574),
#     ([[197, 495], [217, 495], [217, 517], [197, 517]], '4', 1.0),
#     ([[273, 489], [523, 489], [523, 527], [273, 527]],
#      'De op de website',
#      0.9514119903864656),
#     ([[521, 484], [1300, 484], [1300, 533], [521, 533]],
#      'aangeboden spellen zijn aan te merken als kansspelen.',
#      0.7094612184007894),
#     ([[1309, 491], [1399, 491], [1399, 527], [1309, 527]],
#      'Op de',
#      0.9990785411339245),
#     ([[273, 527], [1397, 527], [1397, 571], [273, 571]],
#      'website werden casinospelen aangeboden 2 Deze spellen zijn aan te merken als',
#      0.7973982610808389),
#     ([[273, 573], [439, 573], [439, 611], [273, 611]],
#      'kansspelen.',
#      0.9680693497326918),
#     ([[196, 658], [220, 658], [220, 686], [196, 686]],
#      '5',
#      0.9999991655351472),
#     ([[275, 653], [1341, 653], [1341, 695], [275, 695]],
#      'Met deelname aan de kansspelen kan worden meegedongen naar prijzen of',
#      0.9368709892057374),
#     ([[272, 695], [1283, 695], [1283, 739], [272, 739]],
#      'premies. Dat is, naast deelname aan een aangeboden kansspel door de',
#      0.8778629917820296),
#     ([[270, 735], [1387, 735], [1387, 779], [270, 779]],
#      'toezichthouder , onder andere gebleken uit promotionele teksten op de website',
#      0.7915105749198532),
#     ([[273, 781], [947, 781], [947, 821], [273, 821]],
#      'waaruit blijkt dat er geldprijzen te winnen zijn.3',
#      0.7696871368270081),
#     ([[196, 866], [220, 866], [220, 894], [196, 894]], '6', 0.999999880790714),
#     ([[273, 865], [1341, 865], [1341, 903], [273, 903]],
#      'Op de website stond vermeld dat GoldWin is gevestigd in Malta en daar een',
#      0.892541387374648),
#     ([[273, 905], [539, 905], [539, 945], [273, 945]],
#      'vergunning heeft. 4',
#      0.9974174431934825),
#     ([[272, 984], [1424, 984], [1424, 1032], [272, 1032]],
#      'Bij het inschrijvingsproces werd de leeftijd niet zichtbaar geverifieerd voordat het',
#      0.8059063647579514),
#     ([[269, 1025], [736, 1025], [736, 1075], [269, 1075]],
#      'inschrijvingsproces was voltooid.',
#      0.9459289828941686),
#     ([[255, 1094], [1005, 1094], [1005, 1139], [255, 1139]],
#      '2.1.2 Gerichtheid op de Nederlandse markt',
#      0.6645836156677022),
#     ([[194, 1146], [220, 1146], [220, 1172], [194, 1172]], '8', 1.0),
#     ([[274, 1143], [798, 1143], [798, 1176], [274, 1176]],
#      'Zoals benoemd onder randnummer 3',
#      0.9333482207338498),
#     ([[806, 1144], [1328, 1144], [1328, 1176], [806, 1176]],
#      'was de website bereikbaar vanaf een',
#      0.7093965175340073),
#     ([[275, 1183], [1431, 1183], [1431, 1224], [275, 1224]],
#      'Nederlands IP-adres en kon er vanuit Nederland een account worden aangemaakt',
#      0.5608156579233738),
#     ([[274, 1230], [312, 1230], [312, 1258], [274, 1258]],
#      'en',
#      0.999985754394923),
#     ([[316, 1224], [741, 1224], [741, 1267], [316, 1267]],
#      'deelgenomen aan kansspelen.',
#      0.7951952233924264),
#     ([[197, 1313], [217, 1313], [217, 1337], [197, 1337]],
#      '9',
#      0.9476219411819533),
#     ([[273, 1309], [1385, 1309], [1385, 1347], [273, 1347]],
#      'Uit de data van Similarweb blijkt dat de website veelvuldig vanuit Nederland is',
#      0.6336958159946873),
#     ([[273, 1350], [1415, 1350], [1415, 1387], [273, 1387]],
#      'bezocht. 5 Het totale aantal bezoeken van de website, zonder bounce rate, vanuit',
#      0.5794122582801506),
#     ([[275, 1390], [892, 1390], [892, 1431], [275, 1431]],
#      'Nederland over de periode 2022 is 843.132.',
#      0.753502263393079),
#     ([[196, 1478], [240, 1478], [240, 1508], [196, 1508]],
#      '10.',
#      0.995968121884827),
#     ([[273, 1474], [1367, 1474], [1367, 1515], [273, 1515]],
#      'Er is met een Mastercard, gekoppeld aan een Nederlandse bankrekening  een',
#      0.8788166461101344),
#     ([[269, 1514], [999, 1514], [999, 1557], [269, 1557]],
#      'storting van € 20,- op de spelersrekening verricht. 6',
#      0.7798884472637118),
#     ([[196, 1602], [238, 1602], [238, 1634], [196, 1634]],
#      '11 _',
#      0.29007989168167114),
#     ([[275, 1599], [1409, 1599], [1409, 1640], [275, 1640]],
#      'Nederland is niet aangemerkt als uitgesloten land om met bonussen te spelen in',
#      0.5076180600685531),
#     ([[272, 1644], [368, 1644], [368, 1676], [272, 1676]],
#      'artikel',
#      0.999978237452287),
#     ([[375, 1649], [389, 1649], [389, 1671], [375, 1671]],
#      '1',
#      0.996024752435062),
#     ([[397, 1641], [1423, 1641], [1423, 1681], [397, 1681]],
#      'van de General bonus terms and conditions, onderdeel van de algemene',
#      0.5930605324602382),
#     ([[273, 1679], [927, 1679], [927, 1721], [273, 1721]],
#      'voorwaarden (General terms and conditions) .7',
#      0.7971587912142334),
#     ([[196, 1770], [240, 1770], [240, 1800], [196, 1800]],
#      '12.',
#      0.9930095085742336),
#     ([[273, 1764], [1297, 1764], [1297, 1807], [273, 1807]],
#      'De website was internationaal georiënteerd, waaruit medegerichtheid op',
#      0.8801997782640503),
#     ([[275, 1808], [1267, 1808], [1267, 1848], [275, 1848]],
#      'Nederland bleek. De website was beschikbaar in de Engelse taal en de',
#      0.7954021059772006),
#     ([[211, 1913], [599, 1913], [599, 1952], [211, 1952]],
#      'Bijlage 15573/01.281.308/04.',
#      0.6692588561826529),
#     ([[211, 1942], [599, 1942], [599, 1982], [211, 1982]],
#      'Bijlage 15573/01.281.308/06.',
#      0.9996962827341813),
#     ([[211, 1974], [641, 1974], [641, 2012], [211, 2012]],
#      'Bijlage 15573/01.281.308/05/06.',
#      0.9205002162368409),
#     ([[211, 2004], [597, 2004], [597, 2044], [211, 2044]],
#      'Bijlage 15573/01.290.252/01.',
#      0.9639058536030732),
#     ([[211, 2034], [597, 2034], [597, 2074], [211, 2074]],
#      'Bijlage 15573/01.281.308/03.',
#      0.9121582937888402),
#     ([[211, 2064], [599, 2064], [599, 2104], [211, 2104]],
#      'Bijlage 15573/01.281.308/06.',
#      0.9996963916143532),
#     ([[1254, 2108], [1440, 2108], [1440, 2136], [1254, 2136]],
#      'Pagina 2 van 13',
#      0.9471733110156093)],
#    [([[196, 202], [354, 202], [354, 234], [196, 234]],
#      'OPENBAAR',
#      0.9998503319014985),
#     ([[901, 189], [1150, 189], [1150, 237], [901, 237]],
#      'Kansspelautoriteit',
#      0.9999914300996261),
#     ([[1318, 208], [1510, 208], [1510, 234], [1318, 234]],
#      'Kansspelautoriteit',
#      0.9999987074957091),
#     ([[1318, 244], [1388, 244], [1388, 268], [1318, 268]],
#      'Datum',
#      0.9999757429984504),
#     ([[1318, 276], [1474, 276], [1474, 300], [1318, 300]],
#      '10 oktober 2023',
#      0.9973421120582678),
#     ([[1316, 310], [1458, 310], [1458, 334], [1316, 334]],
#      'Ons kenmerk',
#      0.9998587735718668),
#     ([[1318, 344], [1522, 344], [1522, 368], [1318, 368]],
#      '16442/01.299.858 en',
#      0.994131453834111),
#     ([[1318, 376], [1492, 376], [1492, 400], [1318, 400]],
#      '16442/01.299.854',
#      0.9326132975762313),
#     ([[273, 447], [1397, 447], [1397, 487], [273, 487]],
#      'klantenservice was in de Engelse taal, maar werd vertaald naar de Nederlandse',
#      0.7617251400635792),
#     ([[271, 488], [1371, 488], [1371, 529], [271, 529]],
#      'taal. Er was sprake van een internationale topleveldomeinnaam, namelijk een',
#      0.5621011006126149),
#     ([[281, 530], [1354, 530], [1354, 569], [281, 569]],
#      'com-extensie. Volgens de artikel 5.7 van de algemene voorwaarden konden',
#      0.7545411249556948),
#     ([[269, 569], [1293, 569], [1293, 613], [269, 613]],
#      'spelers ook geld opnemen in diverse munteenheden, waaronder de euro',
#      0.9232030486576831),
#     ([[1300, 576], [1382, 576], [1382, 606], [1300, 606]],
#      'en de',
#      0.9999433291385168),
#     ([[273, 615], [583, 615], [583, 653], [273, 653]],
#      '(Amerikaanse) dollar.',
#      0.8265547059334807),
#     ([[256, 684], [346, 684], [346, 716], [256, 716]],
#      '2.1.3',
#      0.9437399669679474),
#     ([[355, 680], [737, 680], [737, 725], [355, 725]],
#      'Last onder dwangsom',
#      0.9151217188424206),
#     ([[196, 728], [240, 728], [240, 758], [196, 758]],
#      '13 .',
#      0.6084696650505066),
#     ([[253, 725], [1387, 725], [1387, 765], [253, 765]],
#      'Op 23 januari 2023 heeft de Kansspelautoriteit een voornemen tot het opleggen',
#      0.6836277551905557),
#     ([[256, 772], [308, 772], [308, 798], [256, 798]],
#      'van',
#      0.999777421602064),
#     ([[315, 766], [1035, 766], [1035, 807], [315, 807]],
#      'een last onder dwangsom aan GoldWin verstuurd. 8',
#      0.7684181080390448),
#     ([[196, 852], [240, 852], [240, 884], [196, 884]],
#      '14.',
#      0.9982256827672259),
#     ([[255, 851], [853, 851], [853, 889], [255, 889]],
#      'Naar aanleiding hiervan is de website op 2',
#      0.8377282186903137),
#     ([[861, 850], [1397, 850], [1397, 890], [861, 890]],
#      'maart 2023 nogmaals onderzocht. De',
#      0.7108819534048026),
#     ([[255, 889], [1371, 889], [1371, 932], [255, 932]],
#      'Kansspelautoriteit heeft onderzocht of er gelegenheid werd gegeven om vanuit',
#      0.9127286581737427),
#     ([[255, 932], [843, 932], [843, 974], [255, 974]],
#      'Nederland deel te nemen aan kansspelen.',
#      0.9264574775149466),
#     ([[853, 933], [1319, 933], [1319, 973], [853, 973]],
#      'Daaruit bleek dat het nog steeds',
#      0.7344093000748255),
#     ([[254, 973], [1413, 973], [1413, 1017], [254, 1017]],
#      'mogelijk was om vanuit Nederland deel te nemen aan kansspelen  zolang niet het',
#      0.7069681171494322),
#     ([[256, 1018], [1198, 1018], [1198, 1050], [256, 1050]],
#      'woord "medewerker" in de naam of in het e-mailadres voorkwam. 9',
#      0.5119431669631979),
#     ([[196, 1102], [242, 1102], [242, 1134], [196, 1134]],
#      '15.',
#      0.9982541009970985),
#     ([[255, 1100], [1439, 1100], [1439, 1140], [255, 1140]],
#      'Op 20 april 2023 heeft de Kansspelautoriteit een last onder dwangsom aan GoldWin',
#      0.8912499441222215),
#     ([[253, 1139], [1351, 1139], [1351, 1183], [253, 1183]],
#      'verstuurd. 10 Daarin is GoldWin opgedragen om het aanbieden van kansspelen',
#      0.7685092728661657),
#     ([[255, 1187], [389, 1187], [389, 1213], [255, 1213]],
#      'waarvoor',
#      0.9999310163680809),
#     ([[471, 1181], [1417, 1181], [1417, 1223], [471, 1223]],
#      'vergunning ingevolge de Wok is verleend, te staken en gestaakt te',
#      0.7544665137101755),
#     ([[255, 1225], [369, 1225], [369, 1261], [255, 1261]],
#      'houden.',
#      0.9992660716826347),
#     ([[198, 1336], [260, 1336], [260, 1368], [198, 1368]],
#      '2.2',
#      0.9930316805839539),
#     ([[297, 1333], [575, 1333], [575, 1371], [297, 1371]],
#      'De betrokkene',
#      0.8857011682413263),
#     ([[196, 1426], [240, 1426], [240, 1458], [196, 1458]],
#      '16.',
#      0.9990429737585005),
#     ([[272, 1424], [1405, 1424], [1405, 1463], [272, 1463]],
#      'Naast de website is ook de betrokkene onderzocht. Blijkens het onderzoek biedt',
#      0.6520098706661913),
#     ([[273, 1467], [1245, 1467], [1245, 1507], [273, 1507]],
#      'GoldWin gelegenheid tot deelname aan de kansspelen op de website.',
#      0.720801177991267),
#     ([[1255, 1467], [1393, 1467], [1393, 1503], [1255, 1503]],
#      'Dat blijkt',
#      0.9756756863642664),
#     ([[273, 1509], [683, 1509], [683, 1547], [273, 1547]],
#      'onder meer uit het volgende.',
#      0.9940217579513964),
#     ([[196, 1594], [240, 1594], [240, 1624], [196, 1624]],
#      '17.',
#      0.9944772856422216),
#     ([[273, 1589], [1413, 1589], [1413, 1631], [273, 1631]],
#      'Op de website staan haar contactgegevens en vergunning vermeld. 11 De website',
#      0.6065470844204243),
#     ([[273, 1631], [1359, 1631], [1359, 1674], [273, 1674]],
#      'waarop de kansspelen worden aangeboden, staat geregistreerd op naam van',
#      0.7003832103566822),
#     ([[272, 1671], [1395, 1671], [1395, 1714], [272, 1714]],
#      'GoldWin. 12 Blijkens de informatie op de website exploiteert GoldWin de website.',
#      0.7824400567551278),
#     ([[273, 1717], [1391, 1717], [1391, 1757], [273, 1757]],
#      'Onderaan de homepagina en in artikel 2.1 van de algemene voorwaarden werd',
#      0.8431370824633527),
#     ([[273, 1755], [1437, 1755], [1437, 1797], [273, 1797]],
#      'GoldWin als eigenaar van de website genoemd. 13 GoldWin vermeldt daarbij tevens',
#     ([[273, 581], [1319, 581], [1319, 624], [273, 624]],
#      '10 juli 2023 een rapport (hierna: het rapport) opgesteld. In het rapport is',
#      0.6306493965497645),
#     ([[272, 621], [1317, 621], [1317, 664], [272, 664]],
#      'geconstateerd dat GoldWin door middel van de website gelegenheid heeft',
#      0.9294582334527051),
#     ([[271, 662], [1399, 662], [1399, 705], [271, 705]],
#      'gegeven om mede te dingen naar prijzen of premies, waarbij de aanwijzing van',
#      0.8239773861193098),
#     ([[273, 703], [1361, 703], [1361, 748], [273, 748]],
#      'de winnaars geschiedt door enige kansbepaling waarop de deelnemers in het',
#      0.8870142740175541),
#     ([[271, 747], [1387, 747], [1387, 789], [271, 789]],
#      'algemeen geen overwegende invloed kunnen uitoefenen, terwijl daarvoor geen',
#      0.6306012937301216),
#     ([[273, 791], [603, 791], [603, 829], [273, 829]],
#      'vergunning is verleend.',
#      0.9695421694945072),
#     ([[613, 787], [1423, 787], [1423, 829], [613, 829]],
#      'Dat is een overtreding van artikel 1, eerste lid, aanhef en',
#      0.9040759144313175),
#     ([[273, 832], [576, 832], [576, 868], [273, 868]],
#      'onder a, van de Wok.',
#      0.9584218308251244),
#     ([[292, 936], [536, 936], [536, 988], [292, 988]],
#      'Zienswijze',
#      0.7490929195399584),
#     ([[196, 1024], [238, 1024], [238, 1056], [196, 1056]],
#      '19',
#      0.9999967125473989),
#     ([[273, 1021], [1420, 1021], [1420, 1061], [273, 1061]],
#      'Bij e-mail van 13 juli 2023 heeft de Kansspelautoriteit GoldWin in de gelegenheid',
#      0.9507941737466983),
#     ([[269, 1062], [1391, 1062], [1391, 1104], [269, 1104]],
#      'gesteld om een zienswijze op het rapport naar voren te brengen. Ze is in die e-',
#      0.8252337031251727),
#     ([[275, 1103], [1383, 1103], [1383, 1145], [275, 1145]],
#      'mail uitgenodigd voor een hoorzitting. In de e-mail is vermeld dat als zij bij de',
#      0.7858205246262283),
#     ([[272, 1145], [1437, 1145], [1437, 1188], [272, 1188]],
#      'hoorzitting wil zijn, zij dat uiterlijk op 8 augustus 2023 moet laten weten. GoldWin',
#      0.7134761351571712),
#     ([[273, 1189], [1379, 1189], [1379, 1230], [273, 1230]],
#      'heeft niet gereageerd. Daarom is van het horen van GoldWin afgezien. 14 In de',
#      0.6378775580679455),
#     ([[273, 1229], [1411, 1229], [1411, 1272], [273, 1272]],
#      'e-mail is GoldWin ook in de gelegenheid gesteld om uiterlijk op 8 augustus 2023',
#      0.6939598346670091),
#     ([[274, 1278], [330, 1278], [330, 1306], [274, 1306]],
#      'een',
#      0.9999620772373462),
#     ([[332, 1269], [833, 1269], [833, 1312], [332, 1312]],
#      'schriftelijke zienswijze in te dienen.',
#      0.9610658266945626),
#     ([[841, 1269], [1373, 1269], [1373, 1314], [841, 1314]],
#      'Daar heeft GoldWin geen gebruik van',
#      0.9568813306696708),
#     ([[270, 1313], [407, 1313], [407, 1353], [270, 1353]],
#      'gemaakt.',
#      0.9905513291873236),
#     ([[198, 1424], [226, 1424], [226, 1460], [198, 1460]],
#      '5',
#      0.9999978542339392),
#     ([[289, 1409], [800, 1409], [800, 1472], [289, 1472]],
#      'Juridische beoordeling',
#      0.9958804749440217),
#     ([[195, 1503], [259, 1503], [259, 1539], [195, 1539]],
#      '5.1',
#      0.9930422648910362),
#     ([[296, 1497], [770, 1497], [770, 1549], [296, 1549]],
#      'De wettelijke bepalingen',
#      0.9999626470750104),
#     ([[196, 1592], [240, 1592], [240, 1624], [196, 1624]],
#      '20 .',
#      0.7032661143270108),
#     ([[273, 1591], [1401, 1591], [1401, 1629], [273, 1629]],
#      'Artikel 1, eerste lid, aanhef en onder a, van de Wok bepaalt dat het verboden is',
#      0.7655631463915367),
#     ([[273, 1631], [1399, 1631], [1399, 1671], [273, 1671]],
#      'om gelegenheid te geven om mede te dingen naar prijzen of premies, indien de',
#      0.8545812719866315),
#     ([[272, 1670], [1439, 1670], [1439, 1714], [272, 1714]],
#      'aanwijzing der winnaars geschiedt door enige kansbepaling waarop de deelnemers',
#      0.7952785694447403),
#     ([[273, 1713], [1435, 1713], [1435, 1758], [273, 1758]],
#      'geen overwegende invloed kunnen uitoefenen, tenzij daarvoor ingevolge deze wet',
#      0.5067530862239107),
#     ([[273, 1759], [605, 1759], [605, 1797], [273, 1797]],
#      'vergunning is verleend.',
#      0.9973501786880048),
#     ([[196, 1842], [238, 1842], [238, 1874], [196, 1874]],
#      '21 _',
#      0.4211271568895602),
#     ([[273, 1839], [1299, 1839], [1299, 1879], [273, 1879]],
#      'Artikel 35a, eerste lid, van de Wok bepaalt dat de Kansspelautoriteit een',
#      0.7297459784092281),
#     ([[273, 1879], [1315, 1879], [1315, 1923], [273, 1923]],
#      'bestuurlijke boete kan opleggen wegens overtreding van onder andere de',
#      0.7326815453376118),
#     ([[273, 1921], [1261, 1921], [1261, 1962], [273, 1962]],
#      'voorschriften vastgesteld bij of krachtens artikel 1, eerste lid, onder a',
#      0.8602362921398197),
#     ([[197, 2069], [221, 2069], [221, 2087], [197, 2087]],
#      '14',
#      0.9999852486348886),
#     ([[225, 2066], [1085, 2066], [1085, 2104], [225, 2104]],
#      'Artikel 7:3, aanhef en onder d, van de Algemene wet bestuursrecht _',
#      0.9109650262948366),
#     ([[1254, 2108], [1440, 2108], [1440, 2138], [1254, 2138]],
#      'Pagina 4 van 13',
#      0.9102978929417154)],
#    [([[196, 202], [354, 202], [354, 234], [196, 234]],
#      'OPENBAAR',
#      0.9998503319014985),
#     ([[901, 189], [1150, 189], [1150, 237], [901, 237]],
#      'Kansspelautoriteit',
#      0.9999914300996261),
#     ([[1318, 208], [1510, 208], [1510, 234], [1318, 234]],
#      'Kansspelautoriteit',
#      0.9999987074957091),
#     ([[1318, 244], [1388, 244], [1388, 268], [1318, 268]],
#      'Datum',
#      0.9999757429984504),
#     ([[1318, 276], [1474, 276], [1474, 300], [1318, 300]],
#      '10 oktober 2023',
#      0.9973421120582678),
#     ([[1318, 310], [1458, 310], [1458, 334], [1318, 334]],
#      'Ons kenmerk',
#      0.8153285987589605),
#     ([[1318, 344], [1522, 344], [1522, 368], [1318, 368]],
#      '16442/01.299.858 en',
#      0.994131453834111),
#     ([[1318, 376], [1492, 376], [1492, 400], [1318, 400]],
#      '16442/01.299.854',
#      0.9326132975762313),
#     ([[196, 450], [240, 450], [240, 480], [196, 480]],
#      '22 .',
#      0.5284591913223267),
#     ([[273, 446], [1433, 446], [1433, 488], [273, 488]],
#      'Artikel 35a, tweede lid, van de Wok bepaalt dat de bestuurlijke boete die voor een',
#      0.7217681355133986),
#     ([[271, 484], [1378, 484], [1378, 533], [271, 533]],
#      'overtreding als bedoeld in het eerste lid kan worden opgelegd ten hoogste het',
#      0.9469100090441789),
#     ([[271, 528], [1422, 528], [1422, 570], [271, 570]],
#      'bedrag van de zesde categorie, bedoeld in artikel 23, vierde lid, van het Wetboek',
#      0.7465834120327084),
#     ([[273, 572], [1399, 572], [1399, 611], [273, 611]],
#      'van Strafrecht of, indien dat meer is, tien procent van de omzet in het boekjaar',
#      0.5409687978527938),
#     ([[273, 611], [759, 611], [759, 653], [273, 653]],
#      'voorafgaande aan de beschikking .',
#      0.8535493446687485),
#     ([[195, 723], [261, 723], [261, 759], [195, 759]],
#      '5.2',
#      0.9951042205524439),
#     ([[292, 710], [1037, 710], [1037, 770], [292, 770]],
#      'Aanleiding voor het bestuurlijk rapport',
#      0.9299730983661885),
#     ([[196, 808], [240, 808], [240, 838], [196, 838]],
#      '23 .',
#      0.9854567050933838),
#     ([[273, 803], [1407, 803], [1407, 846], [273, 846]],
#      'Volgens vaste jurisprudentie kunnen een toezichthoudend bestuursorgaan en de',
#      0.7166645582623176),
#     ([[273, 846], [1433, 846], [1433, 888], [273, 888]],
#      'bij haar werkzame toezichthouders om adequaat toezicht te kunnen uitoefenen op',
#      0.8003863416161586),
#     ([[273, 885], [1351, 885], [1351, 929], [273, 929]],
#      'de naleving van de bij en krachtens de wet gestelde regels, beschikken over',
#      0.7480671451636237),
#     ([[273, 928], [1413, 928], [1413, 970], [273, 970]],
#      'verschillende bevoegdheden die zij steeds en spontaan kunnen uitoefenen. 15 Het',
#      0.6308819947821179),
#     ([[273, 970], [1429, 970], [1429, 1012], [273, 1012]],
#      'aanbieden van online kansspelen die zijn gericht op de Nederlandse markt zonder',
#      0.7222002001237688),
#     ([[273, 1011], [1393, 1011], [1393, 1053], [273, 1053]],
#      'de daarvoor benodigde vergunning was zonder uitzondering verboden en tegen',
#      0.8036317011056028),
#     ([[271, 1055], [1377, 1055], [1377, 1095], [271, 1095]],
#      'illegale aanbieders kan, ook spontaan, door de Kansspelautoriteit handhavend',
#      0.7341480593540337),
#     ([[271, 1092], [586, 1092], [586, 1140], [271, 1140]],
#      'worden opgetreden: 16',
#      0.6436676190498866),
#     ([[196, 1184], [240, 1184], [240, 1214], [196, 1214]],
#      '24 .',
#      0.7292658290458086),
#     ([[273, 1178], [1335, 1178], [1335, 1222], [273, 1222]],
#      'Op basis van haar prioriteringsbeleidı7 heeft de Kansspelautoriteit websites',
#      0.7888242171524547),
#     ([[272, 1219], [1371, 1219], [1371, 1263], [272, 1263]],
#      'aangetroffen die in aanmerking komen voor een onderzoek wegens mogelijke',
#      0.8699008372737314),
#     ([[272, 1261], [1239, 1261], [1239, 1303], [272, 1303]],
#      'overtreding van artikel 1, eerste lid, aanhef en onder a, van de Wok.',
#      0.7196661692401883),
#     ([[1248, 1266], [1418, 1266], [1418, 1298], [1248, 1298]],
#      'Eén van die',
#      0.7148149819616086),
#     ([[274, 1308], [698, 1308], [698, 1340], [274, 1340]],
#      'websites was westcasino.com.',
#      0.9515705610370316),
#     ([[195, 1415], [261, 1415], [261, 1451], [195, 1451]],
#      '5.3',
#      0.9620823266797727),
#     ([[291, 1405], [526, 1405], [526, 1458], [291, 1458]],
#      'Overtreding',
#      0.9993090552297833),
#     ([[196, 1502], [242, 1502], [242, 1534], [196, 1534]],
#      '25.',
#      0.9374212622642517),
#     ([[272, 1500], [1405, 1500], [1405, 1541], [272, 1541]],
#      'Volgens vaste jurisprudentie moet het in artikel 1, eerste lid, aanhef en onder a,',
#      0.6898185884657008),
#     ([[274, 1544], [584, 1544], [584, 1576], [274, 1576]],
#      'van de Wok verboden',
#      0.9845199098680322),
#     ([[598, 1542], [1423, 1542], [1423, 1581], [598, 1581]],
#      '\'gelegenheid geven" ruim worden uitgelegd bij de vraag of',
#      0.4667292752298652),
#     ([[273, 1582], [1411, 1582], [1411, 1623], [273, 1623]],
#      'het via internet aanbieden van kansspelen in Nederland daaronder valt. Het doel',
#      0.6096535414564882),
#     ([[274, 1628], [358, 1628], [358, 1658], [274, 1658]],
#      'en de',
#      0.9758570678298992),
#     ([[357, 1621], [1391, 1621], [1391, 1665], [357, 1665]],
#      'strekking van die bepaling nopen daartoe. 18 Artikel 1, aanhef en onder a,',
#      0.6418182348649474),
#     ([[273, 1665], [1443, 1665], [1443, 1707], [273, 1707]],
#      'van de Wok is overtreden indien het voor een consument uit Nederland mogelijk is',
#      0.5810911174543879),
#     ([[273, 1705], [1413, 1705], [1413, 1747], [273, 1747]],
#      'om door middel van een mede op Nederland gerichte website deel te nemen aan',
#      0.862301309853014),
#     ([[274, 1756], [330, 1756], [330, 1784], [274, 1784]],
#      'een',
#      0.8886867761611938),
#     ([[332, 1747], [1385, 1747], [1385, 1790], [332, 1790]],
#      'onlinekansspel. 19 Het gaat erom of aanbieders van kansspelen via internet',
#      0.8205833395981493),
#     ([[273, 1789], [1337, 1789], [1337, 1831], [273, 1831]],
#      'door de inrichting van hun website de mogelijkheid bieden dat Nederlandse',
#      0.778920940213354),
#     ([[271, 1833], [1269, 1833], [1269, 1874], [271, 1874]],
#      'ingezetenen via hun computer rechtstreeks aan de kansspelen kunnen',
#      0.7837842893008379),
#     ([[195, 1945], [221, 1945], [221, 1965], [195, 1965]],
#      '15',
#      0.9999899690647899),
#     ([[225, 1945], [1407, 1945], [1407, 1981], [225, 1981]],
#      'College van Beroep voor het bedrijfsleven 15 oktober 2019, ECLI:NL:CBB:2019.496, r.o. 4.5.',
#      0.5974877508450895),
#     ([[195, 1975], [221, 1975], [221, 1995], [195, 1995]],
#      '16',
#      0.9999892104238298),
#     ([[223, 1971], [1206, 1971], [1206, 2011], [223, 2011]],
#      'Afdeling 29 juni 2022, ECLI:NL:RVS:2022:1833 (Corona Limited) , r.o. 10.2.)',
#      0.5046523533159694),
#     ([[195, 2007], [219, 2007], [219, 2025], [195, 2025]],
#      '17',
#      0.9999951952626506),
#     ([[224, 2001], [1271, 2001], [1271, 2042], [224, 2042]],
#      'Handhavingsbeleid , Prioritering van handhavingsonderzoeken, Stcrt. 2021, 44765.',
#      0.6413192650099679),
#     ([[195, 2037], [221, 2037], [221, 2055], [195, 2055]],
#      '18',
#      0.9999814554370187),
#     ([[225, 2033], [893, 2033], [893, 2069], [225, 2069]],
#      'HR 18 februari 2005, ECLI:NL:HR:2005:AR4841, r.o',
#      0.8806286040065857),
#     ([[903, 2033], [1139, 2033], [1139, 2071], [903, 2071]],
#      '3.3.2 (Ladbrokes) .',
#      0.6928383738897634),
#     ([[195, 2067], [221, 2067], [221, 2087], [195, 2087]],
#      '19',
#      0.9999967125473989),
#     ([[223, 2062], [1065, 2062], [1065, 2104], [223, 2104]],
#      'Afdeling 22 februari 2017, ECLI:NL:RVS:2017.484 (Bluemay) r.o.',
#      0.5737464353430163),
#     ([[1074, 2070], [1098, 2070], [1098, 2096], [1074, 2096]],
#      '5',
#      0.999999046325911),
#     ([[1254, 2108], [1440, 2108], [1440, 2136], [1254, 2136]],
#      'Pagina 5 van 13',
#      0.9403494577030267)],
#    [([[196, 202], [354, 202], [354, 234], [196, 234]],
#      'OPENBAAR',
#      0.9998503319014985),
#     ([[901, 189], [1150, 189], [1150, 237], [901, 237]],
#      'Kansspelautoriteit',
#      0.9999914300996261),
#     ([[1318, 208], [1510, 208], [1510, 234], [1318, 234]],
#      'Kansspelautoriteit',
#      0.9999987074957091),
#     ([[1318, 244], [1388, 244], [1388, 268], [1318, 268]],
#      'Datum',
#      0.9999757429984504),
#     ([[1318, 276], [1474, 276], [1474, 300], [1318, 300]],
#      '10 oktober 2023',
#      0.9973421120582678),
#     ([[1316, 310], [1458, 310], [1458, 334], [1316, 334]],
#      'Ons kenmerk',
#      0.9998587735718668),
#     ([[1318, 344], [1522, 344], [1522, 368], [1318, 368]],
#      '16442/01.299.858 en',
#      0.994131453834111),
#     ([[1318, 376], [1492, 376], [1492, 400], [1318, 400]],
#      '16442/01.299.854',
#      0.9326132975762313),
#     ([[273, 445], [1269, 445], [1269, 487], [273, 487]],
#      'deelnemen. Volgens vaste jurisprudentie is het daarbij niet relevant of',
#      0.5263466295709242),
#     ([[272, 485], [959, 485], [959, 530], [272, 530]],
#      'kansspelaanbod primair op Nederland is gericht:',
#      0.7216473379749833),
#     ([[971, 489], [1341, 489], [1341, 529], [971, 529]],
#      'Voor de vraag of artikel 1,',
#      0.8027065059853541),
#     ([[272, 529], [1438, 529], [1438, 568], [272, 568]],
#      'aanhef en onder a, van de Wok is overtreden, is namelijk, anders dan [appellante]',
#      0.6682421043598477),
#     ([[273, 568], [1439, 568], [1439, 612], [273, 612]],
#      "hebben aangevoerd, niet relevant of het aanbod primair is gericht op Nederland.'20",
#      0.9279956842221522),
#     ([[196, 658], [240, 658], [240, 688], [196, 688]],
#      '26.',
#      0.9995143829633594),
#     ([[275, 654], [1435, 654], [1435, 696], [275, 696]],
#      'De Kansspelautoriteit heeft vastgesteld dat GoldWin haar website zo had ingericht',
#      0.7332063622633487),
#     ([[272, 691], [1436, 691], [1436, 739], [272, 739]],
#      'dat toegang tot kansspelen werd geboden aan potentiële deelnemers in Nederland',
#      0.7962728052819347),
#     ([[273, 737], [1431, 737], [1431, 780], [273, 780]],
#      'en dat potentiële deelnemers in Nederland via hun computer rechtstreeks aan het',
#      0.8884704618173049),
#     ([[271, 781], [1273, 781], [1273, 819], [271, 819]],
#      'spel konden deelnemen. Potentiële deelnemers konden storten via een',
#      0.770372006539605),
#     ([[274, 823], [1297, 823], [1297, 861], [274, 861]],
#      'Nederlandse bankrekening  in de munteenheid van Nederland (euro) en',
#      0.7552368514205238),
#     ([[273, 861], [1049, 861], [1049, 905], [273, 905]],
#      'vervolgens deelnemen aan de aangeboden kansspelen.',
#      0.9787255129366449),
#     ([[196, 950], [238, 950], [238, 980], [196, 980]],
#      '27_',
#      0.3968566358089447),
#     ([[273, 945], [1419, 945], [1419, 988], [273, 988]],
#      'Verder wijst de Kansspelautoriteit op het volgende. Daadwerkelijk websitebezoek',
#      0.7263128938317046),
#     ([[272, 984], [1298, 984], [1298, 1032], [272, 1032]],
#      'door spelers is geen bestanddeel van de verbodsbepaling. Volgens vaste',
#      0.6973615780471483),
#     ([[269, 1031], [1289, 1031], [1289, 1069], [269, 1069]],
#      'jurisprudentie is niet vereist dat de website en de kansspelen in kwestie',
#      0.6383983268751341),
#     ([[272, 1071], [1431, 1071], [1431, 1113], [272, 1113]],
#      'daadwerkelijk (vanuit Nederland) zijn bezocht dan wel gespeeld. 21 Dat neemt niet',
#      0.5356229024026262),
#     ([[273, 1115], [1231, 1115], [1231, 1153], [273, 1153]],
#      'weg dat ook dit kenmerken zijn van medegerichtheid op Nederland .',
#      0.8140518206749442),
#     ([[196, 1200], [238, 1200], [238, 1230], [196, 1230]],
#      '28_',
#      0.8824552230983468),
#     ([[274, 1200], [328, 1200], [328, 1230], [274, 1230]],
#      'Het',
#      0.9999344095720059),
#     ([[326, 1191], [1280, 1191], [1280, 1239], [326, 1239]],
#      'gebruik van de Engelse taal bij de inrichting van een website en de',
#      0.8471788219888233),
#     ([[273, 1237], [1419, 1237], [1419, 1277], [273, 1277]],
#      'klantenservice vormt ook een kenmerk van medegerichtheid op Nederland. 22 Het',
#      0.8645867781067103),
#     ([[274, 1281], [1351, 1281], [1351, 1321], [274, 1321]],
#      'maakt het voor veel Nederlandse ingezetenen tenslotte mogelijk om via hun',
#      0.7729938728226525),
#     ([[270, 1321], [1409, 1321], [1409, 1363], [270, 1363]],
#      'computer rechtstreeks aan de kansspelen deel te nemen. Immers, Engels is niet',
#      0.6595324869421973),
#     ([[273, 1365], [1413, 1365], [1413, 1403], [273, 1403]],
#      'alleen een internationale taal, maar het is een feit van algemene bekendheid dat',
#      '31.',
#      0.9165725111961365),
#     ([[273, 739], [1425, 739], [1425, 777], [273, 777]],
#      'Dat leidt tot de conclusie dat GoldWin artikel 1, eerste lid, aanhef en onder a, van',
#      0.5208257424590319),
#     ([[274, 782], [632, 782], [632, 814], [274, 814]],
#      'de Wok heeft overtreden.',
#      0.8099850663650484),
#     ([[297, 887], [427, 887], [427, 929], [297, 929]],
#      'Boete',
#      0.999845606997705),
#     ([[197, 969], [259, 969], [259, 1005], [197, 1005]],
#      '6.1',
#      0.9987702369689941),
#     ([[295, 967], [487, 967], [487, 1011], [295, 1011]],
#      'Algemeen',
#      0.9977298038453576),
#     ([[196, 1066], [240, 1066], [240, 1098], [196, 1098]],
#      '32.',
#      0.9975012953422889),
#     ([[273, 1064], [1411, 1064], [1411, 1106], [273, 1106]],
#      'De Kansspelautoriteit neemt bij het bepalen van de hoogte van een op te leggen',
#      0.7036790046743636),
#     ([[273, 1103], [809, 1103], [809, 1146], [273, 1146]],
#      'boete de Boetebeleidsregels in acht. 24',
#      0.879895912017359),
#     ([[196, 1192], [240, 1192], [240, 1222], [196, 1222]],
#      '33 .',
#      0.6615306012780736),
#     ([[273, 1187], [1363, 1187], [1363, 1230], [273, 1230]],
#      'De Kansspelautoriteit ziet zich thans gesteld voor de vraag of en zo ja, welke',
#      0.770657454606375),
#     ([[272, 1234], [460, 1234], [460, 1264], [272, 1264]],
#      'sanctie in dit',
#      0.871710896515602),
#     ([[545, 1230], [703, 1230], [703, 1271], [545, 1271]],
#      'passend is.',
#      0.9512557855969722),
#     ([[196, 1342], [260, 1342], [260, 1374], [196, 1374]],
#      '6.2',
#      0.9927812218666077),
#     ([[296, 1333], [766, 1333], [766, 1383], [296, 1383]],
#      'Ernst en verwijtbaarheid',
#      0.9958118438072542),
#     ([[196, 1432], [240, 1432], [240, 1464], [196, 1464]],
#      '34 .',
#      0.4594413763185445),
#     ([[273, 1427], [1339, 1427], [1339, 1469], [273, 1469]],
#      'Bij de beoordeling van de ernst en verwijtbaarheid van de overtreding door',
#      0.8142612492955763),
#     ([[273, 1472], [1401, 1472], [1401, 1511], [273, 1511]],
#      'GoldWin acht de Kansspelautoriteit met name de volgende omstandigheden van',
#      0.6355037767793916),
#     ([[271, 1512], [378, 1512], [378, 1553], [271, 1553]],
#      'belang .',
#      0.9467714647154681),
#     ([[256, 1584], [346, 1584], [346, 1616], [256, 1616]],
#      '6.2.1',
#      0.7297645181742125),
#     ([[354, 1579], [1422, 1579], [1422, 1627], [354, 1627]],
#      'De gevolgen van onvergund aanbieden van online kansspelen',
#      0.5899686504674999),
#     ([[196, 1628], [240, 1628], [240, 1658], [196, 1658]],
#      '35.',
#      0.8007200360298157),
#     ([[275, 1621], [1390, 1621], [1390, 1666], [275, 1666]],
#      'De kansspelmarkt is geen gewone economische markt. Omdat financieel gewin',
#      0.601926744821948),
#     ([[273, 1663], [1429, 1663], [1429, 1706], [273, 1706]],
#      'kan optreden zonder dat daar een evenredige inspanning tegenover staat, is deze',
#      0.8795339395384472),
# ...
#      'Hier heeft zij geen',
#      0.8552107216403542),
#     ([[241, 1423], [555, 1423], [555, 1465], [241, 1465]],
#      'gebruik van gemaakt.',
#      0.8102788029411336),
#     ([[196, 1534], [226, 1534], [226, 1566], [196, 1566]],
#      '2',
#      0.999940151999668),
#     ([[252, 1526], [556, 1526], [556, 1578], [252, 1578]],
#      'Overwegingen',
#      0.9998025941578784),
#     ([[194, 1616], [220, 1616], [220, 1644], [194, 1644]],
#      '3',
#      0.9860788730443286),
#     ([[245, 1611], [1427, 1611], [1427, 1652], [245, 1652]],
#      'De Kansspelautoriteit maakt besluiten in beginsel openbaar op grond van artikel 3.1',
#      0.7468114548683226),
#     ([[245, 1651], [829, 1651], [829, 1690], [245, 1690]],
#      'van de Wet open overheid (hierna: Woo).',
#      0.689872654331611),
#     ([[196, 1734], [220, 1734], [220, 1758], [196, 1758]],
#      '4',
#      0.9999958276792178),
#     ([[245, 1728], [1433, 1728], [1433, 1770], [245, 1770]],
#      'De Kansspelautoriteit hecht eraan sanctiebesluiten openbaar te maken vanwege het',
#      0.9080168494073221),
#     ([[245, 1768], [1267, 1768], [1267, 1809], [245, 1809]],
#      'maatschappelijk belang om de consument te informeren over dan wel te',
#      0.8507534457752831),
#     ([[245, 1809], [1355, 1809], [1355, 1847], [245, 1847]],
#      'waarschuwen voor bepaalde handelspraktijken van aanbieders van kansspelen',
#      0.6625478119988956),
#     ([[243, 1846], [1149, 1846], [1149, 1886], [243, 1886]],
#      "zonder vergunning en de risico's die consumenten daarbij Iopen_",
#      0.7975067442325279),
#     ([[1158, 1846], [1417, 1846], [1417, 1885], [1158, 1885]],
#      'Daarnaast beoogt',
#      0.9986549554960341),
#     ([[243, 1885], [1427, 1885], [1427, 1923], [243, 1923]],
#      'de Kansspelautoriteit met de openbaarmaking van sanctiebesluiten transparantie te',
#      0.8023785042661077)],
#    [([[194, 202], [354, 202], [354, 234], [194, 234]],
#      'OPENBAAR',
#      0.9986728101627489),
#     ([[893, 189], [1142, 189], [1142, 237], [893, 237]],
#      'Kansspelautoriteit',
#      0.9999906714487399),
#     ([[1315, 207], [1510, 207], [1510, 235], [1315, 235]],
#      'Kansspelautoriteit',
#      0.9999986512998278),
#     ([[1318, 244], [1388, 244], [1388, 268], [1318, 268]],
#      'Datum',
#      0.9999904038318659),
#     ([[1318, 276], [1474, 276], [1474, 300], [1318, 300]],
#      '12 oktober 2023',
#      0.9963416894243465),
#     ([[1316, 310], [1458, 310], [1458, 334], [1316, 334]],
#      'Ons kenmerk',
#      0.9432796479146744),
#     ([[1317, 345], [1499, 345], [1499, 365], [1317, 365]],
#      '16442/ 01.299.882',
#      0.6730417253455693),
#     ([[243, 398], [1143, 398], [1143, 440], [243, 440]],
#      'bieden met betrekking tot het functioneren van zijn organisatie.',
#      0.7098142957552146),
#     ([[1152, 402], [1328, 402], [1328, 434], [1152, 434]],
#      'Ten slotte is',
#      0.9948738434026724),
#     ([[243, 437], [1319, 437], [1319, 479], [243, 479]],
#      'openbaarmaking van belang in verband met de preventieve werking die van',
#      0.9548807254491445),
#     ([[243, 477], [1403, 477], [1403, 520], [243, 520]],
#      'sanctiebesluiten kan uitgaan naar andere ondernemingen en natuurlijke personen.',
#      0.9426153950793931),
#     ([[196, 566], [222, 566], [222, 594], [196, 594]],
#      '5.',
#      0.9990082601659968),
#     ([[245, 561], [1412, 561], [1412, 603], [245, 603]],
#      'De Kansspelautoriteit acht openbaarmaking ook in dit concrete geval in het belang',
#      0.8440392808947123),
#     ([[246, 607], [1406, 607], [1406, 640], [246, 640]],
#      'van consumenten die aldus kennis kunnen nemen van het feit dat ten aanzien van',
#      0.5661277875325471),
#     ([[243, 643], [1205, 643], [1205, 687], [243, 687]],
#      'GoldWin is vastgesteld dat zij in strijd heeft gehandeld met artikel 1',
#      0.9811929618951237),
#     ([[1218, 650], [1364, 650], [1364, 682], [1218, 682]],
#      'eerste lid,',
#      0.808211074230671),
#     ([[243, 686], [1343, 686], [1343, 730], [243, 730]],
#      'onder a, van de Wok en dat de Kansspelautoriteit hiertegen heeft opgetreden.',
#      0.8380642906317123),
#     ([[194, 776], [222, 776], [222, 804], [194, 804]],
#      '6.',
#      0.21525848645248455),
#     ([[245, 773], [1151, 773], [1151, 811], [245, 811]],
#      'De Kansspelautoriteit neemt hierbij het volgende in aanmerking .',
#      0.7132976533651605),
#     ([[196, 860], [220, 860], [220, 886], [196, 886]],
#      '7',
#      0.9999995231628986),
#     ([[245, 851], [1419, 851], [1419, 895], [245, 895]],
#      'De Afdeling bestuursrechtspraak van de Raad van State (hierna: de Afdeling) heeft',
#      0.8488177461071507),
#     ([[243, 897], [1389, 897], [1389, 937], [243, 937]],
#      "bij uitspraak van 10 november 2010, ECLI:NL:RVS:2010.B03468, bepaald: 'Het",
#      0.5300601012776003),
#     ([[245, 937], [1407, 937], [1407, 977], [245, 977]],
#      'boetebesluit is een bevoegd genomen besluit in het kader van een aan het college',
#      0.777132758685604),
#     ([[245, 977], [1337, 977], [1337, 1019], [245, 1019]],
#      'door de wetgever toegekende taak om toezicht te houden op de naleving van',
#      0.9585949402128059),
#     ([[245, 1021], [1377, 1021], [1377, 1062], [245, 1062]],
#      'regelgeving en de daarmee samenhangende bevoegdheid om handhavend op te',
#      0.8661861719254788),
#     ([[245, 1065], [895, 1065], [895, 1103], [245, 1103]],
#      'treden tegen overtreding van die regelgeving.',
#      0.49214173742443396),
#     ([[902, 1066], [1214, 1066], [1214, 1096], [902, 1096]],
#      'In het kader van deze',
#      0.7897494275651554),
#     ([[245, 1102], [1307, 1102], [1307, 1146], [245, 1146]],
#      'toezichthoudende taak past dat boetebesluiten worden gepubliceerd; zodat',
#      0.9028705334064256),
#     ([[245, 1143], [1235, 1143], [1235, 1187], [245, 1187]],
#      'bekendheid wordt gegeven aan de wijze van uitvoering van deze taak',
#      0.5682247316752982),
#     ([[1246, 1147], [1429, 1147], [1429, 1187], [1246, 1187]],
#      '(overweging',
#      0.9999060781597237),
#     ([[246, 1192], [314, 1192], [314, 1224], [246, 1224]],
#      '2.5).',
#      0.3614015327387017),
#     ([[194, 1276], [222, 1276], [222, 1304], [194, 1304]],
#      '8.',
#      0.39848045612562155),
#     ([[245, 1270], [1429, 1270], [1429, 1312], [245, 1312]],
#      'Ten aanzien van de vereiste belangenafweging bepaalde de Afdeling in voornoemde',
#      0.8460448108431841),
#     ([[242, 1309], [1377, 1309], [1377, 1354], [242, 1354]],
#      "uitspraak: 'Van een onevenredige benadeling zal in gevallen als de onderhavige",
#      0.5893892096690987),
#     ([[246, 1358], [588, 1358], [588, 1388], [246, 1388]],
#      'naar het oordeel van de',
#      0.6382802585795553),
#     ([[589, 1351], [1433, 1351], [1433, 1396], [589, 1396]],
#      'Afdeling sprake kunnen zijn als het boetebesluit uiteindelijk',
#      0.9298302897667985),
#     ([[245, 1398], [1309, 1398], [1309, 1437], [245, 1437]],
#      'in rechte geen stand houdt en de betrokken rechtspersoon ten onrechte als',
#      0.742672047504464),
#     ([[245, 1435], [1385, 1435], [1385, 1478], [245, 1478]],
#      'overtreder kenbaar is gemaakt. Of sprake is van onevenredige benadeling hangt',
#      0.7398323727981511),
#     ([[245, 1481], [1211, 1481], [1211, 1519], [245, 1519]],
#      'dan af van een oordeel over de rechtmatigheid van het boetebesluit.',
#      0.7523706640238503),
#     ([[194, 1566], [220, 1566], [220, 1594], [194, 1594]],
#      '9',
#      0.9999943971712391),
#     ([[245, 1561], [1431, 1561], [1431, 1603], [245, 1603]],
#      'De Kansspelautoriteit is van oordeel dat er geen aanleiding is te veronderstellen dat',
#      0.853349949412104),
#     ([[245, 1605], [961, 1605], [961, 1645], [245, 1645]],
#      'het sanctiebesluit in rechte geen stand zal houden.',
#      0.8989123039255449),
#     ([[969, 1605], [1315, 1605], [1315, 1641], [969, 1641]],
#      'Naar het oordeel van de',
#      0.8247423423066674),
#     ([[245, 1645], [1425, 1645], [1425, 1689], [245, 1689]],
#      'Kansspelautoriteit is afdoende aangetoond dat er sprake is van een overtreding van',
#      0.7963667153741915),
#     ([[244, 1692], [364, 1692], [364, 1722], [244, 1722]],
#      'artikel 1',
#      0.9967944776055983),
#     ([[379, 1688], [980, 1688], [980, 1725], [379, 1725]],
#      'eerste lid, aanhef en onder a, van de Wok.',
#      0.8390164150952375),
#     ([[195, 1772], [1384, 1772], [1384, 1812], [195, 1812]],
#      '10. Van andere belangen of omstandigheden, op grond waarvan zou moeten worden',
#      0.7113634465135554),
#     ([[243, 1810], [1221, 1810], [1221, 1853], [243, 1853]],
#      'afgezien van openbaarmaking, is de Kansspelautoriteit niet gebleken.',
#      0.7945614002229764)],
#    [([[194, 202], [354, 202], [354, 234], [194, 234]],
#      'OPENBAAR',
#      0.9986728101627489),
#     ([[893, 189], [1142, 189], [1142, 237], [893, 237]],
#      'Kansspelautoriteit',
#      0.9999906714487399),
#     ([[1315, 207], [1510, 207], [1510, 235], [1315, 235]],
#      'Kansspelautoriteit',
#      0.9999986512998278),
#     ([[1318, 244], [1388, 244], [1388, 268], [1318, 268]],
#      'Datum',
#      0.9999904038318659),
#     ([[1318, 276], [1474, 276], [1474, 300], [1318, 300]],
#      '12 oktober 2023',
#      0.9963416894243465),
#     ([[1316, 310], [1458, 310], [1458, 334], [1316, 334]],
#      'Ons kenmerk',
#      0.9432796479146744),
#     ([[1317, 345], [1499, 345], [1499, 365], [1317, 365]],
#      '16442/ 01.299.882',
#      0.6730417253455693),
#     ([[196, 408], [236, 408], [236, 436], [196, 436]],
#      '11',
#      0.9999808653843955),
#     ([[245, 407], [1413, 407], [1413, 445], [245, 445]],
#      'De Kansspelautoriteit wijst er verder op dat de namen van natuurlijke personen en',
#      0.9195662833431444),
#     ([[244, 452], [448, 452], [448, 482], [244, 482]],
#      'de namen van',
#      0.6234151428466771),
#     ([[452, 447], [1259, 447], [1259, 488], [452, 488]],
#      'rechtspersonen die in het onderzoek zijn genoemd, maar',
#      0.7789698279731632),
#     ([[1264, 450], [1378, 450], [1378, 480], [1264, 480]],
#      'van wie',
#      0.8462563364735517),
#     ([[241, 486], [1401, 486], [1401, 531], [241, 531]],
#      'geen overtreding is vastgesteld; nimmer openbaar worden gemaakt. Verwijzingen',
#      0.7875466241502445),
#     ([[245, 528], [1381, 528], [1381, 570], [245, 570]],
#      'naar namen die genoemd worden in jurisprudentie en reeds openbaar gemaakte',
#      0.8332323786268794),
#     ([[243, 572], [1055, 572], [1055, 611], [243, 611]],
#      'besluiten van de Kansspelautoriteit vallen hier niet onder .',
#      0.613758452309033),
#     ([[196, 678], [226, 678], [226, 712], [196, 712]],
#      '3',
#      0.9999967813517721),
#     ([[255, 673], [401, 673], [401, 715], [255, 715]],
#      'Besluit',
#      0.9999976119846353),
#     ([[195, 765], [1213, 765], [1213, 804], [195, 804]],
#      '12.Op grond van het voorgaande zal de Kansspelautoriteit overgaan tot',
#      0.8084084072949401),
#     ([[243, 807], [1377, 807], [1377, 845], [243, 845]],
#      'openbaarmaking van het besluit van 10 oktober 2023 met kenmerk 01.299.858.',
#      0.7175653430740893),
#     ([[245, 845], [1233, 845], [1233, 888], [245, 888]],
#      'Tevens zal dit besluit tot openbaarmaking openbaar worden gemaakt.',
#      0.6019446018820145),
#     ([[195, 927], [1387, 927], [1387, 970], [195, 970]],
#      '13. In de openbaar te maken besluiten blijft vermelding van de namen van alle in de',
#      0.7812290138474907),
#     ([[243, 971], [939, 971], [939, 1013], [243, 1013]],
#      'zaak betrokken natuurlijke personen achterwege.',
#      0.8719674207256655),
#     ([[949, 972], [1202, 972], [1202, 1013], [949, 1013]],
#      'Daarnaast blijven',
#      0.9887113708632931),
#     ([[243, 1015], [1085, 1015], [1085, 1054], [243, 1054]],
#      'bedrijfsvertrouwelijke gegevens buiten de openbaarmaking .',
#      0.7906082392835522),
#     ([[1093, 1014], [1401, 1014], [1401, 1053], [1093, 1053]],
#      'Ook blijft achterwege',
#      0.998656891734572),
#     ([[243, 1055], [1345, 1055], [1345, 1096], [243, 1096]],
#      'openbaarmaking van de namen van rechtspersonen ten aanzien van wie geen',
#      0.7837238419727584),
#     ([[242, 1093], [1133, 1093], [1133, 1138], [242, 1138]],
#      'overtreding wordt vastgesteld en geen sanctie wordt opgelegd.',
#      0.889292207797067),
#     ([[195, 1177], [1217, 1177], [1217, 1219], [195, 1219]],
#      '14. Openbaarmaking geschiedt door middel van publicatie op de website',
#      0.6840430606039398),
#     ([[244, 1222], [1439, 1222], [1439, 1262], [244, 1262]],
#      'www.kansspelautoriteit.nl op de datum en tijd zoals genoemd in de aanbiedingsbrief',
#      0.7778309419847935),
#     ([[243, 1266], [440, 1266], [440, 1303], [243, 1303]],
#      'bij dit besluit.',
#      0.9603280789927434),
#     ([[195, 1350], [591, 1350], [591, 1390], [195, 1390]],
#      'Den Haag, 12 oktober 2023',
#      0.9592529920064357),
#     ([[195, 1455], [389, 1455], [389, 1491], [195, 1491]],
#      'Hoogachtend,',
#      0.9831212024841917),
#     ([[195, 1520], [865, 1520], [865, 1559], [195, 1559]],
#      'De raad van bestuur van de Kansspelautoriteit,',
#      0.5830266164483562),
#     ([[196, 1555], [395, 1555], [395, 1588], [196, 1588]],
#      'namens deze,',
#      0.9683910583023618),
#     ([[196, 1628], [252, 1628], [252, 1658], [196, 1658]],
#      'W.g-',
#      0.8370715975761414),
#     ([[196, 1694], [244, 1694], [244, 1720], [196, 1720]],
#      'mr.',
#      0.9675708850492059),
#     ([[254, 1690], [452, 1690], [452, 1722], [254, 1722]],
#      'Laurence M.A.',
#      0.5595495595536559),
#     ([[462, 1690], [598, 1690], [598, 1722], [462, 1722]],
#      'Gimbrere',
#      0.9999933829357155),
#     ([[197, 1719], [897, 1719], [897, 1763], [197, 1763]],
#      'Hoofd afdeling Juridische Zaken en Vergunningen',
#      0.8325179478356556),
#     ([[196, 1826], [310, 1826], [310, 1854], [196, 1854]],
#      'Bezwaar',
#      0.7832775259735376),
#     ([[196, 1851], [1340, 1851], [1340, 1890], [196, 1890]],
#      'Tegen dit besluit kan degene wiens belang rechtstreeks bij dit besluit is betrokken, binnen',
#      0.5344009667712517),
#     ([[1345, 1861], [1389, 1861], [1389, 1881], [1345, 1881]],
#      'zes',
#      0.9961567417218757),
#     ([[197, 1881], [1421, 1881], [1421, 1920], [197, 1920]],
#      'weken na de dag van bekendmaking van dit besluit een gemotiveerd bezwaarschrift indienen bij',
#      0.677113424645002)],
#    [([[194, 202], [354, 202], [354, 234], [194, 234]],
#      'OPENBAAR',
#      0.9986728101627489),
#     ([[893, 189], [1142, 189], [1142, 237], [893, 237]],
#      'Kansspelautoriteit',
#      0.9999906714487399),
#     ([[1315, 207], [1510, 207], [1510, 235], [1315, 235]],
#      'Kansspelautoriteit',
#      0.9999986512998278),
#     ([[1318, 244], [1388, 244], [1388, 268], [1318, 268]],
#      'Datum',
#      0.9999904038318659),
#     ([[1318, 276], [1474, 276], [1474, 300], [1318, 300]],
#      '12 oktober 2023',
#      0.9963416894243465),
#     ([[1316, 310], [1458, 310], [1458, 334], [1316, 334]],
#      'Ons kenmerk',
#      0.9432796479146744),
#     ([[1317, 345], [1499, 345], [1499, 365], [1317, 365]],
#      '16442/ 01.299.882',
#      0.6730417253455693),
#     ([[195, 399], [1385, 399], [1385, 435], [195, 435]],
#      'de Kansspelautoriteit;, afdeling Juridische Zaken en Vergunningen, Postbus 298, 2501 CG Den',
#      0.4550773339242448),
#     ([[195, 431], [269, 431], [269, 463], [195, 463]],
#      'Haag.',
#      0.9890495429048181),
#     ([[196, 489], [489, 489], [489, 525], [196, 525]],
#      'Voorlopiqe_voorziening',
#      0.7318990378626244),
#     ([[196, 524], [294, 524], [294, 552], [196, 552]],
#      'Let wel_',
#      0.9648735572536916),
#     ([[306, 522], [1158, 522], [1158, 554], [306, 554]],
#      'het instellen van bezwaar schort de werking van dit besluit niet op.',
#      0.8384574090681647),
#     ([[197, 549], [1429, 549], [1429, 587], [197, 587]],
#      'Kunt u de beslissing op uw bezwaarschrift niet afwachten vanwege een spoedeisend belang? Dan',
#      0.6664654281586738),
#     ([[196, 583], [1346, 583], [1346, 616], [196, 616]],
#      'kunt u bij de sector bestuursrecht van de rechtbank in uw arrondissement een verzoek om',
#      0.7704498017680952),
#     ([[195, 610], [609, 610], [609, 649], [195, 649]],
#      'voorlopige voorziening indienen.',
#      0.6354881902447854)]]])

# %% [markdown]
# ### Analyse raw OCR output into structured text
#
# Take those OCR fragments and separate off headers, group into paragraphs and such.
#
# This is separate from the above because with a bit of tweaking specific to this document layout, we can give cleaner output.
#
# It's also long because a bunch of specific augmentation goes on here.
# It's separate so that we can tweak and re-run it easily.
#
# It's still little more than a bunch of math on numbers, so takes less than a minute.

# %%
# a bunch of helpers
from wetsuite.extras.ocr import doc_extent, page_fragment_filter, bbox_max_x, bbox_max_y, bbox_min_x, bbox_min_y, bbox_height

verbose = False

dataset_cases = [] # distinct name, has a different structure

for case_i, case_tuple in enumerate(extracted_cases):
    case_dict, case_doc_dicts, ocrdata = case_tuple
    case_name = case_dict['name']

    print( 'CASE %d: %s'%(case_i, case_name) )

    case_docs = [] #this part's main output, becomes a dict per case (with keys like 'url', 'pages')
    assert len(case_doc_dicts) == len(ocrdata)

    case_doc_dates = set() # or maybe count?

    ## for each document, analyze the OCR fragments and sort it into more directly useful data
    for doc_i in range(len(case_doc_dicts)): #ocrdata should have the same length
        pdf_dict = case_doc_dicts[doc_i]
        doc_ocr  = ocrdata[doc_i]


        pdf_url = pdf_dict['pdf_url']
        print( '  DOC %d:  %s'%(doc_i,   wetsuite.helpers.format.url_basename( pdf_url ) ) )


        doc_pages = [] # the main output for a document - a list of dicts that each detail a page
        doc_dates = [] # picks out dates from the headers

        doc_wide_extent = doc_extent( doc_ocr ) # the area outside there is no text at all, throughout all of the page's document
        #print( 'doc_min_x, doc_max_x, doc_min_y, doc_max_y', extent )

        for page_i, page in enumerate( doc_ocr ): # page is now all text framents on a page, a list of all (bbox, text, cert) 
            if verbose:
                print( '   PAGE %s ---------------------------------------------------------------------------'%(page_i) )

            ### Determine margins
            # so that we can have logic that extract text that hopefully flows between pages
            head_y_ary, foot_y_ary = [], []
            # - Top margin defined by lowest box extent of 
            #    - "Kansspenautoriteit" (not really necessary)
            #    - "OPENBAAR"
            #    - "Ons kenmerk" plus one extra box's worth
            matches = page_fragment_filter( page, r'^Kansspelautoriteit$', q_max_y=0.25, extent=doc_wide_extent )
            for bbox, text, cert in matches:
                #print ('    [page %d] Kansspelautoriteit MATCH: %s %s %s'%(page_i, bbox, text, cert))
                head_y_ary.append( bbox_max_y(bbox) )
            matches = page_fragment_filter( page, r'^OPENBAAR$', q_max_y=0.3, q_max_x=0.35, extent=doc_wide_extent )
            for bbox, text, cert in matches:
                #print ('    [page %d] OPENBAAR MATCH: %s %s %s'%(page_i, bbox, text, cert))
                head_y_ary.append( bbox_max_y(bbox) )
            matches = page_fragment_filter( page, r'Ons kenmerk', q_max_y=0.25, extent=doc_wide_extent )
            for bbox, text, cert in matches:
                #print ('    [page %d] Ons kenmerk MATCH: %s %s %s'%(page_i, bbox, text, cert))
                head_y_ary.append( bbox_max_y(bbox) + 1.2* bbox_height(bbox) ) # we expect one more line of the same height below it (times fudge factor, for expected whitespace)
            
            # - Bottom margin defined by highest box y of "agina [0-9]+ van [0-9]+" in the bottom right
            matches = page_fragment_filter( page, r'Pagina', q_min_x=0.7, q_min_y=0.75, extent=doc_wide_extent ) # the rest, e.g. (\s*[0-9]+\s*van\s*[0-9]+)?, is optional because it's sometimes detected separately, or not at all
            for bbox, text, cert in matches: # 
                #print ('    [page %d] Pagina MATCH: %s %s %s'%(page_i, bbox, text, cert))
                foot_y_ary.append( bbox_min_y(bbox)  )
            if len(foot_y_ary)==0: # look harder for page - a lone number to the bottom right that matches roughly with the page number we think it is is probably also the page number
                pages_around = '|'.join( str(pag)  for pag in range(page_i-1, page_i+2) )
                matches = page_fragment_filter( page, r'^(%s)$'%pages_around, q_min_y=0.75, q_min_x=0.7, extent=doc_wide_extent )
                for bbox, text, cert in matches: # (\s*[0-9]+\s*van\s*[0-9]+)?
                    #print ('    [page %d] Bare pagina MATCH: %s %s %s'%(page_i, bbox, text, cert))
                    foot_y_ary.append( bbox_min_y(bbox)  )

            if len(head_y_ary)==0:
                head_bot_y = None
            else:
                head_bot_y = max(head_y_ary)

            if len(foot_y_ary)==0:
                foot_top_y = None
            else:
                foot_top_y = min(foot_y_ary)

            if verbose:
                print("    page head_y: ", head_bot_y) # TODO: call this head_bot_y (and probably rename h)
                print("    page foot_y: ", foot_top_y) # TODO: call this foot_top_y


            ### Figure out some things about the page
            ## list-iten X position
            # Most of these documents have numbering on their headers and paragraphs
            # these list-iten numbers at the start of lines are not detected consistently by OCR,
            # nor are they linguistic information, so attempt to remove them.
            # We like to be sure (to not remove such things from actual text), so 
            lnum_righty = []
            matches = page_fragment_filter( page, r'^[0-9.]+$', q_max_x=0.2, q_min_y=head_bot_y,q_max_y=foot_top_y, extent=doc_wide_extent ) 
            for bbox, text, cert in matches:
                if verbose:
                    print ('    [page %d] LI NUM MATCH: %s %s %s'%(page_i, bbox, text, cert))
                lnum_righty.append( bbox_max_x(bbox)  )            
            if len(lnum_righty) < 4: # not sure enough - be more conservative
                lnum_righty = doc_wide_extent[0] + 20 # TODO: avoid that constant
            else:
                lnum_righty = max(lnum_righty)

            ## average box size
            box_heights = []
            for bbox, text, cert in page:
                box_heights.append( bbox_height( bbox ) )
            median_boxheight = numpy.median(box_heights)
            #print(box_heights)
            #print("Median bbox height: %d"%median_boxheight)


            ### Group and process fragments   (in passes, to make logic like 'is this the last thing in the body' easier)
            # - separate into head, body, foot
            # - polish the body, e.g. 
            #   'is this the last thing on the page AFTER we removed the footer' logic easier
            #   replace '-' at end of paragraph with '.'

            page_contents = {
                'head_fragments':[],
                'body_fragments':[],
                'misc_fragments':[],
                'foot_fragments':[],
                'body_text':[],
            }


            ## Sort fragments into header, body, and footer
            prev_topy, prev_boty = 0,0 
            for frag_i, (bbox, text, cert) in enumerate(page):
                topleft, topright, botright, botleft = bbox
                topy, boty = topleft[1], botright[1]

                text = re.sub('[_-]\s*$','.', text) # mistaken for period sometimes. Could be more thorough, but this is a start

                if head_bot_y is not None and topy < head_bot_y :
                    page_contents['head_fragments'].append( (bbox, text, cert) )

                elif foot_top_y is not None and boty > foot_top_y: # CONSIDER: also remove numbers from left of boxes that start at the -- IF we think it's such a number.
                    page_contents['foot_fragments'].append( (bbox, text, cert) )

                elif wetsuite.helpers.strings.is_numeric( text) and topleft[0] < lnum_righty+5:
                    pass
                    #page_contents['misc_fragments'].append( (bbox, text, cert) )

                else: #probably useful body
                    #print( '      %6s  %12s %-12s  fs:%-5s  %s '%( keep_ignore, topleft, botright, boxheight, text ) )
                    page_contents['body_fragments'].append( (bbox, text, cert) )

                    case_dict['money'].extend( find_eur_money(text, minimum=5001) )

                prev_topy, prev_boty = topy, boty

            ## Header stuff. Little smartness yet.
            head_text = [] 
            for body_frag_i, (bbox, text, cert) in enumerate(page_contents['head_fragments']):
                head_text.append(text)

                _, dts = wetsuite.helpers.date.find_dates_in_text(text)
                for dt in dts:
                    if dt is not None:
                        case_doc_dates.add( dt )
                        doc_dates.append( wetsuite.helpers.date.format_date(dt) )
                # CONSIDER: getting out kenmerk


            foot_text = [] 
            for body_frag_i, (bbox, text, cert) in enumerate(page_contents['foot_fragments']):
                foot_text.append(text)

            ## Figure out body's paragraphs, seprate where sensible
            body_text = [] 
            temp_par  = []
            prev_topy, prev_boty, prev_boxheight, prev_text = 0,0, 0, ''
            def flush_par():
                global temp_par, body_text
                if len(temp_par)>0:
                    body_text.append( ' '.join(temp_par) )
                    temp_par=[] 


            for body_frag_i, (bbox, text, cert) in enumerate(page_contents['body_fragments']):
                topleft, topright, botright, botleft = bbox
                topy, boty = topleft[1], botright[1]
                boxheight = bbox_height(bbox) # is a good indicator of font size

                same_line            = (boty - prev_boty) < 0.6*boxheight
                current_line_shorter = len(text) < 0.5 * len(prev_text) 
                prev_line_shorter    = 0.5 * len(prev_text) < len(text)

                #if topy-prev_boty > -5:
                #    print( "                                                   [ydist %d (%s->%s)]"%(topy-prev_boty, prev_boty, topy) )

                #if topy < prev_boty by roughly boxheight it's the same line

                if topy < prev_boty-200:
                    if verbose:
                        print( "LARGE DECREASE IN Y HUH?")
                        print( '      %12s %-12s  fs:%-5s  %s '%( topleft, botright, boxheight, text ) )
                    #continue
                    break
                    
                if prev_boty!=0  and  topy-prev_boty > median_boxheight: 
                    if verbose:
                        print( "                                                   [YSEP %d (%s->%s)]"%(topy-prev_boty, prev_boty, topy) )
                    flush_par()

                elif prev_boty!=0  and  topy-prev_boty > 0.6*median_boxheight: 
                    if verbose:
                        print( "                                                   [YSEP %d (%s->%s)]"%(topy-prev_boty, prev_boty, topy) )
                    flush_par()

                elif (boxheight > 1.25 * prev_boxheight)  and  current_line_shorter  and  not same_line:  # larger text, and shorter
                    # A large title of a new section is generally  caught by YSEP, actually
                    #print( 'size diff;   line diff?  botdiff is %d,  relative to 0.5*boxheight=%d'%( (boty-prev_boty),  0.5*boxheight ) )

                    if verbose:
                        print( "                                                   [LARGER_TEXT %s->%s]"%(prev_boxheight, boxheight) )
                    flush_par()

                elif boxheight < 0.8 * prev_boxheight  and  prev_line_shorter  and not same_line: # font smaller than the previous line, and the previous line was shorter
                    if verbose:
                        print( "                                                   [SMALLER_TEXT %s->%s]"%(prev_boxheight, boxheight) )
                    flush_par()

                temp_par.append( text )

                if verbose:
                    print( '      %12s %-12s  fs:%-5s  %s '%( topleft, botright, boxheight, text ) )

                prev_topy, prev_boty, prev_boxheight, prev_text = topy, boty,  boxheight, text

            flush_par()

            del page_contents['body_fragments']
            del page_contents['head_fragments']
            del page_contents['foot_fragments']
            del page_contents['misc_fragments']

            page_contents['head_text'] = head_text
            page_contents['body_text'] = body_text
            page_contents['foot_text'] = foot_text

            doc_pages.append( page_contents )

            #print( 'body_text' )
            #pprint.pprint( page_contents['body_text'] )
            #for par in page_contents['body_text']:
            #    for line in textwrap.wrap(par):
            #        print( '[%s]'%line )
            #    print()

        case_docs.append( 
            {
                'url':pdf_url, 
                'pages':doc_pages,
                'header_dates':doc_dates,
                'status':pdf_dict.get('status'),
            }
        )

        # summarize document
        #pprint.pprint( doc_contents )

        if 0:
            for page in doc_pages:
                for temp_par in page['body_text']:
                    for line in textwrap.wrap(temp_par):
                        print( '%s'%line )
                    print()



    date_range = ()
    if len(case_doc_dates)>0:
        date_range = (
            wetsuite.helpers.date.format_date( min(case_doc_dates) ), 
            wetsuite.helpers.date.format_date( max(case_doc_dates) )
        )

    dataset_cases.append( { 
                'name': case_name,
                'docs': case_docs,
        'date_range': date_range,

        # CONSIDER: maybe just start with case_dict so we don't have to manually do:
                'money': case_dict['money'],
                'ecli': case_dict['ecli'],
    'case_detail_url': case_dict['case_detail_url'],
    } )

print( len(dataset_cases) )
# Out:
# CASE 0: GoldWin Limited
#   DOC 0:  16442_boetebesluit_goldwin.pdf
#   DOC 1:  16442_01-299-883_openbaarmakingsbesluit_goldwin.pdf
# CASE 1: MKC Limited
#   DOC 0:  16402_boetebesluit_mkc_limited.pdf
#   DOC 1:  16402_01-299-881_openbaarmakingsbesluit_mkc_limited.pdf
# CASE 2: Blue High House S.A.
#   DOC 0:  20230929_01-296-617_besluit_lod_1a_blue_high_house_s-a-.pdf
#   DOC 1:  20230929_01-296-618_besluit_openbaarmaking_woo_blue_high_house_s-a-.pdf
# CASE 3: L.C.S Limited
# 117

# %%
# a case now looks like:
dataset_cases[0]
# Out:
# {'name': 'GoldWin Limited',
#  'docs': [{'url': 'https://kansspelautoriteit.nl/publish/library/32/16442_boetebesluit_goldwin.pdf',
#    'pages': [{'body_text': ['Besluit van de raad van bestuur van de Kansspelautoriteit als bedoeld in artikel 35a van de Wet op de kansspelen tot oplegging van een boete aan GoldWin Limited.',
#       'Zaak: 16442 Kenmerk: 01.299.858 Openbaarmaking onder kenmerk: 01.299.854',
#       'Besluit',
#       'Inleiding',
#       'De raad van bestuur van de Kansspelautoriteit (hierna: de Kansspelautoriteit) is belast met het toezicht op de naleving van de Wet op de kansspelen (hierna: Wok) . De Wok bevat een verbod op het gelegenheid geven tot deelname aan kansspelen zonder vergunning. Het handhaven van dit verbod is één van de prioriteiten van de Kansspelautoriteit. In dit besluit stelt de Kansspelautoriteit vast dat GoldWin Limited (hierna: GoldWin) dit verbod heeft overtreden. Daarom wordt haar een boete van € 6.794.000,- opgelegd. De Kansspelautoriteit zet dat hieronder nader uiteen.',
#       'Onderzoek naar website en betrokkene',
#       'De website',
#       'De Kansspelautoriteit heeft op 22 december 2022 de website westcasino.com (hierna: de website) onderzocht. Daarbij is onder meer het volgende gebleken. 2.1.1 Gelegenheid tot deelneming aan kansspelen',
#       'De website was bereikbaar vanaf een Nederlands IP-adres en het was voor de toezichthouder mogelijk om met Nederlandse (adres)gegevens een account aan te maken, daarop in te loggen, een storting te doen en deel te nemen aan kansspelen. Er waren geen technische maatregelen genomen om deelnemers vanuit Nederland de toegang tot de kansspelen te beletten.',
#       'Bijlage 15573/01.281.308/01 t/m 15573/01.281.308/04 .'],
#      'head_text': ['Kansspelautoriteit', 'OPENBAAR'],
#      'foot_text': ['Pagina 1 van 13']},
#     {'body_text': ['16442/01.299.854',
#       'De op de website aangeboden spellen zijn aan te merken als kansspelen. Op de website werden casinospelen aangeboden 2 Deze spellen zijn aan te merken als kansspelen.',
#       'Met deelname aan de kansspelen kan worden meegedongen naar prijzen of premies. Dat is, naast deelname aan een aangeboden kansspel door de toezichthouder , onder andere gebleken uit promotionele teksten op de website waaruit blijkt dat er geldprijzen te winnen zijn.3',
#       'Op de website stond vermeld dat GoldWin is gevestigd in Malta en daar een vergunning heeft. 4',
#       'Bij het inschrijvingsproces werd de leeftijd niet zichtbaar geverifieerd voordat het inschrijvingsproces was voltooid. 2.1.2 Gerichtheid op de Nederlandse markt',
#       'Zoals benoemd onder randnummer 3 was de website bereikbaar vanaf een Nederlands IP-adres en kon er vanuit Nederland een account worden aangemaakt en deelgenomen aan kansspelen.',
#       'Uit de data van Similarweb blijkt dat de website veelvuldig vanuit Nederland is bezocht. 5 Het totale aantal bezoeken van de website, zonder bounce rate, vanuit Nederland over de periode 2022 is 843.132.',
#       'Er is met een Mastercard, gekoppeld aan een Nederlandse bankrekening  een storting van € 20,- op de spelersrekening verricht. 6',
#       '11 . Nederland is niet aangemerkt als uitgesloten land om met bonussen te spelen in artikel 1 van de General bonus terms and conditions, onderdeel van de algemene voorwaarden (General terms and conditions) .7',
#       'De website was internationaal georiënteerd, waaruit medegerichtheid op Nederland bleek. De website was beschikbaar in de Engelse taal en de',
#       'Bijlage 15573/01.281.308/04. Bijlage 15573/01.281.308/06. Bijlage 15573/01.281.308/05/06. Bijlage 15573/01.290.252/01. Bijlage 15573/01.281.308/03. Bijlage 15573/01.281.308/06.'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '10 oktober 2023',
#       'Ons kenmerk',
#       '16442/01.299.858 en'],
#      'foot_text': ['Pagina 2 van 13']},
#     {'body_text': ['16442/01.299.854',
#       'klantenservice was in de Engelse taal, maar werd vertaald naar de Nederlandse taal. Er was sprake van een internationale topleveldomeinnaam, namelijk een com-extensie. Volgens de artikel 5.7 van de algemene voorwaarden konden spelers ook geld opnemen in diverse munteenheden, waaronder de euro en de (Amerikaanse) dollar.',
#       '2.1.3 Last onder dwangsom 13 . Op 23 januari 2023 heeft de Kansspelautoriteit een voornemen tot het opleggen van een last onder dwangsom aan GoldWin verstuurd. 8',
#       'Naar aanleiding hiervan is de website op 2 maart 2023 nogmaals onderzocht. De Kansspelautoriteit heeft onderzocht of er gelegenheid werd gegeven om vanuit Nederland deel te nemen aan kansspelen. Daaruit bleek dat het nog steeds mogelijk was om vanuit Nederland deel te nemen aan kansspelen  zolang niet het',
#       'woord "medewerker" in de naam of in het e-mailadres voorkwam. 9',
#       'Op 20 april 2023 heeft de Kansspelautoriteit een last onder dwangsom aan GoldWin verstuurd. 10 Daarin is GoldWin opgedragen om het aanbieden van kansspelen waarvoor vergunning ingevolge de Wok is verleend, te staken en gestaakt te houden.',
#       'De betrokkene',
#       'Naast de website is ook de betrokkene onderzocht. Blijkens het onderzoek biedt GoldWin gelegenheid tot deelname aan de kansspelen op de website. Dat blijkt onder meer uit het volgende.',
#       'Op de website staan haar contactgegevens en vergunning vermeld. 11 De website waarop de kansspelen worden aangeboden, staat geregistreerd op naam van GoldWin. 12 Blijkens de informatie op de website exploiteert GoldWin de website. Onderaan de homepagina en in artikel 2.1 van de algemene voorwaarden werd GoldWin als eigenaar van de website genoemd. 13 GoldWin vermeldt daarbij tevens dat zij over een kansspelvergunning beschikt van de Malta Gaming Authority .',
#       'Bijlage 15573/20230123/01.281.308. Bijlage 15573/01.287.207. Bijlage 15573/01.287.208 . Bijlage 15573/01.281.308/05/13 en 15573/01.281.308/05/06. Bijlage 15573/01.281.308/05/13. Bijlage 15573/01.281.308/05/06.'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '10 oktober 2023',
#       'Ons kenmerk',
#       '16442/01.299.858 en'],
#      'foot_text': ['Pagina 3 van 13']},
#     {'body_text': ['16442/01.299.854',
#       'Rapport',
#       'De Kansspelautoriteit heeft op grond van de hierboven genoemde onderzoeken op 10 juli 2023 een rapport (hierna: het rapport) opgesteld. In het rapport is geconstateerd dat GoldWin door middel van de website gelegenheid heeft gegeven om mede te dingen naar prijzen of premies, waarbij de aanwijzing van de winnaars geschiedt door enige kansbepaling waarop de deelnemers in het algemeen geen overwegende invloed kunnen uitoefenen, terwijl daarvoor geen vergunning is verleend. Dat is een overtreding van artikel 1, eerste lid, aanhef en onder a, van de Wok.',

#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '10 oktober 2023',
#       'Ons kenmerk',
#       '16442/01.299.858 en'],
#      'foot_text': ['Pagina 6 van 13']},
#     {'body_text': ['16442/01.299.854',
#       'deelnemers geen overwegende invloed konden uitoefenen. Dit aanbod was in ieder beschikbaar op 22 december 2022 en 2 maart 2023.',
#       'Tevens stelt de Kansspelautoriteit vast dat zij hiervoor geen vergunning heeft verleend. Bovendien stelt de Kansspelautoriteit vast dat de website mede gericht is op Nederland.',
#       'Dat leidt tot de conclusie dat GoldWin artikel 1, eerste lid, aanhef en onder a, van de Wok heeft overtreden.',
#       'Boete',
#       'Algemeen',
#       'De Kansspelautoriteit neemt bij het bepalen van de hoogte van een op te leggen boete de Boetebeleidsregels in acht. 24',
#       '33 . De Kansspelautoriteit ziet zich thans gesteld voor de vraag of en zo ja, welke sanctie in dit passend is.',
#       'Ernst en verwijtbaarheid',
#       '34 . Bij de beoordeling van de ernst en verwijtbaarheid van de overtreding door GoldWin acht de Kansspelautoriteit met name de volgende omstandigheden van belang .',
#       '6.2.1 De gevolgen van onvergund aanbieden van online kansspelen De kansspelmarkt is geen gewone economische markt. Omdat financieel gewin kan optreden zonder dat daar een evenredige inspanning tegenover staat, is deze markt extra gevoelig voor fraude, bedrog en verslaving waarvan de kansspelconsument de dupe kan worden. 25',
#       'Kansspelverslaving brengt negatieve persoonlijke en sociaal-maatschappelijke gevolgen met zich mee. Het kan leiden tot ernstige psychische, sociale, lichamelijke en financiële problemen, zoals agressie, relatieproblemen, gezinsproblemen, arbeidsproblemen en schulden waar de betrokkene niet meer',
#       'Stcrt. 2021, 41413. 25 Zesde voortgangsrapportage kansspelen, 27 januari 2009, p. 6.'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '10 oktober 2023',
#       'Ons kenmerk',
#       '16442/01.299.858 en'],
#      'foot_text': ['Pagina', '7 van 13']},
#     {'body_text': ['16442/01.299.854',
#       'uit komt zonder hulp. Veel probleem- en risicospelers blijken delicten als diefstal en fraude te plegen  en probleemspelers doen dit veelal in verband met hun kansspelverslaving. 26',
#       "Daar komt bij dat kansspelen op afstand andere en ernstigere risico's met zich mee brengen dan de traditionele fysieke  landgebonden kansspelen. In het bijzonder voor minderjarigen  personen met een bijzondere goklust, of personen die een dergelijke lust kunnen ontwikkelen. Dat komt onder andere door het ontbreken van direct contact tussen deelnemer en de aanbieder, een zeer makkelijke en permanente toegang tot het kansspel, het isolement van de deelnemer, en het ontbreken van sociale controle. 27",
#       '38 . De aangeboden kansspelen zijn tevens short odd-kansspelen; zoals casinospelen. Uit de (wetenschappelijke) literatuur is bekend dat bij short-odd kansspelen meer verslaafde spelers te vinden zijn dan bij long odd-kansspelen, zoals loterijen. Bij de aangeboden kansspelen speelt verslavingsproblematiek derhalve een rol van betekenis.',
#       "Gelet op deze risico's op het gebied van onder andere eerlijk spel, verslaving, en diverse vormen van criminaliteit zijn legale kansspelen streng gereguleerd. Door het ontbreken van een Nederlandse vergunning voor kansspelen op afstand en de mogelijkheid van toezicht daarop, kan geen enkele garantie worden geboden voor de waarborging van het Nederlandse kansspelbeleid. Dat GoldWin zich daaraan onttrekt is zeer ernstig.",
#       "f Bijzondere omstandigheden, zie paragraaf 5 onder M van de Boetebeleidsregels. De Kansspelautoriteit heeft in de algemene voorwaarden diverse onredelijke voorwaarden aangetroffen . Uit artikel 9.9 blijkt dat GoldWin zich het recht voorbehoudt om opname te weigeren totdat een speler al het geld op zijn account minstens één keer heeft ingezet. Consumenten konden aldus niet vrijelijk over hun saldo beschikken. Zij werden gedwongen om eerst aan kansspelen van GoldWin deel te nemen, met alle bij illegale kansspelen behorende risico's van dien. Daarnaast blijkt uit artikel 9.1.3 dat GoldWin zich het recht voorbehoudt om kosten te rekenen voor een uitbetaling. De Kansspelautoriteit acht deze voorwaarden een ontoelaatbare"],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '10 oktober 2023',
#       'Ons kenmerk',
#       '16442/01.299.858 en'],
#      'foot_text': ['Pagina 9 van 13']},
#     {'body_text': ['16442/01.299.854',
#       'benadeling voor de consument. Op grond van deze omstandigheden verhoogt zij het percentage van de basisboete met 0,5%.',
#       'Boetevaststelling',
#       '43 . Gelet op het hiervoor gestelde kwalificeert de Kansspelautoriteit het onvergund en ongereguleerd aanbieden van kansspelen online door GoldWin als zeer ernstig en verwijtbaar.',
#       '44 . Gelet op bovenstaande acht de Kansspelautoriteit passend en geboden dat een boete wordt opgelegd aan GoldWin.',
#       'De Kansspelautoriteit heeft bij het bepalen van de boete acht geslagen op de ernst en verwijtbaarheid van de overtreding en heeft hierbij, met in achtneming van de Boetebeleidsregels, de omstandigheden betrokken zoals die hiervoor zijn benoemd en toegelicht.',
#       "6.3.1 Omzet vanuit Nederland De Kansspelautoriteit heeft in haar Boetebeleidsregels uiteengezet hoe zij de boete berekent en hoe zij relevante begrippen uitlegt. Deze beleidsregels zijn kenbaar voor GoldWin. Met deze Boetebeleidsregels bepaalt de Kansspelautoriteit hoe zij een passende hoogte van de boete vast stelt. Daartoe heeft zij een rekenmethode ontwikkeld, waarbij zij onder meer gebruik maakt van het begrip 'omzet'.",
#       '47 . De omzet van GoldWin is geschat op basis van de rekenmethode zoals genoemd in bijlage 15573/01.290.252 van het rapport. Hiermee is berekend dat een bezoek vanuit Nederland aan een website met kansspelen op afstand zonder vergunning gemiddeld € 230,24 aan omzet voor de aanbieder oplevert. Via Similarweb zijn de websitebezoeken van de website uit 2021 verkregen. Hierbij is de bounce rate28 buiten beschouwing gelaten .',
#       'De Kansspelautoriteit heeft deze rekenmethode toegepast op een aantal vergunninghouders en de resultaten daarvan vergeleken met een berekening gebaseerd op de cijfers die die vergunninghouders hebben verstrekt aan de Belastingdienst (zie bijlage 10101/01.281.712). In randnummer 11 is toegelicht dat uit deze berekening blijkt dat de rekenmethode die de Kansspelautoriteit',
#       '28 Aantal websitebezoekers dat vertrekt zonder een tweede pagina op de website te bekijken.'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '10 oktober 2023',
#       'Ons kenmerk',
#       '16442/01.299.858 en'],
#      'foot_text': ['Pagina 10 van 13']},
#     {'body_text': ['16442/01.299.854',
#       'hanteert in bijlage 15573/01.290.252 van het rapport; bij vergunninghouders bedragen oplevert die gemiddeld een factor 1,84 hoger zijn dan de bedragen die volgen uit de gegevens van de Belastingdienst. Daarom heeft Kansspelautoriteit besloten om een tweede correctie toe te passen door de geschatte omzet te delen door 2',
#       'Voor GoldWin betekent dit dat de geschatte omzet vanuit Nederland € 97.061.355,84 bedraagt. Dit is als volgt opgebouwd: 843.132 bezoeken maal (€ 230,24 2) omzet per bezoek is een omzet van ongeveer € 97.061.355,84.29',
#       '6.3.2 Boetebedrag 50 . Conform artikel 4.2 van de Boetebeleidsregels is de hoogte van de basisboete bij een (geschatte) omzet gelijk aan of hoger dan € 15 miljoen 4% van de omzet. Het percentage van de basisboete wordt conform de Boetebeleidsregels verhoogd in verband met de boeteverhogende omstandigheden zoals die aan de orde zijn gekomen onder randnummer 42. Voor een overzicht van de verhoging per boeteverhogende omstandigheid die de Kansspelautoriteit van toepassing acht verwijst zij naar onderstaande tabel. Hierin wordt vermeld welke concrete omstandigheden, in welke mate, en in relatie tot welk onderdeel van de Boetebeleidsregels voor de verhogingen van belang zijn geacht.',
#       'Paragraaf 5 Omschrijving Verhoging [in Boetebeleidsregels punt] C Inactiviteitskosten 0,5 Voorwaarde van prijzen 0,5 De manier van stortingen 0,5 Autoplaylturboplay 0,5 ] Ontbreken van leeftijdsverificatie 0,5 M Bijzondere omstandigheden 0,5 Totale_verhoging 3 %-punt',
#       'De Kansspelautoriteit is niet gebleken van andere boeteverhogende of boeteverlagende omstandigheden.',
#       'Alles afwegende stelt de Kansspelautoriteit de boete vast op 7% van de geschatte omzet vanuit Nederland. Dit komt uit op een totaalbedrag van',
#       'Bijlage 15573/01.290.252, randnummer 6.'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '10 oktober 2023',
#       'Ons kenmerk',
#       '16442/01.299.858 en'],
#      'foot_text': ['Pagina 11 van 13']},
#     {'body_text': ['16442/01.299.854',
#       '6.794.000, 30 Dit bedrag wordt, gelet op de omstandigheden van het geval , passend en geboden geacht.',
#       'Besluit',
#       'De raad van bestuur van de Kansspelautoriteit:',
#       'a stelt vast dat GoldWin artikel 1, eerste lid, aanhef en onder a, van de Wok heeft overtreden door gelegenheid te geven om mede te dingen naar prijzen of premies, waarbij de aanwijzing der winnaars geschiedt door enige kansbepaling waarop de deelnemers geen overwegende invloed kunnen uitoefenen, en waarvoor niet de vereiste vergunning is verleend; b. legt aan GoldWin een boete op van € 6.794.000, -.',
#       "'s-Gravenhage, 10 oktober 2023,",
#       'De raad van bestuur van de Kansspelautoriteit,',
#       'W.g.',
#       'drs. René J.P. Jansen Voorzitter',
#       'VERZONDEN OP [datum].',
#       'Bezwaar Tegen dit besluit kan degene wiens belang rechtstreeks bij dit besluit is betrokken; binnen zes weken na de dag van bekendmaking van dit besluit een gemotiveerd bezwaarschrift indienen bij de Kansspelautoriteit, afdeling Juridische Zaken en Vergunningen, Postbus 298, 2501 CG Den Haag. U kunt uw bezwaarschrift ook digitaal indienen, door het in PDF-formaat te e-mailen naar @kansspelautoriteit.nI.',
#       'Verzoek om voorlopige_voorziening Kunt u de beslissing op uw bezwaarschrift niet afwachten vanwege een spoedeisend belang? Dan kunt u bij de sector bestuursrecht van de rechtbank in uw arrondissement een verzoek om voorlopige voorziening indienen.',
#       '30 Dit bedrag is naar beneden afgerond tot een veelvoud van € 1000,-, conform de Boetebeleidsregels.'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '10 oktober 2023',
#       'Ons kenmerk',
#       '16442/01.299.858 en'],
#      'foot_text': ['Pagina 12 van 13']},
#     {'body_text': ['16442/01.299.854',
#       'Betaling_boete Boetes dienen binnen zes weken nadat het besluit op de in artikel 3:41 van de Algemene wet bestuursrecht voorgeschreven wijze bekend is gemaakt; te zijn betaald op bankrekeningnummer IBAN NLO7ABNA0501634479 ten name van Kansspelautoriteit; Den Haag, Nederland, onder vermelding van het kenmerk van dit besluit. Na het verstrijken van deze termijn wordt de geldboete vermeerderd met de wettelijke rente.'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '10 oktober 2023',
#       'Ons kenmerk',
#       '16442/01.299.858 en'],
#      'foot_text': ['Pagina 13 van 13']}],
#    'header_dates': ['2023-10-10',
#     '2023-10-10',
#     '2023-10-10',
#     '2023-10-10',
#     '2023-10-10',
#     '2023-10-10',
#     '2023-10-10',
#     '2023-10-10',
#     '2023-10-10',
#     '2023-10-10',
#     '2023-10-10',
#     '2023-10-10'],
#    'status': 'Tegen dit besluit kan bezwaar worden gemaakt.'},
#   {'url': 'https://kansspelautoriteit.nl/publish/library/32/16442_01-299-883_openbaarmakingsbesluit_goldwin.pdf',
#    'pages': [{'body_text': ['Besluit als bedoeld in artikel 3.1 van de Wet open overheid.',
#       'Zaak: 16442 Kenmerk: 01.299.882 Openbaarmaking onder kenmerk: 01.299.883',
#       'Besluit tot openbaarmaking',
#       'Besluit tot openbaarmaking van het besluit van 10 oktober 2023, kenmerk 01.299.858, tot oplegging van een bestuurlijke boete aan GoldWin Limited en dit openbaarmakingsbesluit.',
#       'Inleiding',
#       'In het besluit met kenmerk 01.299.858 heeft de raad van bestuur van de Kansspelautoriteit (hierna: de Kansspelautoriteit) een bestuurlijke boete opgelegd wegens overtreding van artikel 1, eerste lid, aanhef en onder a, van de Wet op de kansspelen (hierna: Wok), aan GoldWin Limited (hierna: GoldWin) .',
#       'GoldWin is bij e-mail van 13 juli 2023 in de gelegenheid gesteld een zienswijze te geven over het sanctiebesluit en de openbaarmaking hiervan. Hier heeft zij geen gebruik van gemaakt.',
#       'Overwegingen',
#       'De Kansspelautoriteit maakt besluiten in beginsel openbaar op grond van artikel 3.1 van de Wet open overheid (hierna: Woo).',
#       "De Kansspelautoriteit hecht eraan sanctiebesluiten openbaar te maken vanwege het maatschappelijk belang om de consument te informeren over dan wel te waarschuwen voor bepaalde handelspraktijken van aanbieders van kansspelen zonder vergunning en de risico's die consumenten daarbij Iopen. Daarnaast beoogt de Kansspelautoriteit met de openbaarmaking van sanctiebesluiten transparantie te"],
#      'head_text': ['Kansspelautoriteit', 'OPENBAAR'],
#      'foot_text': []},
#     {'body_text': ['bieden met betrekking tot het functioneren van zijn organisatie. Ten slotte is openbaarmaking van belang in verband met de preventieve werking die van sanctiebesluiten kan uitgaan naar andere ondernemingen en natuurlijke personen.',
#       'De Kansspelautoriteit acht openbaarmaking ook in dit concrete geval in het belang',
#       'van consumenten die aldus kennis kunnen nemen van het feit dat ten aanzien van GoldWin is vastgesteld dat zij in strijd heeft gehandeld met artikel 1 eerste lid, onder a, van de Wok en dat de Kansspelautoriteit hiertegen heeft opgetreden.',
#       'De Kansspelautoriteit neemt hierbij het volgende in aanmerking .',
#       "De Afdeling bestuursrechtspraak van de Raad van State (hierna: de Afdeling) heeft bij uitspraak van 10 november 2010, ECLI:NL:RVS:2010.B03468, bepaald: 'Het boetebesluit is een bevoegd genomen besluit in het kader van een aan het college door de wetgever toegekende taak om toezicht te houden op de naleving van regelgeving en de daarmee samenhangende bevoegdheid om handhavend op te treden tegen overtreding van die regelgeving. In het kader van deze toezichthoudende taak past dat boetebesluiten worden gepubliceerd; zodat bekendheid wordt gegeven aan de wijze van uitvoering van deze taak (overweging 2.5).",
#       "Ten aanzien van de vereiste belangenafweging bepaalde de Afdeling in voornoemde uitspraak: 'Van een onevenredige benadeling zal in gevallen als de onderhavige naar het oordeel van de Afdeling sprake kunnen zijn als het boetebesluit uiteindelijk in rechte geen stand houdt en de betrokken rechtspersoon ten onrechte als overtreder kenbaar is gemaakt. Of sprake is van onevenredige benadeling hangt dan af van een oordeel over de rechtmatigheid van het boetebesluit.",
#       'De Kansspelautoriteit is van oordeel dat er geen aanleiding is te veronderstellen dat het sanctiebesluit in rechte geen stand zal houden. Naar het oordeel van de Kansspelautoriteit is afdoende aangetoond dat er sprake is van een overtreding van artikel 1 eerste lid, aanhef en onder a, van de Wok.',
#       '10. Van andere belangen of omstandigheden, op grond waarvan zou moeten worden afgezien van openbaarmaking, is de Kansspelautoriteit niet gebleken.'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 oktober 2023',
#       'Ons kenmerk',
#       '16442/ 01.299.882'],
#      'foot_text': []},
#     {'body_text': ['De Kansspelautoriteit wijst er verder op dat de namen van natuurlijke personen en de namen van rechtspersonen die in het onderzoek zijn genoemd, maar van wie geen overtreding is vastgesteld; nimmer openbaar worden gemaakt. Verwijzingen naar namen die genoemd worden in jurisprudentie en reeds openbaar gemaakte besluiten van de Kansspelautoriteit vallen hier niet onder .',
#       'Besluit',
#       '12.Op grond van het voorgaande zal de Kansspelautoriteit overgaan tot openbaarmaking van het besluit van 10 oktober 2023 met kenmerk 01.299.858. Tevens zal dit besluit tot openbaarmaking openbaar worden gemaakt.',
#       '13. In de openbaar te maken besluiten blijft vermelding van de namen van alle in de zaak betrokken natuurlijke personen achterwege. Daarnaast blijven bedrijfsvertrouwelijke gegevens buiten de openbaarmaking . Ook blijft achterwege openbaarmaking van de namen van rechtspersonen ten aanzien van wie geen overtreding wordt vastgesteld en geen sanctie wordt opgelegd.',
#       '14. Openbaarmaking geschiedt door middel van publicatie op de website www.kansspelautoriteit.nl op de datum en tijd zoals genoemd in de aanbiedingsbrief bij dit besluit.',
#       'Den Haag, 12 oktober 2023',
#       'Hoogachtend,',
#       'De raad van bestuur van de Kansspelautoriteit, namens deze,',
#       'W.g.',
#       'mr. Laurence M.A. Gimbrere Hoofd afdeling Juridische Zaken en Vergunningen',
#       'Bezwaar Tegen dit besluit kan degene wiens belang rechtstreeks bij dit besluit is betrokken, binnen zes weken na de dag van bekendmaking van dit besluit een gemotiveerd bezwaarschrift indienen bij'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 oktober 2023',
#       'Ons kenmerk',
#       '16442/ 01.299.882'],
#      'foot_text': []},
#     {'body_text': ['de Kansspelautoriteit;, afdeling Juridische Zaken en Vergunningen, Postbus 298, 2501 CG Den Haag.',
#       'Voorlopiqe_voorziening Let wel. het instellen van bezwaar schort de werking van dit besluit niet op. Kunt u de beslissing op uw bezwaarschrift niet afwachten vanwege een spoedeisend belang? Dan kunt u bij de sector bestuursrecht van de rechtbank in uw arrondissement een verzoek om voorlopige voorziening indienen.'],
#      'head_text': ['OPENBAAR',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 oktober 2023',
#       'Ons kenmerk',
#       '16442/ 01.299.882'],
#      'foot_text': []}],
#    'header_dates': ['2023-10-12', '2023-10-12', '2023-10-12'],
#    'status': 'Tegen dit besluit kan bezwaar worden gemaakt.'}],
#  'date_range': ('2023-10-10', '2023-10-12'),
#  'money': ['6794000', '97061355', '97061355', '6794000'],
#  'ecli': [],
#  'case_detail_url': 'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/goldwin-limited/'}

# %% [markdown]
# # Write out
#
# Now write that augmented structure into something we can call a dataset

# %%
kse = wetsuite.helpers.localdata.MsgpackKV('kansspelautoriteit_extracted.db', key_type=str)

# %%
kse._put_meta('description', '''This is a plaintext form of the set of documents you can find under https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/ as PDFs.

        Since almost half of those PDFs do not have a text stream, this data is entirely OCR'd,
        so expect some typical OCR errors.  The OCR quality seems fairly decent, and some effort was made to remove headers and footers,
        yet there are some leftovers  like _ instead of . and = instead of :


        The data is a fairly nested structure of python objects (or JSON, before it's parsed).
        - .data is a list of cases.

        - each case is a dict, with a 
            - 'name', 
            - 'docs' (a list) 
            - and some extracted information like mentioned money amounts, the apparent date span of the case

        - each document in that mentioned list is is a dict, with keys like
            - 'url' - to the PDF it came from
            - 'status' - from the detail page (if we could find it - not 100%) 
            - extracted informations like 'header_dates' (comes from PDF contents)
            - 'pages' (a list)

        - each page in that list is a dict, which has keys:
            - 'body_text' - a list, which containts text fragments that are _almost_ like paragraphs 
                except that text may continue between pages anyway - currently still up to you to detect - 
                plus the post-OCR processing isn't perfect.
            - 'foot_text' - generally just [ "Pagina 1 van 27" ]
            - 'head_text' - fragments like []"Kansspelautoriteit", "OPENBAAR"] but also the date and kenmerk lines


        (TODO: update this example)
        For example (body text edited for brevity), one case's dict, with one document:
            { # dict for a case
                'name': 'Toto Online B.V.',  # case's name
                'docs': [                    # list of PDF documents in this case
                    { # dict detailing first document in case
                        'url': 'https://kansspelautoriteit.nl/publish/library/32/01_278_071_15091_sanctiebesluit_toto_ov.pdf',
                        'pages': [
                            {  # first page's dict   (currently contains only body's text fragments; idea was to split off header contents)
                                'body_text':[  # first page's text fragments
                                    'Besluit van de raad van [more sentence]',
                                    'Zaak: 15091 Kenmerk: 15091 [more kenmerk]',
                                    'Besluit',
                                    'Inleiding',
                                    'De raad van bestuur van de Kansspelautoriteit [more paragraph]'
                                ]
                            },
                            { # second page's dict
                                'body_text': [   # second page text fragment
                                'heeft heeft ontvangen sinds hij daar [more paragraph]',
                                'De toezichthouders zijn naar aanleiding [more paragraph]'
                                ]
                            } 
                            # ...more pages
                        ], 
                    }, # end of document dict
                    # ...more documents
                ]
            }
        ''')

# %%
for d in dataset_cases:
    kse.put( d.get('case_detail_url'), d)
