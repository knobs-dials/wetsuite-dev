# %% [markdown]
# # Purpose of this notebook
#
# See what kind of things we can find out from the [tweede kamer open data portal](https://opendata.tweedekamer.nl/).

# %% [markdown]
# There are two interfaces for this: an [Atom-style API called SyncFeed](https://opendata.tweedekamer.nl/documentatie/syncfeed-api), and an [OData API](https://opendata.tweedekamer.nl/documentatie/odata-api).
#
# The Atom API is a little easier to speak yourself, OData can be a little more thorough but more work to use.
#
# Either way, there is a [relational data model](https://opendata.tweedekamer.nl/documentatie/informatiemodel) that you should be thinking of.
#
# Formats seem to be XML and JSON.

# %% [markdown]
# ## Atom/SyncFeed API

# %%
#   Fetch all resources of the mentioned soort/category, save into a single .xml file of its name.
import pprint

import wetsuite.datacollect.tweedekamer_nl # contains some basic code dealing with this API
import wetsuite.helpers.etree

for soort in (#'Persoon', 
              'Fractie', 
              #'FractieZetel', 'FractieZetelPersoon',

              #'Kamerstukdossier',

              #Not used yet 
              #'Document',

              'Zaal', 
              #'Vergadering', 
              # 'Stemming', 
              #'Zaak',
              #'Verslag',
             ): # or wetsuite.datacollect.tweedekamer_nl.resource_types for all
    print( f' == {soort} ==' )

    # this function actually does little more stick that soort on a URL and fetch ...repeatedly if necessary
    etrees = wetsuite.datacollect.tweedekamer_nl.fetch_all( soort )     
    
    # it also returned a list of etree objects,  and because our plan is currently to write that into a single XML file, we want to merge that
    single_tree = wetsuite.datacollect.tweedekamer_nl.merge_etrees( etrees )  

    print( wetsuite.helpers.etree.debug_pretty( single_tree ) )

    #xmlstring = wetsuite.helpers.etree.tostring( single_tree )                # then save that 
    #with open('%s.xml'%soort, 'wb') as xf:   # technically injection-sensitive, except it's fine as long as we control the values
    #    xf.write( xmlstring )
# Out:
#  == Fractie ==
# <feed>
#   <entry>
#     <title>ea081a13-e90e-4b8c-a917-95b7026bb635</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/ea081a13-e90e-4b8c-a917-95b7026bb635</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:19Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662055"/>
#     <content type="application/xml">
#       <fractie id="ea081a13-e90e-4b8c-a917-95b7026bb635" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2761</nummer>
#         <afkorting>LPF</afkorting>
#         <naamNl>Lijst Pim Fortuyn</naamNl>
#         <naamEn>List Pim Fortuyn</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen>541233</aantalStemmen>
#         <datumActief>2002-05-23</datumActief>
#         <datumInactief>2006-11-29</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>771d14b3-7360-4adc-821e-6d09d57b3f82</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/771d14b3-7360-4adc-821e-6d09d57b3f82</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:19Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662057"/>
#     <content type="application/xml">
#       <fractie id="771d14b3-7360-4adc-821e-6d09d57b3f82" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2758</nummer>
#         <afkorting>Groep Wijnschenk</afkorting>
#         <naamNl>Groep Wijnschenk</naamNl>
#         <naamEn>Group Wijnschenk</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2002-11-12</datumActief>
#         <datumInactief>2003-01-29</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>af740a5b-1910-4159-8a26-f71480962c0b</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/af740a5b-1910-4159-8a26-f71480962c0b</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:19Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662059"/>
#     <content type="application/xml">
#       <fractie id="af740a5b-1910-4159-8a26-f71480962c0b" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2762</nummer>
#         <afkorting>Groep Nawijn</afkorting>
#         <naamNl>Groep Nawijn</naamNl>
#         <naamEn>Group Nawijn</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen>23030</aantalStemmen>
#         <datumActief>2005-06-23</datumActief>
#         <datumInactief>2006-11-29</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>62c1a13c-85ff-40ed-90f7-a9546d61f869</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/62c1a13c-85ff-40ed-90f7-a9546d61f869</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:19Z</updated>
#     <category term="fractie"/>
#     <link rel="enclosure" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Resources/62c1a13c-85ff-40ed-90f7-a9546d61f869"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662060"/>
#     <content type="application/xml">
#       <fractie id="62c1a13c-85ff-40ed-90f7-a9546d61f869" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false" contentType="image/jpeg" contentLength="5362">
#         <nummer>2752</nummer>
#         <afkorting>CDA</afkorting>
#         <naamNl>Christen-Democratisch Appèl</naamNl>
#         <naamEn>Christian Democratic Appeal</naamEn>
#         <aantalZetels>14</aantalZetels>
#         <aantalStemmen>990601</aantalStemmen>
#         <datumActief>1980-10-11</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>037d290b-4b01-46b3-b95e-c145ddfd1474</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/037d290b-4b01-46b3-b95e-c145ddfd1474</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:19Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662061"/>
#     <content type="application/xml">
#       <fractie id="037d290b-4b01-46b3-b95e-c145ddfd1474" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2759</nummer>
#         <afkorting>Groep Lazrak</afkorting>
#         <naamNl>Groep Lazrak</naamNl>
#         <naamEn>Group Lazrak</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen>2387</aantalStemmen>
#         <datumActief>2004-02-04</datumActief>
#         <datumInactief>2006-11-29</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>d7cec3bd-f1f1-41ec-80f5-db5b66be3b86</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/d7cec3bd-f1f1-41ec-80f5-db5b66be3b86</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:19Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662063"/>
#     <content type="application/xml">
#       <fractie id="d7cec3bd-f1f1-41ec-80f5-db5b66be3b86" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2766</nummer>
#         <afkorting>Groep Eerdmans-van Schijndel</afkorting>
#         <naamNl>Groep Eerdmans-van Schijndel</naamNl>
#         <naamEn>Group Eerdmans-van Schijndel</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2006-09-25</datumActief>
#         <datumInactief>2006-11-29</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>d720f5af-0516-408a-b830-0b6ffb8a581c</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/d720f5af-0516-408a-b830-0b6ffb8a581c</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:19Z</updated>
#     <category term="fractie"/>
#     <link rel="enclosure" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Resources/d720f5af-0516-408a-b830-0b6ffb8a581c"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662065"/>
#     <content type="application/xml">
#       <fractie id="d720f5af-0516-408a-b830-0b6ffb8a581c" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false" contentType="image/gif" contentLength="2930">
#         <nummer>2753</nummer>
#         <afkorting>CU</afkorting>
#         <naamNl>ChristenUnie</naamNl>
#         <naamEn>Christian Union</naamEn>
#         <aantalZetels>5</aantalZetels>
#         <aantalStemmen>351275</aantalStemmen>
#         <datumActief>2001-03-15</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>ba2fa401-7f36-46ae-b7a3-68f006bfb7f2</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/ba2fa401-7f36-46ae-b7a3-68f006bfb7f2</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:19Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662068"/>
#     <content type="application/xml">
#       <fractie id="ba2fa401-7f36-46ae-b7a3-68f006bfb7f2" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2755</nummer>
#         <afkorting>Groep De Jong</afkorting>
#         <naamNl>Groep De Jong</naamNl>
#         <naamEn>Group De Jong</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2002-10-02</datumActief>
#         <datumInactief>2003-01-29</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>2590e192-a08d-4558-aa34-443c8816dfce</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/2590e192-a08d-4558-aa34-443c8816dfce</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:19Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662069"/>
#     <content type="application/xml">
#       <fractie id="2590e192-a08d-4558-aa34-443c8816dfce" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2757</nummer>
#         <afkorting>Groep van Oudenallen</afkorting>
#         <naamNl>Groep van Oudenallen</naamNl>
#         <naamEn>Group van Oudenallen</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2006-07-07</datumActief>
#         <datumInactief>2006-11-29</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>eb72ccb0-e80a-42d0-8b15-ebc30051447c</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/eb72ccb0-e80a-42d0-8b15-ebc30051447c</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="enclosure" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Resources/eb72ccb0-e80a-42d0-8b15-ebc30051447c"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662071"/>
#     <content type="application/xml">
#       <fractie id="eb72ccb0-e80a-42d0-8b15-ebc30051447c" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false" contentType="image/jpeg" contentLength="3519">
#         <nummer>2785</nummer>
#         <afkorting>Klein</afkorting>
#         <naamNl>Klein</naamNl>
#         <naamEn>Klein</naamEn>
#         <aantalZetels>0</aantalZetels>
#         <aantalStemmen>3511</aantalStemmen>
#         <datumActief>2014-11-13</datumActief>
#         <datumInactief>2017-03-22</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>b094bfef-e14b-4868-8d2e-78e12c6077d1</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/b094bfef-e14b-4868-8d2e-78e12c6077d1</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662073"/>
#     <content type="application/xml">
#       <fractie id="b094bfef-e14b-4868-8d2e-78e12c6077d1" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2779</nummer>
#         <afkorting>50PLUS/Baay-Timmerman</afkorting>
#         <naamNl>50PLUS/Baay-Timmerman</naamNl>
#         <naamEn>50PLUS/Baay-Timmerman</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2014-06-03</datumActief>
#         <datumInactief>2014-11-13</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>2833a04a-0b87-4f74-bd9e-6597f695db43</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/2833a04a-0b87-4f74-bd9e-6597f695db43</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662075"/>
#     <content type="application/xml">
#       <fractie id="2833a04a-0b87-4f74-bd9e-6597f695db43" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2782</nummer>
#         <afkorting>Monasch</afkorting>
#         <naamNl>Monasch</naamNl>
#         <naamEn>Monasch</naamEn>
#         <aantalZetels>0</aantalZetels>
#         <aantalStemmen nil="true"/>
#         <datumActief>2016-11-08</datumActief>
#         <datumInactief>2017-03-22</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>e2c3dd23-f247-430a-9c94-53f9f5c06c0b</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/e2c3dd23-f247-430a-9c94-53f9f5c06c0b</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662076"/>
#     <content type="application/xml">
#       <fractie id="e2c3dd23-f247-430a-9c94-53f9f5c06c0b" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2780</nummer>
#         <afkorting>Van Vliet</afkorting>
#         <naamNl>Van Vliet</naamNl>
#         <naamEn>Van Vliet</naamEn>
#         <aantalZetels>0</aantalZetels>
#         <aantalStemmen>1113</aantalStemmen>
#         <datumActief>2014-03-21</datumActief>
#         <datumInactief>2017-03-22</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>fc594dee-bad8-4caf-ba89-9496537c3527</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/fc594dee-bad8-4caf-ba89-9496537c3527</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662077"/>
#     <content type="application/xml">
#       <fractie id="fc594dee-bad8-4caf-ba89-9496537c3527" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2786</nummer>
#         <afkorting>GrBvK</afkorting>
#         <naamNl>Groep Bontes/Van Klaveren</naamNl>
#         <naamEn>Group Bontes/Van Klaveren</naamEn>
#         <aantalZetels>0</aantalZetels>
#         <aantalStemmen nil="true"/>
#         <datumActief>2014-04-15</datumActief>
#         <datumInactief>2017-03-22</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>a3689bb6-3914-4d5c-a6a8-42e24582e299</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/a3689bb6-3914-4d5c-a6a8-42e24582e299</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="enclosure" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Resources/a3689bb6-3914-4d5c-a6a8-42e24582e299"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662078"/>
#     <content type="application/xml">
#       <fractie id="a3689bb6-3914-4d5c-a6a8-42e24582e299" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false" contentType="image/png" contentLength="2876">
#         <nummer>2768</nummer>
#         <afkorting>SP</afkorting>
#         <naamNl>Socialistische Partij</naamNl>
#         <naamEn>Socialist Party</naamEn>
#         <aantalZetels>9</aantalZetels>
#         <aantalStemmen>623371</aantalStemmen>
#         <datumActief>1994-05-17</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>06c7d1e6-394d-40db-ad2a-141a20124714</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/06c7d1e6-394d-40db-ad2a-141a20124714</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662079"/>
#     <content type="application/xml">
#       <fractie id="06c7d1e6-394d-40db-ad2a-141a20124714" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2771</nummer>
#         <afkorting>Groep Wilders</afkorting>
#         <naamNl>Groep Wilders</naamNl>
#         <naamEn>Group Wilders</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen>4763</aantalStemmen>
#         <datumActief>2004-09-02</datumActief>
#         <datumInactief>2006-11-29</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>489c052b-1917-4a1e-918d-1ef58fda123b</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/489c052b-1917-4a1e-918d-1ef58fda123b</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662080"/>
#     <content type="application/xml">
#       <fractie id="489c052b-1917-4a1e-918d-1ef58fda123b" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2769</nummer>
#         <afkorting>Verdonk</afkorting>
#         <naamNl>Verdonk</naamNl>
#         <naamEn>Verdonk</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen>620555</aantalStemmen>
#         <datumActief>2007-01-01</datumActief>
#         <datumInactief>2010-06-16</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>5b457d01-2569-40e3-9201-b99b1d80c471</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/5b457d01-2569-40e3-9201-b99b1d80c471</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662081"/>
#     <content type="application/xml">
#       <fractie id="5b457d01-2569-40e3-9201-b99b1d80c471" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2787</nummer>
#         <afkorting>Houwers</afkorting>
#         <naamNl>Houwers</naamNl>
#         <naamEn>Houwers</naamEn>
#         <aantalZetels>0</aantalZetels>
#         <aantalStemmen nil="true"/>
#         <datumActief>2015-03-25</datumActief>
#         <datumInactief>2017-03-22</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>831e85cb-62dc-4341-84ec-78c3c593c244</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/831e85cb-62dc-4341-84ec-78c3c593c244</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662082"/>
#     <content type="application/xml">
#       <fractie id="831e85cb-62dc-4341-84ec-78c3c593c244" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2772</nummer>
#         <afkorting>BONTES</afkorting>
#         <naamNl>Bontes</naamNl>
#         <naamEn>Bontes</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2013-10-29</datumActief>
#         <datumInactief>2017-02-14</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>b04f833d-8704-4f2c-bd98-83f3068dbb24</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/b04f833d-8704-4f2c-bd98-83f3068dbb24</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662083"/>
#     <content type="application/xml">
#       <fractie id="b04f833d-8704-4f2c-bd98-83f3068dbb24" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2781</nummer>
#         <afkorting>GrKÖ</afkorting>
#         <naamNl>Groep Kuzu/Öztürk</naamNl>
#         <naamEn>Group Kuzu/Öztürk</naamEn>
#         <aantalZetels>0</aantalZetels>
#         <aantalStemmen nil="true"/>
#         <datumActief>2014-11-14</datumActief>
#         <datumInactief>2017-03-22</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>e133cd98-1b5c-47e0-ac4d-031f34199767</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/e133cd98-1b5c-47e0-ac4d-031f34199767</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662084"/>
#     <content type="application/xml">
#       <fractie id="e133cd98-1b5c-47e0-ac4d-031f34199767" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2783</nummer>
#         <afkorting>BRINK</afkorting>
#         <naamNl>Brinkman</naamNl>
#         <naamEn>Brinkman</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2012-03-20</datumActief>
#         <datumInactief>2012-09-19</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>c82898bb-a5b0-4915-8452-3c9469363b0b</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/c82898bb-a5b0-4915-8452-3c9469363b0b</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662085"/>
#     <content type="application/xml">
#       <fractie id="c82898bb-a5b0-4915-8452-3c9469363b0b" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2774</nummer>
#         <afkorting>Van Bemmel</afkorting>
#         <naamNl>Van Bemmel</naamNl>
#         <naamEn>Van Bemmel</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2012-07-06</datumActief>
#         <datumInactief>2012-09-19</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>92dec5db-fce3-4235-b432-2feec47d3241</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/92dec5db-fce3-4235-b432-2feec47d3241</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662086"/>
#     <content type="application/xml">
#       <fractie id="92dec5db-fce3-4235-b432-2feec47d3241" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2777</nummer>
#         <afkorting>Baay-Timmerman</afkorting>
#         <naamNl>Baay-Timmerman</naamNl>
#         <naamEn>Baay-Timmerman</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2014-05-28</datumActief>
#         <datumInactief>2014-06-03</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>4517964b-fe02-4b7c-b5df-a4357d750ca4</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/4517964b-fe02-4b7c-b5df-a4357d750ca4</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662088"/>
#     <content type="application/xml">
#       <fractie id="4517964b-fe02-4b7c-b5df-a4357d750ca4" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2784</nummer>
#         <afkorting>Van Klaveren</afkorting>
#         <naamNl>Van Klaveren</naamNl>
#         <naamEn>Van Klaveren</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2014-03-22</datumActief>
#         <datumInactief>2014-04-14</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>a34bf6c8-834e-4dba-b4d2-f2f1b3957bd2</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/a34bf6c8-834e-4dba-b4d2-f2f1b3957bd2</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="enclosure" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Resources/a34bf6c8-834e-4dba-b4d2-f2f1b3957bd2"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662091"/>
#     <content type="application/xml">
#       <fractie id="a34bf6c8-834e-4dba-b4d2-f2f1b3957bd2" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false" contentType="image/png" contentLength="13605">
#         <nummer>2775</nummer>
#         <afkorting>50PLUS</afkorting>
#         <naamNl>50PLUS</naamNl>
#         <naamEn>50PLUS</naamEn>
#         <aantalZetels>0</aantalZetels>
#         <aantalStemmen>106702</aantalStemmen>
#         <datumActief>2012-09-20</datumActief>
#         <datumInactief>2021-05-11</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>292e65d3-7337-424e-a956-9066f285861a</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/292e65d3-7337-424e-a956-9066f285861a</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:23:21Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16662094"/>
#     <content type="application/xml">
#       <fractie id="292e65d3-7337-424e-a956-9066f285861a" bijgewerkt="2023-08-29T11:09:50Z" verwijderd="false">
#         <nummer>2773</nummer>
#         <afkorting>GrKH</afkorting>
#         <naamNl>Groep Kortenoeven/Hernandez</naamNl>
#         <naamEn>Group Kortenoeven/Hernandez</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2012-07-03</datumActief>
#         <datumInactief>2012-09-19</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>deb74bb5-63a9-4ffc-98ed-af577167452e</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/deb74bb5-63a9-4ffc-98ed-af577167452e</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:28:20Z</updated>
#     <category term="fractie"/>
#     <link rel="enclosure" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Resources/deb74bb5-63a9-4ffc-98ed-af577167452e"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16663344"/>
#     <content type="application/xml">
#       <fractie id="deb74bb5-63a9-4ffc-98ed-af577167452e" bijgewerkt="2023-08-29T11:09:52Z" verwijderd="false" contentType="image/jpeg" contentLength="3941">
#         <nummer>5126</nummer>
#         <afkorting>DENK</afkorting>
#         <naamNl>DENK</naamNl>
#         <naamEn>DENK</naamEn>
#         <aantalZetels>3</aantalZetels>
#         <aantalStemmen>211237</aantalStemmen>
#         <datumActief>2017-03-23</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>e0b7b638-de3c-47cc-85bd-341dd65ea33d</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/e0b7b638-de3c-47cc-85bd-341dd65ea33d</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T11:28:20Z</updated>
#     <category term="fractie"/>
#     <link rel="enclosure" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Resources/e0b7b638-de3c-47cc-85bd-341dd65ea33d"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16663353"/>
#     <content type="application/xml">
#       <fractie id="e0b7b638-de3c-47cc-85bd-341dd65ea33d" bijgewerkt="2023-08-29T11:09:52Z" verwijderd="false" contentType="image/jpeg" contentLength="4223">
#         <nummer>5127</nummer>
#         <afkorting>FVD</afkorting>
#         <naamNl>Forum voor Democratie</naamNl>
#         <naamEn>Forum for Democracy</naamEn>
#         <aantalZetels>5</aantalZetels>
#         <aantalStemmen>275557</aantalStemmen>
#         <datumActief>2017-03-23</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>8140f3a2-f9c1-48a6-a0b2-7e6eb78b3006</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/8140f3a2-f9c1-48a6-a0b2-7e6eb78b3006</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T13:56:20Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16694195"/>
#     <content type="application/xml">
#       <fractie id="8140f3a2-f9c1-48a6-a0b2-7e6eb78b3006" bijgewerkt="2023-08-29T11:10:31Z" verwijderd="false">
#         <nummer>45459</nummer>
#         <afkorting>Van Haga</afkorting>
#         <naamNl>Van Haga</naamNl>
#         <naamEn>Van Haga</naamEn>
#         <aantalZetels>0</aantalZetels>
#         <aantalStemmen>2156</aantalStemmen>
#         <datumActief>2019-09-24</datumActief>
#         <datumInactief>2020-11-29</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>1ffd89a8-9db9-437f-a064-651770ce85f3</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/1ffd89a8-9db9-437f-a064-651770ce85f3</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T14:00:11Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16694848"/>
#     <content type="application/xml">
#       <fractie id="1ffd89a8-9db9-437f-a064-651770ce85f3" bijgewerkt="2023-08-29T11:10:32Z" verwijderd="true"/>
#     </content>
#   </entry>
#   <entry>
#     <title>18e95d6d-1684-4fa0-968a-1a6140d2d793</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/18e95d6d-1684-4fa0-968a-1a6140d2d793</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T14:10:12Z</updated>
#     <category term="fractie"/>
#     <link rel="enclosure" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Resources/18e95d6d-1684-4fa0-968a-1a6140d2d793"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16697111"/>
#     <content type="application/xml">
#       <fractie id="18e95d6d-1684-4fa0-968a-1a6140d2d793" bijgewerkt="2023-08-29T11:10:37Z" verwijderd="false" contentType="image/png" contentLength="59041">
#         <nummer>50309</nummer>
#         <afkorting>BIJ1</afkorting>
#         <naamNl>BIJ1</naamNl>
#         <naamEn>BIJ1</naamEn>
#         <aantalZetels>1</aantalZetels>
#         <aantalStemmen>87238</aantalStemmen>
#         <datumActief>2021-03-31</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>ae48391e-ce4d-47e0-86e3-ee310282f66f</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/ae48391e-ce4d-47e0-86e3-ee310282f66f</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T14:10:12Z</updated>
#     <category term="fractie"/>
#     <link rel="enclosure" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Resources/ae48391e-ce4d-47e0-86e3-ee310282f66f"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16697121"/>
#     <content type="application/xml">
#       <fractie id="ae48391e-ce4d-47e0-86e3-ee310282f66f" bijgewerkt="2023-08-29T11:10:37Z" verwijderd="false" contentType="image/jpeg" contentLength="13128">
#         <nummer>50311</nummer>
#         <afkorting>Volt</afkorting>
#         <naamNl>Volt</naamNl>
#         <naamEn>Volt</naamEn>
#         <aantalZetels>2</aantalZetels>
#         <aantalStemmen>211128</aantalStemmen>
#         <datumActief>2021-03-31</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>ea1ba564-db2c-4c57-b867-91ac4dcc5643</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/ea1ba564-db2c-4c57-b867-91ac4dcc5643</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T14:20:10Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16699142"/>
#     <content type="application/xml">
#       <fractie id="ea1ba564-db2c-4c57-b867-91ac4dcc5643" bijgewerkt="2023-08-29T11:10:39Z" verwijderd="false">
#         <nummer>52314</nummer>
#         <afkorting>Fractie Den Haan</afkorting>
#         <naamNl>Fractie Den Haan</naamNl>
#         <naamEn>Fractie Den Haan</naamEn>
#         <aantalZetels>1</aantalZetels>
#         <aantalStemmen>106702</aantalStemmen>
#         <datumActief>2021-05-10</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>acc6e04b-e53e-489b-8904-dc91d3af2e11</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/acc6e04b-e53e-489b-8904-dc91d3af2e11</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T14:22:16Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16700059"/>
#     <content type="application/xml">
#       <fractie id="acc6e04b-e53e-489b-8904-dc91d3af2e11" bijgewerkt="2023-08-29T11:10:39Z" verwijderd="false">
#         <nummer>52799</nummer>
#         <afkorting>Omtzigt</afkorting>
#         <naamNl>Omtzigt</naamNl>
#         <naamEn>Omtzigt</naamEn>
#         <aantalZetels>1</aantalZetels>
#         <aantalStemmen>342472</aantalStemmen>
#         <datumActief>2021-09-15</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>ab3fa1a5-3bd9-413e-957f-61b2a697c967</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/ab3fa1a5-3bd9-413e-957f-61b2a697c967</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T14:26:17Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16701055"/>
#     <content type="application/xml">
#       <fractie id="ab3fa1a5-3bd9-413e-957f-61b2a697c967" bijgewerkt="2023-08-29T11:10:41Z" verwijderd="false">
#         <nummer>53624</nummer>
#         <afkorting>Gündoğan</afkorting>
#         <naamNl>Gündoğan</naamNl>
#         <naamEn>Gündoğan</naamEn>
#         <aantalZetels>1</aantalZetels>
#         <aantalStemmen>41352</aantalStemmen>
#         <datumActief>2022-02-26</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>56803c7e-9424-4122-9aea-eb4b548ba700</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/56803c7e-9424-4122-9aea-eb4b548ba700</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-08-29T14:37:26Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16703444"/>
#     <content type="application/xml">
#       <fractie id="56803c7e-9424-4122-9aea-eb4b548ba700" bijgewerkt="2023-08-29T11:10:43Z" verwijderd="false">
#         <nummer>57046</nummer>
#         <afkorting>Ephraim</afkorting>
#         <naamNl>Ephraim</naamNl>
#         <naamEn>Ephraim</naamEn>
#         <aantalZetels>1</aantalZetels>
#         <aantalStemmen>989</aantalStemmen>
#         <datumActief>2023-08-02</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>65129918-f256-4975-9da4-488da34d6695</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/65129918-f256-4975-9da4-488da34d6695</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-09-05T08:22:10Z</updated>
#     <category term="fractie"/>
#     <link rel="enclosure" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Resources/65129918-f256-4975-9da4-488da34d6695"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16746353"/>
#     <content type="application/xml">
#       <fractie id="65129918-f256-4975-9da4-488da34d6695" bijgewerkt="2023-09-05T08:21:39Z" verwijderd="false" contentType="image/jpeg" contentLength="4484">
#         <nummer>2765</nummer>
#         <afkorting>PVV</afkorting>
#         <naamNl>Partij voor de Vrijheid</naamNl>
#         <naamEn>Party for Freedom</naamEn>
#         <aantalZetels>16</aantalZetels>
#         <aantalStemmen>1124482</aantalStemmen>
#         <datumActief>2006-11-30</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>fab6e7e1-9d63-446a-a6e1-e1c74e3f679e</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/fab6e7e1-9d63-446a-a6e1-e1c74e3f679e</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-09-05T08:23:17Z</updated>
#     <category term="fractie"/>
#     <link rel="enclosure" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Resources/fab6e7e1-9d63-446a-a6e1-e1c74e3f679e"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16746424"/>
#     <content type="application/xml">
#       <fractie id="fab6e7e1-9d63-446a-a6e1-e1c74e3f679e" bijgewerkt="2023-09-05T08:22:51Z" verwijderd="false" contentType="image/png" contentLength="119481">
#         <nummer>50310</nummer>
#         <afkorting>JA21</afkorting>
#         <naamNl>JA21</naamNl>
#         <naamEn>JA21</naamEn>
#         <aantalZetels>1</aantalZetels>
#         <aantalStemmen>246620</aantalStemmen>
#         <datumActief>2021-03-31</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>626555ac-e836-44e3-9978-a6a7f0abc3ce</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/626555ac-e836-44e3-9978-a6a7f0abc3ce</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-09-05T08:27:10Z</updated>
#     <category term="fractie"/>
#     <link rel="enclosure" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Resources/626555ac-e836-44e3-9978-a6a7f0abc3ce"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16746698"/>
#     <content type="application/xml">
#       <fractie id="626555ac-e836-44e3-9978-a6a7f0abc3ce" bijgewerkt="2023-09-05T08:26:31Z" verwijderd="false" contentType="image/jpeg" contentLength="30017">
#         <nummer>50312</nummer>
#         <afkorting>BBB</afkorting>
#         <naamNl>BBB</naamNl>
#         <naamEn>Farmer–Citizen Movement</naamEn>
#         <aantalZetels>4</aantalZetels>
#         <aantalStemmen>104319</aantalStemmen>
#         <datumActief>2021-03-31</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>77f9b6f1-b1a9-4d1b-a05e-9936e79d8fa5</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/77f9b6f1-b1a9-4d1b-a05e-9936e79d8fa5</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-09-05T13:26:09Z</updated>
#     <category term="fractie"/>
#     <link rel="enclosure" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Resources/77f9b6f1-b1a9-4d1b-a05e-9936e79d8fa5"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16750259"/>
#     <content type="application/xml">
#       <fractie id="77f9b6f1-b1a9-4d1b-a05e-9936e79d8fa5" bijgewerkt="2023-09-05T13:25:50Z" verwijderd="false" contentType="image/jpeg" contentLength="6838">
#         <nummer>2767</nummer>
#         <afkorting>SGP</afkorting>
#         <naamNl>Staatkundig Gereformeerde Partij</naamNl>
#         <naamEn>Calvinist Political Party</naamEn>
#         <aantalZetels>3</aantalZetels>
#         <aantalStemmen>215249</aantalStemmen>
#         <datumActief>1922-04-30</datumActief>
#         <datumInactief nil="true"/>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>fdcd3f2b-52ec-4a88-8034-cf592f0b9d47</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/fdcd3f2b-52ec-4a88-8034-cf592f0b9d47</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-10-05T10:40:09Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16948509"/>
#     <content type="application/xml">
#       <fractie id="fdcd3f2b-52ec-4a88-8034-cf592f0b9d47" bijgewerkt="2023-10-05T10:39:08Z" verwijderd="false">
#         <nummer>2760</nummer>
#         <afkorting>LN</afkorting>
#         <naamNl>Leefbaar Nederland</naamNl>
#         <naamEn>Leefbaar Nederland</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2002-05-23</datumActief>
#         <datumInactief>2003-01-29</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>43eff828-86b7-4cb1-9c73-4ea0e33f93ac</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/43eff828-86b7-4cb1-9c73-4ea0e33f93ac</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-10-05T10:41:10Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16948511"/>
#     <content type="application/xml">
#       <fractie id="43eff828-86b7-4cb1-9c73-4ea0e33f93ac" bijgewerkt="2023-10-05T10:40:17Z" verwijderd="false">
#         <nummer>2776</nummer>
#         <afkorting>DPK</afkorting>
#         <naamNl>Democratisch Politiek Keerpunt</naamNl>
#         <naamEn>Democratisch Politiek Keerpunt</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2012-09-20</datumActief>
#         <datumInactief>2012-09-20</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>b4907c2d-282d-465e-bf23-18369f68086c</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/b4907c2d-282d-465e-bf23-18369f68086c</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-10-05T10:42:09Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16948515"/>
#     <content type="application/xml">
#       <fractie id="b4907c2d-282d-465e-bf23-18369f68086c" bijgewerkt="2023-10-05T10:41:31Z" verwijderd="false">
#         <nummer>2778</nummer>
#         <afkorting>50PLUS/Klein</afkorting>
#         <naamNl>50PLUS/Klein</naamNl>
#         <naamEn>50PLUS/Klein</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2014-06-03</datumActief>
#         <datumInactief>2014-11-13</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>cf46369d-a0e2-4090-b9f3-dd2feb5b4f35</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/cf46369d-a0e2-4090-b9f3-dd2feb5b4f35</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-10-05T10:42:09Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16948516"/>
#     <content type="application/xml">
#       <fractie id="cf46369d-a0e2-4090-b9f3-dd2feb5b4f35" bijgewerkt="2023-10-05T10:41:44Z" verwijderd="false">
#         <nummer>5149</nummer>
#         <afkorting>GRSCH</afkorting>
#         <naamNl>Groep Van Schijndel</naamNl>
#         <naamEn>Groep Van Schijndel</naamEn>
#         <aantalZetels nil="true"/>
#         <aantalStemmen nil="true"/>
#         <datumActief>2006-09-07</datumActief>
#         <datumInactief>2006-09-24</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>5452aab2-d0cb-40a8-82b7-144c6e6bc5ca</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/5452aab2-d0cb-40a8-82b7-144c6e6bc5ca</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-10-05T10:42:09Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16948517"/>
#     <content type="application/xml">
#       <fractie id="5452aab2-d0cb-40a8-82b7-144c6e6bc5ca" bijgewerkt="2023-10-05T10:41:53Z" verwijderd="false">
#         <nummer>44981</nummer>
#         <afkorting>vKA</afkorting>
#         <naamNl>Van Kooten-Arissen</naamNl>
#         <naamEn>Van Kooten-Arissen</naamEn>
#         <aantalZetels>0</aantalZetels>
#         <aantalStemmen>6131</aantalStemmen>
#         <datumActief>2019-07-16</datumActief>
#         <datumInactief>2020-05-05</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>68b24085-9d89-4c00-a61c-a06a1493dcdd</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/68b24085-9d89-4c00-a61c-a06a1493dcdd</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-10-05T10:43:09Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16948519"/>
#     <content type="application/xml">
#       <fractie id="68b24085-9d89-4c00-a61c-a06a1493dcdd" bijgewerkt="2023-10-05T10:42:07Z" verwijderd="false">
#         <nummer>46106</nummer>
#         <afkorting>Krol</afkorting>
#         <naamNl>Krol</naamNl>
#         <naamEn>Krol</naamEn>
#         <aantalZetels>0</aantalZetels>
#         <aantalStemmen>233179</aantalStemmen>
#         <datumActief>2020-05-03</datumActief>
#         <datumInactief>2020-05-05</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>ae60c2d3-5f87-4170-8f0c-503c36ddd130</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/ae60c2d3-5f87-4170-8f0c-503c36ddd130</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-10-05T10:43:09Z</updated>
#     <category term="fractie"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Fractie&amp;skiptoken=16948520"/>
#     <content type="application/xml">
#       <fractie id="ae60c2d3-5f87-4170-8f0c-503c36ddd130" bijgewerkt="2023-10-05T10:42:16Z" verwijderd="false">
#         <nummer>46112</nummer>
#         <afkorting>Groep Krol/vKA</afkorting>
#         <naamNl>Groep Krol/van Kooten-Arissen</naamNl>
#         <naamEn>Groep Krol/van Kooten-Arissen</naamEn>
#         <aantalZetels>0</aantalZetels>
#         <aantalStemmen>239310</aantalStemmen>
#         <datumActief>2020-05-06</datumActief>
#         <datumInactief>2020-08-05</datumInactief>
#       </fractie>
#     </content>
#   </entry>
#   <entry>
#     <title>9baf43e2-3081-4fb1-93c4-6f002f395271</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/9baf43e2-3081-4fb1-93c4-6f002f395271</id>
#     <author>
# ...
#         <naam>(Nog) geen zaal beschikbaar</naam>
#         <sysCode>241</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>8faebef7-9e47-4f39-a1f7-11f2e22feac6</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/8faebef7-9e47-4f39-a1f7-11f2e22feac6</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-05-27T13:56:00Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10466037"/>
#     <content type="application/xml">
#       <zaal id="8faebef7-9e47-4f39-a1f7-11f2e22feac6" bijgewerkt="2021-05-27T15:55:06.8370000" verwijderd="false">
#         <naam>Aletta Jacobszaal</naam>
#         <sysCode>77</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>b749a6d4-b076-4e97-9b42-722a1340825b</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/b749a6d4-b076-4e97-9b42-722a1340825b</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-03T08:53:00Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10501000"/>
#     <content type="application/xml">
#       <zaal id="b749a6d4-b076-4e97-9b42-722a1340825b" bijgewerkt="2021-06-03T10:52:01.1600000" verwijderd="false">
#         <naam>Suze Groenewegzaal</naam>
#         <sysCode>76</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>4efd094a-d128-4ae5-8da8-d47bc80241cc</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/4efd094a-d128-4ae5-8da8-d47bc80241cc</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-09T13:37:59Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10548155"/>
#     <content type="application/xml">
#       <zaal id="4efd094a-d128-4ae5-8da8-d47bc80241cc" bijgewerkt="2021-06-09T15:37:06.2200000" verwijderd="false">
#         <naam>Wttewaall van Stoetwegenzaal</naam>
#         <sysCode>75</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>2f12af84-7b6d-492c-8aab-4bb7763b1343</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/2f12af84-7b6d-492c-8aab-4bb7763b1343</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-10T13:25:48Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10561477"/>
#     <content type="application/xml">
#       <zaal id="2f12af84-7b6d-492c-8aab-4bb7763b1343" bijgewerkt="2021-06-10T15:24:50.7600000" verwijderd="false">
#         <naam>Petitie Statenpassage</naam>
#         <sysCode>239</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>ecb7b01f-a05b-48cd-a715-8996e92e500d</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/ecb7b01f-a05b-48cd-a715-8996e92e500d</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-11T11:44:18Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10570265"/>
#     <content type="application/xml">
#       <zaal id="ecb7b01f-a05b-48cd-a715-8996e92e500d" bijgewerkt="2021-06-11T13:44:06.9770000" verwijderd="false">
#         <naam>Petitie Statenpassage</naam>
#         <sysCode>238</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>b4f266b6-a11b-4c58-bd15-6d00d6cce7e3</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/b4f266b6-a11b-4c58-bd15-6d00d6cce7e3</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-14T13:09:52Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10576587"/>
#     <content type="application/xml">
#       <zaal id="b4f266b6-a11b-4c58-bd15-6d00d6cce7e3" bijgewerkt="2021-06-14T15:09:51.4670000" verwijderd="false">
#         <naam>Schaperkamer</naam>
#         <sysCode>85</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>0ad10e62-479e-45ec-8c89-b41ece33b880</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/0ad10e62-479e-45ec-8c89-b41ece33b880</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-15T11:19:18Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10581333"/>
#     <content type="application/xml">
#       <zaal id="0ad10e62-479e-45ec-8c89-b41ece33b880" bijgewerkt="2021-06-15T13:19:04.1400000" verwijderd="false">
#         <naam>Daleszaal</naam>
#         <sysCode>103</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>82ec6018-715d-4347-a6c4-22581ce2b5c4</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/82ec6018-715d-4347-a6c4-22581ce2b5c4</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-17T10:24:58Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10600261"/>
#     <content type="application/xml">
#       <zaal id="82ec6018-715d-4347-a6c4-22581ce2b5c4" bijgewerkt="2021-06-17T12:24:34.4100000" verwijderd="false">
#         <naam>Rommekamer</naam>
#         <sysCode>89</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>1d9ab223-78c5-4a0d-9be2-a94bab6b57ea</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/1d9ab223-78c5-4a0d-9be2-a94bab6b57ea</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-17T11:55:19Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10602851"/>
#     <content type="application/xml">
#       <zaal id="1d9ab223-78c5-4a0d-9be2-a94bab6b57ea" bijgewerkt="2021-06-17T13:54:37.8000000" verwijderd="false">
#         <naam>Den Uylzaal</naam>
#         <sysCode>60</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>52b03fec-dd66-4190-866b-cda7f2c79db9</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/52b03fec-dd66-4190-866b-cda7f2c79db9</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-18T08:05:47Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10610909"/>
#     <content type="application/xml">
#       <zaal id="52b03fec-dd66-4190-866b-cda7f2c79db9" bijgewerkt="2021-06-18T10:04:49.7930000" verwijderd="false">
#         <naam>Thorbeckezaal</naam>
#         <sysCode>94</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>5d2a8166-4e2f-4a1d-8437-1888d2f4f720</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/5d2a8166-4e2f-4a1d-8437-1888d2f4f720</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-18T09:10:36Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10612207"/>
#     <content type="application/xml">
#       <zaal id="5d2a8166-4e2f-4a1d-8437-1888d2f4f720" bijgewerkt="2021-06-18T11:09:52.3800000" verwijderd="false">
#         <naam>K4</naam>
#         <sysCode>370</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>c3b9da32-11c6-445f-8018-b65517b108e9</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/c3b9da32-11c6-445f-8018-b65517b108e9</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-18T09:25:48Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10612551"/>
#     <content type="application/xml">
#       <zaal id="c3b9da32-11c6-445f-8018-b65517b108e9" bijgewerkt="2021-06-18T11:24:53.9370000" verwijderd="false">
#         <naam>Petitie Statenpassage</naam>
#         <sysCode>237</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>abef31fc-88c5-4149-ae74-359df4105f59</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/abef31fc-88c5-4149-ae74-359df4105f59</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-18T11:00:50Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10614468"/>
#     <content type="application/xml">
#       <zaal id="abef31fc-88c5-4149-ae74-359df4105f59" bijgewerkt="2021-06-18T12:59:54.7800000" verwijderd="false">
#         <naam>Groen van Prinstererzaal</naam>
#         <sysCode>95</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>b4076a1c-371e-4ad1-83d9-adfd3f8fffc3</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/b4076a1c-371e-4ad1-83d9-adfd3f8fffc3</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-18T11:40:23Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10614824"/>
#     <content type="application/xml">
#       <zaal id="b4076a1c-371e-4ad1-83d9-adfd3f8fffc3" bijgewerkt="2021-06-18T13:39:55.0930000" verwijderd="false">
#         <naam>Troelstrazaal</naam>
#         <sysCode>96</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>a6c79d16-f968-417a-b604-3f28d143a5d4</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/a6c79d16-f968-417a-b604-3f28d143a5d4</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-18T19:20:21Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10618521"/>
#     <content type="application/xml">
#       <zaal id="a6c79d16-f968-417a-b604-3f28d143a5d4" bijgewerkt="2021-06-18T21:20:18.6470000" verwijderd="false">
#         <naam>Tilanuskamer</naam>
#         <sysCode>88</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>0202177b-ac53-46c4-9e14-390127c44360</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/0202177b-ac53-46c4-9e14-390127c44360</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-18T19:20:21Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10618522"/>
#     <content type="application/xml">
#       <zaal id="0202177b-ac53-46c4-9e14-390127c44360" bijgewerkt="2021-06-18T21:20:12.9270000" verwijderd="false">
#         <naam>Vondelingkamer</naam>
#         <sysCode>86</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>a78a762d-6d94-4492-8ba8-d81e7bfec0fa</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/a78a762d-6d94-4492-8ba8-d81e7bfec0fa</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-25T12:59:02Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10664573"/>
#     <content type="application/xml">
#       <zaal id="a78a762d-6d94-4492-8ba8-d81e7bfec0fa" bijgewerkt="2021-06-25T14:58:18.0500000" verwijderd="false">
#         <naam>(Nog) geen zaal beschikbaar</naam>
#         <sysCode>240</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>fa795714-6049-4a78-a02c-07b117abd9ac</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/fa795714-6049-4a78-a02c-07b117abd9ac</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-06-29T08:15:20Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10675806"/>
#     <content type="application/xml">
#       <zaal id="fa795714-6049-4a78-a02c-07b117abd9ac" bijgewerkt="2021-06-29T10:14:37.1270000" verwijderd="false">
#         <naam>Max van der Stoelzaal</naam>
#         <sysCode>391</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>091e45d7-0451-41d3-a45c-0dca271e39db</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/091e45d7-0451-41d3-a45c-0dca271e39db</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-07-08T06:42:59Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10755244"/>
#     <content type="application/xml">
#       <zaal id="091e45d7-0451-41d3-a45c-0dca271e39db" bijgewerkt="2021-07-08T08:42:01.1570000" verwijderd="false">
#         <naam>Groen van Prinstererzaal</naam>
#         <sysCode>418</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>192bfff7-4cc1-457f-b889-7b7c9033399c</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/192bfff7-4cc1-457f-b889-7b7c9033399c</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2021-09-03T09:47:55Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=10910217"/>
#     <content type="application/xml">
#       <zaal id="192bfff7-4cc1-457f-b889-7b7c9033399c" bijgewerkt="2021-09-03T11:47:05.5200000" verwijderd="false">
#         <naam>VVD Fractiekamer</naam>
#         <sysCode>61</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>6a528771-d839-4c5c-9072-0519fa88c0be</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/6a528771-d839-4c5c-9072-0519fa88c0be</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2022-03-30T14:16:33Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=12203279"/>
#     <content type="application/xml">
#       <zaal id="6a528771-d839-4c5c-9072-0519fa88c0be" bijgewerkt="2022-03-30T16:16:01.3030000" verwijderd="false">
#         <naam>Klompézaal</naam>
#         <sysCode>74</sysCode>
#       </zaal>
#     </content>
#   </entry>
#   <entry>
#     <title>badf4c46-43c8-4d31-94d2-2a7090522a69</title>
#     <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/badf4c46-43c8-4d31-94d2-2a7090522a69</id>
#     <author>
#       <name>Tweede Kamer der Staten-Generaal</name>
#     </author>
#     <updated>2023-03-29T08:10:29Z</updated>
#     <category term="zaal"/>
#     <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Zaal&amp;skiptoken=15820640"/>
#     <content type="application/xml">
#       <zaal id="badf4c46-43c8-4d31-94d2-2a7090522a69" bijgewerkt="2023-03-29T10:09:57.4730000" verwijderd="false">
#         <naam>Balzaal</naam>
#         <sysCode>105</sysCode>
#       </zaal>
#     </content>
#   </entry>
# </feed>

# %% [markdown]
# ## OData interface

# %% [markdown]
# The SyncFeed API is perfectly functional, though it leaves you to do interpretation of the relations yourself,
# so let's see if the OData API is any more help.
#
# There is a helpful library out there, [tkapi](https://github.com/openkamer/tkapi) (MIT license), that means we don't have to implement it ourselves.
#
# Note that neither API is is a very efficient interface
# when you want to sift through the entire collection of data in ways it was not initially designed for,
# aldo why it might be valuable to make some datasets from this later.
#
# ...but this one _is_ a little more help along the way.

# %%
# !pip3 install tkapi

# %%
import tkapi, tkapi.document   
from tkapi.document import DocumentSoort
api = tkapi.TKApi()

# %%
# The document types are function calls, to wit:
list(name   for name in dir(api)   if name.startswith('get_'))
# Out:
# ['get_activiteiten',
#  'get_agendapunten',
#  'get_all_items',
#  'get_antwoorden',
#  'get_besluiten',
#  'get_commissies',
#  'get_documenten',
#  'get_dossiers',
#  'get_fractie_zetels',
#  'get_fracties',
#  'get_geschenken',
#  'get_item',
#  'get_items',
#  'get_kamervragen',
#  'get_personen',
#  'get_reizen',
#  'get_related',
#  'get_stemmingen',
#  'get_vergaderingen',
#  'get_verslagen',
#  'get_verslagen_van_algemeen_overleg',
#  'get_zaken']

# %%
dossiers = api.get_dossiers( )
len(dossiers)  # a few thousand, which is why this takes a few secdonds to fetch
# Out:
# 6851

# %%
# Let's get a basic summary of dossiers. 
#    we find out apparently  dossier nummers  are not unique without the  toevoeging
for dossier in sorted(dossiers, key=lambda dossier:str(dossier.nummer)+(dossier.toevoeging or '')):   #[:200]: # show a few hundred, not all
    nummer_toevoeging = ('%s-%s'%(dossier.nummer, dossier.toevoeging or '')).rstrip('-')
    print( "== Dossier %s == %s =="%( nummer_toevoeging, dossier.titel) )
    print( '  ',dossier.url.replace(')','%29') ) # the replace is to make the notebook's url include the final bracket
    #for doci, document in enumerate(dossier.documenten):
    #    print( '   ',doci, 'bestand_url', document.bestand_url )
# Out:
# == Dossier 17050 == Misbruik en oneigenlijk gebruik op het gebied van belastingen, sociale zekerheid en subsidies ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(58cf1611-70a0-436a-ba73-f5e0819fd2a9%29
# == Dossier 17257 == Assemblee van de West-Europese Unie ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(2af0d9a4-cccc-416b-870d-393e1299d540%29
# == Dossier 18031 == Onderzoek militaire missie Suriname ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(a77d0458-31d5-43ca-8b6d-3061ec8f8efe%29
# == Dossier 18106 == Voortgang rivierdijkversterkingen ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(3698cafd-4ffd-428c-9459-4aa205d98ef0%29
# == Dossier 19291 == Parlementaire Assemblée van de NAVO ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(b85f8944-7c73-47dc-8055-ed28bc901fc0%29
# == Dossier 19637 == Vreemdelingenbeleid ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(7eb61ff4-c6c3-476f-8123-fd5394fd0e1a%29
# == Dossier 20043 == Parlementaire Vergadering van de Raad van Europa ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier
==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(1c8cb49c-949b-4127-8dbb-333c11f4ed76%29
# == Dossier 36430 == Wijziging van de Algemene nabestaandenwet en de Participatiewet in verband met het in 2024 niet afbouwen van de dubbele algemene heffingskorting in het referentieminimumloon ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(4a65053a-9705-4974-a35f-55cb4a00f0f8%29
# == Dossier 36431 == Wijziging van de Wet op het kindgebonden budget tot intensivering van het kindgebonden budget in verband met koopkrachtondersteuning ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(f8972fa8-db53-4caf-ba65-704afa9c6220%29
# == Dossier 36432 == Wijziging van de Wet belastingen op milieugrondslag (Wet fiscale klimaatmaatregelen industrie en elektriciteit) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(2327a075-3fbb-4dfa-bbb5-8010d9a7aa9c%29
# == Dossier 36433 == Wijziging van Boek 3 van het Burgerlijk Wetboek en van Boek 3 van het Burgerlijk Wetboek BES in verband met het toekennen van preferentie aan de vorderingen ter zake van de verschuldigde uitkeringen tot voorziening in de kosten van levensonderhoud van minderjarige kinderen en jong meerderjarigen ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(590706a0-02bb-4462-8e73-887aeba440df%29
# == Dossier 36434 == Verslagen van de commissie voor de Verzoekschriften en de Burgerinitiatieven ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(305a2349-e8da-480f-a0c1-97e2cd0a3ba2%29
# == Dossier 36435-A == Wijziging van de begrotingsstaat van het Mobiliteitsfonds voor het jaar 2023 (wijziging samenhangende met Miljoenennota) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(6e812428-f5be-4d2d-8561-3f4e3cbb0331%29
# == Dossier 36435-B == Wijziging van de begrotingsstaat van het gemeentefonds voor het jaar 2023 (wijziging samenhangende met Miljoenennota) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(8c5af133-fada-40af-b14b-547453c5cef7%29
# == Dossier 36435-C == Wijziging van de begrotingsstaat van het provinciefonds voor het jaar 2023 (wijziging samenhangende met Miljoenennota) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(8c0e0aa3-4315-40b8-b78a-01b5fcbac6fd%29
# == Dossier 36435-I == Wijziging van de begrotingsstaat van de Koning (I) voor het jaar 2023 (wijziging samenhangende met Miljoenennota) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(bf086350-6bd2-440f-a034-8f543383458a%29
# == Dossier 36435-IIA == Wijziging van de begrotingsstaat van de Staten-Generaal (IIA) voor het jaar 2023 (wijziging samenhangende met Miljoenennota) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(40867fe7-7b54-4b34-805b-535ced741ccc%29
# == Dossier 36435-IIB == Wijziging van de begrotingsstaat van de overige Hoge Colleges van Staat, Kabinetten van de Gouverneurs en de Kiesraad (IIB) voor het jaar 2023 (wijziging samenhangende met Miljoenennota) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(f0db3343-7fca-45f5-afea-dea52ac1a17f%29
# == Dossier 36435-IV == Wijziging van de begrotingsstaten van Koninkrijksrelaties (IV) en het BES-fonds (H) voor het jaar 2023 (wijziging samenhangende met Miljoenennota) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(4cc356f8-e165-4e99-927a-3af35c573e6a%29
# == Dossier 36435-IX == Wijziging van de begrotingsstaat van het Ministerie van Financiën (IXB) en de begrotingsstaat van Nationale Schuld (IXA) voor het jaar 2023 (wijziging samenhangende met Miljoenennota) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(61f1bfde-711d-4acc-9360-8b0707b5c986%29
# == Dossier 36435-J == Wijziging van de begrotingsstaat van het Deltafonds voor het jaar 2023 (wijziging samenhangende met Miljoenennota) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier
==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(f124dc30-93e9-4313-96d2-5eedbea1a403%29
# == Dossier 36450 == Regels omtrent de instelling van het Adviescollege toetsing regeldruk (Instellingswet Adviescollege toetsing regeldruk) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(923ecddc-7dbd-415b-b4a0-81d7dac583e1%29
# == Dossier 36451 == Uitvoering van verordening (EU) 2022/868 van het Europees Parlement en de Raad van 30 mei 2022 betreffende Europese datagovernance en tot wijziging van Verordening (EU) 2018/1724 (Uitvoeringswet datagovernanceverordening) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(fb129c51-e433-49d4-88ad-f5946ac98ead%29
# == Dossier 36452 == Initiatiefnota van het lid Beckerman: 'Red de camping' ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(c935aa8e-06b5-4432-b34d-696802d32699%29
# == Dossier 36453 == Tijdelijke wet inzake invoering van een belasting op marktinkomsten van inframarginale elektriciteitsproductie overeenkomstig verordening (EU) 2022/1854 van de Raad van 6 oktober 2022 betreffende een noodinterventie in verband met de hoge energieprijzen (PbEU 2022, L 261 I) (Tijdelijke wet inframarginale elektriciteitsheffing) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(3a8a5b7b-3304-441a-a9da-907298f633e4%29
# == Dossier 36454 == Wijziging van de Wet op het hoger onderwijs en wetenschappelijk onderzoek in verband met het schrappen van de grondslag voor kwaliteitsbekostiging in het hoger onderwijs ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(84f7b4a2-98c5-45cd-aa39-0c959bf33d19%29
# == Dossier 36455-(R2188) == Goedkeuring van het op 28 januari 1981 te Straatsburg tot stand gekomen Verdrag tot bescherming van personen met betrekking tot de geautomatiseerde verwerking van persoonsgegevens (Trb. 1988, 7); van het op 10 oktober 2018 te Straatsburg tot stand gekomen Protocol tot wijziging van het Verdrag tot bescherming van personen met betrekking tot de geautomatiseerde verwerking van persoonsgegevens (Trb. 2018, 201 en Trb. 2023, 54) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(b29b6f7d-b192-48c5-b348-10b806146219%29
# == Dossier 36456 == Herijking regels afgesplitste Kamerleden ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(1c4f4bfe-b0d3-4bfb-830c-831888f6e663%29
# == Dossier 36457 == Voorstel van wet van het lid Ellian tot wijziging van de Penitentiaire beginselenwet in verband met de toevoeging van een regeling ter aanscherping van het regime in extra beveiligde inrichtingen en afdelingen intensief toezicht (Wet Aanscherping EBI- en AIT-regime) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(25ec578f-7907-41b6-9347-8654f85d0341%29
# == Dossier 36458 == Wijziging van de Wet tegemoetkomingen loondomein teneinde het lage inkomensvoordeel te laten vervallen en in verband met enkele andere wijzigingen ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(87e099d5-f150-4c04-85ee-7f9c3ca011ff%29

# %%
# Let's say that our interest is finding what Raad van State has to say about wetsvoorstellen.
#   and also to find out what kind of documents there are in each dossier.
#
# We start by selecting dossiers where there already _is_ RvS advice.
#  - this is a decent filter for wetsvoorstellen
#  - and filters out wetsvoorstellen that don't need this advice (e.g. begroting)
# ...but we are about to find out    
# - there are other things that RVS advises on, like finances (see e.g. 36200) 
# - there are law changes that RVS does not advise on (e.g. TODO)


sorted_dossiers = sorted(dossiers, key=lambda d:d.nummer, reverse=True )

for dossier in sorted_dossiers:
    nummer_toevoeging = ('%s-%s'%(dossier.nummer, dossier.toevoeging or '')).rstrip('-')

    if (dossier.nummer%100) == 0: # ignore some specific special cases for now, because they're large
        continue

    sorted_docs = sorted(dossier.documenten, key=lambda d:d.volgnummer )
    has_raadvanstate = False
    for document in sorted_docs:
        try:
            # these come from an enum, try  list( tkapi.document.DocumentSoort )  to see a list
            if document.soort in (DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE, 
                                  #DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_NADER_RAPPORT, # seems to be begrotingstuff?  (TODO: check)
                                  DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS,
                                ):
                has_raadvanstate = True
        except ValueError: # there's some invalid / non-covered soort values in the data
            pass # ignore
        # we can filter on more, but we may not need to?
    if not has_raadvanstate:
        continue
    
    # if it passed that, it's probably interesting to us.
    #if len(sorted_docs)>500:
    #    print( "\n\n== Dossier %s == %s =="%( dossier.nummer, dossier.titel) )
    #    print(' LARGE: %d documents'%len(sorted_docs))
    #    print(' %s ({{kamerdossier|%d}}'%(dossier.titel, dossier.nummer))
    #    continue

    print( "\n== %r == Dossier %s == %d docs == %s =="%( dossier.id, nummer_toevoeging, len(dossier.documenten), dossier.titel) )
    for document in sorted_docs:
        try:
            if 0: # just to make the summaries a little easier to read
                if document.soort in (DocumentSoort.MOTIE, DocumentSoort.AMENDEMENT, DocumentSoort.BRIEF_REGERING, DocumentSoort.VERSLAG_VAN_EEN_ALGEMEEN_OVERLEG,
                                    DocumentSoort.MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL,
                                    ):
                    continue
        except ValueError:
            print( "soort not known by tkapi")
            continue

        try:
            docsoort = document.soort
        except ValueError: # this seems to be internal inconsistency
            continue

        if True or docsoort in (DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE, 
                              DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS):

            print( '#%s'%(document.volgnummer, ), document.soort.name)
            #print( 'soort', document.soort.name, '(%s)'%document.soort.value )
            print( '  onderwerp', document.onderwerp )     # for wetsvoorstel-dossiers, seems to often be the same as soort plus some detail (who a letter is from, who )
            print( '  citeertitel',document.titel_citeer ) # for wetsvoorstel-dossiers, this often seems to name the law. Or a related one, see e.g. 36195
            print( '  titel',document.titel )              # for wetsvoorstel-dossiers, this seems to often name the law, plus some reason
            #print( 'versies', document.versies )
            print( '  url', document.bestand_url )
            if 0:        # It may be interesting to know the document is part of multiple dossiers and/or multiple zaken
                print( '  zaken', document.zaken )
                #nums = document.dossier_nummers
                #nums.pop(dossier.nummer)
                #if len(nums)>0:
                #  print( "  also in dossiers: %s"%nums )

            print()
# Out:
# == '87a7ff74-bf81-4e71-a69e-2439ce536c2c' == Dossier 36346 == 5 docs == Voorstel van wet van het lid Van Houwelingen betreffende het houden van een raadplegend referendum over het Nederlandse lidmaatschap van de Europese Unie (Wet raadplegend referendum Nederlands EU-lidmaatschap) ==
# #1 GELEIDENDE_BRIEF
#   onderwerp Geleidende brief
#   citeertitel Wet raadplegend referendum Nederlands EU-lidmaatschap
#   titel Voorstel van wet van het lid Van Houwelingen betreffende het houden van een raadplegend referendum over het Nederlandse lidmaatschap van de Europese Unie (Wet raadplegend referendum Nederlands EU-lidmaatschap)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2416f81d-4ee0-4111-a00b-c412992ed7ac)/TK.DA.GGM.OData.Resource()
#
# #2 VOORSTEL_VAN_WET_INITIATIEFVOORSTEL
#   onderwerp Voorstel van wet
#   citeertitel Wet raadplegend referendum Nederlands EU-lidmaatschap
#   titel Voorstel van wet van het lid Van Houwelingen betreffende het houden van een raadplegend referendum over het Nederlandse lidmaatschap van de Europese Unie (Wet raadplegend referendum Nederlands EU-lidmaatschap)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4c873fd9-a1e3-4357-977e-81414ae70199)/TK.DA.GGM.OData.Resource()
#
# #3 MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL
#   onderwerp Memorie van toelichting
#   citeertitel Wet raadplegend referendum Nederlands EU-lidmaatschap
#   titel Voorstel van wet van het lid Van Houwelingen betreffende het houden van een raadplegend referendum over het Nederlandse lidmaatschap van de Europese Unie (Wet raadplegend referendum Nederlands EU-lidmaatschap)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e1e462c2-c498-4a01-89e3-81644c5468e8)/TK.DA.GGM.OData.Resource()
#
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel Wet raadplegend referendum Nederlands EU-lidmaatschap
#   titel Voorstel van wet van het lid Van Houwelingen betreffende het houden van een raadplegend referendum over het Nederlandse lidmaatschap van de Europese Unie (Wet raadplegend referendum Nederlands EU-lidmaatschap)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bd0dbb7d-bbbe-4aa3-8e28-ba55df7756e3)/TK.DA.GGM.OData.Resource()
#
# #5 VERSLAG_INITIATIEFWETSVOORSTEL_NADER
#   onderwerp Verslag
#   citeertitel Wet raadplegend referendum Nederlands EU-lidmaatschap
#   titel Voorstel van wet van het lid Van Houwelingen betreffende het houden van een raadplegend referendum over het Nederlandse lidmaatschap van de Europese Unie (Wet raadplegend referendum Nederlands EU-lidmaatschap)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4a160a52-8bc4-4df3-8b37-2af567f32860)/TK.DA.GGM.OData.Resource()
#
#
# == '759d319b-389a-494e-b69e-2ed3f5291b27' == Dossier 36195 == 32 docs == Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten (Wet vaste huurcontracten) ==
# #1 GELEIDENDE_BRIEF
#   onderwerp Geleidende brief
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(fc090fca-5b8e-441c-bf48-bb2d592855f8)/TK.DA.GGM.OData.Resource()
#
# #2 VOORSTEL_VAN_WET_INITIATIEFVOORSTEL
#   onderwerp Voorstel van wet
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5d4e1533-f2ee-443c-b9f9-abcd45ed41b2)/TK.DA.GGM.OData.Resource()
#
# #3 MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL
#   onderwerp Memorie van toelichting
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6f43500f-1cee-4843-be78-f1e4b22c717d)/TK.DA.GGM.OData.Resource()
#
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bf72af35-dbb5-49a3-87b0-b7c834cd6ec0)/TK.DA.GGM.OData.Resource()
#
# #5 MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL
#   onderwerp Memorie van toelichting zoals gewijzigd naar aanleiding van het advies van de Afdeling advisering van de Raad van State
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(fbeb64c2-59d1-4241-99e3-6e24cb9486bc)/TK.DA.GGM.OData.Resource()
#
# #6 VERSLAG_INITIATIEFWETSVOORSTEL_NADER
#   onderwerp Verslag
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8b664692-c648-4fe3-a9af-d23328139183)/TK.DA.GGM.OData.Resource()
#
# #7 NOTA_NAV_HET_NADERTWEEDE_NADERENZ_VERSLAG
#   onderwerp Nota naar aanleiding van het verslag
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0efa528d-e5f2-4a10-af4b-0b2b104e7e86)/TK.DA.GGM.OData.Resource()
#
# #8 AMENDEMENT
#   onderwerp Amendement van het lid Beckerman over het afschaffen van een aantal doelgroepcontracten
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f22168c5-b5f6-4052-b63e-d3b384687d53)/TK.DA.GGM.OData.Resource()
#
# #9 AMENDEMENT
#   onderwerp Amendement van het lid Beckerman over het laten vervallen van de wettelijke opzeggingsgrond voor huurcontracten voor flexwoningen
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e9ae8611-7172-44a9-b89e-e7845c5bde20)/TK.DA.GGM.OData.Resource()
#
# #10 AMENDEMENT
#   onderwerp Amendement van het lid Beckerman over het afschaffen van het tijdelijk verhuren van een onzelfstandige woonruimte
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(580e4d11-d667-4ab8-8695-198722981127)/TK.DA.GGM.OData.Resource()
#
# #11 AMENDEMENT
#   onderwerp Amendement van het lid Geurts over dat tijdelijke verhuur mogelijk blijft voor aangewezen categorieën personen
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ac9a3667-8657-4da5-9944-b636ca03f2a7)/TK.DA.GGM.OData.Resource()
#
# #12 NOTA_VAN_WIJZIGING
#   onderwerp Nota van wijziging
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(19274fca-1d53-4a92-be05-09b50c1133ec)/TK.DA.GGM.OData.Resource()
#
# #13 MOTIE
#   onderwerp Motie van het lid Boulakjar over in gesprek met gemeenten meer ruimte creëren voor kamerverhuur met campuscontracten
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ff959381-b9d9-49b1-97ff-ed0252b6f7b3)/TK.DA.GGM.OData.Resource()
#
# #14 MOTIE
#   onderwerp Motie van het lid Beckerman over de Monitor Tijdelijke Verhuur continueren
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ef32030c-be08-4a99-9216-aa23f9b6daf6)/TK.DA.GGM.OData.Resource()
#
# #15 MOTIE
#   onderwerp Motie van het lid Peter de Groot over het effect van de stapeling en aanscherping van huurwetten op het aanbod van huurwoningen monitoren
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ecfcb937-f7f7-4640-a3ae-73f1864146a3)/TK.DA.GGM.OData.Resource()
#
# #19 AMENDEMENT
#   onderwerp Amendement van de leden Peter de Groot en Geurts over de uitbreiding van de diplomatenclausule voor de mogelijkheid tot verkoop
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c9304076-a69b-4672-a283-7151a5e62619)/TK.DA.GGM.OData.Resource()
#
# #21 AMENDEMENT
#   onderwerp Amendement van de leden Geurts en Peter de Groot over de uitbreiding van de diplomatenclausule voor de mogelijkheid om een woning door een bloed- of aanverwant te laten betrekken
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5a9ab28c-9b9d-4972-9a0e-40428cd8ec77)/TK.DA.GGM.OData.Resource()
#
# #23 BRIEF_LID__FRACTIE
#   onderwerp Brief van de leden Nijboer en Grinwis over reactie op het amendement van de leden Peter de Groot en Geurts over uitbreiding van de diplomatenclausule voor de mogelijkheid tot verkoop (Kamerstuk 36195-19) en het gewijzigd amendement van de leden Geurts en Peter de Groot over de uitbreiding van de diplomatenclausule voor de mogelijkheid om een woning door een bloed- of aanverwant te laten betrekken (Kamerstuk 36195-22)
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7c5b5fb2-f495-4e74-9e88-a0781a8b2ee0)/TK.DA.GGM.OData.Resource()
#
# #25 AMENDEMENT
#   onderwerp Amendement van het lid Inge van Dijk over het uitbreiden van de diplomatenclausule indien de verhuurder voorafgaand aan de huurperiode gedurende een periode van twee jaar als eigenaar in de woning heeft gewoond
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a2dce504-b85b-4b7c-b357-65995651d733)/TK.DA.GGM.OData.Resource()
#
# #26 NOTA_VAN_WIJZIGING_INITIATIEFVOORSTEL
#   onderwerp Tweede nota van wijziging
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(da979fa3-143b-47a2-b19c-5a70469dcb08)/TK.DA.GGM.OData.Resource()
#
# #30 BRIEF_REGERING
#   onderwerp Appreciatie van de ingediende amendementen bij het initiatiefwetvoorstel Wet vaste huurcontracten van de leden Nijboer en Grinwis
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c1315ee8-b0d2-4ad3-a007-2807deeff6b1)/TK.DA.GGM.OData.Resource()
#
# #33 BRIEF_REGERING
#   onderwerp Overzicht tijdelijke huurcontracten
#   citeertitel Wet vaste huurcontracten
#   titel Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten (Wet vaste huurcontracten)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2c60cf6c-d550-47ad-9d63-cb6382d18223)/TK.DA.GGM.OData.Resource()
#
#
# == 'bf967829-e330-46a1-989b-3b9e688dd411' == Dossier 36178 == 6 docs == Voorstel van wet van de leden Van der Laan, Van der Woude, De Hoop, Westerveld, Kwint en Van Esch tot wijziging van het Wetboek van Strafrecht en enige andere wetten in verband met het strafbaar stellen van handelingen gericht op het veranderen of onderdrukken van de seksuele gerichtheid, genderidentiteit of genderexpressie (Wet strafbaarstelling conversiehandelingen) ==
# #1 GELEIDENDE_BRIEF
#   onderwerp Geleidende brief
#   citeertitel Wet strafbaarstelling conversiehandelingen
#   titel Voorstel van wet van de leden Van der Laan, Van der Woude, De Hoop, Westerveld, Kwint en Van Esch tot wijziging van het Wetboek van Strafrecht en enige andere wetten in verband met het strafbaar stellen van handelingen gericht op het veranderen of onderdrukken van de seksuele gerichtheid, genderidentiteit of genderexpressie (Wet strafbaarstelling conversiehandelingen)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document

#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(27d1b89a-7f7b-4eb2-a33f-78ed76982e25)/TK.DA.GGM.OData.Resource()
#
#
# == 'cc270778-4153-4d65-af77-fe3519a32b76' == Dossier 36161 == 7 docs == Voorstel van wet van de leden Baudet en Van Houwelingen houdende regels inzake een breed raadgevend referendum (Wet raadgevend referendum naar Zwitsers model) ==
# #1 GELEIDENDE_BRIEF
#   onderwerp Geleidende brief
#   citeertitel Wet raadgevend referendum naar Zwitsers model
#   titel Voorstel van wet van de leden Baudet en Van Houwelingen houdende regels inzake een breed raadgevend referendum (Wet raadgevend referendum naar Zwitsers model)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(22b27376-ca7a-4589-853c-0d18b2218425)/TK.DA.GGM.OData.Resource()
#
# #2 VOORSTEL_VAN_WET_INITIATIEFVOORSTEL
#   onderwerp Voorstel van wet
#   citeertitel Wet raadgevend referendum naar Zwitsers model
#   titel Voorstel van wet van de leden Baudet en Van Houwelingen houdende regels inzake een breed raadgevend referendum (Wet raadgevend referendum naar Zwitsers model)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(353e8cd6-e63e-47d5-91d9-6fb0bfb44f5c)/TK.DA.GGM.OData.Resource()
#
# #3 MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL
#   onderwerp Memorie van toelichting
#   citeertitel Wet raadgevend referendum naar Zwitsers model
#   titel Voorstel van wet van de leden Baudet en Van Houwelingen houdende regels inzake een breed raadgevend referendum (Wet raadgevend referendum naar Zwitsers model)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0ff9bb80-dd26-4e0e-85ab-c72795ef14e4)/TK.DA.GGM.OData.Resource()
#
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel Wet raadgevend referendum naar Zwitsers model
#   titel Voorstel van wet van de leden Baudet en Van Houwelingen houdende regels inzake een breed raadgevend referendum (Wet raadgevend referendum naar Zwitsers model)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(92f3980e-07d2-4e10-8b40-e7d5953961c4)/TK.DA.GGM.OData.Resource()
#
# #5 VERSLAG_INITIATIEFWETSVOORSTEL_NADER
#   onderwerp Verslag
#   citeertitel Wet raadgevend referendum naar Zwitsers model
#   titel Voorstel van wet van de leden Baudet en Van Houwelingen houdende regels inzake een breed raadgevend referendum (Wet raadgevend referendum naar Zwitsers model)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(39e64c4b-4b00-4fcf-bc0a-83c7f4ee2928)/TK.DA.GGM.OData.Resource()
#
# #6 NOTA_NAV_HET_NADERTWEEDE_NADERENZ_VERSLAG
#   onderwerp Nota naar aanleiding van het verslag
#   citeertitel Wet raadgevend referendum naar Zwitsers model
#   titel Voorstel van wet van de leden Baudet en Van Houwelingen houdende regels inzake een breed raadgevend referendum (Wet raadgevend referendum naar Zwitsers model)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8c0aae73-459e-41bf-8a62-766fa12b156c)/TK.DA.GGM.OData.Resource()
#
# #7 NOTA_VAN_WIJZIGING_INITIATIEFVOORSTEL
#   onderwerp Nota van wijziging
#   citeertitel Wet raadgevend referendum naar Zwitsers model
#   titel Voorstel van wet van de leden Baudet en Van Houwelingen houdende regels inzake een breed raadgevend referendum (Wet raadgevend referendum naar Zwitsers model)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(61166d2f-b18d-4fdc-b082-fe0798937c1c)/TK.DA.GGM.OData.Resource()
#
#
# == '06397d33-825c-47ec-ae31-6b186a4a06dd' == Dossier 36160 == 15 docs == Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum ==
# #1 GELEIDENDE_BRIEF
#   onderwerp Geleidende brief
#   citeertitel
#   titel Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d8b8acd9-7ae1-4f63-a3f4-9ffd6954a3af)/TK.DA.GGM.OData.Resource()
#
# #2 VOORSTEL_VAN_WET_INITIATIEFVOORSTEL
#   onderwerp Voorstel van wet
#   citeertitel
#   titel Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c064a462-793f-449d-ad2f-fe2298dc87b6)/TK.DA.GGM.OData.Resource()
#
# #3 MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL
#   onderwerp Memorie van toelichting
#   citeertitel
#   titel Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(758e9162-716c-4060-b3c6-f97423a3117e)/TK.DA.GGM.OData.Resource()
#
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c4b73975-1fb0-4b46-ada1-4d39fdd365ad)/TK.DA.GGM.OData.Resource()
#
# #5 VERSLAG_INITIATIEFWETSVOORSTEL_NADER
#   onderwerp Verslag
#   citeertitel
#   titel Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d1b59712-9050-4a7e-9222-fc98889ec543)/TK.DA.GGM.OData.Resource()
#
# #6 NOTA_NAV_HET_NADERTWEEDE_NADERENZ_VERSLAG
#   onderwerp Nota naar aanleiding van het verslag
#   citeertitel
#   titel Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(02682b2b-6751-4b71-b489-9f8bf6f4513d)/TK.DA.GGM.OData.Resource()
#
# #7 NOTA_VAN_WIJZIGING_INITIATIEFVOORSTEL
#   onderwerp Nota van wijziging
#   citeertitel
#   titel Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1ecbbfa1-898c-4cd6-a244-a4f9263873c8)/TK.DA.GGM.OData.Resource()
#
# #8 BRIEF_LID__FRACTIE
#   onderwerp Brief van het lid Leijten over de stand van zaken van de initiatief zoals die is aangekondigd in de memorie van toelichting bij het Voorstel van wet van het lid Leijten houdende een verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   citeertitel
#   titel Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(03987fb6-3376-4c5f-b7b9-23aa79dcb91e)/TK.DA.GGM.OData.Resource()
#
# #9 NOTA_VAN_WIJZIGING_INITIATIEFVOORSTEL
#   onderwerp Tweede nota van wijziging
#   citeertitel
#   titel Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b638cd37-be2d-48da-bc3f-36edd629f7da)/TK.DA.GGM.OData.Resource()
#
# #10 AMENDEMENT
#   onderwerp Amendement van het lid Bisschop over het schrappen van de mogelijkheid referenda te houden over onderdelen van wetgeving
#   citeertitel
#   titel Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ca491cb9-7c5a-4485-8b14-d05151ed5d36)/TK.DA.GGM.OData.Resource()
#
# #11 AMENDEMENT
#   onderwerp Amendement van het lid Van der Graaf c.s. over facultatieve bindende correctieve referenda voor provincies en gemeenten
#   citeertitel
#   titel Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(72f58982-9606-40a6-b20c-863f8470fb90)/TK.DA.GGM.OData.Resource()
#
# #12 AMENDEMENT
#   onderwerp Amendement Van der Graaf en Chris Simons over een uitkomstdrempel
#   citeertitel
#   titel Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(eb9da90f-11ad-44da-81b2-ca8551266261)/TK.DA.GGM.OData.Resource()
#
# #13 AMENDEMENT
#   onderwerp Amendement van de leden Sneller en Bromet over het uitzonderen van referenda over de goedkeuring van internationale verdragen
#   citeertitel
#   titel Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e1964155-0486-4204-bc34-4413bb86d4e9)/TK.DA.GGM.OData.Resource()
#
# #14 NOTA_VAN_WIJZIGING_INITIATIEFVOORSTEL
#   onderwerp Derde nota van wijziging
#   citeertitel
#   titel Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3e7a4a42-cae5-4354-8d4f-4a7c3e011e61)/TK.DA.GGM.OData.Resource()
#
#
# == '992cfaeb-47f7-41d9-ae24-7905719cfca9' == Dossier 36128 == 10 docs == Voorstel van wet van de leden Maatoug en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen ==
# #1 GELEIDENDE_BRIEF
#   onderwerp Geleidende brief
#   citeertitel
#   titel Voorstel van wet van de leden Maatoug, Van der Lee en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen en het vervangen van het box 2-tarief door een progressief tarief
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4a77bf06-4a10-4ab3-a1ca-f9242765f488)/TK.DA.GGM.OData.Resource()
#
# #2 VOORSTEL_VAN_WET_INITIATIEFVOORSTEL
#   onderwerp Voorstel van wet
#   citeertitel
#   titel Voorstel van wet van de leden Maatoug, Van der Lee en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen en het vervangen van het box 2-tarief door een progressief tarief
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3846a7b9-fc05-4624-bd7c-6cc3a3910604)/TK.DA.GGM.OData.Resource()
#
# #3 MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL
#   onderwerp Memorie van toelichting
#   citeertitel
#   titel Voorstel van wet van de leden Maatoug, Van der Lee en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen en het vervangen van het box 2-tarief door een progressief tarief
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a472f28d-371f-47f6-9dcc-70170efc7df5)/TK.DA.GGM.OData.Resource()
#
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel Voorstel van wet van de leden Maatoug, Van der Lee en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen en het vervangen van het box 2-tarief door een progressief tarief
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(21766f02-9869-4df9-a59f-94d2330f7a08)/TK.DA.GGM.OData.Resource()
#
# #5 VOORSTEL_VAN_WET_INITIATIEFVOORSTEL
#   onderwerp Voorstel van wet zoals gewijzigd naar aanleiding van het advies van de Afdeling Advisering van de Raad van State
#   citeertitel
#   titel Voorstel van wet van de leden Maatoug, Van der Lee en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen en het vervangen van het box 2-tarief door een progressief tarief
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(72d18851-e7bc-4859-be70-3d11a342468f)/TK.DA.GGM.OData.Resource()
#
# #6 MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL
#   onderwerp Memorie van toelichting zoals gewijzigd naar aanleiding van het advies van de Afdeling advisering van de Raad van State
#   citeertitel
#   titel Voorstel van wet van de leden Maatoug, Van der Lee en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen en het vervangen van het box 2-tarief door een progressief tarief
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c04ad43f-5656-45c6-9f28-8f6c170a6d1b)/TK.DA.GGM.OData.Resource()
#
# #7 VERSLAG_INITIATIEFWETSVOORSTEL_NADER
#   onderwerp Verslag
#   citeertitel
#   titel Voorstel van wet van de leden Maatoug, Van der Lee en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3d07e399-dee7-47f6-9254-4e1e61f0c430)/TK.DA.GGM.OData.Resource()
#
# #8 NOTA_NAV_HET_NADERTWEEDE_NADERENZ_VERSLAG
#   onderwerp Nota naar aanleiding van het verslag
#   citeertitel
#   titel Voorstel van wet van de leden Maatoug, Van der Lee en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(645ac4c6-bc0e-409a-a9c0-b0cb73e92b06)/TK.DA.GGM.OData.Resource()
#
# #9 BRIEF_LID__FRACTIE
#   onderwerp Brief van de leden Maatoug, Van der Lee en Nijboer inzake de verdediging van het initiatiefvoorstel
#   citeertitel
#   titel Voorstel van wet van de leden Maatoug, Van der Lee en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(618fb5fc-d65e-4d39-a9ca-f80e4b4775b5)/TK.DA.GGM.OData.Resource()
#
# #10 NOTA_VAN_WIJZIGING_INITIATIEFVOORSTEL
#   onderwerp Nota van wijziging
#   citeertitel
#   titel Voorstel van wet van de leden Maatoug en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(caafa2b4-864d-4a9d-98cd-1611d88aa2e3)/TK.DA.GGM.OData.Resource()
#
#
# == '77900319-43c1-4121-8d58-883970285392' == Dossier 36125 == 6 docs == Voorstel van wet van het lid Sneller tot wijziging van de Wet op de rechterlijke organisatie in verband met het laten vervallen van de bijzondere aanwijzingsbevoegdheid van de minister met betrekking tot de uitoefening van de taken en bevoegdheden van het openbaar ministerie (Wet verval bijzondere aanwijzingsbevoegdheid openbaar ministerie) ==
# #1 GELEIDENDE_BRIEF
#   onderwerp Geleidende brief
#   citeertitel Wet verval bijzondere aanwijzingsbevoegdheid openbaar ministerie
#   titel Voorstel van wet van het lid Sneller tot wijziging van de Wet op de rechterlijke organisatie in verband met het laten vervallen van de bijzondere aanwijzingsbevoegdheid van de minister met betrekking tot de uitoefening van de taken en bevoegdheden van het openbaar ministerie (Wet verval bijzondere aanwijzingsbevoegdheid openbaar ministerie)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(

#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cb1e2cbb-5da5-417e-83d8-efcd557db95a)/TK.DA.GGM.OData.Resource()
#
#
# == 'ad0b6d7d-4132-4f09-84ac-1cbb6927994c' == Dossier 36052 == 8 docs == Voorstel van wet van het lid Van Houwelingen houdende splitsing van de gemeente Groningen en instelling van de gemeente Haren ==
# #1 GELEIDENDE_BRIEF
#   onderwerp Geleidende brief
#   citeertitel
#   titel Voorstel van wet van het lid Van Houwelingen houdende splitsing van de gemeente Groningen en instelling van de gemeente Haren
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2c3e3018-b52b-4315-b23a-e12b78d94dbf)/TK.DA.GGM.OData.Resource()
#
# #2 VOORSTEL_VAN_WET_INITIATIEFVOORSTEL
#   onderwerp Voorstel van wet
#   citeertitel
#   titel Voorstel van wet van het lid Van Houwelingen houdende splitsing van de gemeente Groningen en instelling van de gemeente Haren
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2c023127-d884-4c8a-a825-147acca44ff1)/TK.DA.GGM.OData.Resource()
#
# #3 MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL
#   onderwerp Memorie van toelichting
#   citeertitel
#   titel Voorstel van wet van het lid Van Houwelingen houdende splitsing van de gemeente Groningen en instelling van de gemeente Haren
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6cefb58c-4ce8-484c-a81a-46b0833d5e82)/TK.DA.GGM.OData.Resource()
#
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel Voorstel van wet van het lid Van Houwelingen houdende splitsing van de gemeente Groningen en instelling van de gemeente Haren
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(28e4b35d-51b4-4db6-abd3-353e58e219e7)/TK.DA.GGM.OData.Resource()
#
# #5 VERSLAG_INITIATIEFWETSVOORSTEL_NADER
#   onderwerp Verslag
#   citeertitel
#   titel Voorstel van wet van het lid Van Houwelingen houdende splitsing van de gemeente Groningen en instelling van de gemeente Haren
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(55a1cebf-cab3-4993-a466-a1731719a218)/TK.DA.GGM.OData.Resource()
#
# #6 NOTA_NAV_HET_NADERTWEEDE_NADERENZ_VERSLAG
#   onderwerp Nota naar aanleiding van het verslag
#   citeertitel
#   titel Voorstel van wet van het lid Van Houwelingen houdende splitsing van de gemeente Groningen en instelling van de gemeente Haren
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9b3c6122-1ffb-42ce-915c-f58f3894bc6b)/TK.DA.GGM.OData.Resource()
#
# #7 MOTIE
#   onderwerp Motie van het lid Bisschop over altijd een evaluatiebepaling opnemen in een wetsvoorstel voor een gedwongen gemeentelijke herindeling
#   citeertitel
#   titel Voorstel van wet van het lid Van Houwelingen houdende splitsing van de gemeente Groningen en instelling van de gemeente Haren
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6fe2e534-886c-45a2-ae69-5e51f9ee0fd9)/TK.DA.GGM.OData.Resource()
#
# #8 MOTIE
#   onderwerp Motie van het lid Bisschop over een evaluatie van de herindeling van de gemeente Haren door een onafhankelijke instantie zoals de Noordelijke Rekenkamer
#   citeertitel
#   titel Voorstel van wet van het lid Van Houwelingen houdende splitsing van de gemeente Groningen en instelling van de gemeente Haren
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(40cec2ea-87b4-417a-a67a-2460f9f74e04)/TK.DA.GGM.OData.Resource()
#
#
# == 'bebb0654-c0c7-49a3-838a-d3346c0cc7fc' == Dossier 36047 == 11 docs == Voorstel van wet van de leden Sneller en Bushoff tot wijziging van de Kieswet in verband met de permanente invoering van de mogelijkheid voor kiezers om gedurende twee dagen voorafgaand aan de dag van de stemming vervroegd te stemmen in het stemlokaal (Wet vervroegd stemmen in het stemlokaal) ==
# #1 GELEIDENDE_BRIEF
#   onderwerp Geleidende brief
#   citeertitel Wet vervroegd stemmen in het stemlokaal
#   titel Voorstel van wet van de leden Sneller en Kathmann tot wijziging van de Kieswet in verband met de permanente invoering van de mogelijkheid voor kiezers om gedurende twee dagen voorafgaand aan de dag van de stemming vervroegd te stemmen in het stemlokaal (Wet vervroegd stemmen in het stemlokaal)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b4111850-71f1-43bf-b5b2-4c57f7a62dab)/TK.DA.GGM.OData.Resource()
#
# #2 VOORSTEL_VAN_WET_INITIATIEFVOORSTEL
#   onderwerp Voorstel van wet
#   citeertitel Wet vervroegd stemmen in het stemlokaal
#   titel Voorstel van wet van de leden Sneller en Kathmann tot wijziging van de Kieswet in verband met de permanente invoering van de mogelijkheid voor kiezers om gedurende twee dagen voorafgaand aan de dag van de stemming vervroegd te stemmen in het stemlokaal (Wet vervroegd stemmen in het stemlokaal)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c0b430ae-3293-4632-8a12-71923b4cfd43)/TK.DA.GGM.OData.Resource()
#
# #3 MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL
#   onderwerp Memorie van toelichting
#   citeertitel Wet vervroegd stemmen in het stemlokaal
#   titel Voorstel van wet van de leden Sneller en Kathmann tot wijziging van de Kieswet in verband met de permanente invoering van de mogelijkheid voor kiezers om gedurende twee dagen voorafgaand aan de dag van de stemming vervroegd te stemmen in het stemlokaal (Wet vervroegd stemmen in het stemlokaal)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(af84d0cd-0a19-4220-ae37-4646fda8f8ef)/TK.DA.GGM.OData.Resource()
#
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel Wet vervroegd stemmen in het stemlokaal
#   titel Voorstel van wet van de leden Sneller en Kathmann tot wijziging van de Kieswet in verband met de permanente invoering van de mogelijkheid voor kiezers om gedurende twee dagen voorafgaand aan de dag van de stemming vervroegd te stemmen in het stemlokaal (Wet vervroegd stemmen in het stemlokaal)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5af5cab2-077c-4f7b-86c7-f03799cd2d4d)/TK.DA.GGM.OData.Resource()
#
# #5 VERSLAG_INITIATIEFWETSVOORSTEL_NADER
#   onderwerp Verslag
#   citeertitel Wet vervroegd stemmen in het stemlokaal
#   titel Voorstel van wet van de leden Sneller en Kathmann tot wijziging van de Kieswet in verband met de permanente invoering van de mogelijkheid voor kiezers om gedurende twee dagen voorafgaand aan de dag van de stemming vervroegd te stemmen in het stemlokaal (Wet vervroegd stemmen in het stemlokaal)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(79c40a6b-59a8-4f6b-850f-7994392dc1c7)/TK.DA.GGM.OData.Resource()
#
# #6 NOTA_NAV_HET_NADERTWEEDE_NADERENZ_VERSLAG
#   onderwerp Nota naar aanleiding van het verslag
#   citeertitel Wet vervroegd stemmen in het stemlokaal
#   titel Voorstel van wet van de leden Sneller en Kathmann tot wijziging van de Kieswet in verband met de permanente invoering van de mogelijkheid voor kiezers om gedurende twee dagen voorafgaand aan de dag van de stemming vervroegd te stemmen in het stemlokaal (Wet vervroegd stemmen in het stemlokaal)
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(98936ab2-aac6-4e46-b5c0-a5ab983ddb8e)/TK.DA.GGM.OData.Resource()
# ...
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(64f617b6-6033-4870-9753-b97d56b39e49)/TK.DA.GGM.OData.Resource()
#
# #8 NOTA_NAV_HET_NADERTWEEDE_NADERENZ_VERSLAG
#   onderwerp Nota naar aanleiding van het verslag
#   citeertitel
#   titel Voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c29a8814-55ca-405b-9e26-e66ed98d58d0)/TK.DA.GGM.OData.Resource()
#
# #9 NOTA_VAN_WIJZIGING_INITIATIEFVOORSTEL
#   onderwerp Nota van wijziging
#   citeertitel
#   titel Voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(598da509-1082-49fa-a67a-fffcadfff78f)/TK.DA.GGM.OData.Resource()
#
# #10 NOTA_VAN_WIJZIGING_INITIATIEFVOORSTEL
#   onderwerp Tweede nota van wijziging
#   citeertitel
#   titel Voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(eb573fb9-cf40-459c-bf9e-1b3464a762f1)/TK.DA.GGM.OData.Resource()
#
# #11 NOTA_VAN_WIJZIGING_INITIATIEFVOORSTEL
#   onderwerp Derde nota van wijziging
#   citeertitel
#   titel Voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e748c0bc-70e3-4fb4-852a-abd71928cb24)/TK.DA.GGM.OData.Resource()
#
# #12 NOTA_VAN_WIJZIGING
#   onderwerp Vierde nota van wijziging
#   citeertitel
#   titel Voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2ed0e807-8374-4025-b6d6-fea95d4cf653)/TK.DA.GGM.OData.Resource()
#
# #13 AMENDEMENT
#   onderwerp Amendement van de leden Grinwis en Goudzwaard over het behoud van de geborgde zetels doch met een andere verdeling
#   citeertitel
#   titel Voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ee044672-660c-4fb7-babd-ee5e85e0e51f)/TK.DA.GGM.OData.Resource()
#
# #14 MOTIE
#   onderwerp Motie van het lid Minhas c.s. over een eventuele afschaffing van de geborgde zetels pas na 2023 in werking laten treden
#   citeertitel
#   titel Voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bc3b0328-b6f7-4e35-b6ac-087307442454)/TK.DA.GGM.OData.Resource()
#
# #16 AMENDEMENT
#   onderwerp Amendement van het lid Grinwis c.s. over het gedeeltelijk behouden van de geborgde zetels doch met een andere verdeling
#   citeertitel
#   titel Voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(779cd45c-e8a9-4328-98d0-bdc02ce4fd09)/TK.DA.GGM.OData.Resource()
#
# #18 MOTIE
#   onderwerp Motie van het lid Bromet c.s. over inwerkingtreding van het wetsvoorstel nog voor de aankomende waterschapsverkiezingen
#   citeertitel
#   titel Voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(59be727d-2a69-4770-abda-b674b4a77442)/TK.DA.GGM.OData.Resource()
#
# #19 BRIEF_REGERING
#   onderwerp Bekrachtiging van het voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen
#   citeertitel
#   titel Voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen
#   url https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(eb676896-8b01-4db1-837d-9d460f375627)/TK.DA.GGM.OData.Resource()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tkdossiers.ipynb Cell 12 line <cell line: 14>()
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tkdossiers.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> if (dossier.nummer%100) == 0: # ignore some specific special cases for now, because they're large
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tkdossiers.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>     continue
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tkdossiers.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> sorted_docs = sorted(dossier.documenten, key=lambda d:d.volgnummer )
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tkdossiers.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> has_raadvanstate = False
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tkdossiers.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a> for document in sorted_docs:
#
# File /usr/local/lib/python3.8/dist-packages/tkapi/dossier.py:42, in Dossier.documenten(self)
#      40 @property
#      41 def documenten(self) -> List[Document]:
# ---> 42     return self.related_items(Document)
#
# File /usr/local/lib/python3.8/dist-packages/tkapi/core.py:133, in TKItem.related_items(self, tkitem, filter, item_key)
#     131     return self._items_cache[cache_key]
#     132 url = self.json[navigation_key]
# --> 133 items = TKApi().get_related(tkitem, related_url=url, filter=filter)
#     134 self._set_cache(tkitem, filter, items)
#     135 return items
#
# File /usr/local/lib/python3.8/dist-packages/tkapi/tkapi.py:187, in TKApi.get_related(cls, tkitem_related, related_url, filter)
#     185 params = tkitem_related.get_param_expand()
#     186 params = TKApi.add_filter_to_params(filter, params)
# --> 187 first_page = cls._request_json(related_url, params)
#     188 related_items = []
#     189 if 'value' in first_page:
#
# File /usr/local/lib/python3.8/dist-packages/tkapi/tkapi.py:157, in TKApi._request_json(cls, url, params, max_items)
#     155 if cls.api_root.strip().lower() not in url.lower():
#     156     url = cls.api_root + url
# --> 157 response = requests.get(
#     158     url=url,
#     159     params=params,
#     160     timeout=60
#     161 )
#     162 if cls._verbose:
#     163     print('url ({} ms): {}'.format(
#     164         int(response.elapsed.total_seconds() * 1000),
#     165         urllib.parse.unquote(response.url))
#     166     )
#
# File /usr/local/lib/python3.8/dist-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /usr/local/lib/python3.8/dist-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /usr/local/lib/python3.8/dist-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File /usr/local/lib/python3.8/dist-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File /usr/local/lib/python3.8/dist-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File /usr/local/lib/python3.8/dist-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File /usr/lib/python3.8/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File /usr/lib/python3.8/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1037         if timeout == 0.0:
#    1038             # non-blocking
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#    1042     self.close()
#
# File /usr/lib/python3.8/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1307     if timeout == 0.0 and block:
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#    1311     self.settimeout(timeout)
#
# KeyboardInterrupt:
