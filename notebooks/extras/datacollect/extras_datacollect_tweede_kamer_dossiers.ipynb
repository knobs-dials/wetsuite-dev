# %% [markdown]
# # Purpose of this notebook
#
# See what kind of things we can find out from the [tweede kamer open data portal](https://opendata.tweedekamer.nl/).

# %% [markdown]
# There are two interfaces for this: an [Atom-style API called SyncFeed](https://opendata.tweedekamer.nl/documentatie/syncfeed-api), and an [OData API](https://opendata.tweedekamer.nl/documentatie/odata-api).
#
# The Atom API is a little easier to speak yourself, OData can be a little more thorough but more work to use.
#
# The returned formats seem to be XML and JSON.

# %% [markdown]
# Either way, there is a [relational data model](https://opendata.tweedekamer.nl/documentatie/informatiemodel) that you should be thinking of,
# though in this notebook we focus primarily on the dossiers and documents in them, which stays relatively simple.
#
# Because there is a bunch of data referring to other data, much of the below is trying to explore/show
# what kind of interesting things might be in there in the first place.
#
# ...because we probably don't want to just fetch everything,
# we want to show how to figure how to get and use the parts you need for a specific purpose.

# %% [markdown]
# ## Atom/SyncFeed API

# %%
import collections, pprint

from wetsuite.datacollect     import tweedekamer_nl # contains some basic code dealing with this API
from wetsuite.helpers         import etree
from wetsuite.helpers         import strings
from wetsuite.helpers         import notebook

# %% [markdown]
# #### Any one resource type
#
# Fetch all resources of the mentioned soort/category, save into a single .xml file of its name.
#
# There e.g. is [another notebook](extras_datacollect_tweede_kamer_parties.ipynb) that fetches 'Persoon', 'Fractie', 'FractieZetel', and 'FractieZetelPersoon', to extract who is member of what party.
#
# If you wanted a record of what gets done in an everyday way, you might care about 'Vergadering', 'Verslag', 'Stemming',
# or if you are more interested in documentation, then 'Zaak', 'Document', 'Kamerstukdossier'.
#
# For a list with explanation, see [its documentation](https://opendata.tweedekamer.nl/documentatie/).
# For just a list, `see wetsuite.datacollect.tweedekamer_nl.resource_types`.

# %%
# For a quick example, though, let's stick to something with simple ouput

# this function actually does little more stick that soort on a URL and fetch ...repeatedly if necessary
etrees = tweedekamer_nl.fetch_all( 'Zaal' )     
# it returned a list of etree objects,  
# so if our goal were to to write that into a single XML file, we want to merge that
single_tree = tweedekamer_nl.merge_etrees( etrees )  

#There is another function that helps us see each entry's
pprint.pprint( tweedekamer_nl.entries( single_tree ) )

print( etree.debug_pretty( single_tree ) )

#xmlstring = wetsuite.helpers.etree.tostring( single_tree )                # then save that 
#with open('%s.xml'%soort, 'wb') as xf:   # technically injection-sensitive, except it's fine as long as we control the values
#    xf.write( xmlstring )

# %%
from importlib import reload
reload(wetsuite.datacollect.tweedekamer_nl)
for detail_dict in wetsuite.datacollect.tweedekamer_nl.entries( single_tree ):
    print(f"{detail_dict['naam']:40s}    {detail_dict['id']}")
#pprint.pprint( wetsuite.datacollect.tweedekamer_nl.entries( single_tree ) )

# %% [markdown]
# #### Kamerstukdossiers

# %% [markdown]
# Now let's focus on the kamerstukdossiers.
#
# And see what kind of topics we have in there (...so far purely by looking at the text in their title).
#
# (note: we don't actually use this, it's just inspection)

# %%
# Fetch all kamerstukdossiers.    
#   May take half a minute or so to fetch all,
#   because that's ~30 fetches amounting to ~6MByte of XML.
#   and so also let's not print it
single_tree = tweedekamer_nl.merge_etrees( tweedekamer_nl.fetch_all( 'Kamerstukdossier' ) )

# %%
verbose = 0

ourtypes = collections.defaultdict(list)
for i, entry_node in enumerate( single_tree ):
    edict = tweedekamer_nl.entry_dict_from_node( entry_node )

    ksd = entry_node.find('content/kamerstukdossier')
    if verbose:
        print()
        print(etree.debug_pretty(ksd))
        pprint.pprint(edict)

    # exception case:   if that attribute is there, there are no contents
    if ksd.get('verwijderd', None) == 'true':   
        ourtypes['[verwijderd]'].append( ksd.get('id') )
        #print("SKIP verwijderd (%s)"%ksd.get('id'))
        continue 

    try:
        titel = ksd.find('titel').text
    except AttributeError:
        print( 'ERROR: no title? (%r)'%entry_node )
        display( notebook.etree_visualize_selection(ksd, '*', mark_subtree=True) )

    if titel is None:
        print( 'ERROR: dossier without titel (%r)'%entry_node )
        display( notebook.etree_visualize_selection(ksd, '*', mark_subtree=True) )
        continue
    titel = titel.strip()

    if strings.contains_any_of(titel, ['wetsvoorstel', 'voorstel van wet'], case_sensitive=False):
        #print( 'LAW       %-7s %20s  %s'%(ksd.get('nummer'), ksd.get('updated'), titel) )
        ourtypes['wet'].append( titel )
        continue

    elif titel.startswith('Wet '):
        ourtypes['wet'].append( titel ) 
        continue

    elif strings.contains_any_of(titel, ['begrotingssta', 'slotwet', 'voorjaarsnota','najaarsnota', 'Financieel jaarverslag'], case_sensitive=False):
        #print( 'BEGROTING %-7s %20s  %s'%(edict.get('nummer'), edict.get('updated'), titel) )
        ourtypes['begroting'].append( titel )   # up here to not accidentally count wijziging in begrotingsstaat as a law
        continue
    elif strings.contains_any_of(titel, ['omzetbelasting'], case_sensitive=False):
        #print( 'BELASTING %-7s %20s  %s'%(edict.get('nummer'), edict.get('updated'), titel) )
        ourtypes['belasting'].append( titel )
        continue

    elif strings.contains_any_of(titel, ['wetswijziging', 'wijziging van wet ', 'wijziging van de wet ', 'aanpassing van de wet',
                                 'Wijziging van de', # followed by a specifically named law   this one is fuzzier than necessary, might be better to regexp-match
                                 ], case_sensitive=False):
        ourtypes['wet'].append( titel )
        continue
    elif strings.contains_all_of(titel, ['wijziging', 'wetboek'], case_sensitive=False):
        ourtypes['wet'].append( titel )
        continue
    elif strings.contains_all_of(titel, ['wijziging', 'wetten'], case_sensitive=False):
        #print( 'LAW       %-7s %20s  %s'%(ksd.get('nummer'), ksd.get('updated'), titel) )
        ourtypes['wet'].append( titel )
        continue
    elif strings.contains_all_of(titel, ['verbeter', 'wetten'], case_sensitive=False):
        ourtypes['wet'].append( titel )
        continue
    elif strings.contains_all_of(titel, ['aanpassing', ' Wet'], case_sensitive=False):
        ourtypes['wet'].append( titel )
        continue

    elif strings.contains_any_of(titel, ['Initiatiefnota','Interpellatie'], case_sensitive=False):
        ourtypes['discussions'].append( titel )
        continue
    elif strings.contains_any_of(titel, ['burgerinitiatief',], case_sensitive=False):
        ourtypes['discussions'].append( titel )
        continue
    elif strings.contains_any_of(titel, ['EU-voorstel', 'EU voorstel', 'EU-mededeling', 'EU-trendrapport']):
        ourtypes['eu'].append( titel )
        continue
    elif strings.contains_any_of(titel, ['Herindeling van de gemeenten',]):
        ourtypes['local'].append( titel )
        continue

    elif strings.contains_any_of(titel, ['mbudsman',]):
        ourtypes['mbudsman'].append( titel )
        continue

    elif strings.contains_any_of(titel, ['Evaluatie',]):
        ourtypes['evaluatie'].append( titel )
        continue

    elif strings.contains_any_of(titel, ['Verdrag',]):
        ourtypes['verdrag'].append( titel )
        continue

    else:
        ourtypes['unsorted'].append( titel )
        #print( 'DUNNO %-7s %20s  %s'%(edict.get('nummer'), edict.get('updated'), titel) )
        continue
        #if re.search('', titel):

    #sru_openpub.search_retrieve_many( 'w.dossiernummer=%s'%edict.get('nummer'), callback=op_callback )


for typ, title_list in ourtypes.items():
    #if typ=='unsorted': # cases for which the title isn't a strong indication -- fair enough, but print them to see if there's any patterns we're missing
    #    pprint.pprint( title_list )
    print(  '%-5d %s'%( len(title_list), typ )  )
#pprint.pprint( dtypes )
# Out:
# 2056  wet
# 2005  unsorted
# 1710  begroting
# 437   verdrag
# 244   discussions
# 108   evaluatie
# 290   eu
# 24    mbudsman
# 6     local
# 16    belasting
# 17    [verwijderd]

# %%
# TODO: remove this, or decide what to do with it if not
#     print("\n== kamerstukdossier %s =="%entry.get('nummer'))
#     print("titel: %s"%titel) # check whether citeertitle is unused or not
#     print("kamer: %s"%entry.get('kamer')) 
#     print("updated: %s"%entry.get('updated')) 
#     print("afgesloten: %s"%entry.get('afgesloten')) 
#     #'hoogsteVolgnummer': '516', 
#     print( edict )


#     def op_callback(record):
#         recordData     = record.find('recordData')        # the actual record
#         recordPosition = record.find('recordPosition')    # e.g. <recordPosition>12</recordPosition>
#         print( '\n====== record %s ====='%recordPosition.text )
#         payload = recordData[0]
#         print( wetsuite.helpers.etree.tostring( wetsuite.helpers.etree.indent( payload ) ).decode('u8') )

#     sru_openpub.search_retrieve( 'w.dossiernummer=%s'%edict.get('nummer'), callback=op_callback )
#     print( "Number of kamerstukken: %d"%sru_openpub.num_records )



# https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/cab88793-32df-413a-9ca1-51a075c196db

# https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Resources/cab88793-32df-413a-9ca1-51a075c196db


#with open('fractie_membership.json','wb') as jsonfile:
#    jsonfile.write( json.dumps( persoon_combined ).encode('ascii') )

# %% [markdown]
# ## OData interface

# %% [markdown]
# The SyncFeed API is perfectly functional, though it leaves you to do interpretation of the relations yourself,
# so let's see if the OData API is any more help.
#
# There is a helpful library out there, [tkapi](https://github.com/openkamer/tkapi) (MIT license).
# This means we don't have to implement it ourselves.
#
# Note that neither API is is a very _fast_ interface,
# or efficient when your goal is sifting through the entire collection of data in ways it was not initially designed for.
# (It also seems it sometimes refuses to connect?)
#
# That is part of why it might be interesting to some to have this notebook, and the produced dataset just give you the actual list.

# %%
# if you haven't already
# !pip3 install tkapi

# %%
import tkapi, tkapi.document   
from tkapi.document import DocumentSoort
api = tkapi.TKApi()

# %%
# Get an idea of what this API even does
#   the document types are function calls, to wit:
list(name   for name in dir(api)   if name.startswith('get_'))
# Out:
# ['get_activiteiten',
#  'get_agendapunten',
#  'get_all_items',
#  'get_antwoorden',
#  'get_besluiten',
#  'get_commissies',
#  'get_documenten',
#  'get_dossiers',
#  'get_fractie_zetels',
#  'get_fracties',
#  'get_geschenken',
#  'get_item',
#  'get_items',
#  'get_kamervragen',
#  'get_personen',
#  'get_reizen',
#  'get_related',
#  'get_stemmingen',
#  'get_vergaderingen',
#  'get_verslagen',
#  'get_verslagen_van_algemeen_overleg',
#  'get_zaken']

# %%
# Okay, let's try that
dossiers = api.get_dossiers( )
len(dossiers)  # a few thousand, which is why the previous line will take a few secdonds to fetch
# Out:
# 6896

# %%
# Let's get a basic summary of dossiers. 
#    we find out apparently  dossier nummers  are not unique without the  toevoeging

# let's also sort by dossies -- and toevoeging, which requires minor syntax-fu right now
sorted_dossiers = sorted(  dossiers,   key=lambda dossier:str(dossier.nummer)+(dossier.toevoeging or '')  )

i=0
for dossier in sorted_dossiers:   #[:200]: # show a few hundred, not all
    nummer_and_toevoeging = ('%s-%s'%(dossier.nummer, dossier.toevoeging or '')).rstrip('-')
    print( "== Dossier %s == %s =="%( nummer_and_toevoeging, dossier.titel) )
    print( '  ',dossier.url.replace(')','%29') ) # the replace is to make the notebook's url include the final bracket
    for doci, document in enumerate(dossier.documenten):
        print( f'    DOC: {document.onderwerp:100s}  {document.bestand_url:30s}'
              )
    #break
# Out:
# == Dossier 17050 == Misbruik en oneigenlijk gebruik op het gebied van belastingen, sociale zekerheid en subsidies ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(58cf1611-70a0-436a-ba73-f5e0819fd2a9%29
#     DOC: Motie Ulenbelt over beoordelingscriteria voor samenwonen                                              https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(29ba2e71-84b6-4b8d-bc0e-0014f7bb5766)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Berndsen-Jansen c.s. over een jaarlijkse nationale frauderisicoanalyse              https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ca155dba-efc8-4a24-8850-002a349aa2c4)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op berichtgeving over het koppelen van data in verband met fraudeonderzoeken                  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(66490208-7212-4b91-83a9-01552e52a243)/TK.DA.GGM.OData.Resource()
#     DOC: Tweede voortgangsbrief herijking handhavingsinstrumentarium                                           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c116f931-0c34-4e76-babb-026ec525e52d)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Wiersma over het sociale zekerheidssysteem doorlichten op fraudegevoeligheid        https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1c25d8b3-f4d7-4bfe-bbbe-029087c7995e)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Berndsen-Jansen over het aanstellen van een fraudecommissaris                       https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(870e76ff-a36b-47ff-bb23-0417c4002d8e)/TK.DA.GGM.OData.Resource()
#     DOC: Signaleringsbrief fraudefenomenen sociale zekerheid                                                   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(54d9f9f8-de26-4c2b-9ee0-06226fea4796)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 27 april 2011, inzake Handhaving (tweede termijn)       https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(42b0a7ff-5ea7-427f-8fc9-070bc025d3ec)/TK.DA.GGM.OData.Resource()
#     DOC: Analyse van fraudeonderzoeken (verzoek De Roon, AO 29 oktober 2008)                                   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(82a0f13c-5e3b-4456-b4d6-070d8f254879)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een schriftelijk overleg over de rapportage over toeslagen en uitvoering van de motie van het lid Koolmees c.s. inzake het maximaal inzetten op het innen van de onterecht uitgekeerde toeslagen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(23869bd5-0b63-4073-94de-075ed4e734f7)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 17 november 2010, inzake Handhaving                     https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9644324e-a83c-40fa-a778-07bd231d9137)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Schouten c.s. over een advies van de Raad voor de Rechtspraak over het wetsvoorstel fraudewet  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(18ca26e3-a4e0-4258-941f-0803a7708d17)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van de leden Wiersma en Jasper van Dijk over het versterken van de positie van de Kamer bij de ICT-operatie bij het UWV  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a547985b-33f0-49d1-93a6-081adf3d5318)/TK.DA.GGM.OData.Resource()
#     DOC: Onterechte uitkeringen aan gedetineerden                                                              https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5c6b7ff6-7879-4662-b209-08b7a77e59f1)/TK.DA.GGM.OData.Resource()
#     DOC: Signaleringsbrief Fraudefenomenen 2020                                                                https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c5add940-1508-4660-8ab2-09bf555f4a7f)/TK.DA.GGM.OData.Resource()
#     DOC: Gewijzigde motie Van Weyenberg (t.v.v. 17050, nr. 481) over meldingen van de Stichting Normering Arbeid  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e0d1f7d0-43c5-46e9-b1ab-0a299ff692c2)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op de aangenomen motie van het lid Gesthuizen over slachtoffers van identiteitsfraude         https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(24b06bfb-3eb8-41aa-a2f6-0a5703116df5)/TK.DA.GGM.OData.Resource()
#     DOC: Onregelmatigheden Stimuleringsregeling Energieprestatie Huursector (STEP)                             https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(61694b1b-cccc-40a8-9d8d-0ac0a8233428)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Jasper van Dijk over voor adresregistratie volledig overgaan op de BRP              https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(195bf493-3144-4538-97d7-0c891135bdd4)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Azmani/Van den Besselaar over een verjaringstermijn                                             https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e325bccf-7216-40d0-a956-0d924db75140)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 25 juni 2014, over Handhaving                           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5560c58f-6172-4d9c-9291-0e90c689deac)/TK.DA.GGM.OData.Resource()
#     DOC: Uitkeringsfraude arbeidsmigranten WW                                                                  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7805c179-f4af-4a8b-875c-14d013f26df5)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op verzoek commissie over de aflevering van Brandpunt van 6 december 2016 over naast uitbuiting, ook mogelijke vormen van fraude bij horecaondernemingen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1610b2b1-4c29-4477-9fec-1707df1e8f02)/TK.DA.GGM.OData.Resource()
#     DOC: Resultaten SVB onderzoek dubbele kinderbijslag in Egypte                                              https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a17266aa-8a89-452a-b958-175c527f6608)/TK.DA.GGM.OData.Resource()
#     DOC: Gewijzigde motie van de leden Karabulut en Van Weyenberg (t.v.v. 17050, nr. 424) over het wegnemen van uitvoeringsobstakels  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(00d57f1f-f005-4c77-b8fd-17dbc64b5553)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Bontes over fors terugbrengen van de omvang van het toeslagenstelsel                https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cf784812-dcf3-432d-a148-18945d6ee6c5)/TK.DA.GGM.OData.Resource()
#     DOC: Nadere toelichting op antwoord op vragen van het lid Schouten over het opleggen van een werkstraf aan een uitkeringsgerechtigde vanwege het niet opgeven van vrijwilligerswerk  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4a9bb697-d333-4deb-96f9-198f85ba8a9f)/TK.DA.GGM.OData.Resource()
#     DOC: Jaarverslag 2007 van de Sociale Inlichtingen- en Opsporingsdienst (SIOD)                              https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8d710a4a-e206-404a-81a9-19a18aca6da4)/TK.DA.GGM.OData.Resource()
#     DOC: Uitstel rapportage Aanpak Malafide Uitzendbureaus (AMU) over het functioneren van de zelfregulering in de uitzendbranche  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(541bc93a-d9a6-427e-88ba-19a8ab4de8f8)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Bontes over onder de Europese verordening brengen van het terugvorderen van de huurtoeslag  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1b12c84d-0151-431d-93d8-1b34caf5052a)/TK.DA.GGM.OData.Resource()
#     DOC: Toezicht op de positie van de pakketbezorgers                                                         https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(108a5592-5b6e-45c1-80cc-1b4038089eea)/TK.DA.GGM.OData.Resource()
#     DOC: Integrale Rapportage Handhaving 2010                                                                  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0bd188c9-a802-4deb-842b-1b5047e7b51b)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een schriftelijk overleg over feitenrelaas systeemfraude met toeslagen                    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b3f38649-b878-4d81-8371-1b73351a3bf4)/TK.DA.GGM.OData.Resource()
#     DOC: Bewijslastverdeling en verkeerscontroles UWV                                                          https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2d9db84b-3767-4caa-82bc-1c0a87146cbe)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van de leden Neppérus en Nijboer over meer waarborgen tegen fraude in het nieuwe toeslagenstelsel  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cfd7954a-c887-4bb1-a5e7-1c0bdcd50477)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Karabulut over ruimte voor de gemeenten om boetebesluiten te herzien                https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(eb684853-4710-4f6e-b436-1d2fb9a8728b)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Sterk over hogere sancties voor fraude met kinderbijslag                                        https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(43471843-c29e-46c0-9e42-1dcbe95db180)/TK.DA.GGM.OData.Resource()
#     DOC: Afschrift van de brief aan de gemeente Vaals inzake bestrijding bijstandstoerisme Vaals               https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b4f5413d-440d-43a7-b291-1e728d2bed7e)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Verhoeven/Koser Kaya over de financiële consequenties                                           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c2f2a910-efce-4d4f-8807-1eecbd700377)/TK.DA.GGM.OData.Resource()
#     DOC: Motie De Jong en Azmani over beslagleggen op bezittingen van bijstandsfraudeurs                       https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(88ef08ea-ef7c-4a8f-8073-1fd5dde92928)/TK.DA.GGM.OData.Resource()
#     DOC: Toezegging evaluatie Landelijke Aanpak adreskwaliteit                                                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(03e1f84f-a7ee-4887-9ab3-200000a4aa03)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid De Graaf over het ter verantwoording roepen van oud-bestuurders van het UWV         https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4ef83b35-7514-4caa-a8cf-2009680a7b4e)/TK.DA.GGM.OData.Resource()
#     DOC: Vierde voortgangsrapportage aanpak schijnconstructies                                                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(66b29e56-9500-43b3-b03d-220ddb0002fe)/TK.DA.GGM.OData.Resource()
#     DOC: Integrale Rapportage Handhaving 2008                                                                  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d94a65e8-79ec-4a97-9f97-22e94a8b25a4)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op verzoek commissie over een reactie naar aanleiding van het vonnis van de rechter inzake het Systeem Risico Indicatie (SyRI)  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(749227e2-d78e-4f16-8a26-242ff0b71e29)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Karabulut over voorkomen dat mensen worden uitgesloten van schuldhulpverlening      https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c005acaf-11da-4c80-b71c-254ce011c286)/TK.DA.GGM.OData.Resource()
#     DOC: Beantw aanv. vr cie over de gang van zaken bij de Stichting Huisvesting Alleenstaanden en Meerpersoonshuishoudens (SHAM)  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(fd6a39cf-0c3b-46ad-9154-25709212cce9)/TK.DA.GGM.OData.Resource()
#     DOC: Toezeggingen gedaan tijdens AO Handhaving d.d. 11 juni 2009                                           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(487e6062-0818-45ed-8e56-25f5892ceb8c)/TK.DA.GGM.OData.Resource()
#     DOC: Rapportage over het Systeem Risico Indicatie (SyRI)-projecten                                         https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(25a9547a-f213-4f88-8609-27f4a4039a4f)/TK.DA.GGM.OData.Resource()
#     DOC: Gew motie Sterk over hogere sancties voor fraude met kinderbijslag (t.v.v. 17050, nr. 375)            https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dfaaa43c-7509-44de-8396-299bce74629f)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Van Weyenberg over een analyse van de handhavingscapaciteit bij het UWV             https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6f15597d-232f-43f9-b3ac-2b085b9c5cf7)/TK.DA.GGM.OData.Resource()
#     DOC: Beantwoording vragen van de vaste commissie voor Financiën over de bereikbaarheid van de Belastingdienst en antwoorden op vragen van het lid Omtzigt over fraudebestrijding.  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(20e53922-8951-49c9-b975-2cbae91a406e)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg over de Beleidsbrief over de taakuitoefening door de bijzondere opsporingsidensten  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c2976a62-13c6-4a51-9410-2e98185acaec)/TK.DA.GGM.OData.Resource()
#     DOC: Voortgang vermogensonderzoeken in het buitenland in het kader van de bijstand                         https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f3ccf329-4310-4371-ba02-302ca9653d63)/TK.DA.GGM.OData.Resource()
#     DOC: Stichting Huisvesting Alleenstaanden en Meerpersoonshuishoudens (SHAM)                                https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(16e2580e-938b-4ce5-b2c0-336445b72402)/TK.DA.GGM.OData.Resource()
#     DOC: Uitstel beantwoording vragen commissie voor Sociale Zaken en Werkgelegenheid over de toepassing van de zelfstandigenregeling door UWV  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2ad4d62e-d548-4b57-af73-3425c18d20c9)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van de leden Klever en Tony van Dijck over afreizen naar Bulgarije om alle onterecht uitgekeerde toeslagen terug te halen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f034d0f5-2cbe-4ad7-9cd9-35ed31e564db)/TK.DA.GGM.OData.Resource()
#     DOC: Informatie t.b.v. het Algemeen Overleg Handhaving op 28 november 2012                                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f2c957ad-5ea9-4010-85d1-36099607b0df)/TK.DA.GGM.OData.Resource()
#     DOC: Jaarverslag SIOD 2008                                                                                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(04a7ed27-2d88-400e-8d20-37ac9c5b64e4)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van de leden Stoffer en Van Brenk over verbieden dat tussenpersonen rechtshandelingen verrichten  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f9fedc2a-28f0-468a-b55e-38c942ebe7e1)/TK.DA.GGM.OData.Resource()
#     DOC: Gewijzigde motie van het lid Bontes  (t.v.v. 17050, nr.457) over een rechtsbasis voor het terugvorderen van de huurtoeslag  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d103cf1f-b7ab-4978-ab0a-394c878cafa7)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Heerma over verruimen van de mogelijkheden voor het omdraaien van de bewijslast                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(31e7067b-7baf-4a75-b608-39e18504638a)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op het verzoek van het lid Omtzigt over het aantal alleenstaanden dat een toeslag ontvangt    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(19adbee6-3971-4690-878c-3b48125075a9)/TK.DA.GGM.OData.Resource()
#     DOC: Voortgangsbrief aanpak malafide uitzendbureaus                                                        https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(da08f125-b445-4192-92f4-3b56a9b6bd66)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op verzoek commissie over uitkeringsfraude door Poolse arbeidsmigranten                       https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8bc0cee2-6dcd-4c82-9c54-3c0b9060de5f)/TK.DA.GGM.OData.Resource()
#     DOC: Fraude in de sociale zekerheid                                                                        https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5be32942-dee0-4b08-8648-3c231f1e70dc)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Smeulders over het opsporen en aanpakken van fraude niet ten koste laten gaan van de dienstverlening  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9ae05cc6-cd06-4aba-a35d-3e2affd3c995)/TK.DA.GGM.OData.Resource()
#     DOC: Verzoek om kabinetsreactie op rapporten met betrekking tot handhaving                                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0e434280-f623-4787-811f-402bcd121449)/TK.DA.GGM.OData.Resource()
#     DOC: Vertrek van de werknemersorganisaties uit de Stichting SNA                                            https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(511b71aa-d0b6-44e1-9f70-41e66eb0fc9c)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op signaal Landelijk Contact Sociaal Rechercheurs over de gemeentelijke aanpak van bijstandsfraude  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(42687a20-4d06-41fb-9a25-425d151e0dc6)/TK.DA.GGM.OData.Resource()
#     DOC: Afpakresultaat toeslagenfraude                                                                        https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3bc1bdbc-2ae4-4605-8365-42ba6bed304c)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Gijs van Dijk over een registratieplicht van werknemers bij uitzendbureaus          https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8a98deb3-4d01-48ab-8c7f-42efc15447e3)/TK.DA.GGM.OData.Resource()
#     DOC: Toezegging tijdens het AO zelfstandigen inzake het ten onrechte door UWV opgelegde terugvorderingen en boetes  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8ad217b7-f97d-49d7-8100-43688a2e33bd)/TK.DA.GGM.OData.Resource()
#     DOC: SZW-handhavingsprogramma 2011 – 2014                                                                  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ff358bb1-f5e0-48a9-8434-43f7a69fc906)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid De Graaf over het beëindigen van discriminatie door bijstandsfraude middels vermogen in het buitenland te bestraffen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e211cd25-7466-4779-87cb-46942022a8a9)/TK.DA.GGM.OData.Resource()
#     DOC: Rapport Inspectie SZW "Over signaal, sanctie en incasso"                                              https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bec3a30b-07d9-4975-9988-4710318b8c07)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 17 maart 2016, over Fraude                              https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(59a0b9c0-a798-4b9c-b678-474cc8270775)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Jasper van Dijk over een parlementaire ondervraging naar de geconstateerde WW-fraude  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d7e1e800-0bdf-4fca-b10c-47c9becec6eb)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op het bericht “UWV stuurt werkzoekenden naar oplichters”                                     https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(56c1e759-cc83-4c06-84cb-47eb0fab08ed)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 11 juni 2009, over Handhaving SZW                       https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cab16719-c7ba-4394-a251-486c9f4def8c)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op verzoek van het lid Omtzigt c.s. bij de Regeling van Werkzaamheden van 25 april 2013 over feitenrelaas Bulgaarse fraudezaak  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(acb0764a-6daf-4e16-9505-493d1fd365da)/TK.DA.GGM.OData.Resource()
#     DOC: Fraudeaanpak, handhaving en naleving                                                                  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b48cec50-5cf0-499a-85a0-4b482c7336f8)/TK.DA.GGM.OData.Resource()
#     DOC: Stand van zaken uitkeringsfraude                                                                      https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(af5eac05-65f9-45b4-9f31-4d445ba7be7b)/TK.DA.GGM.OData.Resource()
#     DOC: Lijst van vragen en antwoorden over het rapport ‘legale identiteitswisselingen in de Balkan en Oost-Europa’  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bf400cab-bb34-49a1-8eb3-4d6075bcfc92)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van de leden Van Weyenberg en Schut-Welkzijn over concrete outcome-doelstellingen voor de aanpak van arbeidsmarktfraude  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(45ce651e-a2dd-481d-b8c2-4d6c5aacc845)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op verzoek van het lid Klaver n.a.v. de reportage van Brandpunt dat Bulgaren de Nederlandse fiscus oplichten  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0e33a076-91b9-4c84-b2bc-4de47e9dcf67)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van de leden Heerma en Van Weyenberg over monitoren van het begrip "verwijtbaarheid"            https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(39e1b871-70fc-46de-aff4-50b4212ee77b)/TK.DA.GGM.OData.Resource()
#     DOC: Monitoren van de Fraudewet en rapportage fraudeaanpak en handhaving                                   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a61b35d8-512f-4cdc-affb-520fb277d580)/TK.DA.GGM.OData.Resource()
#     DOC: Bij gemeenten uitstaande vorderingen op (ex-)bijstandontvangers in verband met verwijtbaar handelen   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6d77eead-cd98-45f2-b143-52190ad0da70)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Jasper van Dijk c.s. over onterecht verstrekte uitkeringen terugvorderen            https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d3916300-b7d5-430b-b49c-54e874ce1af3)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Palland over terugvordering van onterecht verstrekte uitkeringen                    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(66fd4dbc-bc94-4e44-9a56-54ecf5c18eb3)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van de leden Smeulders en Van Brenk over onderzoek naar onrechtmatig verstrekte WW-uitkeringen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8ef92822-69ee-47cc-a343-5501e62c265d)/TK.DA.GGM.OData.Resource()
#     DOC: Voortgang rijksbrede aanpak van fraude                                                                https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ba34221a-e882-4cdc-b155-5527d757d46b)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Bouchibti c.s. over een onderzoek naar de export van kinderbijslag naar niet-EU-lidstaten       https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c8b6c9ac-5ae9-4105-89bd-5644cd41bf3f)/TK.DA.GGM.OData.Resource()
#     DOC: Antwoorden op vragen van de commissie voor Wonen en Rijksdienst over onregelmatigheden bij de uitvoering STEP-regeling  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2247c2af-21cc-4b22-a91a-59105913029b)/TK.DA.GGM.OData.Resource()
#     DOC: Beantwoording vragen commissie over ‘Uitkeringsfraude door Poolse arbeidsmigranten’                   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5a104c36-6081-442c-a73e-59cb18134b1f)/TK.DA.GGM.OData.Resource()
#     DOC: Fraudewet, onderzoek Nationale Ombudsman en rapport In-spectie SZW 'De Boete belicht'                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ccd90369-a75a-4efd-896a-59f007cee755)/TK.DA.GGM.OData.Resource()
#     DOC: Uitstel reactie over de business cases intensivering toezicht UWV en SVB                              https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cfaac57b-d52b-4987-af5f-59f38eaa4ac7)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op het verzoek van het lid De Jong, gedaan tijdens de Regeling van Werkzaamheden van 6 maart 2018, over bijstandsfraude door Turkse Nederlanders  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(59e749bf-df9c-407c-b860-5b6f29fbe56d)/TK.DA.GGM.OData.Resource()
#     DOC: Voortgang in de aanpak van malafide uitzendbureaus                                                    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f9ec25f6-6766-4ec9-97c0-5bbdcf27ebec)/TK.DA.GGM.OData.Resource()
#     DOC: Tweede voortgangsrapportage aanpak schijnconstructies                                                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(63741e25-924b-4af0-813e-5d176cb8b643)/TK.DA.GGM.OData.Resource()
#     DOC: Onderzoeksrapport ‘Even kloppen a.u.b.’                                                               https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(17550203-7e1a-4d8c-8816-5d687af2a2fe)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid De Graaf over gemeentelijke prioritering bij de opsporing van bijstandsfraude       https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b34e8cb1-cd17-4e9b-aba0-5e31d7d25b21)/TK.DA.GGM.OData.Resource()
#     DOC: Landelijke Stuurgroep Interventieteams                                                                https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(122b4e42-b182-4d28-8b75-5fed3d1ec34a)/TK.DA.GGM.OData.Resource()
#     DOC: Openbaar Ministerie (OM) Fraudemonitor 2017 en 2018                                                   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4c2ea596-87a9-4260-94c7-600dce802729)/TK.DA.GGM.OData.Resource()
#     DOC: Uitstelbericht toezending feitenrelaas over het rapport identiteitsfraude                             https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3b9919de-fdf2-4f1d-add3-6045c066d2b6)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op het verzoek van het lid De Jong, gedaan tijdens de Regeling van werkzaamheden van 15 november 2018, over een rapport van Divosa waaruit blijkt dat eind 2017 bij gemeenten voor 1,46 miljard aan vorderingen open staan in het kader van de uitvoering van de bijstandsregelingen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9c7fe989-d601-4318-84e8-615ee27bb113)/TK.DA.GGM.OData.Resource()
#     DOC: Uitstel inzake feitenrelaas identiteitsfraude                                                         https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(17351da3-fc90-4b7b-a9f7-62615a3896f4)/TK.DA.GGM.OData.Resource()
#     DOC: Huisvesting arbeidsmigranten bij een bedrijf in Someren                                               https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8510d8bb-fe42-4210-9950-64913aa60d34)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Bontes over het drastisch verhogen van de pakkans voor fraude                       https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3cb1fc0e-89d8-4525-8489-64b2147ae4f2)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid De Jong over het ministerssalaris van de minister voor Medische Zorg en Sport halveren  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(55721b82-21fd-4301-acca-6628f324daaa)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 19 november 2009, over Integrale Rapportage Handhaving 2008  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5ed67fe7-965a-4780-b070-6732e48a238b)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 28 november 2012, inzake handhaving                     https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a312e9d3-75ed-4ba6-951d-678ff7575f5c)/TK.DA.GGM.OData.Resource()
#     DOC: Hoofdlijnen handhavingsbeleid in de sociale zekerheid                                                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a7d2f9a5-2daf-4cba-b314-690b66c356d5)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Van Brenk c.s. over de algehele sturing en communicatie binnen het UWV doorlichten  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f2d12047-b341-4fe4-8195-6934dda7d234)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Öztürk over maatwerk van het OM in de casus van een oudere first offender           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dacb97ec-84d5-4019-ad30-696c32f5f11f)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Schut-Welkzijn over inkomensverrekening                                             https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(61641d73-338f-46ea-ab23-6a5c296be031)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op berichtgeving van RTL Nieuws op 9 april 2015 over de naar Turkije vertrokken hoofdverdachte in de zaak die bekend is komen te staan als de ‘Bulgarenfraude’  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(42728b61-4f08-43ed-a781-6aee5e489d9a)/TK.DA.GGM.OData.Resource()
#     DOC: Toezeggingen gedaan tijdens het debat over uitkeringsfraude met de WW door arbeidsmigranten op 11 oktober 2018  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6c857ddc-dfdd-401e-891a-6f3419b5f4ac)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Koolmees c.s. over maximaal inzetten op het innen van de onterecht uitgekeerde toeslagen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(984ec7c4-857d-4f95-b119-6fa81ff2b1e3)/TK.DA.GGM.OData.Resource()
#     DOC: WW-uitkeringsfraude                                                                                   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0379cb1d-31e1-41a0-9a6b-7287ffc081a1)/TK.DA.GGM.OData.Resource()
#     DOC: Recente ontwikkelingen rond de kinderopvanginstelling De Parel                                        https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5c879372-3e58-4296-a5ad-731a45b09f7b)/TK.DA.GGM.OData.Resource()
#     DOC: Stand van zaken van het SNA-keurmerk                                                                  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d324ec5c-9d27-4773-9361-7450a86f1e8b)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Azmani/Van den Besselaar over fraude in het bedrijfsleven                                       https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f71369bf-3033-4510-990e-7459abf55122)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Karabulut over resultaten van handhavingsonderzoeken in Turkije en Marokko                      https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(89c55614-63b4-4aeb-b1ab-765890c4f7f4)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een rondetafelgesprek, gehouden op 4 februari 2019, over WW-fraude                        https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(60f3257a-4f48-4edf-b631-787ec03df758)/TK.DA.GGM.OData.Resource()
#     DOC: Meerjarige handhavingskoers 2022-2025                                                                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0cc52577-f8a0-45af-968b-79ab0df75405)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid De Jong over standaard controleren of de aanvrager recht heeft op een WW-uitkering  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(04e5a7ba-d234-4b86-aa18-7f02b95bcf54)/TK.DA.GGM.OData.Resource()
#     DOC: Continuering Landelijke Aanpak Adreskwaliteit (LAA)                                                   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8fc63b65-85b3-466f-958d-7f3a9d0e12bc)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op verzoek van de vaste commissie voor Veiligheid en Justitie over het onderzoek “Status: Vermist. Opzoek naar een oplossing”  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(22a969a7-705f-459b-95e6-7f71f923cadd)/TK.DA.GGM.OData.Resource()
#     DOC: Toepassing van de zelfstandigenregeling door UWV                                                      https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(56d231f2-b248-465c-aa9f-84af0dad673d)/TK.DA.GGM.OData.Resource()
#     DOC: Beleidsreactie onderzoek 'Fraudemeldpunten: synergie en samenwerking'                                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(39f94912-0a79-483d-b78d-862adea4023f)/TK.DA.GGM.OData.Resource()
#     DOC: Mogelijke onregelmatigheden bij de Stimuleringsregeling Energieprestatie Huursector (STEP-regeling)   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d74146ad-8f7a-4248-bb48-8777972e0d3b)/TK.DA.GGM.OData.Resource()
#     DOC: Maatregelen Fraudebeleid                                                                              https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9097ed66-c4f8-4c87-8a25-878bd11daa5c)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Jasper van Dijk over een parlementaire ondervraging over het UWV                    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c1207e35-b3ef-44af-a50f-8aa8d4e6391a)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Kerstens c.s. over de evaluatie van het certificeringssysteem van uitzendbureaus    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d8da88cd-90eb-4a32-b338-8b621c16afba)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Kerstens over de wijze waarop lagere overheden omgaan met hun verantwoordelijkheden uit hoofde van de Was  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9ff4827c-2288-4751-8a04-8c310aa0f0f1)/TK.DA.GGM.OData.Resource()
#     DOC: Terugvordering zorgtoeslag, kinderopvangtoeslag en kindgebondenbudget                                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(82443ca8-7344-4c61-b48e-8c764e638e1c)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 5 februari 2009, over o.a. bij gemeenten uitstaande vorderingen op (ex-)bijstandontvangers in verband met verwijtbaar handelen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d45c819b-a543-4ba2-b953-8d816ff3f60d)/TK.DA.GGM.OData.Resource()
#     DOC: Motie De Jong over het maximaal toegestane eigen vermogen                                             https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2908bac1-e268-495d-bc8c-8de6be435f86)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van de leden Pieter Heerma en Van Weyenberg over concrete uitwerking van de criteria voor verwijtbaarheid  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(75c6a9c4-3eaf-45bf-96b0-8e71ab27d992)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid De Jong over het fraudebedrag tot de laatste cent terugvorderen                     https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(59085a7c-230a-4fae-aa87-8ec06022a1a6)/TK.DA.GGM.OData.Resource()
#     DOC: Voortgang herijking handhavingsinstrumentarium                                                        https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0b65f133-4678-44b5-8cb9-8f4d59ff1643)/TK.DA.GGM.OData.Resource()
#     DOC: Beleidsreactie onderzoek 'Cross-sectorale gegevensdeling tussen private partijen voor fraudebestrijding'  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(84bac836-bee5-4ed2-8a5f-8f557d7e39d2)/TK.DA.GGM.OData.Resource()
#     DOC: Aanpak identiteitsfraude - Uitvoeringsagenda 2014                                                     https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(26493c7b-dd9e-4fdf-9c71-902e43f897e2)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Karabulut over het verlagen van de strafrechtelijke aangiftegrens                   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(84f5e1aa-4613-4308-9938-9223eda2c3b3)/TK.DA.GGM.OData.Resource()
#     DOC: Motie De Jong en Azmani over terugvorderen van het fraudebedrag plus boete                            https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e64ca5dc-abb6-4761-be63-92637717c988)/TK.DA.GGM.OData.Resource()
#     DOC: Planning aanpassing Fraudewet en Boetebesluit, beantwoording vraag opsporing zorgfraude               https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f7c4d081-2745-403f-ac07-9356c1dc342f)/TK.DA.GGM.OData.Resource()
#     DOC: Evaluatie bestuurlijke boete Arbeidstijdenwet (ATW)                                                   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(34590848-13e4-4587-9f6d-939939ccf173)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op verzoek van het lid Siderius, gedaan tijdens de Regeling van Werkzaamheden op 15 april 2015 over fraude met kinderopvangtoeslag door gastouderbureaus  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3d8b9616-889a-44eb-ad7d-962bab0f1c05)/TK.DA.GGM.OData.Resource()
#     DOC: Fraudemonitor van het Openbaar Ministerie (OM) 2019-2020                                              https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d104bed8-2eac-4404-8e84-96cee13ab42c)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Van Brenk c.s. over een mogelijke onbalans van taken en budget bij het UWV          https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(58030f8d-0253-4001-84f0-97a420f60fe1)/TK.DA.GGM.OData.Resource()
#     DOC: Voortgangsrapportage aanpak schijnconstructies                                                        https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9e0402be-294e-4874-b628-9813a6433cdb)/TK.DA.GGM.OData.Resource()
#     DOC: Besluitvorming herziening boetebesluiten uitspraak Centrale Raad van Beroep (CRvB)                    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(24448514-60c2-49b3-956b-985d55321c71)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid De Jong over bestuurders van het UWV tussen 2011-2018 ter verantwoording roepen     https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4566fba7-395e-475b-b1b1-9affdd0b3b78)/TK.DA.GGM.OData.Resource()
#     DOC: Feitenrelaas systeemfraude met toeslagen                                                              https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(33c8a9d7-06b7-4644-a790-9c83957019e0)/TK.DA.GGM.OData.Resource()
#     DOC: Brief ter voorbereiding op het spoeddebat inzake mogelijke fraude met kinderbijslag van uitwonende kinderen in Marokko en Turkije  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(982d8bcc-fd91-4e4f-aea6-9cb55020d8b2)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Van Brenk over de gewenste aanscherping van het handhavingsbeleid afstemmen op het onderzoek van de Rijksuniversiteit Groningen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d0969341-e099-4588-afd9-9d65a251317a)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Karabulut c.s. over wijzigingsvoorstellen die recht doen aan de bezwaren van werkzoekenden, de Ombudsman en uitvoeringsinstanties  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(772eb822-9833-4be3-8bb8-9e6d246e2919)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op het rapport "legale identiteitswisselingen in de Balkan en Oost-Europa"                    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5f7f5b79-69c8-40f3-b5a0-9e6ddba35b8b)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 31 oktober 2013, over handhaving                        https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ab03cda8-be69-410c-93da-9ec85dfa3fb7)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op het bericht dat FNV en CNV zich terugtrekken uit het bestuur van de Stichting Normering Arbeid (SNA) omdat zij zorgen hebben over het keurmerk inzake zelfregulering uitzendbranche  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7a7fbe30-9a35-4a54-aa29-9f0fb2963159)/TK.DA.GGM.OData.Resource()
#     DOC: Integrale Rapportage handhaving 2007                                                                  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(022a0b73-3817-4b01-9641-9f47d9d816a4)/TK.DA.GGM.OData.Resource()
#     DOC: Omissie op de brief over toeslagfraude door Bulgaren                                                  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(127e0c9e-6118-42fd-b66d-a01f1badf714)/TK.DA.GGM.OData.Resource()
#     DOC: Onderzoeksrapport evaluatie bestuurlijke boete Wet arbeid vreemdelingen                               https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f3317227-0d27-4412-ba1e-a0617d0e4723)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op het verzoek van de leden Van Nispen en Renkema, gedaan tijdens de Regeling van werkzaamheden van 19 juni 2018, over verschillende fraudevormen in de sociale zekerheid  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1d9c65d7-5730-4f74-a9f9-a155d978a08f)/TK.DA.GGM.OData.Resource()
#     DOC: Onterechte uitkeringsverstrekking gedetineerden UWV                                                   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(821222f6-615c-4b33-96e0-a15b22076bcb)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op de gewijzigde motie van de leden Pieter Heerma en Van Weyenberg (Kamerstuk 17 050, nr. 477) over concrete uitwerking van de criteria voor verwijtbaarheid  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(aebc308e-7712-428c-9a11-a1bd87525108)/TK.DA.GGM.OData.Resource()
#     DOC: Toezeggingen gedaan tijdens het Algemeen Overleg van 5 februari 2009 over handhaving sociale zekerheid  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d3715035-4460-42cb-a775-a30edbb5b21a)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Van Weyenberg over meldingen van de Stichting Normering Arbeid                      https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(79f6fb2d-b32c-4b60-8e4c-a56c1b01c08c)/TK.DA.GGM.OData.Resource()
#     DOC: Eindrapportage Voortgang rijksbrede aanpak fraude                                                     https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8e2be3f8-f433-4ff4-8153-a77a188d8e3d)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van de leden Schouten en Kerstens over beleidsregels voor vrijwilligerswerk bij commerciële activiteiten  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(daba7041-5db8-4d3d-a218-a785b875dce3)/TK.DA.GGM.OData.Resource()
#     DOC: Aanpak malafide uitzendbureaus en zelfregulering                                                      https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(556fdb2f-bed1-4d28-bfee-a8a71180061c)/TK.DA.GGM.OData.Resource()
#     DOC: Maatregelen voor eerlijk werk                                                                         https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(544b17fe-28ae-4a21-ad9a-aa4c979a68fb)/TK.DA.GGM.OData.Resource()
#     DOC: Gewijzigde motie van de leden Pieter Heerma en Van Weyenberg  (t.v.v. 17050, nr.476) over concrete uitwerking van de criteria voor verwijtbaarheid  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(279bec01-67d6-4daa-b3c2-aaf98802b23f)/TK.DA.GGM.OData.Resource()
#     DOC: Aanpak schijnconstructies                                                                             https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3192f59f-e3c7-4334-a6b3-ae28f346c6fb)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Fritsma en Verdonk over het niet uitkeren van kinderbijslag ten behoeve van in Marokko en Turkije verblijvende kinderen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8cd231e3-56b2-4e5a-8dba-ae5c23926a42)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op verzoek van het lid Omtzigt inzake de toeslagenfraude van de gemeente Bronckhorst          https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5c085d7b-b533-44af-adfb-ae744342ce06)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 30 maart 2011, inzake Handhaving                        https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6750c6cd-2089-4c9a-a01e-af64579cd37b)/TK.DA.GGM.OData.Resource()
#     DOC: Rapportage over toeslagen en uitvoering van de motie van het lid Koolmees c.s. inzake het maximaal inzetten op het innen van de onterecht uitgekeerde toeslagen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(862a34d0-c889-469c-9d41-af71d00a51e7)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Karabulut over een kosten- en batenanalyse                                                      https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1b849d3a-c174-4ed5-bb42-af7fd92f8840)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van de leden Berndsen-Jansen en Gesthuizen over fraude aanmerken als high-impact crime          https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f20e6af0-6f47-4cbf-b96d-b0c08eb8a4ed)/TK.DA.GGM.OData.Resource()
#     DOC: OM Fraudemonitor 2015                                                                                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b8b75081-e27c-48df-a260-b21609736904)/TK.DA.GGM.OData.Resource()
#     DOC: Aanpak van malafide uitzendbureaus                                                                    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(342b336b-1539-41c2-9eaa-b2cd794adfdc)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van de leden Siderius en Heerma over onderzoek door de Nationale Ombudsman naar het boetebeleid van UWV  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1d4530a1-30d9-4816-ad8c-b51a94f6563f)/TK.DA.GGM.OData.Resource()
#     DOC: Uitstel van de bijeenkomst inzake het Handhavingsprogramma 2011-2014                                  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d3fff0fb-856a-46d2-b9be-b8ed9f8b89f4)/TK.DA.GGM.OData.Resource()
#     DOC: Kabinetsreactie op de motie van het lid Bontes (Kamerstuk 17050, nr. 457) en een reactie op de suggestie van het lid Omtzigt om de terugvordering van de huurtoeslag in een bijlage bij Verordening (EG) 883/2004 op te nemen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(36cb726c-1755-49f5-8924-b9adbc436b80)/TK.DA.GGM.OData.Resource()
#     DOC: Toezeggingen gedaan bij het debat fraude met toeslagen                                                https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4259b8a9-1f42-4c38-a157-bab7971878e0)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 11 juni 2009, over toepassing zelfstandigenregeling door UWV  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(85983b24-0783-48fa-ac1b-bcb38f5772a4)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op moties ingediend tijdens het spoeddebat over de aanpak van uitkeringsfraude                https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f6ddb2d6-1ae6-4932-9e4d-bd4855521bfd)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Van Hijum c.s. over problemen bij de uitvoering van de regeling voor zelfstandigen gestart vanuit de WW  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ea18cdf9-0696-4e4b-9987-bdb7cdc0ddc0)/TK.DA.GGM.OData.Resource()
#     DOC: Artikel 10 Waadi                                                                                      https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(921b3b3d-c4ac-4080-b0f5-be04d58e235c)/TK.DA.GGM.OData.Resource()
#     DOC: Intensivering toezicht in het sociale zekerheidsdomein                                                https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a97606dd-bd06-4ecc-8120-bf11131bd8a8)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op het verzoek van het lid Van Brenk, gedaan tijdens de Regeling van Werkzaamheden van 5 maart 2019, over het bericht ‘Mensen met uitkering doodsbang’ (Gelderlander, 20 februari 2019)  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ee8dc4c5-386f-4a5f-a201-bf9011abb17a)/TK.DA.GGM.OData.Resource()
#     DOC: Roemeense aspergestekers                                                                              https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e64316a6-b3d3-49e1-9b08-bfaa66cae1bd)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op vraag van het lid Van Kent, gedaan tijdens het commissiedebat van 30 juni 2021, over werkwijze Inlichtingenbureau (IB)  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b06ec5fc-964f-49cc-997a-bfe6851089c8)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 25 februari 2015, over Legale identiteitswisselingen en reisdocumenten  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(14f01ec4-3995-4090-ae9d-c25633a762e8)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Wiersma over verbetervoorstellen voor het aan het licht brengen van ten onrechte verstrekte uitkeringen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e00450c1-fd22-4b23-92ef-c349c9320dba)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Jasper van Dijk over een overzicht van de bijstandsfraude vanwege verzwegen bezit in het buitenland  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dbe00374-dc71-42a9-8019-c3f33ba18ec2)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 2 november 2016, over handhaving                        https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4d7657a0-02e6-4df5-9139-c3ff970e200f)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Siderius over het in gesprek gaan met gemeenten over het bijstandsverhaal           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(078e6d7e-448a-493c-a5db-c49caaa65f04)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van de leden Oskam en Getshuizen over de digitale uitwisseling van (bank)gegevens               https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(18b97e44-e968-45d3-87b4-c4f71947f3ac)/TK.DA.GGM.OData.Resource()
#     DOC: Aanpak van fraude in de sociale zekerheid en arbeidswetgeving                                         https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9fc4e7b7-3c09-4e36-b8bf-c552c8efeed4)/TK.DA.GGM.OData.Resource()
#     DOC: Breed extern onderzoek misbruikrisico's                                                               https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(248ad26c-000d-42cf-83ef-c63c8cac2edc)/TK.DA.GGM.OData.Resource()
#     DOC: Aanpassingen Fraudewet, aanbevelingen Nationale ombudsman                                             https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(49311621-7aa5-461e-8a4a-c6875ceff910)/TK.DA.GGM.OData.Resource()
#     DOC: Fraude en illegaliteit in de uitzendbranche                                                           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dc3690f3-6510-4456-bfa2-c692303ab154)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 8 april 2015, over Fraude                               https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6ae4c277-035f-434d-9541-c81aa7b42ee5)/TK.DA.GGM.OData.Resource()
#     DOC: Onderzoek VNG naar verwerking IB-signalen bij gemeenten                                               https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(62f98116-00b1-4d05-bd08-c861474edcf0)/TK.DA.GGM.OData.Resource()
#     DOC: Fraude met de Ziektewet (ZW)                                                                          https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(52bbf9c9-5670-4c4a-bcc3-c876db700c8e)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 17 december 2014, over Handhaving                       https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0378f53e-4423-4acc-8a06-cb9e0f64de30)/TK.DA.GGM.OData.Resource()
#     DOC: Voortgang rijksbrede aanpak van fraude                                                                https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2a5a7c7b-b40f-4b52-8063-cc3e9936c617)/TK.DA.GGM.OData.Resource()
#     DOC: Monitoronderzoek Fraudewet en Evaluatie handhavingsbeleid SZW inzake sociale zekerheidswetten         https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(95e20b05-1194-415e-b795-cc586f02122b)/TK.DA.GGM.OData.Resource()
#     DOC: Integrale rapportage Handhaving 2009 Jaarverslag SIOD 2009 andere rapporten                           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(505588fc-86d2-4204-841c-cda23770828e)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Schouten c.s. over het garanderen van de beslagvrije voet in de fraudewetgeving     https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(412fbcfd-4b45-4e12-b832-d07c02948741)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Pieter Heerma c.s. over een veel betere controle op verwijtbaarheid van werkloosheid  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0d1ca40a-8696-428a-ba6d-d0d600046ef1)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 6 juni 2012, inzake Handhaving                          https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e42cac3c-ebd1-4def-95fe-d3b3cdca9ba0)/TK.DA.GGM.OData.Resource()
#     DOC: OM Fraudemonitor 2016                                                                                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8ab47e08-e16c-435e-b345-d4ed568dd619)/TK.DA.GGM.OData.Resource()
#     DOC: Rapportage handhaving tijdens de dienstverlening van de Inspectie SZW                                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3428f561-5c19-4de4-94f9-d514d8914bad)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een schriftelijk overleg over toezeggingen gedaan tijdens het debat over uitkeringsfraude met de WW door arbeidsmigranten op 11 oktober 2018  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e5a9a057-1d6e-42f3-8287-d57e75e7af1a)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Sterk en Blok over een einde maken aan de exporteerbaarheid van kinderbijslag                   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(179406ac-9ceb-4d56-9660-d609fecb8b17)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Blok over het stopzetten van de export van kinderbijslag en andere kinderregelingen naar niet-EU-landen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(93eb4668-cbf2-48a9-935e-d7bacd82c407)/TK.DA.GGM.OData.Resource()
#     DOC: Toezegging evaluatie Landelijke Aanpak Adreskwaliteit over de periode van 2017 - 2020                 https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(92746d68-7775-4f48-b29f-d7d3605cc8e6)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Fritsma en Verdonk over strafrechtelijke vervolging van degene die fraude pleegt met kinderbijslag  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(936f723a-64c6-4af8-b23f-d7fbbe824364)/TK.DA.GGM.OData.Resource()
#     DOC: Rijksbrede aanpak van fraude                                                                          https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b7e54aae-5deb-4bbe-8d65-d91d219d8ad5)/TK.DA.GGM.OData.Resource()
#     DOC: Verslag van een algemeen overleg, gehouden op 1 juli 2015, over Handhaving                            https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7f492cfb-24ad-41fb-9e89-d96b6b236f08)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Karabulut over het wegnemen van uitvoeringsobstakels                                            https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(39f4b34f-8fed-4f53-9805-d9aa4ad2e931)/TK.DA.GGM.OData.Resource()
#     DOC: Integrale Rapportage Handhaving 2011                                                                  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a9308d1c-2a5f-46b4-ba43-da1f60b89419)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op recente berichtgeving in Nieuwsuur over uitkeringsfraude door arbeidsmigranten             https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8311501e-04c4-42ac-82af-dacde2590447)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op aangenomen moties n.a.v. het spoeddebat over de mogelijke fraude met AKW-gelden in Turkije en Marokko  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2970c96f-cd63-4674-b41c-db5045c21cd3)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Omtzigt over een onderzoek naar problemen met de GBA                                https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(76c0d806-c4ec-4f82-be4e-df3bbf34fe67)/TK.DA.GGM.OData.Resource()
#     DOC: Voortgang van de aanpak van malafide uitzendbureaus (AMU)                                             https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(213fec28-9727-427c-b4e9-df4df07fbdf5)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Voordewind en Karabulut over een plicht voor ouders om het recht op kinderbijslag voor uitwonende kinderen in het buitenland aan te tonen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(73de7319-20ff-40b4-bcf1-e4083df3d56f)/TK.DA.GGM.OData.Resource()
#     DOC: Stand van zaken op de overeengekomen verbetermaatregelen van de arbeidswettelijke aspecten van het keurmerk van de Stichting Normering Arbeid (SNA)  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(56c0bd00-8b36-4d7a-bd3c-e51d7312e04d)/TK.DA.GGM.OData.Resource()
#     DOC: Maatregelen ter bestrijding van fraude met toeslagen                                                  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(50dc5eba-6a8a-4317-ae37-e5492271e454)/TK.DA.GGM.OData.Resource()
#     DOC: Signalering fraudefenomenen in de Sociale Zekerheid                                                   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e9b14990-7adf-4896-9026-e61a920a8045)/TK.DA.GGM.OData.Resource()
#     DOC: Handhavingskoers 2018-2021                                                                            https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(47524ebc-337d-474a-9299-e78f53533ee3)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van de leden Nijboer en Neppérus over vermindering van het aantal terugbetalingen van toeslagen  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(538a76ed-2b28-45c2-8b7c-e7d853865be8)/TK.DA.GGM.OData.Resource()
#     DOC: Gegevensuitwisseling in het kader van fraudebestrijding                                               https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(24e8a583-8926-4381-a9f3-e834d612d58d)/TK.DA.GGM.OData.Resource()
#     DOC: Stand van zaken inzake coördinatie fraudebestrijding                                                  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(225415b2-1aec-4703-b6e9-e968527df2c9)/TK.DA.GGM.OData.Resource()
#     DOC: Rapport Handhaving Preventie boven repressie van de IWI                                               https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d4f40174-93c0-42b3-9ff8-ec0ca9fb2768)/TK.DA.GGM.OData.Resource()
#     DOC: Reactie op het proefschrift 'Fraude ontrafeld. Een studie naar de werkwijzen en drijfveren van fraudeurs’  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1237b975-379d-4984-b1f5-eecfb26f3a7c)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid De Jong over een parlementair onderzoek naar het UWV-debacle                        https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bfe066b9-3808-485f-a8cd-f1e22513fe1a)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Omtzigt c.s. over het opzeggen van het vertrouwen in de staatssecretaris van Financiën  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0196e98a-9095-487e-94a4-f21f6c8de084)/TK.DA.GGM.OData.Resource()
#     DOC: Misbruik subsidiegelden voor de huisvesting van asielzoekers                                          https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(749e62af-cc28-4fb1-95de-f3e30a32e083)/TK.DA.GGM.OData.Resource()
#     DOC: Gemeentelijke terugvordering                                                                          https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(97b0e24f-09f0-4c48-a6f0-f6fb0caae2b9)/TK.DA.GGM.OData.Resource()
#     DOC: Derde voortgangsrapportage aanpak schijnconstructies                                                  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b6978ac9-9d4d-4460-b6fe-f84b2e4c7a2f)/TK.DA.GGM.OData.Resource()
#     DOC: Stand van zaken uitkeringsfraude WW                                                                   https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5011302c-efe8-4027-bb3f-f8f9495986b3)/TK.DA.GGM.OData.Resource()
#     DOC: Motie Van der Vlies over het aanpassen van de hoogte van de kinderbijslag aan het prijspeil van het land waar het kind verblijft  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3f766b45-53d2-4332-bdba-f9d193081904)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Ulenbelt over in aanmerking komen voor het keurmerk van de Stichting Normering Arbeid  https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(35783f15-d8ee-4540-a702-fb31f6723d2a)/TK.DA.GGM.OData.Resource()
#     DOC: Motie van het lid Merkies over invorderingsbijstand van de Bulgaarse autoriteiten                     https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3d4d0413-7848-45b2-b6bd-fbe85c9c3666)/TK.DA.GGM.OData.Resource()
#     DOC: Evaluatie Convenant Landelijke StuurgroepInterventieteams                                             https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(59a16828-b6b6-4125-b004-fce42cdf2f49)/TK.DA.GGM.OData.Resource()
#     DOC: Beleidsbrief over de taakuitoefening door de bijzondere opsporingsidensten                            https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ed41a24f-9c7b-40ef-9c9b-ff717cfc1499)/TK.DA.GGM.OData.Resource()

# %% [markdown]
# Let's say that our interest is more specific:
# finding what  Raad van State  has to say about  proposed laws (wetsvoorstellen).
#
# ...and, in the process also learn what the kinds of documents there are in each dossier.
#
# There is also the [advice on the raad van state site](https://www.raadvanstate.nl/adviezen/),
# (for a more data-like form, see also our [extras_datacollect_raadvanstate](extras_datacollect_raadvanstate.ipynb)),
# but there it is not placed in the context of the law it's referring to.
# This interface should at least gives us the law's name.

# %%
# We start by selecting dossiers where there already _is_ RvS advice.
#  - this is a decent filter for wetsvoorstellen
#  - and filters out wetsvoorstellen that don't need this advice (e.g. begroting)
# ...but we are about to find out
# - there are other things that RVS advises on, like finances (see e.g. 36200) 
# - there are law changes that RVS does not advise on (e.g. TODO)

sorted_dossiers = sorted(dossiers,  key=lambda d:d.nummer,  reverse=True )

count = 0
for i, dossier in enumerate( sorted_dossiers ):
    nummer_and_toevoeging = ('%s-%s'%(dossier.nummer, dossier.toevoeging or '')).rstrip('-')

    #if (dossier.nummer%100) == 0: # ignore a few specific special cases for now,   just because they're large to print
    #    continue

    ## In our stated interest:  first see if it has RvS advice
    sorted_docs      = sorted(dossier.documenten,  key=lambda d:d.volgnummer )
    has_raadvanstate = False
    for document in sorted_docs:
        try:
            # these come from an enum, try  list( tkapi.document.DocumentSoort )  to see a list
            if document.soort in (DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE, 
                                  #DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_NADER_RAPPORT, # seems to be begrotingstuff?  (TODO: check)
                                  DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS,
                                ):
                has_raadvanstate = True
        except ValueError: # there's some invalid / non-covered soort values in the data
            pass # ignore
        # we can filter on more, but we may not need to?

    if not has_raadvanstate:
        continue
    # if execution gets here, it's probably interesting to us.
    
    count += 1
    #if len(sorted_docs)>500:
    #    print( "\n\n== Dossier %s == %s =="%( dossier.nummer, dossier.titel) )
    #    print(' LARGE: %d documents'%len(sorted_docs))
    #    print(' %s ({{kamerdossier|%d}}'%(dossier.titel, dossier.nummer))
    #    continue

    print( "\n== %r == Dossier %s == %d docs == %s =="%( dossier.id, nummer_and_toevoeging, len(dossier.documenten), dossier.titel) )
    for document in sorted_docs:
        try:
            if 0: # just to make the summaries a little easier to read
                if document.soort in (DocumentSoort.MOTIE, DocumentSoort.AMENDEMENT, DocumentSoort.BRIEF_REGERING, DocumentSoort.VERSLAG_VAN_EEN_ALGEMEEN_OVERLEG,
                                    DocumentSoort.MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL,
                                    ):
                    continue
        except ValueError:
            print( "soort not known by tkapi")
            continue

        try:
            docsoort = document.soort
        except ValueError: # this seems to be internal inconsistency
            continue

        show_all_docs = False
        if show_all_docs or docsoort in (DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE, 
                                DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS):

            print( '#%s'%(document.volgnummer, ), document.soort.name)
            #print( 'soort', document.soort.name, '(%s)'%document.soort.value )
            print( '  onderwerp    ', document.onderwerp )     # for wetsvoorstel-dossiers, seems to often be the same as soort plus some detail (who a letter is from, who )
            print( '  citeertitel  ', document.titel_citeer ) # for wetsvoorstel-dossiers, this often seems to name the law. Or a related one, see e.g. 36195
            print( '  titel        ', document.titel )              # for wetsvoorstel-dossiers, this seems to often name the law, plus sometimes some reason
            #print( 'versies', document.versies )
            print( '  url          ', document.bestand_url )
            if 0:        # It may be interesting to know the document is part of multiple dossiers and/or multiple zaken
                print( '  zaken         ', document.zaken )
                #nums = document.dossier_nummers
                #nums.pop(dossier.nummer)
                #if len(nums)>0:
                #  print( "  also in dossiers: %s"%nums )

            print()

    #if i > 1000: # show only a bunch, not all
    #    print("break %d"%i)
    #    break
print( 'Interesting cases: %d'%count )
# Out:
# == '87a7ff74-bf81-4e71-a69e-2439ce536c2c' == Dossier 36346 == 5 docs == Voorstel van wet van het lid Van Houwelingen betreffende het houden van een raadplegend referendum over het Nederlandse lidmaatschap van de Europese Unie (Wet raadplegend referendum Nederlands EU-lidmaatschap) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet raadplegend referendum Nederlands EU-lidmaatschap
#   titel         Voorstel van wet van het lid Van Houwelingen betreffende het houden van een raadplegend referendum over het Nederlandse lidmaatschap van de Europese Unie (Wet raadplegend referendum Nederlands EU-lidmaatschap)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bd0dbb7d-bbbe-4aa3-8e28-ba55df7756e3)/TK.DA.GGM.OData.Resource()
#
#
# == '49f64470-6e41-4115-9547-420f5e3b6a3e' == Dossier 36200 == 188 docs == Nota over de toestand van ’s Rijks Financiën ==
# #6 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE
#   onderwerp     Najaarsrapportage Afdeling advisering Raad van State en Kabinetsreactie
#   citeertitel   Miljoenennota 2023
#   titel         Nota over de toestand van ’s Rijks Financiën
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dd727f69-b617-4d27-89d8-0adb403e483c)/TK.DA.GGM.OData.Resource()
#
#
# == '759d319b-389a-494e-b69e-2ed3f5291b27' == Dossier 36195 == 32 docs == Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten (Wet vaste huurcontracten) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet vaste huurcontracten
#   titel         Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bf72af35-dbb5-49a3-87b0-b7c834cd6ec0)/TK.DA.GGM.OData.Resource()
#
#
# == 'bf967829-e330-46a1-989b-3b9e688dd411' == Dossier 36178 == 6 docs == Voorstel van wet van de leden Van der Laan, Van der Woude, De Hoop, Westerveld, Kwint en Van Esch tot wijziging van het Wetboek van Strafrecht en enige andere wetten in verband met het strafbaar stellen van handelingen gericht op het veranderen of onderdrukken van de seksuele gerichtheid, genderidentiteit of genderexpressie (Wet strafbaarstelling conversiehandelingen) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet strafbaarstelling conversiehandelingen
#   titel         Voorstel van wet van de leden Van der Laan, Van der Woude, De Hoop, Westerveld, Kwint en Van Esch tot wijziging van het Wetboek van Strafrecht en enige andere wetten in verband met het strafbaar stellen van handelingen gericht op het veranderen of onderdrukken van de seksuele gerichtheid, genderidentiteit of genderexpressie (Wet strafbaarstelling conversiehandelingen)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d5b82f36-b1cd-4872-bf4d-240b438387ce)/TK.DA.GGM.OData.Resource()
#
#
# == 'cc270778-4153-4d65-af77-fe3519a32b76' == Dossier 36161 == 7 docs == Voorstel van wet van de leden Baudet en Van Houwelingen houdende regels inzake een breed raadgevend referendum (Wet raadgevend referendum naar Zwitsers model) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet raadgevend referendum naar Zwitsers model
#   titel         Voorstel van wet van de leden Baudet en Van Houwelingen houdende regels inzake een breed raadgevend referendum (Wet raadgevend referendum naar Zwitsers model)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(92f3980e-07d2-4e10-8b40-e7d5953961c4)/TK.DA.GGM.OData.Resource()
#
#
# == '06397d33-825c-47ec-ae31-6b186a4a06dd' == Dossier 36160 == 15 docs == Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c4b73975-1fb0-4b46-ada1-4d39fdd365ad)/TK.DA.GGM.OData.Resource()
#
#
# == '992cfaeb-47f7-41d9-ae24-7905719cfca9' == Dossier 36128 == 10 docs == Voorstel van wet van de leden Maatoug en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Maatoug, Van der Lee en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen en het vervangen van het box 2-tarief door een progressief tarief
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(21766f02-9869-4df9-a59f-94d2330f7a08)/TK.DA.GGM.OData.Resource()
#
#
# == '77900319-43c1-4121-8d58-883970285392' == Dossier 36125 == 6 docs == Voorstel van wet van het lid Sneller tot wijziging van de Wet op de rechterlijke organisatie in verband met het laten vervallen van de bijzondere aanwijzingsbevoegdheid van de minister met betrekking tot de uitoefening van de taken en bevoegdheden van het openbaar ministerie (Wet verval bijzondere aanwijzingsbevoegdheid openbaar ministerie) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet verval bijzondere aanwijzingsbevoegdheid openbaar ministerie
#   titel         Voorstel van wet van het lid Sneller tot wijziging van de Wet op de rechterlijke organisatie in verband met het laten vervallen van de bijzondere aanwijzingsbevoegdheid van de minister met betrekking tot de uitoefening van de taken en bevoegdheden van het openbaar ministerie (Wet verval bijzondere aanwijzingsbevoegdheid openbaar ministerie)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9cebfb50-4e51-451e-9d8e-c728ead4b003)/TK.DA.GGM.OData.Resource()
#
#
# == 'ad0b6d7d-4132-4f09-84ac-1cbb6927994c' == Dossier 36052 == 8 docs == Voorstel van wet van het lid Van Houwelingen houdende splitsing van de gemeente Groningen en instelling van de gemeente Haren ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Van Houwelingen houdende splitsing van de gemeente Groningen en instelling van de gemeente Haren
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(28e4b35d-51b4-4db6-abd3-353e58e219e7)/TK.DA.GGM.OData.Resource()
#
#
# == 'bebb0654-c0c7-49a3-838a-d3346c0cc7fc' == Dossier 36047 == 11 docs == Voorstel van wet van de leden Sneller en Bushoff tot wijziging van de Kieswet in verband met de permanente invoering van de mogelijkheid voor kiezers om gedurende twee dagen voorafgaand aan de dag van de stemming vervroegd te stemmen in het stemlokaal (Wet vervroegd stemmen in het stemlokaal) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet vervroegd stemmen in het stemlokaal
#   titel         Voorstel van wet van de leden Sneller en Kathmann tot wijziging van de Kieswet in verband met de permanente invoering van de mogelijkheid voor kiezers om gedurende twee dagen voorafgaand aan de dag van de stemming vervroegd te stemmen in het stemlokaal (Wet vervroegd stemmen in het stemlokaal)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5af5cab2-077c-4f7b-86c7-f03799cd2d4d)/TK.DA.GGM.OData.Resource()
#
#
# == '5d249bfc-57df-4090-8a3d-697345122d44' == Dossier 36041 == 5 docs == Voorstel van wet van de leden Kops en Edgar Mulder tot wijziging van de Wet op de omzetbelasting 1968 en de Belastingwet BES inzake het tijdelijk onder het nultarief plaatsen van energie en tot wijziging van de begrotingsstaat van het gemeentefonds voor het jaar 2022 inzake het extra compenseren van huishoudens (Tijdelijke noodwet betaalbare energie) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Tijdelijke noodwet betaalbare energie
#   titel         Voorstel van wet van de leden Kops en Edgar Mulder tot wijziging van de Wet op de omzetbelasting 1968 en de Belastingwet BES inzake het tijdelijk onder het nultarief plaatsen van energie en tot wijziging van de begrotingsstaat van het gemeentefonds voor het jaar 2022 inzake het extra compenseren van huishoudens (Tijdelijke noodwet betaalbare energie)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9a4bcf7a-3b0e-416d-b91e-a03d7063cfcc)/TK.DA.GGM.OData.Resource()
#
#
# == 'bff0de26-0e61-433a-a06a-f479d1ad87ca' == Dossier 36028 == 6 docs == Wijziging van het Wetboek van Burgerlijke Rechtsvordering en het Wetboek van Burgerlijke Rechtsvordering BES in verband met het op 2 december 2004 te New York tot stand gekomen Verdrag van de Verenigde Naties inzake de immuniteit van rechtsmacht van staten en hun eigendommen (Uitvoeringswet VN-Verdrag staatsimmuniteit) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE
#   onderwerp     Advies Afdeling advisering Raad van State
#   citeertitel
#   titel         Wijziging van het Wetboek van Burgerlijke Rechtsvordering en het Wetboek van Burgerlijke Rechtsvordering BES in verband met het op 2 december 2004 te New York tot stand gekomen Verdrag van de Verenigde Naties inzake de immuniteit van rechtsmacht van staten en hun eigendommen (Uitvoeringswet VN-Verdrag staatsimmuniteit)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b966124c-359e-45cb-bf62-6f944e0089d6)/TK.DA.GGM.OData.Resource()
#
#
# == '3e2a9c16-63a4-44f5-9e83-3e1e5660f3d1' == Dossier 35999 == 16 docs == Voorstel van wet van de leden Koerhuis, Van der Plas, Grinwis en Westerveld tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Woningwet in verband met het bieden van huurbescherming aan weeskinderen (Wet huurbescherming weeskinderen) ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet huurbescherming weeskinderen
#   titel         Voorstel van wet van de leden Koerhuis, Van der Plas, Grinwis en Westerveld tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Woningwet in verband met het bieden van huurbescherming aan weeskinderen (Wet huurbescherming weeskinderen)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(85277fa6-d27e-48eb-b888-ef773d15e16d)/TK.DA.GGM.OData.Resource()
#
#
# == '53e35856-bb9b-453a-b797-05e4f5f2dbd8' == Dossier 35953 == 8 docs == Voorstel van wet van het lid Van Raan houdende wijziging van de Klimaatwet om te bewerkstelligen dat Nederland zo spoedig mogelijk een zo groot mogelijke bijdrage gaat leveren aan het voorkomen van een verdere opwarming van de Aarde (Klimaatwet 1.5) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Van Raan houdende wijziging van de Klimaatwet om te bewerkstelligen dat Nederland zo spoedig mogelijk een zo groot mogelijke bijdrage gaat leveren aan het voorkomen van een verdere opwarming van de Aarde (Klimaatwet 1.5)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(79f92ea9-a2ac-47a4-adac-e43687e9d965)/TK.DA.GGM.OData.Resource()
#
#
# == '8baa7ea2-fc92-4043-9e00-48a91cbdf8bf' == Dossier 35925-XIV == 162 docs == Vaststelling van de begrotingsstaten van het Ministerie van Landbouw, Natuur en Voedselkwaliteit (XIV) en het Diergezondheidsfonds (F) voor het jaar 2022 ==
# #3 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE
#   onderwerp     Advies Afdeling advisering Raad van State en Nader rapport
#   citeertitel
#   titel         Vaststelling van de begrotingsstaten van het Ministerie van Landbouw, Natuur en Voedselkwaliteit (XIV) en het Diergezondheidsfonds (F) voor het jaar 2022
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(81f48e48-8189-4335-a543-81b6a64cc813)/TK.DA.GGM.OData.Resource()
#
#
# == 'cb5510e3-80c1-4cbf-9531-9cc7430e90cb' == Dossier 35914 == 15 docs == Voorstel van wet van het lid Kops tot wijziging van de Huisvestingswet 2014 in verband met het uitzonderen van het verlenen van voorrang aan vergunninghouders bij huisvesting op grond van het feit dat zij vergunninghouder zijn (Wet uitzonderen voorrang vergunninghouders) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet uitzonderen voorrang vergunninghouders
#   titel         Voorstel van wet van het lid Kops tot wijziging van de Huisvestingswet 2014 in verband met het uitzonderen van het verlenen van voorrang aan vergunninghouders bij huisvesting op grond van het feit dat zij vergunninghouder zijn (Wet uitzonderen voorrang vergunninghouders)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(88979d43-f591-4ca3-8a5b-73524f86c000)/TK.DA.GGM.OData.Resource()
#
#
# == 'c6222530-7f6d-49ee-bc6c-364fb4a85b85' == Dossier 35761 == 20 docs == Voorstel van wet van de leden Van der Graaf, Jasper van Dijk, Thijssen, Van der Lee, Koekkoek en Hammelburg houdende regels voor gepaste zorgvuldigheid in waardeketens om schending van mensenrechten en het milieu tegen te gaan bij het bedrijven van buitenlandse handel (Wet verantwoord en duurzaam internationaal ondernemen) ==
# #8 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet verantwoord en duurzaam internationaal ondernemen
#   titel         Voorstel van wet van de leden Van der Graaf, Jasper van Dijk, Thijssen, Van der Lee, Koekkoek en Hammelburg houdende regels voor gepaste zorgvuldigheid in productieketens om schending van mensenrechten, arbeidsrechten en het milieu tegen te gaan bij het bedrijven van buitenlandse handel (Wet verantwoord en duurzaam internationaal ondernemen)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(fe675c97-22f9-46f4-8110-10a73d6fc5a4)/TK.DA.GGM.OData.Resource()
#
#
# == '5cb39db5-7a01-49b9-909b-c0154aa0e796' == Dossier 35754 == 11 docs == Voorstel van wet van de leden Bikker, Mohandis, Kuik, Westerveld, Van der Staaij, Dijk, Van Esch en Van der Plas tot wijziging van de Wet publieke gezondheid ter bevordering en verankering van integrale suïcidepreventie (Wet integrale suïcidepreventie) ==
# #7 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Bikker, Mohandis, Kuik, Westerveld, Van der Staaij, Dijk, Van Esch en Van der Plas tot wijziging van de Wet publieke gezondheid ter bevordering en verankering van integrale suïcidepreventie (Wet integrale suïcidepreventie)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f515ebad-cec3-4cc2-87b8-e45983818ec3)/TK.DA.GGM.OData.Resource()
#
#
# == '17e6671a-e68b-4084-ac90-a9ac4a63d5c2' == Dossier 35741 == 8 docs == Voorstel van wet van de leden Hammelburg, Bromet en De Hoop houdende verandering in de Grondwet, strekkende tot toevoeging van handicap en seksuele gerichtheid als non-discriminatiegrond ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies van de afdeling advisering van de Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Bergkamp, Özütok en Van den Hul houdende verandering in de Grondwet, strekkende tot toevoeging van handicap en seksuele gerichtheid als non-discriminatiegrond
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7bfca2d9-fe7c-4060-820a-0625b03bff8b)/TK.DA.GGM.OData.Resource()
#
#
# == '71f7a199-ece7-4aca-abf1-a00385746296' == Dossier 35737 == 29 docs == Voorstel van wet van de leden Paternotte, Kuiken, Ellemeet en Tellegen tot wijziging van Wet afbreking zwangerschap in verband met het afschaffen van de verplichte minimale beraadtermijn voor de afbreking van zwangerschappen ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Jetten tot wijziging van Wet afbreking zwangerschap in verband met het afschaffen van de verplichte minimale beraadtermijn voor de afbreking van zwangerschappen
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(18f1e108-8068-421f-bb05-2739125d0f7d)/TK.DA.GGM.OData.Resource()
#
#
# == 'a4827a89-332c-4667-b49d-d7fa1ec53873' == Dossier 35729 == 16 docs == Voorstel van wet van het lid Leijten houdende verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     35729 Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer inzake het voorstel van wet van het lid Van Raak houdende verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   citeertitel
#   titel         Voorstel van wet van het lid Van Raak houdende verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5102166a-a7d2-4677-90dc-6877eee40fcb)/TK.DA.GGM.OData.Resource()
#
#
# == '2c61a29f-1d53-4cba-8347-347d348342e8' == Dossier 35714 == 17 docs == Voorstel van wet van de leden Van Weyenberg en Maatoug tot wijziging van de Wet flexibel werken in verband met het bevorderen van flexibel werken naar arbeidsplaats (Wet werken waar je wilt) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet werken waar je wilt
#   titel         Voorstel van wet van de leden Van Weyenberg en Smeulders tot wijziging van de Wet flexibel werken in verband met het bevorderen van flexibel werken naar arbeidsplaats (Wet werken waar je wilt)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(63941ab0-d4f5-47ee-89b8-00d5166e3d05)/TK.DA.GGM.OData.Resource()
#
#
# == '0d382dd6-6e86-459e-ac4d-fd2770bde129' == Dossier 35709 == 11 docs == Voorstel van wet van de leden Ellemeet en Bikker tot wijziging van het Wetboek van Strafrecht in verband met de invoering van het discriminatoir oogmerk als strafverzwaringsgrond ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Ellemeet en Segers tot wijziging van het Wetboek van Strafrecht in verband met de invoering van het discriminatoir oogmerk als strafverzwaringsgrond
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9004be05-c82c-4317-994f-0d83be5d0e7b)/TK.DA.GGM.OData.Resource()
#
#
# == 'ae3373f1-cc16-4e98-af57-ad19d21cb9b8' == Dossier 35681 == 10 docs == Voorstel van wet van het lid Van Kent tot tijdelijke wijziging van de Pensioenwet en de Wet verplichte beroepspensioenregeling in verband met het invoeren van een maatregel tot onder meer aanpassing van de disconteringsvoet waartegen pensioenfondsen hun pensioenverplichtingen moeten berekenen ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Van Brenk tot tijdelijke wijziging van de Pensioenwet en de Wet verplichte beroepspensioenregeling in verband met het invoeren van een maatregel tot onder meer aanpassing van de disconteringsvoet waartegen pensioenfondsen hun pensioenverplichtingen moeten berekenen
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d02e3f0a-8896-4a18-94e5-0a15d1373ad9)/TK.DA.GGM.OData.Resource()
#
#
# == '9d878b43-e8d3-4d22-8e6c-e259eb0e4eec' == Dossier 35660 == 16 docs == Voorstel van wet van de leden Ellemeet en Tielen houdende wijziging van de Wet kwaliteit, klachten en geschillen zorg in verband met de invloed van zorgverleners ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Ellemeet en Aukje de Vries houdende wijziging van de Wet kwaliteit, klachten en geschillen zorg in verband met de invloed van zorgverleners
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(14c4df0f-2034-4113-9a3e-ce30db81ef3b)/TK.DA.GGM.OData.Resource()
#
#
# == 'bd9e437c-6e9b-45e0-89c6-75a2919dccb7' == Dossier 35636 == 7 docs == Voorstel van wet van het lid Van Kent tot wijziging van de Wet minimumloon en minimumvakantiebijslag in verband met het achterblijven van de loonontwikkeling (Wet eerlijker inkomen) ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van initiatiefnemers
#   citeertitel   Wet eerlijker inkomen
#   titel         Voorstel van wet van het lid Van Kent tot wijziging van de Wet minimumloon en minimumvakantiebijslag in verband met het achterblijven van de loonontwikkeling (Wet eerlijker inkomen)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9035be73-fb52-44fa-b748-474515d9a950)/TK.DA.GGM.OData.Resource()
#
#
# == 'f73f058a-30bf-49a9-8844-c60b51e67326' == Dossier 35608 == 19 docs == Voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(505fed20-e14e-4e96-a56e-f568d539e7cd)/TK.DA.GGM.OData.Resource()
#
#
# == '6a2f93f7-75a7-40a9-9327-5ea8e4216d94' == Dossier 35592 == 22 docs == Voorstel van wet van het lid Maatoug tot wijziging van de Arbeidsomstandighedenwet in verband met het verplicht stellen van een vertrouwenspersoon ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Maatoug tot wijziging van de Arbeidsomstandighedenwet in verband met het verplicht stellen van een vertrouwenspersoon
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3946d523-5332-41fb-a634-620d7d410876)/TK.DA.GGM.OData.Resource()
#
#
# == '69c79bee-4219-4bcb-905f-fb622a151feb' == Dossier 35536 == 11 docs == Voorstel van wet van het lid Kathmann tot wijziging van de Arbeidsomstandighedenwet in verband met het aangaan van een gesprek tussen werkgever en werknemers over bereikbaarheid buiten werktijd ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet op het recht op onbereikbaarheid
#   titel         Voorstel van wet van het lid Gijs van Dijk tot wijziging van de Arbeidsomstandighedenwet in verband met het aangaan van een gesprek tussen werkgever en werknemers over bereikbaarheid buiten werktijd (Wet op het recht op onbereikbaarheid)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(491229cc-6706-45f5-b8f6-12b1375f7c9d)/TK.DA.GGM.OData.Resource()
#
#
# == 'c1c1adfb-1f15-4796-afbf-e10f972eee03' == Dossier 35534 == 8 docs == Voorstel van wet van het lid Podt houdende toetsing van levenseindebegeleiding van ouderen op verzoek en tot wijziging van het Wetboek van Strafrecht, de Wet op de beroepen in de individuele gezondheidszorg en enkele andere wetten (Wet toetsing levenseindebegeleiding van ouderen op verzoek) ==
# #6 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet toetsing levenseindebegeleiding van ouderen op verzoek
#   titel         Voorstel van wet van het lid Podt houdende toetsing van levenseindebegeleiding van ouderen op verzoek en tot wijziging van het Wetboek van Strafrecht, de Wet op de beroepen in de individuele gezondheidszorg en enkele andere wetten (Wet toetsing levenseindebegeleiding van ouderen op verzoek)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(18fda2bb-78ac-492e-9b29-2f76019ca030)/TK.DA.GGM.OData.Resource()
#
#
# == '887f7acc-1e76-4677-9cb7-b80ae79ebe3c' == Dossier 35523 == 20 docs == Voorstel van wet van het lid Van der Lee tot wijziging van de Wet op de dividendbelasting 1965 en enige andere belastingwetten in verband met de invoering van een conditionele eindafrekening (Spoedwet conditionele eindafrekening dividendbelasting) ==
# #6 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Spoedwet conditionele eindafrekening dividendbelasting
#   titel         Voorstel van wet van het lid Snels tot wijziging van de Wet op de dividendbelasting 1965 en enige andere belastingwetten in verband met de invoering van een conditionele eindafrekening (Spoedwet conditionele eindafrekening dividendbelasting)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5739c7d0-b254-4b99-866a-340a7df81eb1)/TK.DA.GGM.OData.Resource()
#
# #7 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer inzake de nota van wijziging
#   citeertitel   Spoedwet conditionele eindafrekening dividendbelasting
#   titel         Voorstel van wet van het lid Snels tot wijziging van de Wet op de dividendbelasting 1965 en enige andere belastingwetten in verband met de invoering van een conditionele eindafrekening (Spoedwet conditionele eindafrekening dividendbelasting)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(57673193-df16-4611-b910-d6123b92c22a)/TK.DA.GGM.OData.Resource()
#
#
# == '987c2d57-c829-47e7-88f8-e84c5c7db5f1' == Dossier 35444 == 9 docs == Voorstel van wet van het lid Bromet tot wijziging van de Wet natuurbescherming en enige andere wetten in verband met het treffen van maatregelen betreffende stikstofemissie en het opnemen van een grondslag voor subsidieverlening voor veestapelreductie en natuurversterking (Wet duurzame aanpak stikstof) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet duurzame aanpak stikstof
#   titel         Voorstel van wet van de leden Klaver en Bromet tot wijziging van de Wet natuurbescherming in verband met het treffen van maatregelen betreffende stikstofemissie en het opnemen van een grondslag voor subsidieverlening voor veestapelreductie en natuurversterking (Wet duurzame aanpak stikstof)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6f381d17-8b99-461a-b5f8-09d7b9612f1a)/TK.DA.GGM.OData.Resource()
#
#
# == 'f41ce961-b8f4-4ec1-8538-701d5b673783' == Dossier 35410 == 9 docs == Voorstel van wet van het lid Kuiken houdende wijziging van de Geneesmiddelenwet, de Wet medische hulpmiddelen en de Wet op de beroepen in de individuele gezondheidszorg, tot oprichting van een openbaar register over de financiële betrekkingen tussen vergunninghouders en fabrikanten van geneesmiddelen en leveranciers van medische hulpmiddelen enerzijds en beroepsbeoefenaren, maatschappen, zorginstellingen, derden en patiënten-consumentenorganisaties anderzijds (Wet transparantieregister zorg) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies van de Afdeling advisering van de Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet transparantieregister zorg
#   titel         Voorstel van wet van het lid Ploumen houdende wijziging van de Geneesmiddelenwet, de Wet medische hulpmiddelen en de Wet op de beroepen in de individuele gezondheidszorg, tot oprichting van een openbaar register over de financiële betrekkingen tussen vergunninghouders en fabrikanten van geneesmiddelen en leveranciers van medische hulpmiddelen enerzijds en beroepsbeoefenaren, maatschappen, zorginstellingen, derden en patiënten-consumentenorganisaties anderzijds (Wet transparantieregister zorg)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(64bbfe4a-a72b-438a-b0a0-d29870566647)/TK.DA.GGM.OData.Resource()
#
#
# == 'e81db02a-5326-4bd1-a216-5cffdede639e' == Dossier 35406 == 10 docs == Voorstel van wet van de leden Markuszower en De Graaf tot wijziging van de Vreemdelingenwet in verband met afschaffing van de dwangsomregeling bij asielaanvragen (Noodwet afschaffing dwangsomregeling ter voorkoming van misbruik door asielzoekers) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Noodwet afschaffing dwangsomregeling ter voorkoming van misbruik door asielzoekers
#   titel         Voorstel van wet van de leden Wilders en Emiel van Dijk tot wijziging van de Vreemdelingenwet in verband met afschaffing van de dwangsomregeling bij asielaanvragen (Noodwet afschaffing dwangsomregeling ter voorkoming van misbruik door asielzoekers)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9d97ee0c-d228-4b92-a760-c4576ee8a64f)/TK.DA.GGM.OData.Resource()
#
#
# == '5c069fb5-bc99-44ce-9a05-22f3397c2dbf' == Dossier 35397 == 9 docs == Voorstel van wet van de leden Chris Simons en Inge van Dijk tot wijziging van de Gemeentewet, de Provinciewet en de Wet openbare lichamen Bonaire, Sint Eustatius en Saba in verband met het laten vervallen van het verplicht voorzitterschap door raadsleden, statenleden en eilandsraadsleden van raads-, staten- en eilandsraadscommissies ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Van den Bosch en Van der Molen tot wijziging van de Gemeentewet, de Provinciewet en de Wet openbare lichamen Bonaire, Sint Eustatius en Saba in verband met het laten vervallen van het verplicht voorzitterschap door raadsleden, statenleden en eilandsraadsleden van raads-, staten- en eilandsraadscommissies
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(11e0fb10-fd86-4ca2-b807-ba57501b87a0)/TK.DA.GGM.OData.Resource()
#
#
# == 'db70f6e0-cb2f-4721-b456-9e9a1859f0b4' == Dossier 35386 == 11 docs == Voorstel van wet van de leden Klaver en Ouwehand tot wijziging van de Wet milieubeheer en de Wet op de economische delicten in verband met de invoering van een vuurwerkverbod voor consumenten ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Klaver en Ouwehand tot wijziging van de Wet milieubeheer en de Wet op de economische delicten in verband met de invoering van een vuurwerkverbod voor consumenten
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bfdc17af-3d66-47ab-afe6-8515f1b42443)/TK.DA.GGM.OData.Resource()
#
#
# == '2638ab4b-8577-49be-8e04-b8c708f38716' == Dossier 35335 == 23 docs == Voorstel van wet van de leden Kathmann en Maatoug houdende wijziging van de Wet minimumloon en minimumvakantiebijslag en enige andere wetten in verband met de invoering van een uniform wettelijk minimumuurloon en enige andere wijzigingen (Wet invoering minimumuurloon) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet invoering minimumuurloon
#   titel         Voorstel van wet van het lid Gijs van Dijk houdende wijziging van de Wet minimumloon en minimumvakantiebijslag en enige andere wetten in verband met de invoering van een uniform wettelijk minimumuurloon en enige andere wijzigingen (Wet invoering minimumuurloon)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ed0af36d-6860-4cf7-9c2a-94b054f146fa)/TK.DA.GGM.OData.Resource()
#
#
# == '9c8835d2-9fb2-43e6-8f86-946354a0b419' == Dossier 35333 == 9 docs == Voorstel van wet van de leden Kops, Graus en Van Aalst houdende een noodregeling over stikstof (Tijdelijke noodwet stikstof) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Tijdelijke noodwet stikstof
#   titel         Voorstel van wet van de leden Kops, Graus en Van Aalst houdende een noodregeling over stikstof (Tijdelijke noodwet stikstof)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(54f1ea8f-ca87-4770-8a61-522e00ce4812)/TK.DA.GGM.OData.Resource()
#
#
# == '4edfde49-dc95-4a38-9b85-89db323edc18' == Dossier 35298 == 22 docs == Wijziging van de Gemeentewet, de Provinciewet en de Comptabiliteitswet 2016 in verband met het afschaffen van de decentrale rekenkamerfunctie en het uitbreiden van de bevoegdheden van de rekenkamers (Wet versterking decentrale rekenkamers) ==
# #14 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE
#   onderwerp     Advies Afdeling advisering Raad van State en Nader rapport
#   citeertitel   Wet versterking decentrale rekenkamers
#   titel         Wijziging van de Gemeentewet, de Provinciewet en de Comptabiliteitswet 2016 in verband met het afschaffen van de decentrale rekenkamerfunctie en het uitbreiden van de bevoegdheden van de rekenkamers (Wet versterking decentrale rekenkamers)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f31479ec-4f15-4f0e-b3b6-a342a5eebafc)/TK.DA.GGM.OData.Resource()
#
#
# == 'da54d573-1296-4fee-b096-645c663e0fb7' == Dossier 35296 == 18 docs == Voorstel van wet van de leden Koerhuis en Van Toorenburg tot wijziging van het Wetboek van Strafvordering in verband met het wijzigen van de rechterlijke procedure voor de beoordeling van de rechtmatige binnentreding van een woning of lokaal met als doel het verwijderen van personen alsmede voorwerpen die daar worden aangetroffen (Wet handhaving kraakverbod) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer(s)
#   citeertitel   Wet handhaving kraakverbod
#   titel         Voorstel van wet van de leden Koerhuis en Van Toorenburg tot wijziging van het Wetboek van Strafvordering in verband met het wijzigen van de rechterlijke procedure voor de beoordeling van de rechtmatige binnentreding van een woning of lokaal met als doel het verwijderen van personen alsmede voorwerpen die daar worden aangetroffen (Wet handhaving kraakverbod)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dcde8c11-5bcb-4ad1-8941-de523f32eb67)/TK.DA.GGM.OData.Resource()
#
#
# == 'c79b1c77-e0b1-462b-98b0-56d13959a9df' == Dossier 35257 == 14 docs == Voorstel van wet van het lid Verhoeven houdende een regeling voor een afwegingsproces voor het gebruik van kwetsbaarheden in geautomatiseerde werken door de overheid (Wet Zerodays Afwegingsproces) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer inzake het voorstel van wet van het lid Verhoeven houdende een regeling voor een afwegingsproces voor het gebruik van kwetsbaarheden in geautomatiseerde werken door de overheid (Wet Zerodays Afwegingsproces)
#   citeertitel   Wet Zerodays Afwegingsproces
#   titel         Voorstel van wet van het lid Verhoeven houdende een regeling voor een afwegingsproces voor het gebruik van kwetsbaarheden in geautomatiseerde werken door de overheid (Wet Zerodays Afwegingsproces)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(71adafdd-c96b-4e40-bdce-90125bf21f15)/TK.DA.GGM.OData.Resource()
#
#
# == 'd70ddedc-ab67-4e36-810a-c8298ff2c482' == Dossier 35202-(R2126) == 10 docs == Voorstel van rijkswet van de leden Verhoeven en Jetten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot toevoeging van bepalingen inzake het lidmaatschap van de Europese Unie ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State van het Koninkrijk en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van rijkswet van de leden Verhoeven en Jetten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot toevoeging van bepalingen inzake het lidmaatschap van de Europese Unie
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9b2fb066-f1ac-4974-a8ed-d47d3efc866e)/TK.DA.GGM.OData.Resource()
#
#
# == 'c75a0799-2199-4522-bbd0-6d9b006a39fc' == Dossier 35157 == 8 docs == Voorstel van wet van de leden Ploumen, Özütok, Jasper van Dijk en Van Brenk tot wijziging van de Wet gelijke behandeling mannen en vrouwen in verband met de invoering van een certificaat als bewijs dat vrouwen en mannen gelijk loon ontvangen voor arbeid van gelijke waarde (Wet gelijke beloning van vrouwen en mannen) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet gelijke beloning van vrouwen en mannen
#   titel         Voorstel van wet van de leden Ploumen, Özütok, Jasper van Dijk en Van Brenk tot wijziging van de Wet gelijke behandeling mannen en vrouwen in verband met de invoering van een certificaat als bewijs dat vrouwen en mannen gelijk loon ontvangen voor arbeid van gelijke waarde (Wet gelijke beloning van vrouwen en mannen)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(eddad807-9a2d-4a8f-a883-b55a1806f83d)/TK.DA.GGM.OData.Resource()
#
#
# == '2bc77341-f6e4-46cb-84f5-fed70a79707b' == Dossier 35130-(R2119) == 18 docs == Voorstel van Rijkswet van de leden Sjoerdsma, Asscher, Van Otterloo, Van Wijngaarden en Van Ojik houdende regels inzake het creëren van tijdelijke uitzonderingen op de Rijkswet op het Nederlanderschap (Rijkswet inperking gevolgen Brexit) ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State van het Koninkrijk en Reactie van de initiatiefnemers
#   citeertitel   Rijkswet inperking gevolgen Brexit
#   titel         Voorstel van Rijkswet van de leden Sjoerdsma, Asscher en Van Rooijen houdende regels inzake het creëren van tijdelijke uitzonderingen op de Rijkswet op het Nederlanderschap (Rijkswet inperking gevolgen Brexit)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(86019a2b-b8c3-4f38-8678-2eac9220a2ed)/TK.DA.GGM.OData.Resource()
#
#
# == '9c85134d-c871-4844-9e18-73695f9c7b0a' == Dossier 35129 == 16 docs == Voorstel van wet van het lid Van Raak houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Van Raak houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a713b831-7bb0-4ca1-a675-d277bd86ff3f)/TK.DA.GGM.OData.Resource()
#
#
# == 'bfd7ec3b-73c5-4b1b-826c-e850dd63467e' == Dossier 35101 == 13 docs == Voorstel van wet van het lid Warmerdam tot wijziging van de Pensioenwet en de Wet verplichte beroepspensioenregeling in verband met het toekennen van een adviesrecht aan het verantwoordingsorgaan en belanghebbendenorgaan voor het maatschappelijk verantwoord beleggingsbeleid (Wet eigen strategie pensioenfonds) ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Van Beukering-Huijbregts tot wijziging van de Pensioenwet en de Wet verplichte beroepspensioenregeling in verband met het toekennen van een adviesrecht aan het verantwoordingsorgaan en belanghebbendenorgaan voor het maatschappelijk verantwoord beleggingsbeleid en een goedkeuringsrecht voor het uitsluitingenbeleid
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1d9e5222-df81-48f7-8f55-790fcfbcb80c)/TK.DA.GGM.OData.Resource()
#
#
# == 'c34e6e0c-e82d-4fef-8426-249b3da53959' == Dossier 35096 == 9 docs == Voorstel van wet van de leden Smeulders en Van Rooijen tot wijziging van de Pensioenwet en de Wet verplichte beroepspensioenregeling in verband met het voorkomen van pensioenkortingen op de korte termijn ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies van de Afdeling advisering van de Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Smeulders en Van Rooijen tot wijziging van de Pensioenwet en de Wet verplichte beroepspensioenregeling in verband met het voorkomen van pensioenkortingen op de korte termijn
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7ba34ddd-5807-425e-b344-b61446b33adf)/TK.DA.GGM.OData.Resource()
#
#
# == 'f7be3cd0-4483-4bde-bc7e-752508c65e87' == Dossier 35079 == 29 docs == Voorstel van wet van de leden Kuiken, Kuik, Van Wijngaarden, Van der Graaf en Van der Staaij houdende regels over het bestuursrechtelijk verbieden van organisaties die een cultuur van wetteloosheid creëren, bevorderen of in stand houden (Wet bestuurlijk verbod ondermijnende organisaties) ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet bestuurlijk verbod ondermijnende organisaties
#   titel         Voorstel van wet van de leden Kuiken, Van Toorenburg, Van Wijngaarden, Drost en Van der Staaij houdende regels over het bestuursrechtelijk verbieden van organisaties die een cultuur van wetteloosheid creëren, bevorderen of in stand houden (Wet bestuurlijk verbod ondermijnende organisaties)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8cf08a2a-afe8-473c-9ece-bb48a5507a5d)/TK.DA.GGM.OData.Resource()
#
#
# == '2baa2d0d-2940-4614-a55b-c38cf712a1ce' == Dossier 35063 == 18 docs == Voorstel van wet van de leden Kwint en Westerveld tot wijziging van diverse onderwijswetten teneinde te verbieden dat leerlingen van ouders die geen vrijwillige geldelijke bijdrage hebben voldaan worden buitengesloten van activiteiten ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies van de Afdeling advisering van de Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Kwint en Westerveld tot wijziging van diverse onderwijswetten teneinde te verbieden dat leerlingen van ouders die geen vrijwillige geldelijke bijdrage hebben voldaan worden buitengesloten van activiteiten
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1663dbbf-d99d-442e-8e05-445e2bbeff18)/TK.DA.GGM.OData.Resource()
#
#
# == '153215eb-ee73-485e-8c8b-7a8faf75d755' == Dossier 35049 == 14 docs == Voorstel van wet van het lid Van Meenen tot wijziging van de Wet kinderopvang teneinde te bevorderen dat ouders kunnen kiezen tussen kindercentra die wel of niet kinderen toelaten die niet deelnemen aan het rijksvaccinatieprogramma ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Raemakers tot wijziging van de Wet kinderopvang teneinde te bevorderen dat ouders kunnen kiezen tussen kindercentra die wel of niet kinderen toelaten die niet deelnemen aan het rijksvaccinatieprogramma
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0a2fef0f-9183-4c8e-b6ae-582a354488d3)/TK.DA.GGM.OData.Resource()
#
#
# == '2c711fdf-94be-49a8-9b3b-796d47276018' == Dossier 35039 == 5 docs == Voorstel van wet van de leden Wilders en De Graaf betreffende het verbod van bepaalde islamitische uitingen ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
# ...
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cc9617fc-984f-49ac-8a57-2aa586f4ae41)/TK.DA.GGM.OData.Resource()
#
#
# == '1b2ae7ec-5120-4b48-8604-1c3f67dfb917' == Dossier 32414 == 12 docs == Voorstel van wet van de leden Eijsink, Van Dijk, Hachchi, El Fassed, Voordewind, Ouwehand, Van der Staaij, Hernandez, Bruins Slot en Bosman tot vaststelling van regels omtrent de bijzondere zorgplicht voor veteranen (Veteranenwet) ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Veteranenwet
#   titel         Voorstel van wet van de leden Eijsink, Van Dijk, Hachchi, El Fassed, Voordewind, Ouwehand, Van der Staaij, Hernandez, Bruins Slot en Bosman tot vaststelling van regels omtrent de bijzondere zorgplicht voor veteranen (Veteranenwet)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b4961f0b-1282-4f3c-8d1c-a5570caf1fad)/TK.DA.GGM.OData.Resource()
#
#
# == 'bf1f385f-a691-475f-b4bb-943fe68444ba' == Dossier 32411 == 14 docs == Voorstel van wet van de leden Bergkamp, Özütok en Van den Hul houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot toevoeging van handicap en seksuele gerichtheid als non-discriminatiegrond ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Van der Ham, Van Tongeren en Heijnen houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot toevoeging van handicap en hetero- of homoseksuele gerichtheid als non-discriminatiegrond
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3c209bde-70ff-4cbb-a928-1dad4ff8ef50)/TK.DA.GGM.OData.Resource()
#
#
# == '0f6b5e33-7604-43ba-b21b-6552a14b2998' == Dossier 32399 == 91 docs == Regels voor het kunnen verlenen van verplichte zorg aan een persoon met een psychische stoornis (Wet verplichte geestelijke gezondheidszorg) ==
# #11 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE
#   onderwerp     Advies Raad van State bij de nota van wijziging
#   citeertitel   Wet verplichte geestelijke gezondheidszorg
#   titel         Regels voor het kunnen verlenen van verplichte zorg aan een persoon met een psychische stoornis (Wet verplichte geestelijke gezondheidszorg)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2a277682-9316-4588-9a48-3e259f06d454)/TK.DA.GGM.OData.Resource()
#
#
# == 'ac10d8d1-cb07-4135-8c5a-bfa4143c2346' == Dossier 32328 == 11 docs == Voorstel van wet van het lid Van Nieuwenhuizen tot wijziging van de Wet werk en bijstand teneinde de eis tot beheersing van de Nederlandse taal toe te voegen aan de wet ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Van Nieuwenhuizen tot wijziging van de Wet werk en bijstand teneinde de eis tot beheersing van de Nederlandse taal toe te voegen aan de wet
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(90cff829-ee19-4474-b02f-fe8e1df8ca04)/TK.DA.GGM.OData.Resource()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tweede_kamer_dossiers.ipynb Cell 22 line <cell line: 11>()
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tweede_kamer_dossiers.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> nummer_and_toevoeging = ('%s-%s'%(dossier.nummer, dossier.toevoeging or '')).rstrip('-')
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tweede_kamer_dossiers.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> #if (dossier.nummer%100) == 0: # ignore a few specific special cases for now,   just because they're large to print
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tweede_kamer_dossiers.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> #    continue
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tweede_kamer_dossiers.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tweede_kamer_dossiers.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> ## In our stated interest:  first see if it has RvS advice
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tweede_kamer_dossiers.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> sorted_docs      = sorted(dossier.documenten,  key=lambda d:d.volgnummer )
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tweede_kamer_dossiers.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> has_raadvanstate = False
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/extras/datacollect/extras_datacollect_tweede_kamer_dossiers.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> for document in sorted_docs:
#
# File /usr/local/lib/python3.8/dist-packages/tkapi/dossier.py:42, in Dossier.documenten(self)
#      40 @property
#      41 def documenten(self) -> List[Document]:
# ---> 42     return self.related_items(Document)
#
# File /usr/local/lib/python3.8/dist-packages/tkapi/core.py:133, in TKItem.related_items(self, tkitem, filter, item_key)
#     131     return self._items_cache[cache_key]
#     132 url = self.json[navigation_key]
# --> 133 items = TKApi().get_related(tkitem, related_url=url, filter=filter)
#     134 self._set_cache(tkitem, filter, items)
#     135 return items
#
# File /usr/local/lib/python3.8/dist-packages/tkapi/tkapi.py:187, in TKApi.get_related(cls, tkitem_related, related_url, filter)
#     185 params = tkitem_related.get_param_expand()
#     186 params = TKApi.add_filter_to_params(filter, params)
# --> 187 first_page = cls._request_json(related_url, params)
#     188 related_items = []
#     189 if 'value' in first_page:
#
# File /usr/local/lib/python3.8/dist-packages/tkapi/tkapi.py:157, in TKApi._request_json(cls, url, params, max_items)
#     155 if cls.api_root.strip().lower() not in url.lower():
#     156     url = cls.api_root + url
# --> 157 response = requests.get(
#     158     url=url,
#     159     params=params,
#     160     timeout=60
#     161 )
#     162 if cls._verbose:
#     163     print('url ({} ms): {}'.format(
#     164         int(response.elapsed.total_seconds() * 1000),
#     165         urllib.parse.unquote(response.url))
#     166     )
#
# File /usr/local/lib/python3.8/dist-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /usr/local/lib/python3.8/dist-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /usr/local/lib/python3.8/dist-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File /usr/local/lib/python3.8/dist-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File /usr/local/lib/python3.8/dist-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File /usr/local/lib/python3.8/dist-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File /usr/lib/python3.8/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File /usr/lib/python3.8/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1037         if timeout == 0.0:
#    1038             # non-blocking
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#    1042     self.close()
#
# File /usr/lib/python3.8/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1307     if timeout == 0.0 and block:
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#    1311     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Actually making data from that
#
# TODO: decide what
