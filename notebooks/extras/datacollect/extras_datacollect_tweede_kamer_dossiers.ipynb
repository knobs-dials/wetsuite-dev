# %% [markdown]
# # Purpose of this notebook
#
# See what kind of things we can find out from the [tweede kamer open data portal](https://opendata.tweedekamer.nl/).

# %% [markdown]
# That portal has two interfaces:
# an [Atom-style API called SyncFeed](https://opendata.tweedekamer.nl/documentatie/syncfeed-api), and an [OData API](https://opendata.tweedekamer.nl/documentatie/odata-api).
#
# The Atom API is a little easier to interact without a whole library, OData is indeed more work to use but can be a little more thorough and flexible.
#
# The returned formats seem to be XML and JSON.

# %% [markdown]
# Either way, there is a [relational data model](https://opendata.tweedekamer.nl/documentatie/informatiemodel) that you should be thinking of,
# though in this notebook we focus primarily on the dossiers and documents in them, which stays relatively simple.
#
# Because there is a bunch of data referring to other data, much of the below is trying to explore/show
# what kind of interesting things might be in there in the first place.
#
# ...because we probably don't want to just fetch everything,
# we want to show how to figure how to get and use the parts you need for a specific purpose.

# %% [markdown]
# ## Atom/SyncFeed API

# %%
import collections, pprint

import wetsuite.datacollect.tweedekamer_nl

from wetsuite.datacollect     import tweedekamer_nl # contains some basic code dealing with the syncfeed API
from wetsuite.helpers         import etree
from wetsuite.helpers         import strings
from wetsuite.helpers         import notebook

# %% [markdown]
# #### Any one resource type
#
# Syncfeed starts by interacting with an URL like:
#
#         https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Persoon
#
# ...which is the first bunch/page of them, and links to successive pages.
#
# To fetch all resources of the mentioned soort/category, and to then perhaps make a single list of it,
# you need something that follows and fetches those links, e.g. our wetsuite.datacollect.tweedekamer_nl.fetch_all
#
# However, due to the relational nature of of the data (pointing at related objects, and you often wanting to fetch a related constellation of them),
# it quickly becomes interesting to interrogate the data with more foresight - we'll get to that later.

# %% [markdown]
# Uses vary.
# - There is e.g. a [another notebook that extracts who is member of what party](extras_datacollect_tweede_kamer_parties.ipynb),
#   which is a somewhat manual piecing together of 'Persoon', 'Fractie', 'FractieZetel', and 'FractieZetelPersoon'.
#
# - If you wanted a record of what gets done in an everyday way, you might care about 'Vergadering', 'Verslag', 'Stemming',
#   or if you are more interested in documentation, then 'Zaak', 'Document', 'Kamerstukdossier'.
#
# - Kamerstukdossiers are interesting - and also their relations are a little more complex than they seem at first.
#
# For a list of types with some explanation of their relations, see [the documentation](https://opendata.tweedekamer.nl/documentatie/).
#
# For just a list of the types:

# %%
tweedekamer_nl.resource_types

# %%
# Let's start with something basic - fetch a lits of all Zaal objects

etrees = tweedekamer_nl.fetch_all( 'Zaal' )   # in this case it should take only a handful of seconds, 
#                     though note that for e.g. Stemming, Zaak, Document total to hundred of megabytes
# It returned a list of etree objects,  
# so if our goal were to to write that into a single XML file, we want to merge that
single_tree = tweedekamer_nl.merge_etrees( etrees )  

# For reference, you could see that joined thing
#print( etree.debug_pretty( single_tree ) )
# ...or possibly save that for later use
#xmlstring = wetsuite.helpers.etree.tostring( single_tree )                # then save that 
#with open('%s.xml'%soort, 'wb') as xf:   # (technically injection-sensitive, except it's fine as long as we control the values of soort)
#    xf.write( xmlstring )       

# Right now we are probably just interested in getting out data into python dicts so you can handle them more easily
#There is another function that helps us see each entry's details as python dict structures
entry_dicts = tweedekamer_nl.entry_dicts( single_tree )

pprint.pprint( entry_dicts )
# Out:
# [{'category': 'zaal',
#   'id': '6e7dfdae-583a-4191-8818-a89a538c469f',
#   'naam': 'Z7 - Statenpassage - Petitie',
#   'sysCode': '154',
#   'title': '6e7dfdae-583a-4191-8818-a89a538c469f',
#   'updated': '2019-08-15T14:45:52Z'},
#  {'category': 'zaal',
#   'id': 'f207b9d5-434e-4cdc-aa1b-7e5a55bc1791',
#   'naam': 'Eerste Kamer',
#   'sysCode': '101',
#   'title': 'f207b9d5-434e-4cdc-aa1b-7e5a55bc1791',
#   'updated': '2019-08-15T14:45:52Z'},
#  {'category': 'zaal',
#   'id': 'be4bcf1c-a5a1-426b-8ca0-e41fb9493846',
#   'naam': 'Z6 - Plein 2 - Petitie',
#   'sysCode': '142',
#   'title': 'be4bcf1c-a5a1-426b-8ca0-e41fb9493846',
#   'updated': '2019-08-15T14:45:52Z'},
#  {'category': 'zaal',
#   'id': '65c9a207-3a13-4213-99d5-b9a2d6157c26',
#   'naam': 'Regentenkamer',
#   'sysCode': '67',
#   'title': '65c9a207-3a13-4213-99d5-b9a2d6157c26',
#   'updated': '2019-08-15T14:45:51Z'},
#  {'category': 'zaal',
#   'id': 'c66f17e7-6b9a-40b5-b722-01600d78cfb8',
#   'naam': 'Schrijfkamer',
#   'sysCode': '55',
#   'title': 'c66f17e7-6b9a-40b5-b722-01600d78cfb8',
#   'updated': '2019-08-15T14:45:51Z'},
#  {'category': 'zaal',
#   'id': 'e5bd1f16-003d-4af3-8aa5-bbac17c6be38',
#   'naam': 'Statenlokaal',
#   'sysCode': '72',
#   'title': 'e5bd1f16-003d-4af3-8aa5-bbac17c6be38',
#   'updated': '2019-08-15T14:45:51Z'},
#  {'category': 'zaal',
#   'id': '8d7503e2-f300-4a1f-8e7c-cebfb8c2690c',
#   'naam': 'Van Mierlozaal',
#   'sysCode': '102',
#   'title': '8d7503e2-f300-4a1f-8e7c-cebfb8c2690c',
#   'updated': '2019-08-15T14:45:52Z'},
#  {'category': 'zaal',
#   'id': '37359881-2750-4700-b4c5-4ee5fc90972c',
#   'naam': 'Z5 - Schriftelijke Inbreng',
#   'sysCode': '148',
#   'title': '37359881-2750-4700-b4c5-4ee5fc90972c',
#   'updated': '2019-08-15T14:45:52Z'},
#  {'category': 'zaal',
#   'id': '0741e6d8-c702-4e06-925b-f19b1e08f058',
#   'naam': 'van Someren-Downerzaal',
#   'sysCode': '73',
#   'title': '0741e6d8-c702-4e06-925b-f19b1e08f058',
#   'updated': '2019-08-15T14:45:51Z'},
#  {'category': 'zaal',
#   'id': '5df81c3f-5976-4689-abbb-4bf6ebe562bf',
#   'naam': 'Rooksalon',
#   'sysCode': '56',
#   'title': '5df81c3f-5976-4689-abbb-4bf6ebe562bf',
#   'updated': '2019-08-15T14:45:51Z'},
#  {'category': 'zaal',
#   'id': 'ac9cafe8-22ed-4690-9b31-5d0f96ffc35a',
#   'naam': 'Fortuynzaal',
#   'sysCode': '106',
#   'title': 'ac9cafe8-22ed-4690-9b31-5d0f96ffc35a',
#   'updated': '2019-08-15T14:45:52Z'},
#  {'category': 'zaal',
#   'id': '440a9af6-6028-4833-bbe1-2896f8e5a882',
#   'naam': 'Koffiekamer',
#   'sysCode': '153',
#   'title': '440a9af6-6028-4833-bbe1-2896f8e5a882',
#   'updated': '2019-08-15T14:45:52Z'},
#  {'category': 'zaal',
#   'id': 'e2fead75-5085-4a98-aa71-53689333b91c',
#   'naam': 'Extern',
#   'sysCode': '263',
#   'title': 'e2fead75-5085-4a98-aa71-53689333b91c',
#   'updated': '2019-08-15T14:45:53Z'},
#  {'category': 'zaal',
#   'id': '3f42c27b-2b35-43de-a029-eece96e7bfe4',
#   'naam': 'Z5 - (Nog) geen zaal beschikbaar',
#   'sysCode': '244',
#   'title': '3f42c27b-2b35-43de-a029-eece96e7bfe4',
#   'updated': '2019-08-15T14:45:53Z'},
#  {'category': 'zaal',
#   'id': '53f31d22-3e08-4862-8ab6-c831f0a31e37',
#   'naam': 'Evenementruimte 1',
#   'sysCode': '216',
#   'title': '53f31d22-3e08-4862-8ab6-c831f0a31e37',
#   'updated': '2019-08-15T14:45:53Z'},
#  {'category': 'zaal',
#   'id': '65c014a6-30d4-4157-9c57-e5026786e127',
#   'naam': 'Koffiekamer',
#   'sysCode': '330',
#   'title': '65c014a6-30d4-4157-9c57-e5026786e127',
#   'updated': '2019-08-15T14:45:53Z'},
#  {'category': 'zaal',
#   'id': '03992fde-43d1-4b74-a944-163f91000fbd',
#   'naam': 'Z4 - (Nog) geen zaal beschikbaar',
#   'sysCode': '243',
#   'title': '03992fde-43d1-4b74-a944-163f91000fbd',
#   'updated': '2019-08-15T14:45:53Z'},
#  {'category': 'zaal',
#   'id': '8c758168-4118-4621-85a5-114d168acbfb',
#   'naam': 'Oude zaal - Rooksalon',
#   'sysCode': '231',
#   'title': '8c758168-4118-4621-85a5-114d168acbfb',
#   'updated': '2019-08-15T14:45:53Z'},
#  {'category': 'zaal',
#   'id': 'ab9b417e-b2d0-470f-950e-92adb31395d5',
#   'naam': 'Rooksalon - Stadhouderskamer',
#   'sysCode': '234',
#   'title': 'ab9b417e-b2d0-470f-950e-92adb31395d5',
#   'updated': '2019-08-15T14:45:53Z'},
#  {'category': 'zaal',
#   'id': '14d87de5-8ae4-4b73-91e7-633fbe5ba652',
#   'naam': 'Schrijfkamer - Koffiekamer',
#   'sysCode': '221',
#   'title': '14d87de5-8ae4-4b73-91e7-633fbe5ba652',
#   'updated': '2019-08-15T14:45:53Z'},
#  {'category': 'zaal',
#   'id': 'd8a89950-519e-4070-8532-30681a8e699b',
#   'naam': 'Z3 - (Nog) geen zaal beschikbaar',
#   'sysCode': '242',
#   'title': 'd8a89950-519e-4070-8532-30681a8e699b',
#   'updated': '2019-10-01T15:15:40Z'},
#  {'category': 'zaal',
#   'id': '1df976b4-f013-4808-be26-405b1137dcd5',
#   'naam': 'Y4 - Petitie Binnenhof 1a',
#   'sysCode': '261',
#   'title': '1df976b4-f013-4808-be26-405b1137dcd5',
#   'updated': '2019-10-03T11:30:30Z'},
#  {'category': 'zaal',
#   'id': '7ba8c438-cea9-47c3-b761-a60aad801433',
#   'naam': 'Zandtkamer',
#   'sysCode': '82',
#   'title': '7ba8c438-cea9-47c3-b761-a60aad801433',
#   'updated': '2019-10-27T20:20:36Z'},
#  {'category': 'zaal',
#   'id': 'c1fd68f6-6088-436b-a08f-5f091cf4462d',
#   'naam': 'PvdA Fractiekamer',
#   'sysCode': '68',
#   'title': 'c1fd68f6-6088-436b-a08f-5f091cf4462d',
#   'updated': '2019-11-12T10:19:54Z'},
#  {'category': 'zaal',
#   'id': 'a5c7cf56-9007-4d17-824f-a4457027eed6',
#   'naam': 'Donkerkamer',
#   'sysCode': '87',
#   'title': 'a5c7cf56-9007-4d17-824f-a4457027eed6',
#   'updated': '2020-01-05T20:20:01Z'},
#  {'category': 'zaal',
#   'id': 'b6953420-6b66-4c8c-8d23-052796fda0b6',
#   'naam': 'Oudkamer',
#   'sysCode': '81',
#   'title': 'b6953420-6b66-4c8c-8d23-052796fda0b6',
#   'updated': '2020-01-06T20:20:14Z'},
#  {'category': 'zaal',
#   'id': 'dbcaecd1-1d91-4b6e-8348-65513980de06',
#   'naam': 'Y5 - Petitie Plein 2',
#   'sysCode': '262',
#   'title': 'dbcaecd1-1d91-4b6e-8348-65513980de06',
#   'updated': '2020-01-28T08:22:15Z'},
#  {'category': 'zaal',
#   'id': '7935b4f8-a1d5-4892-928a-e299578cf453',
#   'naam': 'Jongelingkamer',
#   'sysCode': '83',
#   'title': '7935b4f8-a1d5-4892-928a-e299578cf453',
#   'updated': '2020-02-24T20:17:51Z'},
#  {'category': 'zaal',
#   'id': '25985037-0703-43e5-8277-78a3bfc5fdef',
#   'naam': 'Schaepmankamer',
#   'sysCode': '91',
#   'title': '25985037-0703-43e5-8277-78a3bfc5fdef',
#   'updated': '2020-03-01T20:18:30Z'},
#  {'category': 'zaal',
#   'id': 'f7ae0a8c-a8df-452b-81da-42997b8b55d3',
#   'naam': 'Marcus Bakkerkamer',
#   'sysCode': '80',
#   'title': 'f7ae0a8c-a8df-452b-81da-42997b8b55d3',
#   'updated': '2020-03-19T20:17:39Z'},
#  {'category': 'zaal',
#   'id': '6396bfa5-c577-489e-9d2c-11d673628d0d',
#   'naam': 'Terlouwzaal',
#   'sysCode': '104',
#   'title': '6396bfa5-c577-489e-9d2c-11d673628d0d',
#   'updated': '2020-05-14T14:09:36Z'},
#  {'category': 'zaal',
#   'id': '5922191f-5373-438b-95ee-3bfc21f89042',
#   'naam': 'Plenaire zaal Tweede Kamer',
#   'sysCode': '79',
#   'title': '5922191f-5373-438b-95ee-3bfc21f89042',
#   'updated': '2020-07-30T19:18:06Z'},
#  {'category': 'zaal',
#   'id': '697ddf4d-65ef-4429-811b-6210ecdd7dee',
#   'naam': 'PVV Fractiekamer',
#   'sysCode': '66',
#   'title': '697ddf4d-65ef-4429-811b-6210ecdd7dee',
#   'updated': '2020-09-02T11:55:10Z'},
#  {'category': 'zaal',
#   'id': '8b354ff6-3933-4e1c-9c70-c4d8fee3323a',
#   'naam': 'Dreeskamer',
#   'sysCode': '84',
#   'title': '8b354ff6-3933-4e1c-9c70-c4d8fee3323a',
#   'updated': '2020-10-01T19:19:44Z'},
#  {'category': 'zaal',
#   'id': '90c28bc5-cb8e-4973-a145-969e6c84fb14',
#   'naam': 'Enquêtezaal',
#   'sysCode': '141',
#   'title': '90c28bc5-cb8e-4973-a145-969e6c84fb14',
#   'updated': '2021-01-11T20:17:44Z'},
#  {'category': 'zaal',
#   'id': '61e9c5fa-201f-48a2-8e02-95b779d6f3ec',
#   'naam': 'Schoutenkamer',
#   'sysCode': '92',
#   'title': '61e9c5fa-201f-48a2-8e02-95b779d6f3ec',
#   'updated': '2021-02-04T13:15:32Z'},
#  {'category': 'zaal',
#   'id': 'aaea1191-c126-4fda-af47-8a1bc319b64f',
#   'naam': 'Grenadierszaal',
#   'sysCode': '63',
#   'title': 'aaea1191-c126-4fda-af47-8a1bc319b64f',
#   'updated': '2021-02-21T19:19:51Z'},
#  {'category': 'zaal',
#   'id': '2302d207-b2c2-4d1a-9d97-609d2e821215',
#   'naam': 'Oude zaal',
#   'sysCode': '54',
#   'title': '2302d207-b2c2-4d1a-9d97-609d2e821215',
#   'updated': '2021-03-12T20:19:59Z'},
#  {'category': 'zaal',
#   'id': '6ce985d0-0a02-4a6b-9b8a-910756cc620e',
#   'naam': 'Kuyperkamer',
#   'sysCode': '90',
#   'title': '6ce985d0-0a02-4a6b-9b8a-910756cc620e',
#   'updated': '2021-05-17T11:54:38Z'},
#  {'category': 'zaal',
#   'id': 'c4506328-360b-4935-ad43-3c99dbc1a07a',
#   'naam': '(Nog) geen zaal beschikbaar',
#   'sysCode': '241',
#   'title': 'c4506328-360b-4935-ad43-3c99dbc1a07a',
#   'updated': '2021-05-25T18:25:20Z'},
#  {'category': 'zaal',
#   'id': '8faebef7-9e47-4f39-a1f7-11f2e22feac6',
#   'naam': 'Aletta Jacobszaal',
#   'sysCode': '77',
#   'title': '8faebef7-9e47-4f39-a1f7-11f2e22feac6',
#   'updated': '2021-05-27T13:56:00Z'},
#  {'category': 'zaal',
#   'id': 'b749a6d4-b076-4e97-9b42-722a1340825b',
#   'naam': 'Suze Groenewegzaal',
#   'sysCode': '76',
#   'title': 'b749a6d4-b076-4e97-9b42-722a1340825b',
#   'updated': '2021-06-03T08:53:00Z'},
#  {'category': 'zaal',
#   'id': '4efd094a-d128-4ae5-8da8-d47bc80241cc',
#   'naam': 'Wttewaall van Stoetwegenzaal',
#   'sysCode': '75',
#   'title': '4efd094a-d128-4ae5-8da8-d47bc80241cc',
#   'updated': '2021-06-09T13:37:59Z'},
#  {'category': 'zaal',
#   'id': '2f12af84-7b6d-492c-8aab-4bb7763b1343',
#   'naam': 'Petitie Statenpassage',
#   'sysCode': '239',
#   'title': '2f12af84-7b6d-492c-8aab-4bb7763b1343',
#   'updated': '2021-06-10T13:25:48Z'},
#  {'category': 'zaal',
#   'id': 'ecb7b01f-a05b-48cd-a715-8996e92e500d',
#   'naam': 'Petitie Statenpassage',
#   'sysCode': '238',
#   'title': 'ecb7b01f-a05b-48cd-a715-8996e92e500d',
#   'updated': '2021-06-11T11:44:18Z'},
#  {'category': 'zaal',
#   'id': 'b4f266b6-a11b-4c58-bd15-6d00d6cce7e3',
#   'naam': 'Schaperkamer',
#   'sysCode': '85',
#   'title': 'b4f266b6-a11b-4c58-bd15-6d00d6cce7e3',
#   'updated': '2021-06-14T13:09:52Z'},
#  {'category': 'zaal',
#   'id': '0ad10e62-479e-45ec-8c89-b41ece33b880',
#   'naam': 'Daleszaal',
#   'sysCode': '103',
#   'title': '0ad10e62-479e-45ec-8c89-b41ece33b880',
#   'updated': '2021-06-15T11:19:18Z'},
#  {'category': 'zaal',
#   'id': '82ec6018-715d-4347-a6c4-22581ce2b5c4',
#   'naam': 'Rommekamer',
#   'sysCode': '89',
#   'title': '82ec6018-715d-4347-a6c4-22581ce2b5c4',
#   'updated': '2021-06-17T10:24:58Z'},
#  {'category': 'zaal',
#   'id': '1d9ab223-78c5-4a0d-9be2-a94bab6b57ea',
#   'naam': 'Den Uylzaal',
#   'sysCode': '60',
#   'title': '1d9ab223-78c5-4a0d-9be2-a94bab6b57ea',
#   'updated': '2021-06-17T11:55:19Z'},
#  {'category': 'zaal',
#   'id': '52b03fec-dd66-4190-866b-cda7f2c79db9',
#   'naam': 'Thorbeckezaal',
#   'sysCode': '94',
#   'title': '52b03fec-dd66-4190-866b-cda7f2c79db9',
#   'updated': '2021-06-18T08:05:47Z'},
#  {'category': 'zaal',
#   'id': '5d2a8166-4e2f-4a1d-8437-1888d2f4f720',
#   'naam': 'K4',
#   'sysCode': '370',
#   'title': '5d2a8166-4e2f-4a1d-8437-1888d2f4f720',
#   'updated': '2021-06-18T09:10:36Z'},
#  {'category': 'zaal',
#   'id': 'c3b9da32-11c6-445f-8018-b65517b108e9',
#   'naam': 'Petitie Statenpassage',
#   'sysCode': '237',
#   'title': 'c3b9da32-11c6-445f-8018-b65517b108e9',
#   'updated': '2021-06-18T09:25:48Z'},
#  {'category': 'zaal',
#   'id': 'abef31fc-88c5-4149-ae74-359df4105f59',
#   'naam': 'Groen van Prinstererzaal',
#   'sysCode': '95',
#   'title': 'abef31fc-88c5-4149-ae74-359df4105f59',
#   'updated': '2021-06-18T11:00:50Z'},
#  {'category': 'zaal',
#   'id': 'b4076a1c-371e-4ad1-83d9-adfd3f8fffc3',
#   'naam': 'Troelstrazaal',
#   'sysCode': '96',
#   'title': 'b4076a1c-371e-4ad1-83d9-adfd3f8fffc3',
#   'updated': '2021-06-18T11:40:23Z'},
#  {'category': 'zaal',
#   'id': 'a6c79d16-f968-417a-b604-3f28d143a5d4',
#   'naam': 'Tilanuskamer',
#   'sysCode': '88',
#   'title': 'a6c79d16-f968-417a-b604-3f28d143a5d4',
#   'updated': '2021-06-18T19:20:21Z'},
#  {'category': 'zaal',
#   'id': '0202177b-ac53-46c4-9e14-390127c44360',
#   'naam': 'Vondelingkamer',
#   'sysCode': '86',
#   'title': '0202177b-ac53-46c4-9e14-390127c44360',
#   'updated': '2021-06-18T19:20:21Z'},
#  {'category': 'zaal',
#   'id': 'a78a762d-6d94-4492-8ba8-d81e7bfec0fa',
#   'naam': '(Nog) geen zaal beschikbaar',
#   'sysCode': '240',
#   'title': 'a78a762d-6d94-4492-8ba8-d81e7bfec0fa',
#   'updated': '2021-06-25T12:59:02Z'},
#  {'category': 'zaal',
#   'id': 'fa795714-6049-4a78-a02c-07b117abd9ac',
#   'naam': 'Max van der Stoelzaal',
#   'sysCode': '391',
#   'title': 'fa795714-6049-4a78-a02c-07b117abd9ac',
#   'updated': '2021-06-29T08:15:20Z'},
#  {'category': 'zaal',
#   'id': '091e45d7-0451-41d3-a45c-0dca271e39db',
#   'naam': 'Groen van Prinstererzaal',
#   'sysCode': '418',
#   'title': '091e45d7-0451-41d3-a45c-0dca271e39db',
#   'updated': '2021-07-08T06:42:59Z'},
#  {'category': 'zaal',
#   'id': '192bfff7-4cc1-457f-b889-7b7c9033399c',
#   'naam': 'VVD Fractiekamer',
#   'sysCode': '61',
#   'title': '192bfff7-4cc1-457f-b889-7b7c9033399c',
#   'updated': '2021-09-03T09:47:55Z'},
#  {'category': 'zaal',
#   'id': '6a528771-d839-4c5c-9072-0519fa88c0be',
#   'naam': 'Klompézaal',
#   'sysCode': '74',
#   'title': '6a528771-d839-4c5c-9072-0519fa88c0be',
#   'updated': '2022-03-30T14:16:33Z'},
#  {'category': 'zaal',
#   'id': 'badf4c46-43c8-4d31-94d2-2a7090522a69',
#   'naam': 'Balzaal',
#   'sysCode': '105',
#   'title': 'badf4c46-43c8-4d31-94d2-2a7090522a69',
#   'updated': '2023-03-29T08:10:29Z'}]

# %%
# a little more readably  /  an example of picking things from that dict
for detail_dict in wetsuite.datacollect.tweedekamer_nl.entry_dicts( single_tree ):
    print(f"{detail_dict['naam']:40s}    {detail_dict['updated']}")
# Out:
# Z7 - Statenpassage - Petitie                2019-08-15T14:45:52Z
# Eerste Kamer                                2019-08-15T14:45:52Z
# Z6 - Plein 2 - Petitie                      2019-08-15T14:45:52Z
# Regentenkamer                               2019-08-15T14:45:51Z
# Schrijfkamer                                2019-08-15T14:45:51Z
# Statenlokaal                                2019-08-15T14:45:51Z
# Van Mierlozaal                              2019-08-15T14:45:52Z
# Z5 - Schriftelijke Inbreng                  2019-08-15T14:45:52Z
# van Someren-Downerzaal                      2019-08-15T14:45:51Z
# Rooksalon                                   2019-08-15T14:45:51Z
# Fortuynzaal                                 2019-08-15T14:45:52Z
# Koffiekamer                                 2019-08-15T14:45:52Z
# Extern                                      2019-08-15T14:45:53Z
# Z5 - (Nog) geen zaal beschikbaar            2019-08-15T14:45:53Z
# Evenementruimte 1                           2019-08-15T14:45:53Z
# Koffiekamer                                 2019-08-15T14:45:53Z
# Z4 - (Nog) geen zaal beschikbaar            2019-08-15T14:45:53Z
# Oude zaal - Rooksalon                       2019-08-15T14:45:53Z
# Rooksalon - Stadhouderskamer                2019-08-15T14:45:53Z
# Schrijfkamer - Koffiekamer                  2019-08-15T14:45:53Z
# Z3 - (Nog) geen zaal beschikbaar            2019-10-01T15:15:40Z
# Y4 - Petitie Binnenhof 1a                   2019-10-03T11:30:30Z
# Zandtkamer                                  2019-10-27T20:20:36Z
# PvdA Fractiekamer                           2019-11-12T10:19:54Z
# Donkerkamer                                 2020-01-05T20:20:01Z
# Oudkamer                                    2020-01-06T20:20:14Z
# Y5 - Petitie Plein 2                        2020-01-28T08:22:15Z
# Jongelingkamer                              2020-02-24T20:17:51Z
# Schaepmankamer                              2020-03-01T20:18:30Z
# Marcus Bakkerkamer                          2020-03-19T20:17:39Z
# Terlouwzaal                                 2020-05-14T14:09:36Z
# Plenaire zaal Tweede Kamer                  2020-07-30T19:18:06Z
# PVV Fractiekamer                            2020-09-02T11:55:10Z
# Dreeskamer                                  2020-10-01T19:19:44Z
# Enquêtezaal                                 2021-01-11T20:17:44Z
# Schoutenkamer                               2021-02-04T13:15:32Z
# Grenadierszaal                              2021-02-21T19:19:51Z
# Oude zaal                                   2021-03-12T20:19:59Z
# Kuyperkamer                                 2021-05-17T11:54:38Z
# (Nog) geen zaal beschikbaar                 2021-05-25T18:25:20Z
# Aletta Jacobszaal                           2021-05-27T13:56:00Z
# Suze Groenewegzaal                          2021-06-03T08:53:00Z
# Wttewaall van Stoetwegenzaal                2021-06-09T13:37:59Z
# Petitie Statenpassage                       2021-06-10T13:25:48Z
# Petitie Statenpassage                       2021-06-11T11:44:18Z
# Schaperkamer                                2021-06-14T13:09:52Z
# Daleszaal                                   2021-06-15T11:19:18Z
# Rommekamer                                  2021-06-17T10:24:58Z
# Den Uylzaal                                 2021-06-17T11:55:19Z
# Thorbeckezaal                               2021-06-18T08:05:47Z
# K4                                          2021-06-18T09:10:36Z
# Petitie Statenpassage                       2021-06-18T09:25:48Z
# Groen van Prinstererzaal                    2021-06-18T11:00:50Z
# Troelstrazaal                               2021-06-18T11:40:23Z
# Tilanuskamer                                2021-06-18T19:20:21Z
# Vondelingkamer                              2021-06-18T19:20:21Z
# (Nog) geen zaal beschikbaar                 2021-06-25T12:59:02Z
# Max van der Stoelzaal                       2021-06-29T08:15:20Z
# Groen van Prinstererzaal                    2021-07-08T06:42:59Z
# VVD Fractiekamer                            2021-09-03T09:47:55Z
# Klompézaal                                  2022-03-30T14:16:33Z
# Balzaal                                     2023-03-29T08:10:29Z

# %% [markdown]
# #### Kamerstukdossiers

# %% [markdown]
# Now let's focus on the kamerstukdossiers.
#
# (note: half of this code is more for interrogating what's there, you can white much shorter things)

# %%
# Fetch all kamerstukdossiers.    
#   May take half a minute or so to fetch all,
#   because that's ~30 fetches amounting to ~6MByte of XML.
#   and so also let's not print it
single_tree = tweedekamer_nl.merge_etrees( tweedekamer_nl.fetch_all( 'Kamerstukdossier' ) )

# %%
# Let's see what kind of dossier topics we have in there, 
#    ...so far purely by looking at the text in their title

verbose = 0

ourtypes = collections.defaultdict(list)
for i, entry_node in enumerate( single_tree ):
    edict = tweedekamer_nl.entry_dict_from_node( entry_node )

    ksd = entry_node.find('content/kamerstukdossier')
    if verbose:
        print()
        print(etree.debug_pretty(ksd))
        pprint.pprint(edict)

    # exception case:   if that attribute is there, there are no contents
    if ksd.get('verwijderd', None) == 'true':   
        ourtypes['[verwijderd]'].append( ksd.get('id') )
        #print("SKIP verwijderd (%s)"%ksd.get('id'))
        continue 

    try:
        titel = ksd.find('titel').text
    except AttributeError:
        print( 'ERROR: no title? (%r)'%entry_node )
        display( notebook.etree_visualize_selection(ksd, '*', mark_subtree=True) )

    if titel is None:
        print( 'ERROR: dossier without titel (%r)'%entry_node )
        display( notebook.etree_visualize_selection(ksd, '*', mark_subtree=True) )
        continue
    titel = titel.strip()


    if strings.contains_any_of(titel, ['EU-voorstel', 'EU voorstel', 'EU-mededeling', 'EU-trendrapport']):
        ourtypes['eu'].append( titel )
        continue

    elif strings.contains_any_of(titel, ['begrotingssta', 'slotwet', 'voorjaarsnota','najaarsnota', 'Financieel jaarverslag'], case_sensitive=False):
        #print( 'BEGROTING %-7s %20s  %s'%(edict.get('nummer'), edict.get('updated'), titel) )
        ourtypes['begroting'].append( titel )   # up here to not accidentally count wijziging in begrotingsstaat as a law
        continue
    elif strings.contains_any_of(titel, ['omzetbelasting'], case_sensitive=False):
        #print( 'BELASTING %-7s %20s  %s'%(edict.get('nummer'), edict.get('updated'), titel) )
        ourtypes['belasting'].append( titel )
        continue

    elif strings.contains_any_of(titel, ['wetsvoorstel', 'voorstel van wet'], case_sensitive=False):
        #print( 'LAW       %-7s %20s  %s'%(ksd.get('nummer'), ksd.get('updated'), titel) )
        ourtypes['wet'].append( titel )
        continue
    elif titel.startswith('Wet '):
        ourtypes['wet'].append( titel ) 
        continue
    
    elif strings.contains_any_of(titel, ['wetswijziging', 'wijziging van wet ', 'wijziging van de wet ', 'aanpassing van de wet',
                                 'Wijziging van de', # followed by a specifically named law   this one is fuzzier than necessary, might be better to regexp-match
                                 ], case_sensitive=False):
        ourtypes['wet'].append( titel )
        continue
    elif strings.contains_all_of(titel, ['wijziging', 'wetboek'], case_sensitive=False):
        ourtypes['wet'].append( titel )
        continue
    elif strings.contains_all_of(titel, ['wijziging', 'wetten'], case_sensitive=False):
        #print( 'LAW       %-7s %20s  %s'%(ksd.get('nummer'), ksd.get('updated'), titel) )
        ourtypes['wet'].append( titel )
        continue
    elif strings.contains_all_of(titel, ['verbeter', 'wetten'], case_sensitive=False):
        ourtypes['wet'].append( titel )
        continue
    elif strings.contains_all_of(titel, ['aanpassing', ' Wet'], case_sensitive=False):
        ourtypes['wet'].append( titel )
        continue

    elif strings.contains_any_of(titel, ['Initiatiefnota','Interpellatie'], case_sensitive=False):
        ourtypes['discussions'].append( titel )
        continue
    elif strings.contains_any_of(titel, ['burgerinitiatief',], case_sensitive=False):
        ourtypes['discussions'].append( titel )
        continue
    elif strings.contains_any_of(titel, ['Herindeling van de gemeenten',]):
        ourtypes['local'].append( titel )
        continue

    elif strings.contains_any_of(titel, ['mbudsman',]):
        ourtypes['ombudsman'].append( titel )
        continue

    elif strings.contains_any_of(titel, ['Evaluatie',]):
        ourtypes['evaluatie'].append( titel )
        continue

    elif strings.contains_any_of(titel, ['Verdrag',]):
        ourtypes['verdrag'].append( titel )
        continue

    else:
        ourtypes['unsorted'].append( titel )
        #print( 'DONTKNOW %-7s %20s  %s'%(edict.get('nummer'), edict.get('updated'), titel) )
        continue
        #if re.search('', titel):

    #sru_openpub.search_retrieve_many( 'w.dossiernummer=%s'%edict.get('nummer'), callback=op_callback )


for typ, title_list in ourtypes.items():
    #if typ=='unsorted': # cases for which the title isn't a strong indication -- fair enough, but print them to see if there's any patterns we're missing
    #    pprint.pprint( title_list )
    print(  '%-5d %s'%( len(title_list), typ )  )
#pprint.pprint( dtypes )
# Out:
# 2056  wet
# 2009  unsorted
# 1713  begroting
# 438   verdrag
# 245   discussions
# 108   evaluatie
# 298   eu
# 24    ombudsman
# 6     local
# 17    belasting
# 18    [verwijderd]

# %% [markdown]
# ## OData interface

# %% [markdown]
# The SyncFeed API is perfectly functional, though it leaves you to do interpretation of the relations yourself,
# so let's see if the OData API is any more help.
#
# There is a helpful library out there, [tkapi](https://github.com/openkamer/tkapi) (MIT license).
# This means we don't have to implement it ourselves.
#
# Note that neither API is is a very _fast_ interface,
# or efficient when your goal is sifting through the entire collection of data in ways it was not initially designed for.
# (It also seems it sometimes refuses to connect?)
#
# That is part of why it might be interesting to some to have this notebook, and the produced dataset just give you the actual list.

# %%
# if you haven't already
# !pip3 install tkapi

# %%
import tkapi, tkapi.document   
from tkapi.document import DocumentSoort
api = tkapi.TKApi()

# %%
# Get an idea of what this API even does
#   the document types are function calls, to wit:
list(name   for name in dir(api)   if name.startswith('get_'))
# Out:
# ['get_activiteiten',
#  'get_agendapunten',
#  'get_all_items',
#  'get_antwoorden',
#  'get_besluiten',
#  'get_commissies',
#  'get_documenten',
#  'get_dossiers',
#  'get_fractie_zetels',
#  'get_fracties',
#  'get_geschenken',
#  'get_item',
#  'get_items',
#  'get_kamervragen',
#  'get_personen',
#  'get_reizen',
#  'get_related',
#  'get_stemmingen',
#  'get_vergaderingen',
#  'get_verslagen',
#  'get_verslagen_van_algemeen_overleg',
#  'get_zaken']

# %%
# Okay, let's try that
#dossiers = api.get_dossiers( )
#len(dossiers)  # a few thousand, which is why get_dossiers took a few secdonds to fetch

from tkapi.dossier import Dossier
dossier_filter = Dossier.create_filter()
dossier_filter.filter_nummer('35302')

dossiers = api.get_dossiers( dossier_filter )

# %%
from tkapi.document import Document 
verslag_filter = Document.create_filter()
verslag_filter.filter_dossier()

dossiers = api.get_dossiers( dossier_filter )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 3>()
#       1 from tkapi.document import Document
#       2 verslag_filter = Document.create_filter()
# ----> 3 verslag_filter.filter_dossier()
#       5 dossiers = api.get_dossiers( dossier_filter )
#
# TypeError: filter_dossier() missing 1 required positional argument: 'nummer'

# %%
# Let's get a basic summary of dossiers.
#    we find out apparently  dossier nummers  are not unique without the  toevoeging

# let's also sort by dossiers -- and toevoeging, which requires minor syntax-fu right now
sorted_dossiers = sorted(  dossiers,   key=lambda dossier:str(dossier.nummer)+(dossier.toevoeging or '')  )

i = 0
for dossier in sorted_dossiers:   #[:200]: # show a few hundred, not all

    # you could e.g. figure out other zaken that refer to the same documents
    #zaaknrs = set()
    #for zaak in dossier.zaken:
    #    zaaknrs.add( zaak.nummer ) # zaak.onderwerp)

    nummer_and_toevoeging = ('%s-%s'%(dossier.nummer, dossier.toevoeging or '')).rstrip('-')
    print( f"== Dossier {nummer_and_toevoeging} == {dossier.titel} ==" )
    print( '  ',dossier.url.replace(')','%29') ) # the replace is to make the notebook's url include the final bracket
    for document in sorted(dossier.documenten, key=lambda doc:doc.volgnummer):
        # {str(document.soort).split(".",1)[1][:25]:25s}
        print( f'   DOC #{str(document.volgnummer):3s}  {str(document.nummer):10s} - {str(document.datum):12s} - {document.onderwerp:100s} - {document.bestand_url:30s}'
              )
        #document.print_json()
        
    #break


# a document object has attributes like
['aanhangselnummer', 'activiteiten', 'actors', 'agendapunten', 'alias', 'begin_date_key', 'bestand_url', 'create_filter', 
'datum', 'dossier_nummers', 'dossiers', 'end_date_key', 'expand_params', 'filter_param', 'get_date_from_datetime_or_none',
'get_date_or_none', 'get_datetime_or_none', 'get_param_expand', 'get_params_default', 'get_property_enum_or_none',
'get_property_or_empty_string', 'get_property_or_none', 'get_resource_url_or_none', 'get_year_or_none', 'gewijzigd_op',
'id', 'nummer', 'onderwerp', 'orderby_param', 'print_json', 'related_item', 'related_items', 'related_items_deep',
'soort', 'titel', 'titel_citeer', 'type', 'url', 'vergaderjaar', 'versies', 'volgnummer', 'zaken']
# Out:
# == Dossier 35302 == Wijziging van enkele belastingwetten en enige andere wetten (Belastingplan 2020) ==
#    https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Kamerstukdossier(d1b73eca-a237-451f-817e-1e96a9328a5a%29
#    DOC #1    2019D36146 - 2019-09-17   - Koninklijke boodschap                                                                                - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5c820386-d13d-4615-96d3-bcd5a299e754)/TK.DA.GGM.OData.Resource()
#    DOC #2    2019D36042 - 2019-09-17   - Voorstel van wet                                                                                     - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(168dbc2e-8efb-4818-bc4c-41dd4d7cbc77)/TK.DA.GGM.OData.Resource()
#    DOC #3    2019D36045 - 2019-09-17   - Memorie van toelichting                                                                              - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(05794c6c-47e8-4598-98e5-a6e78160bd1b)/TK.DA.GGM.OData.Resource()
#    DOC #4    2019D36052 - 2019-09-17   - Advies Afdeling advisering Raad van State en Nader rapport                                           - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ad8f1768-2d09-47b7-966f-2331b6914206)/TK.DA.GGM.OData.Resource()
#    DOC #5    2019D36070 - 2019-09-17   - Amendement van de leden Asscher en Nijboer over het niet verlagen van het hoge tarief Vpb in 2021    - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b8807a0d-6a5a-41d1-9923-446744bbcb6f)/TK.DA.GGM.OData.Resource()
#    DOC #6    2019D36033 - 2019-09-17   - Pakket Belastingplan 2020                                                                            - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(071a2a16-c498-4ec1-9f38-92468fcf283a)/TK.DA.GGM.OData.Resource()
#    DOC #7    2019D37726 - 2019-09-26   - Aanvullende reactie op de motie van de leden Leijten en Lodders over letselschadevergoedingen        - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(83c01e2d-2314-4d39-8f92-0912d95640af)/TK.DA.GGM.OData.Resource()
#    DOC #8    2019D38004 - 2019-09-27   - Onderzoek marginale druk                                                                             - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8c592dae-7819-49a7-b2fe-56b415add85d)/TK.DA.GGM.OData.Resource()
#    DOC #9    2019D39108 - 2019-10-03   - Amendement van de leden Leijten en Beckerman over beperking van de verhuurderheffing                 - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a0145e17-b56c-45cf-9d9c-b308401b0e51)/TK.DA.GGM.OData.Resource()
#    DOC #10   2019D40049 - 2019-10-09   - Amendement van het lid Nijboer over het verhogen van het toptarief                                   - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9ebe8d3c-a4c4-44bf-a08c-6052ccf73741)/TK.DA.GGM.OData.Resource()
#    DOC #11   2019D40388 - 2019-10-10   - Verslag                                                                                              - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ee4dcb5e-a102-4a63-b64b-10df63260559)/TK.DA.GGM.OData.Resource()
#    DOC #12   2019D40394 - 2019-10-10   - Amendement van het lid Nijboer over een overdrachtsbelasting-tarief van 0 percent voor starters      - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a4bb3a81-01e6-4398-9f49-907c7bef42da)/TK.DA.GGM.OData.Resource()
#    DOC #13   2019D41936 - 2019-10-22   - Nota naar aanleiding van het verslag                                                                 - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(397e8c70-aac2-41ab-b50d-dfb8dbce985b)/TK.DA.GGM.OData.Resource()
#    DOC #14   2019D41939 - 2019-10-22   - Nota van wijziging                                                                                   - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0272b59f-b38f-4e52-ace0-c631c7b6df4b)/TK.DA.GGM.OData.Resource()
#    DOC #15   2019D41933 - 2019-10-18   - Aanbieding nota's naar aanleiding van het verslag en nota's van wijziging inzake het pakket Belastingplan 2020 - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(33115a33-df21-4032-aa16-afa40cdfc6e9)/TK.DA.GGM.OData.Resource()
#    DOC #16   2019D42432 - 2019-10-24   - Gewijzigd amendement van het lid Nijboer ter vervanging van nr. 12 over een overdrachtsbelasting-tarief van 0 percent voor starters - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b165c45e-11be-4d56-b07d-c754b6c6dc57)/TK.DA.GGM.OData.Resource()
#    DOC #17   2019D41953 - 2019-10-22   - Verslag van een schriftelijk overleg over reactie op de motie van de leden Leijten en Lodders over letselschadevergoedingen (Herziene brief) en over aanpassing box 3 - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5c043578-4efe-40e4-96c8-425cd1f7093a)/TK.DA.GGM.OData.Resource()
#    DOC #18   2019D43397 - 2019-10-31   - Amendement van het lid kwint over het verhogen van de bankenbelasting                                - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2fa08538-dc9a-4d36-ae1f-d72d5cb80652)/TK.DA.GGM.OData.Resource()
#    DOC #19   2019D43464 - 2019-10-31   - Verdergaande terugwerkende kracht getto-uitkeringen                                                  - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(30dd1f89-ac69-479b-a692-e110e1cf58e3)/TK.DA.GGM.OData.Resource()
#    DOC #20   2019D43544 - 2019-10-31   - Schriftelijke beantwoording van een deel van de vragen die zijn gesteld tijdens het wetgevingsoverleg van 28 oktober 2019 over het pakket Belastingplan 2020 - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ee44a9b4-5cd9-4fa5-ad01-9279d8de0d6a)/TK.DA.GGM.OData.Resource()
#    DOC #21   2019D44066 - 2019-11-04   - Motie van het lid Omtzigt c.s. over stoppen van de invordering bij CAF-gerelateerde toeslagzaken     - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2cd3e194-d515-4cf4-ac7d-9642af1bdaba)/TK.DA.GGM.OData.Resource()
#    DOC #22   2019D44067 - 2019-11-04   - Motie van het lid Leijten over het voor de zomer behandelen van het wetsvoorstel ter aanpassing van de liquidatie- en stakingsverliesrekening - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ff2c548d-c8d5-4c38-b37e-ab3383087be0)/TK.DA.GGM.OData.Resource()
#    DOC #23   2019D44571 - 2019-11-07   - Gewijzigd amendement van het lid Nijboer ter vervanging van nr. 10 over het verhogen van het toptarief - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4cc9edb1-bc93-4ba2-a47c-1a328676cf53)/TK.DA.GGM.OData.Resource()
#    DOC #24   2019D45079 - 2019-11-11   - Amendement van het lid Stoffer c.s. over verhoging van de kansspelbelasting                          - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(afae8aee-a46e-4a99-8901-28abd2de46eb)/TK.DA.GGM.OData.Resource()
#    DOC #25   2019D45242 - 2019-11-11   - Amendement van het lid Nijboer over de heffingsvermindering voor nieuwbouw die van toepassing wordt in elke gemeente - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b565a5cd-84e9-4120-b6c5-84d8897f2e17)/TK.DA.GGM.OData.Resource()
#    DOC #26   2019D44981 - 2019-11-08   - Schriftelijke beantwoording van een deel van de vragen die zijn gesteld tijdens het wetgevingsoverleg van 4 november 2019 over het pakket Belastingplan 2020 en toezeggingen m.b.t. invordering toeslagen - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5da67b1a-2e16-44d6-b12f-987892f7a000)/TK.DA.GGM.OData.Resource()
#    DOC #27   2019D45379 - 2019-11-12   - Amendement van het lid Snels over maximaal 3 jaar meenemen van aftrekbare rente uit eerdere jaren    - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ad1ddcef-cbaa-47a7-91b2-e02254672845)/TK.DA.GGM.OData.Resource()
#    DOC #28   2019D45392 - 2019-11-12   - Amendement van het lid Nijboer over een verlaging van de verhuurderheffing voor krimpregio's en Rotterdam-Zuid - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a004d084-488a-4255-bbe2-282efb8e3734)/TK.DA.GGM.OData.Resource()
#    DOC #29   2019D45441 - 2019-11-12   - Gewijzigd amendement van de leden Leijten en Beckerman ter vervanging van nr. 9 over beperking van de verhuurderheffing - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3be3eb12-76ad-4020-9d6f-ea387877274d)/TK.DA.GGM.OData.Resource()
#    DOC #30   2019D45455 - 2019-11-12   - Nader gewijzigd amendement van het lid Nijboer ter vervanging van nr. 23 over het verhogen van het toptarief - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(58228c55-9f35-4e60-9ad2-7459cf75dd3d)/TK.DA.GGM.OData.Resource()
#    DOC #31   2019D45466 - 2019-11-12   - Amendement van het lid Van Otterloo over de ouderkorting                                             - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(860126d6-fcd6-4d02-800f-07cc63e98b93)/TK.DA.GGM.OData.Resource()
#    DOC #32   2019D45468 - 2019-11-12   - Amendement van het lid Van Otterloo over minder belasting voor kleine vermogens                      - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(990f05b6-d15a-4649-bd99-dc9525db8817)/TK.DA.GGM.OData.Resource()
#    DOC #33   2019D45491 - 2019-11-12   - Amendement van het lid Nijboer over aanpassing van de minimumkapitaalregel                           - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4745887f-efcb-41f9-a350-44f2992f17fe)/TK.DA.GGM.OData.Resource()
#    DOC #34   2019D45495 - 2019-11-12   - Amendement van het lid Ronnes c.s. over toegankelijkheid van de heffingsvermindering verhuurderheffing - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2d0127d4-60ec-4038-985e-9f977c3c6cf6)/TK.DA.GGM.OData.Resource()
#    DOC #35   2019D45630 - 2019-11-13   - Gewijzigd amendement van het lid Van Otterloo t.v.v. nr. 31 over de ouderkorting                     - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(93861bad-7d41-4451-a3f9-3dccff10935c)/TK.DA.GGM.OData.Resource()
#    DOC #36   2019D45651 - 2019-11-13   - gewijzigd amendement van het lid Ronnes c.s. ter vervanging van nr. 34 over toegankelijkheid van de heffingsvermindering verhuurderheffing - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(34eccb9a-4e9c-47ee-b52b-308d969b8037)/TK.DA.GGM.OData.Resource()
#    DOC #37   2019D45358 - 2019-11-12   - Reactie op het verzoek van het lid Omtzigt om toezending van de door de Belastingdienst uitgebrachte herziene uitvoeringstoets inzake de Wet vereenvoudiging beslagvrije voet - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6a6d6fd1-da2e-402b-8ef2-691b7c3f8479)/TK.DA.GGM.OData.Resource()
#    DOC #38   2019D44987 - 2019-11-13   - Tweede nota van wijziging                                                                            - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a735d976-fab4-4814-b7ed-21483f00eb1d)/TK.DA.GGM.OData.Resource()
#    DOC #39   2019D45785 - 2019-11-13   - Motie van de leden Edgar Mulder en Wilders over iedere transactie naar een OIC-land belasten met 10% van het transferbedrag - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(620751e2-1597-4dd0-91b2-7c98078f693b)/TK.DA.GGM.OData.Resource()
#    DOC #40   2019D45786 - 2019-11-13   - Motie van het lid Edgar Mulder over het afschaffen van subsidie voor stekkerauto's                   - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c23020f7-7ef3-497c-90f7-1b5c11c561e7)/TK.DA.GGM.OData.Resource()
#    DOC #41   2019D45787 - 2019-11-13   - Motie van het lid Edgar Mulder over het terugdraaien van de btw-verhoging                            - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(636de0c6-3924-4787-accc-ed0a9eb63f9d)/TK.DA.GGM.OData.Resource()
#    DOC #42   2019D45790 - 2019-11-13   - Motie van het lid Lodders c.s. over het monitoren van de consequenties van het stijgende ODE -tarief voor de glastuinbouw - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f8cee452-9ade-40cf-b6f2-d6b51a485a57)/TK.DA.GGM.OData.Resource()
#    DOC #43   2019D45788 - 2019-11-13   - Motie van de leden Lodders en Van Weyenberg over onderzoek naar de empirische effecten van verstoringen in het globaal evenwicht - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(98a550d2-5cb1-47d3-a4fa-cb9b34828572)/TK.DA.GGM.OData.Resource()
#    DOC #44   2019D45789 - 2019-11-13   - Motie van het lid Lodders over onderzoek naar modernisering van de reiskostenvergoeding              - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3b5606db-4279-47b8-9793-10a524bd4b91)/TK.DA.GGM.OData.Resource()
#    DOC #45   2019D45791 - 2019-11-13   - Motie van het lid Lodders c.s. over het monitoren van administratieve last voor mkb'ers door ATAD 2  - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6fc9b8b8-3287-4175-a623-c8e3d3f18c6f)/TK.DA.GGM.OData.Resource()
#    DOC #46   2019D45792 - 2019-11-13   - Motie van het lid Snels over een onderzoek van de Europese Commissie naar het omzeilen van de meldingsplicht - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7b3b783a-0999-4bb1-98ce-615c683fd918)/TK.DA.GGM.OData.Resource()
#    DOC #47   2019D45793 - 2019-11-13   - Motie van de leden Omtzigt en Lodders over de juridische houdbaarheid van box 3                      - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e0ad275e-962c-4ff7-81e4-5d4fcfdb3a99)/TK.DA.GGM.OData.Resource()
#    DOC #48   2019D45794 - 2019-11-13   - Motie van de leden Omtzigt en Lodders over de implementatie van meetmethoden en de bpm               - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1532707b-45b5-40e7-a413-bb98d99727ac)/TK.DA.GGM.OData.Resource()
#    DOC #49   2019D45795 - 2019-11-13   - Motie van de leden Omtzigt en Lodders over specifieke informatie in de Voortgangsmonitor             - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0b26cfd9-adf8-4b8c-826f-1ec9ab772213)/TK.DA.GGM.OData.Resource()
#    DOC #50   2019D45796 - 2019-11-13   - Motie van het lid Omtzigt c.s. over de ambitie dat Nederland niet meer voorkomt in de top vijf van doorstroomlanden - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(392dc8d0-837a-4bf8-8f0d-dc95c0ddde98)/TK.DA.GGM.OData.Resource()
#    DOC #51   2019D45797 - 2019-11-13   - Amendement van het lid Omtzigt over het verlengen van de termijn waarbinnen een verzoek moet zijn gedaan - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4501c83e-2f40-46a8-b108-bbff537c30ca)/TK.DA.GGM.OData.Resource()
#    DOC #52   2019D45798 - 2019-11-13   - Motie van de leden Alkaya en Leijten over kinderopvangtoeslag voor iedereen die op basis van een medische indicatie in de dagbesteding zit - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(74596a09-c5d0-470a-9fa4-34a4fa84e380)/TK.DA.GGM.OData.Resource()
#    DOC #53   2019D45799 - 2019-11-13   - Motie van de leden Van Weyenberg en Middendorp over het lage btw-tarief voor toegang tot innovatieve vormen van nieuwsvoorziening - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(19a75410-361d-4ab0-ab51-47a628998ce1)/TK.DA.GGM.OData.Resource()
#    DOC #54   2019D45800 - 2019-11-13   - Motie van het lid Van Weyenberg c.s. over het monitoren van de budgettaire opbrengsten van de bronbelasting op rente en royalty's - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(adf73905-0660-481a-b5f8-11d65fcf2b6b)/TK.DA.GGM.OData.Resource()
#    DOC #55   2019D45801 - 2019-11-13   - Motie van de leden Van Weyenberg en Alkaya over mogelijkheden voor hogere belastingen op vermogens boven de 1 miljoen euro - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(93873627-7fbe-4e57-b865-661aaca9170b)/TK.DA.GGM.OData.Resource()
#    DOC #56   2019D45802 - 2019-11-13   - Motie van het lid Bruins c.s. over de effectiviteit van de CO2-reducerende stimuleringsmaatregelen voor elektrische auto's - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a8e31704-5455-4497-88ad-4c0bf3304044)/TK.DA.GGM.OData.Resource()
#    DOC #57   2019D45803 - 2019-11-13   - Motie van het lid Van Raan over prioriteit geven aan CO2-reductie                                    - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ce3484cb-a9f1-412c-9b43-365a0095c8e8)/TK.DA.GGM.OData.Resource()
#    DOC #58   2019D45804 - 2019-11-13   - Motie van het lid Van Raan over een CO2-grensheffing                                                 - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(259b973a-7fa6-4f47-a0b6-202e13ecc020)/TK.DA.GGM.OData.Resource()
#    DOC #59   2019D45805 - 2019-11-13   - Motie van het lid Stoffer over het bevriezen van de overdraagbaarheid van de algemene heffingskorting - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(da746216-e294-45d1-bea9-6f247d64ae3b)/TK.DA.GGM.OData.Resource()
#    DOC #60   2019D45806 - 2019-11-13   - Motie van het lid Stoffer over het per 2021 invoeren van de aangepaste vermogensrendementsheffing    - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ac684f66-b7c8-4bf0-b1ee-98dced4b8319)/TK.DA.GGM.OData.Resource()
#    DOC #61   2019D45807 - 2019-11-13   - Motie van het lid Stoffer over de bpm voor auto's in het A- en B-segment                             - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b54d9e0f-1695-4861-ba91-9a2cfcf71639)/TK.DA.GGM.OData.Resource()
#    DOC #62   2019D45870 - 2019-11-14   - Nader gewijzigd amendement van het lid Ronnes c.s. tvv nr. 36 over toegankelijkheid van de heffingsvermindering verhuurderheffing - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b5215b8d-3de2-4d83-92b0-ae8ef9ac385e)/TK.DA.GGM.OData.Resource()
#    DOC #63   2019D45883 - 2019-11-14   - Amendement van het lid Snels ter vervanging van nr. 27 over maximaal 3 jaar meenemen van aftrekbare rente uit eerdere jaren - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a1a63850-7c5e-44f0-919a-4e2acccda659)/TK.DA.GGM.OData.Resource()
#    DOC #64   2019D45917 - 2019-11-14   - Tweede nader gewijzigd amendement van het lid Ronnes c.s. tvv nr. 62 over toegankelijkheid van de heffingsvermindering verhuurderheffing - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(20742f82-2a08-4726-8c54-e6e312b9927a)/TK.DA.GGM.OData.Resource()
#    DOC #65   2019D45443 - 2019-11-12   - Betrekken verbranding buitenlands afval in afvalstoffenbelasting                                     - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8b58b49b-d7d2-4b8b-8316-87cbbdf43674)/TK.DA.GGM.OData.Resource()
#    DOC #66   2019D45877 - 2019-11-14   - Overzicht amendementen en moties pakket Belastingplan 2020                                           - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bbe656b2-21fc-448f-b626-d3e017bed41b)/TK.DA.GGM.OData.Resource()
#    DOC #67   2019D46790 - 2019-11-19   - Verslag van een wetgevingsoverleg, gehouden op 28 oktober 2019, over het Pakket Belastingplan 2020   - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(126d6333-4795-4069-8da5-ed8507b5320a)/TK.DA.GGM.OData.Resource()
#    DOC #68   2019D47465 - 2019-11-21   - Verslag van een wetgevingsoverleg, gehouden op 4 november 2019, over het pakket Belastingplan 2020   - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e86417c5-1ccc-496d-8431-e5db4e43faed)/TK.DA.GGM.OData.Resource()
#    DOC #69   2019D45921 - 2019-11-14   - Reactie op het nader gewijzigd amendement van het lid Ronnes c.s. 35302-62 tvv nr. 36 over toegankelijkheid van de heffingsvermindering verhuurderheffing (Kamerstuk 35302-62) - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(46957edc-5ba7-48a4-84ba-22f8eecfcbe4)/TK.DA.GGM.OData.Resource()
#    DOC #70   2019D49652 - 2019-12-04   - Reactie op verzoek commissie inzake informatie over het overleg met de branche over de afvalstoffenbelasting - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7c3441c9-e3e1-44d2-9bfc-0822d3e27571)/TK.DA.GGM.OData.Resource()
#    DOC #71   2020D05235 - 2020-02-10   - Ontwerpbesluit tot wijziging van het Besluit Wet financiering sociale verzekeringen                  - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6cb9be22-b145-41cb-8d1d-4891556fca7a)/TK.DA.GGM.OData.Resource()
#    DOC #72   2020D07498 - 2020-02-20   - Pilot gegevensuitwisseling ANBI’s                                                                    - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(75fb4a3c-7b0c-456c-a6cc-e6f104a2c29c)/TK.DA.GGM.OData.Resource()
#    DOC #73   2020D07708 - 2020-02-21   - Beantwoording overige vragen en uitvoeringstoetsen op aangenomen amendementen pakket Belastingplan 2020 en het wetsvoorstel Wet implementatie EU-richtlijn meldingsplichtige grensoverschrijdende constructies (DAC6) - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(11b712bb-0e03-4112-88c8-a4017962fdff)/TK.DA.GGM.OData.Resource()
#    DOC #74   2020D08324 - 2020-03-02   - Verslag van een schriftelijk overleg over het ontwerpbesluit tot wijziging van het Besluit Wet financiering sociale verzekeringen - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4fefb065-0d82-4385-80f4-41a0299f559a)/TK.DA.GGM.OData.Resource()
#    DOC #75   2020D08657 - 2020-03-03   - Forfaitaire rendementen box 3                                                                        - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f424dd8a-71c7-49f9-8c41-01ddb9d603b7)/TK.DA.GGM.OData.Resource()
#    DOC #76   2020D12285 - 2020-03-31   - Evaluatie Assurantiebelasting                                                                        - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f8748aa3-dc1d-4ab9-8024-52f16421ea37)/TK.DA.GGM.OData.Resource()
#    DOC #77   2020D18322 - 2020-05-13   - Btw nultarief op mondkapjes gelet op het OV                                                          - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a6c91d6d-35b7-4375-87d4-51af35a27566)/TK.DA.GGM.OData.Resource()
#    DOC #78   2020D19160 - 2020-05-19   - Geactualiseerd overzicht maatregelen pakket Belastingplan 2021 en fiscale wetsvoorstellen 2020       - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c4e31661-2355-4d96-a12a-274412e160d6)/TK.DA.GGM.OData.Resource()
#    DOC #79   2020D21212 - 2020-05-29   - Uitvoering van de motie van de leden Omtzigt en Lodders over de implementatie van meetmethoden en de bpm - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(87eb2f81-294a-4269-8263-e2b5b0a17643)/TK.DA.GGM.OData.Resource()
#    DOC #80   2020D25345 - 2020-06-24   - Verslag van een schriftelijk overleg over Btw nultarief op mondkapjes gelet op het OV                - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(16435fd8-d2d4-414d-837a-1accc9efe83e)/TK.DA.GGM.OData.Resource()
#    DOC #81   2020D25429 - 2020-06-26   - Verslag van een schriftelijk overleg over uitvoering van de motie van de leden Omtzigt en Lodders over de implementatie van meetmethoden en de bpm (Kamerstuk 35302-79) - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(39c00612-0cff-4db2-97c0-b760ffccd744)/TK.DA.GGM.OData.Resource()
#    DOC #82   2020D26479 - 2020-06-26   - Stand van zaken aanpassing box 3                                                                     - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8e71e142-9675-4a7c-a376-735963ee700c)/TK.DA.GGM.OData.Resource()
#    DOC #83   2020D27994 - 2020-07-02   - Overleg met autobranche over budgettair neutrale omzetting naar WLTP                                 - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(29b180b8-8512-4698-bb52-5eb3aa63f5d9)/TK.DA.GGM.OData.Resource()
#    DOC #84   2020D28579 - 2020-07-03   - Reactie op de motie van de leden Van Weyenberg en Middendorp (Kamerstuk 35302-53) en prijsvergelijking elektronische publicaties - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d5e49dc8-7863-4cdb-a7c6-79b858cff9d8)/TK.DA.GGM.OData.Resource()
#    DOC #85   2020D32945 - 2020-08-31   - Onderzoek toepassing culturele btw-vrijstelling op denksporten                                       - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(98b7e5d6-b62a-47f5-b868-b2167caef22b)/TK.DA.GGM.OData.Resource()
# ['aanhangselnummer',
#  'activiteiten',
#  'actors',
#  'agendapunten',
#  'alias',
#  'begin_date_key',
#  'bestand_url',
#  'create_filter',
#  'datum',
#  'dossier_nummers',
#  'dossiers',
#  'end_date_key',
#  'expand_params',
#  'filter_param',
#  'get_date_from_datetime_or_none',
#  'get_date_or_none',
#  'get_datetime_or_none',
#  'get_param_expand',
#  'get_params_default',
#  'get_property_enum_or_none',
#  'get_property_or_empty_string',
#  'get_property_or_none',
#  'get_resource_url_or_none',
#  'get_year_or_none',
#  'gewijzigd_op',
#  'id',
#  'nummer',
#  'onderwerp',
#  'orderby_param',
#  'print_json',
#  'related_item',
#  'related_items',
#  'related_items_deep',
#  'soort',
#  'titel',
#  'titel_citeer',
#  'type',
#  'url',
#  'vergaderjaar',
#  'versies',
#  'volgnummer',
#  'zaken']

# %% [markdown]
# Let's say that our interest is more specific:
# finding what  Raad van State  has to say about  proposed laws (wetsvoorstellen).
#
# ...and, in the process also learn what the kinds of documents there are in each dossier.
#
# There is also the [advice on the raad van state site](https://www.raadvanstate.nl/adviezen/),
# (for a more data-like form, see also our [extras_datacollect_raadvanstate](extras_datacollect_raadvanstate.ipynb)),
# but there it is not placed in the context of the law it's referring to.
# This interface should at least gives us the law's name.

# %%
# We start by selecting dossiers where there already _is_ RvS advice.
#  - this is a decent filter for wetsvoorstellen
#  - and filters out wetsvoorstellen that don't need this advice (e.g. begroting)
# ...but we are about to find out
# - there are other things that RVS advises on, like finances (see e.g. 36200) 
# - there are law changes that RVS does not advise on (e.g. TODO)

sorted_dossiers = sorted(dossiers,  key=lambda d:d.nummer,  reverse=True )

count = 0
for i, dossier in enumerate( sorted_dossiers ):
    nummer_and_toevoeging = ('%s-%s'%(dossier.nummer, dossier.toevoeging or '')).rstrip('-')

    #if (dossier.nummer%100) == 0: # ignore a few specific special cases for now,   just because they're large to print
    #    continue

    ## In our stated interest:  first see if it has RvS advice
    sorted_docs      = sorted(dossier.documenten,  key=lambda d:d.volgnummer )
    has_raadvanstate = False
    for document in sorted_docs:
        try:
            # these come from an enum, try  list( tkapi.document.DocumentSoort )  to see a list
            if document.soort in (DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE, 
                                  #DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_NADER_RAPPORT, # seems to be begrotingstuff?  (TODO: check)
                                  DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS,
                                ):
                has_raadvanstate = True
        except ValueError: # there's some invalid / non-covered soort values in the data
            pass # ignore
        # we can filter on more, but we may not need to?

    if not has_raadvanstate:
        continue
    # if execution gets here, it's probably interesting to us.
    
    count += 1
    #if len(sorted_docs)>500:
    #    print( "\n\n== Dossier %s == %s =="%( dossier.nummer, dossier.titel) )
    #    print(' LARGE: %d documents'%len(sorted_docs))
    #    print(' %s ({{kamerdossier|%d}}'%(dossier.titel, dossier.nummer))
    #    continue

    print( "\n== %r == Dossier %s == %d docs == %s =="%( dossier.id, nummer_and_toevoeging, len(dossier.documenten), dossier.titel) )
    for document in sorted_docs:
        try:
            if 0: # just to make the summaries a little easier to read
                if document.soort in (DocumentSoort.MOTIE, DocumentSoort.AMENDEMENT, DocumentSoort.BRIEF_REGERING, DocumentSoort.VERSLAG_VAN_EEN_ALGEMEEN_OVERLEG,
                                    DocumentSoort.MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL,
                                    ):
                    continue
        except ValueError:
            print( "soort not known by tkapi")
            continue

        try:
            docsoort = document.soort
        except ValueError: # this seems to be internal inconsistency
            continue

        show_all_docs = False
        if show_all_docs or docsoort in (DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE, 
                                DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS):

            print( '#%s'%(document.volgnummer, ), document.soort.name)
            #print( 'soort', document.soort.name, '(%s)'%document.soort.value )
            print( '  onderwerp    ', document.onderwerp )     # for wetsvoorstel-dossiers, seems to often be the same as soort plus some detail (who a letter is from, who )
            print( '  citeertitel  ', document.titel_citeer ) # for wetsvoorstel-dossiers, this often seems to name the law. Or a related one, see e.g. 36195
            print( '  titel        ', document.titel )              # for wetsvoorstel-dossiers, this seems to often name the law, plus sometimes some reason
            #print( 'versies', document.versies )
            print( '  url          ', document.bestand_url )
            if 0:        # It may be interesting to know the document is part of multiple dossiers and/or multiple zaken
                print( '  zaken         ', document.zaken )
                #nums = document.dossier_nummers
                #nums.pop(dossier.nummer)
                #if len(nums)>0:
                #  print( "  also in dossiers: %s"%nums )

            print()

    #if i > 1000: # show only a bunch, not all
    #    print("break %d"%i)
    #    break
print( 'Interesting cases: %d'%count )
# Out:
# Interesting cases: 0

# %% [markdown]
# ## Actually making data from that
#
# TODO: decide what
