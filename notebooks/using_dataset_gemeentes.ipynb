# %% [markdown]
# # Purpose of this notebook
#
# A quick introduction of the more-of-a-table-than-a-dataset that is some metadata of the Dutch municipalities

# %%
import random, pprint
import pandas
import wetsuite.datasets

gemeentes = wetsuite.datasets.load('gemeentes')

print( gemeentes.description )
# Out:
# Downloading 'https://wetsuite.knobs-dials.com/datasets/gemeentes.json' to '/home/scarfboy/.wetsuite/datasets/ebe6444b6e4a35c313d4f082ad1ee5aedd835387'
# Downloaded    388KiB  [==================================================]
#     This is largely the more interesting fields from https://organisaties.overheid.nl/export/Gemeenten.csv
#     augmented with RDF-like data like that under https://standaarden.overheid.nl/owms/terms/Leiden_(gemeente)
#
#
#     .data is a list of dicts, one per gemeente (currently 344 of them). Keys in that dict include:
#
#     'Namen' - a list of name variants.
#        Usually just the short name, and a longer one with "Gemeente " in front
#        Sometimes with alternative names, e.g. ["Den Bosch", "Gemeente 's-Hertogenbosch", "'s-Hertogenbosch"]
#        We have used these as "Match one of these" to search for gemeentebeleid per gemeente
#
#     Descriptions like 'Aantal inwoners', 'Oppervlakte'
#
#     Organisational relations like
#       - 'Bevat plaatsen'
#       - 'Overlaps with', mentioning Provinces, Waterschappen
#       - 'Service area of' - things like GGD, Police, Social services  (each item is a list because we tend to have a full name and an abbreviation)
#       - 'Predecessors' - mentions previous gemeente names
#
#     Useful in other APIs / joining with other data
#     - 'OWMS URI'
#     - 'CBSCode', 'Organisatiecode'
#
#     Politics
#     - 'Totaal aantal zetels', 'Raad'
#
#
#     This vesion was fetched on 2023-01-27

# %%
random.choice( gemeentes.data )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/www/coding/wetsuite/notebooks/using_dataset_gemeentes.ipynb Cell 3 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/notebooks/using_dataset_gemeentes.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> random.choice( gemeentes.data.items() )
#
# AttributeError: 'list' object has no attribute 'items'

# %%
import pandas # pandas is a nice way to inspect (and manipulate) things in a tabular-like way
df = pandas.DataFrame.from_dict( gemeentes.data )
df
#pandas.DataFrame.from_dict( gemeentes.data )['Alternatieve naam'].values
# Out:
#     Oppervlakte                                     Bevat plaatsen  \
# 0    [279, km2]  [Amen, Anderen, Anloo, Annen, Annerveenschekan...
# 1     [33, km2]                            [Aalsmeer, Kudelstaart]
# 2     [97, km2]         [Aalten, Bredevoort, De Heurne, Dinxperlo]
# 3    [103, km2]  [Augustinusga, Boelenslaan, Buitenpost, Drogeh...
# 4     [10, km2]                                     [Alblasserdam]
# ..          ...                                                ...
# 337  [120, km2]  [Achtmaal, Klein Zundert, Rijsbergen, Wernhout...
# 338   [42, km2]                               [Warnsveld, Zutphen]
# 339   [87, km2]     [Genemuiden, Hasselt, Mastenbroek, Zwartsluis]
# 340   [22, km2]                         [Heerjansdam, Zwijndrecht]
# 341  [119, km2]                                           [Zwolle]
#
#     Aantal inwoners Totaal aantal zetels  \
# 0             25579                   21
# 1             32452                   23
# 2             27100                   21
# 3             27954                   21
# 4             20087                   19
# ..              ...                  ...
# 337           22260                   19
# 338           48330                   29
# 339           23012                   19
# 340           44789                   27
# 341          130668                   39
#
#                                                   Raad CBSCode  \
# 0    [[Gemeentebelangen Aa en Hunze, 9], [VVD, 3], ...    1680
# 1    [[Absoluut Aalsmeer, 6], [CDA, 6], [VVD, 5], [...    0358
# 2    [[CDA, 7], [GemeenteBelangen, 4], [BBB-HMV, 4]...    0197
# 3    [[CDA, 6], [FNP, 4], [ChristenUnie, 3], [GBA, ...    0059
# 4    [[SGP, 5], [VVD, 3], [CDA, 3], [PvdA, 3], [D66...    0482
# ..                                                 ...     ...
# 337  [[Ondernemend Platteland, 5], [CDA, 4], [VVD, ...    0879
# 338  [[GroenLinks, 5], [PvdA, 4], [Burgerbelang, 4]...    0301
# 339  [[SGP, 6], [ChristenUnie, 4], [BGZ, 4], [PvdA,...    1896
# 340  [[Algemeen Belang Zwijndrecht, 10], [ChristenU...    0642
# 341  [[ChristenUnie, 7], [GroenLinks, 7], [VVD, 5],...    0193
#
#                                        Service area of  \
# 0    [[90, GGD Drenthe], [Alescon], [RUD Drenthe, R...
# 1    [[340, GGD Amsterdam], [Amstelland en Meerland...
# 2    [[Erfgoedcentrum Achterhoek en Liemers], [GGD ...
# 3    [[1040, GGD Fryslân], [FUMO, Fryske Utfierings...
# 4    [[480, GGD Zuid-Holland Zuid], [Dienst Gezondh...
# ..                                                 ...
# 337  [[BENEGO], [BWB, Belastingsamenwerking West-Br...
# 338  [[Delta], [GGD Gelre-IJssel], [GGD NOG, Gemeen...
# 339  [[GGD IJsselland, 100], [OD IJsselland, Omgevi...
# 340  [[480, GGD Zuid-Holland Zuid], [Dienst Gezondh...
# 341  [[GBLT, Gemeenschappelijk Belastingkantoor Loc...
#
#                                          Overlaps with  \
# 0    [[Drenthe], [Waterschap Drents Overijsselse De...
# 1    [[Hoogheemraadschap Amstel, Gooi en Vecht], [H...
# 2          [[Gelderland], [Waterschap Rijn en IJssel]]
# 3                    [[Fryslân], [Wetterskip Fryslân]]
# 4          [[Waterschap Rivierenland], [Zuid-Holland]]
# ..                                                 ...
# 337    [[Noord-Brabant], [Waterschap Brabantse Delta]]
# 338  [[Gelderland], [Waterschap Rijn en IJssel], [W...
# 339  [[Overijssel], [Waterschap Drents Overijsselse...
# 340     [[Waterschap Hollandse Delta], [Zuid-Holland]]
# 341  [[Overijssel], [Waterschap Drents Overijsselse...
#
#                                 Predecessors  \
# 0                                         []
# 1                                         []
# 2                              [[Dinxperlo]]
# 3                                         []
# 4                                         []
# ..                                       ...
# 337                                       []
# 338                            [[Warnsveld]]
# 339  [[Genemuiden], [Hasselt], [Zwartsluis]]
# 340                          [[Heerjansdam]]
# 341                                       []
#
#                                               OWMS URI Organisatiecode  \
# 0    http://standaarden.overheid.nl/owms/terms/Aa_e...          gm1680
# 1    http://standaarden.overheid.nl/owms/terms/Aals...          gm0358
# 2    http://standaarden.overheid.nl/owms/terms/Aalt...          gm0197
# 3    http://standaarden.overheid.nl/owms/terms/Acht...          gm0059
# 4    http://standaarden.overheid.nl/owms/terms/Albl...          gm0482
# ..                                                 ...             ...
# 337  http://standaarden.overheid.nl/owms/terms/Zund...          gm0879
# 338  http://standaarden.overheid.nl/owms/terms/Zutp...          gm0301
# 339  http://standaarden.overheid.nl/owms/terms/Zwar...          gm1896
# 340  http://standaarden.overheid.nl/owms/terms/Zwij...          gm0642
# 341  http://standaarden.overheid.nl/owms/terms/Zwol...          gm0193
#
#                                            Namen
# 0            [Aa en Hunze, Gemeente Aa en Hunze]
# 1                  [Aalsmeer, Gemeente Aalsmeer]
# 2                      [Aalten, Gemeente Aalten]
# 3        [Achtkarspelen, Gemeente Achtkarspelen]
# 4          [Alblasserdam, Gemeente Alblasserdam]
# ..                                           ...
# 337                  [Zundert, Gemeente Zundert]
# 338                  [Zutphen, Gemeente Zutphen]
# 339  [Zwartewaterland, Gemeente Zwartewaterland]
# 340          [Zwijndrecht, Gemeente Zwijndrecht]
# 341                    [Zwolle, Gemeente Zwolle]
#
# [342 rows x 12 columns]
