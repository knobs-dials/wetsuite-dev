# %%
# start with this when working in a disposable environment like google colab
# !pip --quiet install https://github.com/scarfboy/wetsuite-dev/archive/refs/heads/main.zip

# %% [markdown]
# ### Basic test

# %%
import bs4

import wetsuite.helpers.net
import wetsuite.phrases.abbreviations

# %%
# Unreasonably clean data,  that also contains some less usual cases so we can report what we might eventually want to deal with
html = wetsuite.helpers.net.download('https://organisaties.overheid.nl/Zelfstandige_bestuursorganen/') 

soup = bs4.BeautifulSoup( html ) # parse the webpage into something we can query
for link in soup.select('.content .list--linked li a'):   # we are interested in the link text:
    found = False
    for ab, words in wetsuite.phrases.abbreviations.find_abbrevs( link.text ):
        print( 'FOUND  %s = %s'%( ab, words ) )
        found = True

    # Things we didn't find - more creative things that we _might_ want to consider
    if '(' in link.text and not found:    # (assuming bracket indicates there is an explained abbreviation in that link text)
        print( "MISS  ", link.text )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/www/coding/wetsuite/examples/Abbrevs.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/examples/Abbrevs.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Unreasonably clean data,  that also contains some less usual cases so we can report what we might eventually want to deal with
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/examples/Abbrevs.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> html = wetsuite.helpers.net.download('https://organisaties.overheid.nl/Zelfstandige_bestuursorganen/')
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/examples/Abbrevs.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> soup = bs4.BeautifulSoup( html ) # parse the webpage into something we can query
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a223139322e3136382e3137382e323139222c2275736572223a227363617266626f79227d/var/www/coding/wetsuite/examples/Abbrevs.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> for link in soup.select('.content .list--linked li a'):   # we are interested in the link text:
#
# File /usr/local/lib/python3.8/dist-packages/wetsuite/helpers/net.py:38, in download(url, tofile_path, show_progress)
#      35 total_length = response.headers.get('content-length')
#      37 if not response.ok:
# ---> 38     raise ValueError( response.status_code )
#      40 chunk_size = 128*1024
#      41 if total_length is not None:
#
# ValueError: 500

# %%
# Similar idea, different site
html = wetsuite.helpers.net.download('https://publications.europa.eu/code/nl/nl-5000400.htm') 

soup = bs4.BeautifulSoup( html ) # parse the webpage into something we can query
for tr in soup.select('table.definitionsTable tr'):   # we are interested in the link text:
    tds = tr.findAll('td')

    # TODO: deal with the way it mentions multiple definitions
    text = '%s (%s)'%(tds[0].text.strip(), tds[1].text.strip())  # pretend we don't know this is good data and just put it next to each other

    found = False
    for ab, words in wetsuite.phrases.abbreviations.find_abbrevs( text ):
        print( 'FOUND  %s = %s'%( ab, words ) )
        found = True

    # Things we didn't find - more creative things that we _might_ want to consider
    if '(' in text and not found:    # (assuming bracket indicates there is an explained abbreviation in that link text)
        print( "MISS  ", text )
# Out:
# MISS   ABH (Agentschap voor Buitenlandse Handel (voorheen BDBH (Belgische Dienst voor Buitenlandse Handel)))
# MISS   ABVV (Algemeen Belgisch Vakverbond)
# MISS   ACS (staten in Afrika, het Caribisch gebied en de Stille Oceaan)
# FOUND  ACV = ['Algemeen', 'Christelijk', 'Vakverbond']
# MISS   ADB (1.
# Afrikaanse Ontwikkelingsbank
# (African Development Bank)
# 2.
# Arabische Ontwikkelingsbank
# (Arab Development Bank)
# 3.
# Aziatische Ontwikkelingsbank
# (Asian Development Bank))
# MISS   ADN (Europese Overeenkomst betreffende het internationale vervoer van gevaarlijke goederen over de binnenwateren)
# MISS   ADR (Europese Overeenkomst betreffende het internationale vervoer van gevaarlijke goederen over de weg)
# MISS   Afnor (Frans Normalisatie-instituut
# (Association française de normalisation))
# MISS   ALO (algemene leningsovereenkomst)
# MISS   Altener II (meerjarenprogramma ter bevordering van hernieuwbare energiebronnen in de Gemeenschap)
# MISS   AKE (Agentschap voor Kernenergie (OESO))
# FOUND  ANP = ['Algemeen', 'Nederlands', 'Persbureau']
# MISS   APRK (actieplan risicokapitaal)
# MISS   APS (algemeen preferentiestelsel)
# MISS   Ariane (programma voor steun op het gebied van het boek en het lezen, met inbegrip van vertalingen)
# MISS   Asean (Associatie van Zuidoost-Aziatische Staten
# (Association of South-East Asian Nations))
# MISS   ASEM (Ontmoeting Azië-Europa
# (Asia-Europe meeting))
# MISS   AU (Afrikaanse Unie (voorheen OAE))
# FOUND  BBT = ['beste', 'beschikbare', 'technologie']
# MISS   BC-net (business cooperation network)
# MISS   Benelux (Economische Unie van België, Nederland en Luxemburg)
# MISS   Berec (Orgaan van Europese regulerende instanties voor elektronische communicatie (Body of European Regulators for Electronic Communications))
# MISS   BIB (Bank voor Internationale Betalingen)
# MISS   BIC (bedrijfsinnovatiecentrum)
# MISS   BIN (Belgisch Instituut voor Normalisatie(vervangen door NBN))
# FOUND  BLEU = ['Belgisch', 'Luxemburgse', 'Economische', 'Unie']
# MISS   Care (databank van de Europese Unie inzake ongevallen in het wegverkeer)
# MISS   Cariforum (Forum van de Caribische groep van de landen van Afrika, het Caribisch gebied en de landen van de Stille Oceaan)
# FOUND  CB = ['communautair', 'bestek']
# MISS   CBS (1.
# Centraal Bureau voor de Statistiek (NL)
# 2.
# College van burgemeester en schepenen (BE))
# MISS   CCAMLR (Commissie voor de instandhouding van de levende rijkdommen in de Antarctische wateren (Commission for the Conservation of Antarctic Marine Living Resources))
# MISS   CCOL (Coördinatiecommissie voor de ozonlaag
# (Coordinating Committee on the Ozone Layer))
# MISS   CDO (Commissie voor duurzame ontwikkeling)
# MISS   Cecaf (Visserijcommissie voor het centraaloostelijk deel van de Atlantische Oceaan (Fishery Committee for the Eastern Central Atlantic))
# MISS   CEEP (Europees Centrum van gemeenschapsbedrijven en bedrijven van algemeen economisch belang
# (European Centre of Employers and Enterprises providing Public services))
# MISS   CEI (Internationale Elektrotechnische Commissie
# (Commission électrotechnique internationale))
# MISS   Ceies (Europees Raadgevend Comité voor statistische informatie op economisch en sociaal gebied
# (comité consultatif européen de l’information statistique dans les domaines économique et social))
# MISS   Celad (Europees Comité voor drugsbestrijding
# (comité européen de lutte antidrogue))
# MISS   Celex (interinstitutioneel meertalig systeem van geautomatiseerde documentatie voor het Gemeenschapsrecht (databank)
# (Communitatis Europaeae Lex))
# MISS   CEN (Europees Comité voor normalisatie
# (Comité européen de normalisation))
# MISS   Cenelec (Europees Comité voor elektrotechnische normalisatie
# (Comité européen de normalisation électrotechnique))
# MISS   CEPS (Centrum voor Europese beleidsstudies
# (Centre for European Policy Studies))
# MISS   CERN (Europese Organisatie voor Kernfysisch Onderzoek
# (Organisation européenne pour la recherche nucléaire))
# MISS   CIES (Ministersconferentie over de internationale economische samenwerking
# (Conférence sur la coopération économique internationale))
# MISS   CIST (Internationaal Centrum voor Wetenschap en Technologie
# (Centre international pour la science et la technologie))
# MISS   Cites (Overeenkomst inzake de internationale handel in bedreigde in het wild levende dier- en plantensoorten
# (Convention on International Trade in Endangered Species of Wild Flora and Fauna ))
# MISS   Codest (Comité voor de Europese ontwikkeling van wetenschap en technologie
# (comité de développement européen de la science et de la technologie))
# MISS   Cogeca (Algemeen Comité van de landbouwcoöperaties van de Europese Unie)
# MISS   COPA (Comité van de landbouworganisaties van de Europese Unie)
# MISS   CORDIS (Informatiedienst voor communautair onderzoek en ontwikkeling
# (Community Research and Development Information Service)
# (Dit is een uitzondering op de algemene hoofdletterregel (zie punt 10.2.9): om verwarring met een commerciële organisatie met dezelfde afkorting te voorkomen, wordt CORDIS in deze betekenis altijd met hoofdletters geschreven.))
# MISS   Coreper (Comité van permanente vertegenwoordigers
# (Comité des représentants permanents))
# MISS   COST (Europese samenwerking inzake wetenschap en technologie (coopération européenne en science et technologie)
# (oude benaming: Europese samenwerking op het gebied van het wetenschappelijk en technisch onderzoek (coopération européenne dans le domaine de la recherche scientifique et technique)))
# MISS   Crest (Comité voor wetenschappelijk en technisch onderzoek
# (comité de la recherche scientifique et technique))
# MISS   Cronos (databank van Eurostat voor de verwerking van tijdreeksen)
# MISS   CSTD (Commissie voor wetenschap en techniek voor ontwikkeling
# (Committee on Science and Technology for Development))
# FOUND  DG = ['directoraat', 'generaal']
# MISS   Diane (informatienetwerk met directe toegang voor Europa
# (direct information access network for Europe))
# MISS   DIN (1.
# Duitse industrienorm
# (Deutsche Industrie Norm)
# 2.
# Duits Normalisatie-instituut
# (Deutsches Institut für Normung))
# MISS   Easdaq (European Association of Securities Dealers Automatic Quotation)
# MISS   EBWO (Europese Bank voor Wederopbouw en Ontwikkeling)
# MISS   ECAC (Europese Burgerluchtvaartconferentie
# (European Civil Aviation Conference))
# MISS   Eccas (Economische Gemeenschap van Centraal-Afrikaanse Staten (Communauté économique des États d’Afrique centrale))
# MISS   ECE (Economische Commissie voor Europa (VN))
# FOUND  ECIP = ['European', 'Community', 'Investment', 'Partners']
# MISS   Eclac (Economische Commissie voor Latijns-Amerika en het Caribisch gebied
# (Economic Commission for Latin America and the Caribbean))
# FOUND  ECN = ['Energieonderzoek', 'Centrum', 'Nederland']
# MISS   ECOO (Europees Comité voor onderzoek en ontwikkeling)
# MISS   Ecosoc (Economische en Sociale Raad (VN))
# MISS   Ecowas (Economische Gemeenschap van West-Afrikaanse Staten)
# MISS   ECPS (Europees  Centrum voor politieke strategie)
# MISS   EDG (Europese Defensiegemeenschap)
# MISS   EEA (Europees Milieuagentschap)
# FOUND  EEG = ['Europese', 'Economische', 'Gemeenschap']
# FOUND  EER = ['Europese', 'Economische', 'Ruimte']
# MISS   EESV (Europees Economisch Samenwerkingsverband)
# MISS   EFG (Europees Fonds voor aanpassing aan de globalisering)
# MISS   Efics (Europees informatie- en communicatiesysteem voor de bosbouw
# (European forestry information and communication system))
# MISS   EFMS (Europees Fonds voor monetaire samenwerking)
# MISS   EFRO (Europees Fonds voor regionale ontwikkeling)
# MISS   EGKS (Europese Gemeenschap voor Kolen en Staal)
# MISS   EHRM (Europees Hof voor de Rechten van de Mens)
# FOUND  EIC = ['Euro', 'Info', 'Centre']
# MISS   EIF (Europees Investeringsfonds)
# MISS   Einecs (Europese inventaris van bestaande chemische handelsstoffen
# (European inventory of existing commercial chemical substances))
# MISS   EIPP (Europees investeringsprojectenportaal)
# MISS   ELA (Europese Arbeidsautoriteit)
# MISS   Elfpo (Europees Landbouwfonds voor plattelandsontwikkeling)
# MISS   ELGF (Europees Landbouwgarantiefonds)
# MISS   Elise (Europees leninggarantiesysteem voor het scheppen van werkgelegenheid (European loan insurance scheme for employment))
# MISS   EMA (Europees Geneesmiddelenbureau)
# FOUND  EMF = ['Europees', 'Monetair', 'Fonds']
# MISS   EMRE (Europese monetaire rekeneenheid)
# FOUND  EMS = ['Europees', 'Monetair', 'Stelsel']
# MISS   EMU (economische en monetaire unie)
# MISS   EMVAF (Europees Maritiem, Visserij- en Aquacultuurfonds
# (voorheen EVF/EFMZV))
# MISS   ENEA (zie NEA)
# MISS   ENO (Europese Normalisatieorganisatie)
# MISS   EOB (Europees Octrooibureau)
# MISS   EOF (Europees Ontwikkelingsfonds)
# MISS   EOGFL (Europees Oriëntatie- en Garantiefonds voor de landbouw
# EOGFL-Oriëntatie; EOGFL, afdeling Oriëntatie
# EOGFL-Garantie; EOGFL, afdeling Garantie)
# MISS   EOR (Europese onderzoeksruimte)
# MISS   EPD (enig programmeringsdocument)
# MISS   Erasmus (programma van de Europese Unie inzake de mobiliteit van studenten
# (European Community action scheme for the mobility of university students))
# MISS   Ermes (Europees Radioberichtensysteem
# (European radio-messaging system))
# MISS   ESA (Europees Ruimteagentschap
# (European Space Agency))
# MISS   ESCB (Europees Stelsel van centrale banken)
# MISS   ESER (Europees Stelsel van economische rekeningen)
# FOUND  ESF = ['Europees', 'Sociaal', 'Fonds']
# MISS   ESM (Europees stabiliteitsmechanisme (http://www.esm.europa.eu/))
# MISS   ESR (Europees Stelsel van nationale en regionale rekeningen)
# MISS   EUIPO (Bureau voor intellectuele eigendom van de Europese Unie (European Union Intellectual Property Office))
# MISS   EUMC (1.
# Militair Comité van de Europese Unie
# 2.
# Europees Waarnemingscentrum voor racisme en vreemdelingenhaat
# (sinds 2007 Bureau van de Europese Unie voor de grondrechten, FRA))
# MISS   Eumetsat (Europese Organisatie voor de Exploitatie van Meteorologische Satellieten
# (European Organisation for the Exploitation of Meteorological Satellites))
# MISS   Eureka (Europees Agentschap voor de coördinatie van het onderzoek
# (European Research Coordination Agency))
# MISS   Eures (Europese dienst voor arbeidsvoorziening
# (European employment services))
# MISS   Eurocontrol (Europese Organisatie voor de veiligheid van de luchtvaart)
# MISS   Eurodicautom (meertalige terminologische databank van de Europese Commissie, opgenomen in IATE (zie IATE))
# MISS   Europol (Agentschap van de Europese Unie voor samenwerking op het gebied van rechtshandhaving)
# MISS   Eurydice (informatienet voor onderwijs in Europa)
# MISS   EUSA (Europese Bestuursschool)
# MISS   EVA (Europese Vrijhandelsassociatie)
# MISS   EVDA (Europese Veiligheids- en defensieacademie)
# MISS   EVDB (Europees gemeenschappelijk veiligheids- en defensiebeleid
#   (vervangen door GVDB))
# MISS   EVF (Europees Visserijfonds (zie EMVAF))
# MISS   EVRM (1.
# Europees Verdrag voor de rechten van de mens
# 2.
# Verdrag tot bescherming van de rechten van de mens en de fundamentele vrijheden)
# MISS   EVV (Europees Verbond van Vakverenigingen)
# MISS   FAO (Voedsel- en Landbouworganisatie van de Verenigde Naties
# (Food and Agriculture Organization of the United Nations))
# MISS   FIOV (Financieringsinstrument voor de oriëntatie van de visserij)
# MISS   Fiscalis (actieprogramma van de Europese Unie ter verbetering van de stelsels van indirecte belastingen van de interne markt)
# MISS   Flegt (wetshandhaving, governance en handel in de bosbouw
# (Forest Law Enforcement, Governance and Trade))
# MISS   GAB (gewijzigde en aanvullende begroting)
# MISS   GBVB (gemeenschappelijk buitenlands en veiligheidsbeleid)
# MISS   GCC (Samenwerkingsraad van de Golfstaten
# (Gulf Cooperation Council))
# MISS   GDT (gemeenschappelijk douanetarief)
# MISS   GLB (gemeenschappelijk landbouwbeleid)
# MISS   GMO (gemeenschappelijke marktordening)
# FOUND  GN = ['gecombineerde', 'nomenclatuur']
# MISS   GOP (geïntegreerde ontwikkelingsprojecten)
# MISS   GOS (Gemenebest van Onafhankelijke Staten)
# MISS   GPD (gecombineerd programmeringsdocument)
# MISS   GVB (gemeenschappelijk visserijbeleid)
# MISS   GVDB (gemeenschappelijk veiligheids- en defensiebeleid
# (voorheen EVDB))
# MISS   Habitat (Programma van de Verenigde Naties voor menselijke nederzettingen)
# MISS   HV (hoge vertegenwoordiger van de Unie voor buitenlandse zaken en veiligheidsbeleid)
# MISS   IAB (Internationaal Arbeidsbureau)
# MISS   IAEA (Internationale Organisatie voor Atoomenergie
# (International Atomic Energy Agency))
# MISS   IAO (Internationale Arbeidsorganisatie (ook ILO))
# MISS   IATA (Internationale Luchtvaartorganisatie
# (International Air Transport Association))
# MISS   IATE (InterActive Terminology for Europe
# (omvat o.a. Eurodicautom))
# MISS   IBHO (Internationale Bank voor Herstel en Ontwikkeling (Wereldbank))
# MISS   IBSFC (Internationale Visserijcommissie voor de Oostzee
# (International Baltic Sea Fishery Commission))
# MISS   ICAO (Internationale Burgerluchtvaartorganisatie)
# MISS   ICES (Internationale Raad voor het onderzoek van de zee (International Council for the Exploration of the Sea))
# MISS   ICRK (Internationaal Comité van het Rode Kruis)
# MISS   ICTY (Internationaal Straftribunaal voor het voormalige Joegoslavië)
# MISS   IEA (Internationaal Energieagentschap)
# MISS   IFAD (Internationaal Fonds voor agrarische ontwikkeling
# (International Fund for Agricultural Development))
# MISS   IGC (intergouvernementele conferentie)
# MISS   IKK (Internationale Kamer van Koophandel)
# MISS   ILO (zie IAO)
# MISS   ILB (informatienet inzake landbouwbedrijfsboekhoudingen)
# FOUND  IMF = ['Internationaal', 'Monetair', 'Fonds']
# MISS   INRA (Internationale Natuurrubberovereenkomst
# (International Natural Rubber Agreement))
# MISS   Intelsat (Internationale Organisatie voor Telecommunicatiesatellieten
# (International Telecommunications Satellite Organisation))
# MISS   Interprise (communautair programma inzake samenwerking tussen ondernemingen)
# MISS   Interreg (communautair initiatief ten behoeve van grensgebieden)
# MISS   IPPC (Internationaal Verdrag voor de bescherming van planten
# (International Plant Protection Convention))
# MISS   Irdac (Raadgevend Comité voor onderzoek en ontwikkeling in de industrie
# (Industrial Research and Development Advisory Committee))
# MISS   ISO (Internationale Organisatie voor Normalisatie
# (International Organisation for Standardisation))
# MISS   JBZ (Justitie en Binnenlandse Zaken)
# FOUND  JET = ['Joint', 'European', 'Torus']
# MISS   JRC (Gemeenschappelijk Centrum voor onderzoek
# (Joint Research Centre))
# FOUND  KB = ['Koninklijk', 'Besluit']
# MISS   KEDO (Organisatie voor Energieontwikkeling op het Koreaanse Schiereiland)
# MISS   kmo’s (kleine en middelgrote ondernemingen (BE), zie ook mkb)
# MISS   Leader II (communautair initiatief voor plattelandsontwikkeling)
# MISS   Leonardo (programma van de Europese Unie inzake beroepsopleiding)
# MISS   LGO’s (landen en gebieden overzee)
# MISS   LIFE (financieringsinstrument voor het milieu
# (l’Instrument financier pour l’environnement))
# MISS   LIFE+ (financieringsinstrument voor het milieu)
# MISS   LMOE’s (landen van Midden- en Oost-Europa)
# MISS   MAP 2000 (modernisering van de administratieve procedures en van het beheer van de menselijke hulpbronnen
# (modernisation of administrative procedures and the management of human resources))
# MISS   Matthaeus (communautair actieprogramma voor de beroepsopleiding van douaneambtenaren)
# MISS   MCB’s (monetaire compenserende bedragen)
# MISS   Meda (indicatief programma inzake financiële en technische maatregelen ter ondersteuning van de hervorming van de economische en maatschappelijke structuren in het kader van het Europees-mediterrane partnerschap)
# MISS   Media II (— ontwikkeling en distributieprogramma ter bevordering van de ontwikkeling en de distributie van Europese audiovisuele werken— opleidingopleidingsprogramma voor de vakmensen van de Europese audiovisuele programma-industrie)
# MISS   Mercosur (Zuid-Amerikaanse Gemeenschappelijke Markt
# (Mercado Común del Sur))
# MISS   mkb (midden- en kleinbedrijf (NL), zie ook kmo’s)
# MISS   MOL’s (minst ontwikkelde landen)
# MISS   NACE (algemene systematische bedrijfsindeling in de Europese Unie)
# MISS   NAFO (Visserijorganisatie voor het noordwestelijke deel van de Atlantische Oceaan
# (North-West Atlantic Fisheries Organisation))
# MISS   Nafta (Noord-Amerikaanse Vrijhandelsovereenkomst
# (North American Free Trade Agreement))
# MISS   NAVO (Noord-Atlantische Verdragsorganisatie)
# MISS   NBB (Nationale Bank van België)
# MISS   NBN (Belgisch Instituut voor Normalisatie
#   (voorheen BIN))
# FOUND  NCI = ['nieuw', 'communautair', 'instrument']
# MISS   NEA (Agentschap voor kernenergie
# (Nuclear Energy Agency, voorheen European Nuclear Energy Agency ENEA))
# MISS   NEN (Nederlandse norm)
# FOUND  NET = ['Next', 'European', 'Torus']
# FOUND  ngo = ['niet', 'gouvernementele', 'organisatie']
# MISS   NIC’s (nieuwe industrielanden)
# FOUND  NOS = ['nieuwe', 'onafhankelijke', 'staten']
# MISS   NUTS (nomenclatuur van territoriale eenheden voor de statistiek)
# FOUND  NVU = ['niet', 'verplichte', 'uitgave']
# MISS   OAE (Organisatie voor Afrikaanse Eenheid (vervangen door AU))
# MISS   OAS (1.
# Organisatie van Afrikaanse Staten
# 2.
# Organisatie van Amerikaanse Staten)
# MISS   ODA (officiële ontwikkelingshulp
# (Official Development Assistance))
# MISS   Odysseus (programma voor opleiding, uitwisseling en samenwerking op het gebied van het asielbeleid, het immigratiebeleid en de overschrijding van de buitengrenzen)
# MISS   OESO (Organisatie voor Economische Samenwerking en Ontwikkeling)
# MISS   ONP (open telecommunicatienetwerk
# (open network provision))
# MISS   O&O (onderzoek en ontwikkeling)
# MISS   OPEC (Organisatie van Olie-exporterende Landen
# (Organization of Petroleum Exporting Countries))
# MISS   OTO (onderzoek en technologische ontwikkeling)
# MISS   OVSE (Organisatie voor Veiligheid en Samenwerking in Europa)
# MISS   Phare (programma voor communautaire hulp aan de landen van Midden- en Oost-Europa)
# MISS   RCWTO (Raadgevend Comité voor wetenschappelijke en technische opleiding)
# MISS   Reach (registratie en beoordeling van en autorisatie en beperkingen ten aanzien van chemische stoffen
# (Registration, Evaluation, Authorisation and Restriction of Chemicals))
# MISS   Safe (communautair programma ter verbetering van de veiligheid, de hygiëne en de gezondheid op het werk)
# MISS   SAP (stelsel van algemene preferenties)
# MISS   Satcen (Satellietcentrum van de Europese Unie)
# MISS   Save (meerjarenprogramma ter bevordering van de energie-efficiëntie in de Gemeenschap)
# MISS   SCIC (Gemeenschappelijke tolken-conferentiedienst (Europese Commissie; vervangen door het directoraat-generaal Tolken))
# MISS   SCK (Studiecentrum voor kernenergie)
# MISS   SEM 2000 (goed en efficiënt financieel beheer
# (sound and efficient financial management 2000))
# MISS   SFEU (Solidariteitsfonds van de Europese Unie)
# MISS   SIS (Schengeninformatiesysteem)
# MISS   Socrates (communautair actieprogramma op onderwijsgebied)
# MISS   Stabex (systeem voor de stabilisatie van de exportopbrengsten)
# MISS   Synergy (programma ter bevordering van de internationale samenwerking in de energiesector)
# MISS   Sysmin (systeem voor mijnbouwproducten)
# MISS   TAC (totaal toegestane vangst)
# MISS   Tacis ((programma voor) technische bijstand aan de nieuwe onafhankelijke staten en Mongolië)
# MISS   Taric (geïntegreerd douanetarief van de Europese Unie)
# MISS   TCIH (typeclassificatie voor de internationale handel)
# MISS   Tempus III (trans-Europees mobiliteitsprogramma voor universiteitsstudies
# (trans-European mobility scheme for university studies))
# FOUND  TEN = ['trans', 'Europees', 'netwerk']
# MISS   TIF (grensoverschrijdend vervoer per spoor)
# MISS   Trips (handelsgerelateerde aspecten van intellectuele eigendom (Agreement on Trade Related Aspects of Intellectual Property Rights))
# MISS   TTIP (Trans-Atlantisch Partnerschap voor handel en investeringen (Transatlantic Trade and Investment Partnership))
# MISS   Unced (Conferentie van de Verenigde Naties over milieu en ontwikkeling
# (United Nations Conference on Environment and Development))
# MISS   UNCSTD (Conferentie van de Verenigde Naties over wetenschap en technologie voor ontwikkeling
# 	(United Nations Conference on Science and Technology for Development))
# MISS   Unctad (Conferentie van de Verenigde Naties voor handel en ontwikkeling
# (United Nations Conference on Trade and Development))
# MISS   UNDP (Ontwikkelingsprogramma van de Verenigde Naties
# (United Nations Development Programme))
# MISS   UNEP (Milieuprogramma van de Verenigde Naties
# (United Nations Environment Programme))
# MISS   Unesco (Organisatie van de Verenigde Naties voor Onderwijs, Wetenschap en Cultuur
# (United Nations Educational, Scientific and Cultural Organization))
# MISS   UNHCR (Hoge Commissaris van de Verenigde Naties voor de Vluchtelingen
# (United Nations High Commissioner for Refugees))
# MISS   Unice (Unie van Industrie- en Werkgeversfederaties in Europa (Union of Industrial and Employers’ Confederations of Europe))
# MISS   Unicef (Kinderfonds van de Verenigde Naties
# (United Nations Children’s Fund))
# MISS   Unido (Organisatie van de Verenigde Naties voor Industriële Ontwikkeling
# (United Nations Industrial Development Organisation))
# MISS   UNRWA (Organisatie van de Verenigde Naties voor Hulpverlening aan Palestijnse Vluchtelingen
# (United Nations Relief and Works Agency for Palestine Refugees in the Near East))
# MISS   Urban (communautair initiatief voor stedelijke gebieden)
# MISS   VBO (Verbond van Belgische Ondernemingen)
# FOUND  VEV = ['Vlaams', 'Economisch', 'Verbond']
# MISS   VK (vastleggingskrediet)
# FOUND  VN = ['Verenigde', 'Naties']
# MISS   VNO (Verbond van Nederlandse Ondernemingen)
# MISS   VOB (voorontwerp van begroting)
# MISS   VOGB (voorontwerp van gewijzigde begroting)
# MISS   VU’s (verplichte uitgaven)
# MISS   WCO (Werelddouaneorganisatie)
# MISS   WDO ((zie WCO))
# MISS   WEC (Wereldenergieraad
# (World Energy Council))
# FOUND  WEU = ['West', 'Europese', 'Unie']
# MISS   WFC (Wereldvoedselconferentie
# (World Food Conference))
# MISS   WGO ((zie WHO))
# MISS   WHO (Wereldgezondheidsorganisatie
# (World Health Organization))
# MISS   WIPO (Wereldorganisatie voor de Intellectuele Eigendom
# (World Intellectual Property Organization))
# FOUND  WMO = ['Wereld', 'Meteorologische', 'Organisatie']
# MISS   WNF (Wereldnatuurfonds)
# MISS   WTECV (Wetenschappelijk, Technisch en Economisch Comité voor de visserij)
# MISS   WTC (Wetenschappelijk en Technisch Comité)
# MISS   WTO (Wereldhandelsorganisatie
# (World Trade Organization))
# MISS   Zoavo (Zuidoost-Aziatische Verdragsorganisatie)

# %%
# Similar idea, different site
html = wetsuite.helpers.net.download('https://www.rijksfinancien.nl/memorie-van-toelichting/2021/OWB/XIII/onderdeel/644956') 

soup = bs4.BeautifulSoup( html ) # parse the webpage into something we can query
for tr in soup.select('.kio2 tr'):   # we are interested in the link text:

    tds = tr.findAll('td')

    text = '%s (%s)'%(tds[0].text.strip(), tds[1].text.strip())  # pretend we don't know this is good data and just put it next to each other

    found = False
    for ab, words in wetsuite.phrases.abbreviations.find_abbrevs( text ):
        print( 'FOUND  %s = %s'%( ab, words ) )
        found = True

    # Things we didn't find - more creative things that we _might_ want to consider
    if '(' in text and not found:    # (assuming bracket indicates there is an explained abbreviation in that link text)
        print( "MISS  ", text )
# Out:
# MISS    ()
# MISS   ACM (Autoriteit Consument en Markt)
# FOUND  ACT = ['Accelerating', 'CCS', 'Technologies']
# MISS   ACVG (Adviescollege Veiligheid Groningen)
# FOUND  ANBI = ['Algemeen', 'nut', 'beogende', 'instellingen']
# FOUND  AT = ['Agentschap', 'Telecom']
# FOUND  ATR = ['Adviescollege', 'toetsing', 'regeldruk']
# MISS   AWTI (Adviesraad voor Wetenschap, Technologie en Innovatie)
# MISS   BBE (Biobased Economy)
# FOUND  BBP = ['Bruto', 'Binnenlands', 'Product']
# MISS   BES (Bonaire, Sint Eustatius, Saba)
# MISS   BIS (Basisinfrastructuur voor cultuur)
# MISS   BIPM (Bureau International des Poids en Mesures)
# MISS   BMKB (Borgstellingsregeling Midden en Kleinbedrijf)
# FOUND  BNP = ['Bruto', 'Nationaal', 'Product']
# FOUND  BOM = ['Brabantse', 'Ontwikkelings', 'Maatschappij']
# MISS   BPM (Belasting van personenauto's en motorrijwielen)
# MISS   BTW (Belasting over de toegevoegde waarde)
# MISS   BZ (Ministerie van Buitenlandse Zaken)
# MISS   BZK (Ministerie van Binnenlandse Zaken en Koninkrijksrelaties)
# MISS   CBS (Centraal Bureau voor de Statistiek)
# MISS   CCS (Carbon Capture and Storage)
# FOUND  CCU = ['Carbon', 'Capture', 'Usage']
# MISS   CEPT (Europese Conferentie van administraties voor Post en Telecommunicatie)
# FOUND  COE = ['Council', 'of', 'Europe']
# MISS   COL (Corona Overbruggingslening)
# FOUND  COVA = ['Centraal', 'Orgaan', 'Voorraadvorming', 'Aardolieproducten']
# MISS   CPB (Centraal Planbureau)
# FOUND  CSIRT = ['Computer', 'Security', 'Incident', 'Response', 'Team']
# FOUND  CVW = ['Centrum', 'Veilig', 'Wonen']
# FOUND  DEI = ['Demonstratieregeling', 'Energie', 'innovatie']
# MISS   DG B&I (Directoraat-Generaal Bedrijfsleven en Innovatie)
# FOUND  DGGF = ['Dutch', 'Good', 'Growth', 'Fund']
# MISS   DICTU (Dienst ICT Uitvoering)
# FOUND  DLG = ['Dienst', 'Landelijk', 'Gebied']
# FOUND  DTC = ['Digitaal', 'Trust', 'Centre']
# FOUND  DVI = ['Dutch', 'Venture', 'Initiative']
# MISS   EB (Energiebelasting)
# FOUND  EBN = ['Energie', 'beheer', 'Nederland']
# FOUND  ECB = ['European', 'Central', 'Bank']
# FOUND  ECN = ['Energieonderzoek', 'Centrum', 'Nederland']
# MISS   ECSEL (Electronics Components and Systems for European Leadership)
# MISS   EDS (Energiebesparing en duurzame energie sportaccommodaties)
# MISS   EED (Europese Energie-Efficiency Richtlijn)
# MISS   EFRO (Europees Fonds voor Regionale Ontwikkeling)
# MISS   EFSI (European Fund for Strategic Investments)
# MISS   EGO (Revolverend fonds energiebesparing)
# MISS   EHG (Energie-efficiency en hernieuwbare energie glastuinbouw)
# MISS   EIA (Energie- investeringsaftrek)
# MISS   eIDAS (Electronic Identification, Authentication and trust Services)
# MISS   EIF (Europees Investeringsfonds)
# MISS   EMT (Energie en Milieutechnologie)
# FOUND  END = ['Expert', 'National', 'Detaché']
# MISS   EPBD (Energy Performance of Buildings Directieve)
# FOUND  ESA = ['European', 'Space', 'Agency']
# MISS   ESTEC (European Space Research and Technology Centre)
# MISS   ETD (Elektronische Toegangsdiensten)
# MISS   ETFF (Energie Transitie Financieringsfaciliteit)
# MISS   ETS (Emission Trading Scheme/System)
# FOUND  EU = ['Europese', 'Unie']
# MISS   EV (Energie voor Vervoer)
# MISS   EZK (Ministerie van Economische Zaken en Klimaat)
# FOUND  FES = ['Fonds', 'Economische', 'Structuurversterking']
# MISS   FIN (Ministerie van Financiën)
# MISS   FMO (Financieringsmaatschappij voor Ontwikkelingslanden)
# MISS   FTE (Fulltime-equivalent)
# MISS   GF (Groeifaciliteit)
# MISS   GHz (Gigahertz)
# FOUND  GO = ['Garantie', 'Ondernemingsfinanciering']
# MISS   GSF (Garantiefaciliteit Scheepsnieuwbouwfinanciering)
# FOUND  GTS = ['Gasunie', 'Transport', 'Services']
# FOUND  HBO = ['Hoger', 'Beroeps', 'Onderwijs']
# FOUND  HER = ['Hernieuwbare', 'Energie', 'Regeling']
# FOUND  HEV = ['Hernieuwbare', 'Energie', 'Vervoer']
# FOUND  HFR = ['Hoge', 'Flux', 'Reactor']
# FOUND  HHI = ['Herfindahl', 'Hirschman', 'Index']
# MISS   HTSM (HighTech Systems & Materials)
# MISS   IBO (Interdepartementaal Beleidsonderzoek)
# MISS   ICANN/GAC (The Internet Corporation for Assigned Names and Numbers/Governmental Advisory Committee)
# MISS   ICT (Informatie- en communicatietechnologie)
# FOUND  IE = ['Intellectueel', 'Eigendom']
# FOUND  IEA = ['International', 'Energy', 'Agency']
# MISS   IenW (Ministerie van Infrastructuur en Waterstaat)
# FOUND  IGF = ['Internet', 'Governance', 'Forum']
# FOUND  IMM = ['Investeringsregeling', 'Milieuvriendelijke', 'Maatregelen']
# FOUND  IMVO = ['Internationaal', 'Maatschappelijk', 'Verantwoord', 'Ondernemen']
# MISS   INEK (Integraal Energie- en Klimaatplan)
# MISS   INTERREG (Europese Territoriale Samenwerking)
# MISS   IOP’s (Innovatieve onderzoeksprogramma’s)
# MISS   IPC (Innovatieprestatiecontracten)
# MISS   IPCC (Intergovernmental Panel on Climate Change)
# FOUND  IQ = ['Innovation', 'Quarter']
# MISS   IRE (Investeringsregeling Energiebesparing)
# MISS   IRENA (International Renewable Energy Agency)
# MISS   ISDE (InvesteringsSubsidie Duurzame Energie)
# MISS   ISO (Internationale Organisatie voor Standaardisatie)
# FOUND  ITU = ['International', 'Telecommunications', 'Union']
# MISS   IUC (Inkoop Uitvoeringscentrum)
# MISS   J&V (Ministerie van Justitie en Veiligheid)
# FOUND  JTI = ['Joint', 'Technology', 'Initiatives']
# MISS   KEV (Klimaat- en Energieverkenning)
# MISS   KKC (Garantieregeling Klein Krediet Corona)
# MISS   KNAW (Koninklijke Nederlandse Akademie van Wetenschappen)
# FOUND  KNMI = ['Koninklijk', 'Nederlands', 'Meteorologisch', 'Instituut']
# MISS   KP7 (Zevende kaderprogramma voor onderzoek en technologische ontwikkeling)
# FOUND  KvK = ['Kamer', 'van', 'Koophandel']
# FOUND  LEI = ['Landbouw', 'Economisch', 'Instituut']
# MISS   LIOF (De Limburgse industrie- en investeringsbank)
# MISS   LNV (Ministerie van Landbouw, Natuur en Voedselkwaliteit)
# FOUND  LPG = ['Liquefied', 'Petroleum', 'Gas']
# MISS   LS&H (Life Sciences and Health)
# MISS   MARIN (Maritime Research Institute Netherlands)
# MISS   MBO (Middelbaar beroepsonderwijs)
# FOUND  MEI = ['Marktintroductie', 'en', 'innovatie']
# MISS   MEP (Milieukwaliteit Elektriciteitsproductie)
# MISS   MER (Milieueffectrapportage)
# FOUND  MEV = ['Macro', 'Economische', 'Verkenning']
# MISS   MIA (Milieu-investeringsaftrek)
# FOUND  MIT = ['MKB', 'Innovatiestimulering', 'Topsectoren']
# FOUND  MEE = ['Meerjarenafspraken', 'energie', 'efficiëntie']
# MISS   MKB (Midden- en Kleinbedrijf)
# MISS   MRB (Motorrijtuigenbelasting)
# FOUND  MVO = ['Maatschappelijk', 'Verantwoord', 'Ondernemen']
# MISS   MWM (Minister van Wonen en Milieu)
# FOUND  NAM = ['Nederlandse', 'Aardolie', 'Maatschappij']
# MISS   NBTC (Nederlands Bureau voor Toerisme en Congressen)
# FOUND  NCG = ['Nationaal', 'Coördinator', 'Groningen']
# MISS   NEa (Nederlandse Emissieautoriteit)
# MISS   NEN (Nederlands Normalisatie-instituut)
# FOUND  NFIA = ['Netherlands', 'Foreign', 'Investment', 'Agency']
# FOUND  NIA = ['Nederlands', 'Investerings', 'Agentschap']
# MISS   NIB (Netwerk- en informatiebeveiliging)
# MISS   NLR (Nationaal Lucht- en Ruimtevaartlaboratorium)
# FOUND  NMI = ['Nationaal', 'Metrologisch', 'Instituut']
# FOUND  NML = ['Nederland', 'Maritiem', 'Land']
# MISS   NOM (Investerings- en ontwikkelingsmaatschappij voor Noord - Nederland)
# FOUND  NPS = ['Net', 'Promoter', 'Score']
# MISS   NRG (Nuclear Research and consultancy Group)
# FOUND  NSO = ['Netherlands', 'Space', 'Office']
# MISS   NVWA (Nederlandse Voedsel- en Warenautoriteit)
# MISS   NWO (Nederlandse Organisatie voor Wetenschappelijk Onderzoek)
# MISS   OCNL (Octrooicentrum Nederland)
# MISS   OCW (Ministerie van Onderwijs, Cultuur en Wetenschap)
# FOUND  ODE = ['Opslag', 'Duurzame', 'Energie']
# MISS   OIML (Organisation Internationale de Métrologie Légale)
# MISS   O&O (Onderwijs en Ondernemen)
# MISS   Oost NL (De ontwikkelingsmaatschappij van Oost-Nederland)
# MISS   OVB (Overdrachtsbelasting)
# FOUND  PAS = ['Programmatische', 'Aanpak', 'Stikstof']
# MISS   PBL (Planbureau voor de Leefomgeving)
# MISS   PIANOo (Professioneel en Innovatief Aanbesteden Netwerk voor Overheidsopdrachtgevers)
# MISS   PJ (Petajoule)
# FOUND  PMK = ['Project', 'Menselijk', 'Kapitaal']
# FOUND  PoC = ['Proof', 'of', 'Concept']
# FOUND  PPS = ['Publiek', 'Private', 'Samenwerking']
# FOUND  PTvT = ['Platform', 'Talent', 'voor', 'Technologie']
# MISS   RA (Regeerakkoord)
# MISS   RCR (Rijkscoördinatieregeling)
# MISS   RDA (Research & Developmentaftrek)
# MISS   RED (Richtlijn voor hernieuwbare energie)
# MISS   R&D (Research and Development)
# MISS   RES (Regionale Energiestrategie)
# MISS   RHB (Rijks Hoofdboekhouding)
# MISS   RIVM (Rijksinstituut voor Volksgezondheid en Milieu)
# MISS   ROM (Regionale Ontwikkelingsmaatschappijen)
# MISS   RUG (Rijksuniversiteit Groningen)
# FOUND  RvA = ['Raad', 'voor', 'Accreditatie']
# MISS   RVB (Rijksvastgoedbedrijf)
# MISS   RVO.nl (Rijksdienst voor Ondernemend Nederland)
# MISS   RWS (Rijkswaterstaat)
# MISS   RWT (Rechtspersonen met een Wettelijke taak)
# FOUND  SBIR = ['Small', 'Business', 'Innovation', 'Research']
# FOUND  SDE = ['Stimulering', 'Duurzame', 'Energieproductie']
# FOUND  SEA = ['Strategische', 'Evaluatie', 'Agenda']
# FOUND  SDS = ['Subsidieregeling', 'Duurzame', 'Scheepsbouw']
# FOUND  SER = ['Sociaal', 'Economische', 'Raad']
# MISS   SEV (Structuurprogramma Elektriciteitsvoorziening)
# FOUND  SGR = ['Stichting', 'Garantiefonds', 'Reisgelden']
# FOUND  SI = ['Smart', 'Industry']
# MISS   SMO (Samenwerkingsmiddelen Onderzoek)
# MISS   S&O (Speur- en Ontwikkelingswerk)
# FOUND  SodM = ['Staatstoezicht', 'op', 'de', 'Mijnen']
# FOUND  SSO = ['Shared', 'Service', 'Organisatie']
# MISS   STG-C (Staatsgeheim-confidentieel)
# MISS   STW (Stichting voor de Technische Wetenschappen)
# MISS   SURF (ICT-samenwerkingsorganisatie van het onderwijs en onderzoek in Nederland)
# MISS   SZW (Ministerie van Sociale Zaken en Werkgelegenheid)
# MISS   TCBB (Technische commissie bodembeweging)
# FOUND  TCMG = ['Tijdelijke', 'Commissie', 'Mijnbouwschade', 'Groningen']
# MISS   TKI (Topconsortia voor Kennis en Innovatie)
# MISS   TNO (Nederlandse Organisatie voor toegepast-natuurwetenschappelijk onderzoek)
# MISS   TNO-AGE (TNO Adviesgroep Economische Zaken)
# MISS   TO2 (Toegepast Onderzoek Organisaties)
# MISS   TOF (Toekomstfondskrediet voor Onderzoeksfaciliteiten)
# MISS   TOGS (Tegemoetkoming Ondernemers Getroffen Sectoren COVID-19)
# MISS   TSE (Tenderregeling Energie-innovatie)
# FOUND  TTF = ['Title', 'Transfer', 'Facility']
# FOUND  TTT = ['Thematische', 'Technology', 'Transfer']
# MISS   TTW (Toegepaste en Technische Wetenshappen)
# FOUND  TVL = ['Tegemoetkoming', 'vaste', 'lasten']
# FOUND  TWA = ['Technisch', 'Wetenschappelijke', 'Attaché']
# MISS   Twh (Terawattuur)
# FOUND  UMTS = ['Universal', 'Mobile', 'Telecommunications', 'System']
# MISS   UNFCCC (United Nations Framework Convention on Climate Change)
# MISS   UNWTO (World Tourism Organization)
# FOUND  UPU = ['Universal', 'Postal', 'Union']
# MISS   VAMIL (Regeling Vervroegde Afschrijving Milieu-investeringen)
# MISS   VK (het Verenigd Koninkrijk)
# FOUND  VN = ['Verenigde', 'Naties']
# FOUND  VSL = ['Van', 'Swinden', 'Laboratorium']
# MISS   VWS (Ministerie van Volksgezondheid, Welzijn en Sport)
# FOUND  WABO = ['Wet', 'Algemene', 'Bepalingen', 'Omgevingsrecht']
# MISS   WBSO (Wet Bevordering Speur- en Ontwikkelingswerk)
# MISS   WELMEC (Europese samenwerking op wettelijke Metrologie)
# FOUND  WIM = ['Werkgroep', 'Internationale', 'Mobiliteit']
# MISS   WION (Wet Informatie uitwisseling Ondergrondse Netten)
# FOUND  WIPO = ['World', 'Intellectual', 'Property', 'Organization']
# FOUND  WOZT = ['Wet', 'ongewenste', 'zeggenschap', 'telecommunicatie']
# FOUND  Wva = ['Wet', 'voorraadvorming', 'aardolieproducten']
# MISS   ZBO (Zelfstandig Bestuursorgaan)

# %%
html = wetsuite.helpers.net.download('https://juridisch-woordenboek.nl/afkortingen') 

soup = bs4.BeautifulSoup( html ) # parse the webpage into something we can query
for tr in soup.select('table#afkortingen tbody tr'):
    #print(tr)
    tds = tr.findAll('td')

    text = '%s (%s)'%(tds[0].text.strip(), tds[1].text.strip())  # pretend we don't know this is good data and just put it next to each other

    found = False
    for ab, words in wetsuite.phrases.abbreviations.find_abbrevs( text ):
        print( 'FOUND  %s = %s'%( ab, words ) )
        found = True

    # Things we didn't find - more creative things that we _might_ want to consider
    if '(' in text and not found:    # (assuming bracket indicates there is an explained abbreviation in that link text)
        print( "MISS  ", text )
# Out:
# FOUND  AA = ['Ars', 'Aequi']
# FOUND  AA = ['Accountant', 'Administratieconsulent']
# FOUND  AA = ['Advertising', 'Association']
# MISS   a.a. (ad acta, bij de akten (wegleggen))
# FOUND  AAA = ['American', 'Arbitration', 'Association']
# MISS   AAC (Advies- en Arbitragecommissie)
# MISS   AAf (Algemeen Arbeidsongeschiktheidsfonds)
# MISS   AAR (Algemeen ambtenarenreglement)
# MISS   AAR (Algemene Aanwijzingen voor de Rijksdienst)
# FOUND  AAV = ['Algemene', 'administratieve', 'voorschriften']
# MISS   AAW (Algemene Arbeidsongeschiktheidswet)
# FOUND  AB = ['Administratiefrechterlijke', 'Beslissingen']
# MISS   AB (Administratieve en Rechterlijke Beslissingen)
# MISS   AB (Nederlandse Jurisprudentie Administratiefrechtelijke Beslissingen (sinds 1971))
# MISS   AB (Wet Algemene Bepalingen)
# FOUND  ABA = ['American', 'Bar', 'Association']
# MISS   ABAR (Algemene bepalingen van administratief recht)
# MISS   abbb (algemene beginselen van behoorlijk bestuur)
# FOUND  ABP = ['Algemeen', 'Burgerlijk', 'Pensioenfonds']
# MISS   ABRS (Afdeling bestuursrechtspraak van de Raad van State)
# MISS   Abs. (Absatz)
# MISS   ABV (Algemene Bankvoorwaarden)
# FOUND  AC = ['Appeal', 'Cases']
# MISS   ACD (Arbeidscomplexendocumentatie)
# MISS   A.C.O.P. (Algemene Centrale van Overheidspersoneel)
# MISS   Acv (Adviescommissie voor vreemdelingenzaken)
# MISS   ACWW (Adviescommissie Warenwet)
# FOUND  ADN = ['Assurantie', 'Data', 'Netwerk']
# FOUND  ADR = ['Alternative', 'Dispute', 'Resolution']
# MISS   ADV (Arbeidsduurverkorting)
# MISS   ADV (Automatische Datenverarbeitung)
# MISS   adv. (advocaat)
# MISS   Adv. (Advies)
# MISS   Adv.bl. (Advocatenblad)
# MISS   Adv. (RvS Advies van de Raad van State)
# MISS   Advw (Advocatenwet)
# MISS   afb. (afbeelding)
# MISS   Afd. (Afdeling)
# MISS   AbRvS (Afdeling Bestuursrechtspraak van de Raad van State)
# MISS   afk. (afkorting(en))
# MISS   AG (Ambtenarengerecht)
# MISS   A-G (Advocaat-Generaal)
# FOUND  AG = ['Advocaat', 'Generaal']
# MISS   A.G. (Aktiengesellschaft (Duitse naamloze vennootschap))
# MISS   AGB (Allgemeine Geschäftsbedingungen (Gesetz))
# MISS   AGBG (Gesetz zur Regelung des Rechts der allgemeinen Geschäftsbedingungen)
# MISS   AGRS (Afdeling voor de geschillen van bestuur van de Raad van State)
# MISS   AG (RvS Afdeling voor de geschillen van bestuur van de Raad van State)
# MISS   AGvB (Afdeling Geschillen van bestuur Raad van State)
# MISS   a.h.v. (algemene handelsvoorwaarden)
# FOUND  a.h.w. = ['als', 'het', 'ware']
# MISS   a.i. (ad interim, voorlopig, waarnemend)
# FOUND  AIB = ['Arbitrage', 'Instituut', 'Bouwkunst']
# MISS   AID (Algemene Inspectiedienst)
# MISS   AJCL (American Journal of Comparative Law)
# MISS   AJIL (American Journal of International Law)
# MISS   AK (Administratiekantoor)
# MISS   AK (Asser Instituut Kaartsysteem internationaal privaatrecht)
# FOUND  a.k.g. = ['arbitraal', 'kort', 'geding']
# MISS   AKO (Algemene Kredietovereenkomst)
# MISS   AktG (Aktiengesetz)
# MISS   Akv (Antwoord kamervragen)
# MISS   AKW (Algemene Kinderbijslagwet)
# MISS   al. (alinea)
# MISS   Awbi (Algemene wet op het binnentreden)
# MISS   All LR (All England Law Reports)
# FOUND  ALR = ['American', 'Law', 'Reports']
# MISS   AMAR (Algemeen militair ambtenarenreglement)
# MISS   AMBH (Algemene Bepalingen MilieuhygiÎne)
# MISS   Ambts. CvK (Ambtsinstructie commissaris van de Koning)
# FOUND  AMC = ['American', 'Maritime', 'Cases']
# MISS   Amend. (Amendement)
# MISS   AMI (Informatierecht/AMI, Tijdschrift voor auteurs- en mediarecht(tot 1986: AMR))
# MISS   AMR (Auteursrecht, Tijdschrift voor auteurs- en mediarecht(tot 1982: Auteursrecht))
# FOUND  AMvB = ['Algemene', 'Maatregel', 'van', 'Bestuur']
# MISS   amvrb (algemene maatregel van rijksbestuur)
# MISS   Anh. (Anhang)
# MISS   Anm. (Anmerkung)
# MISS   anon. (anoniem)
# FOUND  ANP = ['Algemeen', 'Nederlands', 'Persbureau']
# MISS   Aof (Arbeidsongeschiktheidsfonds)
# MISS   AOW (Algemene Ouderdomswet)
# FOUND  AP = ['Aanvullend', 'protocol']
# MISS   app. (appellant)
# MISS   app. (appendix)
# MISS   A.P.O. (Arbeidsplaatsenovereenkomst)
# FOUND  APR = ['Algemene', 'practische', 'rechtsverzameling']
# FOUND  APV = ['Algemene', 'Plaatselijke', 'Verordening']
# FOUND  A.R. = ['Algemene', 'Raad']
# MISS   ARAK (Automatisering Ruilverkavelingsadministratie Kadaster)
# MISS   ARAR (Algemeen Rijksambtenarenreglement)
# FOUND  ARB = ['Administratief', 'rechterlijke', 'beslissingen']
# MISS   ARB ((Wet) Administratieve rechtspraak belastingzaken)
# MISS   ARB (Administratieve en Rechterlijke Beslissingen betreffende het openbaar bestuur in Ned)
# MISS   ARBO ((Wet) Administratieve rechtspraak bedrijfsorganisatie)
# MISS   Arbo (Wet Administratieve rechtspraak bedrijfsorganisatie)
# MISS   Arbowet (Arbeidsomstandighedenwet. Wet van 1980, S. 664)
# MISS   Arbvowet (Arbeidsvoorzieningswet)
# MISS   Arbw (Arbeidswet 1919)
# MISS   A/Res (Resolutie van de Algemene Vergadering van de Verenigde Naties)
# MISS   Arhi (Wet algemene regels herindeling)
# MISS   AROB ((Wet) Administratieve rechtspraak overheidsbeschikkingen)
# FOUND  ARRvS = ['Afdeling', 'Rechtspraak', 'Raad', 'van', 'State']
# MISS   arr. (arrondissement)
# MISS   ARSG (Ambtenarenreglement Staten-Generaal)
# MISS   art. (artikel)
# MISS   Art(t) (Artikel(en))
# MISS   ARV (Algemeen Reglement Vervoer (Spoorwegen))
# MISS   a.s. (aanstaande)
# FOUND  ASAS = ['Amsterdam', 'Security', 'Account', 'System']
# MISS   ASB ((afdeling) Arbeidsvoorwaarden en Sociaal Beleid)
# MISS   AtomG (Atomgesetz)
# MISS   ATOR (Automatisering Toedelingsontwerp Ruilverkavelingen)
# MISS   A.T.V. (Arbeidstijdverkorting)
# MISS   ATw (Algemene Termijnenwet)
# MISS   a.u.b. (alstublieft)
# MISS   aut.bel (auteursrechtbelangen)
# MISS   Aut.w. (Auteurswet 1912)
# MISS   AV ((directie) Arbeidsvoorwaarden)
# FOUND  av = ['algemene', 'vergadering']
# FOUND  a.v. = ['algemene', 'voorschriften']
# MISS   A&V (Aansprakelijkheid en verzekering)
# MISS   A en V (Tijdschrift voor aansprakelijkheid en verzekering)
# MISS   AVA (Algemene vergadering van aandeelhouders)
# MISS   AvA (Algemene vergadering van aandeelhouders)
# FOUND  avas = ['afwezigheid', 'van', 'alle', 'schuld']
# MISS   AVB (Aansprakelijkheidsverzekering Bedrijven)
# FOUND  AvB = ['Afdeling', 'van', 'Beroep']
# MISS   AVBB (Algemeen Verbond Bouwbedrijf)
# MISS   AVKA (Algemene Voorwaarden uitvoering Kleine Aannemingen in het bouwbedrijf 1979)
# MISS   AVP (Aansprakelijkheidsverzekering Particulieren)
# MISS   AVP (Algemene Voorwaarden van Postbank N.V.)
# MISS   AVV (algemeen-verbindendverklaring)
# FOUND  avv = ['Algemeen', 'verbindend', 'voorschrift']
# FOUND  A.v.v.a. = ['Algemene', 'vergadering', 'van', 'aandeelhouders']
# MISS   AVW (Algemene Voorwaarden voor de uitvoering van Werken)
# MISS   AW (Afvalstoffenwet)
# MISS   Aw (Ambtenarenwet 1929)
# MISS   Aw (Auteurswet 1912)
# FOUND  a.w. = ['aangehaald', 'werk']
# MISS   Awb (Algemene wet bestuursrecht. Wet van 4 juni 1992, S. 315)
# MISS   Awbi (Algemene wet op het binnentreden)
# FOUND  AWBZ = ['Algemene', 'Wet', 'Bijzondere', 'Ziektekosten']
# MISS   AWD (Algemene Wet inzake Douane en Accijnzen)
# MISS   AWDA (Algemene Wet inzake Douane en Accijnzen)
# FOUND  AWGB = ['Algemene', 'Wet', 'Gelijke', 'Behandeling']
# MISS   AWR (Algemene Wet inzake Rijksbelastingen)
# MISS   AWT (Aanwijzingen voor de wetgevingstechniek)
# MISS   AWW (Algemene Wet Weduwen en Wezen)
# MISS   AWW (Algemene Werkloosheidswet bedrijfsvereniging)
# FOUND  AZH = ['Ambtenarenreglement', 'Zuid', 'Holland']
# FOUND  b.a. = ['boven', 'aangehaald']
# FOUND  B.A. = ['beperkte', 'aansprakelijkheid']
# MISS   BAB ((Wet) Beroep administratieve beschikkingen)
# FOUND  b.a.b. = ['beroep', 'adminstratieve', 'beschikkingen']
# MISS   BABW (Besluit administratieve bepalingen inzake het wegverkeer)
# FOUND  BAC = ['Besluit', 'Adviescommissie', 'consumentenkrediet']
# FOUND  BACA = ['Besluit', 'aanwijzing', 'chemische', 'afvalstoffen']
# MISS   BAG (Bundesarbeitsgericht)
# FOUND  BAGA = ['Besluit', 'aanwijzing', 'gevaarlijke', 'afvalstoffen']
# FOUND  BARP = ['Besluit', 'algemene', 'rechtspositie', 'politie']
# FOUND  BART = ['Besluit', 'Algemene', 'Richtlijnen', 'Telecommunicatie']
# MISS   b.a.s. (besluit van algemene strekking)
# MISS   BauR (BauRecht)
# MISS   BAW (Besluit aanbesteding van werken 1973)
# MISS   BayObLG (Bayerisches Oberstes Landesgericht)
# MISS   BB (Beslissingen in Belastingzaken)
# FOUND  BB = ['Binnenlands', 'Bestuur']
# MISS   BB (Bankbetrieb)
# FOUND  BBA = ['Buitengewoon', 'Besluit', 'Arbeidsverhoudingen']
# MISS   BBBG (Wet buitengewone bevoegdheden burgerlijk gezag. Wet van 23 juni 1952, S. 361)
# MISS   BBABS (Besluit Bijzondere akten van de Burgerlijke Stand)
# FOUND  BBED = ['Besluit', 'Berechting', 'Economische', 'Delicten']
# FOUND  BBH = ['Besluit', 'bijzondere', 'huurprijzen']
# MISS   BBI (Besluit beleggingsinstellingen)
# FOUND  BBP = ['Besluit', 'bezoldiging', 'politie']
# MISS   BBRA (Bezoldigingsbesluit burgerlijke rijksambtenaren)
# FOUND  BBS = ['Besluit', 'Burgerlijke', 'Stand']
# FOUND  BBW = ['Belgisch', 'Burgerlijk', 'Wetboek']
# FOUND  BC = ['Berner', 'Conventie']
# MISS   BC (Beroepscommissie (van de CRS))
# MISS   BE (Bank- en effectenbedrijf)
# MISS   B&E (Bank- en Effectenbedrijf)
# MISS   Bedr.org. (Wet op de bedrijfsorganisatie)
# MISS   Beg.wet (Beginselenwet Gevangeniswezen)
# MISS   bekn. (beknopt)
# MISS   beleidsreg. (beleidsregel)
# MISS   Belg. (WvK Belgisch Wetboek van Koophandel)
# MISS   Bel.w. (Verord. Belemmeringenwet Verordeningen)
# MISS   BenGH (Benelux-Gerechtshof)
# MISS   BenGH-reglement (Reglement op de procesvoering van het Benelux-Gerechtshof)
# MISS   BenGH-Verdrag (Verdrag betreffende de oprichting en het statuut van een Benelux-Gerechtshof)
# MISS   ber.cie (beroepscommissie)
# MISS   Bern. Conv. (Berner Conventie voor de bescherming van letterkunde en kunst)
# MISS   Ber.w. (Beroepswet)
# MISS   Besch. (beschikking)
# MISS   Besch. Just. (Aanwijzingsbeschikking hulpofficieren van justitie 1994)
# MISS   besl. (besluit)
# MISS   Besl.alc.ond. (Besluit alcohol onderzoeken)
# MISS   Besl. Div.Bel. (Besluit op de Dividendbelasting 1941)
# MISS   Besl. i.b.g.voorw (Besluit inbeslaggenomen voorwerpen)
# MISS   Besl. IB'41 (Besluit op de Inkomstenbelasting 1941)
# MISS   Besl. oproep (Besluit oproepingen, mededelingen en zendingen verzoekverzschriftprocedure)
# MISS   Besluit Buo (Besluit buitengewoon onderwijs 1967)
# MISS   Besluit v.d.b. (Besluit voorkoming dubbele belasting)
# MISS   Besluit Vpb (Besluit op de Vennootschapsbelasting 1942)
# MISS   Besl. wapensen m. (Besluit wapens en munitie)
# MISS   Besl. WB '40 (Besluit op de Winstbelasting)
# MISS   betr. (betreffend(e))
# FOUND  BEU = ['Benelux', 'Economische', 'Unie']
# MISS   bev. (bevestigend)
# MISS   bew. (bewerker)
# MISS   Bew.V (Verdrag inzake de verkrijging van bewijs in het buitenland in burgerlijke en handelszaken)
# FOUND  BFA = ['British', 'Franchise', 'Association']
# FOUND  bfi = ['bijzondere', 'financiële', 'instelling']
# MISS   BG (Besluit gewetensbezwaren militaire dienst)
# FOUND  BG = ['Beginselenwet', 'gevangeniswezen']
# MISS   BG (Bundesgericht)
# MISS   b.g. (bovengenoemde)
# MISS   BGB (Burgerliches Gesetzbuch (Duitsland))
# FOUND  BGGL = ['Besluit', 'geluidsbelasting', 'grote', 'luchtvaartterreinen']
# MISS   BGH (Benelux-Gerechtshof)
# MISS   BGH (Bundesgerichtshof)
# MISS   BGHR (BGH-Rechtsprechung Strafsachen)
# FOUND  BGKL = ['Besluit', 'geluidsbelasting', 'kleine', 'luchtvaartuigen']
# FOUND  BGSV = ['Besluit', 'geldelijke', 'steun', 'volkshuisvesting']
# MISS   Bgw (Besluit goederenvervoer over de weg)
# MISS   BHAC (Bedrijfshuuradviescommissie)
# MISS   BIB (Bank voor Internationale Betalingen)
# FOUND  BiB = ['Beslissingen', 'in', 'Belastingzaken']
# MISS   BIG (Wet op de Beroepen in de Individuele Gezondheidszorg)
# FOUND  b.i.h. = ['beschrijving', 'in', 'hoofdlijnen']
# MISS   bijl. (bijlage)
# MISS   bijv. (bijvoorbeeld)
# MISS   B.Inl.J.D (Besluit inlichtingen justitiële documentatie)
# MISS   B.Inl.S.Reg. (Besluit inlichtingen strafregisters)
# FOUND  BIO = ['Bijzonder', 'inventariserend', 'onderzoek']
# FOUND  BIV = ['Besluit', 'inbeslaggenomen', 'voorwerpen']
# MISS   BiZa (Ministerie van Binnenlandse Zaken)
# MISS   BK (Beginselenwet voor de Kinderbescherming)
# MISS   BKA (Besluit kredietaanbiedingen)
# MISS   Bkadr 1994 (Besluit kadastraal recht 1994)
# FOUND  Bkb = ['Besluit', 'krediethypotheek', 'bijstand']
# MISS   BKV (Besluit Kredietvergoeding)
# MISS   Blb (Besluit op de lijkbezorging)
# FOUND  BLEU = ['Belgisch', 'Luxemburgse', 'Economische', 'Unie']
# FOUND  BLN = ['Besluit', 'Landelijke', 'Normering']
# MISS   blz. (bladzijde)
# MISS   BMB (Benelux-Merkenbureau)
# FOUND  BMB = ['Besluit', 'meldingplichtige', 'bouwwerken']
# MISS   BMM (Benelux-vereniging van Merken- en Modellen gemachtigden)
# MISS   BMM-Bulletin (Bulletin van de Benelux-vereniging van Merken- en Modellen gemachtigden)
# MISS   BMMB (BMM-Bulletin)
# MISS   BMV (Benelux-Merkenverdrag)
# MISS   BMW (Eenvormige Benelux-wet op de Warenmerken (Benelux- merkenwet))
# MISS   Bmw (Bestrijdingsmiddelenwet (1962))
# MISS   Bmw (Bekendmakingswet)
# FOUND  BNB = ['Beslissingen', 'Nederlandse', 'Belastingrechtspraak']
# MISS   BNB (Beslissingen in belastingzaken)
# MISS   BNLG (Verdrag betreffende instelling en het statuut van een Benelux- Gerechtshof)
# MISS   BNLX merkw. (Eenvormige Beneluxwet op de merken)
# MISS   BNLX (Tek. ofMod. Eenvormige Beneluxwet inzake Tekeningen of Modellen)
# MISS   BNLX uitl. Rh. (Benelux verdrag over uitlevering en rechtshulp in strafzaken)
# MISS   B.N.N. ((Koninklijke) Broederschap der notarissen in Nederland)
# MISS   BO (Wet op de bedrijfsorganisatie)
# MISS   BOB (Besluit openbaarheid van bestuur (Stb. 1979, 590))
# MISS   BOM (Besluit overleg en medezeggenschap politie (1994))
# MISS   BOMV (Besluit oproepingen, mededelingen en zendingen verzoek schriftprocedure)
# MISS   Boom (Besluit kwaliteit en gebruik overige organische afvalstoffen)
# MISS   Boot (Besluit opslaan in ondergrondse tanks)
# MISS   BOPZ (Wet Bijzondere Opnemingen in Psychiatrische Ziekenhuizen. Wet van 29 oktober 1992)
# FOUND  BOT = ['Besluit', 'opgedragen', 'Telecommunicatiediensten']
# MISS   BOW (Boswet)
# FOUND  B.O.Z. = ['Besluit', 'Olieverontreiniging', 'Zeewater']
# FOUND  BP = ['Belemmeringenwet', 'Privaatrecht']
# MISS   BPB (Benelux Publikatieblad)
# MISS   BPK (Besluit periodieke keuring van motorrijtuigen, aanhangwagens en opleggers)
# MISS   BPR (Binnenvaartpolitiereglement)
# MISS   BP-rechten (ex Belemmeringenwet Privaatrecht 1927)
# MISS   BPW (Bedrijfspensioenfondsenwet)
# MISS   B.R. (Bouwrecht (maandblad voor rechtspraak en literatuur op het stuk van bouwrecht))
# MISS   B.R.just.geg. (Besluit registratie justitiële gegevens)
# MISS   BRK (Belastingregeling voor het Koninkrijk)
# MISS   BRO (Besluit op de Ruimtelijke Ordening)
# MISS   Bro 1985 (Besluit op de ruimtelijke ordening 1985)
# MISS   BRV (Belastingen van rechtsverkeer)
# MISS   BRv (Wetboek van burgerlijke rechtsvordering)
# FOUND  BRvC = ['Bijzondere', 'Raad', 'van', 'Cassatie']
# MISS   BS (Bijvoegsel van het Staatsblad)
# MISS   BSB ((Commissie) Bodemsanering in gebruik zijnde bedrijfsterreinen)
# MISS   B. Sr. (Besluit Buitengewoon Strafrecht)
# MISS   B. Stb. (Bijvoegsel tot het Staatsblad)
# MISS   BSW (Binnenschepenwet)
# MISS   Bsw (Boswet)
# FOUND  Bte = ['Besluit', 'toezicht', 'effectenverkeer']
# MISS   BTMB (Benelux-Bureau voor Tekeningen of Modellen)
# MISS   BTMV (Benelux-verdrag inzake Tekeningen of Modellen)
# MISS   BTMW (Benelux Tekeningen en Modellen Wet)
# MISS   BTS (Beneluxverdrag inzake de tenuitvoerlegging van rechterlijke beslissingen in strafzaken)
# FOUND  BUGM = ['Besluit', 'uitvoering', 'gemeentelijk', 'milieubeleid']
# MISS   Bull. Ben. (Bulletin Benelux (Publikatieblad))
# MISS   Bull. EG (Bulletin van de Europese Gemeenschappen)
# FOUND  BUMA = ['Bureau', 'Uitvoering', 'Muziek', 'Auteursrechten']
# MISS   BUPO-verdrag (Internationaal verdrag inzake burgerrechten en politieke rechten)
# MISS   BUV (Benelux Uitleverings- en hulpverdrag)
# MISS   BV (Besloten vennootschap met beperkte aansprakelijkheid)
# FOUND  b.v. = ['besloten', 'vennootschap']
# MISS   b.v. (bijvoorbeeld)
# MISS   B & V (beleidsinformatie en voorlichting)
# MISS   BVA (Besluit vergunningaanvraag)
# FOUND  BVDP = ['Besluit', 'vergoeding', 'dienstreizen', 'politie']
# MISS   B.verg.R.B. (Besluit vergoedingen rechtsbijstand)
# MISS   BVerwG (Bundesverwaltungsgericht)
# MISS   BV i.o. (besloten vennootschap met beperkte aansprakelijkheid in oprichting)
# FOUND  BVVP = ['Besluit', 'vergoeding', 'verplaatsingskosten', 'politie']
# FOUND  BW = ['Burgerlijk', 'Wetboek']
# FOUND  B.W. = ['Burgerlijk', 'Wetboek']
# MISS   Bw (Beroepswet)
# MISS   BW Int. reg. (Burgerlijk Wetboek, Internationale regelingen (ed. S&J))
# MISS   BW-oud (Burgerlijk Wetboek (1838))
# MISS   BWOO (Besluit Werkloosheid onderwijs- en onderzoekpersoneel)
# FOUND  BWS = ['Besluit', 'woninggebonden', 'subsidies']
# MISS   B&W (Burgemeester en Wethouders)
# MISS   BWW (Brandweerwet 1985)
# MISS   bijl. (bijlage)
# MISS   Bijl. (ESH Bijlage Europees Sociaal Handvest)
# MISS   bijv. (bijvoorbeeld)
# MISS   Bz (Besluit bijstandverlening zelfstandigen)
# MISS   B.Z.D.G. (Afdeling Besmettelijke Ziekten, Drankwet en Geneesmiddelen)
# MISS   bzw. (beziehungsweise)
# MISS   C (Conclusies (Rechtspraak van de Week))
# MISS   c. (caput (hoofdstuk))
# MISS   c. (contre)
# MISS   C.A. ((Brits) Cour d'Appèl)
# MISS   C.A. ((met plaatsnaam) (Frans) Cour d'Appèl)
# MISS   CA (U.S.A. evt. met nummer) ((Amerikaans) Court of Appeals (Circuitaanduiding))
# MISS   c.a. (cum annexis (met bijbehoren))
# MISS   ca. (circa)
# MISS   cass. (cassatie)
# MISS   cass.verw. (beroep in cassatie verworpen)
# MISS   Cass. (Cour de Cassation (Hof van verbreking) Brussel)
# MISS   CAO (Collectieve Arbeidsovereenkomst)
# MISS   CBB (College van Beroep voor het bedrijfsleven)
# MISS   CBN (Correspondentieblad Notarissen)
# MISS   CBvB (College van Beroep voor het Bedrijfsleven)
# FOUND  C.C. = ['Code', 'civil']
# MISS   CC (Reclame Code Commissie)
# MISS   C de C (Code de commerce)
# MISS   CCR (Centrale Commissie voor de Rijnvaart)
# MISS   CCS (Centrale commissie voor de statistiek)
# MISS   CD (Collection of Decisions of the European Commission on Hu man Rights)
# FOUND  CdC = ['Cour', 'de', 'Cassation']
# FOUND  CdC = ['Code', 'de', 'Commerce']
# FOUND  CdK = ['Commissaris', 'der', 'Koningin']
# MISS   CDW (Communautair Douanewetboek)
# MISS   CELEX (Communitatis Europaeae Lex (Database EG-wetgeving))
# MISS   cert. (certificaat)
# MISS   c.ex. (cum expensis)
# MISS   cfm (conform, in gelijke zin)
# FOUND  CG = ['Centrale', 'Grondkamer']
# MISS   Ch. ((English Cases in) Chancery)
# MISS   Ch. (Chapter)
# MISS   Ch.App. (Law Reports, Chancery Division, Appeal Cases)
# MISS   Cie. (Commissie)
# MISS   CIER (Centrum voor Intellectueel Eigendomsrecht (RUU))
# MISS   CIMK (Centraal Instituut voor Midden- en Kleinbedrijf)
# MISS   circ. (circulaire)
# MISS   Circ.Z. (Circulaire voor de zeemacht)
# MISS   CISG (United Nations Convention on Contracts for the International Sale of Goods)
# MISS   cit. (citato ((als) aangehaald))
# MISS   cit.loc. (citato loco (op de aangehaalde plaats))
# MISS   CJIB (Centraal Justitieel Incassobureau)
# MISS   c.l. (cum laude, met lof)
# FOUND  CLJ = ['Consumer', 'Law', 'Journal']
# MISS   CLR (Commonwealth Law Reports (Verenigd Koninkrijk))
# FOUND  CMLR = ['Common', 'Market', 'Law', 'Reports']
# MISS   CMLRev (Common Market Law Review)
# MISS   Cmt. (centraal medisch tuchtcollege)
# MISS   c.n. (cum notis, met aantekeningen)
# MISS   Co. (Compagnon/Corporation)
# MISS   Cognoss.v. (Brussels Cognossementsverdrag)
# MISS   COGSA (Carriage of Goods by Sea Act)
# MISS   Coll. v. B. (College van beroep voor het bedrijfsleven)
# MISS   Colp.w. (Colportagewet)
# MISS   COM (Commissie van de Europese Gemeenschappen)
# MISS   Com. Cas. (Commercial Cases)
# MISS   Comm. (commentaire)
# MISS   Common Mkt L. Rev. (Common Market Law Review)
# MISS   Compt.w. (Comptabiliteitswet)
# MISS   conf. (confer, conferatur (men vergelijke))
# MISS   Confl.w. (Wet conflictenrecht inzake ontbinding huwelijk en scheiding van tafel en bed)
# MISS   Confl.w.huwbetr. (Wet conflictenrecht huwelijksbetrekkingen)
# MISS   cons. (considerans)
# MISS   COR (Centrale ondernemingsraad)
# MISS   COVO (Concentratieverordening)
# FOUND  c.p. = ['constitutum', 'possessorium']
# MISS   CPA (Centrale Persoonsadministratie)
# MISS   CP(B) (Code PÈnal (België))
# MISS   CPT (European Committee for the prevention of torture and inhuman or degrading treatment)
# MISS   c.q. (casu quo (respectievelijk))
# MISS   CR (Computerrecht (tijdschrift))
# FOUND  CRI = ['Centrale', 'Recherche', 'Informatiedienst']
# MISS   CrL (Criminal Law Reporter)
# MISS   CRS (Centrale Raad voor Strafrechtstoepassing)
# FOUND  CRvB = ['Centrale', 'Raad', 'van', 'Beroep']
# FOUND  CRvS = ['Centrale', 'Raad', 'voor', 'Strafrechtstoepassing']
# MISS   Cs (Calculatieschema voor advocatendeclaraties)
# MISS   c.s. (cum suis (met de zijnen))
# MISS   c.s.q.n. (conditio sine qua non, voorwaarde zonder welke niet)
# FOUND  CSV = ['Coördinatiewet', 'Sociale', 'Verzekering']
# MISS   Ctsv (College van toezicht sociale verzekeringen)
# MISS   CTW (Commissie voor de toetsing van wetgevingsprojecten)
# MISS   Cur. (curator)
# MISS   curs. (cursivering)
# FOUND  CV = ['Commanditaire', 'Vennootschap']
# MISS   CV (1995 Comptabiliteitsvoorschriften 1995)
# FOUND  c.v.a. = ['certificaat', 'van', 'aandeel']
# FOUND  CvB = ['College', 'van', 'Beroep']
# FOUND  cvb = ['college', 'van', 'bestuur']
# MISS   CvBB (College van Beroep voor het bedrijfsleven)
# FOUND  Cvbs = ['College', 'van', 'beroep', 'studiefinanciering']
# FOUND  CvG = ['Conventie', 'van', 'Genève']
# FOUND  c.v.o. = ['certificaat', 'van', 'obligatie']
# FOUND  CvR = ['Conventie', 'van', 'Rome']
# FOUND  CvT = ['Commissie', 'van', 'Toezicht']
# MISS   CVV (Commissie Vervoervergunningen)
# MISS   CW (Comptabiliteitswet)
# MISS   CwSV (Coördinatiewet Sociale Verzekering)
# MISS   dat. (datum, daterend)
# MISS   d.a.v. (daaraanvolgend)
# FOUND  DB = ['dagelijks', 'bestuur']
# MISS   DB (Douanebesluit)
# FOUND  DB = ['Der', 'Betrieb']
# MISS   DBesch. (Dienstplichtbeschikking)
# MISS   DBesl. (Dienstplichtbesluit)
# FOUND  DCA = ['Dienst', 'Collectieve', 'Arbeidsvoorwaarden']
# MISS   DC, U.S.D.C. (Amerikaans District Court)
# MISS   DD (Delikt en Delinkwent)
# MISS   d.d. (de dato (daterend van, gedagtekend))
# MISS   derg. (dergelijke(n))
# MISS   Deurw. regl. (Deurwaardersreglement. Besluit van 27 december 1960)
# MISS   dez. (dezelfde)
# MISS   D.-G. (Directeur-Generaal)
# MISS   dgl. (dergelijke)
# MISS   DGR (Directoraat-Generaal Rechtspleging (MvJ))
# MISS   DGSM (Directoraat-Generaal Scheepvaart en Maritieme Zaken)
# MISS   DGW (Diergeneesmiddelenwet)
# MISS   dhr. (de heer)
# FOUND  DIA = ['Dienst', 'Inspectie', 'Arbeidsverhoudingen']
# MISS   dir. (directeur)
# MISS   disc. (disconto)
# MISS   disp. (dispositie)
# MISS   diss. (dissertatie)
# MISS   div. (dividend)
# MISS   DIV (Wet op de dividendbelasting)
# MISS   dl(n). (deel (delen))
# MISS   DNB (De Nederlandsche Bank NV)
# MISS   Doc. (Document)
# MISS   d.o.v. (daaropvolgend)
# FOUND  DP = ['Dienst', 'Persoonsbeveiliging']
# MISS   Dr. (doctor)
# MISS   DR (Deurwaardersreglement)
# MISS   D&R (Decisions and Reports of the European Commission of Human Rights)
# MISS   dr.mr. (doctor in de rechten)
# MISS   DSW (Destructiewet)
# MISS   dt. (debet)
# MISS   dtp. (daar ter plaatse)
# MISS   DW (Douanewet)
# MISS   DW (Dienstplichtwet)
# MISS   DW (Distributiewet 1939)
# MISS   dwz. (dat wil zeggen)
# FOUND  e.a. = ['en', 'andere']
# MISS   E.A. (Edelachtbaar)
# MISS   EAAA (European Association of Advertising Agencies)
# FOUND  EASA = ['European', 'Advertising', 'Standards', 'Alliance']
# FOUND  EAT = ['European', 'Advertising', 'Tripartite']
# FOUND  EBI = ['Extra', 'Beveiligde', 'Inrichting']
# MISS   E.B. tek. mod. (Eenvormige Beneluxwet inzake Tekeningen of Modellen)
# FOUND  EC = ['European', 'Community']
# FOUND  ECB = ['Europese', 'Centrale', 'Bank']
# MISS   ECCP (European Committee on Crime Problems)
# MISS   ECHR (European Convention on Human Rights and Fundamental Freedoms)
# MISS   ECHRA (Publication of the European Court of Human Rights (A serie) judgements and decisions)
# FOUND  ECLR = ['European', 'Competition', 'Law', 'Review']
# MISS   ECOSOC (Economisch en Sociaal ComitÈ Ecosocul Internationaal Verdrag inzake economisc)
# MISS   Ec. Pol.r. (Economische Politierechter)
# FOUND  ECR = ['European', 'Court', 'Reports']
# MISS   ECRE (European Consultation on Refugees & Exiles)
# MISS   ECRM (Europese Commissie voor de Rechten van de Mens)
# MISS   ed. (editor (redacteur))
# MISS   ed. (edition)
# FOUND  e.d. = ['en', 'dergelijke']
# MISS   e.e. (Lat.) (erro're excep'to, behoudens vergissingen)
# MISS   eds. (editors)
# FOUND  e.e.a. = ['een', 'en', 'ander']
# FOUND  EEG = ['Europese', 'Economische', 'Gemeenschap']
# MISS   EEG Verb.V. (Verdrag inzake het recht dat van toepassing is op verbintenissen uit overeenkomst)
# MISS   EEG-Verdrag (Verdrag tot oprichting van de EEG, Trb 1957,91)
# FOUND  EER = ['Europese', 'Economische', 'Ruimte']
# MISS   EESV (Europees Economisch Samenwerkingsverband)
# MISS   EEV (EEG-Verbintenissenverdrag)
# MISS   EEX (EEG-Executieverdrag)
# MISS   EEX San S. (Europees Executieverdrag (Donostia-San Sebastian))
# FOUND  EFF = ['European', 'Franchise', 'Federation']
# MISS   EFMS (Europees Fonds voor Monetaire Samenwerking)
# FOUND  EFSL = ['European', 'Financial', 'Services', 'Law']
# MISS   EFTA (European Free Trade Association (= EVA))
# FOUND  EG = ['Europese', 'Gemeenschappen']
# MISS   e.g. (exempli gratia (bij voorbeeld))
# MISS   EGA (Europese Gemeenschap voor Atoomenergie (Euratom))
# MISS   EGKS (Europese Gemeenschap voor Kolen en Staal EGTUL Verdrag tussen de Lid-Staten van de EU)
# MISS   EHJ (Europees Hof van Justitie)
# MISS   EHRM (Europees Hof voor de rechten van de mens)
# FOUND  EHRR = ['European', 'Human', 'Rights', 'Reports']
# MISS   EIB (Europese Investeringsbank)
# MISS   eig. (eigenlijk)
# MISS   EIM (Economisch Instituut voor het Midden- en Kleinbedrijf)
# MISS   EIM (EIM-mededelingen)
# FOUND  EIPR = ['European', 'Intellectual', 'Property', 'Review']
# MISS   EK (Eerste Kamer der Staten-Generaal)
# FOUND  ELR = ['European', 'Law', 'Review']
# FOUND  e.m.a. = ['en', 'meer', 'anderen']
# FOUND  EMF = ['Europees', 'Monetair', 'Fonds']
# FOUND  EMI = ['Europees', 'Monetair', 'Instituut']
# FOUND  EMO = ['Europese', 'Monetaire', 'Overeenkomst']
# FOUND  EMS = ['Europees', 'Monetair', 'Stelsel']
# MISS   EMU (Europese Economische en Monetaire Unie)
# MISS   e.n.a.c. (Exceptio non adimpleti contractus, verweer van niet vervuld contract; exceptie waarm)
# MISS   enz. (enzovoort)
# MISS   e.o. (Lat.) (ex offi'cio, ambtshalve)
# MISS   EOB (Europees Octrooibureau)
# MISS   EOO (Europese Octrooiorganisatie)
# MISS   EOV (Europees Octrooiverdrag)
# FOUND  EPC = ['European', 'Patent', 'Convention']
# MISS   EPO (European Patent Office (Europees Octrooibureau))
# MISS   E.Pol.R (Economische politierechter)
# MISS   EPR (Economische politierechter)
# FOUND  EPS = ['Europese', 'Politieke', 'Samenwerking']
# FOUND  EPU = ['Europese', 'Politieke', 'Unie']
# FOUND  ER = ['Europese', 'Regels']
# FOUND  ER = ['English', 'Reports']
# MISS   ERE (Europese rekeneenheid)
# MISS   erecode (Europese Erecode inzake Franchising)
# MISS   E/Res (Resolutie van de ECOSOC)
# MISS   ERV (Europees Verdrag aangaande wederzijdse Rechtshulp in straf zaken)
# FOUND  ESB = ['Economisch', 'Statistische', 'Berichten']
# MISS   ESC (Economisch en Sociaal ComitÈ)
# FOUND  ESC = ['European', 'Social', 'Charter']
# FOUND  ESC = ['European', 'Shippers', 'Council']
# MISS   ESCB (Europees Stelsel van Centrale Banken)
# FOUND  ESF = ['Europees', 'Sociaal', 'Fonds']
# FOUND  ESH = ['Europees', 'Sociaal', 'Handvest']
# MISS   ESOCUL (Internationaal Verdrag inzake Economische, Sociale en Culturele Rechten)
# MISS   E.S.R.A. (Economische en Sociale Raad van Advies)
# MISS   et al. (et alii (en anderen))
# MISS   etc. (Lat.) (et cetera)
# FOUND  ETL = ['European', 'Transport', 'Law']
# FOUND  ETS = ['European', 'Treaty', 'Series']
# FOUND  ETSI = ['Europees', 'Telecommunicatie', 'Standaardisatie', 'Instituut']
# MISS   etq. (e tutti quanti (enzovoorts))
# MISS   ETV (Europees Verdrag tot bestrijding van Terrorisme)
# FOUND  EU = ['Europese', 'Unie']
# MISS   Eur. T.S. (European Treaty Series)
# MISS   EUV (Europees Verdrag betreffende uitlevering)
# MISS   EV (Europees Verdrag tot bescherming van de rechten van de mens en de fundamentele vrijh)
# MISS   ev. (eventueel)
# FOUND  e.v. = ['en', 'volgende']
# FOUND  e.v.a. = ['en', 'vele', 'anderen']
# MISS   EVA (Europese Vrijhandelsassociatie)
# FOUND  EVB = ['Editie', 'Vakstudie', 'Belastingwetgeving']
# MISS   EVEX (Verdrag betreffende de rechterlijke bevoegdheid)
# MISS   EVIG (Europees Verdrag inzake de internationale geldigheid van strafvonnissen EVO EEG-Verd)
# MISS   EVO (Algemene Verladers en Eigen Vervoer Organisatie)
# MISS   EVR (Europees Vervoersrecht)
# MISS   EV (rechtsh. Europees verdrag wederzijdse rechtshulp in strafzaken)
# MISS   EVRM (Europees Verdrag tot bescherming van de rechten van de mens en de fundamentele vrijheden)
# MISS   evt. (eventueel)
# MISS   EV uitl. (Europees uitleveringsverdrag)
# MISS   e.w. (en wel, namelijk)
# MISS   EW (Electriciteitswet)
# MISS   ex (uit, op grond van)
# MISS   ex. (exemplaar)
# MISS   Ex (Exchequer)
# MISS   Exec. (Executive Document)
# MISS   EZ ((Ministerie van) Economische Zaken)
# MISS   F (Faillissementswet)
# MISS   f. (folio ((op ) blad))
# MISS   fa. (firma)
# MISS   FAR ((afdeling) Financiële Arbeidsvoorwaarden Rijkspersoneel)
# MISS   FBV (Federatie van bedrijfsverenigingen)
# MISS   FD (Het Financieele Dagblad)
# MISS   FED (Losbladig fiscaal weekblad FED)
# MISS   Fed. (Case Federal Cases)
# FOUND  FEM = ['Financieel', 'Economisch', 'Magazine']
# MISS   FENEX (Federatie van Nederlandse Expediteurs-Organisaties)
# MISS   FENIT (Federatie van Nederlandse Brancheverenigingen voor Informatietechnologie)
# MISS   ffp's (frequent flyer programs)
# MISS   Ffw (Flora- en Faunawet)
# MISS   fg. (Fungerend)
# MISS   fig. (figuur, figuurlijk)
# MISS   Fin. Verh.w. (Financiële Verhoudingswet 1984)
# MISS   FIO (Free in and Out)
# MISS   FIOD (Fiscale Inlichtingen en Opsporingsdienst)
# MISS   FJR (Tijdschrift voor Familie-en Jeugdrecht)
# MISS   fol. (folio ((op ) blad))
# MISS   Form (Formulier)
# MISS   f.r. (franco)
# FOUND  F.R.D. = ['Federal', 'Rules', 'Decisions']
# FOUND  FTA = ['Financiële', 'Termijnmarkt', 'Amsterdam']
# MISS   fr. (franko)
# FOUND  Fun = ['Financiering', 'uitvoering', 'NMP']
# MISS   FUSW (Fusiewet)
# MISS   Fw. (Faillissementswet)
# MISS   FW (Faillissementswet)
# MISS   Fwbl (Fiscaal weekblad)
# MISS   G (Grondwet)
# FOUND  g.a. = ['gedeeltelijke', 'aansprakelijkheid']
# FOUND  g.a. = ['gewijzigde', 'aansprakelijkheid']
# MISS   GATT (General Agreement on Tariffs and Trade)
# FOUND  g.a.v. = ['gaarne', 'antwoord', 'verwacht']
# MISS   Gb (Gouvernementsblad)
# MISS   GBA (Gemeentelijke Basisadministratie persoonsgegevens)
# MISS   GBMV (Wet gelijke behandeling van mannen en vrouwen)
# MISS   GBOD (Wet gelijke behandeling van mannen en vrouwen in de burgerlijke openbare dienst)
# MISS   GBR (Gedrags- en beroepsregels (van de Registeraccountants))
# MISS   GCB (Geschillencommissie Bankzaken)
# MISS   GCP (Geschillencommssie bankzaken Postbank)
# MISS   GCV (Gemeentelijke comptabiliteitsvoorschriften)
# MISS   GCV 1982 (Besluit gemeentelijke comptabiliteitsvoorschriften uit 1982)
# MISS   GDW (De Gerechtsdeurwaarder)
# MISS   Ged. St. (Gedeputeerde Staten)
# MISS   Gedr.St. (Gedrukte Stukken)
# MISS   geh. (gehuwd)
# MISS   Gem. Comm. (Gemeenschappelijk Commentaar der Regeringen)
# MISS   Gem. MvT (Gemeenschappelijke Memorie van Toelichting)
# MISS   GemOR (Gemeenschappelijke ondernemingsraad)
# MISS   Gem.st (De Gemeentestem)
# MISS   Gem.w. (Gemeentewet.)
# MISS   Ger. EG (Gerecht van eerste aanleg van de Europese Gemeenschappen)
# MISS   gereq. (gerequireerd)
# MISS   Ger.W (Gerechtelijk Wetboek)
# MISS   gesch. (gescheiden)
# MISS   getr. (getreden)
# MISS   Gev. maatr. (Gevangenismaatregel)
# MISS   gew. (gewijzigd)
# MISS   gew.erecode (Europese Erecode inzake Franchising (ontwerp), 1 augustus 1990, EFF)
# MISS   GG (Grundgesetz)
# MISS   GHV (Grote handelsvaart)
# MISS   Gib (Gemeenschappelijk instituut van bedrijfsverenigingen)
# MISS   Gir.eff.verk. (Wet giraal effectenverkeer)
# MISS   GIW (Stichting Garantie-Instituut Woningbouw)
# MISS   Gk. (Grondkamer)
# FOUND  GKvB = ['Grote', 'Kamer', 'van', 'beroep']
# FOUND  GO = ['Gewijzigd', 'Ontwerp']
# FOUND  G.O. = ['Georganiseerd', 'Overleg']
# MISS   GOA (Gemeenschappelijke Opleidingsactiviteiten)
# MISS   g.ont.w. (gewijzigd ontwerp van wet)
# MISS   GOR (Groepsondernemingsraad)
# MISS   G.P. (gemeentepolitie)
# MISS   Grat.w. (Gratiewet)
# MISS   GRUR (Gewerblicher Rechtsschutz und Urheberrecht)
# MISS   Grw. (Grondwet)
# MISS   GS (de Gemeentestem)
# FOUND  GS = ['Gedeputeerde', 'Staten']
# MISS   GschG (Gewässerschutsgesetz)
# MISS   GSG (Gewässerschutsgesetz)
# FOUND  G.t. = ['Geldende', 'tekst']
# FOUND  GV = ['Gids', 'Vreemdelingenrecht']
# MISS   GVG (Gerichtsverfassungsgesetz)
# MISS   GVO (Gerechtelijk vooronderzoek)
# FOUND  GvR = ['Genootschap', 'voor', 'Reclame']
# MISS   Gw. (Grondwet)
# FOUND  GW = ['Gewijzigd', 'Wetsontwerp']
# MISS   Gwd (Gezondheids- en welzijnswet voor dieren)
# MISS   Gww (Grondwaterwet)
# MISS   H. (hoofdstuk)
# FOUND  HA = ['Hof', 'Arnhem']
# MISS   Hand. (Handelingen)
# MISS   Hand. II (Handelingen (der Tweede Kamer))
# MISS   Handelingen I (Handelingen van de Eerste Kamer der Staten-Generaal)
# MISS   Handelingen II (Handelingen van de Tweede Kamer der Staten-Generaal)
# MISS   Handelsn.w. (Handelsnaamwet. Wet van 5 juli 1921)
# MISS   Handelsreg.w. (Handelsregisterwet. Wet van 26 juli 1918)
# MISS   Harv.L.Rev. (Harvard Law Review)
# MISS   HB (Huisvestingsbesluit)
# MISS   Hc. (Wet op de huurcommissies)
# FOUND  HCA = ['Heffingenbesluit', 'Chemische', 'Afvalstoffen']
# MISS   HGB (Handelsgesetzbuch)
# MISS   Hgrw. (Handelsregisterwet)
# MISS   HID (Hoofdingenieur-Directeur)
# MISS   HL (House of Lords)
# FOUND  HMG = ['Hoog', 'Militair', 'Gerechtshof']
# FOUND  HNJV = ['Handelingen', 'Nederlandse', 'Juristen', 'Vereniging']
# MISS   HNW (Handelsnaamwet)
# MISS   Hof (Gerechtshof)
# MISS   Hof (Arnhem Pachtkamer van het gerechtshof te Arnhem)
# MISS   Hof (EG Hof van Justitie der Europese Gemeenschappen)
# MISS   Hooggel. (Hooggeleerde)
# MISS   Hoogl. (Hoogleraar)
# MISS   HOvJ (Hulpofficier van Justitie)
# MISS   HPBP (Handboek privacybescherming persoonsbescherming)
# MISS   Hpw. (Huurprijzenwet woonruimte)
# FOUND  HR = ['Hoge', 'Raad']
# MISS   h.r.(voor de h.v.b.'s) (huishoudelijk reglement (voor de huizen van bewaring))
# MISS   Hrgw (Handelsregisterwet)
# FOUND  HRLJ = ['Human', 'Rights', 'Law', 'Journal']
# MISS   HRW (Handelsregisterwet)
# MISS   HSL (Hogesnelheidslijn)
# MISS   hst. (hoofdstuk)
# FOUND  HTK = ['Handelingen', 'Tweede', 'Kamer']
# MISS   Huisv.w (Huisvestingswet)
# MISS   Hup (Hinderwet-uitvoeringsprogramma)
# MISS   Huurk.onr.z. (Tijdelijke wet huurkoop onroerende zaken)
# MISS   Huurpr.w. (Huurprijzenwet woonruimte. Wet van 18 januari 1979)
# MISS   Huurw. (Huurwet. Wet van 13 oktober 1950)
# MISS   HVB (Huisvestingsbesluit)
# FOUND  HvB = ['Hof', 'van', 'Beroep']
# FOUND  HvD = ['Hof', 'van', 'Discipline']
# MISS   HvJ (Hof van Justitie (EG))
# MISS   HvJEG (Hof van Justitie van de Europese Gemeenschappen)
# MISS   HVV (Haags Verkeersongevallenverdrag)
# MISS   HV.VN. (Handvest van de Verenigde Naties)
# MISS   HvW (Huisvestingswet)
# MISS   HW (Huisvestingswet)
# MISS   Hw. (Huurwet)
# MISS   Hw (Hinderwet)
# MISS   Hyp. (W. Hypotheekwet (België))
# FOUND  IAA = ['International', 'Advertising', 'Association']
# MISS   IACHR (Inter-American Commission on Human Rights)
# MISS   IAO (Internationale Arbeidsorganisatie)
# FOUND  IAS = ['International', 'Accounting', 'Standards']
# MISS   IB (Wet op de Inkomstenbelasting 1964)
# MISS   Ib (Inkwartieringsbesluit)
# MISS   ib. (ibidem, op dezelfde bladzijde)
# MISS   ibid. (ibidem, op dezelfde bladzijde)
# MISS   IBS (Interimwet Bodemsanering)
# MISS   I.B.S. (Inbewaringstelling)
# MISS   IBTW (Inkomensbesluit Toeslagenwet)
# MISS   i.c. (in casu (in dit geval))
# MISS   icbe (Instelling voor collectieve belegging in effecten)
# MISS   ICC (Interdepartementale Commissie voor Consumentenaangelegen heden)
# MISS   ICC (International Chamber of Commerce (Parijs))
# MISS   ICCA (International Council for Commercial Arbitration)
# MISS   ICJ (International Court of Justice)
# MISS   ICJ (International Commission of Jurists)
# MISS   ICLQ (International and Comparative Law Quarterly)
# MISS   ICPC (International Classification of Primary Care)
# FOUND  ICR = ['Industrial', 'Cases', 'Reports']
# MISS   ICSID (International Centre for Settlement of Investment Disputes)
# MISS   id. (idem (hetzelfde))
# MISS   IE (De Industriële Eigendom)
# MISS   i.e. (id est (dat wil zeggen))
# MISS   IELL (The International encyclopaedia for labour law and industrial relations)
# MISS   IER (Intellectuele Eigendom en Reclamerecht)
# MISS   IER (Industriële en Intellectuele Eigendom)
# MISS   i.e.-rechten (intellectuele eigendomsrechten)
# FOUND  IFA = ['International', 'Franchise', 'Association']
# FOUND  IFC = ['International', 'Finance', 'Corporation']
# MISS   IFJ (International Federation of journalists)
# MISS   IGC (Intergouvernementele Conferentie)
# MISS   IGH (Internationaal Gerechtshof)
# FOUND  i.g.v. = ['in', 'geval', 'van']
# FOUND  i.h. = ['in', 'handen']
# FOUND  i.h.a. = ['in', 'het', 'algemeen']
# FOUND  i.h.b. = ['in', 'het', 'bijzonder']
# FOUND  II = ['Instructie', 'Invordering']
# MISS   I&I (Informatie & informatiebeleid)
# MISS   IIV (Instructie Informatievoorziening)
# MISS   IKadw (Invoeringswet Kadasterwet)
# MISS   IKK (Internationale Kamer van Koophandel)
# FOUND  ILA = ['International', 'Law', 'Association']
# FOUND  ILC = ['International', 'Labour', 'Conference']
# FOUND  ILC = ['International', 'Law', 'Commission']
# MISS   ill. (illustratie)
# FOUND  ILM = ['International', 'Legal', 'Materials']
# MISS   ILO (International Labour Organization (= IAO))
# MISS   ILPZ (Wet interne lastenverevening particuliere ziektekostenverzekeringsbedrijf)
# FOUND  IMF = ['Internationaal', 'Monetair', 'Fonds']
# FOUND  INBW = ['Invoeringswet', 'Nieuw', 'Burgerlijk', 'Wetboek']
# MISS   inc. (incorporation)
# MISS   incl. (inclusief)
# MISS   Ind. Prop. (Industrial Property)
# MISS   inf. (infra (beneden, verder in het boek))
# MISS   ing. (ingenieur)
# MISS   INK (Wet op de inkomensbelasting)
# MISS   Int'l & Comp.L.Q. (International and Comparative Law Quarterly)
# MISS   Int'l Leg. Mat. (International Legal Materials)
# MISS   Int. rechtsh.strafz (Internationale rechtshulp in strafzaken (ed. S&J))
# MISS   INV (Invorderingswet 1990)
# MISS   Inv. (Invorderingswet 1990)
# MISS   Inv. (Invoeringswet)
# MISS   Inv. F (Wet ter invoering van de Faillissementswet. Wet van 20 januari 1896)
# MISS   Invord.w.1990 (Invorderingswet 1990)
# MISS   Inv. (Wet Invoeringswet nieuw Burgerlijk Wetboek)
# MISS   Inv.wet (hABW Invoeringswet herinrichting Algemene Bijstandswet)
# MISS   inz. (inzake)
# FOUND  i.o. = ['in', 'oprichting']
# MISS   IOA (Internationale Organisatie voor Atoomenergie)
# MISS   IOAW (Wet inkomensvoorziening oudere en gedeeltelijk arbeidsongeschikte werkloze werknemers)
# FOUND  IOsv = ['Invoeringswet', 'Organisatiewet', 'sociale', 'verzekeringen']
# MISS   IOW (Wetsvoorstel inkomensvoorziening)
# FOUND  IPA = ['International', 'Publishers', 'Association']
# MISS   i.pl.v. (in plaats van)
# MISS   IPO (Interprovinciaal overleg)
# MISS   I.P.O. (Interprovinciaal Overlegorgaan)
# MISS   IPO-RO (Interprovinciaal Overleg Ruimtelijke Ordening)
# MISS   IPPC (Integrated Pollution Prevention and Control)
# MISS   IPR (Internationaal Privaatrecht)
# FOUND  i.p.v. = ['in', 'plaats', 'van']
# MISS   ir. (ingenieur)
# MISS   IR (In Raadkamer (behorende bij de RvdW))
# MISS   ISBN (Internationaal Standaard-Boeknummer)
# MISS   ISDA (International Swaps and Derivatives Association)
# FOUND  i.s.m. = ['in', 'samenwerking', 'met']
# MISS   ISOVSO (Interimwet op het speciaal onderwijs en het voortgezet speciaal onderwijs)
# MISS   IT (Informatietechnologie)
# FOUND  i.t.t. = ['in', 'tegenstelling', 'tot']
# MISS   IUW (In- en uitvoerwet)
# MISS   Ivb (Inrichtingen- en vergunningenbesluit milieubeheer)
# MISS   I/Vb.mb (Inrichtingen- en vergunningenbesluit milieubeheer)
# MISS   IVBP (Internationaal Verdrag inzake Burgerrechten en Politieke rechten)
# MISS   IVBPR (Internationaal Verdrag inzake Burgerrechten en Politieke rechten)
# MISS   IVESCR (Internationaal Verdrag inzake economische, sociale en culturele rechten)
# FOUND  i.v.m. = ['in', 'verband', 'met']
# MISS   IVRK (Internationaal Verdrag voor de Rechten van het Kind)
# MISS   IVS (Invoeringswet stelselherziening sociale zekerheid)
# FOUND  IVVV = ['Internationaal', 'Verbond', 'van', 'Vakverenigingen']
# MISS   IW (Invaliditeitswet)
# MISS   IW (Invorderingswet 1990)
# MISS   Iw (Inkwartieringswet)
# MISS   IWHBO (Invoeringswet WHBO)
# MISS   IWI (Interimwet invaliditeitsrentetrekkers)
# MISS   IWS (Invoeringswet stelselherziening sociale zekerheid)
# MISS   iwtr. (inwerkingtreding)
# MISS   i.w.tr. (in werking treding)
# MISS   IWWO (Invoeringswet WWO)
# MISS   i.z. (inzake)
# MISS   IZA (Interimregeling Ziektekosten Ambtenaren 1982)
# MISS   J. (Jurisprudence)
# MISS   j. (jaar)
# MISS   j∫ (juncto, in verbinding met, samen met)
# MISS   JABW (Jurisprudentie Algemene Bijstandswet en Rijksgroepregelingen)
# MISS   JAR (Jurisprudentie Arbeidsrecht)
# MISS   Jaw (Jachtwet)
# MISS   JB (Jurisprudentie Bestuursrecht, vanaf 1994)
# MISS   Jb (Jurisprudentie bestuursrecht, vanaf 1994)
# MISS   JBL (Journal of Business Law)
# MISS   JBN (Juridische Berichten voor het Notariaat)
# MISS   JBZ (Samenwerking op het gebied van Justitie en Binnenlandse Zaken)
# MISS   Jeugdwerkg.w. (Jeugdwerkgarantiewet. Wet van 29 mei 1991)
# MISS   JG (Jurisprudentie voor Gemeenten)
# MISS   jis./jo. (junctis/juncto (in samenhang met))
# MISS   jl. (jongstleden)
# FOUND  JO = ['Jurisprudentie', 'Onderwijswetten']
# MISS   jo (juncto (in samenhang met, in verband met))
# FOUND  JOR = ['Jurisprudentie', 'Onderneming', 'Recht']
# MISS   jrg. (jaargang)
# FOUND  JSV = ['Jurisprudentie', 'Sociale', 'Voorzieningen']
# MISS   Jur. (Jurisprudentie van het Hof van Justitie der Europese Gemeenschappen)
# MISS   Jura (Juristische Ausbildung)
# MISS   Jur. (Anvers Jurisprudence du port d'Anvers)
# MISS   Jur. (Hof EG Jurisprudentie van het Hof van Justitie der Europese Gemeenschappen)
# MISS   JWG (Jeugdwerkgarantiewet)
# MISS   JWWV/WSW (Jurisprudentie Wet Werkloosheidsvoorzieningen/Wet Sociale Werkvoorzieningen)
# MISS   JZ (Juristenzeitung)
# MISS   K (Wetboek van Koophandel)
# MISS   K (Kamerstuk)
# MISS   k. (kolom)
# MISS   K (II Tweede Kamer)
# MISS   KA-AV 1976 (Koop/aanneming-Algemene Voorwaarden 1976)
# MISS   Kadasterw. (Kadasterwet. Wet van 3 mei 1989)
# MISS   Kadb (Kadasterbesluit)
# MISS   Kador. (Rijksdienst van het Kadaster en de Openbare Registers)
# MISS   Kadr 1994 (Kadasterregeling 1994)
# MISS   Kadw (Kadasterwet)
# FOUND  KB = ['Koninklijk', 'Besluit']
# MISS   Kdw (Kadasterwet)
# MISS   KEW (Kernenergiewet)
# MISS   Kew (Kernenergiewet)
# FOUND  KG = ['Kort', 'Geding']
# MISS   KG (Kammergericht)
# FOUND  K.G. = ['Kort', 'geding']
# FOUND  KGK = ['Kort', 'Geding', 'Kort']
# MISS   Kh. (Rechtbank van Koophandel)
# MISS   Kiesw. (Kieswet)
# MISS   Kind.bes.V. (Kinderbeschermingsverdrag 1961)
# MISS   KKZ (Kinderbijslagwet voor kleine zelfstandigen)
# MISS   KNAW (Koninklijke Nederlandse Academie van Wetenschappen)
# MISS   KNUB (Koninklijke Nederlandse Uitgeversbond)
# MISS   KonsG (Konsulargesetz)
# MISS   KoopV. (Verdrag der Verenigde Naties inzake internationale koopovereenkomst)
# MISS   KOW (Kleuteronderwijswet)
# MISS   KS (Kamerstukken)
# MISS   KSBS 1980 (Kaderegeling steun bedrijven stadsvernieuwing 1980)
# MISS   Kt. (Kanton)
# MISS   Ktg. (Kantongerecht)
# MISS   Ktr. (Kantonrechter)
# MISS   KVE 1991 (Kaderwet Volwasseneneducatie 1991)
# MISS   KVG (Koninklijke Vereniging van Gerechtsdeurwaarders)
# FOUND  Kvk = ['Kamer', 'van', 'Koophandel']
# MISS   K.v.K. (Kamer(s) van Koophandel)
# MISS   K.v.K. en F. (Kamer van Koophandel en Fabrieken)
# MISS   KVV (Kennisgeving van verdere vervolging)
# MISS   KvT (Kamer van Toezicht op de notarissen en candidaat-notarissen)
# MISS   KW (Kieswet)
# MISS   Kw (Kadasterwet)
# MISS   KWL (Kinderbijslagwet voor loontrekkenden)
# MISS   l. (linea (regel))
# MISS   l. (lees)
# FOUND  LAB = ['Legal', 'Advisory', 'Board']
# MISS   LAB 1984 (Leidraad administratieve boeten 1984)
# FOUND  L.B. = ['loco', 'burgermeester']
# MISS   Lbb (Leidraad bodembescherming)
# MISS   LBW (Landbouwwet)
# MISS   l.c. (loco citato (op de eerder aangehaalde plaats))
# MISS   LCCM (Landelijke Coördinatiecommissie Milieuwethandhaving)
# FOUND  LEI = ['Landbouw', 'Economisch', 'Instituut']
# MISS   Leidraad Vpb (Leidraad bij het Besluit op de Vennootschapsbelasting 1942)
# MISS   LG (Landesgericht)
# MISS   l. gew. (laatstelijk gewijzigd)
# FOUND  LGR = ['Local', 'Government', 'Reports']
# FOUND  lis = ['limitatief', 'imperatief', 'stelsel']
# MISS   lit. (literatuur)
# MISS   Liw. (Landinrichtingswet 1985)
# MISS   Liwet (Landinrichtingswet 1985)
# FOUND  l.j. = ['lopend', 'jaar']
# MISS   lk. (linkerkant)
# FOUND  l.k. = ['linker', 'kolom']
# MISS   LKW (Landbouwkwaliteitswet)
# MISS   ll. (laatstleden)
# MISS   LMBK (Landelijk Meerjaren Beleidskader)
# MISS   LMV (leefmilieuverordening)
# MISS   LOR (Landoorlogreglement)
# MISS   losbl. (losbladig(e))
# MISS   LOW (Lager-onderwijswet 1920)
# MISS   LPA (Landelijke Personenadministratie)
# MISS   Ltd. (Limited company (naamloze vennootschap, Engels))
# MISS   LTW (Locaalspoor- en tramwegwet)
# MISS   Luchtv.w. (Luchtvaartwet. Wet van 19 mei 1985)
# MISS   LUVO ((Wet) inzake de luchtverontreiniging)
# MISS   LUW (Landbouwuitvoerwet 1938)
# FOUND  LvA = ['Lijst', 'van', 'Antwoorden']
# MISS   L.V.R. (Luchtvaartreglement)
# FOUND  LvV = ['Lijst', 'van', 'Vragen']
# MISS   LVW (Luchtvaartwet)
# MISS   L.V.W. (Luchtvaartwet)
# FOUND  l.w. = ['let', 'wel']
# MISS   LW (Loodsenwet)
# MISS   LW57 (Loodswet 1957)
# MISS   M. (mijnheer)
# MISS   mand. (mandaat)
# FOUND  Mas = ['Milieu', 'aansprakelijkheidsverzekerings', 'samenwerkingsverband']
# FOUND  m.a.w. = ['met', 'andere', 'woorden']
# MISS   MAW ('31 Militaire Ambtenarenwet 1931)
# MISS   max. (maximaal)
# FOUND  MB = ['Ministeriële', 'Beschikking']
# MISS   MB (Model Bouwverordening van de Vereniging van Nederlandse gemeenten)
# FOUND  Mb = ['Ministerieel', 'besluit']
# FOUND  Mb = ['Ministeriële', 'beschikking']
# FOUND  MBB = ['Maandblad', 'Belasting', 'Beschouwingen']
# MISS   Mbl. Not. (Maandblad voor het Notariaat)
# MISS   MBO (Maatschappij tot Financiering van Bedrijfsobjecten)
# MISS   MBR (Maandblad voor Berechting en Reclassering)
# FOUND  m.b.t. = ['met', 'betrekking', 'tot']
# MISS   MBV (Modelbouwverordening van de VNG)
# MISS   Me. Bo. (Mededelingenblad Bedrijfsorganisatie)
# MISS   Med.bl.Bo. (Mededelingenblad Bedrijfsorganisatie)
# MISS   Med. verslag (Verslag over het mededingingsbeleid)
# MISS   Meetbr.w. (Meetbrievenwet 1981. Wet van 12 februari 1981)
# MISS   MEPC (Marine Environment Protection Committee van de IMO)
# MISS   MER (Milieu-effectrapport)
# MISS   m.e.r. (milieu-effectrapportage)
# MISS   MEV (Model-exploitatieverordening)
# MISS   MEZ (Minister van Economische Zaken)
# MISS   Mf (Mediaforum (tijdschrift))
# MISS   MGS (Wet milieugevaarlijke stoffen)
# FOUND  M.H. = ['Mijne', 'Heren']
# FOUND  m.h.d. = ['met', 'hartelijke', 'dank']
# FOUND  m.i. = ['mijns', 'inziens']
# MISS   Min. Besch. (Ministeriële Beschikking)
# MISS   Min. Besch. (Beschikking van het Comité van Ministers)
# MISS   min. circ. (Ministeriële circulaire)
# MISS   Min.verantw. (Wet op de ministerieële verantwoordelijkheid)
# FOUND  m.k. = ['midden', 'kolom']
# MISS   MKB (Midden- en Kleinbedrijf)
# FOUND  MLAT = ['Mutual', 'Legal', 'Assistance', 'Treaty']
# FOUND  MLR = ['Modern', 'Law', 'Review']
# MISS   m.m. (mutatis mutandis, met de nodige veranderingen)
# MISS   M.M.H.H. (Mijne Heren)
# FOUND  m.m.v. = ['met', 'medewerking', 'van']
# MISS   m.n. (met noot van)
# FOUND  m.n. = ['met', 'name']
# MISS   MN (Maandblad voor het Notariaat)
# MISS   m.nt. (met noot van)
# MISS   MNW (Mijnwet 1903)
# FOUND  m.o. = ['met', 'onderschrift']
# FOUND  MO = ['Mondeling', 'Overleg']
# MISS   MOOZ (Wet medefinanciering oververtegenwoordiging oudere ziekenfondsverzeken)
# MISS   MOT ((Wet) Melding Ongebruikelijke Transacties)
# FOUND  MP = ['Minister', 'President']
# FOUND  MP = ['Ministeriële', 'Publikaties']
# FOUND  MR = ['Ministeriële', 'Regeling']
# MISS   M en R (Tijdschrift voor Milieu en Recht)
# MISS   M & R (Tijdschrift voor Milieu en Recht)
# MISS   MRB (Wet op de motorrijtuigenbelasting 1966)
# MISS   MRR (Motor- en Rijwielreglement)
# MISS   MRT (Militairrechtelijk Tijdschrift)
# MISS   MRW (Motor- en rijwielwet)
# MISS   MS (manuscript (meervoud: MSS))
# MISS   ms. (manuscript (meervoud: mss))
# MISS   MSr (Wetboek van Militair Strafrecht)
# MISS   Msw (Meststoffenwet)
# FOUND  MtL = ['Maatregel', 'teboekgestelde', 'Luchtvaartuigen']
# ...
# MISS   Wet Gh (Wet Geluidhinder)
# MISS   Wet IB (Wet op de Inkomstenbelasting)
# MISS   Wet ink.bel. (Wet op de inkomstenbelasting 1964)
# MISS   Wet JD (Wet op de justitiÎle documentatie en op de verklaring omtrent het gedrag)
# MISS   Wet LB (Wet op de Loonbelasting)
# MISS   Wet L.V. (Wet op de loonvorming)
# MISS   Wet LUVO (Wet inzake Luchtverontreiniging)
# MISS   Wet MB'66 (Wet op de motorrijtuigenbelasting 1966)
# MISS   Wet MB'94 (Wet op de motorrijtuigenbelasting 1994)
# MISS   Wet MM (Wet minimumloon en minimum-vakantiebijslag)
# MISS   Wet MOT (Wet melding ongebruikelijke transacties)
# MISS   Wet MRB 1966 (Wet op de motorrijtuigenbelasting 1966)
# MISS   Wet Mulder (Wet administratiefrechtelijke handhaving verkeersvoorschriften.)
# MISS   Wet OB (Wet op de omzetbelasting)
# MISS   Wet ODOL (Wet Onrechtmatige Daden Openbare Lichamen)
# MISS   Wet Plannen (Wet plannen en milieukwaliteitseisen)
# MISS   Wet RA (Wet op de registeraccountants)
# MISS   Wet RO (Wet op de Rechterlijke Organisatie)
# MISS   Wet RO (Wet op de Ruimtelijke Ordening)
# MISS   Wet RP '85 (Wet voor het reserve-personeel der krijgsmacht 1985)
# MISS   Wet Rvb (De (vervallen) wet houdende instelling van raden van beroep voor de directe belastin)
# MISS   Wet RvS (Wet op de Raad van State)
# MISS   Wet RvSt (Wet op de Raad van State)
# MISS   Wet SVB (Wet op de Sociale Verzekeringsbank)
# MISS   Wet TAV (Wet terugdringing arbeidsongeschiktheidsvolume)
# MISS   Wet TBA (Wet terugdringing beroep op de)
# MISS   Wet TBO (Wet Tuchtrechtspraak Bedrijfsorganisatie)
# MISS   Wet TZ (Wet terugdringing ziekteverzuim)
# MISS   Wet Vamil (Wet vervroegde afschrijving milieu-investeringen)
# MISS   Wet Var (Wet vergunningen en algemene regels voor inrichtingen)
# MISS   Wet VB (Wet op de vermogensbelasting)
# MISS   Wet VOV (Wet vervoersvoorwaarden openbaar vervoer)
# MISS   Wet Vpb (Wet op de vennootschapsbelasting 1969)
# MISS   Wet WOZ (Wet waardering onroerende zaken)
# MISS   wetg.ov. II (wetgevingsoverleg Tweede Kamer)
# MISS   WEU (Westeuropese Unie)
# FOUND  WEV = ['Wet', 'Europese', 'verkiezingen']
# MISS   WFA (World Federation of Advertisers)
# FOUND  WFB = ['Wet', 'financiÎle', 'bijstand']
# FOUND  Wfbb = ['Wet', 'financiÎle', 'betrekkingen', 'buitenland']
# MISS   Wfbb 1980 (Wet financiÎle betrekkingen buitenland 1980)
# MISS   Wfbb 1994 (Wet financiÎle betrekkingen buitenland 1994)
# FOUND  WFO = ['Wet', 'financiÎle', 'ondersteuning']
# MISS   WFR (Weekblad voor Fiscaal Recht)
# MISS   W.F.R. (Weekblad voor fiscaal recht)
# FOUND  Wfv = ['Wet', 'financiering', 'volksverzekeringen']
# MISS   w.g. (wettelijke gemeenschap van goederen)
# MISS   WG (Wet gewetensbezwaren militaire dienst)
# FOUND  WGB = ['Wet', 'Geneeskundige', 'Behandelingsovereenkomst']
# FOUND  WGB = ['Wet', 'Goederenvervoer', 'Binnenscheepvaart']
# MISS   WGB. (Weekblad voor Gemeente Belangen)
# MISS   WGBAP (Wet Gemeentelijke Basisadministratie Persoonsgegevens)
# MISS   WGBO (Wet op de Geneeskundige Behandelingsovereenkomst)
# FOUND  WGE = ['Wet', 'giraal', 'effectenverkeer']
# FOUND  Wge = ['Wet', 'giraal', 'effectenverkeer']
# MISS   W. gelijke beh. (Wet gelijke behandeling mannen en vrouwen. wet van 1 maart m/v 1980)
# FOUND  WGG = ['Wet', 'gehandicaptenvoorzieningen', 'gemeenten']
# MISS   Wgh (Wet geluidhinder)
# MISS   WGJ (Wet houdende bijzondere bepalingen voor de geconsolideerde jaarekening)
# MISS   WGL (Wet gelijk loon voor vrouwen en mannen)
# FOUND  WGMD = ['Wet', 'gewetensbezwaren', 'militaire', 'dienst']
# MISS   WGO (Wereldgezondheidsorganisatie)
# MISS   WGOV (Wet grensoverschrijdend vervoer van aan bederf onderhevige levensmiddelen)
# MISS   WGR (Wet gemeenschappelijke regelingen. Wet van 20 december 1984)
# FOUND  Wgr = ['Wet', 'gemeenschappelijke', 'regelingen']
# FOUND  WGS = ['Wet', 'Gevaarlijke', 'Stoffen']
# MISS   WGV (Wet op de geneesmiddelenvoorziening)
# MISS   WGW (Wet goederenvervoer over de weg)
# MISS   WHBO (Wet op het hoger beroepsonderwijs)
# MISS   WHG (Wasserhaushaltsgesetz)
# FOUND  WHI = ['Wet', 'herverzekering', 'investeringen']
# FOUND  WHLB = ['Wet', 'heffingen', 'luchtverontreiniging', 'benzine']
# MISS   WHP (Wet op de Handelspraktijken (BelgiÎ))
# MISS   WHVZ (Wet hygiÎne en veiligheid zwemgelegenheden)
# MISS   WHW (Wet op het hoger onderwijs en wetenschappelijk onderzoek)
# MISS   WIB (Wet op de internationale bijstandsverlening bij de heffing van belastingen)
# MISS   WIBH (Wet op de internationale bijstandsverlening bij de heffing van belastingen)
# MISS   WID (Wet op de identificatieplicht)
# MISS   WID (Wet inzake de douane)
# MISS   W.ident.pl. (Wet op de identificatieplicht)
# FOUND  WIEP = ['Wet', 'incomptabiliteiten', 'Europees', 'Parlement']
# MISS   Wif (Wet identiteitsvaststelling bij financiÎle dienstverlening)
# MISS   WIGB (Wet invoering gelijke behandeling van mannen en vrouwen in de AOW alsmede aanpassing)
# MISS   WIKE (Wet in- en doorvoer van kippe- en eendeÎieren)
# FOUND  WIM = ['Wet', 'immunisatie', 'militairen']
# MISS   Winkelt.w. (Winkeltijdenwet)
# MISS   WIPO (World Intellectual Property Organization (= OMPI))
# FOUND  WIR = ['Wet', 'Investeringsrekening', 'regeling']
# MISS   Wistra (Zeitschrift f¸r Wirtschaft, Steuer, Strafrecht)
# MISS   WIV (Wet buitengewoon pensioen Indisch verzet)
# MISS   WIV (Wet op de Inlichtingen en Veiligheidsdiensten)
# MISS   Wiw (Wet inzake de wisselkantoren)
# MISS   WJ (Wet op de Jaarrekening 1970)
# MISS   WJD (Wet op de JustitiÎle Documentatie en op de verklaring omtrenthet gedrag Wjdvog W)
# MISS   WJGG (Werkgroep Informatieuitwisseling Gewestelijk Arbeidsbureau -Gemeentelijke Sociale die)
# MISS   Wjhv (Wet op de jeugdhulpverlening)
# MISS   W. just. doc. (Wet op de justitiÎle documentatie en op de verklaring omtrent het gedrag. Wet v)
# FOUND  WK = ['Weens', 'Koopverdrag']
# MISS   WKA (Wet Ketenaansprakelijkheid)
# MISS   WL (Wet van 10 september 1936, houdende voorzieningen inzake het luchtvervoer)
# MISS   WL (Wet op de loonvorming)
# MISS   W.L. (Wet op de lijkbezorging)
# MISS   Wlb (Wet op de lijkbezorging)
# FOUND  W.L.R. = ['Weekly', 'Law', 'Report']
# MISS   WLR (The Weekly Law Reports)
# MISS   WLV (Wet Luchtverkeer)
# MISS   W.L.V. (Wet inzake de Luchtverontreiniging)
# MISS   Wlv (Wet inzake de luchtverontreiniging)
# MISS   WLW (Waterleidingwet)
# MISS   WLW (Wet op het leerlingwezen)
# FOUND  WM = ['Wertpapier', 'Mitteilungen']
# FOUND  Wm = ['Wet', 'milieubeheer']
# MISS   Wmb (Wet milieubeheer)
# FOUND  WMCO = ['Wet', 'Melding', 'Collectief', 'Ontslag']
# MISS   WMH (Wet op de medische hulpmiddelen)
# MISS   W. mil.straf.spr. (Wet militaire strafrechtspraak. Rijkswet van 14 juni 1990)
# MISS   WML (Wet minimumloon en minimumvakantiebijslag)
# MISS   WML (Wet houdende vaststelling van minimumeisen voor het houden van legkippen)
# MISS   WMM (Wet Minimumloon en Minimumvakantiebijslag)
# MISS   WMO (1992 Wet medezeggenschap onderwijs 1992)
# FOUND  WMOT = ['Wet', 'melding', 'ongebruikelijke', 'transacties']
# MISS   WMR (Wet Misleidende Reclame (art. 6:194-196 BW))
# FOUND  WMS = ['Wet', 'milieugevaarlijke', 'stoffen']
# MISS   WMS (Wetboek van Militair Strafrecht)
# FOUND  Wms = ['Wet', 'milieugevaarlijke', 'stoffen']
# MISS   WMSD (Wet militaire Strafrechtspraak)
# FOUND  WMT = ['Wet', 'Militair', 'Tuchtrecht']
# MISS   W.m/v (Wet gelijke behandeling van mannnen en vrouwen)
# MISS   Wmz (Wet melding zeggenschap in ter beurze genoteerde vennootschappen)
# MISS   WNA (Wet op het notarisambt)
# MISS   W.N. (Wet op het Notarisambt)
# MISS   WN (Weekblad voor het Notariaat)
# MISS   wnd (waarnemend)
# MISS   WNed (Rijkswet op het Nederlandschap en het ingezetenschap. Rijkswet van 1)
# MISS   WNo (Wet op de Nationale ombudsman)
# MISS   W. Not.ambt. (Wet op het Notarisambt. Wet van 1 juli 1842)
# MISS   WNR (Wet op de Naburige Rechten)
# MISS   WNR (Weekblad voor Notarisambt en Registratie (vanaf 1898 WPNR))
# MISS   WO (Wetsontwerp)
# MISS   WO (Weekoverzicht Raad van State)
# MISS   w.o. (wetsontwerp)
# MISS   w.o. (waaronder)
# FOUND  WOA = ['Wet', 'overgangsregeling', 'arbeidsongeschiktheidsverzekering']
# MISS   WOA (Wet op de architectentitel)
# MISS   WOB (Wet op de omzetbelasting)
# MISS   WOB (Wet Openbaarheid van Bestuur)
# MISS   Wob (Wet openbaarheid van bestuur)
# MISS   WOB (Wet houdende tijdelijke fiscale maatregelen ter bevordering van het gebruik van onge)
# MISS   WOBOP (Wet Overeenkomst Binnenlands Openbaar Personenvervoer (oud))
# MISS   WODC (Wetenschappelijk Onderzoek- en Documentatiecentrum)
# FOUND  W.o.d.K. = ['Wet', 'op', 'de', 'Kansspelen']
# MISS   WOG (Wet op de geneesmiddelenvoorziening)
# MISS   WOGW (Wet op de gevaarlijke werktuigen)
# FOUND  WohC = ['Wet', 'op', 'het', 'Consumentenkrediet']
# MISS   WOK (Wet op de Kansspelen)
# MISS   WOL (Wet op het levensverzekeringsbedrijf)
# MISS   WOLP (Wet overheidsopdrachten voor levering van produkten)
# MISS   Won.w. (Woningwet)
# MISS   W. Oorl.sr. (Wet Oorlogsstrafrecht. Wet van 10 juli 1952)
# MISS   W. op de huur-comm. (Wet op de huurcommissies. Wet van 18 januari 1979)
# MISS   WOR (Wet op de ondernemingsraden. Wet van 28 januari 1971)
# MISS   WOS (Wet op het schadeverzekeringsbedrijf)
# MISS   WOTS (Wet Overdracht Tenuitvoerlegging Strafvonnissen. Wet van 10 september 1986)
# MISS   WOTV (Wet op de telecommunicatievoorzieningen)
# MISS   WOU (Wet op de Open Universiteit)
# MISS   WOW (Wet Overeenkomst Wegvervoer. Wet van 2 december 1982)
# FOUND  WOZ = ['Wet', 'Olieverontreiniging', 'Zeewater']
# FOUND  WP = ['Wet', 'personenvervoer']
# MISS   WPA (Wet produktaansprakelijkheid)
# MISS   WPC-schaal (World Pensions Committee-schaal)
# FOUND  WPE = ['Wet', 'Parlementaire', 'EnquÍte']
# MISS   WPNR (Weekblad voor Privaatrecht, Notariaat en Registratie)
# MISS   WPNR (Weekblad voor Privaatrecht, Notarisambt en Registratie)
# MISS   WPNR (Weekblad voor Privaatrecht, Notaris-ambt en Registratie)
# MISS   WPolR (Wet Politieregisters)
# MISS   WPR (Wet op de Persoonsregistratie)
# MISS   Won.w. (Woningwet)
# MISS   WR (Woonrecht)
# MISS   Wr (Woonrecht)
# MISS   W.R. (Wet op de Registratie (1832))
# MISS   WRB (Woonruimtebeschikking 1984)
# MISS   Wrb (Wet op de rechtsbijstand)
# FOUND  WRD = ['Wet', 'rechtstoestand', 'dienstplichtigen']
# MISS   WRO (Wet op de Ruimtelijke Ordening)
# MISS   WROM (Wet Rechtsbijstand aan On- en Minvermogenden)
# MISS   WRP (Wettbewerb in Recht und Praxis)
# MISS   WRR (Woonruimterecht (losbladig), VUGA)
# MISS   WRvST (Wet op de Raad van State)
# MISS   WRW (Woonruimtewet)
# MISS   WRW (Warenwet)
# MISS   WS (Het Waterschap)
# FOUND  WSB = ['Wet', 'Sloopregeling', 'Binnenvaart']
# MISS   WSC (Wet op het specifiek cultuurbeleid)
# MISS   WSD (Wet op de stads- en dorpsvernieuwing)
# MISS   WSDV (Wet op de stads- en dorpsvernieuwing)
# MISS   WSF (Wet op de Studiefinanciering)
# FOUND  WSNS = ['Weer', 'Samen', 'Naar', 'School']
# MISS   Wsr. (Wetboek van Strafrecht)
# MISS   WSS (Wet Structurele Sanering Binnenvaart)
# FOUND  WSSB = ['Wet', 'structurele', 'sanering', 'binnenvaart']
# MISS   WSV (Wet op de sociale verzekeringsbank)
# FOUND  WSW = ['Wet', 'Sociale', 'Werkvoorziening']
# FOUND  WTB = ['Wet', 'toezicht', 'beleggingsinstellingen']
# FOUND  Wtb = ['Wet', 'toezicht', 'beleggingsinstellingen']
# MISS   WTBA (Wet op het ter beschikking stellen van arbeidskrachten)
# MISS   WTBZ (Wet Tarieven in Burgerlijke Zaken)
# FOUND  WTE = ['Wet', 'toezicht', 'effectenverkeer']
# FOUND  Wte = ['Wet', 'toezicht', 'effectenverkeer']
# MISS   W. teboekgest.Luchtv. (Wet teboekgestelde Luchtvaartuigen. Wet van 6 maart 1957)
# MISS   W. telecomm.voorz. (Wet op de telecommunicatievoorzieningen)
# FOUND  Wtg = ['Wet', 'Tarieven', 'gezondheidszorg']
# FOUND  WTK = ['Wet', 'Toezicht', 'Kredietwezen']
# MISS   WTK 1992 (Wet toezicht kredietwezen 1992)
# FOUND  Wtk = ['Wet', 'toezicht', 'kredietwezen']
# MISS   W.t.kredietw. (Wet toezicht kredietwezen)
# FOUND  WTL = ['Wet', 'Teboekgestelde', 'Luchtvaartuigen']
# FOUND  WTO = ['World', 'Trade', 'Organisation']
# MISS   W.toez.eff. 1995 (Wet toezicht effectenverkeer 1995)
# MISS   WTS (Wet tarieven in strafzaken)
# FOUND  WTS = ['Wet', 'teboekgestelde', 'schepen']
# FOUND  WTS = ['Wet', 'toezicht', 'schadeverzekeringsbedrijf']
# MISS   WTV (Wet Telecommunicatievoorzieningen)
# MISS   Wtv (1993 Wet toezicht verzekeringsbedrijf 1993)
# FOUND  WTVI = ['Wet', 'tarief', 'van', 'invoerrechten']
# MISS   WTZ (Wet op de toegang tot ziektekostenverzekeringen)
# MISS   WUA (Wet uitvoering aanbevelingen krachtens artikel 63, derde lid, EGKS-verdrag)
# MISS   W.U.B. (Wet op de Universitaire Bestuurshervorming)
# MISS   Wubo (Wet uitkeringen burger-oorlogsslachtoffers 1940-1945)
# MISS   WUD (Wet op de uitoefening van de diergeneeskunst)
# MISS   WUG (Wet op de uitoefening van de geneeskunst)
# FOUND  WUIE = ['Wet', 'uitvoering', 'Internationaal', 'Energieprogramma']
# MISS   W.uitv.EEXW.uitv.pl.verord.Wet (uitvoering voorschriften plaatselijke verordeningen Uitvoeringswet EEG-executieverdrag)
# MISS   WUT (Wet op de uitoefening der tandheelkunst)
# MISS   WUV (Wet uitkeringen vervolgingsslachtoffers 1940-1945)
# MISS   WUV11 (Wet tot uitvoering van verordening no. 11 van de Raad van de EEG)
# MISS   WUV17 (Wet tot uitvoering van verordening no. 17 van de Raad van de EEG)
# MISS   WV (Wegenverkeersregeling)
# MISS   w.v. (wetsvoorstel)
# FOUND  WVA = ['Wet', 'voorraadvorming', 'aardolieprodukten']
# MISS   WvBRv (Wetboek van Burgerlijke Rechtsvordering)
# MISS   WvC ((Ministerie van) Welzijn, Volksgezondheid en Cultuur)
# MISS   W. verbind.verkl. (Wet op het algemeen verbindend en het onverbindend verklaren CAO's van bepalingen van collectieve arbeidsovereenkomsten)
# FOUND  WVG = ['Wet', 'voorkeursrecht', 'gemeenten']
# FOUND  WVG = ['Wet', 'voorzieningen', 'gezondheidszorg']
# FOUND  WvhN = ['Weekblad', 'voor', 'het', 'Notariaat']
# MISS   Wvhro 1 (Wet voltooiing eerste fase herziening rechterlijke organisatie)
# FOUND  WvK = ['Wetboek', 'van', 'Koophandel']
# FOUND  W.v.K. = ['Wetboek', 'van', 'Koophandel']
# MISS   WVKS (Wet vrachtprijzen vervoer van kolen en staal)
# FOUND  WVL = ['Wet', 'vervreemding', 'landbouwgronden']
# FOUND  Wvm = ['Wet', 'verplaatsing', 'mestproduktie']
# FOUND  W.v.M.S. = ['Wetboek', 'van', 'Militair', 'Strafrecht']
# MISS   WVO (Wet op het voortgezet onderwijs)
# FOUND  WVO = ['Wet', 'Verontreiniging', 'Oppervlaktewateren']
# FOUND  Wvo = ['Wet', 'verontreiniging', 'oppervlaktewateren']
# MISS   WVOW (Wet verontreiniging oppervlaktewateren)
# FOUND  W.V.R. = ['Wegen', 'Verkeers', 'Reglement']
# FOUND  WvS = ['Wetboek', 'van', 'Strafrecht']
# FOUND  W.v.S. = ['Wetboek', 'van', 'Strafrecht']
# MISS   WvSr (Wetboek van Strafrecht)
# MISS   WVT (Wet op de telecommunicatievoorzieningen)
# MISS   WVVS (Wet voorkoming verontreiniging van de zee door schepen)
# MISS   WvW (Wegen Verkeers Wet. Wet van 21 april 1994)
# FOUND  W.v.W. = ['Wegen', 'Verkeers', 'Wet']
# MISS   WVZ (Wet vervoer over zee)
# FOUND  WVZ = ['Wet', 'verontreiniging', 'zeewater']
# FOUND  Wvz = ['Wet', 'verontreiniging', 'zeewater']
# MISS   WVZW (Wet verontreiniging zeewater)
# MISS   WW (Werkloosheidswet)
# MISS   WW (Woningwet)
# MISS   WW (Welzijnswet)
# MISS   WWB (Wet wederzijdse bijstand bij de invordering van enkele EEG- heffingen en de omzetbela)
# MISS   Wwh (Wet op de waterhuishouding)
# MISS   WWM (Wet Wapens en Munitie)
# MISS   WWO (Wet op het Wetenschappelijk Onderwijs)
# MISS   WWT (Wet tot nadere regeling van de wettelijke tijd)
# MISS   WWV (Wet Werkloosheidsvoorziening)
# MISS   WWW (Woonwagenwet)
# MISS   WWZ (Wedervergeldingswet zeescheepvaart)
# MISS   WZH (Wet tot aanpassing van het WvK aan de Richtlijn van de EEG betreffende zelfstandige)
# MISS   WZV (Wet Ziekenhuisvoorzieningen)
# MISS   x.d. (ex dividend, zonder aandeel in het dividend)
# MISS   YB (Yearbook of the European Convention on Human Rights)
# MISS   Yearbook (Yearbook of the European Convention on Human Rights)
# MISS   z. (zie)
# FOUND  z.a. = ['zie', 'aldaar']
# MISS   Zeebr.w. (Zeebrievenwet. Wet van 10 juni 1926)
# MISS   ZFW (Ziekenfondswet)
# MISS   zgn. (zogenaamde)
# FOUND  z.i. = ['zijns', 'inziens']
# FOUND  z.j. = ['zonder', 'jaartal']
# MISS   z.o.z. (zie ommezijde)
# MISS   z.p. (zonder plaats van uitgave)
# MISS   z.pl. (zonder plaatsnaam)
# MISS   ZRP (Zeitschrift für Rechtspolitik)
# FOUND  z.s.m. = ['zo', 'spoedig', 'mogelijk']
# FOUND  z.v.t. = ['zonder', 'volledige', 'titel']
# MISS   ZW (Ziektewet)
# FOUND  ZZP = ['Zelfstandig', 'Zonder', 'Personeel']

# %%
# Similar idea, different site

html = wetsuite.helpers.net.download('https://www.eur.nl/esl/campus/sanders-law-library/juridische-afkortingen') 

soup = bs4.BeautifulSoup( html ) # parse the webpage into something we can query

for tr in soup.select('div.accordion table tr'):
    tds = tr.findAll('td')

    text = '%s (%s)'%(tds[1].text.strip(), tds[0].text.strip())  # pretend we don't know this is good data and just put it next to each other

    found = False
    for ab, words in wetsuite.phrases.abbreviations.find_abbrevs( text ):
        print( 'FOUND  %s = %s'%( ab, words ) )
        found = True

    # Things we didn't find - more creative things that we _might_ want to consider
    if '(' in text and not found:    # (assuming bracket indicates there is an explained abbreviation in that link text)
        print( "MISS  ", text )
# Out:
# MISS   anno, in het jaar (a°)
# MISS   Algemene bepalingen (A)
# MISS   Antwoord der regering naar aanleiding van het verslag (A)
# MISS   Arbeid; afzonderlijk verschenen van 1946-1953 (A)
# MISS   Atlantic Reporter second series (A.2d.)
# MISS   Accountancy en Bedrijfskunde (A&B)
# MISS   Aansprakelijkheid en Verzekering (A&V)
# MISS   Ars Aequi. Juridisch studentenblad (AA of A.A. of AAe)
# MISS   Accountant-Administratieconsulent (AAC)
# FOUND  AA = ['Advertising', 'Association']
# MISS   ad acta, bij de akten (wegleggen) (a.a)
# FOUND  AAA = ['American', 'Arbitration', 'Association']
# MISS   Algemeen aanduidingenbesluit (AAB)
# MISS   Algemene aannemingsvoorwaarden voor bedrijfsgebouwen in de landbouw (AABL)
# MISS   Advies- en Arbitragecommissie (AAC)
# MISS   Ars Aequi. Juridisch studentenblad (A Ae)
# MISS   Algemeen arbeidsongeschiktheidsfonds (AAF of Aaf)
# MISS   Adem-alcoholgehalte (AAG)
# MISS   Ars Aequi jurisprudentiebundel (AA-Jur)
# MISS   Algemene aannemingsvoorwaarde voor de kassenbouw (AAK)
# FOUND  AAK = ['Aangepast', 'achtergesteld', 'krediet']
# MISS   Aanhangsel bij de Handelingen van de Eerste/Tweede Kamer (Aanh.Hand. I/II)
# MISS   aantekeningen (aant.)
# MISS   Aanverwante stukken, onderdeel van deze uitgave (Aanv.ST.)
# MISS   Aanvullende alleenstaande oudertoeslag (AAOT)
# MISS   Algemeen ambtenarenreglement (AAR)
# MISS   Algemene aanwijzingen voor de Rijksdienst (AAR)
# FOUND  AAV = ['Algemene', 'Administratieve', 'Voorschriften']
# MISS   Algemene Arbeidsongeschiktheidswet (AAW)
# MISS   Administratief rechtelijke beslissingen, Nederlandse Jurisprudentie (t/m 1970 ARB) (AB of ARB)
# FOUND  ABA = ['Algemeen', 'Burgerlijk', 'Armenbestuur']
# MISS   Algemene bepalingen van administratief recht (ABAR)
# MISS   Algemene bepalingen voor de uitvoering van bouwwerken 1968 (ABB 1968)
# MISS   algemene beginselen van behoorlijk bestuur (abbb)
# MISS   Besluit administratieve boeten coördinatiewet SV (ABC-BESLUIT)
# MISS   Allgemeines Bürgerliches Gesetzbuch (ABGB)
# MISS   Algemene Burgerlijke Pensioenwet (ABPW)
# MISS   Algemene bepalingen voor de invoering van Installatiewerken (ABI)
# MISS   Aanpak Bedrijfsvoering Recherche, Informatiehuishouding en Opleiding (ABRIO)
# MISS   Arbeidsbesluit jeugdigen (ABJ)
# FOUND  ABJ = ['Ambulant', 'Bureau', 'Jeugdwelzijnszorg']
# FOUND  ABM = ['Algemene', 'Bepalingen', 'Milieubeheer']
# FOUND  ABM = ['Adviseur', 'Beroepen', 'Milieubeheer']
# FOUND  ABOB = ['Aanwijzingsbesluit', 'bijstandsverlening', 'ondernemers', 'binnenvaart']
# MISS   Algemeen Politieblad (ABP)
# FOUND  ABP = ['Algemene', 'Burgerlijke', 'Pensioenfonds']
# MISS   Afdeling bestuursrechtspraak van de Raad van State (ABRvS)
# MISS   Absatz (Abs)
# FOUND  abs = ['ambtenaar', 'burgerlijke', 'stand']
# FOUND  ABU = ['Algemene', 'Bond', 'Uitzendondernemingen']
# MISS   Algemene Bankvoorwaarden (ABV)
# FOUND  ABVA = ['Algemene', 'Bond', 'voor', 'Ambtenaren']
# MISS   Algemeen Belgisch Vakverbond (ABVV)
# MISS   Algemene Bijstandswet (ABW)
# MISS   Aanmeldcentrum (AC)
# FOUND  AC = ['Appeal', 'Cases']
# MISS   Adviescommissie criminaliteit (ACC)
# MISS   Accountancy en Bedrijfskunde (Acc Bedr)
# FOUND  ACCI = ['Afdeling', 'coördinatie', 'criminele', 'inlichtingen']
# MISS   Accountancy Thema's (Acc Thema's)
# MISS   Arbeidscomplexendocumentatie (ACD)
# MISS   Adviescommissie Maatregel van Bestuur (ACMB)
# MISS   Algemene centrale van overheidspersoneel (ACOP)
# MISS   Archiv für die civilistische Praxis (AcP)
# MISS   Arbeidsconflictenrecht (ACR)
# MISS   Acualités du droit. revue de la faculté de droit de Liège (Act dr)
# MISS   Actualités fiscales (Act fisc)
# MISS   Actualités juridiques (Act jur)
# MISS   Actualités juridiques des baux (Act jur baux)
# MISS   Acta juridica Hungaria (Acta Jur Hung)
# MISS   Adviescommissie voor Vreemdelingenzaken (ACVZ)
# MISS   Adviescommissie Warenwet (ACWW)
# MISS   Antidiscriminatiebureau (ADB)
# MISS   Administratief Lexicon (Adm Lex)
# FOUND  ADOR = ['Anti', 'Discriminatie', 'Overleg', 'Rijksoverheid']
# FOUND  ADL = ['Algemene', 'dagelijkse', 'levensverrichtingen']
# MISS   Administratief akkoord (Adm.Akk.)
# MISS   Administration Publique (Adm Publ)
# FOUND  ADN = ['Assurantie', 'Data', 'Netwerk']
# MISS   Reglement voor vervoer gevaarlijke stoffen over de Rijn (ADNR)
# FOUND  ADR = ['Alternative', 'Dispute', 'Resolution']
# MISS   Advocatenblad (Adv.bl / Adv bl)
# MISS   Advies van de Raad van State (Adv.RvS)
# MISS   Advocatenwet (Adv.w)
# MISS   Algemene Databank Wet- en Regelgeving (ADW)
# MISS   Arbeidservaringsleer/Arbeidsoriëntatie (AEL/AO)
# MISS   Algemene energieraad (AER)
# FOUND  AFBZ = ['Algemeen', 'Fonds', 'Bijzondere', 'Ziektekosten']
# MISS   Afdeling (afd.)
# MISS   Afdeling geschillen Raad van State (Afd. geschillen)
# MISS   Afdeling Rechtspraak Raad van State (Afd. rechtspraak)
# MISS   Africa Legal Aid Quarterly (AFLA)
# MISS   Association française de normalisation (AFNOR)
# MISS   African Journal of International Law (Afr J Int L)
# MISS   Algemene Federatie voor Personenbelangen (AFP)
# FOUND  AFT = ['Algemeen', 'Fiscaal', 'Tijdschrift']
# MISS   Afvalstoffenheffing (AFV)
# FOUND  AFW = ['Algemeen', 'Fonds', 'Werkeloosheid']
# MISS   Afzonderlijke Ondernemingsraad (AfzOR)
# MISS   Aktiengesellschaft (AG)
# MISS   Ambtenarengerecht (AG / Ag)
# MISS   Advocaat-Generaal (A-G)
# MISS   alternatieve geschilbeslechting (AGB)
# MISS   Allgemeine Geschaftsbedingungen (AGB)
# MISS   Gesetz zur Regelung des Rechts der allgemeinen Geschaftbedingungen (AGBG)
# MISS   Alcohol- en Geweldcursus (AGC)
# MISS   Algehele grondwetherziening (Agh)
# MISS   Wet tijdelijke toeslag op accijns van gelode lichte olie (AGLO)
# MISS   Agrarisch recht (Agr R)
# MISS   Afdeling voor geschillen van bestuur van de Raad van State (AGRS / AG RvS / AGvB / Agvb)
# FOUND  AH = ['Algemeen', 'Handelsblad']
# FOUND  a.i. = ['ad', 'interim']
# FOUND  AHLC = ['Ad', 'Hoc', 'Liaison', 'Committee']
# MISS   Acta Hospitalia (A Hosp)
# MISS   Anti-discriminatie, Huisvesting en Participatie (AHP)
# MISS   algemene handelsvoorwaarden (a.h.v.)
# FOUND  AIAG = ['Automotive', 'Industry', 'Action', 'Group']
# FOUND  AIB = ['Arbitrage', 'Instituut', 'Bouwkunst']
# MISS   Algemene Inspectiedienst (AID)
# MISS   Aida-news letter (Aida)
# MISS   Algemeen Informatie- en Automatiseringsservicecentrum (AI/ISc)
# FOUND  AI = ['Arbeid', 'Integraal']
# MISS   Association Internationale pour Protection de la Proprété Industrielle (AIPPI)
# MISS   Antilliaans Juristenblad (AJ of AJB)
# MISS   American Journal of Comparative Law (AJCL)
# FOUND  AJDA = ['Actualité', 'Juridique', 'Droit', 'Administratif']
# FOUND  AJPI = ['Actualité', 'Jurdique', 'Propriété', 'Immobilière']
# FOUND  AJR = ['Arbeidsomstandighedenbesluit', 'justitiële', 'rijksinrichting']
# FOUND  AJT = ['Algemeen', 'Juridisch', 'Tijdschrift']
# MISS   Algemeen Juridisch Tijdschrift. Dossier (AJT-Dossier)
# MISS   Aktiengezetz (AktG)
# MISS   Asser kaartsysteem op internationaal privaat­recht TMC Asser Instituut (AK)
# MISS   Algemene Kinderbijslagwet (AKW)
# FOUND  ALD = ['Actualité', 'législative', 'Dalloz']
# MISS   Algemeen Fiscaal tijdschrift (Alg Fisc)
# MISS   Algemene rechtsberichten, bulletin (Alg Rechtsber)
# MISS   All England Reports (All ER)
# MISS   Alle Risico's (Alle Risico's)
# FOUND  ALM = ['American', 'Law', 'Magazine']
# FOUND  AMA = ['Alleenstaande', 'Minderjarige', 'Asielzoeker']
# MISS   Ambtenarenwet (Ambt.w)
# MISS   Auteurs en Media (AM)
# MISS   Tijdschrift voor auteurs- media en informatie­recht (AMI)
# MISS   Advies- en Meldpunt Kindermishandeling (AMK)
# MISS   Auteursrecht Tijdschrift voor auteurs- mediarecht tot 1982 (AMR)
# MISS   American review of International Arbitration (Am Rev Intl Arb)
# FOUND  AMvB = ['algemene', 'maatregel', 'van', 'bestuur']
# MISS   Annales du droit (Ann Dr)
# MISS   Anuario de derecho (An Der)
# MISS   Anuario de derecho civil (An Der Civ)
# MISS   Anuario de derecho humanos (An Der Hum)
# MISS   Annales du droit de Liège (Ann Dr Liège)
# MISS   Annales du droit de Louvain: revue trimestrielle du droit Belge (Ann Dr Louvain)
# MISS   Annales du droit Luxemburgeois (Ann Dr Lux)
# MISS   annuaire de droit maritime et aéro-spatiale (Ann Dr Marit & Aéro-Spat)
# MISS   les annales de l'économic publique, sociale et coopérative (Ann écon publ soc et coop)
# MISS   annales d'études europèennes (Ann ét eur)
# MISS   Annuaire Européen (Ann Européen)
# MISS   annales de le faculté de droit, d'economie et de scienes sociales de Liége (Ann Fac Dr Liége)
# MISS   Annuaire Français de droit international (Ann Fr Dr Intern)
# MISS   Annuaire d'histoire des facultés de droit de la science juridique (Ann Hist Fac Dr & Sci Jur)
# MISS   annuaire de l'institut de droit international (Ann Inst Dr Intern)
# MISS   annales du notariat et de l'enregistrement (Ann not)
# FOUND  ANSI = ['American', 'National', 'Standards', 'Institute']
# MISS   Algemene Nederlandse Vereniging van Reisbureaus (ANVR)
# MISS   Algemene nabestaandewet (Anw)
# MISS   Algemene Nederlandse Wielrijdersbond (ANWB)
# FOUND  AO = ['Administratieve', 'Organisatie']
# MISS   Arbeidsovereenkomstenbesluit (AOB)
# MISS   Adviesbureaus voor opleiding en beroep (Aob)
# MISS   Agrarisch Opleidingscentrum (AOC)
# MISS   Arbeidsongeschiktheidsfonds (Aof)
# FOUND  AOO = ['Afval', 'Overleg', 'Orgaan']
# MISS   Archiv des öffentlichen rechts (AöR)
# MISS   Algemene Ouderdomswet (AOW)
# MISS   Arbeidsongeschiktheidswet (AOW)
# FOUND  AP = ['Aanvullend', 'protocol']
# MISS   Algemeen Politieblad van het Koninkrijk der Nederlanden (APB)
# MISS   Algemene Periodieke Autokeuring (APK)
# MISS   Arbeidsplaatsenovereenkomst (APO)
# MISS   appellant (app.)
# MISS   appendix (app.)
# FOUND  APPA = ['Algemene', 'Pensioenwet', 'politieke', 'ambtsdragers']
# MISS   Algemene (Plaatselijke) (Politie) Verordening (APV)
# FOUND  AR = ['Algemene', 'Rekenkamer']
# FOUND  AR = ['Agrarisch', 'Recht']
# MISS   Arbitrale Rechtspraak (A.R. of AR)
# MISS   Arbeidsrevalidatieafdeling (ARA)
# MISS   Automatisering Ruilverkavelingsadministratie Kadaster (ARAK)
# MISS   Algemene Rijksambtenaren Reglement (ARAR)
# MISS   Administratiefrechtelijke beslissingen (ARB)
# MISS   Administratieve en Rechterlijke beslissingen betreffende het openbaar bestuur in Nederland (ARB)
# MISS   Arbeidsblad (Arbbl)
# FOUND  APM = ['administration', 'publique', 'mensuel']
# FOUND  APR = ['Algemene', 'praktische', 'rechtsverzameling']
# FOUND  APT = ['administration', 'publique', 'trimesteriel']
# FOUND  APV = ['Algemene', 'Plaatselijke', 'Verordening']
# FOUND  AR = ['Agrarisch', 'Recht']
# FOUND  AR = ['Arbitrale', 'Rechtspraak']
# MISS   Arbeidsrecht (AR)
# MISS   Arbeidsrechtelijke annotaties (ArA)
# MISS   Arab Law Quarterly (Arab L Q)
# MISS   Algemeen Rijksambtenarenreglement (ARAR)
# MISS   Administratieve en Rechterlijke Beslissingen (tot 1970; daarna AB) (ARB)
# MISS   Accounting Research and terminology Bulletins (ARB)
# MISS   Arbitration International (Arb Intl)
# MISS   Wet Administratieve rechtspraak bedrijfsorganisatie (ARBO)
# MISS   Arbeidsomstandighedenwet (Arbowet)
# MISS   Directoraat-Generaal voor de arbeidsvoorziening (ARBVO)
# MISS   Archivio giuridico Filipo Serafini (Arch Giur Serafini)
# MISS   Archives de Philosophie de Droit (Arch Phil Dr)
# MISS   Archiv des Völkerrecht (Arch VR)
# MISS   Algemeen reglement voor de dienst op de spoorwegen (ARD)
# MISS   Algemeen Reglement voor het vervoer van gevaarlijke stoffen over de Rijn (ARGR)
# MISS   Wet algemene regels herindeling (arhi)
# FOUND  ARI = ['Algemene', 'Recherche', 'informatie']
# FOUND  ARO = ['Actuele', 'Rechtspraak', 'Ondernemingspraktijk']
# MISS   Administratieve rechtspraak overheidsbeschikkingen (AROB)
# MISS   Algemeen Rijksambtenarenreglement (ARR)
# MISS   arrondissement (arr.)
# MISS   Arrondisementsrechtbank (ArrRb)
# MISS   Arresten van het Hof van cassatie (Arr Cass)
# MISS   Arresten van Raad van State (Arr R v St)
# MISS   Arresten van het Hof van verbreking (Arr Verbr)
# MISS   artikel(en) (art.)
# MISS   Arbeidstijdenwet (Artw.)
# MISS   Afdeling rechtspraak van de Raad van State (ARRS)
# MISS   Ambtenarenreglement Staten Generaal (ARSG)
# MISS   Archiv für rechts- und sozialphilosophie (ARSP)
# MISS   Algemene Regels en Vergunningen van inrichtingen (ARV)
# MISS   Arbeidsvoorwaarden en Sociaal Beleid (ASB)
# MISS   American Society of International Law (ASIL)
# MISS   Aard, Structuur en Inhoud van het Overleg (ASIO)
# FOUND  ASJ = ['Algemene', 'Subsidievoorschriften', 'Justitie']
# MISS   Arrestatieteam (AT)
# MISS   Automatisering Toedelingsontwerp Ruilverkavelingen (ATOR)
# MISS   Algemene teelvoorwaarden (ATV)
# MISS   Algemene termijnenwet (ATW)
# MISS   Algemeen uitvoeringsbesluit Drank- en Horecawet (AUDH)
# MISS   auteursrechtbelangen (aut.bel)
# MISS   Auteurswet (Aut.w)
# MISS   Audit en revisoraat (Aud Rev)
# MISS   Australian Yearbook of International Law (Austl Yrbk Intl L)
# MISS   Aansprakelijkheidsverzekering (AV)
# FOUND  av = ['algemene', 'vergadering']
# MISS   Tijdschrift voor aansprakelijkheid en verzekering (A en V)
# MISS   aansprakelijkheidsverzekering bedrijven (AVB)
# MISS   Afdeling van Beroep (AAvB)
# MISS   Algemene vergadering van aandeelhouders (AVA of a.v.a.)
# FOUND  avas = ['afwezigheid', 'van', 'alle', 'schuld']
# MISS   Aansprakelijkheidsverzekering Bedrijven (AVB)
# FOUND  AvB = ['Afdeling', 'van', 'Beroep']
# MISS   Algemeen verbond Bouwbedrijf (AVBB)
# MISS   Algemene Vervoerscondities (AVC)
# MISS   Alcohol Verkeerscursus (AVC)
# MISS   Aansprakelijkheid Verzekering en Schade (AV&S of AVVS)
# MISS   Algemene Verkeersdienst (AVD)
# FOUND  AVG = ['Algemene', 'verlofregeling', 'gedetineerden']
# MISS   Aanvullende Opvang (AVO)
# FOUND  AVO = ['Algemeen', 'voortgezet', 'onderwijs']
# MISS   aansprakelijkheidsverzekering particulieren (AVP)
# FOUND  avs = ['afwezigheid', 'van', 'schuld']
# MISS   Algemeen verbindendverklaring (AVV)
# FOUND  AVVE = ['Algemene', 'Veilingvoorwaarden', 'voor', 'Executieveilingen']
# MISS   Algemene voorwaarden voor de uitvoering van werken (AVW)
# FOUND  a.w. = ['aangehaald', 'werk']
# MISS   Afvalstoffenwet (Aw)
# MISS   Auteurswet (Aw)
# MISS   Ambtenarenwet (1929) (AW)
# FOUND  Awb = ['Algemene', 'wet', 'bestuursrecht']
# MISS   Algemene wet op het binnentreden (Awbi)
# FOUND  AWBZ = ['Algemene', 'Wet', 'Bijzondere', 'Ziektekosten']
# MISS   Algemene wet inzake Douane en Accijnzen (AWD)
# MISS   Algemene wet bestuursrecht (AWG)
# FOUND  AWGB = ['Algemene', 'Wet', 'Gelijke', 'Behandeling']
# MISS   Algemeen Werkloosheidsfonds (AWF)
# MISS   Algemeen Waarborgfonds voor de Middenstand (AWM)
# MISS   Algemene Wet op het binnentreden (Awob)
# MISS   Adviescentrum Wagenparkbeheer (AWP)
# MISS   Algemene wet inzake Rijksbelastingen (AWR)
# MISS   Aanwijzingen voor de wetgevingstechniek (AWT)
# MISS   Algemene Weduwen- en Wezenwet (AWW)
# MISS   Algemene Werkeloosheidswet bedrijfsverenigingen (AWW)
# MISS   Asielzoekerscentrum (AZC)
# FOUND  AZH = ['Ambtenarenreglement', 'Zuid', 'Holland']
# MISS   Beslissingen in belastingzaken (tot 1953) (B. of BB)
# FOUND  b.a. = ['boven', 'aangehaald']
# FOUND  B.A. = ['beperkte', 'aansprakelijkheid']
# FOUND  BaaH = ['Besluit', 'algemene', 'aanwijzingen', 'Haltafdoening']
# MISS   Beroep administratieve beschikkingen (wet) (BAB)
# FOUND  babs = ['buitengewoon', 'ambtenaar', 'burgerlijke', 'stand']
# MISS   Besluit administratieve bepalingen inzake wegverkeer (1990) (BABW)
# FOUND  BAC = ['Besluit', 'adviescommissie', 'consumentenkrediet']
# FOUND  BACA = ['Besluit', 'aanwijzing', 'chemische', 'afvalstoffen']
# MISS   Bundesarbeitsgericht (BAG)
# FOUND  BAG = ['Beleidsadviescollege', 'Automatisering', 'Gezondheidszorg']
# MISS   Bloed-alcoholgehalte (BAG)
# FOUND  BAGA = ['Besluit', 'aanwijzing', 'gevaarlijke', 'afvalstoffen']
# FOUND  BaHF = ['Besluit', 'aanwijzing', 'Halt', 'feiten']
# FOUND  BAHV = ['Besluit', 'administratiefrechtelijke', 'handhaving', 'verkeersvoorschriften']
# MISS   Bank- en financiewezen, cahier/Revue de La banque (Bank Fin Cah)
# MISS   Bankcommissie, jaarverslag (Bankcom)
# MISS   Burgerlijk Ambtenarenreglement Defensie (BARD)
# MISS   BasisRaadsOnderzoek (BARO)
# FOUND  BARP = ['Besluit', 'algemene', 'rechtspositie', 'Politie']
# FOUND  BART = ['Besluit', 'Algemene', 'Richtlijnen', 'Telecommunicatie']
# MISS   besluit van algemene strekking (b.a.s.)
# FOUND  BASJ = ['Besluit', 'Alternatieve', 'Sancties', 'Jeugdigen']
# MISS   Overeenkomst inzake de administratieve en strafrechtelijke samenwerking op het gebied van de regelingen die verband houden met de verwezenlijking van de doelstellingen van de Benelux Economische Unie (BASS)
# FOUND  BASW = ['Besluit', 'Arbeidsvoorwaarden', 'Sociale', 'Werkvoorziening']
# MISS   Baurecht (BauR)
# MISS   Beroepsaansprakelijkheidsverzekering (BAV)
# MISS   Besluit aanbesteding van werken (BAW)
# MISS   Bayerisches Oberstes Landesgericht (BayObLG)
# MISS   Beleid & Maatschappij (B&M)
# MISS   Burgemeester en wethouders (B en W (B&W))
# MISS   Beslissingen in Belastingzaken (BB of B)
# FOUND  BB = ['Binnenlands', 'Bestuur']
# MISS   Bankbetrieb (BB)
# FOUND  BB = ['Betriebs', 'Berater']
# MISS   Maandblad belastingbeschouwingen (BB)
# FOUND  Bb = ['Bedrijfsjuridische', 'berichten']
# MISS   Betreibs-berater: zeitschrift für recht und wirtschaft (Bb)
# FOUND  BBP = ['Besluit', 'Bezoldiging', 'Politie']
# MISS   Bestuur en Belang (B&B of BenB of BenB)
# MISS   Beleid en Maatschappij (B&M)
# FOUND  BBA = ['Buitengewoon', 'Besluit', 'Arbeidsverhoudingen']
# FOUND  BBA = ['British', 'Bankers', 'Association']
# MISS   Besluit Bijzondere akten van de Burgerlijke Stand (BBABS)
# MISS   Beschikking Bezwaar en Beroep (BBB)
# FOUND  BBB = ['Bijdragebesluit', 'bewoners', 'bejaardenoorden']
# FOUND  BBBG = ['buitengewone', 'bevoegdheden', 'burgerlijk', 'gezag']
# FOUND  BBED = ['Besluit', 'Berechting', 'Economische', 'Delicten']
# FOUND  BBH = ['Besluit', 'bijzondere', 'huurprijzen']
# MISS   Bedrijfsbeëindigingshulp (regeling) (BBH)
# MISS   Besluit beleggingsinstellingen (BBI)
# MISS   Beleids- en beheersinstrumentarium (BBI)
# FOUND  BBL = ['Bureau', 'Beheer', 'Landbouwgronden']
# MISS   Beroepsbegeleidend onderwijs (BBO OF b.b.o.)
# MISS   Besluit op de bejaardenoorden (BBO)
# FOUND  BBP = ['besluit', 'bezoldiging', 'politie']
# FOUND  BBR = ['Besluit', 'buitengewone', 'rechtspleging']
# MISS   Bezoldigingsbesluit burgerlijke rijksambtenaren (BBRA)
# FOUND  BBRP = ['Besluit', 'beheer', 'regionale', 'politiekorpsen']
# FOUND  BBS = ['Besluit', 'Burgerlijke', 'Stand']
# FOUND  BBS = ['Buitengewoon', 'Besluit', 'Strafzaken']
# FOUND  BBSH = ['Besluit', 'beheer', 'sociale', 'huursector']
# FOUND  BBVSW = ['Besluit', 'betaalbaarstelling', 'vergoedingen', 'sociale', 'werkvoorziening']
# FOUND  BBW = ['Belgisch', 'Burgerlijk', 'Wetboek']
# FOUND  BC = ['Berner', 'Conventie']
# FOUND  BC = ['Beroepscommissie', 'CRS']
# FOUND  BC = ['Bekostigingsbesluit', 'Cultuuruitingen']
# FOUND  BCA = ['Besluit', 'Centrale', 'Adoptieraad']
# MISS   Bulletin of Comperative Labour Relations (BCLR)
# MISS   Broederschap der Candidaat-Notarissen (BCN)
# FOUND  BCNP = ['Bureau', 'Communicatie', 'Nederlandse', 'Politie']
# FOUND  BCOM = ['Bestuurlijke', 'Coördinatie', 'Overleg', 'Minderheden']
# FOUND  BCOSW = ['Besluit', 'centraal', 'overleg', 'sociale', 'werkvoorziening']
# MISS   Bureau Rijksverhuizingen (BCR)
# FOUND  BD = ['Buitenlandse', 'dienstplicht']
# MISS   Bedrijfsvereniging (BDV)
# MISS   Bestuurseenheid (BE)
# MISS   Bank- en Effectenbedrijf (BE of B&E)
# FOUND  B.E.B. = ['Buitenlandse', 'Economische', 'Betrekkingen']
# MISS   Bedrijfsactualiteit (Bedrijfsact)
# MISS   Bedrijfsrevisoraat (Bedrijfsrev)
# MISS   Wet op de bedrijfsorganisatie (Bedr.org.)
# MISS   Beginselenwet voor de Kinderbescherming (Begw KB)
# MISS   Beleidsregel (Bel.)
# MISS   Belasting Beschouwingen (Bel.Besch.)
# MISS   Benelux Gerechtshof (BenGH)
# MISS   Belgische accountant (Belg Acc)
# MISS   Belgisch Wetboek van Koophandel (Belg WvK)
# MISS   Belemmeringenwet Landsverdediging (Bel.w.Lv)
# MISS   Belemmeringenwet Privaatrecht (Bel.w.P.)
# MISS   Belemmeringenwet Verordeningen (Bel.w.Verord)
# MISS   Wet op de belastingen van rechtsverkeer (Bel.rv)
# MISS   Baten & Lastenstelsel (B & L stelsel)
# MISS   Burgerzaken & Recht (B&R)
# MISS   Benelux Gerechtshof. Jurisprudentie / Cour de justice Benelux Jurisprudence (Benelux Jur)
# MISS   Benelux publicatiebald (Benelux pb)
# MISS   Benelux-Gerechtshof (BenGH)
# MISS   Reglement op de procesvoering van het Benelux-Gerechtshof (BenGH-Regl)
# MISS   Verdrag betreffende de oprichting en het statuut van een Benelux-Gerechtshof (BenGH-Verdrag)
# MISS   Burgerlijke Utiliteitsbouw (B en U)
# MISS   Burgemeester en Wethouders (B&W of B.&W. of B en W of B. en W.)
# MISS   beroepscommissie (ber.cie)
# MISS   Berner Conventie voor de bescherming van letterkunde en kunst (Bern.Conv)
# MISS   Beroepswet (Ber.w.)
# MISS   Beschikking (Besch.)
# MISS   Aanwijzingsbeschikking hulpofficieren van justitie (Besch.Just)
# MISS   Besluit (Besl.)
# MISS   Besluit op de Inkomstenbelasting (Besluit IB)
# MISS   Besluit op de Loonbelasting (Besluit LB)
# MISS   Besluit openbare aanbiedingen op effecten (Besluit OBE)
# MISS   Besluit oproeping en mededelingen verzoekschriftprocedure (Besluit OMV)
# MISS   Besluit op de Vennootschapsbelasting (Besluit VPB)
# MISS   Bestuurswetenschappen (Best.w)
# MISS   Bulletin van de Europese Unie (Beu)
# MISS   Bureau Européen des Unions des Consommateurs (BEUC)
# MISS   Benelux Economisch Verdrag (BEUV)
# MISS   Benelux-verdrag inzake de tenuitvoerlegging van rechterlijke beslissingen in strafzaken (BEV)
# MISS   Bewerker (bew.)
# MISS   Verdrag inzake de verkrijging van bewijs in het buitenland in burgerlijke en handelszaken (Bew.V)
# MISS   Borgstellingsfonds (BF)
# FOUND  BFA = ['British', 'Franchise', 'Association']
# MISS   Bulletin de la Fondation André Renard (BFAR)
# MISS   B.F.E. Rechtspraak (BFE)
# FOUND  BFI = ['bijzondere', 'financiële', 'instelling']
# FOUND  BFO = ['Bureau', 'Financiële', 'Ondersteuning']
# FOUND  BFT = ['Bureau', 'Financieel', 'Toezicht']
# FOUND  BFuP = ['Betriebswirtschaftliche', 'Forschung', 'und', 'Praxis']
# MISS   Besluit gewetensbezwaren militaire dienst (BG)
# FOUND  BG = ['Beginselenwet', 'gevangeniswezen']
# MISS   Bundesgericht (BG)
# MISS   Bürgerliches Gesetzbuch (BGB)
# MISS   Bundesgesetsblatt (BGBL)
# MISS   BankGiroCentrale (BGC)
# MISS   Entscheidungen des schweizerischen Bundesgerichts, amtliche Sammlung (BGE)
# FOUND  BGG = ['Besluit', 'Gevoelige', 'Gegevens']
# FOUND  BGGL = ['Besluit', 'geluidsbelasting', 'grote', 'luchtvaartterreinen']
# MISS   Bundesgerichtshof (BGH)
# MISS   Benelux-Gerechtshof (BGH)
# MISS   BGH-Rechtsprechung Strafsachen (BGHR)
# MISS   Entscheidungen des Bundesgerichtshofes in Strafsachen (BGHRst)
# MISS   Entscheidungen des Bundesgerichtshofes in Zi­vilsachen (BGHZ)
# FOUND  BGKL = ['Besluit', 'geluidsbelasting', 'kleine', 'luchtvaartuigen']
# FOUND  BGSHG = ['Beschikking', 'geldelijke', 'steun', 'huisvesting', 'gehandicapten']
# FOUND  BGSV = ['Besluit', 'geldelijke', 'steun', 'volkshuisvesting']
# MISS   Grondwet van het Koninkrijk België (BGW of Bgw)
# MISS   Besluit goederenvervoer over de weg (Bgw)
# MISS   Bedrijfshuuradviescommissie (BHAC)
# MISS   Bureau voor de Harmonisatie in de Internet markt (merken, tekeningen en modellen) (BHIM)
# FOUND  BHW = ['Besluit', 'huurprijzen', 'woonruimte']
# FOUND  BI = ['Besluit', 'Inverzekeringstelling']
# MISS   B.I.B. revue (BIB Revue)
# FOUND  BIB = ['Beslissingen', 'in', 'Belastingzaken']
# MISS   Binnenlandsbestuur (Bibes)
# FOUND  BIBOB = ['Bevordering', 'Integere', 'Besluitvorming', 'Openbaar', 'Bestuur']
# MISS   Bijblad bij De Industriële Eigendom< (BIE /Bijbl Ind Eig)
# MISS   Wet op de Beroepen in de Individuele Gezondheidszorg (BIG)
# FOUND  b.i.h. = ['beschrijving', 'in', 'hoofdlijnen']
# FOUND  BIH = ['Beschikking', 'Individuele', 'Huursubsidie']
# MISS   Bulletin d'information de L'I.N.A.M.I. (BI-INAMI)
# MISS   Regtsgeleerd Bijblad behoorende tot de Nieuwe Bijdragen van Regtsgeleerdheid en wetgeving (Bijbl.N.Bijdr.)
# MISS   Bijlage(n) (Bijl.)
# MISS   Bijlage Europees Sociaal Handvest (Bijl ESH)
# MISS   Bijlage Handelingen Eerste Kamer (Bijl.Hand.I)
# MISS   Bijlage Handelingen Tweede Kamer (Bijl.Hand.II)
# MISS   bijvoorbeeld (bijv.)
# MISS   Bijvoegsel tot het weekblad van het Recht (Bijv.W)
# MISS   Bijzondere Raad van Cassatie (Bijz. RvC)
# MISS   Beleidsagenda Integratie op Lokaal Niveau (BILON)
# MISS   Besluit informatie sociale werkvoorziening (Binfo)
# MISS   Bingham's New Cases (Bing.NC)
# MISS   Besluit Inlichtingen Justitiële Documentatie (B.Inl.J.D.)
# MISS   Besluit Inlichtingen Strafregisters (B.Inl.S.Reg.)
# FOUND  BIO = ['Bijzonder', 'inventariserend', 'onderzoek']
# FOUND  BIOS = ['Basic', 'Input', 'Output', 'System']
# MISS   bulletin d'information pénitentiaire (BIP)
# FOUND  BIRO = ['Beleidsraad', 'Informatievoorziening', 'Rechterlijke', 'Organisatie']
# MISS   Bureaux Internationaux réunis pour la protection de la propreiété intellectuelle (BIRPI)
# MISS   Bureau Internationale Rechtshulp in Strafzaken (BIRS)
# MISS   Bank for International Settlements (BIS)
# FOUND  BISS = ['Bureau', 'Internationale', 'Strafrechtelijke', 'Samenwerking']
# FOUND  BIV = ['Besluit', 'inbeslaggenomen', 'voorwerpen']
# FOUND  BIZ = ['Bureau', 'Internationale', 'Zaken']
# MISS   Ministerie van Binnenlandse Zaken (BiZa)
# MISS   college van burgemeester en wethouders (b. en w.)
# MISS   Belgique judicaiare: gazette des Tribunaux Belges et étrangers (BJ)
# MISS   Bundesjagtgesetz (BJagdG)
# MISS   Bedrijfsjuridische berichten (BJB)
# MISS   Bureau Juridische en Beleidsondersteunende Aangelegenheden (BJBA)
# MISS   Beginselenwet Justitiële Jeugdinrichtingen (BJI)
# FOUND  Bjj = ['Beginselenwet', 'justitiële', 'jeugdinrichtingen']
# MISS   Bundesministerium der Justiz (BJM)
# MISS   Beschikking jeugdwerkregeling (BJR)
# MISS   Beginselenwet voor de Kinderbescherming (BK)
# MISS   Besluit kredietaanbiedingen (BKA)
# MISS   Besluit Kadastraal recht 1994 (Bkadr 1994)
# FOUND  Bkb = ['Besluit', 'krediethypotheek', 'bijstand']
# FOUND  BKR = ['Bureau', 'Krediet', 'registratie']
# MISS   BedrijfsKader Training (BKT)
# MISS   Beroepskeuzevoorlichting (BKV)
# MISS   Besluit Kredietvergoeding (BKV)
# MISS   Fonds voor Beeldende Kunsten, Vormgeving en Bouwkunst (BKVB)
# MISS   Bureau Kwaliteitszorg (BKw)
# MISS   bladzijde(n) (bl. of blz.)
# MISS   Bill of Lading (cognossement) (B/L of b.l.)
# MISS   Besluit lasten sociale werkvoorziening (Blasten)
# MISS   Besluit op de lijkbezorging (Blb)
# FOUND  BLEU = ['Belgisch', 'Luxemburgse', 'Economische', 'Unie']
# FOUND  BLN = ['Besluit', 'Landelijke', 'Normering']
# MISS   Belastingmagazine (BM)
# FOUND  BMA = ['Besluit', 'Mededingingsregeling', 'Aanbestedingen']
# MISS   Benelux Merkenbureau (BMB)
# FOUND  BMB = ['Besluit', 'meldingplichtige', 'bouwwerken']
# MISS   Benelux Merken en Modellenrecht (BMM)
# MISS   Bulletin Beneluxvereniging van merken- en modellengemachtigden (BMM)
# MISS   BMM-Bulletin (BMMB)
# MISS   Beleid en Maatschappij (B&M, BenM of B en M)
# MISS   Monus-Malusregeling (BMS)
# MISS   (Wet) Boeten, maatregelen, terug- en invordering sociale zekerheid (BMTI)
# MISS   Benelux Merkenverdrag (BMV)
# MISS   Benelux-Merkenwet (Eenvormige Beneluxwet op de merken (BMW)
# MISS   Bestrijdingsmiddelenwet (wet van 12 juli 1962, Stb, 288) (Bmw)
# MISS   Bekendmakingswet (Bmw)
# MISS   Bond van Nederlandse Architecten (BNA)
# FOUND  BNB = ['belastingzaken', 'Nederlandse', 'belastingrechtspraak']
# FOUND  BNG = ['Bank', 'Nederlandse', 'Gemeenten']
# MISS   Benelux (BNL)
# MISS   Verdrag betreffende instelling en het statuut van een Benelux-Gerechtshof (BNLG)
# MISS   Eenvormige Beneluxwet op de merken (BNLX merkw.)
# MISS   Eenvormige Beneluxwet inzake Tekeningen of Modellen (BNLX Tek. of Mod.)
# MISS   Benelux verdrag over uitlevering en rechtshulp in strafzaken (BNLX uitl. Rh.)
# MISS   (Koninklijke) Broederschap der notarissen in Nederland (B.N.N)
# FOUND  BNP = ['Bruto', 'Nationaal', 'Product']
# MISS   Bijzonder nabestaandenpensioen (BNP)
# MISS   Wet op de bedrijfsorganisatie (BO)
# MISS   Besluit overheidsaanbesteding (BOA)
# MISS   Besluit openbaarheid van bestuur (Stb, 1979, 590) (BOB)
# MISS   Wet Boeten, maatregelen en terug- en invordering sociale zekerheid (Boeten)
# MISS   Boletin Informativo (Bol. Inf)
# MISS   Besluit overleg en medezeggenschap politie (1994) (BOM)
# MISS   Besluit oproepingen, mededelingen en zendingen verzoekschriftprocedure (BOMV)
# FOUND  BON = ['Bestuur', 'op', 'niveau']
# FOUND  BNP = ['Bruto', 'Nationaal', 'Product']
# MISS   Besluit kwaliteit en gebruik overige organische afvalstoffen (Boom)
# FOUND  Boom = ['Bureau', 'Ondernemingswetgeving', 'Openbaar', 'Ministerie']
# MISS   Besluit organen van overleg sociale werkvoorziening (BOOSW)
# MISS   Besluit opslaan in ondergrondse tanks (Boot)
# FOUND  BOP = ['Bijzondere', 'Opsporingskosten', 'Politie']
# MISS   Wet Bijzondere opneming in psychiatrische ziekenhuizen (BOPZ)
# FOUND  BOS = ['Beslissing', 'Ondersteunend', 'Systeem']
# MISS   Benelux-verdrag inzake de overdracht van strafvervolging (Bos)
# MISS   Boswet (Bosw)
# FOUND  BOT = ['Besluit', 'opgedragen', 'Telecommunicatiediensten']
# MISS   Boswet (BOW)
# FOUND  BOZ = ['Bureau', 'Operationele', 'Zaken']
# FOUND  B.O.Z. = ['Besluit', 'Olieverontreiniging', 'Zeewater']
# FOUND  BP = ['Belemmeringenwet', 'Privaatrecht']
# FOUND  BP = ['Besluit', 'Personenvervoer']
# MISS   Benelux Publikatieblad (BPB)
# MISS   Besluit periodieke keuring van motorrijtuigen, aanhangwagens en opleggers. (BPK)
# MISS   Buitenlandse Pleegkinderen (BPK)
# MISS   Wet op belastingen van personenauto's en motorrijwielen (BPM)
# MISS   Besluit Politieregisters (BPolR)
# MISS   Binnenvaartpolitiereglement (BPR)
# MISS   ex Belemmeringenwet Privaatrecht 1927 (BP-rechten)
# MISS   Besluit Personenvervoer (BPV)
# MISS   Bedrijfspensioenfondsenwet (BPW)
# MISS   Wet betreffende verplichte deelneming in een bedrijfspensioenfonds (BPW)
# FOUND  BR = ['Bankruptcy', 'Reporter']
# MISS   Bouwrecht (BR of Bouwr.)
# MISS   Bestuursraad (BR)
# FOUND  BR = ['Buitenlandse', 'Rechtstijdingen']
# MISS   Brugse Rechtstijdingen (Br Rechtst)
# MISS   Bundes Rechtsanwals Gebühren Ordnung (BRAGO)
# MISS   Besluit rechtsbetrekking sociale werkvoorziening (BRB)
# MISS   Rijksbijdrage regeling maatschappelijke hulp- en dienstverlening aan jongeren en jongvolwassenen (BRBjojo)
# MISS   Bundesrepublik Deutschland (BRD)
# MISS   Bundesrat-Drucksache (BR-DR of BR Drs.)
# MISS   Belgische rechtspraak in handelszaken (BRH)
# MISS   Besluit regels inrichtingen voor justitiële kinderbescherming (Brijk)
# MISS   British Yearbook of International Law (Brit Yrbk Inttl L)
# MISS   Besluit registratie justitiële gegevens (B.R.just.geg)
# MISS   Belastingregeling voor het Koninkrijk (BRK)
# MISS   Besluit op de Ruimtelijke Ordening (BRO)
# MISS   Besluit op de ruimtelijke ordening 1985 (Bro 1985)
# MISS   Broederschap der candidaat-Notarissen (Broed.Cand.Not)
# MISS   Broederschap der Notarissen (Broed.Not)
# MISS   Bezoldigingsreglement politie 1958 (OUD) (BRP)
# FOUND  BRT = ['Bovenregionaal', 'Recherche', 'Team']
# MISS   Bruto registerton (BRT)
# MISS   Besluit rechtsbijstand en toevoegingcriteria (BRT)
# MISS   Administratieve rechtspraak overheidsbeschikkingen, thans onder redactie van redactie van J.B.T.M. ten Berge, B.W.N. de Waard, R.J.G.M. Widdershoven, losb., Alphen aan den Rijn, 1976 e.v. (tB/s)
# MISS   Belastingen van rechtsverkeer (BRV)
# MISS   Wetboek van Burgerlijke rechtsvordering (BRv)
# FOUND  BRvC = ['Bijzondere', 'Raad', 'van', 'Cassatie']
# FOUND  BS = ['Belgisch', 'Staatsblad']
# FOUND  BS = ['Burgerlijke', 'Stand']
# MISS   Bijvoegsel van het Staatsblad (BS)
# MISS   (Commissie) Bodemsanering in gebruik zijnde bedrijfsterreinen (BSB)
# MISS   Actie Bodemsanering in gebruik zijnde bedrijfsterreinen (BSB-actie)
# MISS   Balanced Scorecard (BSC)
# MISS   Besluit op de stads- en dorpsvernieuwing (BSDV)
# FOUND  BSG = ['Bureau', 'Secretaris', 'generaal']
# MISS   Besluit Buitengewoon Strafrecht (B.Sr.)
# MISS   Bovine Somatotroptine (BST)
# MISS   Bijvoegsel tot het Staatsblad (B.Stb.)
# MISS   Besluit stortverbod afvalstoffen (BSV)
# MISS   Bijzondere strafwetten (BSW)
# MISS   Binnenschepenwet (wet van 30 september 1981, Stb. 678) (BSW)
# MISS   Boswet (wet van 20 juli 1961, Stb. 256) (Bsw)
# MISS   Bureau voor Technische Bijstand (BTB)
# MISS   Bureau voor Technische Bijstand van de Europese Commissie (BTBEC)
# MISS   Bundestag-Drucksache (BT-Dr of BT Drs.)
# MISS   Besluit toezicht effectenverkeer 1995 (Bte 1995)
# MISS   Belgisch Tijdschrift voor Internationaal Recht/Revue Belge de droit International (BTIR)
# FOUND  BTJ = ['Besluit', 'tenuitvoerlegging', 'jeugdstrafzaken']
# MISS   Benelux-Bureau voor tekeningen of Modellen (BTMB)
# MISS   Benelux-verdrag inzake Tekeningen of Modellen (BTMV)
# MISS   Eenvormige Beneluxwet inzake tekeningen of modellen (BTMW)
# MISS   Benelux-verdrag inzake de tenuitvoerlegging van rechterlijke beslissingen in strafzaken (BTS)
# MISS   Belgisch tijdschrift voor sociale zekerheid (BTSZ)
# MISS   Haags Betekenisverdrag 1965 (BTV)
# MISS   Belasting toegevoegde waarde (b.t.w. of btw)
# MISS   B.T.W.-Revue (BTW-Revue)
# MISS   Besluit uitbreiding en beperkte kring van verzekerden volksverzekering (BUB)
# MISS   Wet bedreigde uitheemse dier- en plantensoorten (BUD of BUDEP)
# FOUND  BUGM = ['Besluit', 'uitvoering', 'gemeentelijk', 'milieubeleid']
# MISS   Buitenlandse rechtstijdingen / documentation juridique étrangère / Internationale rechtsdocumentatie (Buitenl Rechtst)
# MISS   Bulletin des arrêts de la cour de cassation (Bull)
# MISS   Bulletin des assurances (Bull ass)
# MISS   Bulletin der Belastingen (Bull Bel)
# MISS   Bulletin Benelux (Bull Benelux of Bull. Ben)
# MISS   Bulletin van het bestuur der strafinrichtingen / Bulletin de l'administration péenitentiaere (Bull Best Strafinr)
# MISS   Bulletin association Benelux pour le droit des marques et modèles / Bulletin Benelux vereniging van merken- en modellengemachtigden (Bull BMM)
# MISS   Bulletin des arrêts de la cour de Cassation (Bull Cass)
# MISS   Bulletin des arrêts des cambres civiles de la Cour de cassation (Bull. Civ)
# MISS   Bulletin des contributions (Bull contr)
# MISS   Bulletin des chambres criminelle de la cour de cassation (Bull Crim)
# MISS   Bulletin of Czechoslovak Law (Bull Czech L)
# MISS   Bulletin van de Europese Gemeenschappen (Bull EG)
# MISS   Bulletin Fiduciare (Bull fid)
# MISS   Bulletin voor fiscaal en financieel recht (Bull Fisc Fin R)
# MISS   Bulletin van de Nationale Federatie der Gemeentesecretarissen van België (Bull Gem Secr)
# MISS   Bulletin van de Handelsreglementering (Bull Handelsregl)
# MISS   Bulletin d'information de l'association (Bull inf ass sécr soc)
# MISS   Bulletin d'information. institut des experts-comptables (Bull inf IEC)
# MISS   Bulletin d'information. institut des réviseur d'enterprice (Bull inf IRE)
# MISS   Bulletin van het Instituut voor arbeidsrecht (Bull Inst Arb)
# MISS   Bulletin législatif Belge (Bull lég b)
# MISS   Bulletin officiel des lois et arrêtés royaux de la Belgique (Bull off)
# MISS   Bulletin social des industriels (Bull soc)
# MISS   Bulletin van het bestuur der strafinrichtingen (Bull Straf)
# MISS   Bulletin trimestriel Belge du droit comparé (Bull trim b dr comp)
# MISS   Bulletin usuel des lois et arrêtés concernant l'administration générale (Bull us)
# MISS   Bulletin van het verbond van Belgische ondernemingen (Bull VBO)
# MISS   Bureau voor Muziek- en Auteursrecht (BUMA)
# MISS   Bundeling Particulier Initiatief Stadsvernieuwing (BUPAS)
# MISS   Internationaal Verdrag inzake burgerrechten en politieke rechten (BUPO-Verdrag)
# MISS   Bureau tot bescherming en handhaving van foto- en auteursrechten (BURAFO)
# MISS   Burgerlijke stand (Bursta)
# MISS   Benelux Uitleverings- en Hulpverdrag (BUV)
# MISS   Buitenlandse Zaken (BUZA)
# MISS   Besloten vennootschap met beperkte aansprakelijkheid (BVBA of BV)
# MISS   Bedrijfsvereniging (Bv)
# MISS   besloten vennootschap (BV of b.v.)
# MISS   Bevrachtingsvoorwaarden 1952 (BV)
# MISS   bijvoorbeeld (b.v.)
# MISS   beleidsinformatie en voorlichting (B & V)
# MISS   Besluit vergunningaanvraag (BVA)
# MISS   Associatie Nederlandse Adverteerders (BVA)
# MISS   Binnenlandse Veiligheidsdienst (BVD)
# MISS   Bijzondere voorschriften Douane en Accijnzen (BVDA)
# FOUND  BVDP = ['Besluit', 'vergoeding', 'dienstreizen', 'politie']
# MISS   Beroepsonderwijs en Volwasseneneducatie (BVE)
# MISS   Bureau van de Vertegenwoordiging van de Europese Commissie (BVEC)
# MISS   Bundesverfassungsgericht (BVerfG)
# MISS   Gesetz über das Bundesverfassungsgericht (BverfGG)
# MISS   Besluit vergoedingen rechtsbijstand (B.verg.R.B.)
# MISS   Bundesverwaltungsgericht (BVerwG)
# MISS   Besloten vennootschap met beperkte aansprakelijkheid in oprichting (BV i.o.)
# MISS   Besluit vormingswerk voor jeugdigen (BVJ)
# FOUND  BVL = ['Bijdrageregeling', 'Vakopleiding', 'Leerplichtwezen']
# FOUND  BVN = ['Breedband', 'Video', 'Net']
# MISS   Bedrijfsvoeringsoverleg (BVO)
# MISS   Besluit vergoedingen rechtsbijstand (BVRB)
# FOUND  BVVP = ['Besluit', 'vergoeding', 'verplaatsingskosten', 'politie']
# MISS   Burgerlijk Wetboek (BW of B.W.)
# MISS   Bestuurswetenschappen (BW of BWS)
# MISS   Beroepswet (Bw)
# MISS   Burgerlijk Wetboek van 1838 (BW (oud))
# MISS   Beginselenwet Gevangeniswezen (BWG)
# MISS   Burgerlijk Wetboek, Internationale regelingen (BW Int.reg.)
# MISS   Beginselenwet voor de kinderbescherming (Bwk)
# MISS   Besluit wapens en munitie (BWm)
# MISS   Burgerlijk Wetboek van de Nederlandse Antillen (BWNA)
# MISS   Besluit Werkloosheid onderwijs- en onderzoekspersoneel (BWOO)
# FOUND  BWS = ['Besluit', 'woninggebonden', 'subsidies']
# MISS   Bouw- en Woningtoezicht (BWT)
# MISS   Haags bewijsverdrag 1970. Verkrijging bewijs in buitenland (BWV)
# MISS   Brandweetwet (BWW)
# MISS   Benelux-Gerechtshof (Bxh.)
# FOUND  BZ = ['Binnenlandse', 'zaken']
# FOUND  Bz = ['bijstandsverlening', 'zelfstandigen']
# MISS   Afdeling besmettelijke ziekten, Drankwet en Geneesmiddelen (B.Z.D.G.)
# MISS   Ministerie van Binnenlandse Zaken en Koninkrijksrelaties (BZK)
# FOUND  B.Z.V. = ['Biologisch', 'Zuurstof', 'Verbruik']
# MISS   Bloembollenziektewet (BZW)
# MISS   beziehungsweise (bzw)
# MISS   Conclusies (Rechtspraak van de Week) (C)
# MISS   Codex Iustinianus (C)
# MISS   caput, hoofdstuk (c.)
# MISS   contre (c.)
# MISS   (Brits) Court of Appeals (CA)
# MISS   (Amerikaans) Court of Appeals (Circuitaanduiding (CA(U.S.A. evt met nummer))
# FOUND  CA = ['Centrale', 'Autoriteit']
# MISS   circa (ca.)
# MISS   cum annexis (met bijbehoren) (c.a.)
# MISS   Court of Appeal (C.A.)
# MISS   Centraal Arbeidsbureau (CAB)
# FOUND  CABR = ['Centraal', 'Archief', 'Bijzondere', 'Rechtspleging']
# MISS   Consultatiebureau voor Alcohol en Drugs (CAD)
# MISS   Wet beperking cadeaustelsel (Cadeaust.)
# FOUND  CAdH = ['Centrum', 'Anti', 'discriminatie', 'Homoseksualiteit']
# MISS   Comité ad hoc sur les aspects juriques de l'asile territorial des réfugiés (CAHAR)
# MISS   Les cahier constitutionels (Cah Const)
# MISS   Les Cahiers de droit (Cah Dr)
# MISS   Cahier de droit Européen (Cah Dr Eur)
# MISS   Cahier de droit familial (Cah dr fam)
# MISS   Cahier de droit fiscal international (Cah dr fisc int)
# MISS   Cahier de droit juduciare (Cah Dr Jud)
# MISS   Cahier voor rechtshulp (Cah Rechtshulp)
# FOUND  CAI = ['Centraal', 'Antenne', 'Inrichting']
# MISS   College van advies voor de justitiële kinderbescherming (CAJ)
# MISS   West's Californian Reporter (Cal. Rprt.)
# MISS   California Reports, Second Series (Cal. 2d.)
# MISS   California Reports, Third Series (Cal. 3e.)
# MISS   Collectieve Arbeidsovereenkomst (CAO of C.A.O. of c.a.o. of cao)
# MISS   caput, hoofdstuk (cap.)
# MISS   Capaciteitsuitbreiding Justitiële Inrichtingen (CAP'98)
# MISS   Commissie van Advies voor Post en Telecommunicatie (CAPT)
# MISS   Centrale Adoptieraad (CAR)
# FOUND  CAR = ["Cremer's", 'Administrative', 'Rechtspraak']
# FOUND  CAR = ['Construction', 'All', 'Risk']
# MISS   cargadoor (Carg.)
# MISS   Cour de Cassation (Hof van verbreking) Brussel (Cass.)
# MISS   cassatie (cass.)
# MISS   beroep in cassatie verworpen (cass. verw.)
# MISS   Convention Additionelle bij de CIV (CAV of CACIV)
# MISS   Centraal Bestuur voor de Arbeidsvoorziening (CBA)
# MISS   Centrale Betalingsadministratie (CBA)
# MISS   Centraal bureau aanmelding en plaatsing (CBAP)
# MISS   College voor Beroep voor het bedrijfsleven (CBB)
# MISS   Centrum voor beroepsoriëntatie en beroepsuitoefening (CBB)
# MISS   Centraal Bureau van Bijstand Notarissen (CBBP)
# FOUND  CBF = ['Centraal', 'Bureau', 'Fondsenwerving']
# MISS   Centraal betaalkantoor rijksbelasting (CBK)
# FOUND  CBL = ['Commissie', 'beheer', 'landbouwgronden']
# FOUND  CBM = ['Centraal', 'bureau', 'motorrijtuigenbelastng']
# MISS   Correspondentieblad Broederschap der Notarissen (tot ultimo 1967) (CBN)
# FOUND  CBR = ['Centraal', 'Bureau', 'Rijvaardigheidsbewijzen']
# MISS   College van Burgemeester en Schepenen (België) (CBS)
# MISS   Centraal Bureau voor de Statistiek (CBS)
# MISS   College van beroep studiefinanciering (Cbs of Cbsf)
# MISS   College van beroep voor het bedrijfsleven (CBvB)
# MISS   Code Civil of Code civiel (Code Napoleon) (CC of C.C. of Cc)
# FOUND  CC = ['code', 'commissie']
# FOUND  C.C. = ['Corps', 'Consulaire']
# MISS   Code de Commerce (C, de c. of C de C)
# MISS   Commissie voor Consumentenaangelegenheden van de SER (CCA)
# FOUND  CCC = ['Centrale', 'Cultuurtechnische', 'Commissie']
# FOUND  CCC = ['Constitutio', 'Criminals', 'Carolina']
# MISS   Code Civile Italiano (CCI of C.c.i.)
# MISS   Consultative Committee for International Telegraph and Telephone (CCITT)
# MISS   Code Civil du Québec (CCQ)
# MISS   Centrale Commissie voor de Rijnvaart (CCR)
# MISS   Centrale commissie voor de statistiek (CCS)
# MISS   Zwitserse Code Civiel (C.C.S.)
# MISS   Coördinatiecommissie stadsvernieuwing (CCSV)
# MISS   Consumenten Contactorgaan (CCO)
# MISS   Convention Internationale relative au Contrat de Voyage (CCV)
# FOUND  CCZ = ['Centrale', 'Commissie', 'Zelfstandige']
# FOUND  CD = ['Corps', 'Diplomatique']
# MISS   Collection of Decisions of the European Commission on Human Rights (CD)
# FOUND  CDA = ['Christen', 'Democratisch', 'Appel']
# FOUND  CdC = ['Cour', 'de', 'Cassation']
# FOUND  CdC = ['Code', 'de', 'Commerce']
# MISS   Chambre des Députés (Luxemburg) (CdD)
# MISS   Cahiers de droit Européen (CDE)
# MISS   Code d'Instruction Criminelle (CdIC of Cd'IC)
# MISS   Centrale Dienst voor In- en Uitvoer (CDIU)
# MISS   commissaris van de Koningin (CdK)
# FOUND  CdO = ['Code', 'de', 'Obligation']
# MISS   Croniques de droit Public / Publiekrechtelijke kronieken (CDPK)
# FOUND  CDPP = ['Code', 'de', 'procédure', 'Pénale']
# MISS   Communautair Douanewetboek (CDW)
# MISS   Centrale Directie Wetenschapsbeleid en Ontwikkeling (MvJ) (CDWO)
# MISS   Committee of Experts of the International Labour Organization (CE)
# MISS   Conseil d'Etat (CE)
# MISS   Council of Europe (C.E.)
# MISS   Commission of the European Communities (CEC)
# MISS   Comité Européen pour les Problémes Criminels (CECP)
# MISS   Confederation of European Computer User Associations (CECUA)
# MISS   Publications de la Cour Européenne des droits de l'homme: Arrêts et décicions, Greffe de la Cour (CEDH série A)
# MISS   Publications de la Cour Européenne des droits de l'homme: Mémoires, Plaidoiries et Documents, Greffe de la Cour (CEDH série B)
# MISS   Communitatis European Lex (Databank EG-wetgeving (CELEX)
# MISS   Convention Européenne relative au lieu de paiement des obligations (CELP)
# MISS   Convention Européenne relative aux obligations en monnaie étrangère (CEME)
# MISS   Europese Conferentie van Ministers van Verkeer (CEMT)
# MISS   Comité Européen de Normalisation (CEN)
# MISS   Comité Européen de Normalisation Electrotechnique (CENELEC)
# MISS   Comprehensive Environmental Response and Liability Act (CERCLA)
# FOUND  CEP = ['Centraal', 'Economisch', 'Planbureau']
# MISS   Belgisch Centrum voor Studie en Praktijk van Nationale- en Internationale Arbitrage (CEPINA)
# MISS   Comptabilité et fiscalité pratiques (C&FP)
# MISS   Convention on the Elimination of all forms of Radial Discrimination (CERD)
# MISS   certificaat (cert.)
# MISS   Code Européen des voies de navigation intérieure (CEVNI)
# MISS   cum expensis (met kosten) (c.ex.)
# MISS   Cost and freight (Onkosten en vracht zijn voor rekening verkopers) (C.F. of c.& f.)
# MISS   confer (vergelijk) (cf.)
# MISS   chloorfluorkoolwaterstoffen (cfk's)
# MISS   conform (in gelijke zin) (cfm)
# FOUND  CG = ['Centrale', 'Grondkamer']
# FOUND  CG = ['Consultative', 'Group']
# MISS   Corporate Governance (CG Nieuwsbrief)
# FOUND  CGB = ['Commissie', 'gelijke', 'behandeling']
# MISS   Commissie gelijke behandeling van mannen en vrouwen in de burgerlijke openbare dienst (CGBO)
# MISS   Commissie Gemeentelijke Compatibiliteitsvoorschriften (CGCV)
# MISS   Conditions Génerales pour les Démenagements Internationaux (CGDI)
# MISS   Centraal Georganiseerd Overleg in Ambtenarenzaken (CGOA)
# MISS   Law Reports, Chancery Division (Gbr) (Ch)
# MISS   Chambre of Chambres (civil, social of mixte) (Ch. of Ch.(civ./scc./mixte))
# MISS   Chancery, English Cases (Ch.)
# MISS   Chapter (Ch.)
# MISS   Centrale van Hogere Ambtenaren (C.H.A.)
# MISS   Chancery Division, Appeal Case (Law Reports) (Ch.App)
# MISS   Courrier hebdomadaire du CRISP (CH CRISP)
# MISS   Chancery Division (ChD)
# FOUND  CHR = ['Commissie', 'Hoofdstructuur', 'Rijksdienst']
# MISS   Chroniques de droit social (Chr D S)
# MISS   chronique (Chron.)
# MISS   Curie (Ci)
# MISS   Commissie Inning, beheer en Repartitie Auteursrechtgelden (CIBRA)
# MISS   Criminele Informatiedienst (CID)
# FOUND  CIE = ['Criminele', 'Inlichtingen', 'Eenheid']
# MISS   Commissie (Cie.)
# MISS   Commission internationale de l'état Civil (CIEC)
# MISS   Centrum voor Intellectueel Eigendomsrecht (CIER)
# MISS   Commissie voor Verzoekschriften (Cie. Verz.schr.)
# MISS   Cost Insurance Freight (Onkosten, vracht en Assurantie zijn voor rekening verkopers) (C.I.F. of c.i.f.)
# FOUND  c.i.f.i.c. = ['cost', 'insurance', 'freight', 'interest', 'commission']
# MISS   Coördinatiecommissie Internationale Milieu-aangelegenheden (CIM)
# MISS   Convention Internationale concernant le transport des Marchandises par chemins de fer 1961 (CIM)
# MISS   Régles uniformes concernant le contrat de transport international ferroviaire des marchandises (Uniforme regelen betreffende de overeenkomst van internationaal spoorwegvervoer van goederen) (CIM)
# MISS   Centraal Instituut voor Midden- en Kleinbedrijf (CIMK)
# FOUND  CIOT = ['Centraal', 'Informatiepunt', 'Onderzoek', 'Telecommunicatie']
# MISS   Circuit Court of Appeals (Cir.)
# MISS   circulaire (circ.)
# MISS   Circulaire voor de zeemacht (Circ.Z.)
# MISS   Confédération Internationale des Sociétés d'Auteurs et Compositeurs (CICAC)
# MISS   United Nations Convention on the International Sale of Goods (Weens Koopverdrag) (CISG)
# MISS   citato (als aangehaald) (cit.)
# MISS   citato loco (op aangehaalde plaats) (cit.loc.)
# MISS   Comité International Technique d'Experts Juridiques Aériens (CITEJA)
# MISS   Convention on International Trade in Endangered Species of wild flora and fauna (CITES)
# MISS   Centraal Instituut voor toetsontwikkeling (CITO)
# MISS   Convention Internationale concernant le transport des Voyageurs et des bagages par chemin de fer 1961 (CIV)
# MISS   Cour de Cassation Chambre civile (Civ.)
# FOUND  CJ = ['Chief', 'Justice']
# MISS   Cahier van de Jurist / cahier du juriste (CJ)
# FOUND  CJIB = ['Centraal', 'Justitieel', 'Incasso', 'Bureau']
# MISS   Civil Jurisdiction and Judgements Act (CJJA)
# FOUND  CJV = ['Calvinistische', 'Juristen', 'Vereniging']
# FOUND  CJW = ['Cursussen', 'jeugdige', 'werklozen']
# MISS   cum laude (met lof) (c.l.)
# MISS   Jurisprudence des tribunaux. recueil critique et doctrinal fondé par Cloet et Bonjaen (Cl et B)
# MISS   Centrale landinrichtingscommissie (CLC)
# MISS   clericatus (Cler)
# FOUND  CLIM = ['Centraal', 'Landelijk', 'Informatiepunt', 'Milieudelicten']
# FOUND  CLJ = ['Cambridge', 'Law', 'Journal']
# FOUND  CLJ = ['Consumer', 'Law', 'Journal']
# MISS   Convention relative à la Limitation de la responsabilité des propriétaires de bateaux de Navigation Intérieure 1973 (CLN)
# MISS   Convention sur la limitation de la responsabilité en navigation intérieure (CLNI)
# FOUND  CLR = ['Commonwealth', 'Law', 'Reports']
# MISS   journal de droit international. Clunet (Clunet)
# FOUND  CLY = ['Current', 'Law', 'Yearbook']
# MISS   Committee of Ministers of the Council of Europe (CM)
# MISS   Christelijke Middenstandsbond (CMB)
# FOUND  CMI = ['Comité', 'Maritime', 'International']
# MISS   Common Market Law Review of Reports (CMLR(ev))
# MISS   Convention relative au contrat de transport international de Marchandises par Route 1956 (CMR)
# FOUND  Cmt. = ['Centraal', 'Medisch', 'Tuchtcollege']
# MISS   cum notis (met aantekeningen) (c.n.)
# MISS   Committee on Narcotic Drugs (CND)
# FOUND  CNV = ['Christelijk', 'Nationaal', 'Vakverbond']
# MISS   Code Fédéral des Obligations (CO)
# MISS   Compagnon/Corporation (Co.)
# FOUND  COA = ['Contactcentrum', 'Onderwijs', 'Arbeid']
# MISS   Centraal Orgaan opvang Asielzoekers (COA)
# FOUND  Cob = ['Commissie', 'onderwijs', 'bedrijfsleven']
# ...
# MISS   Wet Tuchtrechtspraak Bedrijfsorganisatie (Wet TBO)
# MISS   Wet terugdringing ziekteverzuim (Wet TZ)
# MISS   Wet vervroegde afschrijving milieu-investeringen (Wet Vamil)
# MISS   Wet vergunningen en algemene regels voor inrichtingen (Wet Var)
# MISS   Wet op de vermogensbelasting 1964 (Wet VB)
# MISS   Wet vermindering afdracht loonbelasting en premie volksverzekering (Wet verm.afd.LB en premie VZ)
# MISS   Wet vervoersvoorwaarden openbaar vervoer (Wet VOV)
# MISS   Wet op de Vennootschapsbelasting 1969 (Wet VPB of Wet Vpb)
# MISS   Wet waardering onroerende zaken (Wet woz)
# MISS   Wet op de organisatie Zorgonderzoek Nederland (Wet ZON)
# FOUND  WEU = ['West', 'Europese', 'Unie']
# FOUND  WEV = ['Wet', 'Europese', 'verkiezingen']
# MISS   World Federation of Advertisers (WEF)
# FOUND  WFB = ['Wet', 'financiële', 'bijstand']
# FOUND  Wfbb = ['Wet', 'financiële', 'betrekkingen', 'buitenland']
# MISS   Wet op de formeel buitenlandse vennootschappen (WFBV)
# FOUND  WFN = ['Wet', 'fiscaal', 'noodrecht']
# FOUND  WFO = ['Wet', 'financiële', 'ondersteuning']
# MISS   Weekblad voor Fiscaal Recht (WFR of W.F.R.)
# FOUND  Wfv = ['Wet', 'financiering', 'volksverzekeringen']
# MISS   wettelijke gemeenschap van goederen (w.g.)
# FOUND  w.g. = ['was', 'getekend']
# MISS   Wet gewetensbezwaren militaire dienst (WG)
# MISS   Wet gelijke behandeling van mannen en vrou­wen (WGB)
# FOUND  WGB = ['Wet', 'Geneeskundige', 'Behandelingsovereenkomst']
# FOUND  WGB = ['Wet', 'Goederenvervoer', 'Binnenscheepvaart']
# MISS   Weekblad voor Gemeentebelangen (WGB.)
# MISS   Wet Gemeenschappelijke Basisadministratie Persoonsgegevens (WGBAP)
# MISS   Wet inzake geneeskundige behandelingsovereenkomst (WGBO)
# MISS   Wet giraal effectenverkeer (WGE of Wge)
# MISS   Wet gelijke behandeling mannen en vrouwen (W.gelijke beh.)
# FOUND  WGG = ['Wet', 'gehandicaptenvoorzieningen', 'gemeenten']
# MISS   Wet geluidhinder (Wgh)
# MISS   Wet houdende bijzondere bepalingen voor de geconsolideerde jaarrekening (WGJ)
# MISS   Wet Gelijk loon voor vrouwen en mannen (WGL)
# MISS   Wet gewetensbezwaren militairen (WGMD)
# MISS   Wereldgezondheidsorganisatie (WGO)
# MISS   Wet grensoverschrijdend vervoer van aan bederf onderhevige levensmiddelen (WGOV)
# MISS   Wet gemeenschappelijke regelingen (Wgr of WGR)
# FOUND  WGS = ['Wet', 'Gevaarlijke', 'Stoffen']
# MISS   Wet op de geneesmiddelenvoorziening (WGV)
# MISS   Wet Goederenvervoer over de Weg (WGW)
# MISS   Wet op het hoger beroepsonderwijs (WHBO)
# MISS   Wasserhaushaltsgesetz (WHG)
# FOUND  WHI = ['Wet', 'herverzekering', 'investeringen']
# FOUND  WHLB = ['Wet', 'heffingen', 'luchtverontreiniging', 'benzine']
# FOUND  WHO = ['World', 'Health', 'Organisation']
# MISS   Wet hygiëne en veiligheid zwemgelegenheden (WHVZ)
# MISS   Wet op het hoger onderwijs en het wetenschappelijk onderzoek (WHW)
# MISS   Wet herverdeling wegenbeheer (WHWB)
# MISS   Wet van 5 juli 1979 tot herziening van de Wet op de ondernemingsraden (WHWOR)
# MISS   Wet op de internationale bestandsverlening bij de heffing van belastingen (WIB of WIBH)
# MISS   werkgeversinspectie en -beroepszaken (wibz)
# MISS   Wet op de Identificatieplicht (WID of W.ident.pl.)
# MISS   Wet inzake de douane (WID)
# FOUND  WIEP = ['Wet', 'incompatibiliteiten', 'Europees', 'Parlement']
# MISS   Wet identiteitsvervalsing bij financiële dienstverlening (Wif)
# MISS   Wet invoering gelijke behandeling van mannen en vrouwen in de AOW alsmede aanpassing van de overige volksverzekeringen (WIGB)
# FOUND  WIK = ['Wet', 'inkomstenvoorziening', 'Kunstenaars']
# MISS   Wet in- en doorvoer van kippen- en eendeneieren (WIKE)
# FOUND  WIM = ['Wet', 'Inburgering', 'Minderheden']
# FOUND  WIM = ['Wet', 'immunisatie', 'militairen']
# MISS   Winkeltijdenwet (Winkelt.w.)
# MISS   World Intellectual Property Organisation (OMPI) (WIPO)
# MISS   Wet inversteringsrekening (WIR)
# MISS   Zeitschrift für Wirtschaft, Steuer und Strafrecht (Wistra)
# MISS   Wet buitengewoon pensioen Indisch verzet (WIV)
# MISS   Wet op de Inlichtingen en Veiligheidsdiensten (WIV of WIVD)
# FOUND  WIW = ['Wet', 'inschakeling', 'werkzoekende']
# FOUND  Wiw = ['Wet', 'inzake', 'wisselkantoren']
# MISS   Wet op de Jaarrekeningen (WJ)
# MISS   Wet op de Justitiële Documentatie en op de verklaring omtrent het gedrag (WJD of Wjdvog)
# MISS   Werkgroep Informatie uitwisseling Gewestelijk Arbeidsbureau - Gemeentelijke Sociale Dienst (WJGG)
# MISS   Wet op de jeugdhulpverlening (WjHV of Wjhv)
# MISS   Wet op de jaarrekeningen van ondernemingen (voormalig) (WJO)
# FOUND  WJS = ['Wet', 'Justitie', 'subsidies']
# MISS   Wet op de justitiële documentatie en op de verklaring omtrent het gedrag (W.just.doc.)
# FOUND  WK = ['Weens', 'Koopverdrag']
# MISS   Wet Ketenaansprakelijkheid (WKA)
# MISS   verklaring wet ketenaansprakelijkheid (wka-verkl.)
# MISS   Wetgevingskwaliteitsbeleid (WKB)
# MISS   Wet op de kansspelen (WKS)
# MISS   Wet voorzieningen inzake Luchtvervoer (WL)
# MISS   Wet op de Loonvorming (WL)
# MISS   Wet op de Lijkbezorging (W.L. of Wlb)
# FOUND  WLA = ['Wet', 'limitering', 'alimentatie']
# MISS   Weekly Law Review (WLR of W.L.R.)
# MISS   Wet Luchtverkeer (WLV)
# MISS   Wet inzake de Luchtverontreiniging (Wlv of W.L.V.)
# MISS   Wet op de Loonvorming (Wlv)
# MISS   Waterleidingwet (WLW)
# MISS   Wet op het leerlingenwezen (WLW)
# FOUND  WM = ['Wertpapier', 'Mitteilungen']
# MISS   Wet milieubeheer (Wm of Wmb)
# FOUND  WMCO = ['Wet', 'melding', 'collectief', 'ontslag']
# MISS   Wet op de medische hulpmiddelen (WMH)
# MISS   Wet militaire strafrechtspraak (W.mil.straf.spr.)
# FOUND  WMK = ['Wet', 'Medische', 'keuringen']
# MISS   Wet minimumloon- en vakantiebijslag (WML)
# MISS   Wet houdende vaststelling van minimumeisen voor het houden van legkippen (WML)
# MISS   Wet minimumloon en -vakantiebijslag (WMM)
# FOUND  WMO = ['Wet', 'medezeggenschap', 'onderwijs']
# FOUND  WMOT = ['Wet', 'melding', 'ongebruikelijke', 'transacties']
# FOUND  WMR = ['Wet', 'Misleidende', 'Reclame']
# MISS   Wet milieugevaarlijke stoffen (WMS of Wms)
# FOUND  WMS = ['Wetboek', 'Militair', 'Strafrecht']
# MISS   Wet militaire Strafrechtspraak (WMSD)
# FOUND  WMT = ['Wet', 'Militair', 'Tuchtrecht']
# FOUND  WMT = ['Wet', 'mobiele', 'telecommunicatie']
# MISS   Wet gelijke behandeling van mannen en vrouwen (W.m/v)
# MISS   Wet melding zeggenschap in ter beurze genoteerde vennootschappen (Wmz)
# MISS   Weekblad voor het Notariaat (WN)
# MISS   Wet op het Notarisambt (W.N.)
# MISS   Wet op het notarisambt (1999) (WNA of Wna)
# MISS   Weekblad voor de Bond van Gemeenteambtenaren (WNBG of WNBGA)
# MISS   waarnemend (wnd)
# MISS   Rijkswet op het Nederlanderschap en het ingezetenenschap (W.Ned of W.Ned.schap)
# FOUND  WNo = ['Wet', 'Nationale', 'ombudsman']
# MISS   Wet op het Notarisambt (W.Not.ambt.)
# MISS   Wet op de naburige rechten (WNR)
# MISS   Weekblad voor Notarisambt en Registratie (WNR)
# MISS   Wetsontwerp (WO of w.o.)
# MISS   Weekoverzicht Raad van State (WO)
# MISS   waaronder (w.o.)
# FOUND  WOA = ['Wet', 'overgangsregeling', 'arbeidsongeschiktheidsverzekering']
# MISS   Wet op de architectentitel (WOA)
# MISS   Wet overgangsregeling arbeidsongeschiktheidsverzekering (WOAO)
# MISS   Wet op de Omzetbelasting (WOB)
# MISS   Wet openbaarheid van bestuur (WOB of Wob)
# MISS   Wet houdende tijdelijke fiscale maatregelen ter bevordering van het gebruik van ongelode benzine en de aankoop van schone en van beperkt schone auto's (WOB)
# FOUND  WOBOP = ['Wet', 'Overeenkomst', 'Binnenlands', 'Openbaar', 'Personenvervoer']
# FOUND  WOD = ['Wet', 'Orgaan', 'Donatie']
# MISS   Wetenschappelijk Onderzoek- en Documentatiecentrum (WODC)
# FOUND  W.o.d.K. = ['Wet', 'op', 'de', 'Kansspelen']
# MISS   Wet op de Geneesmiddelenvoorziening (WOG)
# MISS   Wet op de gevaarlijke werktuigen (WOGW)
# FOUND  WohC = ['Wet', 'op', 'het', 'Consumentenkrediet']
# MISS   Wet op de Kansspelen (WOK)
# MISS   Wet op het levensverzekeringsbedrijf (WOL)
# MISS   Wet overheidsopdrachten voor levering van producten (WOLP)
# MISS   Woningwet (Won.w. of Woningw.)
# MISS   Woonruimtewet (Woonr.w.)
# MISS   Wet Oorlogsstrafrecht (W.Oorl.sr)
# MISS   Wet inzake de uitoefening van de vrijheid van godsdienst en van levensovertuiging en van het recht tot vergadering en betoging (W.openb.manif.)
# MISS   Wet op de Huurcommissie (W.o.d.Huurcomm.)
# MISS   Wet op de ondernemingsraden (WOR)
# MISS   Wet op het schadeverzekeringsbedrijf (WOS)
# FOUND  WOTS = ['Wet', 'Overdracht', 'Tenuitvoerlegging', 'Strafvonnissen']
# MISS   Wet op de telecommunicatievoorzieningen (WOTV)
# MISS   Wet op de Open Universiteit (WOU)
# MISS   Wet op de Onderwijsverzorging (WOV)
# FOUND  WOW = ['Wet', 'Overeenkomst', 'Wegvervoer']
# FOUND  WOZ = ['Waardering', 'Onroerende', 'Zaken']
# FOUND  WOZ = ['Wet', 'Olieverontreiniging', 'Zeewater']
# FOUND  WP = ['Wet', 'personenvervoer']
# MISS   Wet productenaansprakelijkheid (WPA)
# MISS   World Pensions Committee-schaal (WPC-schaal)
# FOUND  WPE = ['Wet', 'Parlementaire', 'Enquête']
# MISS   Weekblad voor Privaatrecht, Notariaat en Registratie (WPNR)
# MISS   Wet Politieregister (WPolR)
# MISS   Wet persoonsregistratie (WPR)
# MISS   Wet op de Pensioen- en Uitkeringsraad (WPUR)
# MISS   Woonrecht: Tijdschrift voor Woon- en Bedrijfsruimterecht (WR)
# MISS   Wet op de Registratie (W.R.)
# MISS   Wet op de Rechtsbijstand (WRB of Wrb)
# MISS   Woonruimtebeschikking (WRB)
# FOUND  WRD = ['Wet', 'rechtstoestand', 'dienstplichtigen']
# MISS   Wet op de Ruimtelijke Ordening (WRO)
# MISS   Wet op de rechtsbijstand on- en minvermogenden (WROM)
# MISS   Wettbewerb in Recht und Praxis (WRP)
# MISS   Wetenschappelijke Raad voor het Regeringsbeleid (WRR)
# MISS   Woonruimterecht (WRR)
# MISS   Wet op de Raad van State (WRvST)
# MISS   Woonruimtewet (WRW)
# MISS   Warenwet (WRW)
# MISS   Het Waterschap (WS)
# FOUND  WSB = ['Wet', 'Sloopregeling', 'Binnenvaart']
# MISS   Wet op het specifiek cultuurbeleid (WSC)
# MISS   Wet op de Stads- en Dorpsvernieuwing (WSD)
# MISS   Wet op de Studiefinanciering (WSF)
# FOUND  WSNP = ['Wet', 'Schuldsanering', 'Natuurlijke', 'Personen']
# FOUND  WSNS = ['Weer', 'samen', 'naar', 'school']
# MISS   Wetboek van Strafrecht (Wsr.)
# MISS   Wet Structurele Sanering Binnenvaart (WSS of WSSB)
# MISS   Wet op de Sociale Verzekeringsbank (WSV)
# FOUND  WSV = ['Werkgroep', 'Stedelijke', 'Verkaveling']
# MISS   Wet Sociale Werkvoorzieningen 1967 (WSW 1967)
# MISS   Wet toezicht beleggingsinstellingen (WTB of Wtb)
# MISS   Wet op het ter beschikking stellen van arbeidskrachten (WTBA)
# FOUND  WTBZ = ['Wet', 'Tarieven', 'Burgerlijke', 'Zaken']
# MISS   Wet toezicht effectenverkeer 1995 (WTE of Wte)
# FOUND  Wtg = ['Wet', 'Tarieven', 'gezondheidszorg']
# MISS   Wet toezicht kredietwezen (WTK of Wtk)
# FOUND  WTL = ['Wet', 'teboekgestelde', 'luchtvaartuigen']
# MISS   Wet toezicht natura-uitvaartverzekeringsbedrijf (WTN)
# FOUND  WTO = ['World', 'Trade', 'Organization']
# MISS   Wet tarieven in Strafzaken (WTS)
# FOUND  WTS = ['Wet', 'teboekgestelde', 'schepen']
# FOUND  WTS = ['Wet', 'toezicht', 'schadeverzekeringsbedrijf']
# MISS   Wet Telecommunicatievoorzieningen (WTV)
# MISS   Wet toezicht verzekeringsbedrijf 1993 (Wtv of WTVb.)
# FOUND  WTVI = ['Wet', 'tarieven', 'van', 'invoerrechten']
# MISS   Wet op de toegang tot ziektekostenverzekeringen (WTZ)
# FOUND  WUA = ['Wet', 'uitvoering', 'aanbevelingen']
# MISS   Wet op de Universitaire Bestuurshervorming (W.U.B.)
# FOUND  Wubo = ['Wet', 'uitkeringen', 'burger', 'oorlogsslachtoffers']
# MISS   Wet op de uitoefening van de diergeneeskunst (WUD)
# MISS   Wet op de uitoefening van de geneeskunst (WUG)
# FOUND  WUIE = ['Wet', 'uitvoering', 'Internationaal', 'Energieprogramma']
# MISS   Uitvoeringswet EEG-Executieverdrag (W.uitv.EEX)
# MISS   Wet uitvoering voorschriften plaatselijke verordeningen (W.uitv.pl.verord.)
# FOUND  WULbZ = ['Wet', 'Uitbreiding', 'Loondoorbetalingsplicht', 'bij', 'Ziekte']
# MISS   Wet op de uitoefening der tandheelkunst (WUT)
# FOUND  WUV = ['Wet', 'uitkeringen', 'vervolgingsslachtoffers']
# MISS   Wet tot uitvoering van verordeningen no. (11 of 17) van de Raad van de EEG (WUV(11) of (17))
# MISS   Wegenverkeersregeling (WV)
# MISS   wetsvoorstel (w.v.)
# FOUND  WVA = ['Wet', 'verminderde', 'afdracht']
# FOUND  WVB = ['Wet', 'vervoer', 'Binnenvaart']
# MISS   Wetboek van Burgerlijke Rechtsvordering (WvBRv)
# MISS   Ministerie van Welzijn, Volksgezondheid en Cultuur (WVC of WvC)
# FOUND  WVG = ['Wet', 'voorkeursrecht', 'gemeenten']
# FOUND  WVG = ['Wet', 'voorzieningen', 'gezondheidszorg']
# FOUND  WVG = ['Wet', 'voorzieningen', 'Gehandicapten']
# FOUND  WvhN = ['Weekblad', 'voor', 'het', 'Notariaat']
# FOUND  WvhR = ['Weekblad', 'van', 'het', 'Recht']
# MISS   Wet voltooiing eerste fase herziening rechterlijke organisatie (Wvhro 1)
# MISS   Wetboek van Koophandel (WvK of W.v.K.)
# MISS   Wet vrachtprijzen vervoer van kolen en staal (WVKS)
# FOUND  WVL = ['Wet', 'vervreemding', 'landbouwgronden']
# MISS   Wetboek Militair Strafrecht (W.v.M.S.)
# MISS   Wet op het voortgezet onderwijs (WVO)
# MISS   Wet op de verontreiniging Oppervlaktewateren (WVO of Wvo of WVOW)
# MISS   Wegenverkeersreglement (WVR of W.V.R.)
# MISS   Wetboek van Strafrecht (WVS of W.v.S. of WvSR)
# MISS   Wet op de telecommunicatievoorzieningen (WVT)
# MISS   Wet van 22 april 1855 tot regeling en beperking der uitoefening van het regt van vereeniging en vergadering (WVV)
# MISS   Wet voorkoming verontreiniging van de zee door schepen (WVVS)
# MISS   W (WVW of W.v.W.)
# MISS   ex dividend, zonder aandeel in het dividend (x.d.)
# MISS   Yale Law Journal (Yale L.J. of YLJ)
# MISS   Yearbook of the European Convention on Human Rights (YB of Yearbook)
# MISS   Yearbook of European Law (YEL)
# FOUND  YLJ = ['Yale', 'Law', 'Journal']
# MISS   Yearbook of European Law (YrbkEuro L)
# MISS   Yearbook of International Environmental Law (Yrbk Int EnvL)
# MISS   Yearbook of the United Nations (YUN)
# FOUND  z.a. = ['zie', 'aldaar']
# MISS   Zeitschrift für Ausländerrecht und Ausländerpolitik (ZAR)
# MISS   Zentralausschluss der Werbewirtschaft (ZAW)
# MISS   Zeitschrift des Bernichen Juristenvereins (ZBJV)
# MISS   Ziektekostenregeling bijzondere Groepen 1976 (ZBG)
# MISS   Schweizerisches Zentralblatt für Staats- und Gemeindeverwaltung (ZBI)
# MISS   Zelfstandig Bestuursorgaan (ZBO)
# MISS   Zentrale Documentationsstelle der freien Wohlfahrtsplege für Flüchtlinge (ZDWF)
# MISS   Zeebrievenwet (Zeebr.w)
# MISS   Zesde Richtlijn (Zesde Richtl.)
# MISS   Zeitschrift für Europäisches Privaatrecht (ZEuP)
# MISS   Zorg en Verzekering (Z & V)
# MISS   Ziekenfondsraad (ZFR)
# MISS   Zwitserse Franken (ZFS)
# MISS   Zeitschrift für Schweizerisches Recht (ZFSchwR)
# MISS   Ziekenfondswet (ZFW of zfw)
# MISS   Ziekenfondsraad (ZFR)
# MISS   Zivilgesetzbuch (CCS voor Zwitserland) (ZGB)
# MISS   zogenaamd(e) (zgn of zgn.)
# MISS   Zeitschrift für Unternehmens- und Gesellschaftsrecht (ZGR)
# MISS   Zeitschrift für die gesamte strafrechtwissenschaft (ZGSW)
# MISS   Zeitschrift für das gesamte Handelsrecht und Wirtschaftsrecht (ZHR)
# FOUND  z.i. = ['zijns', 'inziens']
# MISS   Openbaar lichaam Zuidelijke IJsselmeerpolders (ZIJP)
# MISS   Zeitschrift für Wirtschaftsrecht und Insolvenzpraxis (ZIP)
# MISS   Ziekenhuisinformatiesysteem (ZIS)
# FOUND  z.j. = ['zonder', 'jaartal']
# MISS   Ziektekostenverzekering (ZKV)
# FOUND  ZM = ['Zittende', 'Magistratuur']
# MISS   Zeitschrift für Neuere Rechtsgeschichte (ZNR)
# MISS   Zeeongevallenwet (ZOW)
# MISS   zie ommezijde (z.o.z.)
# MISS   zonder plaats van uitgave (z.p.)
# MISS   zonder plaatsnaam (z.pl)
# MISS   Zivilprozessordnung (ZPO)
# MISS   Zaaizaad- en Plantgoedwet (wet van 6 oktober 1966, Stb.455) (ZPW)
# MISS   Zeitschrift für Rechtspolitik (ZRP)
# FOUND  z.s.m. = ['zo', 'spoedig', 'mogelijk']
# MISS   Zeitschrift für Schweizerisches Recht (ZSR)
# MISS   Zeitschrift für Schweizerisches Recht, Neue Folge (ZSR NF)
# MISS   Zeitschrift für die gesamte Strafrechtswissenschaft (ZStW)
# MISS   Zeitschrift für Vergeleichender Rechtswissenschaft (ZVglRWiss)
# MISS   Zeitschrist für Verbraucherpolitik (=JCP) (ZVP)
# MISS   Ziektekostenvoorziening Rijkspersoneel (ZVR)
# FOUND  zvt = ['zonder', 'volledige', 'titel']
# MISS   Ziektewet (wet van 5 juni 1913, Stb.240) (ZW)
# MISS   Zegelwet 1917 (Zw)
# MISS   Zwitsers Zivil Gesetsbuch (Zw.Zgb)
# FOUND  zzp = ['zelfstandig', 'zonder', 'personeel']
# MISS   Zeitschrift für ZivilProzess (ZZP)
# MISS   Zaaizaad en Plantgoedwet (ZZPW)

# %% [markdown]
# ### Run on a bunch of free-form document text

# %%
import wetsuite.phrases.abbreviations
import wetsuite.datacollect.db
import wetsuite.helpers.etree

conn = wetsuite.datacollect.db.connect()
curs = conn.cursor()

# %%
curs.execute('SELECT plaintext  FROM cvdr  LIMIT 10000') # TODO: change to wetsuite.data.load() after creating a dataset
per_doc_results = []
for text, in curs:
    result = wetsuite.phrases.abbreviations.find_abbrevs(text)
    #for ab, words in result: # individual results
    #    print( ab, words )
    per_doc_results.append( result )    


### test the cleaning - report only things that were explained the same way in two or more documents
min_doc_occur = 2

report = []
abbrev_count = wetsuite.phrases.abbreviations.count_results( per_doc_results )
for abbrev, words_count in abbrev_count.items():
    for words, count in words_count.items():
        if count >= min_doc_occur:   # the point of that structure: being able to ignore rarer explanations
            report.append( (abbrev, count, ' '.join(words) ) )

report.sort(key=lambda tup: -tup[1]) # sort by count descending
#report.sort(key=lambda tup: (tup[0], -tup[1])) # sort/group by abbreviation alphabetically, then by count descending
for abbrev, count, expl in report:
    print( '%10s   %3d:   %s'%( abbrev, count, expl ) )
# Out:
#        Awb   345:   Algemene wet bestuursrecht
#       Wabo    88:   Wet algemene bepalingen omgevingsrecht
#        Wmo    60:   Wet maatschappelijke ondersteuning
#        Wlz    59:   Wet langdurige zorg
#        APV    46:   Algemene Plaatselijke Verordening
#        CAK    35:   Centraal Administratie Kantoor
#        Wro    35:   Wet ruimtelijke ordening
#        Wgs    34:   Wet gemeentelijke schuldhulpverlening
#        LRK    33:   Landelijk Register Kinderopvang
#        VOG    31:   verklaring omtrent gedrag
#        AVG    31:   Algemene Verordening Gegevensbescherming
#        APV    28:   Algemene plaatselijke verordening
#        CIZ    25:   Centrum Indicatiestelling Zorg
#        VNG    25:   van Nederlandse Gemeenten
#        ZIN    25:   zorg in natura
#        VOG    24:   Verklaring Omtrent Gedrag
#        NHG    23:   Nationale Hypotheek Garantie
#         Wm    22:   Wet milieubeheer
#        Apv    19:   Algemene plaatselijke verordening
#       WSNP    18:   Wet Schuldsanering Natuurlijke Personen
#        AVG    18:   Algemene verordening gegevensbescherming
#        ADL    18:   algemene dagelijkse levensverrichtingen
#       PPMO    17:   Periodiek Preventief Medisch Onderzoek
#        CVV    16:   collectief vraagafhankelijk vervoer
#        Wbp    16:   Wet bescherming persoonsgegevens
#       AWBZ    16:   Algemene Wet Bijzondere Ziektekosten
#        Wsw    16:   Wet sociale werkvoorziening
#        TVS    16:   Taakstelling Volg Systeem
#         BW    15:   Burgerlijk Wetboek
#        PvE    14:   programma van eisen
#        Bro    13:   Besluit ruimtelijke ordening
#       CRvB    13:   Centrale Raad van Beroep
#         VE    12:   voorschoolse educatie
#        BRP    12:   Basis Registratie Personen
#         OM    11:   Openbaar Ministerie
#        Bbz    10:   Besluit bijstandsverlening zelfstandigen
#        WMO    10:   Wet Maatschappelijke Ondersteuning
#        WMO    10:   Wet maatschappelijke ondersteuning
#         WI    10:   Wet Inburgering
#        GBA    10:   Gemeentelijke Basis Administratie
#        CBF    10:   Centraal Bureau Fondsenwerving
#        KBR    10:   Kenniscentrum Bestuursdienst Rotterdam
#        WSW    10:   Wet sociale werkvoorziening
#       Wsnp     9:   Wet schuldsanering natuurlijke personen
#        KvK     9:   Kamer van Koophandel
#       Awir     9:   Algemene wet inkomensafhankelijke regelingen
#        CVV     9:   Collectief Vraagafhankelijk Vervoer
#         Wi     9:   Wet inburgering
#        ZIN     9:   Zorg in Natura
#        Wgr     9:   Wet gemeenschappelijke regelingen
#         AP     8:   Autoriteit Persoonsgegevens
#        NAH     8:   niet aangeboren hersenletsel
#        ADL     8:   Algemene dagelijkse levensverrichtingen
#        Wom     8:   Wet openbare manifestaties
#         GI     8:   Gecertificeerde Instelling
#        EED     8:   Ernstige Enkelvoudige Dyslexie
#        Awb     7:   Algemene Wet bestuursrecht
#         FG     7:   Functionaris Gegevensbescherming
#       Wabo     7:   Wet Algemene Bepalingen Omgevingsrecht
#        AHN     7:   Actueel Hoogtebestand Nederland
#        AFM     7:   Autoriteit Financiële Markten
#         VE     7:   Voorschoolse educatie
#        VGI     7:   Verklaring Geregistreerd Inkomen
#        EER     7:   Europese Economische Ruimte
#       Appa     7:   Algemene pensioenwet politieke ambtsdragers
#        KCA     7:   Klein Chemisch Afval
#        UWV     7:   Uitvoeringsinstituut Werknemers Verzekeringen
#       RTIV     7:   Regeling Toegelaten Instellingen Volkshuisvesting
#        LTI     7:   Landelijke Tarieven Index
#         GO     7:   Georganiseerd Overleg
#       EMVI     7:   economisch meest voordelige inschrijving
#        kca     7:   klein chemisch afval
#       WSNP     6:   Wet schuldsanering natuurlijke personen
#       VTLB     6:   vrij te laten bedrag
#        BBT     6:   Best Beschikbare Technieken
#        KCC     6:   Klant Contact Centrum
#       CISO     6:   Chief Information Security Officer
#        SMI     6:   Sociaal Medische Indicatie
#       Bevi     6:   Besluit externe veiligheid inrichtingen
#         WI     6:   Wet inburgering
#         GS     6:   Gedeputeerde Staten
#       AVOI     6:   Algemene verordening ondergrondse infrastructuren
#        KCA     6:   klein chemisch afval
#        VPT     6:   volledig pakket thuis
#        PvE     6:   Programma van Eisen
#         en     6:   even nummers
#        WOZ     6:   waardering onroerende zaken
#        WSW     6:   Wet Sociale Werkvoorziening
#        UEA     6:   Uniform Europees Aanbestedingsdocument
#        WEB     6:   Wet educatie beroepsonderwijs
#        CAP     6:   Collectieve Arbeidsvoorwaardenregeling Provincies
#        DUO     6:   Dienst Uitvoering Onderwijs
#        MVO     5:   Maatschappelijk Verantwoord Ondernemen
#        DDP     5:   Delivered Duty Paid
#        DOR     5:   Digitale Opkopers Register
#        APV     5:   Algemene Plaatselijke verordening
#        APV     5:   algemene plaatselijke verordening
#        ICT     5:   informatie communicatie technologie
#        GHG     5:   Gemiddeld Hoogste Grondwaterstand
#        GLG     5:   gemiddeld laagste grondwaterstand
#       WABO     5:   Wet algemene bepalingen omgevingsrecht
#        OMG     5:   Outlaw Motor Gang
#        SMI     5:   sociaal medische indicatie
#        KNA     5:   Kwaliteitsnorm Nederlandse Archeologie
#        NJI     5:   Nederlands Jeugd Instituut
#         BW     5:   Beschermd wonen
#        ADL     5:   Algemene Dagelijkse Levensverrichtingen
#        WLZ     5:   Wet Langdurige Zorg
#         PV     5:   proces verbaal
#        VOW     5:   verdwenen onbekend waarheen
#        PUV     5:   Platform Uitvoering Voorrangsregeling
#       vvgb     5:   verklaring van geen bedenkingen
#       Wmcz     5:   Wet medezeggenschap cliënten zorginstellingen
#        Wiw     5:   Wet inschakeling werkzoekenden
#       LBIO     5:   Landelijk Bureau Inning Onderhoudsbijdragen
#        MvT     5:   Memorie van Toelichting
#       LOGA     5:   Landelijk Overleg Gemeentelijke Arbeidsvoorwaarden
#       Wkpb     5:   Wet kenbaarheid publiekrechtelijke beperkingen
#       IKAW     5:   Indicatieve Kaart Archeologische Waarden
#       PMIO     5:   pedagogisch medewerkers in ontwikkeling
#        Wvg     5:   Wet voorzieningen gehandicapten
#        VWk     5:   Verordening Wet kinderopvang
#        HIC     4:   High Impact Crimes
#        Awb     4:   Algemene Wet Bestuursrecht
#        Bbz     4:   Besluit bijstandverlening zelfstandigen
#        Wmo     4:   Wet Maatschappelijke Ondersteuning
#         AB     4:   Algemeen Bestuur
#         MO     4:   Maatschappelijke Ontwikkeling
#         GR     4:   Gemeenschappelijke Regeling
#        AIO     4:   aanvullende inkomensvoorziening ouderen
#        GHG     4:   gemiddeld hoogste grondwaterstand
#        LOB     4:   Last onder bestuursdwang
#        PPS     4:   Publiek Private Samenwerking
#        WOM     4:   Wet openbare manifestaties
#         ba     4:   bij afwezigheid
#        BGT     4:   Basisregistratie Grootschalige Topografie
#        AWB     4:   Algemene Wet Bestuursrecht
#       Awbz     4:   Algemene wet bijzondere ziektekosten
#        ADL     4:   algemeen dagelijkse levensverrichtingen
#         WA     4:   wettelijke aansprakelijkheidsverzekering
#        BGL     4:   beschikking geen loonheffingen
#        ZiN     4:   Zorg in Natura
#        WED     4:   Wet Economische Delicten
#        WKO     4:   Warmte Koude Opslag
#        Wob     4:   Wet openbaarheid bestuur
#        EED     4:   ernstige enkelvoudige dyslexie
#        NNB     4:   Natuur Netwerk Brabant
#         OV     4:   openbaar vervoer
#        BIR     4:   Bestuurlijk Informatiecentrum Rotterdam
#       AMvB     4:   Algemene Maatregel van Bestuur
#        WEB     4:   WEB.Wet educatie beroepsonderwijs
#       Btag     4:   Besluit tarieven ambtshandelingen gerechtsdeurwaarders
#         PS     4:   Provinciale Staten
#       SBBI     4:   Sociaal Belang Behartigende Instelling
#        LVB     4:   licht verstandelijke beperking
#        AMK     4:   Archeologische Monumenten Kaart
#       IKAW     4:   Indicatieve kaart Archeologische Waarden
#        CHS     4:   Cultuurhistorische Hoofd Structuur
#        BAO     4:   Besluit Aanbestedingsregels Overheidsopdrachten
#        EVC     4:   Erkenning Verworven Competenties
#        APV     3:   Algemeen Plaatselijke Verordening
#        CIZ     3:   Centrum indicatiestelling zorg
#       WSNP     3:   Wet schuldhulpverlening natuurlijke personen
#        ASV     3:   Algemene Subsidie Verordening
#        Bal     3:   Besluit activiteiten leefomgeving
#        WIN     3:   Wet Inburgering Nieuwkomers
#         RO     3:   Ruimtelijke Ontwikkeling
#         MO     3:   Maatschappelijke Opvang
#        BBT     3:   beste beschikbare technieken
#       Wabo     3:   wet algemene bepalingen omgevingsrecht
#        GHG     3:   gemiddelde hoogste grondwaterstand
#        GHG     3:   Gemiddelde Hoogste Grondwaterstand
#        GLG     3:   gemiddelde laagste grondwaterstand
#        KCC     3:   Klanten Contact Centrum
#        CAK     3:   Centraal administratie kantoor
#         VE     3:   van een
#        BIO     3:   Baseline Informatiebeveiliging Overheid
#        DSO     3:   Digitaal Stelsel Omgevingswet
#        AED     3:   Automatische Externe Defibrillator
#        WNT     3:   Wet Normering Topinkomens
#        VMC     3:   Visual Meteorological Conditions
#        NNN     3:   Natuur Netwerk Nederland
#        Bbl     3:   Besluit bouwwerken leefomgeving
#         BW     3:   Beschermd Wonen
#        AWB     3:   Algemene wet bestuursrecht
#        VNG     3:   Vereniging Nederlandse Gemeenten
#        TTO     3:   Toegelaten Taxi Organisatie
#        ADL     3:   algemene dagelijkse levensbehoeften
#        Apv     3:   Algemene Plaatselijke Verordening
#        MPT     3:   modulair pakket thuis
#        ZIN     3:   Zorg in natura
#         PV     3:   persoonlijke verzorging
#        NAP     3:   Normaal Amsterdams Peil
#        WKO     3:   warmte koude opslag
#        PAS     3:   Programmatische Aanpak Stikstof
#         GI     3:   gecertificeerde instelling
#         HO     3:   Huishoudelijke ondersteuning
#        WOZ     3:   Waardering Onroerende Zaken
#         DB     3:   Dagelijks Bestuur
#        WAM     3:   Wet aansprakelijkheidsverzekering motorrijtuigen
#        AMW     3:   Algemeen Maatschappelijk Werk
#        Sim     3:   Subsidieregeling instandhouding monumenten
#         OV     3:   Openbaar Vervoer
#        RBZ     3:   Regionaal Bureau Zelfstandigen
#       Blah     3:   Besluit lozing afvalwater huishoudens
#       ANBI     3:   algemeen nut beogende instelling
#       ANBI     3:   Algemeen Nut Beogende Instellingen
#         GO     3:   georganiseerd overleg
#        ABP     3:   Algemene Burgerlijke Pensioenwet
#         kk     3:   kosten koper
#        soa     3:   seksueel overdraagbare aandoeningen
#        CJP     3:   cultureel jongeren paspoort
#        SVB     3:   Sociale Verzekerings Bank
#       Wkcz     3:   Wet klachtrecht cliënten zorgsector
#       CVDR     3:   Centrale Voorziening Decentrale Regelgeving
#        KOB     3:   koopkracht oudere belastingplichtigen
#        mpt     3:   modulair pakket thuis
#        VVE     3:   Vereniging van Eigenaren
#        EOC     3:   Explosieven Opruimings Commando
#       babs     3:   buitengewoon ambtenaar burgerlijke stand
#        WVG     3:   Wet voorzieningen gehandicapten
#        MTN     3:   medium term notes
#       Wcpv     3:   Wet collectieve preventie volksgezondheid
#        ILG     3:   Investeringsbudget Landelijk Gebied
#         te     3:   tot een
#        HNO     3:   Hydrologisch Neutraal Ontwikkelen
#        BWC     3:   Bijzondere waterkerende constructie
#        VTA     3:   Visual Tree Assesment
#         HH     3:   het Huishouden
#         ve     3:   voorschoolse educatie
#        BNG     3:   Bank Nederlandse Gemeenten
#        MOP     3:   Meerjaren Onderhoud Plan
#        PVE     3:   Programma van Eisen
#        SKJ     3:   Stichting Kwaliteitszorg Jeugd
#        uov     3:   uniforme openbare voorbereidingsprocedure
#        OIO     3:   Onderzoeksraad Integriteit Overheid
#       Biab     3:   Besluit indieningsvereisten aanvraag bouwvergunning
#        DAW     3:   Deltaplan Agrarisch Waterbeheer
#        DSL     3:   Dorp Stad Land
#        Rlz     3:   Regeling langdurige zorg
#       vtlb     3:   vrij te laten bedrag
#       SRoI     2:   Social Return on Investment
#        VIC     2:   Verbijzonderde Interne Controle
#        HIC     2:   high impact crimes
#        DOR     2:   Digitaal Opkopers Register
#        VAT     2:   voorschools advies team
#       NNGB     2:   Nederlands Norm Gezond Bewegen
#        LRK     2:   Landelijke Register Kinderopvang
#        VOG     2:   Verklaring omtrent Gedrag
#        VOG     2:   Verklaring omtrent gedrag
#        APV     2:   Algemeen plaatselijke verordening
#        APV     2:   ALGEMENE PLAATSELIJKE VERORDENING
#        CIZ     2:   Centraal indicatieorgaan zorg
#        CIZ     2:   Centraal Indicatieorgaan Zorg
#       WKPB     2:   Wet kenbaarheid publiekrechtelijke beperkingen
#         GM     2:   Gemeentelijke monumenten
#       VTLB     2:   Vrij te laten bedrag
#       VTLB     2:   Vrij Te Laten Bedrag
#        Wmo     2:   Wet maatschappelijk ondersteuning
#        ASV     2:   Algemene Subsidieverordening Veenendaal
#         RO     2:   Ruimtelijke Ordening
#         FG     2:   functionaris gegevensbescherming
#         SO     2:   speciaal onderwijs
#        BBT     2:   Beste Beschikbare Technieken
#      ALARA     2:   As Low As Reasonably Achievable
#         GR     2:   gemeenschappelijke regeling
#        RES     2:   Regionale Energie Strategie
#        Who     2:   Wet hergebruik overheidsinformatie
#        BEA     2:   Bomen Effect Analyse
#        SCP     2:   Sociaal Cultureel Planbureau
#        DvE     2:   Delft voor Elkaar
#       WABO     2:   Wet Algemene Bepalingen Omgevingsrecht
#        BSP     2:   Bureau Stedelijke Planning
#        OvJ     2:   Officier van Justitie
#        AFM     2:   Autoriteit financiële Markten
#        OMG     2:   Outlaw Motorcycle Gang
#        LOD     2:   Last onder dwangsom
#        LOD     2:   last onder dwangsom
#       CISO     2:   chief information security officer
#        WOM     2:   Wet Openbare Manifestaties
#         VE     2:   Voorschoolse Educatie
#        MER     2:   Milieu Effect Rapportage
#       VVGB     2:   verklaring van geen bedenkingen
#       BENG     2:   Bijna Energie Neutrale Gebouwen
#        SBI     2:   Standaard Bedrijfs Indeling
#        Wlz     2:   Wet langdurige Zorg
#        Wlz     2:   Wet Langdurige Zorg
#        SMI     2:   Sociaal medische indicatie
#        CPO     2:   Collectief Particulier Opdrachtgeverschap
#        Bkl     2:   Besluit kwaliteit leefomgeving
#        AED     2:   automatische externe defibrillators
#        MWC     2:   Maatschappelijk Welzijn Coevorden
#        VFR     2:   Visual Flight Rules
#       Appa     2:   Algemene pensioenwet politiek ambtsdragers
#       Tozo     2:   Tijdelijke overbruggingsregeling zelfstandig ondernemers
#       ZMLK     2:   Zeer moeilijk lerende kinderen
#        WGA     2:   werkhervatting gedeeltelijk arbeidsongeschikten
#        WGA     2:   Wet gemeentelijke antidiscriminatievoorzieningen
#        WGA     2:   Wet Gemeentelijke Antidiscriminatievoorzieningen
#       RRGS     2:   Risico Register Gevaarlijke Stoffen
#       UAVG     2:   Uitvoeringswet Algemene Verordening Gegevensbescherming
#         WM     2:   Wet milieubeheer
#        DMG     2:   Discriminatie Meldpunt Groningen
#        bvo     2:   bruto vloer oppervlak
#        LBB     2:   Landelijk Bureau Bibob
#        AWB     2:   algemene Wet Bestuursrecht
#        KWO     2:   Koude Warmte Opslag
#         ME     2:   myalgische encefalomyelitis
#        BRP     2:   Basis registratie Personen
#        LOS     2:   Lokale Ontwikkelings Strategie
#        AVB     2:   aansprakelijkheidsverzekering voor bedrijven
#        KCA     2:   Klein chemisch afval
#       NUVO     2:   Nederlandse Unie van Optiekbedrijven
#         PV     2:   Persoonlijke Verzorging
#         PV     2:   Persoonlijke verzorging
#        Wls     2:   Wet lokaal spoor
#        PMV     2:   Provinciale Milieu Verordening
#        BBL     2:   Beroeps Begeleidende Leerweg
#      Wbmgp     2:   Wet bijzondere maatregelen grootstedelijke problematiek
#        CBR     2:   Centraal Bureau Rijvaardigheden
#        Woo     2:   Wet open overheid
#        Beh     2:   Besluit emissiearme huisvesting
#       Waga     2:   Wet arbeidsvoorwaarden grensoverschrijdende arbeid
#        ITP     2:   Integraal Traject Plan
#        bob     2:   binnen onderkant buis
#        Wbb     2:   Wet Bodem Bescherming
#        WAM     2:   Wet Aansprakelijkheidsverzekering Motorvoertuigen
#        VvE     2:   Vereniging van Eigenaren
#        VvE     2:   Vereniging van Eigenaars
#        PSN     2:   Provinciale Subsidieregeling Natuurbeheer
#       PSAN     2:   Provinciale Subsidieregeling Agrarisch Natuurbeheer
#       SROI     2:   Social Return On Investment
#        BAD     2:   Budget Adviesbureau Deventer
#       OOGO     2:   Op Overeenstemming Gericht Overleg
#        AMW     2:   algemeen maatschappelijk werk
#       GIDS     2:   Gezond in de Stad
#        AIV     2:   Advies instructie voorlichting
#        OMD     2:   Ondersteuning maatschappelijke deelname
#        OZB     2:   Onroerend Zaak Belasting
#        Wpg     2:   Wet publieke gezondheid
#        Rbz     2:   Regionaal bureau zelfstandigen
#       Blbi     2:   Besluit lozen buiten inrichtingen
#       Blbi     2:   Besluit lozingen buiten inrichtingen
#        SNN     2:   Samenwerkingsverband Noord Nederland
#        AOG     2:   Activerende ondersteuning groep
#        GOT     2:   Gespecialiseerde Ondersteuning Thuis
#        LOT     2:   Lichte Ondersteuning Thuis
#        BOT     2:   Basis Ondersteuning Thuis
#        BOG     2:   Basis ondersteuning groep
#        GOG     2:   Gespecialiseerde ondersteuning groep
#        adl     2:   algemene dagelijkse levensverrichtingen
#        BBA     2:   Besluit beheer autowrakken
#        VSO     2:   voortgezet speciaal onderwijs
#        SWS     2:   Stichting Waarborgfonds Sport
#       AMvB     2:   algemene maatregel van bestuur
#        KGA     2:   Klein Gevaarlijk Afval
#         SW     2:   sociale werkvoorziening
#       LOBA     2:   Landelijk Overleg Brandweerspecifieke Arbeidsvoorwaarden
#        PAM     2:   Periodiek Arbeidsgeneeskundige Monitor
#        VIK     2:   Verstrekken Informatie Klantgroepen
#        WPA     2:   Wet privatisering ABP
#       BEVI     2:   Besluit Externe Veiligheid Inrichtingen
#         VO     2:   Voortgezet Onderwijs
#        VTT     2:   Veilig Thuis Twente
#       RAAM     2:   Regionale Activiteiten Agenda Milieu
#        zzp     2:   zelfstandigen zonder personeel
#        zzp     2:   zelfstandige zonder personeel
#        vpt     2:   volledig pakket thuis
#        VVE     2:   verklaring voorschoolse educatie
#       JOGG     2:   Jongeren Op Gezond Gewicht
#       POET     2:   Parkeren Op Eigen Terrein
#        AMV     2:   Algemene Muzikale Vorming
#        WSG     2:   William Schrikker Groep
#        Wed     2:   Wet economische delicten
#        BOR     2:   Beheer Openbare Ruimte
#        OLS     2:   Oud Limburgs Schuttersfeest
#       VNCO     2:   van Nederlandse Circus Ondernemingen
#        RvR     2:   Raad van Rechtsbijstand
#        GIR     2:   Gemeentelijk Incidenten Registratiesysteem
#       CJIB     2:   Centraal Justitieel Incasso Bureau
#        ROA     2:   Regeling Opvang Asielzoekers
#        SOA     2:   seksueel overdraagbare aandoeningen
#        ASB     2:   Agrarische Stichting Blaricum
#       SVGV     2:   Stichting Vernieuwing Gelderse Vallei
#        VON     2:   vrij op naam
#        NNI     2:   Nederlands Normalisatie instituut
#         Wk     2:   Wet kinderopvang
#         Wk     2:   Wet Kinderopvang
#         OB     2:   Ondersteunende Begeleiding
#        MOA     2:   moeilijk objectiveerbare aandoening
#        Wvo     2:   Wet verontreiniging oppervlaktewateren
#       IASZ     2:   intergemeentelijke afdeling Sociale Zaken
#        ISV     2:   Investeringsbudget Stedelijke Vernieuwing
#        ISV     2:   investeringsbudget stedelijke vernieuwing
#         PR     2:   plaatsgebonden risico
#        Wvg     2:   Wet voorkeursrecht gemeenten
#       UMTS     2:   Universal Mobile Telecommunications System
#        KHN     2:   Koninklijke Horeca Nederland
#        LOK     2:   Landelijk Overleg Kantonrechters
#        Wnt     2:   Wet Normering Topinkomens
#       BABW     2:   Besluit Administratieve Bepalingen Wegverkeer
#         ve     2:   Voor een
#        ISD     2:   Intergemeentelijke Sociale Dienst
#        BIJ     2:   Bestuurlijke Informatie Justitiabelen
#        GBS     2:   Groeneveld Beeldschermbril Systeem
#       BHIC     2:   Brabants Historisch Informatie Centrum
#        MVI     2:   Maatschappelijk Verantwoord Inkopen
#        DNR     2:   De Nieuwe Regeling
#       WSGO     2:   werkgeversvereniging Samenwerkende Gemeentelijke Organisaties
#       CCvD     2:   Centraal College van Deskundigen
#        PGA     2:   Personeelsregelingen Gemeente Amsterdam
#        Win     2:   Wet inburgering nieuwkomers
#         EU     2:   Europese Unie
#        nog     2:   niet openbaar gemaakt
#       SFAV     2:   Stichting Financiering Afvalstoffen Visserij
#       Bevb     2:   Besluit externe veiligheid buisleidingen
#       Revb     2:   Regeling externe veiligheid buisleidingen
#        SRE     2:   Samenwerkingsverband Regio Eindhoven
#       ROEB     2:   Regionaal Overleg Eindhoven Bouwtoezicht
#        MGE     2:   Maatschappelijk Gebonden Eigendom
#         so     2:   speciaal onderwijs
#        vso     2:   voortgezet speciaal onderwijs
#         BT     2:   bruto ton
#        RHC     2:   Regionaal Historisch Centrum
#       VPPG     2:   voor plaatselijke politieke groeperingen
#        BWS     2:   besluit woninggebonden subsidies
#        WSV     2:   Wet stedelijke vernieuwing
#        CvZ     2:   College van Ziekenhuisvoorzieningen
#        Bza     2:   Besluit zorgaanspraken AWBZ
#       SPVE     2:   stedenbouwkundige programma van eisen

# %%
curs.execute('SELECT plaintext  FROM bwb  LIMIT 10000') # TODO: change to wetsuite.data.load() after creating a dataset
per_doc_results = []
for text, in curs:
    result = wetsuite.phrases.abbreviations.find_abbrevs(text)
    #for ab, words in result: # individual results
    #    print( ab, words )
    per_doc_results.append( result )    


### test the cleaning - report only things that were explained the same way in two or more documents
min_doc_occur = 2

report = []
abbrev_count = wetsuite.phrases.abbreviations.count_results( per_doc_results )
for abbrev, words_count in abbrev_count.items():
    for words, count in words_count.items():
        if count >= min_doc_occur:   # the point of that structure: being able to ignore rarer explanations
            report.append( (abbrev, count, ' '.join(words) ) )

report.sort(key=lambda tup: -tup[1]) # sort by count descending
#report.sort(key=lambda tup: (tup[0], -tup[1])) # sort/group by abbreviation alphabetically, then by count descending
for abbrev, count, expl in report:
    print( '%10s   %3d:   %s'%( abbrev, count, expl ) )
# Out:
#       ETSI    17:   Europese Telecommunicatie Standaardisatie Instituut
#       Cotg    14:   Centraal orgaan tarieven gezondheidszorg
#        IMO     8:   Internationale Maritieme Organisatie
#        IEC     8:   Internationale Electrotechnische Commissie
#        VNG     7:   van Nederlandse Gemeenten
#        NNI     7:   Nederlands Normalisatie Instituut
#        ONP     5:   Open Network Provision
#       BTZR     4:   Besluit tegemoetkoming ziektekosten rijkspersoneel
#       AWVN     4:   Algemene Werkgeversvereniging VNO NCW
#        NFP     4:   Nederlands Fellowships Programma
#        AVR     4:   aanvraag vaststelling rijksvergoeding
#        MAL     3:   Mededeling aan Luchtvarenden
#       KNIL     3:   Koninklijk Nederlands Indonesisch Leger
#        TNO     3:   Toegepast Natuurwetenschappelijk Onderzoek
#        TNO     3:   toegepast natuurwetenschappelijk onderzoek
#       ICPR     3:   Interdepartementale Coördinatievergadering Personeelsbeleid Rijksdienst
#        IEC     3:   Internationale Elektrotechnische Commissie
#         vo     3:   voortgezet onderwijs
#        ITU     3:   Internationale Telecommunicatie Unie
#        DPZ     3:   Directie Politieke Zaken
#        BIR     3:   Besluit inkomenstoeslag rijkspersoneel
#        VOS     3:   vluchtige organische stoffen
#        WPA     3:   Wet privatisering ABP
#       KBvG     3:   Koninklijke Beroepsorganisatie van Gerechtsdeurwaarders
#       Btzr     3:   Besluit tegemoetkoming ziektekosten rijkspersoneel
#       BBSH     3:   Besluit beheer sociale huursector
#        RvC     3:   Raad voor Cultuur
#        HTB     2:   hogere technische bekwaamheid
#         ND     2:   Newcastle Disease
#         VS     2:   Vesiculaire stomatitis
#       AWBZ     2:   Algemene Wet Bijzondere Ziektekosten
#         EU     2:   Europese Unie
#       DBZV     2:   Dienst Buitenlandse Zaken Voorzieningenstelsel
#        EEG     2:   Europese Economische Gemeenschap
#         VK     2:   Verenigd Koninkrijk
#        INS     2:   inertial navigation system
#        INS     2:   Integrale Normstelling Stoffen
#        CBM     2:   Centraal bureau motorrijtuigenbelasting
#       NVvR     2:   Nederlandse Vereniging voor Rechtspraak
#        RvO     2:   Reglement van Orde
#        WAM     2:   Wet aansprakelijkheidsverzekering motorrijtuigen
#         GO     2:   Georganiseerd Overleg
#        CRI     2:   Centrale Recherche Informatiedienst
#        CBR     2:   Centraal Bureau Rijvaardigheidsbewijzen
#       SAIP     2:   Stichting Administratie Indonesische Pensioenen
#       BOOM     2:   Bureau Ontnemingswetgeving Openbaar Ministerie
#        MOT     2:   Meldpunt Ongebruikelijke Transacties
#        MEW     2:   Monteur elektrotechnisch wikkelen
#        DUO     2:   Dienst Uitvoering Ontslaguitkeringsregelingen
#        DUO     2:   Dienst Uitvoering Onderwijs
#       COTG     2:   Centraal Orgaan Tarieven Gezondheidszorg
#        DTA     2:   deskundig toezichthouder asbestsloop
#        WHS     2:   Working Holiday Scheme
#        WHP     2:   Working Holiday Programme
#       BPCO     2:   Besturenraad Protestants Christelijk Onderwijs
#        VGS     2:   voor Gereformeerd Schoolonderwijs
#        Awb     2:   Algemene wet bestuursrecht
#        BSE     2:   boviene spongiforme encefalopathie
#        CAS     2:   Centrale Archief Selectiedienst
#      Pemba     2:   premiedifferentiatie en marktwerking bij arbeidsongeschiktheidsverzekeringen
#        MAP     2:   Milieu Actie Plan
#        SUS     2:   Sanerings Urgentie Systematiek
#        TCB     2:   Technische Commissie Bodembescherming
#       IATA     2:   International Air Transport Association
#        GAT     2:   General Air Traffic
#        OGT     2:   Overzicht Geregistreerde Telgegevens
#        KvW     2:   Keuringsdienst van Waren
#       KBVO     2:   Katholieke Bond Voortgezet Onderwijs
#        Bhw     2:   Besluit huurprijzen woonruimte
#       BCPC     2:   British Crop Protection Council
#       POBB     2:   Programma Ondersteuning Buitenlands Beleid
#       POBB     2:   programma Ondersteuning Buitenlands Beleid
#       BVOM     2:   bureau verkeershandhaving openbaar ministerie

# %%
import wetsuite.datasets
wetsuite.datasets.load('bwb-textonly')

wetsuite.datasets.load('cvdr-textonly')
